# %%
# Load Packages
from __future__ import unicode_literals, print_function

import plac #  wrapper over argparse
import random
from pathlib import Path
import spacy
from tqdm import tqdm, tqdm_notebook # loading bar 
import pandas as pd
import re
from pprint import pprint
from nltk.tokenize import sent_tokenize
import numpy as np

from spacy.util import minibatch, compounding

# %% [markdown]
# # Abrindo e gerando Datasets

# %% [markdown]
# ### Entidade logradouro

# %%
# Obtendo dados crus de endereço

dataset = pd.read_csv("201906AGENCIAS.CSV")
dset = dataset.iloc[:-2,4:10].values  # tipo nparray object
pd_dset = pd.DataFrame(dset) # caso queira visualizar

pd_dset['Join'] = pd_dset[pd_dset.columns[0:]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)
pd_dset.head(5)
# Out:
#                                           0  \
# 0  R.GUILHERME MOREIRA,315
# 1  AV.PRES.VARGAS,248
# 2  R.QUINZE DE NOVEMBRO,195
# 3  PCA.DAS QUATRO JORNADAS,11
# 4  SEXTA AVENIDA,600
#
#                                                    1  \
# 0  SUBLOJA,LOJA E 2.ANDAR                        ...
# 1  1.E 2.ANDARES                                 ...
# 2                                                ...
# 3  MEZANINO                                      ...
# 4  SECRETARIA DA EDUCACAO-TERREO                 ...
#
#                                 2          3  \
# 0  CENTRO                          69005-300
# 1  CAMPINA                         66010-900
# 2  CENTRO                          11010-908
# 3  CENTRO                          28010-000
# 4  CAB                             41745-002
#
#                                                    4   5  \
# 0  MANAUS                                        ...  AM
# 1  BELEM                                         ...  PA
# 2  SANTOS                                        ...  SP
# 3  CAMPOS DOS GOYTACAZES                         ...  RJ
# 4  SALVADOR                                      ...  BA
#
#                                                 Join
# 0  R.GUILHERME MOREIRA,315                 ;SUBLO...
# 1  AV.PRES.VARGAS,248                      ;1.E 2...
# 2  R.QUINZE DE NOVEMBRO,195                ;     ...
# 3  PCA.DAS QUATRO JORNADAS,11              ;MEZAN...
# 4  SEXTA AVENIDA,600                       ;SECRE...

# %%
# Tratando endereço completo do DataFrame
dset = np.array(pd_dset)
end_lista = []

for i in range(len(dset)):
    str_raw = dset[i][6]
    str_tratada = re.sub(r'[ ]{2,}', "",str_raw) # Tirando espaços excedentes no final do endereço
    str_tratada = re.sub(r'[;]{1,}', "; ", str_tratada) # Para complementos vazios, para não ter 2 ";"
    str_tratada = str_tratada.lower()
    
    end_lista.append(str_tratada)

end_lista[:3]
# Out:
# ['r.guilherme moreira,315; subloja,loja e 2.andar; centro; 69005-300; manaus; am',
#  'av.pres.vargas,248; 1.e 2.andares; campina; 66010-900; belem; pa',
#  'r.quinze de novembro,195; centro; 11010-908; santos; sp']

# %%
# Lógica para extrair posição do logradouro:
# Dividir a String inteira por ";", pegar o len do primeiro split
# len de LOGRA é de 0 até len do primeiro split

print(end_lista[0])
split = end_lista[0].split(";")
print(split)
print(split[0])
print(len(split[0]))
# Out:
# r.guilherme moreira,315; subloja,loja e 2.andar; centro; 69005-300; manaus; am
# ['r.guilherme moreira,315', ' subloja,loja e 2.andar', ' centro', ' 69005-300', ' manaus', ' am']
# r.guilherme moreira,315
# 23

# %%
# Extraindo iob com entidade apenas de logradouro

iob = []

for i in range(len(end_lista)):
    split = end_lista[i].split(";")
    len_logra = len(split[0])
    iob_dict = {"entities": [(0, len_logra-1,'LOGRA')]}
    end_lista[i] = end_lista[i].replace(";", " ")
    end_lista[i] = end_lista[i].replace(",", " ")
    end_lista[i] = re.sub(r'[ ]{2,}', " ", end_lista[i])

    
    tupla = (end_lista[i], iob_dict)
    iob.append(tupla)

FULL_DATA = iob

# %%
print(FULL_DATA[0])
print(FULL_DATA[1])
print(FULL_DATA[2])
print(FULL_DATA[5:15])
# Out:
# ('r.guilherme moreira 315 subloja loja e 2.andar centro 69005-300 manaus am', {'entities': [(0, 22, 'LOGRA')]})
# ('av.pres.vargas 248 1.e 2.andares campina 66010-900 belem pa', {'entities': [(0, 17, 'LOGRA')]})
# ('r.quinze de novembro 195 centro 11010-908 santos sp', {'entities': [(0, 23, 'LOGRA')]})
# [('av.rio branco 240 1.andar recife antigo 50030-310 recife pe', {'entities': [(0, 16, 'LOGRA')]}), ('av.santos dumont 2828 5.andar aldeota 60150-162 fortaleza ce', {'entities': [(0, 20, 'LOGRA')]}), ('pca.tiradentes 410 1.andar centro 80020-100 curitiba pr', {'entities': [(0, 17, 'LOGRA')]}), ('r.uruguai 185 5.andar centro 90010-901 porto alegre rs', {'entities': [(0, 12, 'LOGRA')]}), ('pca.1817 129 1.andar centro 58013-010 joao pessoa pb', {'entities': [(0, 11, 'LOGRA')]}), ('pca.odilon resende andrade 76 centro 37410-000 tres coracoes mg', {'entities': [(0, 28, 'LOGRA')]}), ('av fernandes lima 2591 terreo farol 57057-972 maceio al', {'entities': [(0, 22, 'LOGRA')]}), ('r.treze de junho 914 centro 79300-040 corumba ms', {'entities': [(0, 19, 'LOGRA')]}), ('av.leopoldino de oliveira 3635 centro 38010-000 uberaba mg', {'entities': [(0, 29, 'LOGRA')]}), ('pca.quinze de novembro 321 centro 88010-400 florianopolis sc', {'entities': [(0, 25, 'LOGRA')]})]

# %%
# Criação da base de teste e treinamento

n_test= 0.1 # Porcentagem para base de teste
test_n = round(len(FULL_DATA) * n_test)

# Divisao em Train Test Val

def gerador_bases(dataset, n):
    indices_random = random.sample(range(0,len(dataset)-1), n)
    base_teste_n = []
    base_treinamento_n = []
    
    for i in range(n):
        base_teste_n.append(dataset[indices_random[i]])

    for j in range(len(dataset)):
        if(j not in indices_random):
            base_treinamento_n.append(dataset[j])
            
    return base_teste_n, base_treinamento_n


base_teste, base_treinamento = gerador_bases(FULL_DATA, test_n)

random.shuffle(base_treinamento)
random.shuffle(base_teste)

print("Treinamento: " + str(len(base_treinamento)), "\nTeste: " + str(len(base_teste)), "\nTotal: " + str(len(FULL_DATA)))
# Out:
# Treinamento: 19202
# Teste: 2134
# Total: 21336

# %%
for i in range(5):
    print(base_treinamento[i])
# Out:
# ('av. cardeal eugenio pacelli 735 cidade industrial 32210-000 contagem mg', {'entities': [(0, 31, 'LOGRA')]})
# ('av. ceci 1850 tambor� 06460-120 barueri sp', {'entities': [(0, 13, 'LOGRA')]})
# ('r.miguel braz arroteia 661 centro 17260-000 itaju sp', {'entities': [(0, 25, 'LOGRA')]})
# ('av brasil zona 01 zona 01 87013-000 maringa pr', {'entities': [(0, 9, 'LOGRA')]})
# ('rua jose pires neto 314 lojas 01 e 02 cambui 13025-170 campinas sp', {'entities': [(0, 23, 'LOGRA')]})

# %% [markdown]
# # Carregando o modelo

# %%
# Define our variables

model = None
output_dir=Path(".")
n_iter= 100 # número de épocas
batch_size = 16

# %%
# Setting up the pipeline and entity recognizer.
if model is not None:
    nlp = spacy.load(model)  # load existing spacy model
    print("Loaded model '%s'" % model)
else:
    lan = 'pt'
    nlp = spacy.blank(lan)  # create blank Language class
    print("Created blank '%s' model" % lan)
    
if 'ner' not in nlp.pipe_names:
    ner = nlp.create_pipe('ner')
    nlp.add_pipe(ner)
    print('Added new NER')
else:
    ner = nlp.get_pipe('ner')
    print('Got an old NER')
# Out:
# Created blank 'pt' model
# Added new NER

# %%
# create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
if 'ner' not in nlp.pipe_names:
    ner = nlp.create_pipe('ner')
    nlp.add_pipe(ner, last=True)
# otherwise, get it so we can add labels
else:
    ner = nlp.get_pipe('ner')

# %% [markdown]
# ## Treinamento

# %%
print("Batch size: ", batch_size)
print("Épocas: ", n_iter)
print()

# add labels
for _, annotations in base_treinamento:
    for ent in annotations.get('entities'):
        ner.add_label(ent[2])


# get names of other pipes to disable them during training
other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
with nlp.disable_pipes(*other_pipes):  # only train NER
    optimizer = nlp.begin_training()
    for itn in range(n_iter):
        random.shuffle(base_treinamento)
        losses = {}
        batches = minibatch(base_treinamento, size=batch_size)
        
        for batch in batches:
            texts, annotations = zip(*batch)
            try:
                nlp.update(texts, annotations, sgd=optimizer, drop=0.2,
                       losses=losses)
            except:
                pass     
        
        print(itn+1, ' Losses', losses)
# Out:
# Batch size:  16
# Épocas:  100
#
# 1  Losses {'ner': 11602.628621428197}
# 2  Losses {'ner': 5276.184860599323}
# 3  Losses {'ner': 4595.871697298568}
# 4  Losses {'ner': 4241.3442721682695}
# 5  Losses {'ner': 3900.618381412886}
# 6  Losses {'ner': 3493.3100356395607}
# 7  Losses {'ner': 3618.9451190538234}
# 8  Losses {'ner': 3205.481979475259}
# 9  Losses {'ner': 3086.0042172057842}
# 10  Losses {'ner': 2962.6198100986962}
# 11  Losses {'ner': 2850.363329297907}
# 12  Losses {'ner': 2762.507619019205}
# 13  Losses {'ner': 2706.1839191763024}
# 14  Losses {'ner': 2394.040338692879}
# 15  Losses {'ner': 2100.4768702094952}
# 16  Losses {'ner': 2116.5966580680883}
# 17  Losses {'ner': 2010.862363741636}
# 18  Losses {'ner': 1856.1133115363568}
# 19  Losses {'ner': 2295.4676639147715}
# 20  Losses {'ner': 2164.5152972484448}
# 21  Losses {'ner': 1976.617942370528}
# 22  Losses {'ner': 1774.0753300385845}
# 23  Losses {'ner': 1615.6813327383754}
# 24  Losses {'ner': 1773.4604692836442}
# 25  Losses {'ner': 1724.1240108527331}
# 26  Losses {'ner': 1432.9460055158404}
# 27  Losses {'ner': 1524.7523002471785}
# 28  Losses {'ner': 1412.0966551807035}
# 29  Losses {'ner': 1578.4933970086113}
# 30  Losses {'ner': 1217.2507647771733}
# 31  Losses {'ner': 1250.1294801637405}
# 32  Losses {'ner': 1388.874097483604}
# 33  Losses {'ner': 1446.6230940100365}
# 34  Losses {'ner': 1274.9497584818587}
# 35  Losses {'ner': 1195.6144278160166}
# 36  Losses {'ner': 1087.5047155844397}
# 37  Losses {'ner': 1337.7007294502964}
# 38  Losses {'ner': 1159.0310205110804}
# 39  Losses {'ner': 1266.9740076218184}
# 40  Losses {'ner': 1220.4048309527416}
# 41  Losses {'ner': 1235.1368172886553}
# 42  Losses {'ner': 1052.0757645648812}
# 43  Losses {'ner': 1114.2557375877007}
# 44  Losses {'ner': 1067.8629296068234}
# 45  Losses {'ner': 1067.6041782790585}
# 46  Losses {'ner': 973.1503083922373}
# 47  Losses {'ner': 1131.1824532381481}
# 48  Losses {'ner': 1003.8660635249013}
# 49  Losses {'ner': 1043.5674006235479}
# 50  Losses {'ner': 1032.8646098108024}
# 51  Losses {'ner': 959.6697605138048}
# 52  Losses {'ner': 817.653244433083}
# 53  Losses {'ner': 920.1142245307661}
# 54  Losses {'ner': 1001.9103980662244}
# 55  Losses {'ner': 1049.2032950650314}

# %%
# test the trained model
for text, _ in base_teste:
    doc = nlp(text)
    print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
    print('Tokens', [(t.text, t.ent_type_, t.ent_iob) for t in doc])
    print()
# Out:
# Entities [('av. andre araujo', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('andre', 'LOGRA', 1), ('araujo', 'LOGRA', 1), ('adrianopolis', '', 2), ('69057-025', '', 2), ('manaus', '', 2), ('am', '', 2)]
#
# Entities [('praca padre francisco mira(bandeira) 6', 'LOGRA')]
# Tokens [('praca', 'LOGRA', 3), ('padre', 'LOGRA', 1), ('francisco', 'LOGRA', 1), ('mira(bandeira', 'LOGRA', 1), (')', 'LOGRA', 1), ('6', 'LOGRA', 1), ('centro', '', 2), ('a', '', 2), ('37466-000', '', 2), ('itamonte', '', 2), ('mg', '', 2)]
#
# Entities [('av. leopoldino de oliveira 3446', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('leopoldino', 'LOGRA', 1), ('de', 'LOGRA', 1), ('oliveira', 'LOGRA', 1), ('3446', 'LOGRA', 1), ('60746948', '', 2), ('centro', '', 2), ('38010-000', '', 2), ('uberaba', '', 2), ('mg', '', 2)]
#
# Entities [('av.antonio piranga 143', 'LOGRA')]
# Tokens [('av.antonio', 'LOGRA', 3), ('piranga', 'LOGRA', 1), ('143', 'LOGRA', 1), ('centro', '', 2), ('09911-160', '', 2), ('diadema', '', 2), ('sp', '', 2)]
#
# Entities [('av. carlos gomes 1385', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), 
 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('frei', 'LOGRA', 1), ('orestes', 'LOGRA', 1), ('girardi', 'LOGRA', 1), ('859', 'LOGRA', 1), ('centro', '', 2), ('12460-000', '', 2), ('campos', '', 2), ('do', '', 2), ('jordao', '', 2), ('sp', '', 2)]
#
# Entities [('av.ataulfo de paiva 980', 'LOGRA')]
# Tokens [('av.ataulfo', 'LOGRA', 3), ('de', 'LOGRA', 1), ('paiva', 'LOGRA', 1), ('980', 'LOGRA', 1), ('leblon', '', 2), ('22440-035', '', 2), ('rio', '', 2), ('de', '', 2), ('janeiro', '', 2), ('rj', '', 2)]
#
# Entities [('avenida carlos botelho 718', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('carlos', 'LOGRA', 1), ('botelho', 'LOGRA', 1), ('718', 'LOGRA', 1), ('s', '', 2), ('�', '', 2), ('o', '', 2), ('dimas', '', 2), ('13416-145', '', 2), ('piracicaba', '', 2), ('sp', '', 2)]
#
# Entities [('rua marechal floriano peixoto 477', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('marechal', 'LOGRA', 1), ('floriano', 'LOGRA', 1), ('peixoto', 'LOGRA', 1), ('477', 'LOGRA', 1), ('centro', '', 2), ('28460-000', '', 2), ('miracema', '', 2), ('rj', '', 2)]
#
# Entities [('av.goias 1454', 'LOGRA')]
# Tokens [('av.goias', 'LOGRA', 3), ('1454', 'LOGRA', 1), ('v.sta.paula', '', 2), ('09521-300', '', 2), ('sao', '', 2), ('caetano', '', 2), ('do', '', 2), ('sul', '', 2), ('sp', '', 2)]
#
# Entities [('rua joaquim nabuco', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('joaquim', 'LOGRA', 1), ('nabuco', 'LOGRA', 1), ('a', '', 2), ('centro', '', 2), ('93310-002', '', 2), ('novo', '', 2), ('hamburgo', '', 2), ('rs', '', 2)]
#
# Entities [('av. santana', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('santana', 'LOGRA', 1), ('jardim', '', 2), ('amanda', '', 2), ('i', '', 2), ('13188-000', '', 2), ('hortolandia', '', 2), ('sp', '', 2)]
#
# Entities [('av. maximiliano gaidzinski 98', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('maximiliano', 'LOGRA', 1), ('gaidzinski', 'LOGRA', 1), ('98', 'LOGRA', 1), ('centro', '', 2), ('88845-000', '', 2), ('cocal', '', 2), ('do', '', 2), ('sul', '', 2), ('sc', '', 2)]
#
# Entities [('av. de cillo 1600', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('de', 'LOGRA', 1), ('cillo', 'LOGRA', 1), ('1600', 'LOGRA', 1), ('cidade', '', 2), ('jardim', '', 2), ('i', '', 2), ('13466-550', '', 2), ('americana', '', 2), ('sp', '', 2)]
#
# Entities [('r. fulvio aducci 1229', 'LOGRA')]
# Tokens [('r.', 'LOGRA', 3), ('fulvio', 'LOGRA', 1), ('aducci', 'LOGRA', 1), ('1229', 'LOGRA', 1), ('loja', '', 2), ('1', '', 2), ('estreito', '', 2), ('88075-001', '', 2), ('florianopolis', '', 2), ('sc', '', 2)]
#
# Entities [('av.prof.luciano gualberto 660', 'LOGRA')]
# Tokens [('av.prof.luciano', 'LOGRA', 3), ('gualberto', 'LOGRA', 1), ('660', 'LOGRA', 1), ('cid.universitaria', '', 2), ('05508-010', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('av.estados unidos 561-3.andar', 'LOGRA')]
# Tokens [('av.estados', 'LOGRA', 3), ('unidos', 'LOGRA', 1), ('561-3.andar', 'LOGRA', 1), ('predio', '', 2), ('banco', '', 2), ('do', '', 2), ('brasil', '', 2), ('ag', '', 2), ('.', '', 2), ('comercio', '', 2), ('comercio', '', 2), ('40010-904', '', 2), ('salvador', '', 2), ('ba', '', 2)]
#
# Entities [('praca dr. augusto goncalves 64', 'LOGRA')]
# Tokens [('praca', 'LOGRA', 3), ('dr', 'LOGRA', 1), ('.', 'LOGRA', 1), ('augusto', 'LOGRA', 1), ('goncalves', 'LOGRA', 1), ('64', 'LOGRA', 1), ('centro', '', 2), ('35680-084', '', 2), ('itauna', '', 2), ('mg', '', 2)]
#
# Entities [('r.atilio ferri 84', 'LOGRA')]
# Tokens [('r.atilio', 'LOGRA', 3), ('ferri', 'LOGRA', 1), ('84', 'LOGRA', 1), ('centro', '', 2), ('86990-000', '', 2), ('marialva', '', 2), ('pr', '', 2)]
#
# Entities [('avenida tiradentes alto da', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('tiradentes', 'LOGRA', 1), ('alto', 'LOGRA', 1), ('da', 'LOGRA', 1), ('vila', '', 2), ('nova', '', 2), ('13309-320', '', 2), ('itu', '', 2), ('sp', '', 2)]
#
# Entities [('av.rio branco 510', 'LOGRA')]
# Tokens [('av.rio', 'LOGRA', 3), ('branco', 'LOGRA', 1), ('510', 'LOGRA', 1), ('terreo', '', 2), ('centro', '', 2), ('59025-900', '', 2), ('natal', '', 2), ('rn', '', 2)]
#
# Entities [('estrada dos romeiros 1593', 'LOGRA')]
# Tokens [('estrada', 'LOGRA', 3), ('dos', 'LOGRA', 1), ('romeiros', 'LOGRA', 1), ('1593', 'LOGRA', 1), ('vl', '', 2), ('.', '', 2), ('pindorama', '', 2), ('06417-000', '', 2), ('barueri', '', 2), ('sp', '', 2)]
#
# Entities [('pca.odilon resende andrade 76', 'LOGRA')]
# Tokens [('pca.odilon', 'LOGRA', 3), ('resende', 'LOGRA', 1), ('andrade', 'LOGRA', 1), ('76', 'LOGRA', 1), ('centro', '', 2), ('37410-000', '', 2), ('tres', '', 2), ('coracoes', '', 2), ('mg', '', 2)]
#
# Entities [('av. brasil 514', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('brasil', 'LOGRA', 1), ('514', 'LOGRA', 1), ('centro', '', 2), ('99820-000', '', 2), ('viadutos', '', 2), ('rs', '', 2)]
#
# Entities [('qd 101 sul lt 06 av. joaquim teot�nio segurado', 'LOGRA')]
# Tokens [('qd', 'LOGRA', 3), ('101', 'LOGRA', 1), ('sul', 'LOGRA', 1), ('lt', 'LOGRA', 1), ('06', 'LOGRA', 1), ('av', 'LOGRA', 1), ('.', 'LOGRA', 1), ('joaquim', 'LOGRA', 1), ('teot', 'LOGRA', 1), ('�', 'LOGRA', 1), ('nio', 'LOGRA', 1), ('segurado', 'LOGRA', 1), ('plano', '', 2), ('diretor', '', 2), ('sul', '', 2), ('77015-002', '', 2), ('palmas', '', 2), ('to', '', 2)]
#
# Entities [('rua conselheiro moreira de barros 761', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('conselheiro', 'LOGRA', 1), ('moreira', 'LOGRA', 1), ('de', 'LOGRA', 1), ('barros', 'LOGRA', 1), ('761', 'LOGRA', 1), ('santana', '', 2), ('02018-012', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('rua carlos gomes n� 09', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), 
'', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('rua dr. jose rufina bezerra 373', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('dr', 'LOGRA', 1), ('.', 'LOGRA', 1), ('jose', 'LOGRA', 1), ('rufina', 'LOGRA', 1), ('bezerra', 'LOGRA', 1), ('373', 'LOGRA', 1), ('matriz', '', 2), ('vitoria', '', 2), ('sto', '', 2), ('antonio', '', 2), ('55612-410', '', 2), ('ribeirao', '', 2), ('pe', '', 2)]
#
# Entities [('av. bento goncalves 2421', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('bento', 'LOGRA', 1), ('goncalves', 'LOGRA', 1), ('2421', 'LOGRA', 1), ('partenon', '', 2), ('90650-003', '', 2), ('porto', '', 2), ('alegre', '', 2), ('rs', '', 2)]
#
# Entities [('r.epitacio pessoa 272', 'LOGRA')]
# Tokens [('r.epitacio', 'LOGRA', 3), ('pessoa', 'LOGRA', 1), ('272', 'LOGRA', 1), ('centro', '', 2), ('18650-000', '', 2), ('sao', '', 2), ('manuel', '', 2), ('sp', '', 2)]
#
# Entities [('av. vereador jose gomes duda 968', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('vereador', 'LOGRA', 1), ('jose', 'LOGRA', 1), ('gomes', 'LOGRA', 1), ('duda', 'LOGRA', 1), ('968', 'LOGRA', 1), ('centro', '', 2), ('17860-000', '', 2), ('pacaembu', '', 2), ('sp', '', 2)]
#
# Entities [('rua do ros�rio 103', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('do', 'LOGRA', 1), ('ros', 'LOGRA', 1), ('�', 'LOGRA', 1), ('rio', 'LOGRA', 1), ('103', 'LOGRA', 1), ('centro', '', 2), ('20041-004', '', 2), ('rio', '', 2), ('de', '', 2), ('janeiro', '', 2), ('rj', '', 2)]
#
# Entities [('sq - 15 quadra 15', 'LOGRA')]
# Tokens [('sq', 'LOGRA', 3), ('-', 'LOGRA', 1), ('15', 'LOGRA', 1), ('quadra', 'LOGRA', 1), ('15', 'LOGRA', 1), ('loja', '', 2), ('46', '', 2), ('area', '', 2), ('especial', '', 2), ('72880-000', '', 2), ('cidade', '', 2), ('ocidental', '', 2), ('go', '', 2)]
#
# Entities [('rua dos mineiros 67a e b', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('dos', 'LOGRA', 1), ('mineiros', 'LOGRA', 1), ('67a', 'LOGRA', 1), ('e', 'LOGRA', 1), ('b', 'LOGRA', 1), ('centro', '', 2), ('27600-000', '', 2), ('valenca', '', 2), ('rj', '', 2)]
#
# Entities [('av mal deodoro', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('mal', 'LOGRA', 1), ('deodoro', 'LOGRA', 1), ('gonzaga', '', 2), ('11060-400', '', 2), ('santos', '', 2), ('sp', '', 2)]
#
# Entities [('avenida gabriel pandolfi 253', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('gabriel', 'LOGRA', 1), ('pandolfi', 'LOGRA', 1), ('253', 'LOGRA', 1), ('distrito', '', 2), ('de', '', 2), ('guarana', '', 2), ('29195-409', '', 2), ('aracruz', '', 2), ('es', '', 2)]
#
# Entities [('av. joao pessoa 66', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('joao', 'LOGRA', 1), ('pessoa', 'LOGRA', 1), ('66', 'LOGRA', 1), ('centro', '', 2), ('18130-290', '', 2), ('sao', '', 2), ('roque', '', 2), ('sp', '', 2)]
#
# Entities [('r miguel calmon', 'LOGRA')]
# Tokens [('r', 'LOGRA', 3), ('miguel', 'LOGRA', 1), ('calmon', 'LOGRA', 1), ('sobreloja', '', 2), ('comercio', '', 2), ('40015-901', '', 2), ('salvador', '', 2), ('ba', '', 2)]
#
# Entities [('rua bento gon�alves 582', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('bento', 'LOGRA', 1), ('gon', 'LOGRA', 1), ('�', 'LOGRA', 1), ('alves', 'LOGRA', 1), ('582', 'LOGRA', 1), ('centro', '', 2), ('98870-000', '', 2), ('girua', '', 2), ('rs', '', 2)]
#
# Entities [('av.dr.pedro santos torres 3', 'LOGRA')]
# Tokens [('av.dr.pedro', 'LOGRA', 3), ('santos', 'LOGRA', 1), ('torres', 'LOGRA', 1), ('3', 'LOGRA', 1), ('predio', '', 2), ('centro', '', 2), ('48930-000', '', 2), ('curaca', '', 2), ('ba', '', 2)]
#
# Entities [('av rio arinos - quadra 134', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('rio', 'LOGRA', 1), ('arinos', 'LOGRA', 1), ('-', 'LOGRA', 1), ('quadra', 'LOGRA', 1), ('134', 'LOGRA', 1), ('lote', '', 2), ('3', '', 2), ('centro', '', 2), ('78575-000', '', 2), ('juara', '', 2), ('mt', '', 2)]
#
# Entities [('rua amazonas 3244', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('amazonas', 'LOGRA', 1), ('3244', 'LOGRA', 1), ('bairro', '', 2), ('garcia', '', 2), ('89022-001', '', 2), ('blumenau', '', 2), ('sc', '', 2)]
#
# Entities [('avenida puglisi n� 330', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('puglisi', 'LOGRA', 1), ('n', 'LOGRA', 1), ('�', 'LOGRA', 1), ('330', 'LOGRA', 1), ('parte', '', 2), ('centro', '', 2), ('11410-000', '', 2), ('guaruja', '', 2), ('sp', '', 2)]
#
# Entities [('r.quinze de novembro 859', 'LOGRA')]
# Tokens [('r.quinze', 'LOGRA', 3), ('de', 'LOGRA', 1), ('novembro', 'LOGRA', 1), ('859', 'LOGRA', 1), ('centro', '', 2), ('13450-044', '', 2), ('santa', '', 2), ('barbara', '', 2), ("d'oeste", '', 2), ('sp', '', 2)]
#
# Entities [('praca com. jamil a. saad 123', 'LOGRA')]
# Tokens [('praca', 'LOGRA', 3), ('com', 'LOGRA', 1), ('.', 'LOGRA', 1), ('jamil', 'LOGRA', 1), ('a.', 'LOGRA', 1), ('saad', 'LOGRA', 1), ('123', 'LOGRA', 1), ('centro', '', 2), ('13490-000', '', 2), ('cordeiropolis', '', 2), ('sp', '', 2)]
#
# Entities [('av.mauricio cardoso 481', 'LOGRA')]
# Tokens [('av.mauricio', 'LOGRA', 3), ('cardoso', 'LOGRA', 1), ('481', 'LOGRA', 1), ('centro', '', 2), ('99660-000', '', 2), ('campinas', '', 2), ('do', '', 2), ('sul', '', 2), ('rs', '', 2)]
# Entities [('pra�a santos dumont 225 qd. 41 a', 'LOGRA')]
# Tokens [('pra', 'LOGRA', 3), ('�', 'LOGRA', 1), ('a', 'LOGRA', 1), ('santos', 'LOGRA', 1), ('dumont', 'LOGRA', 1), ('225', 'LOGRA', 1), ('qd', 'LOGRA', 1), ('.', 'LOGRA', 1), ('41', 'LOGRA', 1), ('a', 'LOGRA', 1), ('-', '', 2), ('lote', '', 2), ('12', '', 2), ('setor', '', 2), ('aeroporto', '', 2), ('74070-050', '', 2), ('goiania', '', 2), ('go', '', 2)]
#
# Entities [('rua marechal deodoro 212', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('marechal', 'LOGRA', 1), ('deodoro', 'LOGRA', 1), ('212', 'LOGRA', 1), ('centro', '', 2), ('47500-000', '', 2), ('paratinga', '', 2), ('ba', '', 2)]
#
# Entities [('r.jose cleto 28', 'LOGRA')]
# Tokens [('r.jose', 'LOGRA', 3), ('cleto', 'LOGRA', 1), ('28', 'LOGRA', 1), ('palmares', '', 2), ('31160-470', '', 2), ('belo', '', 2), ('horizonte', '', 2), ('mg', '', 2)]
#
# Entities [('pca. prado filho 30', 'LOGRA')]
# Tokens [('pca', 'LOGRA', 3), ('.', 'LOGRA', 1), ('prado', 'LOGRA', 1), ('filho', 'LOGRA', 1), ('30', 'LOGRA', 1), ('centro', '', 2), ('12630-000', '', 2), ('cachoeira', '', 2), ('paulista', '', 2), ('sp', '', 2)]
#
# Entities [('av. sao borja', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('sao', 'LOGRA', 1), ('borja', 'LOGRA', 1), ('centro', '', 2), ('93032-000', '', 2), ('sao', '', 2), ('leopoldo', '', 2), ('rs', '', 2)]
#
# Entities [('r.dom pedro segundo 1066', 'LOGRA')]
# Tokens [('r.dom', 'LOGRA', 3), ('pedro', 'LOGRA', 1), ('segundo', 'LOGRA', 1), ('1066', 'LOGRA', 1), ('predio', '', 2), ('centro', '', 2), ('78700-220', '', 2), ('rondonopolis', '', 2), ('mt', '', 2)]
#
# Entities [('av. ramiro barcelos', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('ramiro', 'LOGRA', 1), ('barcelos', 'LOGRA', 1), ('independencia', '', 2), ('90000-000', '', 2), ('porto', '', 2), ('alegre', '', 2), ('rs', '', 2)]
#
# Entities [('av. benedito de andrade 140', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('benedito', 'LOGRA', 1), ('de', 'LOGRA', 1), ('andrade', 'LOGRA', 1), ('140', 'LOGRA', 1), ('pirituba', '', 2), ('02936-000', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('rua mal. deodoro 316', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('mal', 'LOGRA', 1), ('.', 'LOGRA', 1), ('deodoro', 'LOGRA', 1), ('316', 'LOGRA', 1), ('centro', '', 2), ('95760-000', '', 2), ('sao', '', 2), ('sebastiao', '', 2), ('do', '', 2), ('cai', '', 2), ('rs', '', 2)]
#
# Entities [('av. 09 de julho', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('09', 'LOGRA', 1), ('de', 'LOGRA', 1), ('julho', 'LOGRA', 1), ('centro', '', 2), ('99370-000', '', 2), ('fontoura', '', 2), ('xavier', '', 2), ('rs', '', 2)]
#
# Entities [('av. brasil 455', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('brasil', 'LOGRA', 1), ('455', 'LOGRA', 1), ('centro', '', 2), ('86280-000', '', 2), ('urai', '', 2), ('pr', '', 2)]
#
# Entities [('rua general osorio 411/rua andrade neves', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('general', 'LOGRA', 1), ('osorio', 'LOGRA', 1), ('411', 'LOGRA', 1), ('/', 'LOGRA', 1), ('rua', 'LOGRA', 1), ('andrade', 'LOGRA', 1), ('neves', 'LOGRA', 1), ('centro', '', 2), ('96300-000', '', 2), ('jaguarao', '', 2), ('rs', '', 2)]
#
# Entities [('rua dr pedro de toledo 197', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('dr', 'LOGRA', 1), ('pedro', 'LOGRA', 1), ('de', 'LOGRA', 1), ('toledo', 'LOGRA', 1), ('197', 'LOGRA', 1), ('centro', '', 2), ('13770-000', '', 2), ('caconde', '', 2), ('sp', '', 2)]
#
# Entities [('rua moreira cesar', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('moreira', 'LOGRA', 1), ('cesar', 'LOGRA', 1), ('centro', '', 2), ('95034-000', '', 2), ('caxias', '', 2), ('do', '', 2), ('sul', '', 2), ('rs', '', 2)]
#
# Entities [('praca evangelino meireles 50-a', 'LOGRA')]
# Tokens [('praca', 'LOGRA', 3), ('evangelino', 'LOGRA', 1), ('meireles', 'LOGRA', 1), ('50-a', 'LOGRA', 1), ('centro', '', 2), ('72800-000', '', 2), ('luziania', '', 2), ('go', '', 2)]
#
# Entities [('rua luiz gama', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('luiz', 'LOGRA', 1), ('gama', 'LOGRA', 1), ('centro', '', 2), ('07010-050', '', 2), ('guarulhos', '', 2), ('sp', '', 2)]
#
# Entities [('av. guarda mor lobo viana 153', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('guarda', 'LOGRA', 1), ('mor', 'LOGRA', 1), ('lobo', 'LOGRA', 1), ('viana', 'LOGRA', 1), ('153', 'LOGRA', 1), ('centro', '', 2), ('11600-000', '', 2), ('sao', '', 2), ('sebastiao', '', 2), ('sp', '', 2)]
#
# Entities []
# Tokens [('av.os�rio', '', 2), ('centro', '', 2), ('95625-000', '', 2), ('imbe', '', 2), ('rs', '', 2)]
#
# Entities [('av. joao pedro cardoso 375', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('joao', 'LOGRA', 1), ('pedro', 'LOGRA', 1), ('cardoso', 'LOGRA', 1), ('375', 'LOGRA', 1), ('prq', '', 2), ('.', '', 2), ('jabaquara', '', 2), ('43550-000', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('av.portugal 1186', 'LOGRA')]
# Tokens [('av.portugal', 'LOGRA', 3), ('1186', 'LOGRA', 1), ('centro', '', 2), ('09040-001', '', 2), ('santo', '', 2), ('andre', '', 2), ('sp', '', 2)]
#
# Entities [('avenida menino marcelo s/n', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('menino', 'LOGRA', 1), ('marcelo', 'LOGRA', 1), ('s', 'LOGRA', 1), ('/', 'LOGRA', 1), ('n', 'LOGRA', 1), ('serraria', '', 2), ('57046-000', '', 2), ('maceio', '', 2), ('al', '', 2)]
#
# Entities [('avenida coronel jose soares marcondes num 1199', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('coronel', 'LOGRA', 1), ('jose', 'LOGRA', 1), ('soares', 'LOGRA', 1), ('marcondes', 'LOGRA', 1), ('num', 'LOGRA', 1), ('1199', 'LOGRA', 1), ('centro', '', 2), ('19010-081', '', 2), ('presidente', '', 2), ('prudente', '', 2), ('sp', '', 2)]
#
# Entities [('rua jesus marques prata 124', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('jesus', 'LOGRA', 1), ('marques', 'LOGRA', 1), ('prata', 'LOGRA', 1), ('124', 'LOGRA', 1), ('centro', '', 2), ('38120-000', '', 2), ('conceicao', '', 2), ('das', '', 2), ('alagoas', '', 2), ('mg', '', 2)]
#
# Entities [('av.general flores da cunha 695', 'LOGRA')]
# Tokens [('av.general', 'LOGRA', 3), ('flores', 'LOGRA', 1), ('da', 'LOGRA', 1), ('cunha', 'LOGRA', 1), ('695', 'LOGRA', 1), ('vila', '', 2), ('santo', '', 2), ('angelo', '', 2), ('94910-000', '', 2), ('cachoeirinha', '', 2), ('rs', '', 2)]
#
# Entities [('r marechal deodoro', 'LOGRA')]
# Tokens [('r', 'LOGRA', 3), ('marechal', 'LOGRA', 1), ('deodoro', 'LOGRA', 1), ('centro', '', 2), ('80010-010', '', 2), ('curitiba', '', 2), ('pr', '', 2)]
#
# Entities [('rua da graca 121/127', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('da', 'LOGRA', 1), ('graca', 'LOGRA', 1), ('121/127', 'LOGRA', 1), ('bom', '', 2), ('retiro', '', 2), ('11250-010', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('av dr labieno c machado 956/al mathias', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('dr', 'LOGRA', 1), ('labieno', 'LOGRA', 1), ('c', 'LOGRA', 1), ('machado', 'LOGRA', 1), ('956', 'LOGRA', 1), ('/', 'LOGRA', 1), ('al', 'LOGRA', 1), ('mathias', 'LOGRA', 1), ('manchini', '', 2), ('faixa', '', 2), ('integracao', '', 2), ('17400-000', '', 2), ('garca', '', 2), ('sp', '', 2)]
#
# Entities [('av.jabaquara 1909', 'LOGRA')]
# Tokens [('av.jabaquara', 'LOGRA', 3), ('1909', 'LOGRA', 1), ('saude', '', 2), ('04045-003', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('rua cardoso de almeida 211', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('cardoso', 'LOGRA', 1), ('de', 'LOGRA', 1), ('almeida', 'LOGRA', 1), ('211', 'LOGRA', 1), ('perdizes', '', 2), ('05013-000', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('avenida paulista 2100', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('paulista', 'LOGRA', 1), ('2100', 'LOGRA', 1), ('cerqueira', '', 2), ('cesar', '', 2), ('01310-930', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('rua almirante barroso 1062', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('almirante', 'LOGRA', 1), ('barroso', 'LOGRA', 1), ('1062', 'LOGRA', 1), ('centro', '', 2), ('85851-010', '', 2), ('foz', '', 2), ('do', '', 2), ('iguacu', '', 2), ('pr', '', 2)]
#
# Entities [('avbarreto de menezes', 'LOGRA')]
# Tokens [('avbarreto', 'LOGRA', 3), ('de', 'LOGRA', 1), ('menezes', 'LOGRA', 1), ('loja', '', 2), ('243', '', 2), ('-', '', 2), ('shopping', '', 2), ('center', '', 2), ('guararapes', '', 2), ('piedade', '', 2), ('54410-902', '', 2), ('jaboatao', '', 2), ('dos', '', 2), ('guararapes', '', 2), ('pe', '', 2)]
#
# Entities [('av. guajajaras 1100', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('guajajaras', 'LOGRA', 1), ('1100', 'LOGRA', 1), ('lojas1/2', '', 2), ('tirirical', '', 2), ('65051-070', '', 2), ('sao', '', 2), ('luis', '', 2), ('ma', '', 2)]
#
# Entities [('av paulista 14', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('paulista', 'LOGRA', 1), ('14', 'LOGRA', 1), ('�', '', 2), ('andar', '', 2), ('-', '', 2), ('torre', '', 2), ('matarazzo', '', 2), ('b', '', 2), ('vista', '', 2), ('01310-901', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('av. dr. jose bonif�cio coutinho nogueira', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('dr', 'LOGRA', 1), ('.', 'LOGRA', 1), ('jose', 'LOGRA', 1), ('bonif', 'LOGRA', 1), ('�', 'LOGRA', 1), ('cio', 'LOGRA', 1), ('coutinho', 'LOGRA', 1), ('nogueira', 'LOGRA', 1), ('salas', '', 2), ('239', '', 2), ('e', '', 2), ('241', '', 2), ('jd', '', 2), ('.', '', 2), ('madalena', '', 2), ('13091-611', '', 2), ('campinas', '', 2), ('sp', '', 2)]
#
# Entities [('av rui barbosa 113', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('rui', 'LOGRA', 1), ('barbosa', 'LOGRA', 1), ('113', 'LOGRA', 1), ('heliopolis', '', 2), ('55295-530', '', 2), ('garanhuns', '', 2), ('pe', '', 2)]
#
# Entities [('rua dr.zuquim 1824', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('dr.zuquim', 'LOGRA', 1), ('1824', 'LOGRA', 1), ('santana', '', 2), ('02035-022', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('rua alvaro mendes 991', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('alvaro', 'LOGRA', 1), ('mendes', 'LOGRA', 1), ('991', 'LOGRA', 1), ('centro', '', 2), ('64000-060', '', 2), ('teresina', '', 2), ('pi', '', 2)]
#
# Entities [('praca isai leirner 195', 'LOGRA')]
# Tokens [('praca', 'LOGRA', 3), ('isai', 'LOGRA', 1), ('leirner', 'LOGRA', 1), ('195', 'LOGRA', 1), ('jardim', '', 2), ('bonfiglioli', '', 2), ('05592-140', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('av. barao do rio branco 419', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('barao', 'LOGRA', 1), ('do', 'LOGRA', 1), ('rio', 'LOGRA', 1), ('branco', 'LOGRA', 1), ('419', 'LOGRA', 1), ('centro', '', 2), ('89500-000', '', 2), ('cacador', '', 2), ('sc', '', 2)]
#
# Entities [('av. pref jonas banks leite 422', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('pref', 'LOGRA', 1), ('jonas', 'LOGRA', 1), ('banks', 'LOGRA', 1), ('leite', 'LOGRA', 1), ('422', 'LOGRA', 1), ('centro', '', 2), ('11900-000', '', 2), ('registro', '', 2), ('sp', '', 2)]
#
# Entities [('pca vicentino rodrigues da cunha 0316 / 0318', 'LOGRA')]
# Tokens [('pca', 'LOGRA', 3), ('vicentino', 'LOGRA', 1), ('rodrigues', 'LOGRA', 1), ('da', 'LOGRA', 1), ('cunha', 'LOGRA', 1), ('0316', 'LOGRA', 1), ('/', 'LOGRA', 1), ('0318', 'LOGRA', 1), ('sao', '', 2), ('benedito', '', 2), ('38022-330', '', 2), ('uberaba', '', 2), ('mg', '', 2)]
#
# Entities [('avenida dos bandeirantes', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('dos', 'LOGRA', 1), ('bandeirantes', 'LOGRA', 1), ('centro', '', 2), ('15685-000', '', 2), ('ouroeste', '', 2), ('sp', '', 2)]
#
# Entities [('av.tanus saliba 361', 'LOGRA')]
# Tokens [('av.tanus', 'LOGRA', 3), ('saliba', 'LOGRA', 1), ('361', 'LOGRA', 1), ('centro', '', 2), ('35675-000', '', 2), ('juatuba', '', 2), ('mg', '', 2)]
#
# Entities [('rua pinto de figueiredo', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), 
 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('treze', 'LOGRA', 1), ('de', 'LOGRA', 1), ('maio', 'LOGRA', 1), ('532/538', 'LOGRA', 1), ('centro', '', 2), ('37570-000', '', 2), ('ouro', '', 2), ('fino', '', 2), ('mg', '', 2)]
#
# Entities [('rua governador portela 12', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('governador', 'LOGRA', 1), ('portela', 'LOGRA', 1), ('12', 'LOGRA', 1), ('parte', '', 2), ('centro', '', 2), ('27123-000', '', 2), ('barra', '', 2), ('do', '', 2), ('pirai', '', 2), ('rj', '', 2)]
#
# Entities [('av taquarichim', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('taquarichim', 'LOGRA', 1), ('vila', '', 2), ('vera', '', 2), ('04296-100', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('rua carijos 218', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('carijos', 'LOGRA', 1), ('218', 'LOGRA', 1), ('360305', '', 2), ('centro', '', 2), ('30120-060', '', 2), ('belo', '', 2), ('horizonte', '', 2), ('mg', '', 2)]
#
# Entities [('av.edu chaves 833', 'LOGRA')]
# Tokens [('av.edu', 'LOGRA', 3), ('chaves', 'LOGRA', 1), ('833', 'LOGRA', 1), ('parque', '', 2), ('edu', '', 2), ('chaves', '', 2), ('02229-000', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('av. brasilia', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('brasilia', 'LOGRA', 1), ('centro', '', 2), ('95370-000', '', 2), ('barracao', '', 2), ('rs', '', 2)]
#
# Entities [('av.sete de setembro', 'LOGRA')]
# Tokens [('av.sete', 'LOGRA', 3), ('de', 'LOGRA', 1), ('setembro', 'LOGRA', 1), ('centro', '', 2), ('69005-140', '', 2), ('manaus', '', 2), ('am', '', 2)]
#
# Entities [('av. rubens caramez 150', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('rubens', 'LOGRA', 1), ('caramez', 'LOGRA', 1), ('150', 'LOGRA', 1), ('centro', '', 2), ('06657-000', '', 2), ('itapevi', '', 2), ('sp', '', 2)]
#
# Entities [('pca.dr.carlos sampaio filho 85', 'LOGRA')]
# Tokens [('pca.dr.carlos', 'LOGRA', 3), ('sampaio', 'LOGRA', 1), ('filho', 'LOGRA', 1), ('85', 'LOGRA', 1), ('centro', '', 2), ('16300-000', '', 2), ('penapolis', '', 2), ('sp', '', 2)]
#
# Entities [('p�. padre jose maria do sacramento 114', 'LOGRA')]
# Tokens [('p', 'LOGRA', 3), ('�', 'LOGRA', 1), ('.', 'LOGRA', 1), ('padre', 'LOGRA', 1), ('jose', 'LOGRA', 1), ('maria', 'LOGRA', 1), ('do', 'LOGRA', 1), ('sacramento', 'LOGRA', 1), ('114', 'LOGRA', 1), ('centro', '', 2), ('39648-000', '', 2), ('chapada', '', 2), ('do', '', 2), ('norte', '', 2), ('mg', '', 2)]
#
# Entities [('r.carlos morais 344', 'LOGRA')]
# Tokens [('r.carlos', 'LOGRA', 3), ('morais', 'LOGRA', 1), ('344', 'LOGRA', 1), ('centro', '', 2), ('63220-000', '', 2), ('caririacu', '', 2), ('ce', '', 2)]
#
# Entities [('rua barao do rio branco 714/716/726', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('barao', 'LOGRA', 1), ('do', 'LOGRA', 1), ('rio', 'LOGRA', 1), ('branco', 'LOGRA', 1), ('714/716/726', 'LOGRA', 1), ('centro', '', 2), ('60025-060', '', 2), ('fortaleza', '', 2), ('ce', '', 2)]
#
# Entities [('rua presidente nereu ramos 8', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('presidente', 'LOGRA', 1), ('nereu', 'LOGRA', 1), ('ramos', 'LOGRA', 1), ('8', 'LOGRA', 1), ('�', '', 2), ('andar', '', 2), ('centro', '', 2), ('88015-010', '', 2), ('florianopolis', '', 2), ('sc', '', 2)]
#
# Entities [('av.brasil 1497', 'LOGRA')]
# Tokens [('av.brasil', 'LOGRA', 3), ('1497', 'LOGRA', 1), ('funcionarios', '', 2), ('30140-002', '', 2), ('belo', '', 2), ('horizonte', '', 2), ('mg', '', 2)]
#
# Entities [('avenida washington luiz 403', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('washington', 'LOGRA', 1), ('luiz', 'LOGRA', 1), ('403', 'LOGRA', 1), ('centro', '', 2), ('13890-000', '', 2), ('aguas', '', 2), ('da', '', 2), ('prata', '', 2), ('sp', '', 2)]
#
# Entities [('av. protasio alves 2961 e 2965', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('protasio', 'LOGRA', 1), ('alves', 'LOGRA', 1), ('2961', 'LOGRA', 1), ('e', 'LOGRA', 1), ('2965', 'LOGRA', 1), ('ed.columbia', '', 2), ('petropolis', '', 2), ('90410-003', '', 2), ('porto', '', 2), ('alegre', '', 2), ('rs', '', 2)]
#
# Entities [('rua jacaranda num 305', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('jacaranda', 'LOGRA', 1), ('num', 'LOGRA', 1), ('305', 'LOGRA', 1), ('eucaliptos', '', 2), ('83820-000', '', 2), ('fazenda', '', 2), ('rio', '', 2), ('grande', '', 2), ('pr', '', 2)]
#
# Entities [('r.alfredo gazzolla 14', 'LOGRA')]
# Tokens [('r.alfredo', 'LOGRA', 3), ('gazzolla', 'LOGRA', 1), ('14', 'LOGRA', 1), ('centro', '', 2), ('88840-000', '', 2), ('urussanga', '', 2), ('sc', '', 2)]
#
# Entities [('rua gal. francisco glicerio 666', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('gal', 'LOGRA', 1), ('.', 'LOGRA', 1), ('francisco', 'LOGRA', 1), ('glicerio', 'LOGRA', 1), ('666', 'LOGRA', 1), ('centro', '', 2), ('08674-000', '', 2), ('suzano', '', 2), ('sp', '', 2)]
#
# Entities [('rua monsenhor cintra', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('monsenhor', 'LOGRA', 1), ('cintra', 'LOGRA', 1), ('quadra', '', 2), ('f', '', 2), ('centro', '', 2), ('18150-000', '', 2), ('ibiuna', '', 2), ('sp', '', 2)]
#
# Entities [('avenida gurgel do amaral', 'LOGRA')]
# ...
#
# Entities [('av juracy magalhaes', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('juracy', 'LOGRA', 1), ('magalhaes', 'LOGRA', 1), ('boa', '', 2), ('vista', '', 2), ('45026-090', '', 2), ('vitoria', '', 2), ('da', '', 2), ('conquista', '', 2), ('ba', '', 2)]
#
# Entities [('r. joaquim nabuco 1593', 'LOGRA')]
# Tokens [('r.', 'LOGRA', 3), ('joaquim', 'LOGRA', 1), ('nabuco', 'LOGRA', 1), ('1593', 'LOGRA', 1), ('cidade', '', 2), ('jardim', '', 2), ('83040-210', '', 2), ('sao', '', 2), ('jose', '', 2), ('dos', '', 2), ('pinhais', '', 2), ('pr', '', 2)]
#
# Entities [('ruaa xv de novembro 570', 'LOGRA')]
# Tokens [('ruaa', 'LOGRA', 3), ('xv', 'LOGRA', 1), ('de', 'LOGRA', 1), ('novembro', 'LOGRA', 1), ('570', 'LOGRA', 1), ('96015-000', '', 2), ('pelotas', '', 2), ('rs', '', 2)]
#
# Entities [('av presidente vargas', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), 
 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('mal', 'LOGRA', 1), ('deodoro', 'LOGRA', 1), ('centro', '', 2), ('45800-000', '', 2), ('belmonte', '', 2), ('ba', '', 2)]
#
# Entities [('praca da matriz 122', 'LOGRA')]
# Tokens [('praca', 'LOGRA', 3), ('da', 'LOGRA', 1), ('matriz', 'LOGRA', 1), ('122', 'LOGRA', 1), ('centro', '', 2), ('17230-000', '', 2), ('itapui', '', 2), ('sp', '', 2)]
#
# Entities []
# Tokens [(' ', '', 2), ('sain', '', 2), ('bl', '', 2), ('.', '', 2), ('f', '', 2), ('ed', '', 2), ('.', '', 2), ('sede', '', 2), ('terracap', '', 2), ('70620-000', '', 2), ('brasilia', '', 2), ('df', '', 2)]
#
# Entities [('av.agamenon magalhaes 1301-b', 'LOGRA')]
# Tokens [('av.agamenon', 'LOGRA', 3), ('magalhaes', 'LOGRA', 1), ('1301-b', 'LOGRA', 1), ('mauricio', '', 2), ('de', '', 2), ('nassau', '', 2), ('55014-000', '', 2), ('caruaru', '', 2), ('pe', '', 2)]
#
# Entities [('rua antonio dias adorno 873 883 887', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('antonio', 'LOGRA', 1), ('dias', 'LOGRA', 1), ('adorno', 'LOGRA', 1), ('873', 'LOGRA', 1), ('883', 'LOGRA', 1), ('887', 'LOGRA', 1), ('vila', '', 2), ('nogueira', '', 2), ('09951-000', '', 2), ('diadema', '', 2), ('sp', '', 2)]
#
# Entities [('pca.dr.paterson 11/12 lgo.da', 'LOGRA')]
# Tokens [('pca.dr.paterson', 'LOGRA', 3), ('11/12', 'LOGRA', 1), ('lgo.da', 'LOGRA', 1), ('graca', '', 2), ('graca', '', 2), ('40150-066', '', 2), ('salvador', '', 2), ('ba', '', 2)]
#
# Entities [('r brusque 89', 'LOGRA')]
# Tokens [('r', 'LOGRA', 3), ('brusque', 'LOGRA', 1), ('89', 'LOGRA', 1), ('centro', '', 2), ('88302-000', '', 2), ('itajai', '', 2), ('sc', '', 2)]
#
# Entities [('rua jos� bonif�cio', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('jos', 'LOGRA', 1), ('�', 'LOGRA', 1), ('bonif', 'LOGRA', 1), ('�', 'LOGRA', 1), ('cio', 'LOGRA', 1), ('centro', '', 2), ('18270-200', '', 2), ('tatui', '', 2), ('sp', '', 2)]
#
# Entities [('pca conego joaquim alves 80', 'LOGRA')]
# Tokens [('pca', 'LOGRA', 3), ('conego', 'LOGRA', 1), ('joaquim', 'LOGRA', 1), ('alves', 'LOGRA', 1), ('80', 'LOGRA', 1), ('centro', '', 2), ('14300-000', '', 2), ('batatais', '', 2), ('sp', '', 2)]
#
# Entities [('av aristoteles fernandes valadares', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('aristoteles', 'LOGRA', 1), ('fernandes', 'LOGRA', 1), ('valadares', 'LOGRA', 1), ('centro', '', 2), ('38680-000', '', 2), ('arinos', '', 2), ('mg', '', 2)]
#
# Entities [('av lauro sodre', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('lauro', 'LOGRA', 1), ('sodre', 'LOGRA', 1), ('loja', '', 2), ('101', '', 2), ('parte', '', 2), ('a', '', 2), ('1/2/3/5a', '', 2), ('botafogo', '', 2), ('22290-070', '', 2), ('rio', '', 2), ('de', '', 2), ('janeiro', '', 2), ('rj', '', 2)]
#
# Entities [('rua marechal deodoro da fonseca 2745 2751', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('marechal', 'LOGRA', 1), ('deodoro', 'LOGRA', 1), ('da', 'LOGRA', 1), ('fonseca', 'LOGRA', 1), ('2745', 'LOGRA', 1), ('2751', 'LOGRA', 1), ('centro', '', 2), ('15010-070', '', 2), ('sao', '', 2), ('jose', '', 2), ('do', '', 2), ('rio', '', 2), ('preto', '', 2), ('sp', '', 2)]
#
# Entities [('avenida fernandes de andrade 974', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('fernandes', 'LOGRA', 1), ('de', 'LOGRA', 1), ('andrade', 'LOGRA', 1), ('974', 'LOGRA', 1), ('centro', '', 2), ('83840-000', '', 2), ('quitandinha', '', 2), ('pr', '', 2)]
# Entities [('rua da integra��o vereador bernardino pucci 2025', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('da', 'LOGRA', 1), ('integra', 'LOGRA', 1), ('�', 'LOGRA', 1), ('�', 'LOGRA', 1), ('o', 'LOGRA', 1), ('vereador', 'LOGRA', 1), ('bernardino', 'LOGRA', 1), ('pucci', 'LOGRA', 1), ('2025', 'LOGRA', 1), ('jardim', '', 2), ('integra', '', 2), ('�', '', 2), ('�', '', 2), ('o', '', 2), ('14405-265', '', 2), ('franca', '', 2), ('sp', '', 2)]
#
# Entities [('av inglaterra', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('inglaterra', 'LOGRA', 1), ('jd', '', 2), ('sao', '', 2), ('vicente', '', 2), ('86046-000', '', 2), ('londrina', '', 2), ('pr', '', 2)]
#
# Entities [('rua amando de barros 664', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('amando', 'LOGRA', 1), ('de', 'LOGRA', 1), ('barros', 'LOGRA', 1), ('664', 'LOGRA', 1), ('parte', '', 2), ('centro', '', 2), ('18600-050', '', 2), ('botucatu', '', 2), ('sp', '', 2)]
#
# Entities [('pca prof jose azevedo antunes 48', 'LOGRA')]
# Tokens [('pca', 'LOGRA', 3), ('prof', 'LOGRA', 1), ('jose', 'LOGRA', 1), ('azevedo', 'LOGRA', 1), ('antunes', 'LOGRA', 1), ('48', 'LOGRA', 1), ('lapa', '', 2), ('05072-050', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('av roberto silveira', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('roberto', 'LOGRA', 1), ('silveira', 'LOGRA', 1), ('fatima', '', 2), ('23970-000', '', 2), ('paraty', '', 2), ('rj', '', 2)]
#
# Entities [('r.osorio messias de almeida 5114', 'LOGRA')]
# Tokens [('r.osorio', 'LOGRA', 3), ('messias', 'LOGRA', 1), ('de', 'LOGRA', 1), ('almeida', 'LOGRA', 1), ('5114', 'LOGRA', 1), ('centro', '', 2), ('15350-000', '', 2), ('auriflama', '', 2), ('sp', '', 2)]
#
# Entities [('rua s�o sebasti�', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('s', 'LOGRA', 1), ('�', 'LOGRA', 1), ('o', 'LOGRA', 1), ('sebasti', 'LOGRA', 1), ('�', 'LOGRA', 1), ('o', '', 2), ('centro', '', 2), ('68647-000', '', 2), ('tracuateua', '', 2), ('pa', '', 2)]
#
# Entities [('r sao joao', 'LOGRA')]
# Tokens [('r', 'LOGRA', 3), ('sao', 'LOGRA', 1), ('joao', 'LOGRA', 1), ('centro', '', 2), ('14700-010', '', 2), ('bebedouro', '', 2), ('sp', '', 2)]
#
# Entities [('rua doutor batista laper 10', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('doutor', 'LOGRA', 1), ('batista', 'LOGRA', 1), ('laper', 'LOGRA', 1), ('10', 'LOGRA', 1), ('loja', '', 2), ('01', '', 2), ('e', '', 2), ('02', '', 2), ('centro', '', 2), ('28650-000', '', 2), ('duas', '', 2), ('barras', '', 2), ('rj', '', 2)]
#
# Entities [('rua conde de bonfim 555', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('conde', 'LOGRA', 1), ('de', 'LOGRA', 1), ('bonfim', 'LOGRA', 1), ('555', 'LOGRA', 1), ('loja', '', 2), ('tijuca', '', 2), ('20520-052', '', 2), ('rio', '', 2), ('de', '', 2), ('janeiro', '', 2), ('rj', '', 2)]
#
# Entities [('av mario ypiranga', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('mario', 'LOGRA', 1), ('ypiranga', 'LOGRA', 1), ('adrianopolis', '', 2), ('69057-001', '', 2), ('manaus', '', 2), ('am', '', 2)]
#
# Entities [('av.prestes maia 733', 'LOGRA')]
# Tokens [('av.prestes', 'LOGRA', 3), ('maia', 'LOGRA', 1), ('733', 'LOGRA', 1), ('terreo', '', 2), ('-', '', 2), ('santa', '', 2), ('efigenia', '', 2), ('centro', '', 2), ('01031-001', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('104 sul r.', 'LOGRA')]
# Tokens [('104', 'LOGRA', 3), ('sul', 'LOGRA', 1), ('r.', 'LOGRA', 1), ('se', '', 2), ('1conj', '', 2), ('02', '', 2), ('-', '', 2), ('acse', '', 2), ('01', '', 2), ('lote', '', 2), ('01', '', 2), ('plano', '', 2), ('diretor', '', 2), ('sul', '', 2), ('77020-014', '', 2), ('palmas', '', 2), ('to', '', 2)]
#
# Entities [('rua santos dumont', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('santos', 'LOGRA', 1), ('dumont', 'LOGRA', 1), ('centro', '', 2), ('69020-548', '', 2), ('manaus', '', 2), ('am', '', 2)]
#
# Entities [('avenida das na��es unidas n� 11.633', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('das', 'LOGRA', 1), ('na', 'LOGRA', 1), ('�', 'LOGRA', 1), ('�', 'LOGRA', 1), ('es', 'LOGRA', 1), ('unidas', 'LOGRA', 1), ('n', 'LOGRA', 1), ('�', 'LOGRA', 1), ('11.633', 'LOGRA', 1), ('loja', '', 2), ('parte', '', 2), ('brooklin', '', 2), ('paulista', '', 2), ('04578-000', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('rua cec�nio silva 45', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('cec', 'LOGRA', 1), ('�', 'LOGRA', 1), ('nio', 'LOGRA', 1), ('silva', 'LOGRA', 1), ('45', 'LOGRA', 1), ('centro', '', 2), ('38210-000', '', 2), ('pirajuba', '', 2), ('mg', '', 2)]
#
# Entities [('r. santa iria 530', 'LOGRA')]
# Tokens [('r.', 'LOGRA', 3), ('santa', 'LOGRA', 1), ('iria', 'LOGRA', 1), ('530', 'LOGRA', 1), ('centro', '', 2), ('14815-000', '', 2), ('ibate', '', 2), ('sp', '', 2)]
#
# Entities [('av.manoel dias da silva', 'LOGRA')]
# Tokens [('av.manoel', 'LOGRA', 3), ('dias', 'LOGRA', 1), ('da', 'LOGRA', 1), ('silva', 'LOGRA', 1), ('pituba', '', 2), ('41830-001', '', 2), ('salvador', '', 2), ('ba', '', 2)]
#
# Entities [('rua marginal jos� de anchieta 1440', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('marginal', 'LOGRA', 1), ('jos', 'LOGRA', 1), ('�', 'LOGRA', 1), ('de', 'LOGRA', 1), ('anchieta', 'LOGRA', 1), ('1440', 'LOGRA', 1), ('vila', '', 2), ('guarani', '', 2), ('83408-010', '', 2), ('colombo', '', 2), ('pr', '', 2)]
#
# Entities [('av.mogiana 1810', 'LOGRA')]
# Tokens [('av.mogiana', 'LOGRA', 3), ('1810', 'LOGRA', 1), ('vila', '', 2), ('mariana', '', 2), ('14075-260', '', 2), ('ribeirao', '', 2), ('preto', '', 2), ('sp', '', 2)]
#
# Entities [('pca.cel.marcolino mascarenhas 50', 'LOGRA')]
# Tokens [('pca.cel.marcolino', 'LOGRA', 3), ('mascarenhas', 'LOGRA', 1), ('50', 'LOGRA', 1), ('predio', '', 2), ('centro', '', 2), ('44640-000', '', 2), ('riachao', '', 2), ('do', '', 2), ('jacuipe', '', 2), ('ba', '', 2)]
#
# Entities [('av brigadeiro faria lima 3729', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('brigadeiro', 'LOGRA', 1), ('faria', 'LOGRA', 1), ('lima', 'LOGRA', 1), ('3729', 'LOGRA', 1), ('14', '', 2), ('andar', '', 2), ('#', '', 2), ('nome', '', 2), ('?', '', 2), ('itaim', '', 2), ('bibi', '', 2), ('47190-010', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('av.nove de agosto 2098', 'LOGRA')]
# Tokens [('av.nove', 'LOGRA', 3), ('de', 'LOGRA', 1), ('agosto', 'LOGRA', 1), ('2098', 'LOGRA', 1), ('centro', '', 2), ('29950-000', '', 2), ('jaguare', '', 2), ('es', '', 2)]
#
# Entities [('rua domingos de morais 2072', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('domingos', 'LOGRA', 1), ('de', 'LOGRA', 1), ('morais', 'LOGRA', 1), ('2072', 'LOGRA', 1), ('vila', '', 2), ('mariana', '', 2), ('04036-000', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('av.brig.faria lima 2886', 'LOGRA')]
# Tokens [('av.brig.faria', 'LOGRA', 3), ('lima', 'LOGRA', 1), ('2886', 'LOGRA', 1), ('jd.paulistano', '', 2), ('01452-002', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]

# %%
base_teste_final[0]

# %%
phrase = "SQSW 102, bloco D - O juventino foi na rua comprar pao "

doc = nlp(phrase)
print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
print('Tokens', [(t.text, t.ent_type_, t.ent_iob) for t in doc])

# %%
from spacy.gold import GoldParse
from spacy.scorer import Scorer

def evaluate(ner_model, examples):
    scorer = Scorer()
    for input_, annot in examples:
        doc_gold_text = ner_model.make_doc(input_)
        gold = GoldParse(doc_gold_text, entities=annot)
        pred_value = ner_model(input_)
        scorer.score(pred_value, gold)
    return scorer.scores

# %%
# save model to output directory
if output_dir is not None:
    output_dir = Path(output_dir)
    if not output_dir.exists():
        output_dir.mkdir()
    nlp.to_disk(output_dir)
    print("Saved model to", output_dir)

# %%
loaded_model = spacy.load(output_dir)
evaluate(loaded_model, base_teste_final)
