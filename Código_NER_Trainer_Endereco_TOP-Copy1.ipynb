# %%
# Load Packages
from __future__ import unicode_literals, print_function

import plac #  wrapper over argparse
import random
from pathlib import Path
import spacy
from tqdm import tqdm, tqdm_notebook # loading bar 
import pandas as pd
import re
from pprint import pprint
from nltk.tokenize import sent_tokenize
import numpy as np

from spacy.util import minibatch, compounding

# %% [markdown]
# # Abrindo e gerando Datasets

# %% [markdown]
# ### Entidade logradouro

# %%
# Obtendo dados crus de endereço

dataset = pd.read_csv("201906AGENCIAS.CSV")
dset = dataset.iloc[:-2,4:10].values  # tipo nparray object
pd_dset = pd.DataFrame(dset) # caso queira visualizar

pd_dset['Join'] = pd_dset[pd_dset.columns[0:]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)
pd_dset.head(5)
# Out:
#                                           0  \
# 0  R.GUILHERME MOREIRA,315
# 1  AV.PRES.VARGAS,248
# 2  R.QUINZE DE NOVEMBRO,195
# 3  PCA.DAS QUATRO JORNADAS,11
# 4  SEXTA AVENIDA,600
#
#                                                    1  \
# 0  SUBLOJA,LOJA E 2.ANDAR                        ...
# 1  1.E 2.ANDARES                                 ...
# 2                                                ...
# 3  MEZANINO                                      ...
# 4  SECRETARIA DA EDUCACAO-TERREO                 ...
#
#                                 2          3  \
# 0  CENTRO                          69005-300
# 1  CAMPINA                         66010-900
# 2  CENTRO                          11010-908
# 3  CENTRO                          28010-000
# 4  CAB                             41745-002
#
#                                                    4   5  \
# 0  MANAUS                                        ...  AM
# 1  BELEM                                         ...  PA
# 2  SANTOS                                        ...  SP
# 3  CAMPOS DOS GOYTACAZES                         ...  RJ
# 4  SALVADOR                                      ...  BA
#
#                                                 Join
# 0  R.GUILHERME MOREIRA,315                 ;SUBLO...
# 1  AV.PRES.VARGAS,248                      ;1.E 2...
# 2  R.QUINZE DE NOVEMBRO,195                ;     ...
# 3  PCA.DAS QUATRO JORNADAS,11              ;MEZAN...
# 4  SEXTA AVENIDA,600                       ;SECRE...

# %%
# Tratando endereço completo do DataFrame
dset = np.array(pd_dset)
end_lista = []

for i in range(len(dset)):
    str_raw = dset[i][6]
    str_tratada = re.sub(r'[ ]{2,}', "",str_raw) # Tirando espaços excedentes no final do endereço
    str_tratada = re.sub(r'[;]{1,}', "; ", str_tratada) # Para complementos vazios, para não ter 2 ";"
    str_tratada = str_tratada.lower()
    
    end_lista.append(str_tratada)

end_lista[:3]
# Out:
# ['r.guilherme moreira,315; subloja,loja e 2.andar; centro; 69005-300; manaus; am',
#  'av.pres.vargas,248; 1.e 2.andares; campina; 66010-900; belem; pa',
#  'r.quinze de novembro,195; centro; 11010-908; santos; sp']

# %%
# Lógica para extrair posição do logradouro:
# Dividir a String inteira por ";", pegar o len do primeiro split
# len de LOGRA é de 0 até len do primeiro split

print(end_lista[0])
split = end_lista[0].split(";")
print(split)
print(split[0])
print(len(split[0]))
# Out:
# r.guilherme moreira,315; subloja,loja e 2.andar; centro; 69005-300; manaus; am
# ['r.guilherme moreira,315', ' subloja,loja e 2.andar', ' centro', ' 69005-300', ' manaus', ' am']
# r.guilherme moreira,315
# 23

# %%
# Extraindo iob com entidade apenas de logradouro

iob = []

for i in range(len(end_lista)):
    split = end_lista[i].split(";")
    len_logra = len(split[0])
    iob_dict = {"entities": [(0, len_logra-1,'LOGRA')]}
    end_lista[i] = end_lista[i].replace(";", " ")
    end_lista[i] = end_lista[i].replace(",", " ")
    end_lista[i] = re.sub(r'[ ]{2,}', " ", end_lista[i])

    
    tupla = (end_lista[i], iob_dict)
    iob.append(tupla)

FULL_DATA = iob

# %%
print(FULL_DATA[0])
print(FULL_DATA[1])
print(FULL_DATA[2])
print(FULL_DATA[5:15])
# Out:
# ('r.guilherme moreira 315 subloja loja e 2.andar centro 69005-300 manaus am', {'entities': [(0, 22, 'LOGRA')]})
# ('av.pres.vargas 248 1.e 2.andares campina 66010-900 belem pa', {'entities': [(0, 17, 'LOGRA')]})
# ('r.quinze de novembro 195 centro 11010-908 santos sp', {'entities': [(0, 23, 'LOGRA')]})
# [('av.rio branco 240 1.andar recife antigo 50030-310 recife pe', {'entities': [(0, 16, 'LOGRA')]}), ('av.santos dumont 2828 5.andar aldeota 60150-162 fortaleza ce', {'entities': [(0, 20, 'LOGRA')]}), ('pca.tiradentes 410 1.andar centro 80020-100 curitiba pr', {'entities': [(0, 17, 'LOGRA')]}), ('r.uruguai 185 5.andar centro 90010-901 porto alegre rs', {'entities': [(0, 12, 'LOGRA')]}), ('pca.1817 129 1.andar centro 58013-010 joao pessoa pb', {'entities': [(0, 11, 'LOGRA')]}), ('pca.odilon resende andrade 76 centro 37410-000 tres coracoes mg', {'entities': [(0, 28, 'LOGRA')]}), ('av fernandes lima 2591 terreo farol 57057-972 maceio al', {'entities': [(0, 22, 'LOGRA')]}), ('r.treze de junho 914 centro 79300-040 corumba ms', {'entities': [(0, 19, 'LOGRA')]}), ('av.leopoldino de oliveira 3635 centro 38010-000 uberaba mg', {'entities': [(0, 29, 'LOGRA')]}), ('pca.quinze de novembro 321 centro 88010-400 florianopolis sc', {'entities': [(0, 25, 'LOGRA')]})]

# %%
# Criação da base de teste e treinamento

n_test= 0.1 # Porcentagem para base de teste
test_n = round(len(FULL_DATA) * n_test)

# Divisao em Train Test Val

def gerador_bases(dataset, n):
    indices_random = random.sample(range(0,len(dataset)-1), n)
    base_teste_n = []
    base_treinamento_n = []
    
    for i in range(n):
        base_teste_n.append(dataset[indices_random[i]])

    for j in range(len(dataset)):
        if(j not in indices_random):
            base_treinamento_n.append(dataset[j])
            
    return base_teste_n, base_treinamento_n


base_teste, base_treinamento = gerador_bases(FULL_DATA, test_n)

random.shuffle(base_treinamento)
random.shuffle(base_teste)

print("Treinamento: " + str(len(base_treinamento)), "\nTeste: " + str(len(base_teste)), "\nTotal: " + str(len(FULL_DATA)))
# Out:
# Treinamento: 19202
# Teste: 2134
# Total: 21336

# %%
for i in range(5):
    print(base_treinamento[i])
# Out:
# ('rua fernando luzzatto 208 95320-000 nova prata rs', {'entities': [(0, 25, 'LOGRA')]})
# ('av.olinto meireles milionarios 30620-330 belo horizonte mg', {'entities': [(0, 17, 'LOGRA')]})
# ('av.maj.felizardo pinho pessoa 101 terreo centro 62300-000 vicosa do ceara ce', {'entities': [(0, 32, 'LOGRA')]})
# ('av.paschoal ardito 726 sao vito 13472-130 americana sp', {'entities': [(0, 21, 'LOGRA')]})
# ('rua do catete 117 parte gloria 22220-000 rio de janeiro rj', {'entities': [(0, 17, 'LOGRA')]})

# %% [markdown]
# # Carregando o modelo

# %%
# Define our variables

model = None
output_dir=Path(".")
n_iter= 100 # número de épocas
batch_size = 64

# %%
# Setting up the pipeline and entity recognizer.
if model is not None:
    nlp = spacy.load(model)  # load existing spacy model
    print("Loaded model '%s'" % model)
else:
    lan = 'pt'
    nlp = spacy.blank(lan)  # create blank Language class
    print("Created blank '%s' model" % lan)
    
if 'ner' not in nlp.pipe_names:
    ner = nlp.create_pipe('ner')
    nlp.add_pipe(ner)
    print('Added new NER')
else:
    ner = nlp.get_pipe('ner')
    print('Got an old NER')
# Out:
# Created blank 'pt' model
# Added new NER

# %%
# create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
if 'ner' not in nlp.pipe_names:
    ner = nlp.create_pipe('ner')
    nlp.add_pipe(ner, last=True)
# otherwise, get it so we can add labels
else:
    ner = nlp.get_pipe('ner')

# %% [markdown]
# ## Treinamento

# %%
print("Batch size: ", batch_size)
print("Épocas: ", n_iter)
print()

# add labels
for _, annotations in base_treinamento:
    for ent in annotations.get('entities'):
        ner.add_label(ent[2])


# get names of other pipes to disable them during training
other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
with nlp.disable_pipes(*other_pipes):  # only train NER
    optimizer = nlp.begin_training()
    for itn in range(n_iter):
        random.shuffle(base_treinamento)
        losses = {}
        batches = minibatch(base_treinamento, size=batch_size)
        
        for batch in batches:
            texts, annotations = zip(*batch)
            try:
                nlp.update(texts, annotations, sgd=optimizer, drop=0.2,
                       losses=losses)
            except:
                pass     
        
        print(itn+1, ' Losses', losses)
# Out:
# Batch size:  64
# Épocas:  100
#
# 1  Losses {'ner': 760.4642904412153}
# 2  Losses {'ner': 687.9467526326686}
# 3  Losses {'ner': 571.2996361747396}
# 4  Losses {'ner': 584.0007234295372}
# 5  Losses {'ner': 709.6346988221127}
# 6  Losses {'ner': 677.8147405720304}
# 7  Losses {'ner': 751.0372388633491}
# 8  Losses {'ner': 654.6342283573957}
# 9  Losses {'ner': 807.3264651178127}
# 10  Losses {'ner': 648.1604003574575}
# 11  Losses {'ner': 725.218250008531}
# 12  Losses {'ner': 710.8368854340899}
# 13  Losses {'ner': 694.51988705475}
# 14  Losses {'ner': 640.6430908711286}
# 15  Losses {'ner': 613.810349366108}
# 16  Losses {'ner': 655.73425533827}
# 17  Losses {'ner': 590.9776571386733}
# 18  Losses {'ner': 563.9133672648928}
# 19  Losses {'ner': 445.7783034450096}
# 20  Losses {'ner': 662.9166887719142}
# 21  Losses {'ner': 563.531455903086}
# 22  Losses {'ner': 450.82243060089115}
# 23  Losses {'ner': 477.7843401953881}
# 24  Losses {'ner': 502.37731827908556}
# 25  Losses {'ner': 484.23391088189686}
# 26  Losses {'ner': 534.8800630784662}
# 27  Losses {'ner': 468.5407266363134}
# 28  Losses {'ner': 588.9392078873706}
# 29  Losses {'ner': 565.13152684835}
# 30  Losses {'ner': 480.8308865653794}
# 31  Losses {'ner': 468.56729717507017}
# 32  Losses {'ner': 657.0137674442316}
# 33  Losses {'ner': 557.2630605976483}
# 34  Losses {'ner': 484.64312954881876}
# 35  Losses {'ner': 444.5803337189849}
# 36  Losses {'ner': 451.80977713637276}
# 37  Losses {'ner': 508.73215296691455}
# 38  Losses {'ner': 458.79003993006154}
# 39  Losses {'ner': 436.9878103597634}
# 40  Losses {'ner': 431.93553405842783}
# 41  Losses {'ner': 424.5768326067369}
# 42  Losses {'ner': 459.9666706027454}
# 43  Losses {'ner': 415.565544593162}
# 44  Losses {'ner': 437.9532305635526}
# 45  Losses {'ner': 458.5012666610481}
# 46  Losses {'ner': 455.9059039557}
# 47  Losses {'ner': 443.99057958871634}
# 48  Losses {'ner': 532.5120479004491}
# 49  Losses {'ner': 462.7283110284723}
# 50  Losses {'ner': 603.9026469864068}
# 51  Losses {'ner': 611.5550188162406}
# 52  Losses {'ner': 530.9418968568768}
# 53  Losses {'ner': 562.6032424213328}
# 54  Losses {'ner': 481.96377207602956}
# 55  Losses {'ner': 474.353010270628}
# 56  Losses {'ner': 532.6501567924962}
# 57  Losses {'ner': 435.8178972575954}
# 58  Losses {'ner': 469.9013619687088}
# 59  Losses {'ner': 505.9303267740912}
# 60  Losses {'ner': 379.1867626654057}
# 61  Losses {'ner': 481.6594262825696}
# 62  Losses {'ner': 465.63692942656246}
# 63  Losses {'ner': 551.7921321050317}
# 64  Losses {'ner': 420.916386468452}
# 65  Losses {'ner': 536.7628033437953}
# 66  Losses {'ner': 432.8270200670818}
# 67  Losses {'ner': 407.3204206019257}
# 68  Losses {'ner': 350.05225246847385}
# 69  Losses {'ner': 367.0447608249858}
# 70  Losses {'ner': 387.4685240658077}
# 71  Losses {'ner': 524.7531579369919}
# 72  Losses {'ner': 449.44549598350494}
# 73  Losses {'ner': 417.2216613722619}
# 74  Losses {'ner': 346.49384841915855}
# 75  Losses {'ner': 382.31954822979924}
# 76  Losses {'ner': 406.35056849607145}
# 77  Losses {'ner': 356.82934235562607}
# 78  Losses {'ner': 295.3875061590658}
# 79  Losses {'ner': 337.28973523188864}
# 80  Losses {'ner': 374.8742117885311}
# 81  Losses {'ner': 416.729053796959}
# 82  Losses {'ner': 413.6184601378819}
# 83  Losses {'ner': 340.29202757389265}
# 84  Losses {'ner': 397.36528090052053}
# 85  Losses {'ner': 417.2807672245294}
# 86  Losses {'ner': 343.20980673918}
# 87  Losses {'ner': 355.9660182376454}
# 88  Losses {'ner': 258.2049091807084}
# 89  Losses {'ner': 310.0938573871224}
# 90  Losses {'ner': 546.5400827438605}
# 91  Losses {'ner': 405.5633348692477}
# 92  Losses {'ner': 558.6353252421346}
# 93  Losses {'ner': 378.4125692223295}
# 94  Losses {'ner': 477.4804485444543}
# 95  Losses {'ner': 596.2746707755614}
# 96  Losses {'ner': 320.5944556154266}
# 97  Losses {'ner': 484.11266111844037}
# 98  Losses {'ner': 412.805553497059}
# 99  Losses {'ner': 380.7874003668425}
# 100  Losses {'ner': 329.7694468502031}

# %%
# test the trained model
for text, _ in base_teste:
    doc = nlp(text)
    print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
    print('Tokens', [(t.text, t.ent_type_, t.ent_iob) for t in doc])
    print()
# Out:
# Entities [('av. mal rondon', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('mal', 'LOGRA', 1), ('rondon', 'LOGRA', 1), ('/', '', 2), ('rua', '', 2), ('princesa', '', 2), ('isabel', '', 2), ('centro', '', 2), ('78968-000', '', 2), ('pimenta', '', 2), ('bueno', '', 2), ('ro', '', 2)]
#
# Entities [('r frei caneca 569', 'LOGRA')]
# Tokens [('r', 'LOGRA', 3), ('frei', 'LOGRA', 1), ('caneca', 'LOGRA', 1), ('569', 'LOGRA', 1), ('bela', '', 2), ('vista', '', 2), ('01307-001', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('av. governador carlos de lima cavalcante num 4100', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('governador', 'LOGRA', 1), ('carlos', 'LOGRA', 1), ('de', 'LOGRA', 1), ('lima', 'LOGRA', 1), ('cavalcante', 'LOGRA', 1), ('num', 'LOGRA', 1), ('4100', 'LOGRA', 1), ('casa', '', 2), ('caiada', '', 2), ('53040-000', '', 2), ('olinda', '', 2), ('pe', '', 2)]
#
# Entities [('av. paulista 1429', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('paulista', 'LOGRA', 1), ('1429', 'LOGRA', 1), ('60746948', '', 2), ('bela', '', 2), ('vista', '', 2), ('01311-200', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('r arariboia sl 03', 'LOGRA')]
# Tokens [('r', 'LOGRA', 3), ('arariboia', 'LOGRA', 1), ('sl', 'LOGRA', 1), ('03', 'LOGRA', 1), ('centro', '', 2), ('85501-260', '', 2), ('pato', '', 2), ('branco', '', 2), ('pr', '', 2)]
#
# Entities [('av.carlos gomes 1883', 'LOGRA')]
# Tokens [('av.carlos', 'LOGRA', 3), ('gomes', 'LOGRA', 1), ('1883', 'LOGRA', 1), ('pq.sao', '', 2), ('paulo', '', 2), ('85803-000', '', 2), ('cascavel', '', 2), ('pr', '', 2)]
#
# Entities [('av sete de setembro 2775', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('sete', 'LOGRA', 1), ('de', 'LOGRA', 1), ('setembro', 'LOGRA', 1), ('2775', 'LOGRA', 1), ('7.andar', '', 2), ('reboucas', '', 2), ('80230-010', '', 2), ('curitiba', '', 2), ('pr', '', 2)]
#
# Entities [('r.joao basilio 683', 'LOGRA')]
# Tokens [('r.joao', 'LOGRA', 3), ('basilio', 'LOGRA', 1), ('683', 'LOGRA', 1), ('centro', '', 2), ('17160-000', '', 2), ('arealva', '', 2), ('sp', '', 2)]
#
# Entities [('r.dona alcides c.de souza 799', 'LOGRA')]
# Tokens [('r.dona', 'LOGRA', 3), ('alcides', 'LOGRA', 1), ('c.de', 'LOGRA', 1), ('souza', 'LOGRA', 1), ('799', 'LOGRA', 1), ('centro', '', 2), ('16980-000', '', 2), ('guaracai', '', 2), ('sp', '', 2)]
#
# Entities [('rua aymor� s/n', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('aymor', 'LOGRA', 1), ('�', 'LOGRA', 1), ('s', 'LOGRA', 1), ('/', 'LOGRA', 1), ('n', 'LOGRA', 1), ('centro', '', 2), ('68193-000', '', 2), ('novo', '', 2), ('progresso', '', 2), ('pa', '', 2)]
#
# Entities [('av.dr.arnaldo 2143', 'LOGRA')]
# Tokens [('av.dr.arnaldo', 'LOGRA', 3), ('2143', 'LOGRA', 1), ('sumare', '', 2), ('01255-000', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('pca vicentino rodrigues da cunha 0316 / 0318', 'LOGRA')]
# Tokens [('pca', 'LOGRA', 3), ('vicentino', 'LOGRA', 1), ('rodrigues', 'LOGRA', 1), ('da', 'LOGRA', 1), ('cunha', 'LOGRA', 1), ('0316', 'LOGRA', 1), ('/', 'LOGRA', 1), ('0318', 'LOGRA', 1), ('sao', '', 2), ('benedito', '', 2), ('38022-330', '', 2), ('uberaba', '', 2), ('mg', '', 2)]
#
# Entities [('av. lico maia 691', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('lico', 'LOGRA', 1), ('maia', 'LOGRA', 1), ('691', 'LOGRA', 1), ('loja', '', 2), ('e', '', 2), ('sobreloja', '', 2), ('parte', '', 2), ('concei', '', 2), ('�', '', 2), ('�', '', 2), ('o', '', 2), ('09981-420', '', 2), ('diadema', '', 2), ('sp', '', 2)]
#
# Entities [('rua doutor bozano', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('doutor', 'LOGRA', 1), ('bozano', 'LOGRA', 1), ('centro', '', 2), ('97015-002', '', 2), ('santa', '', 2), ('maria', '', 2), ('rs', '', 2)]
#
# Entities [('rua samuel klabin 794', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('samuel', 'LOGRA', 1), ('klabin', 'LOGRA', 1), ('794', 'LOGRA', 1), ('centro', '', 2), ('84261-050', '', 2), ('telemaco', '', 2), ('borba', '', 2), ('pr', '', 2)]
#
# Entities [('estrada da matriz 425', 'LOGRA')]
# Tokens [('estrada', 'LOGRA', 3), ('da', 'LOGRA', 1), ('matriz', 'LOGRA', 1), ('425', 'LOGRA', 1), ('guaratiba', '', 2), ('23020-715', '', 2), ('rio', '', 2), ('de', '', 2), ('janeiro', '', 2), ('rj', '', 2)]
#
# Entities [('r.cel.candido de assis 405', 'LOGRA')]
# Tokens [('r.cel.candido', 'LOGRA', 3), ('de', 'LOGRA', 1), ('assis', 'LOGRA', 1), ('405', 'LOGRA', 1), ('terreo', '', 2), ('centro', '', 2), ('58840-000', '', 2), ('pombal', '', 2), ('pb', '', 2)]
#
# Entities [('campus universitario s/', 'LOGRA')]
# Tokens [('campus', 'LOGRA', 3), ('universitario', 'LOGRA', 1), ('s', 'LOGRA', 1), ('/', 'LOGRA', 1), ('n', '', 2), ('jardim', '', 2), ('america', '', 2), ('96160-000', '', 2), ('capao', '', 2), ('do', '', 2), ('leao', '', 2), ('rs', '', 2)]
#
# Entities [('cna lts 09/10 ljs 01/10(t�rreo) sbjs 01/12', 'LOGRA')]
# Tokens [('cna', 'LOGRA', 3), ('lts', 'LOGRA', 1), ('09/10', 'LOGRA', 1), ('ljs', 'LOGRA', 1), ('01/10(t', 'LOGRA', 1), ('�', 'LOGRA', 1), ('rreo', 'LOGRA', 1), (')', 'LOGRA', 1), ('sbjs', 'LOGRA', 1), ('01/12', 'LOGRA', 1), ('parte', '', 2), ('taguatinga', '', 2), ('72110-015', '', 2), ('brasilia', '', 2), ('(', '', 2), ('taguatinga', '', 2), (')', '', 2), ('df', '', 2)]
#
# Entities [('r.tiburcio targino 163', 'LOGRA')]
# Tokens [('r.tiburcio', 'LOGRA', 3), ('targino', 'LOGRA', 1), ('163', 'LOGRA', 1), ('centro', '', 2), ('61700-000', '', 2), ('aquiraz', '', 2), ('ce', '', 2)]
#
# Entities [('r.maj.pacheco 160', 'LOGRA')]
# Tokens [('r.maj.pacheco', 'LOGRA', 3), ('160', 'LOGRA', 1), ('centro', '', 2), ('13790-000', '', 2), ('sao', '', 2), ('sebastiao', '', 2), ('da', '', 2), ('grama', '', 2), ('sp', '', 2)]
#
# Entities [('rua voluntarios da patria 393', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('voluntarios', 'LOGRA', 1), ('da', 'LOGRA', 1), ('patria', 'LOGRA', 1), ('393', 'LOGRA', 1), ('botafogo', '', 2), ('22270-000', '', 2), ('rio', '', 2), ('de', '', 2), ('janeiro', '', 2), ('rj', '', 2)]
#
# Entities [('r 74 s/n', 'LOGRA')]
# Tokens [('r', 'LOGRA', 3), ('74', 'LOGRA', 1), ('s', 'LOGRA', 1), ('/', 'LOGRA', 1), ('n', 'LOGRA', 1), ('jereissati', '', 2), ('ii', '', 2), ('61800-000', '', 2), ('pacatuba', '', 2), ('ce', '', 2)]
#
# Entities [('rua bela cintra n.986-2.andar', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('bela', 'LOGRA', 1), ('cintra', 'LOGRA', 1), ('n.986-2.andar', 'LOGRA', 1), ('centro', '', 2), ('14150-000', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('avenida marcolino martins cabral', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('marcolino', 'LOGRA', 1), ('martins', 'LOGRA', 1), ('cabral', 'LOGRA', 1), ('sala', '', 2), ('comercial', '', 2), ('n', '', 2), ('�', '', 2), ('102', '', 2), ('ed', '', 2), ('.', '', 2), ('mgl', '', 2), ('center', '', 2), ('centro', '', 2), ('88701-105', '', 2), ('tubarao', '', 2), ('sc', '', 2)]
#
# Entities [('rua verissimo prado 157', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('verissimo', 'LOGRA', 1), ('prado', 'LOGRA', 1), ('157', 'LOGRA', 1), ('centro', '', 2), ('13520-000', '', 2), ('sao', '', 2), ('pedro', '', 2), ('sp', '', 2)]
#
# Entities [('av. sao joao - 404', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('sao', 'LOGRA', 1), ('joao', 'LOGRA', 1), ('-', 'LOGRA', 1), ('404', 'LOGRA', 1), ('ponte', '', 2), ('s', '', 2), ('�', '', 2), ('o', '', 2), ('jo', '', 2), ('�', '', 2), ('o', '', 2), ('13216-000', '', 2), ('jundiai', '', 2), ('sp', '', 2)]
#
# Entities [('rua pres.nereu ramos 17', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('pres.nereu', 'LOGRA', 1), ('ramos', 'LOGRA', 1), ('17', 'LOGRA', 1), ('centro', '', 2), ('88502-170', '', 2), ('lages', '', 2), ('sc', '', 2)]
#
# Entities [('estrada da cacuia 126', 'LOGRA')]
# Tokens [('estrada', 'LOGRA', 3), ('da', 'LOGRA', 1), ('cacuia', 'LOGRA', 1), ('126', 'LOGRA', 1), ('ilha', '', 2), ('do', '', 2), ('governador', '', 2), ('21921-000', '', 2), ('rio', '', 2), ('de', '', 2), ('janeiro', '', 2), ('rj', '', 2)]
#
# Entities [('av 31 de mar�', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('31', 'LOGRA', 1), ('de', 'LOGRA', 1), ('mar', 'LOGRA', 1), ('�', 'LOGRA', 1), ('o', '', 2), ('centro', '', 2), ('18110-005', '', 2), ('votorantim', '', 2), ('sp', '', 2)]
#
# Entities [('av.ataulfo de paiva - 1175', 'LOGRA')]
# Tokens [('av.ataulfo', 'LOGRA', 3), ('de', 'LOGRA', 1), ('paiva', 'LOGRA', 1), ('-', 'LOGRA', 1), ('1175', 'LOGRA', 1), ('freguesia', '', 2), ('da', '', 2), ('gavea', '', 2), ('22440-032', '', 2), ('rio', '', 2), ('de', '', 2), ('janeiro', '', 2), ('rj', '', 2)]
#
# Entities [('avenida andr� ara�jo n� 39', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('andr', 'LOGRA', 1), ('�', 'LOGRA', 1), ('ara', 'LOGRA', 1), ('�', 'LOGRA', 1), ('jo', 'LOGRA', 1), ('n', 'LOGRA', 1), ('�', 'LOGRA', 1), ('39', 'LOGRA', 1), ('aleixo', '', 2), ('69060-000', '', 2), ('manaus', '', 2), ('am', '', 2)]
#
# Entities [('rua maximiliano fernandes 112', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('maximiliano', 'LOGRA', 1), ('fernandes', 'LOGRA', 1), ('112', 'LOGRA', 1), ('centro', '', 2), ('45015-900', '', 2), ('vitoria', '', 2), ('da', '', 2), ('conquista', '', 2), ('ba', '', 2)]
#
# Entities [('praia de botafogo sala 401', 'LOGRA')]
# Tokens [('praia', 'LOGRA', 3), ('de', 'LOGRA', 1), ('botafogo', 'LOGRA', 1), ('sala', 'LOGRA', 1), ('401', 'LOGRA', 1), ('botafogo', '', 2), ('22250-145', '', 2), ('rio', '', 2), ('de', '', 2), ('janeiro', '', 2), ('rj', '', 2)]
#
# Entities [('praca adelmario pinheiro 174', 'LOGRA')]
# Tokens [('praca', 'LOGRA', 3), ('adelmario', 'LOGRA', 1), ('pinheiro', 'LOGRA', 1), ('174', 'LOGRA', 1), ('centro', '', 2), ('45170-000', '', 2), ('tremedal', '', 2), ('ba', '', 2)]
#
# Entities [('rua do imperador 657', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('do', 'LOGRA', 1), ('imperador', 'LOGRA', 1), ('657', 'LOGRA', 1), ('parte', '', 2), ('centro', '', 2), ('25620-002', '', 2), ('petropolis', '', 2), ('rj', '', 2)]
#
# Entities [('av. manoel guimar�es 195', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), 
 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('visconde', 'LOGRA', 1), ('do', 'LOGRA', 1), ('rio', 'LOGRA', 1), ('branco', 'LOGRA', 1), ('417', 'LOGRA', 1), ('/439', '', 2), ('centro', '', 2), ('12020-040', '', 2), ('taubate', '', 2), ('sp', '', 2)]
#
# Entities [('r jacob shommer', 'LOGRA')]
# Tokens [('r', 'LOGRA', 3), ('jacob', 'LOGRA', 1), ('shommer', 'LOGRA', 1), ('sala', '', 2), ('101', '', 2), ('centro', '', 2), ('95765-000', '', 2), ('bom', '', 2), ('principio', '', 2), ('rs', '', 2)]
#
# Entities [('r.prof.lace 88 ramos', 'LOGRA')]
# Tokens [('r.prof.lace', 'LOGRA', 3), ('88', 'LOGRA', 1), ('ramos', 'LOGRA', 1), ('21060-120', '', 2), ('rio', '', 2), ('de', '', 2), ('janeiro', '', 2), ('rj', '', 2)]
#
# Entities [('rua barao do rio branco 957', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('barao', 'LOGRA', 1), ('do', 'LOGRA', 1), ('rio', 'LOGRA', 1), ('branco', 'LOGRA', 1), ('957', 'LOGRA', 1), ('centro', '', 2), ('14160-000', '', 2), ('sertaozinho', '', 2), ('sp', '', 2)]
#
# Entities [('pca eduardo rudge', 'LOGRA')]
# Tokens [('pca', 'LOGRA', 3), ('eduardo', 'LOGRA', 1), ('rudge', 'LOGRA', 1), ('pari', '', 2), ('03028-010', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('rua nelson mandela n� 100', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('nelson', 'LOGRA', 1), ('mandela', 'LOGRA', 1), ('n', 'LOGRA', 1), ('�', 'LOGRA', 1), ('100', 'LOGRA', 1), ('lj', '', 2), ('109', '', 2), ('a', '', 2), ('112', '', 2), ('botafogo', '', 2), ('22260-005', '', 2), ('rio', '', 2), ('de', '', 2), ('janeiro', '', 2), ('rj', '', 2)]
#
# Entities [('rua lu�s pereira de campos 901', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('lu', 'LOGRA', 1), ('�', 'LOGRA', 1), ('s', 'LOGRA', 1), ('pereira', 'LOGRA', 1), ('de', 'LOGRA', 1), ('campos', 'LOGRA', 1), ('901', 'LOGRA', 1), ('centro', '', 2), ('11250-000', '', 2), ('bertioga', '', 2), ('sp', '', 2)]
#
# Entities [('duque de caxias', 'LOGRA')]
# Tokens [('duque', 'LOGRA', 3), ('de', 'LOGRA', 1), ('caxias', 'LOGRA', 1), ('centro', '', 2), ('14015-020', '', 2), ('ribeirao', '', 2), ('preto', '', 2), ('sp', '', 2)]
#
# Entities [('pca.joao luiz da silva 183', 'LOGRA')]
# Tokens [('pca.joao', 'LOGRA', 3), ('luiz', 'LOGRA', 1), ('da', 'LOGRA', 1), ('silva', 'LOGRA', 1), ('183', 'LOGRA', 1), ('centro', '', 2), ('35240-000', '', 2), ('conselheiro', '', 2), ('pena', '', 2), ('mg', '', 2)]
#
# Entities [('rua general osorio 2', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('general', 'LOGRA', 1), ('osorio', 'LOGRA', 1), ('2', 'LOGRA', 1), ('pavimento', '', 2), ('centro', '', 2), ('29010-035', '', 2), ('vitoria', '', 2), ('es', '', 2)]
#
# Entities [('rua babacu esq. com rua porto velho s/n', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), 
#
# Entities [('r rondonia sala 3/4/5', 'LOGRA')]
# Tokens [('r', 'LOGRA', 3), ('rondonia', 'LOGRA', 1), ('sala', 'LOGRA', 1), ('3/4/5', 'LOGRA', 1), ('mimoso', '', 2), ('do', '', 2), ('oeste', '', 2), ('47850-000', '', 2), ('luis', '', 2), ('eduardo', '', 2), ('magalhaes', '', 2), ('ba', '', 2)]
#
# Entities [('av.maria coelho aguiar 215', 'LOGRA')]
# Tokens [('av.maria', 'LOGRA', 3), ('coelho', 'LOGRA', 1), ('aguiar', 'LOGRA', 1), ('215', 'LOGRA', 1), ('-lj.96', '', 2), ('-', '', 2), ('piso', '', 2), ('subterraneo-cond.centro', '', 2), ('empr', '', 2), ('.', '', 2), ('jardim', '', 2), ('s', '', 2), ('�', '', 2), ('o', '', 2), ('luiz', '', 2), ('jardim', '', 2), ('sao', '', 2), ('luiz', '', 2), ('05804-925', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('rua santa catarina num 361', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('santa', 'LOGRA', 1), ('catarina', 'LOGRA', 1), ('num', 'LOGRA', 1), ('361', 'LOGRA', 1), ('centro', '', 2), ('95770-000', '', 2), ('feliz', '', 2), ('rs', '', 2)]
#
# Entities [('av. ana costa 414', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('ana', 'LOGRA', 1), ('costa', 'LOGRA', 1), ('414', 'LOGRA', 1), ('gonzaga', '', 2), ('11060-002', '', 2), ('santos', '', 2), ('sp', '', 2)]
#
# Entities [('rua do com�rcio n� 281', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('do', 'LOGRA', 1), ('com', 'LOGRA', 1), ('�', 'LOGRA', 1), ('rcio', 'LOGRA', 1), ('n', 'LOGRA', 1), ('�', 'LOGRA', 1), ('281', 'LOGRA', 1), ('centro', '', 2), ('65365-000', '', 2), ('ze', '', 2), ('doca', '', 2), ('ma', '', 2)]
#
# Entities [('avenida 19 981', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('19', 'LOGRA', 1), ('981', 'LOGRA', 1), ('centro', '', 2), ('14780-300', '', 2), ('barretos', '', 2), ('sp', '', 2)]
#
# Entities [('av.bom clima', 'LOGRA')]
# Tokens [('av.bom', 'LOGRA', 3), ('clima', 'LOGRA', 1), ('bom', '', 2), ('clima', '', 2), ('07196-220', '', 2), ('guarulhos', '', 2), ('sp', '', 2)]
#
# Entities [('rua sao jorge 437', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('sao', 'LOGRA', 1), ('jorge', 'LOGRA', 1), ('437', 'LOGRA', 1), ('centro', '', 2), ('68379-200', '', 2), ('altamira', '', 2), ('pa', '', 2)]
#
# Entities [('unb sg 11', 'LOGRA')]
# Tokens [('unb', 'LOGRA', 3), ('sg', 'LOGRA', 1), ('11', 'LOGRA', 1), ('campus', '', 2), ('universit', '', 2), ('�', '', 2), ('rio', '', 2), ('bl', '', 2), ('.', '', 2), ('m', '', 2), ('�', '', 2), ('ltiplos', '', 2), ('usos', '', 2), ('70910-900', '', 2), ('brasilia', '', 2), ('df', '', 2)]
# Entities [('praca eleoterio g andrade 537', 'LOGRA')]
# Tokens [('praca', 'LOGRA', 3), ('eleoterio', 'LOGRA', 1), ('g', 'LOGRA', 1), ('andrade', 'LOGRA', 1), ('537', 'LOGRA', 1), ('sala', '', 2), ('3', '', 2), ('centro', '', 2), ('87250-000', '', 2), ('peabiru', '', 2), ('pr', '', 2)]
#
# Entities [('av. brigadeiro lima e silva 1685', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), 
 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('presidente', 'LOGRA', 1), ('juscelino', 'LOGRA', 1), ('kubitschek', 'LOGRA', 1), ('1300', 'LOGRA', 1), ('vila', '', 2), ('nova', '', 2), ('conceicao', '', 2), ('04543-000', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('r.cap.joao crisostomo 325', 'LOGRA')]
# Tokens [('r.cap.joao', 'LOGRA', 3), ('crisostomo', 'LOGRA', 1), ('325', 'LOGRA', 1), ('centro', '', 2), ('75690-000', '', 2), ('caldas', '', 2), ('novas', '', 2), ('go', '', 2)]
#
# Entities [('avenida tancredo neves', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('tancredo', 'LOGRA', 1), ('neves', 'LOGRA', 1), ('qd30', '', 2), ('lt13', '', 2), ('setor', '', 2), ('rodoviario', '', 2), ('76520-000', '', 2), ('nova', '', 2), ('crixas', '', 2), ('go', '', 2)]
#
# Entities [('av.brasil 946', 'LOGRA')]
# Tokens [('av.brasil', 'LOGRA', 3), ('946', 'LOGRA', 1), ('centro', '', 2), ('98801-590', '', 2), ('santo', '', 2), ('angelo', '', 2), ('rs', '', 2)]
#
# Entities [('av. crist�v�o colombo 545', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('crist', 'LOGRA', 1), ('�', 'LOGRA', 1), ('v', 'LOGRA', 1), ('�', 'LOGRA', 1), ('o', 'LOGRA', 1), ('colombo', 'LOGRA', 1), ('545', 'LOGRA', 1), ('pr', '', 2), ('�', '', 2), ('dio', '', 2), ('1loja', '', 2), ('1241', '', 2), ('floresta', '', 2), ('90560-003', '', 2), ('porto', '', 2), ('alegre', '', 2), ('rs', '', 2)]
#
# Entities [('rua augusto stresser 1609', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('augusto', 'LOGRA', 1), ('stresser', 'LOGRA', 1), ('1609', 'LOGRA', 1), ('hugo', '', 2), ('lange', '', 2), ('80040-310', '', 2), ('curitiba', '', 2), ('pr', '', 2)]
#
# Entities [('av. benjamin constant 154', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('benjamin', 'LOGRA', 1), ('constant', 'LOGRA', 1), ('154', 'LOGRA', 1), ('centro', '', 2), ('95560-000', '', 2), ('torres', '', 2), ('rs', '', 2)]
#
# Entities [('praca capitao gabriel 235', 'LOGRA')]
# Tokens [('praca', 'LOGRA', 3), ('capitao', 'LOGRA', 1), ('gabriel', 'LOGRA', 1), ('235', 'LOGRA', 1), ('centro', '', 2), ('07011-010', '', 2), ('guarulhos', '', 2), ('sp', '', 2)]
#
# Entities [('ruajose filipe da silva', 'LOGRA')]
# Tokens [('ruajose', 'LOGRA', 3), ('filipe', 'LOGRA', 1), ('da', 'LOGRA', 1), ('silva', 'LOGRA', 1), ('jardim', '', 2), ('esther', '', 2), ('05372-040', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('r sen flaquer', 'LOGRA')]
# Tokens [('r', 'LOGRA', 3), ('sen', 'LOGRA', 1), ('flaquer', 'LOGRA', 1), ('centro', '', 2), ('09010-160', '', 2), ('santo', '', 2), ('andre', '', 2), ('sp', '', 2)]
#
# Entities [('rua visconde de piraja 102 lojas a e b', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('visconde', 'LOGRA', 1), ('de', 'LOGRA', 1), ('piraja', 'LOGRA', 1), ('102', 'LOGRA', 1), ('lojas', 'LOGRA', 1), ('a', 'LOGRA', 1), ('e', 'LOGRA', 1), ('b', 'LOGRA', 1), ('ipanema', '', 2), ('22410-000', '', 2), ('rio', '', 2), ('de', '', 2), ('janeiro', '', 2), ('rj', '', 2)]
#
# Entities [('alameda araguaia 641 - parte', 'LOGRA')]
# Tokens [('alameda', 'LOGRA', 3), ('araguaia', 'LOGRA', 1), ('641', 'LOGRA', 1), ('-', 'LOGRA', 1), ('parte', 'LOGRA', 1), ('alphaville', '', 2), ('industrial', '', 2), ('06455-000', '', 2), ('barueri', '', 2), ('sp', '', 2)]
#
# Entities [('rua cassemiro andrade 265', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('cassemiro', 'LOGRA', 1), ('andrade', 'LOGRA', 1), ('265', 'LOGRA', 1), ('cen', '', 2), ('tro', '', 2), ('35910-000', '', 2), ('santa', '', 2), ('maria', '', 2), ('de', '', 2), ('itabira', '', 2), ('mg', '', 2)]
#
# Entities [('av pres.dutra', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('pres.dutra', 'LOGRA', 1), ('cidade', '', 2), ('nova', '', 2), ('28300-000', '', 2), ('itaperuna', '', 2), ('rj', '', 2)]
#
# Entities [('av parada pinto', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('parada', 'LOGRA', 1), ('pinto', 'LOGRA', 1), ('vila', '', 2), ('nova', '', 2), ('cachoeirin', '', 2), ('02611-003', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('r cazuza ramos', 'LOGRA')]
# Tokens [('r', 'LOGRA', 3), ('cazuza', 'LOGRA', 1), ('ramos', 'LOGRA', 1), ('cruzeiro', '', 2), ('65590-000', '', 2), ('barreirinhas', '', 2), ('ma', '', 2)]
#
# Entities [('av. armando mario tozzi 40', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('armando', 'LOGRA', 1), ('mario', 'LOGRA', 1), ('tozzi', 'LOGRA', 1), ('40', 'LOGRA', 1), ('jardim', '', 2), ('meton', '', 2), ('�', '', 2), ('polis', '', 2), ('13058-464', '', 2), ('campinas', '', 2), ('sp', '', 2)]
#
# Entities [('av. das na��es unidas 12.901', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('das', 'LOGRA', 1), ('na', 'LOGRA', 1), ('�', 'LOGRA', 1), ('�', 'LOGRA', 1), ('es', 'LOGRA', 1), ('unidas', 'LOGRA', 1), ('12.901', 'LOGRA', 1), ('parte', '', 2), ('brooklin', '', 2), ('paulista', '', 2), ('04578-910', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('r.dr.sales de oliveira 551', 'LOGRA')]
# Tokens [('r.dr.sales', 'LOGRA', 3), ('de', 'LOGRA', 1), ('oliveira', 'LOGRA', 1), ('551', 'LOGRA', 1), ('v.industrial', '', 2), ('13035-270', '', 2), ('campinas', '', 2), ('sp', '', 2)]
#
# Entities [('av.duque de caxias 560', 'LOGRA')]
# Tokens [('av.duque', 'LOGRA', 3), ('de', 'LOGRA', 1), ('caxias', 'LOGRA', 1), ('560', 'LOGRA', 1), ('5.andar', '', 2), ('sala', '', 2), ('exclusivo', '', 2), ('centro', '', 2), ('60035-110', '', 2), ('fortaleza', '', 2), ('ce', '', 2)]
#
# Entities [('r.conselheiro franco 418', 'LOGRA')]
# Tokens [('r.conselheiro', 'LOGRA', 3), ('franco', 'LOGRA', 1), ('418', 'LOGRA', 1), ('centro', '', 2), ('44002-272', '', 2), ('feira', '', 2), ('de', '', 2), ('santana', '', 2), ('ba', '', 2)]
#
# Entities [('rua prefeito chagas 138', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), 
'', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('praca tubal vilela 207', 'LOGRA')]
# Tokens [('praca', 'LOGRA', 3), ('tubal', 'LOGRA', 1), ('vilela', 'LOGRA', 1), ('207', 'LOGRA', 1), ('360305', '', 2), ('centro', '', 2), ('38400-186', '', 2), ('uberlandia', '', 2), ('mg', '', 2)]
#
# Entities [('r macunis', 'LOGRA')]
# Tokens [('r', 'LOGRA', 3), ('macunis', 'LOGRA', 1), ('vila', '', 2), ('madalena', '', 2), ('05444-000', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('av.inglaterra 751', 'LOGRA')]
# Tokens [('av.inglaterra', 'LOGRA', 3), ('751', 'LOGRA', 1), ('terreo', '', 2), ('centro', '', 2), ('86181-000', '', 2), ('cambe', '', 2), ('pr', '', 2)]
#
# Entities [('r.pe.pedro domingues 59', 'LOGRA')]
# Tokens [('r.pe.pedro', 'LOGRA', 3), ('domingues', 'LOGRA', 1), ('59', 'LOGRA', 1), ('centro', '', 2), ('35995-000', '', 2), ('sao', '', 2), ('domingos', '', 2), ('do', '', 2), ('prata', '', 2), ('mg', '', 2)]
#
# Entities [('av.nossa sra.do loreto 989', 'LOGRA')]
# Tokens [('av.nossa', 'LOGRA', 3), ('sra.do', 'LOGRA', 1), ('loreto', 'LOGRA', 1), ('989', 'LOGRA', 1), ('vila', '', 2), ('medeiros', '', 2), ('02219-001', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('av. rui barbosa 548', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('rui', 'LOGRA', 1), ('barbosa', 'LOGRA', 1), ('548', 'LOGRA', 1), ('centro', '', 2), ('19780-000', '', 2), ('quata', '', 2), ('sp', '', 2)]
#
# Entities []
# Tokens [(' ', '', 2), ('r', '', 2), ('antonio', '', 2), ('tupinamba', '', 2), ('portela', '', 2), ('centro', '', 2), ('64460-000', '', 2), ('agua', '', 2), ('branca', '', 2), ('pi', '', 2)]
#
# Entities [('av. dos autonomistas 5129', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('dos', 'LOGRA', 1), ('autonomistas', 'LOGRA', 1), ('5129', 'LOGRA', 1), ('km', '', 2), ('18', '', 2), ('61900-000', '', 2), ('osasco', '', 2), ('sp', '', 2)]
#
# Entities [('sbn quadra 2 - bl e lt 15', 'LOGRA')]
# Tokens [('sbn', 'LOGRA', 3), ('quadra', 'LOGRA', 1), ('2', 'LOGRA', 1), ('-', 'LOGRA', 1), ('bl', 'LOGRA', 1), ('e', 'LOGRA', 1), ('lt', 'LOGRA', 1), ('15', 'LOGRA', 1), ('11', '', 2), ('andar', '', 2), ('-', '', 2), ('ala', '', 2), ('norte', '', 2), ('a', '', 2), ('norte', '', 2), ('70040-020', '', 2), ('brasilia', '', 2), ('df', '', 2)]
# Entities [('r do humaita', 'LOGRA')]
# Tokens [('r', 'LOGRA', 3), ('do', 'LOGRA', 1), ('humaita', 'LOGRA', 1), ('humaita', '', 2), ('22261-005', '', 2), ('rio', '', 2), ('de', '', 2), ('janeiro', '', 2), ('rj', '', 2)]
#
# Entities [('campus 1 - s/n', 'LOGRA')]
# Tokens [('campus', 'LOGRA', 3), ('1', 'LOGRA', 1), ('-', 'LOGRA', 1), ('s', 'LOGRA', 1), ('/', 'LOGRA', 1), ('n', 'LOGRA', 1), ('cidade', '', 2), ('universitaria', '', 2), ('58051-970', '', 2), ('joao', '', 2), ('pessoa', '', 2), ('pb', '', 2)]
#
# Entities [('tv.mal.deodoro da fonseca 22', 'LOGRA')]
# Tokens [('tv.mal.deodoro', 'LOGRA', 3), ('da', 'LOGRA', 1), ('fonseca', 'LOGRA', 1), ('22', 'LOGRA', 1), ('centro', '', 2), ('49600-000', '', 2), ('nossa', '', 2), ('senhora', '', 2), ('das', '', 2), ('dores', '', 2), ('se', '', 2)]
#
# Entities [('praca cel. pedro osorio 164', 'LOGRA')]
# Tokens [('praca', 'LOGRA', 3), ('cel', 'LOGRA', 1), ('.', 'LOGRA', 1), ('pedro', 'LOGRA', 1), ('osorio', 'LOGRA', 1), ('164', 'LOGRA', 1), ('centro', '', 2), ('96015-010', '', 2), ('pelotas', '', 2), ('rs', '', 2)]
#
# Entities [('scs quadra 08 bloco b/60', 'LOGRA')]
# Tokens [('scs', 'LOGRA', 3), ('quadra', 'LOGRA', 1), ('08', 'LOGRA', 1), ('bloco', 'LOGRA', 1), ('b/60', 'LOGRA', 1), ('loja', '', 2), ('140-a', '', 2), ('1', '', 2), ('�', '', 2), ('andar', '', 2), ('ed', '', 2), ('.', '', 2), ('ven', '', 2), ('�', '', 2), ('ncio', '', 2), ('2000', '', 2), ('asa', '', 2), ('sul', '', 2), ('70308-000', '', 2), ('brasilia', '', 2), ('df', '', 2)]
#
# Entities [('rua 15 de novembro 443', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('15', 'LOGRA', 1), ('de', 'LOGRA', 1), ('novembro', 'LOGRA', 1), ('443', 'LOGRA', 1), ('centro', '', 2), ('96570-000', '', 2), ('cacapava', '', 2), ('do', '', 2), ('sul', '', 2), ('rs', '', 2)]
#
# Entities [('rua libero badaro 425', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('libero', 'LOGRA', 1), ('badaro', 'LOGRA', 1), ('425', 'LOGRA', 1), ('conjuntos', '', 2), ('161', '', 2), ('e', '', 2), ('162', '', 2), ('centro', '', 2), ('01009-000', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('rua joaquim da silva lima 304', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('joaquim', 'LOGRA', 1), ('da', 'LOGRA', 1), ('silva', 'LOGRA', 1), ('lima', 'LOGRA', 1), ('304', 'LOGRA', 1), ('centro', '', 2), ('29200-000', '', 2), ('guarapari', '', 2), ('es', '', 2)]
#
# Entities [('r.cel.campelo 400', 'LOGRA')]
# Tokens [('r.cel.campelo', 'LOGRA', 3), ('400', 'LOGRA', 1), ('centro', '', 2), ('65215-000', '', 2), ('viana', '', 2), ('ma', '', 2)]
#
# Entities [('rua barao do rio branco 173 - lojas 02 e', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('barao', 'LOGRA', 1), ('do', 'LOGRA', 1), ('rio', 'LOGRA', 1), ('branco', 'LOGRA', 1), ('173', 'LOGRA', 1), ('-', 'LOGRA', 1), ('lojas', 'LOGRA', 1), ('02', 'LOGRA', 1), ('e', 'LOGRA', 1), ('03', '', 2), ('centro', '', 2), ('25803-030', '', 2), ('tres', '', 2), ('rios', '', 2), ('rj', '', 2)]
#
# Entities [('rua xv de novembro 60/72', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('xv', 'LOGRA', 1), ('de', 'LOGRA', 1), ('novembro', 'LOGRA', 1), ('60/72', 'LOGRA', 1), ('centro', '', 2), ('06850-100', '', 2), ('itapecerica', '', 2), ('da', '', 2), ('serra', '', 2), ('sp', '', 2)]
#
# Entities [('av. jabaquara 823/827/829', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('jabaquara', 'LOGRA', 1), ('823/827/829', 'LOGRA', 1), ('mirand', '', 2), ('�', '', 2), ('polis', '', 2), ('04045-001', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('av rui barbosa 113', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('rui', 'LOGRA', 1), ('barbosa', 'LOGRA', 1), ('113', 'LOGRA', 1), ('heliopolis', '', 2), ('55295-530', '', 2), ('garanhuns', '', 2), ('pe', '', 2)]
#
# Entities [('pca.mal.floriano 84', 'LOGRA')]
# Tokens [('pca.mal.floriano', 'LOGRA', 3), ('84', 'LOGRA', 1), ('centro', '', 2), ('36150-000', '', 2), ('rio', '', 2), ('novo', '', 2), ('mg', '', 2)]
#
# Entities [('av.pedroso de morais 1553', 'LOGRA')]
# Tokens [('av.pedroso', 'LOGRA', 3), ('de', 'LOGRA', 1), ('morais', 'LOGRA', 1), ('1553', 'LOGRA', 1), ('loja', '', 2), ('1', '', 2), ('pinheiros', '', 2), ('05419-001', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('av cinco de marco', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('cinco', 'LOGRA', 1), ('de', 'LOGRA', 1), ('marco', 'LOGRA', 1), ('centro', '', 2), ('84240-000', '', 2), ('pirai', '', 2), ('do', '', 2), ('sul', '', 2), ('pr', '', 2)]
#
# Entities [('av.sao leopoldo 340', 'LOGRA')]
# Tokens [('av.sao', 'LOGRA', 3), ('leopoldo', 'LOGRA', 1), ('340', 'LOGRA', 1), ('centro', '', 2), ('93700-000', '', 2), ('campo', '', 2), ('bom', '', 2), ('rs', '', 2)]
#
# Entities [('av.tiradentes s-220', 'LOGRA')]
# Tokens [('av.tiradentes', 'LOGRA', 3), ('s-220', 'LOGRA', 1), ('centro', '', 2), ('17280-000', '', 2), ('pederneiras', '', 2), ('sp', '', 2)]
#
# Entities [('av. dos andradas 97/99', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('dos', 'LOGRA', 1), ('andradas', 'LOGRA', 1), ('97/99', 'LOGRA', 1), ('centro', '', 2), ('36036-000', '', 2), ('juiz', '', 2), ('de', '', 2), ('fora', '', 2), ('mg', '', 2)]
#
# Entities [('rua prefessor atilio innocenti n� 165', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('prefessor', 'LOGRA', 1), ('atilio', 'LOGRA', 1), ('innocenti', 'LOGRA', 1), ('n', 'LOGRA', 1), ('�', 'LOGRA', 1), ('165', 'LOGRA', 1), ('conjunto', '', 2), ('1601', '', 2), ('-', '', 2), ('15', '', 2), ('�', '', 2), ('andar', '', 2), ('00000-000', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('av. brasil 660', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('brasil', 'LOGRA', 1), ('660', 'LOGRA', 1), ('centro', '', 2), ('89887-000', '', 2), ('palmitos', '', 2), ('sc', '', 2)]
#
# Entities [('r.dos pioneiros 400', 'LOGRA')]
# Tokens [('r.dos', 'LOGRA', 3), ('pioneiros', 'LOGRA', 1), ('400', 'LOGRA', 1), ('centro', '', 2), ('88420-000', '', 2), ('agrolandia', '', 2), ('sc', '', 2)]
#
# Entities [('rua juazeiro', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('juazeiro', 'LOGRA', 1), ('centro', '', 2), ('85460-000', '', 2), ('quedas', '', 2), ('do', '', 2), ('iguacu', '', 2), ('pr', '', 2)]
#
# Entities [('av. goias 483', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('goias', 'LOGRA', 1), ('483', 'LOGRA', 1), ('santo', '', 2), ('antonio', '', 2), ('09521-310', '', 2), ('sao', '', 2), ('caetano', '', 2), ('do', '', 2), ('sul', '', 2), ('sp', '', 2)]
#
# Entities [('rua pinheiro machado 958', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('pinheiro', 'LOGRA', 1), ('machado', 'LOGRA', 1), ('958', 'LOGRA', 1), ('centro', '', 2), ('98005-000', '', 2), ('cruz', '', 2), ('alta', '', 2), ('rs', '', 2)]
#
# Entities [('r.felipe cardoso 130', 'LOGRA')]
# Tokens [('r.felipe', 'LOGRA', 3), ('cardoso', 'LOGRA', 1), ('130', 'LOGRA', 1), ('sta.cruz', '', 2), ('23515-000', '', 2), ('rio', '', 2), ('de', '', 2), ('janeiro', '', 2), ('rj', '', 2)]
#
# Entities [('av.vol.fernando pinheiro franco 432', 'LOGRA')]
# Tokens [('av.vol.fernando', 'LOGRA', 3), ('pinheiro', 'LOGRA', 1), ('franco', 'LOGRA', 1), ('432', 'LOGRA', 1), ('predio', '', 2), ('centro', '', 2), ('08710-500', '', 2), ('mogi', '', 2), ('das', '', 2), ('cruzes', '', 2), ('sp', '', 2)]
#
# Entities [('qnm 01 s/n�', 'LOGRA')]
# Tokens [('qnm', 'LOGRA', 3), ('01', 'LOGRA', 1), ('s', 'LOGRA', 1), ('/', 'LOGRA', 1), ('n', 'LOGRA', 1), ('�', 'LOGRA', 1), ('conjunto', '', 2), ('g', '', 2), ('-', '', 2), ('lotes', '', 2), ('1', '', 2), ('e', '', 2), ('3', '', 2), ('ceil', '', 2), ('�', '', 2), ('ndia', '', 2), ('sul', '', 2), ('72215-017', '', 2), ('brasilia', '', 2), ('df', '', 2)]
#
# Entities [('rua manoel da nobrega 712', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('manoel', 'LOGRA', 1), ('da', 'LOGRA', 1), ('nobrega', 'LOGRA', 1), ('712', 'LOGRA', 1), ('lojas', '', 2), ('336', '', 2), ('e', '', 2), ('337', '', 2), ('centro', '', 2), ('09910-720', '', 2), ('diadema', '', 2), ('sp', '', 2)]
#
# Entities [('r.dr.antonio marcos gouveia 3', 'LOGRA')]
# Tokens [('r.dr.antonio', 'LOGRA', 3), ('marcos', 'LOGRA', 1), ('gouveia', 'LOGRA', 1), ('3', 'LOGRA', 1), ('centro', '', 2), ('73900-000', '', 2), ('posse', '', 2), ('go', '', 2)]
#
# Entities [('alameda filtros mann 670', 'LOGRA')]
# Tokens [('alameda', 'LOGRA', 3), ('filtros', 'LOGRA', 1), ('mann', 'LOGRA', 1), ('670', 'LOGRA', 1), ('loja', '', 2), ('41', '', 2), ('jardim', '', 2), ('tropical', '', 2), ('13344-580', '', 2), ('indaiatuba', '', 2), ('sp', '', 2)]
#
# Entities [('pca.conego siqueira 37', 'LOGRA')]
# Tokens [('pca.conego', 'LOGRA', 3), ('siqueira', 'LOGRA', 1), ('37', 'LOGRA', 1), ('centro', '', 2), ('12530-000', '', 2), ('cunha', '', 2), ('sp', '', 2)]
#
# Entities [('av gal flores da cunha 3758', 'LOGRA')]
# ...
#
# Entities [('av. lins de vasconcelos 128', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('lins', 'LOGRA', 1), ('de', 'LOGRA', 1), ('vasconcelos', 'LOGRA', 1), ('128', 'LOGRA', 1), ('cambuci', '', 2), ('01538-000', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('av orival c�ndido luz de oliveira 5245', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('orival', 'LOGRA', 1), ('c', 'LOGRA', 1), ('�', 'LOGRA', 1), ('ndido', 'LOGRA', 1), ('luz', 'LOGRA', 1), ('de', 'LOGRA', 1), ('oliveira', 'LOGRA', 1), ('5245', 'LOGRA', 1), ('s', '', 2), ('�', '', 2), ('o', '', 2), ('vicente', '', 2), ('94060-001', '', 2), ('gravatai', '', 2), ('rs', '', 2)]
#
# Entities [('av.nazare 1177', 'LOGRA')]
# Tokens [('av.nazare', 'LOGRA', 3), ('1177', 'LOGRA', 1), ('ipiranga', '', 2), ('04263-100', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('avenida aclimacao 68', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('aclimacao', 'LOGRA', 1), ('68', 'LOGRA', 1), ('aclimacao', '', 2), ('01531-000', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('av.republica argentina 4357', 'LOGRA')]
# Tokens [('av.republica', 'LOGRA', 3), ('argentina', 'LOGRA', 1), ('4357', 'LOGRA', 1), ('novo', '', 2), ('mundo', '', 2), ('81050-000', '', 2), ('curitiba', '', 2), ('pr', '', 2)]
#
# Entities [('avenida puglisi n� 330', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('puglisi', 'LOGRA', 1), ('n', 'LOGRA', 1), ('�', 'LOGRA', 1), ('330', 'LOGRA', 1), ('parte', '', 2), ('centro', '', 2), ('11410-000', '', 2), ('guaruja', '', 2), ('sp', '', 2)]
#
# Entities [('av francisco ferreira lopes 2737/rua schwartzmann', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('francisco', 'LOGRA', 1), ('ferreira', 'LOGRA', 1), ('lopes', 'LOGRA', 1), ('2737', 'LOGRA', 1), ('/', 'LOGRA', 1), ('rua', 'LOGRA', 1), ('schwartzmann', 'LOGRA', 1), ('centro', '', 2), ('88500-000', '', 2), ('mogi', '', 2), ('das', '', 2), ('cruzes', '', 2), ('sp', '', 2)]
#
# Entities [('r pamplona 1129', 'LOGRA')]
# Tokens [('r', 'LOGRA', 3), ('pamplona', 'LOGRA', 1), ('1129', 'LOGRA', 1), ('jardim', '', 2), ('paulista', '', 2), ('01405-200', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('av s�o paulo 911', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('s', 'LOGRA', 1), ('�', 'LOGRA', 1), ('o', 'LOGRA', 1), ('paulo', 'LOGRA', 1), ('911', 'LOGRA', 1), ('alem', '', 2), ('ponte', '', 2), ('18013-002', '', 2), ('sorocaba', '', 2), ('sp', '', 2)]
#
# Entities [('av.canaa 3102', 'LOGRA')]
# Tokens [('av.canaa', 'LOGRA', 3), ('3102', 'LOGRA', 1), ('setor', '', 2), ('01', '', 2), ('setor', '', 2), ('1', '', 2), ('76870-078', '', 2), ('ariquemes', '', 2), ('ro', '', 2)]
#
# Entities [('av almirante barroso 23 andar', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('almirante', 'LOGRA', 1), ('barroso', 'LOGRA', 1), ('23', 'LOGRA', 1), ('andar', 'LOGRA', 1), ('sala', '', 2), ('2301', '', 2), ('centro', '', 2), ('20031-000', '', 2), ('rio', '', 2), ('de', '', 2), ('janeiro', '', 2), ('rj', '', 2)]
#
# Entities [('av.dr. nelson d avila 203', 'LOGRA')]
# Tokens [('av.dr', 'LOGRA', 3), ('.', 'LOGRA', 1), ('nelson', 'LOGRA', 1), ('d', 'LOGRA', 1), ('avila', 'LOGRA', 1), ('203', 'LOGRA', 1), ('jd.sao', '', 2), ('dimas', '', 2), ('12245-030', '', 2), ('sao', '', 2), ('jose', '', 2), ('dos', '', 2), ('campos', '', 2), ('sp', '', 2)]
#
# Entities [('av. fernando ferrari 2033', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('fernando', 'LOGRA', 1), ('ferrari', 'LOGRA', 1), ('2033', 'LOGRA', 1), ('goiabeiras', '', 2), ('29075-051', '', 2), ('vitoria', '', 2), ('es', '', 2)]
#
# Entities [('av.t-sete 599', 'LOGRA')]
# Tokens [('av.', 'LOGRA', 3), ('t-sete', 'LOGRA', 1), ('599', 'LOGRA', 1), ('esq.c', '', 2), ('/', '', 2), ('r.', '', 2), ('t-vinte', '', 2), ('e', '', 2), ('oito', '', 2), ('setor', '', 2), ('bueno', '', 2), ('74210-260', '', 2), ('goiania', '', 2), ('go', '', 2)]
#
# Entities [('rua dr. maruri 693', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('dr', 'LOGRA', 1), ('.', 'LOGRA', 1), ('maruri', 'LOGRA', 1), ('693', 'LOGRA', 1), ('89700-000', '', 2), ('concordia', '', 2), ('sc', '', 2)]
#
# Entities [('av do forte 1628 / 1638', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('do', 'LOGRA', 1), ('forte', 'LOGRA', 1), ('1628', 'LOGRA', 1), ('/', 'LOGRA', 1), ('1638', 'LOGRA', 1), ('vl', '', 2), ('ipiranga', '', 2), ('91360-001', '', 2), ('porto', '', 2), ('alegre', '', 2), ('rs', '', 2)]
#
# Entities [('r. santos dumont n� 68', 'LOGRA')]
# Tokens [('r.', 'LOGRA', 3), ('santos', 'LOGRA', 1), ('dumont', 'LOGRA', 1), ('n', 'LOGRA', 1), ('�', 'LOGRA', 1), ('68', 'LOGRA', 1), ('centro', '', 2), ('28010-220', '', 2), ('campos', '', 2), ('dos', '', 2), ('goytacazes', '', 2), ('rj', '', 2)]
#
# Entities [('av. rui barbosa 756', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('rui', 'LOGRA', 1), ('barbosa', 'LOGRA', 1), ('756', 'LOGRA', 1), ('centro', '', 2), ('68005-080', '', 2), ('santarem', '', 2), ('pa', '', 2)]
#
# Entities [('av. rodovalho', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('rodovalho', 'LOGRA', 1), ('sala', '', 2), ('02', '', 2), ('centro', '', 2), ('88701-170', '', 2), ('tubarao', '', 2), ('sc', '', 2)]
#
# Entities [('rua onze 2353', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('onze', 'LOGRA', 1), ('2353', 'LOGRA', 1), ('centro', '', 2), ('15700-000', '', 2), ('jales', '', 2), ('sp', '', 2)]
#
# Entities [('av. governador pedro de toledo 1126', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('governador', 'LOGRA', 1), ('pedro', 'LOGRA', 1), ('de', 'LOGRA', 1), ('toledo', 'LOGRA', 1), ('1126', 'LOGRA', 1), ('bonfim', '', 2), ('13070-150', '', 2), ('campinas', '', 2), ('sp', '', 2)]
#
# Entities [('rua jose de alencar menino de', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('jose', 'LOGRA', 1), ('de', 'LOGRA', 1), ('alencar', 'LOGRA', 1), ('menino', 'LOGRA', 1), ('de', 'LOGRA', 1), ('deus', '', 2), ('90880-481', '', 2), ('porto', '', 2), ('alegre', '', 2), ('rs', '', 2)]
#
# Entities [('rua siqueira campos 1163', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('siqueira', 'LOGRA', 1), ('campos', 'LOGRA', 1), ('1163', 'LOGRA', 1), ('lojas', '', 2), ('1', '', 2), ('2', '', 2), ('centro', '', 2), ('90010-001', '', 2), ('porto', '', 2), ('alegre', '', 2), ('rs', '', 2)]
#
# Entities [('r episcopal n', 'LOGRA')]
# Tokens [('r', 'LOGRA', 3), ('episcopal', 'LOGRA', 1), ('n', 'LOGRA', 1), ('resid', '', 2), ('s.vilari', '', 2), ('13560-570', '', 2), ('sao', '', 2), ('carlos', '', 2), ('sp', '', 2)]
#
# Entities [('rua voluntarios da patria', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('voluntarios', 'LOGRA', 1), ('da', 'LOGRA', 1), ('patria', 'LOGRA', 1), ('loja', '', 2), ('a', '', 2), ('botafogo', '', 2), ('22270-014', '', 2), ('rio', '', 2), ('de', '', 2), ('janeiro', '', 2), ('rj', '', 2)]
#
# Entities [('rua do passeio', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('do', 'LOGRA', 1), ('passeio', 'LOGRA', 1), ('11', '', 2), ('�', '', 2), ('.', '', 2), ('andar', '', 2), ('-', '', 2), ('parte', '', 2), ('centro', '', 2), ('20021-290', '', 2), ('rio', '', 2), ('de', '', 2), ('janeiro', '', 2), ('rj', '', 2)]
#
# Entities [('av benjamin pinto dias 1281', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('benjamin', 'LOGRA', 1), ('pinto', 'LOGRA', 1), ('dias', 'LOGRA', 1), ('1281', 'LOGRA', 1), ('centro', '', 2), ('26130-000', '', 2), ('belford', '', 2), ('roxo', '', 2), ('rj', '', 2)]
#
# Entities [('rua vieira de moraes 767', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('vieira', 'LOGRA', 1), ('de', 'LOGRA', 1), ('moraes', 'LOGRA', 1), ('767', 'LOGRA', 1), ('campo', '', 2), ('belo', '', 2), ('04617-012', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('r. miguel terra 313', 'LOGRA')]
# Tokens [('r.', 'LOGRA', 3), ('miguel', 'LOGRA', 1), ('terra', 'LOGRA', 1), ('313', 'LOGRA', 1), ('centro', '', 2), ('18230-000', '', 2), ('sao', '', 2), ('miguel', '', 2), ('arcanjo', '', 2), ('sp', '', 2)]
#
# Entities [('r.maria amalia lopes azevedo 493', 'LOGRA')]
# Tokens [('r.maria', 'LOGRA', 3), ('amalia', 'LOGRA', 1), ('lopes', 'LOGRA', 1), ('azevedo', 'LOGRA', 1), ('493', 'LOGRA', 1), ('vl', '', 2), ('albertina', '', 2), ('02350-011', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('rua doutor colares', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('doutor', 'LOGRA', 1), ('colares', 'LOGRA', 1), ('loja', '', 2), ('1', '', 2), ('e', '', 2), ('2', '', 2), ('t', '', 2), ('�', '', 2), ('rreo', '', 2), ('centro', '', 2), ('84010-010', '', 2), ('ponta', '', 2), ('grossa', '', 2), ('pr', '', 2)]
#
# Entities [('av.brasil 229', 'LOGRA')]
# Tokens [('av.brasil', 'LOGRA', 3), ('229', 'LOGRA', 1), ('boqueirao', '', 2), ('11701-090', '', 2), ('praia', '', 2), ('grande', '', 2), ('sp', '', 2)]
#
# Entities [('rua estacio de sa 155', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('estacio', 'LOGRA', 1), ('de', 'LOGRA', 1), ('sa', 'LOGRA', 1), ('155', 'LOGRA', 1), ('estacio', '', 2), ('20211-270', '', 2), ('rio', '', 2), ('de', '', 2), ('janeiro', '', 2), ('rj', '', 2)]
#
# Entities [('rua coronel amazonas', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('coronel', 'LOGRA', 1), ('amazonas', 'LOGRA', 1), ('marcondes', '', 2), ('cabral', '', 2), ('80035-230', '', 2), ('curitiba', '', 2), ('pr', '', 2)]
#
# Entities [('ruacoriolano vila romana 05047-000 sao paulo', 'LOGRA')]
# Tokens [('ruacoriolano', 'LOGRA', 3), ('vila', 'LOGRA', 1), ('romana', 'LOGRA', 1), ('05047-000', 'LOGRA', 1), ('sao', 'LOGRA', 1), ('paulo', 'LOGRA', 1), ('sp', '', 2)]
#
# Entities [('rua pires fleury 149', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('pires', 'LOGRA', 1), ('fleury', 'LOGRA', 1), ('149', 'LOGRA', 1), ('centro', '', 2), ('18400-430', '', 2), ('itapeva', '', 2), ('sp', '', 2)]
#
# Entities [('av.calama 2167 esq.c/salgado filho', 'LOGRA')]
# Tokens [('av.calama', 'LOGRA', 3), ('2167', 'LOGRA', 1), ('esq.c', 'LOGRA', 1), ('/', 'LOGRA', 1), ('salgado', 'LOGRA', 1), ('filho', 'LOGRA', 1), ('sao', '', 2), ('joao', '', 2), ('bosco', '', 2), ('76803-745', '', 2), ('porto', '', 2), ('velho', '', 2), ('ro', '', 2)]
#
# Entities [('avenida vinte de janeiro', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('vinte', 'LOGRA', 1), ('de', 'LOGRA', 1), ('janeiro', 'LOGRA', 1), ('terminal', '', 2), ('2', '', 2), ('�', '', 2), ('rea', '', 2), ('de', '', 2), ('embarque', '', 2), ('port', '', 2), ('�', '', 2), ('o', '', 2), ('d', '', 2), ('gale', '', 2), ('�', '', 2), ('o', '', 2), ('gale', '', 2), ('�', '', 2), ('o', '', 2), ('21941-570', '', 2), ('rio', '', 2), ('de', '', 2), ('janeiro', '', 2), ('rj', '', 2)]
#
# Entities [('r.nereu ramos 222', 'LOGRA')]
# Tokens [('r.nereu', 'LOGRA', 3), ('ramos', 'LOGRA', 1), ('222', 'LOGRA', 1), ('centro', '', 2), ('88240-000', '', 2), ('sao', '', 2), ('joao', '', 2), ('batista', '', 2), ('sc', '', 2)]
#
# Entities [('rua novo horizonte 293', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('novo', 'LOGRA', 1), ('horizonte', 'LOGRA', 1), ('293', 'LOGRA', 1), ('centro', '', 2), ('35148-000', '', 2), ('dom', '', 2), ('cavati', '', 2), ('mg', '', 2)]
#
# Entities [('av antonio bai�', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('antonio', 'LOGRA', 1), ('bai', 'LOGRA', 1), ('�', 'LOGRA', 1), ('o', '', 2), ('centro', '', 2), ('68465-000', '', 2), ('baiao', '', 2), ('pa', '', 2)]
#
# Entities [('av.getulio vargas 625', 'LOGRA')]
# Tokens [('av.getulio', 'LOGRA', 3), ('vargas', 'LOGRA', 1), ('625', 'LOGRA', 1), ('centro', '', 2), ('16920-000', '', 2), ('castilho', '', 2), ('sp', '', 2)]
#
# Entities [('rua da consolacao 2104', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('da', 'LOGRA', 1), ('consolacao', 'LOGRA', 1), ('2104', 'LOGRA', 1), ('consolacao', '', 2), ('01302-001', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('rua santa rita n� 327', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('santa', 'LOGRA', 1), ('rita', 'LOGRA', 1), ('n', 'LOGRA', 1), ('�', 'LOGRA', 1), ('327', 'LOGRA', 1), ('centro', '', 2), ('36010-071', '', 2), ('juiz', '', 2), ('de', '', 2), ('fora', '', 2), ('mg', '', 2)]
#
# Entities [('praca bom jesus de piraporinha 43', 'LOGRA')]
# Tokens [('praca', 'LOGRA', 3), ('bom', 'LOGRA', 1), ('jesus', 'LOGRA', 1), ('de', 'LOGRA', 1), ('piraporinha', 'LOGRA', 1), ('43', 'LOGRA', 1), ('piraporinha', '', 2), ('99000-000', '', 2), ('diadema', '', 2), ('sp', '', 2)]
#
# Entities [('rua fadlo jabur 877', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('fadlo', 'LOGRA', 1), ('jabur', 'LOGRA', 1), ('877', 'LOGRA', 1), ('centro', '', 2), ('19880-000', '', 2), ('candido', '', 2), ('mota', '', 2), ('sp', '', 2)]
#
# Entities [('rua helmuth sprung s/n', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('helmuth', 'LOGRA', 1), ('sprung', 'LOGRA', 1), ('s', 'LOGRA', 1), ('/', 'LOGRA', 1), ('n', 'LOGRA', 1), ('centro', '', 2), ('89108-000', '', 2), ('massaranduba', '', 2), ('sc', '', 2)]
#
# Entities [('rua tiradentes 42', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('tiradentes', 'LOGRA', 1), ('42', 'LOGRA', 1), ('centro', '', 2), ('35900-013', '', 2), ('itabira', '', 2), ('mg', '', 2)]
#
# Entities [('r.mal.deodoro 512 4.andar', 'LOGRA')]
# Tokens [('r.mal.deodoro', 'LOGRA', 3), ('512', 'LOGRA', 1), ('4.andar', 'LOGRA', 1), ('centro', '', 2), ('96810-908', '', 2), ('santa', '', 2), ('cruz', '', 2), ('do', '', 2), ('sul', '', 2), ('rs', '', 2)]
# Entities [('av.sapopemba 2969', 'LOGRA')]
# Tokens [('av.sapopemba', 'LOGRA', 3), ('2969', 'LOGRA', 1), ('v.regente', '', 2), ('feijo', '', 2), ('03345-001', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('rua floriano peixoto 131', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('floriano', 'LOGRA', 1), ('peixoto', 'LOGRA', 1), ('131', 'LOGRA', 1), ('sto', '', 2), ('antonio', '', 2), ('50020-060', '', 2), ('recife', '', 2), ('pe', '', 2)]
#
# Entities [('av.vinte e cinco de abril 787', 'LOGRA')]
# Tokens [('av.vinte', 'LOGRA', 3), ('e', 'LOGRA', 1), ('cinco', 'LOGRA', 1), ('de', 'LOGRA', 1), ('abril', 'LOGRA', 1), ('787', 'LOGRA', 1), ('sala', '', 2), ('1', '', 2), ('centro', '', 2), ('99370-000', '', 2), ('fontoura', '', 2), ('xavier', '', 2), ('rs', '', 2)]
#
# Entities [('av. iguacu 2345', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('iguacu', 'LOGRA', 1), ('2345', 'LOGRA', 1), ('agua', '', 2), ('verde', '', 2), ('80240-030', '', 2), ('curitiba', '', 2), ('pr', '', 2)]
#
# Entities [('rua vereador arthur mariano 1470', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('vereador', 'LOGRA', 1), ('arthur', 'LOGRA', 1), ('mariano', 'LOGRA', 1), ('1470', 'LOGRA', 1), ('forquilhinhas', '', 2), ('88106-501', '', 2), ('sao', '', 2), ('jose', '', 2), ('sc', '', 2)]
#
# Entities [('rua funchal 418 23', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('funchal', 'LOGRA', 1), ('418', 'LOGRA', 1), ('23', 'LOGRA', 1), ('andar', '', 2), ('vila', '', 2), ('olimpia', '', 2), ('04551-060', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('av. bento goncalves 2421', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('bento', 'LOGRA', 1), ('goncalves', 'LOGRA', 1), ('2421', 'LOGRA', 1), ('partenon', '', 2), ('90650-003', '', 2), ('porto', '', 2), ('alegre', '', 2), ('rs', '', 2)]
#
# Entities [('rua julio de castilhos 976', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('julio', 'LOGRA', 1), ('de', 'LOGRA', 1), ('castilhos', 'LOGRA', 1), ('976', 'LOGRA', 1), ('centro', '', 2), ('97220-000', '', 2), ('faxinal', '', 2), ('do', '', 2), ('soturno', '', 2), ('rs', '', 2)]
#
# Entities [('rua vieira de moraes 767', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('vieira', 'LOGRA', 1), ('de', 'LOGRA', 1), ('moraes', 'LOGRA', 1), ('767', 'LOGRA', 1), ('campo', '', 2), ('belo', '', 2), ('04617-012', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('rua dom nery 31', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('dom', 'LOGRA', 1), ('nery', 'LOGRA', 1), ('31', 'LOGRA', 1), ('parte', '', 2), ('vila', '', 2), ('embare', '', 2), ('13271-170', '', 2), ('valinhos', '', 2), ('sp', '', 2)]
#
# Entities [('rua nove 799', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('nove', 'LOGRA', 1), ('799', 'LOGRA', 1), ('centro', '', 2), ('86140-000', '', 2), ('primeiro', '', 2), ('de', '', 2), ('maio', '', 2), ('pr', '', 2)]

# %%
phrase = "SHVP Rua 12 435 casa 22 lote 1"

doc = nlp(phrase)
print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
print('Tokens', [(t.text, t.ent_type_, t.ent_iob) for t in doc])
# Out:
# Entities [('SHVP Rua 12 435', 'LOGRA')]
# Tokens [('SHVP', 'LOGRA', 3), ('Rua', 'LOGRA', 1), ('12', 'LOGRA', 1), ('435', 'LOGRA', 1), ('casa', '', 2), ('22', '', 2), ('lote', '', 2), ('1', '', 2)]

# %%
# save model to output directory
if output_dir is not None:
    output_dir = Path(output_dir)
    if not output_dir.exists():
        output_dir.mkdir()
    nlp.to_disk(output_dir)
    print("Saved model to", output_dir)

# %%
loaded_model = spacy.load(output_dir)
evaluate(loaded_model, base_teste_final)
