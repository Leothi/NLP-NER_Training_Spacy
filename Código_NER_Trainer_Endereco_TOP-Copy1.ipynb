# %%
# Load Packages
from __future__ import unicode_literals, print_function

import plac #  wrapper over argparse
import random
from pathlib import Path
import spacy
from tqdm import tqdm, tqdm_notebook # loading bar 
import pandas as pd
import re
from pprint import pprint
from nltk.tokenize import sent_tokenize
import numpy as np

from spacy.util import minibatch, compounding

# %% [markdown]
# # Abrindo e gerando Datasets

# %% [markdown]
# ### Entidade logradouro

# %%
# Obtendo dados crus de endereço

dataset = pd.read_csv("201906AGENCIAS.CSV")
dset = dataset.iloc[:-2,4:10].values  # tipo nparray object
pd_dset = pd.DataFrame(dset) # caso queira visualizar

pd_dset['Join'] = pd_dset[pd_dset.columns[0:]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)
pd_dset.head(5)
# Out:
#                                           0  \
# 0  R.GUILHERME MOREIRA,315
# 1  AV.PRES.VARGAS,248
# 2  R.QUINZE DE NOVEMBRO,195
# 3  PCA.DAS QUATRO JORNADAS,11
# 4  SEXTA AVENIDA,600
#
#                                                    1  \
# 0  SUBLOJA,LOJA E 2.ANDAR                        ...
# 1  1.E 2.ANDARES                                 ...
# 2                                                ...
# 3  MEZANINO                                      ...
# 4  SECRETARIA DA EDUCACAO-TERREO                 ...
#
#                                 2          3  \
# 0  CENTRO                          69005-300
# 1  CAMPINA                         66010-900
# 2  CENTRO                          11010-908
# 3  CENTRO                          28010-000
# 4  CAB                             41745-002
#
#                                                    4   5  \
# 0  MANAUS                                        ...  AM
# 1  BELEM                                         ...  PA
# 2  SANTOS                                        ...  SP
# 3  CAMPOS DOS GOYTACAZES                         ...  RJ
# 4  SALVADOR                                      ...  BA
#
#                                                 Join
# 0  R.GUILHERME MOREIRA,315                 ;SUBLO...
# 1  AV.PRES.VARGAS,248                      ;1.E 2...
# 2  R.QUINZE DE NOVEMBRO,195                ;     ...
# 3  PCA.DAS QUATRO JORNADAS,11              ;MEZAN...
# 4  SEXTA AVENIDA,600                       ;SECRE...

# %%
# Tratando endereço completo do DataFrame
dset = np.array(pd_dset)
end_lista = []

for i in range(len(dset)):
    str_raw = dset[i][6]
    str_tratada = re.sub(r'[ ]{2,}', "",str_raw) # Tirando espaços excedentes no final do endereço
    str_tratada = re.sub(r'[;]{1,}', "; ", str_tratada) # Para complementos vazios, para não ter 2 ";"
    str_tratada = str_tratada.lower()
    
    end_lista.append(str_tratada)

end_lista[:3]
# Out:
# ['r.guilherme moreira,315; subloja,loja e 2.andar; centro; 69005-300; manaus; am',
#  'av.pres.vargas,248; 1.e 2.andares; campina; 66010-900; belem; pa',
#  'r.quinze de novembro,195; centro; 11010-908; santos; sp']

# %%
# Lógica para extrair posição do logradouro:
# Dividir a String inteira por ";", pegar o len do primeiro split
# len de LOGRA é de 0 até len do primeiro split

print(end_lista[0])
split = end_lista[0].split(";")
print(split)
print(split[0])
print(len(split[0]))
# Out:
# r.guilherme moreira,315; subloja,loja e 2.andar; centro; 69005-300; manaus; am
# ['r.guilherme moreira,315', ' subloja,loja e 2.andar', ' centro', ' 69005-300', ' manaus', ' am']
# r.guilherme moreira,315
# 23

# %%
# Extraindo iob com entidade apenas de logradouro

iob = []

for i in range(len(end_lista)):
    split = end_lista[i].split(";")
    len_logra = len(split[0])
    iob_dict = {"entities": [(0, len_logra-1,'LOGRA')]}
    end_lista[i] = end_lista[i].replace(";", " ")
    end_lista[i] = end_lista[i].replace(",", " ")
    end_lista[i] = re.sub(r'[ ]{2,}', " ", end_lista[i])

    
    tupla = (end_lista[i], iob_dict)
    iob.append(tupla)

FULL_DATA = iob

# %%
print(FULL_DATA[0])
print(FULL_DATA[1])
print(FULL_DATA[2])
print(FULL_DATA[5:15])
# Out:
# ('r.guilherme moreira 315 subloja loja e 2.andar centro 69005-300 manaus am', {'entities': [(0, 22, 'LOGRA')]})
# ('av.pres.vargas 248 1.e 2.andares campina 66010-900 belem pa', {'entities': [(0, 17, 'LOGRA')]})
# ('r.quinze de novembro 195 centro 11010-908 santos sp', {'entities': [(0, 23, 'LOGRA')]})
# [('av.rio branco 240 1.andar recife antigo 50030-310 recife pe', {'entities': [(0, 16, 'LOGRA')]}), ('av.santos dumont 2828 5.andar aldeota 60150-162 fortaleza ce', {'entities': [(0, 20, 'LOGRA')]}), ('pca.tiradentes 410 1.andar centro 80020-100 curitiba pr', {'entities': [(0, 17, 'LOGRA')]}), ('r.uruguai 185 5.andar centro 90010-901 porto alegre rs', {'entities': [(0, 12, 'LOGRA')]}), ('pca.1817 129 1.andar centro 58013-010 joao pessoa pb', {'entities': [(0, 11, 'LOGRA')]}), ('pca.odilon resende andrade 76 centro 37410-000 tres coracoes mg', {'entities': [(0, 28, 'LOGRA')]}), ('av fernandes lima 2591 terreo farol 57057-972 maceio al', {'entities': [(0, 22, 'LOGRA')]}), ('r.treze de junho 914 centro 79300-040 corumba ms', {'entities': [(0, 19, 'LOGRA')]}), ('av.leopoldino de oliveira 3635 centro 38010-000 uberaba mg', {'entities': [(0, 29, 'LOGRA')]}), ('pca.quinze de novembro 321 centro 88010-400 florianopolis sc', {'entities': [(0, 25, 'LOGRA')]})]

# %%
# Criação da base de teste e treinamento

n_test= 0.1 # Porcentagem para base de teste
test_n = round(len(FULL_DATA) * n_test)

# Divisao em Train Test Val

def gerador_bases(dataset, n):
    indices_random = random.sample(range(0,len(dataset)-1), n)
    base_teste_n = []
    base_treinamento_n = []
    
    for i in range(n):
        base_teste_n.append(dataset[indices_random[i]])

    for j in range(len(dataset)):
        if(j not in indices_random):
            base_treinamento_n.append(dataset[j])
            
    return base_teste_n, base_treinamento_n


base_teste, base_treinamento = gerador_bases(FULL_DATA, test_n)

random.shuffle(base_treinamento)
random.shuffle(base_teste)

print("Treinamento: " + str(len(base_treinamento)), "\nTeste: " + str(len(base_teste)), "\nTotal: " + str(len(FULL_DATA)))
# Out:
# Treinamento: 1800
# Teste: 200
# Total: 2000

# %%
for i in range(5):
    print(base_treinamento[i])
# Out:
# ('r.epaminondas otoni 655 centro 39800-013 teofilo otoni mg', {'entities': [(0, 22, 'LOGRA')]})
# ('r.manoel teixeira 104 centro 62690-000 trairi ce', {'entities': [(0, 20, 'LOGRA')]})
# ('av.treze de maio 1271 fatima 60040-531 fortaleza ce', {'entities': [(0, 20, 'LOGRA')]})
# ('r.mal.deodoro 250 centro 36800-000 carangola mg', {'entities': [(0, 16, 'LOGRA')]})
# ('r.osvaldo aranha 1173 centro 95800-000 venancio aires rs', {'entities': [(0, 20, 'LOGRA')]})

# %% [markdown]
# # Carregando o modelo

# %%
# Define our variables

model = None
output_dir=Path(".")
n_iter= 100 # número de épocas
batch_size = 64

# %%
# Setting up the pipeline and entity recognizer.
if model is not None:
    nlp = spacy.load(model)  # load existing spacy model
    print("Loaded model '%s'" % model)
else:
    lan = 'pt'
    nlp = spacy.blank(lan)  # create blank Language class
    print("Created blank '%s' model" % lan)
    
if 'ner' not in nlp.pipe_names:
    ner = nlp.create_pipe('ner')
    nlp.add_pipe(ner)
    print('Added new NER')
else:
    ner = nlp.get_pipe('ner')
    print('Got an old NER')
# Out:
# Created blank 'pt' model
# Added new NER

# %%
# create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
if 'ner' not in nlp.pipe_names:
    ner = nlp.create_pipe('ner')
    nlp.add_pipe(ner, last=True)
# otherwise, get it so we can add labels
else:
    ner = nlp.get_pipe('ner')

# %% [markdown]
# ## Treinamento

# %%
print("Batch size: ", batch_size)
print("Épocas: ", n_iter)
print()

# add labels
for _, annotations in base_treinamento:
    for ent in annotations.get('entities'):
        ner.add_label(ent[2])


# get names of other pipes to disable them during training
other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
with nlp.disable_pipes(*other_pipes):  # only train NER
    optimizer = nlp.begin_training()
    for itn in range(n_iter):
        random.shuffle(base_treinamento)
        losses = {}
        batches = minibatch(base_treinamento, size=batch_size)
        
        for batch in batches:
            texts, annotations = zip(*batch)
            try:
                nlp.update(texts, annotations, sgd=optimizer, drop=0.2,
                       losses=losses)
            except:
                pass     
        
        print(itn+1, ' Losses', losses)
# Out:
# Batch size:  64
# Épocas:  100
#
# 1  Losses {'ner': 1559.5595977943287}
# 2  Losses {'ner': 1490.0462197471606}
# 3  Losses {'ner': 1134.8614108696947}
# 4  Losses {'ner': 687.8915019851787}
# 5  Losses {'ner': 1376.311012612151}
# 6  Losses {'ner': 2280.8992327513965}
# 7  Losses {'ner': 1927.3640766712306}
# 8  Losses {'ner': 1283.797549846296}
# 9  Losses {'ner': 1624.361715951236}
# 10  Losses {'ner': 2852.494131278356}
# 11  Losses {'ner': 2104.7023815662833}
# 12  Losses {'ner': 2805.3739378665923}
# 13  Losses {'ner': 1256.035228499821}
# 14  Losses {'ner': 1200.4833045062624}
# 15  Losses {'ner': 535.1601272814876}
# 16  Losses {'ner': 215.59785919485748}
# 17  Losses {'ner': 133.67288609961608}
# 18  Losses {'ner': 89.57682846451706}
# 19  Losses {'ner': 65.54582043993138}
# 20  Losses {'ner': 33.82947820466246}
# 21  Losses {'ner': 49.49752629896843}
# 22  Losses {'ner': 34.20698050746046}
# 23  Losses {'ner': 35.13046170945543}
# 24  Losses {'ner': 23.74079663874369}
# 25  Losses {'ner': 41.14272138716639}
# 26  Losses {'ner': 93.66768504517897}
# 27  Losses {'ner': 40.60962992307348}
# 28  Losses {'ner': 33.091002524696314}
# 29  Losses {'ner': 135.70740230177142}
# 30  Losses {'ner': 37.35297875455075}
# 31  Losses {'ner': 32.68721746726373}
# 32  Losses {'ner': 120.07348238866624}
# 33  Losses {'ner': 167.63527325791497}
# 34  Losses {'ner': 69.63258313841868}
# 35  Losses {'ner': 11.093956315778183}
# 36  Losses {'ner': 33.224717491961236}
# 37  Losses {'ner': 19.547887591423212}
# 38  Losses {'ner': 21.07753020834586}
# 39  Losses {'ner': 21.950518666549176}
# 40  Losses {'ner': 39.691035081689336}
# 41  Losses {'ner': 33.817596537317904}
# 42  Losses {'ner': 39.12923374442793}
# 43  Losses {'ner': 33.207331172163684}
# 44  Losses {'ner': 26.658776994182023}
# 45  Losses {'ner': 30.43361061117937}
# 46  Losses {'ner': 11.46712860611215}
# 47  Losses {'ner': 11.489212813831315}
# 48  Losses {'ner': 13.82832370121018}
# 49  Losses {'ner': 8.131387961704268}
# 50  Losses {'ner': 15.360959839799632}
# 51  Losses {'ner': 21.960547467954235}
# 52  Losses {'ner': 13.119577433043705}
# 53  Losses {'ner': 97.85921593661841}
# 54  Losses {'ner': 429.91292788269743}
# 55  Losses {'ner': 23.773791906893138}
# 56  Losses {'ner': 26.35462919595108}
# 57  Losses {'ner': 37.9130776668022}
# 58  Losses {'ner': 12.572652751678325}
# 59  Losses {'ner': 7.546690932659443}
# 60  Losses {'ner': 13.596362655176042}
# 61  Losses {'ner': 5.118821911758732}
# 62  Losses {'ner': 9.85302495351348}
# 63  Losses {'ner': 9.206072871738659}
# 64  Losses {'ner': 13.80297332987072}
# 65  Losses {'ner': 10.111916284202627}
# 66  Losses {'ner': 17.178900383049626}
# 67  Losses {'ner': 6.5051975365516865}
# 68  Losses {'ner': 13.603839028420609}
# 69  Losses {'ner': 2.1290337362636125}
# 70  Losses {'ner': 6.802135626505114}
# 71  Losses {'ner': 48.6712238941815}
# 72  Losses {'ner': 17.186428815011084}
# 73  Losses {'ner': 25.932966338199737}
# 74  Losses {'ner': 247.2241109139648}
# 75  Losses {'ner': 44.63079328825991}
# 76  Losses {'ner': 16.581811149005365}
# 77  Losses {'ner': 10.75121348914689}
# 78  Losses {'ner': 18.55547709981645}
# 79  Losses {'ner': 10.79986809777681}
# 80  Losses {'ner': 4.827200651662354}
# 81  Losses {'ner': 9.297897985442617}
# 82  Losses {'ner': 31.1916153101631}
# 83  Losses {'ner': 13.627029033151297}
# 84  Losses {'ner': 55.25014117575004}
# 85  Losses {'ner': 122.9043395559584}
# 86  Losses {'ner': 307.75534435294713}
# 87  Losses {'ner': 106.09568297000651}
# 88  Losses {'ner': 31.85710908958146}
# 89  Losses {'ner': 32.11300535719091}
# 90  Losses {'ner': 17.658207298800907}
# 91  Losses {'ner': 29.521183403694828}
# 92  Losses {'ner': 21.748837611895954}
# 93  Losses {'ner': 74.16934593236843}
# 94  Losses {'ner': 34.189402807625896}
# 95  Losses {'ner': 47.64720774248951}
# 96  Losses {'ner': 41.92947716632708}
# 97  Losses {'ner': 29.628548712585083}
# 98  Losses {'ner': 50.50246420906681}
# 99  Losses {'ner': 42.04675757939852}
# 100  Losses {'ner': 50.71920314089943}

# %%
# test the trained model
for text, _ in base_teste:
    doc = nlp(text)
    print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
    print('Tokens', [(t.text, t.ent_type_, t.ent_iob) for t in doc])
    print()
# Out:
# Entities [('av.barao do rio branco 2108', 'LOGRA')]
# Tokens [('av.barao', 'LOGRA', 3), ('do', 'LOGRA', 1), ('rio', 'LOGRA', 1), ('branco', 'LOGRA', 1), ('2108', 'LOGRA', 1), ('terreo', '', 2), ('centro', '', 2), ('68743-050', '', 2), ('castanhal', '', 2), ('pa', '', 2)]
#
# Entities [('av. presidente getulio vargas 2230', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('presidente', 'LOGRA', 1), ('getulio', 'LOGRA', 1), ('vargas', 'LOGRA', 1), ('2230', 'LOGRA', 1), ('rec', '', 2), ('lago', '', 2), ('45987-900', '', 2), ('teixeira', '', 2), ('de', '', 2), ('freitas', '', 2), ('ba', '', 2)]
#
# Entities [('av.do engenho 309', 'LOGRA')]
# Tokens [('av.do', 'LOGRA', 3), ('engenho', 'LOGRA', 1), ('309', 'LOGRA', 1), ('centro', '', 2), ('89893-000', '', 2), ('mondai', '', 2), ('sc', '', 2)]
#
# Entities [('r.comandai 500 centro', 'LOGRA')]
# Tokens [('r.comandai', 'LOGRA', 3), ('500', 'LOGRA', 1), ('centro', 'LOGRA', 1), ('97950-000', '', 2), ('guarani', '', 2), ('das', '', 2), ('missoes', '', 2), ('rs', '', 2)]
#
# Entities [('av.gov.walfredo siqueira 15', 'LOGRA')]
# Tokens [('av.gov.walfredo', 'LOGRA', 3), ('siqueira', 'LOGRA', 1), ('15', 'LOGRA', 1), ('terreo', '', 2), ('centro', '', 2), ('56700-000', '', 2), ('sao', '', 2), ('jose', '', 2), ('do', '', 2), ('egito', '', 2), ('pe', '', 2)]
#
# Entities [('r.dr.bernardo ribeiro viana 976', 'LOGRA')]
# Tokens [('r.dr.bernardo', 'LOGRA', 3), ('ribeiro', 'LOGRA', 1), ('viana', 'LOGRA', 1), ('976', 'LOGRA', 1), ('terreo', '', 2), ('centro', '', 2), ('85555-000', '', 2), ('palmas', '', 2), ('pr', '', 2)]
#
# Entities [('r.dois 232', 'LOGRA')]
# Tokens [('r.dois', 'LOGRA', 3), ('232', 'LOGRA', 1), ('centro', '', 2), ('14620-000', '', 2), ('orlandia', '', 2), ('sp', '', 2)]
#
# Entities [('r.sao benedito 951', 'LOGRA')]
# Tokens [('r.sao', 'LOGRA', 3), ('benedito', 'LOGRA', 1), ('951', 'LOGRA', 1), ('sao', '', 2), ('benedito', '', 2), ('38022-100', '', 2), ('uberaba', '', 2), ('mg', '', 2)]
#
# Entities [('r.sao vicente de paula 17', 'LOGRA')]
# Tokens [('r.sao', 'LOGRA', 3), ('vicente', 'LOGRA', 1), ('de', 'LOGRA', 1), ('paula', 'LOGRA', 1), ('17', 'LOGRA', 1), ('centro', '', 2), ('47940-000', '', 2), ('wanderley', '', 2), ('ba', '', 2)]
#
# Entities [('r.jorge lacerda 1168', 'LOGRA')]
# Tokens [('r.jorge', 'LOGRA', 3), ('lacerda', 'LOGRA', 1), ('1168', 'LOGRA', 1), ('centro', '', 2), ('89930-000', '', 2), ('sao', '', 2), ('jose', '', 2), ('do', '', 2), ('cedro', '', 2), ('sc', '', 2)]
#
# Entities [('r.cel.candido de assis 405', 'LOGRA')]
# Tokens [('r.cel.candido', 'LOGRA', 3), ('de', 'LOGRA', 1), ('assis', 'LOGRA', 1), ('405', 'LOGRA', 1), ('terreo', '', 2), ('centro', '', 2), ('58840-000', '', 2), ('pombal', '', 2), ('pb', '', 2)]
#
# Entities [('av.sete de setembro 285', 'LOGRA')]
# Tokens [('av.sete', 'LOGRA', 3), ('de', 'LOGRA', 1), ('setembro', 'LOGRA', 1), ('285', 'LOGRA', 1), ('centro', '', 2), ('84430-000', '', 2), ('imbituva', '', 2), ('pr', '', 2)]
#
# Entities [('pca.da republica 116', 'LOGRA')]
# Tokens [('pca.da', 'LOGRA', 3), ('republica', 'LOGRA', 1), ('116', 'LOGRA', 1), ('centro', '', 2), ('86925-000', '', 2), ('borrazopolis', '', 2), ('pr', '', 2)]
#
# Entities [('pca.dr.luiz viana filho 214', 'LOGRA')]
# Tokens [('pca.dr.luiz', 'LOGRA', 3), ('viana', 'LOGRA', 1), ('filho', 'LOGRA', 1), ('214', 'LOGRA', 1), ('centro', '', 2), ('47640-000', '', 2), ('santa', '', 2), ('maria', '', 2), ('da', '', 2), ('vitoria', '', 2), ('ba', '', 2)]
#
# Entities [('r.anibal mascarenhas 143', 'LOGRA')]
# Tokens [('r.anibal', 'LOGRA', 3), ('mascarenhas', 'LOGRA', 1), ('143', 'LOGRA', 1), ('centro', '', 2), ('65980-000', '', 2), ('carolina', '', 2), ('ma', '', 2)]
#
# Entities [('av.flores da cunha 1286', 'LOGRA')]
# Tokens [('av.flores', 'LOGRA', 3), ('da', 'LOGRA', 1), ('cunha', 'LOGRA', 1), ('1286', 'LOGRA', 1), ('centro', '', 2), ('99500-000', '', 2), ('carazinho', '', 2), ('rs', '', 2)]
#
# Entities [('r.francisco duarte 95', 'LOGRA')]
# Tokens [('r.francisco', 'LOGRA', 3), ('duarte', 'LOGRA', 1), ('95', 'LOGRA', 1), ('centro', '', 2), ('57240-000', '', 2), ('sao', '', 2), ('miguel', '', 2), ('dos', '', 2), ('campos', '', 2), ('al', '', 2)]
#
# Entities [('rua rangel junior 170', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('rangel', 'LOGRA', 1), ('junior', 'LOGRA', 1), ('170', 'LOGRA', 1), ('centro', '', 2), ('08900-000', '', 2), ('guararema', '', 2), ('sp', '', 2)]
#
# Entities [('r.da independencia 1310', 'LOGRA')]
# Tokens [('r.da', 'LOGRA', 3), ('independencia', 'LOGRA', 1), ('1310', 'LOGRA', 1), ('centro', '', 2), ('59900-000', '', 2), ('pau', '', 2), ('dos', '', 2), ('ferros', '', 2), ('rn', '', 2)]
#
# Entities [('pca.barao de araras 171', 'LOGRA')]
# Tokens [('pca.barao', 'LOGRA', 3), ('de', 'LOGRA', 1), ('araras', 'LOGRA', 1), ('171', 'LOGRA', 1), ('centro', '', 2), ('13600-905', '', 2), ('araras', '', 2), ('sp', '', 2)]
#
# Entities [('r.arlindo colaco 210', 'LOGRA')]
# Tokens [('r.arlindo', 'LOGRA', 3), ('colaco', 'LOGRA', 1), ('210', 'LOGRA', 1), ('sao', '', 2), ('miguel', '', 2), ('paulista', '', 2), ('08010-010', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('av.rio branco 688 a', 'LOGRA')]
# Tokens [('av.rio', 'LOGRA', 3), ('branco', 'LOGRA', 1), ('688', 'LOGRA', 1), ('a', 'LOGRA', 1), ('o', '', 2), ('lado', '', 2), ('do', '', 2), ('carrefour', '', 2), ('centro', '', 2), ('97010-422', '', 2), ('santa', '', 2), ('maria', '', 2), ('rs', '', 2)]
#
# Entities [('pca.dr.henrique sampaio 150', 'LOGRA')]
# Tokens [('pca.dr.henrique', 'LOGRA', 3), ('sampaio', 'LOGRA', 1), ('150', 'LOGRA', 1), ('centro', '', 2), ('45745-000', '', 2), ('ibicarai', '', 2), ('ba', '', 2)]
#
# Entities [('av.castelo branco s/', 'LOGRA')]
# Tokens [('av.castelo', 'LOGRA', 3), ('branco', 'LOGRA', 1), ('s', 'LOGRA', 1), ('/', 'LOGRA', 1), ('n', '', 2), ('centro', '', 2), ('65393-000', '', 2), ('buriticupu', '', 2), ('ma', '', 2)]
#
# Entities [('r.hugo napoleao 1132', 'LOGRA')]
# Tokens [('r.hugo', 'LOGRA', 3), ('napoleao', 'LOGRA', 1), ('1132', 'LOGRA', 1), ('centro', '', 2), ('64110-000', '', 2), ('jose', '', 2), ('de', '', 2), ('freitas', '', 2), ('pi', '', 2)]
#
# Entities [('av.sao jose 100', 'LOGRA')]
# Tokens [('av.sao', 'LOGRA', 3), ('jose', 'LOGRA', 1), ('100', 'LOGRA', 1), ('centro', '', 2), ('55636-000', '', 2), ('cha', '', 2), ('grande', '', 2), ('pe', '', 2)]
#
# Entities [('r.prof.irineu chaluppe 75', 'LOGRA')]
# Tokens [('r.prof.irineu', 'LOGRA', 3), ('chaluppe', 'LOGRA', 1), ('75', 'LOGRA', 1), ('centro', '', 2), ('06653-180', '', 2), ('itapevi', '', 2), ('sp', '', 2)]
#
# Entities [('av.juracy magalhaes 150 centro', 'LOGRA')]
# Tokens [('av.juracy', 'LOGRA', 3), ('magalhaes', 'LOGRA', 1), ('150', 'LOGRA', 1), ('centro', 'LOGRA', 1), ('48180-000', '', 2), ('entre', '', 2), ('rios', '', 2), ('ba', '', 2)]
#
# Entities [('avenida prefeito sizenando jaime 1', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('prefeito', 'LOGRA', 1), ('sizenando', 'LOGRA', 1), ('jaime', 'LOGRA', 1), ('1', 'LOGRA', 1), ('centro', '', 2), ('72980-000', '', 2), ('pirenopolis', '', 2), ('go', '', 2)]
#
# Entities [('av.brasil 1377', 'LOGRA')]
# Tokens [('av.brasil', 'LOGRA', 3), ('1377', 'LOGRA', 1), ('centro', '', 2), ('85851-000', '', 2), ('foz', '', 2), ('do', '', 2), ('iguacu', '', 2), ('pr', '', 2)]
#
# Entities [('r.dom pedro segundo 161', 'LOGRA')]
# Tokens [('r.dom', 'LOGRA', 3), ('pedro', 'LOGRA', 1), ('segundo', 'LOGRA', 1), ('161', 'LOGRA', 1), ('centro', '', 2), ('65268-000', '', 2), ('cururupu', '', 2), ('ma', '', 2)]
#
# Entities [('av.francisco raulino 1734 centro', 'LOGRA')]
# Tokens [('av.francisco', 'LOGRA', 3), ('raulino', 'LOGRA', 1), ('1734', 'LOGRA', 1), ('centro', 'LOGRA', 1), ('64290-000', '', 2), ('altos', '', 2), ('pi', '', 2)]
#
# Entities [('av.cinco de setembro 796', 'LOGRA')]
# Tokens [('av.cinco', 'LOGRA', 3), ('de', 'LOGRA', 1), ('setembro', 'LOGRA', 1), ('796', 'LOGRA', 1), ('centro', '', 2), ('69800-000', '', 2), ('humaita', '', 2), ('am', '', 2)]
#
# Entities [('av.raul soares 265', 'LOGRA')]
# Tokens [('av.raul', 'LOGRA', 3), ('soares', 'LOGRA', 1), ('265', 'LOGRA', 1), ('centro', '', 2), ('36970-000', '', 2), ('manhumirim', '', 2), ('mg', '', 2)]
#
# Entities [('praca beraldo arruda 82', 'LOGRA')]
# Tokens [('praca', 'LOGRA', 3), ('beraldo', 'LOGRA', 1), ('arruda', 'LOGRA', 1), ('82', 'LOGRA', 1), ('centro', '', 2), ('16500-000', '', 2), ('cafelandia', '', 2), ('sp', '', 2)]
#
# Entities [('r.d-sete s/', 'LOGRA')]
# Tokens [('r.', 'LOGRA', 3), ('d-sete', 'LOGRA', 1), ('s', 'LOGRA', 1), ('/', 'LOGRA', 1), ('n', '', 2), ('qd.18', '', 2), ('pca.do', '', 2), ('centro', '', 2), ('civico', '', 2), ('centro', '', 2), ('69360-000', '', 2), ('caracarai', '', 2), ('rr', '', 2)]
#
# Entities [('r.mal.deodoro 512 1', 'LOGRA')]
# Tokens [('r.mal.deodoro', 'LOGRA', 3), ('512', 'LOGRA', 1), ('1', 'LOGRA', 1), ('.', '', 2), ('2.e', '', 2), ('3.andares', '', 2), ('centro', '', 2), ('96810-908', '', 2), ('santa', '', 2), ('cruz', '', 2), ('do', '', 2), ('sul', '', 2), ('rs', '', 2)]
#
# Entities [('r.tiradentes 707 sala 1', 'LOGRA')]
# Tokens [('r.tiradentes', 'LOGRA', 3), ('707', 'LOGRA', 1), ('sala', 'LOGRA', 1), ('1', 'LOGRA', 1), ('centro', '', 2), ('99260-000', '', 2), ('casca', '', 2), ('rs', '', 2)]
#
# Entities [('r.rui barbosa 1175', 'LOGRA')]
# Tokens [('r.rui', 'LOGRA', 3), ('barbosa', 'LOGRA', 1), ('1175', 'LOGRA', 1), ('centro', '', 2), ('88930-000', '', 2), ('turvo', '', 2), ('sc', '', 2)]
#
# Entities [('av.gov.leonel de moura brizola 1461', 'LOGRA')]
# Tokens [('av.gov.leonel', 'LOGRA', 3), ('de', 'LOGRA', 1), ('moura', 'LOGRA', 1), ('brizola', 'LOGRA', 1), ('1461', 'LOGRA', 1), ('centro', '', 2), ('25010-009', '', 2), ('duque', '', 2), ('de', '', 2), ('caxias', '', 2), ('rj', '', 2)]
#
# Entities [('pca. joao nery de santana 210', 'LOGRA')]
# Tokens [('pca', 'LOGRA', 3), ('.', 'LOGRA', 1), ('joao', 'LOGRA', 1), ('nery', 'LOGRA', 1), ('de', 'LOGRA', 1), ('santana', 'LOGRA', 1), ('210', 'LOGRA', 1), ('centro', '', 2), ('47530-000', '', 2), ('oliveira', '', 2), ('dos', '', 2), ('brejinhos', '', 2), ('ba', '', 2)]
#
# Entities [('r.sete de setembro 80', 'LOGRA')]
# Tokens [('r.sete', 'LOGRA', 3), ('de', 'LOGRA', 1), ('setembro', 'LOGRA', 1), ('80', 'LOGRA', 1), ('centro', '', 2), ('45570-000', '', 2), ('ipiau', '', 2), ('ba', '', 2)]
#
# Entities [('r.assis brasil 67', 'LOGRA')]
# Tokens [('r.assis', 'LOGRA', 3), ('brasil', 'LOGRA', 1), ('67', 'LOGRA', 1), ('centro', '', 2), ('95185-000', '', 2), ('carlos', '', 2), ('barbosa', '', 2), ('rs', '', 2)]
#
# Entities [('r.rio de janeiro 2162', 'LOGRA')]
# Tokens [('r.rio', 'LOGRA', 3), ('de', 'LOGRA', 1), ('janeiro', 'LOGRA', 1), ('2162', 'LOGRA', 1), ('centro', '', 2), ('15600-000', '', 2), ('fernandopolis', '', 2), ('sp', '', 2)]
#
# Entities [('pca.bernardino v.dos santos 84', 'LOGRA')]
# Tokens [('pca.bernardino', 'LOGRA', 3), ('v.dos', 'LOGRA', 1), ('santos', 'LOGRA', 1), ('84', 'LOGRA', 1), ('centro', '', 2), ('75950-000', '', 2), ('jandaia', '', 2), ('go', '', 2)]
#
# Entities [('r.jose bonifacio 534', 'LOGRA')]
# Tokens [('r.jose', 'LOGRA', 3), ('bonifacio', 'LOGRA', 1), ('534', 'LOGRA', 1), ('centro', '', 2), ('15850-000', '', 2), ('urupes', '', 2), ('sp', '', 2)]
#
# Entities [('r.princesa isabel 563', 'LOGRA')]
# Tokens [('r.princesa', 'LOGRA', 3), ('isabel', 'LOGRA', 1), ('563', 'LOGRA', 1), ('centro', '', 2), ('17930-000', '', 2), ('tupi', '', 2), ('paulista', '', 2), ('sp', '', 2)]
#
# Entities [('r.barao do rio branco 1548', 'LOGRA')]
# Tokens [('r.barao', 'LOGRA', 3), ('do', 'LOGRA', 1), ('rio', 'LOGRA', 1), ('branco', 'LOGRA', 1), ('1548', 'LOGRA', 1), ('centro', '', 2), ('83750-000', '', 2), ('lapa', '', 2), ('pr', '', 2)]
#
# Entities [('r.dr.luis bastos', 'LOGRA')]
# Tokens [('r.dr.luis', 'LOGRA', 3), ('bastos', 'LOGRA', 1), ('do', '', 2), ('prado', '', 2), ('1317', '', 2), ('centro', '', 2), ('94010-020', '', 2), ('gravatai', '', 2), ('rs', '', 2)]
#
# Entities [('r.vigario antunes 201 predio', 'LOGRA')]
# Tokens [('r.vigario', 'LOGRA', 3), ('antunes', 'LOGRA', 1), ('201', 'LOGRA', 1), ('predio', 'LOGRA', 1), ('centro', '', 2), ('35550-000', '', 2), ('itapecerica', '', 2), ('mg', '', 2)]
#
# Entities [('r.pedro lessa 36', 'LOGRA')]
# Tokens [('r.pedro', 'LOGRA', 3), ('lessa', 'LOGRA', 1), ('36', 'LOGRA', 1), ('loja', '', 2), ('b', '', 2), ('centro', '', 2), ('20030-030', '', 2), ('rio', '', 2), ('de', '', 2), ('janeiro', '', 2), ('rj', '', 2)]
#
# Entities [('av.cuiaba 135', 'LOGRA')]
# Tokens [('av.cuiaba', 'LOGRA', 3), ('135', 'LOGRA', 1), ('terreo', '', 2), ('centro', '', 2), ('78830-000', '', 2), ('dom', '', 2), ('aquino', '', 2), ('mt', '', 2)]
#
# Entities [('rua quinze de novembro 1305', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('quinze', 'LOGRA', 1), ('de', 'LOGRA', 1), ('novembro', 'LOGRA', 1), ('1305', 'LOGRA', 1), ('1.andar', '', 2), ('centro', '', 2), ('89010-915', '', 2), ('blumenau', '', 2), ('sc', '', 2)]
#
# Entities [('r.pe.cacique 785 centro', 'LOGRA')]
# Tokens [('r.pe.cacique', 'LOGRA', 3), ('785', 'LOGRA', 1), ('centro', 'LOGRA', 1), ('98910-000', '', 2), ('tres', '', 2), ('de', '', 2), ('maio', '', 2), ('rs', '', 2)]
#
# Entities [('r.senhor do bonfim 268', 'LOGRA')]
# Tokens [('r.senhor', 'LOGRA', 3), ('do', 'LOGRA', 1), ('bonfim', 'LOGRA', 1), ('268', 'LOGRA', 1), ('terreo', '', 2), ('centro', '', 2), ('46500-000', '', 2), ('macaubas', '', 2), ('ba', '', 2)]
#
# Entities [('r.lopes trovao 511', 'LOGRA')]
# Tokens [('r.lopes', 'LOGRA', 3), ('trovao', 'LOGRA', 1), ('511', 'LOGRA', 1), ('centro', '', 2), ('49900-000', '', 2), ('propria', '', 2), ('se', '', 2)]
#
# Entities [('r.benedito quintino 397', 'LOGRA')]
# Tokens [('r.benedito', 'LOGRA', 3), ('quintino', 'LOGRA', 1), ('397', 'LOGRA', 1), ('centro', '', 2), ('35830-000', '', 2), ('jaboticatubas', '', 2), ('mg', '', 2)]
#
# Entities [('r.juvenal hartmann 53', 'LOGRA')]
# Tokens [('r.juvenal', 'LOGRA', 3), ('hartmann', 'LOGRA', 1), ('53', 'LOGRA', 1), ('centro', '', 2), ('07901-111', '', 2), ('francisco', '', 2), ('morato', '', 2), ('sp', '', 2)]
#
# Entities [('av.antonio carlos 6627', 'LOGRA')]
# Tokens [('av.antonio', 'LOGRA', 3), ('carlos', 'LOGRA', 1), ('6627', 'LOGRA', 1), ('campus', '', 2), ('ufmg', '', 2), ('pampulha', '', 2), ('pampulha', '', 2), ('31270-901', '', 2), ('belo', '', 2), ('horizonte', '', 2), ('mg', '', 2)]
#
# Entities [('r.da saudade 2', 'LOGRA')]
# Tokens [('r.da', 'LOGRA', 3), ('saudade', 'LOGRA', 1), ('2', 'LOGRA', 1), ('centro', '', 2), ('55340-000', '', 2), ('aguas', '', 2), ('belas', '', 2), ('pe', '', 2)]
#
# Entities [('av.nilopecanha 108', 'LOGRA')]
# Tokens [('av.nilopecanha', 'LOGRA', 3), ('108', 'LOGRA', 1), ('centro', '', 2), ('27600-000', '', 2), ('valenca', '', 2), ('rj', '', 2)]
#
# Entities [('r.jose niero 136', 'LOGRA')]
# Tokens [('r.jose', 'LOGRA', 3), ('niero', 'LOGRA', 1), ('136', 'LOGRA', 1), ('centro', '', 2), ('13290-000', '', 2), ('louveira', '', 2), ('sp', '', 2)]
#
# Entities [('r.dr.orlando teixeira 29', 'LOGRA')]
# Tokens [('r.dr.orlando', 'LOGRA', 3), ('teixeira', 'LOGRA', 1), ('29', 'LOGRA', 1), ('terreo', '', 2), ('centro', '', 2), ('48410-000', '', 2), ('cicero', '', 2), ('dantas', '', 2), ('ba', '', 2)]
#
# Entities [('r.pedro de toledo 557', 'LOGRA')]
# Tokens [('r.pedro', 'LOGRA', 3), ('de', 'LOGRA', 1), ('toledo', 'LOGRA', 1), ('557', 'LOGRA', 1), ('centro', '', 2), ('15840-000', '', 2), ('itajobi', '', 2), ('sp', '', 2)]
#
# Entities [('av.quinze de novembro 933', 'LOGRA')]
# Tokens [('av.quinze', 'LOGRA', 3), ('de', 'LOGRA', 1), ('novembro', 'LOGRA', 1), ('933', 'LOGRA', 1), ('centro', '', 2), ('15990-170', '', 2), ('matao', '', 2), ('sp', '', 2)]
#
# Entities [('av.expedicionarios 291', 'LOGRA')]
# Tokens [('av.expedicionarios', 'LOGRA', 3), ('291', 'LOGRA', 1), ('terreo', '', 2), ('centro', '', 2), ('86600-000', '', 2), ('rolandia', '', 2), ('pr', '', 2)]
#
# Entities [('av.dr.edilson pontes 249', 'LOGRA')]
# Tokens [('av.dr.edilson', 'LOGRA', 3), ('pontes', 'LOGRA', 1), ('249', 'LOGRA', 1), ('terreo', '', 2), ('centro', '', 2), ('46140-000', '', 2), ('livramento', '', 2), ('de', '', 2), ('nossa', '', 2), ('senhora', '', 2), ('ba', '', 2)]
#
# Entities [('av.pedro de toledo 345', 'LOGRA')]
# Tokens [('av.pedro', 'LOGRA', 3), ('de', 'LOGRA', 1), ('toledo', 'LOGRA', 1), ('345', 'LOGRA', 1), ('centro', '', 2), ('19600-000', '', 2), ('rancharia', '', 2), ('sp', '', 2)]
#
# Entities [('qne 17', 'LOGRA'), ('brasilia', 'LOGRA')]
# Tokens [('qne', 'LOGRA', 3), ('17', 'LOGRA', 1), ('lotes', '', 2), ('5/6', '', 2), ('av.comercial', '', 2), ('norte', '', 2), ('taguatinga', '', 2), ('norte', '', 2), ('72125-170', '', 2), ('brasilia', 'LOGRA', 3), ('(', '', 2), ('taguatinga', '', 2), (')', '', 2), ('df', '', 2)]
#
# Entities [('av.parque 533', 'LOGRA')]
# Tokens [('av.parque', 'LOGRA', 3), ('533', 'LOGRA', 1), ('centro', '', 2), ('69100-000', '', 2), ('itacoatiara', '', 2), ('am', '', 2)]
#
# Entities [('pca.cornelio procopio 53', 'LOGRA')]
# Tokens [('pca.cornelio', 'LOGRA', 3), ('procopio', 'LOGRA', 1), ('53', 'LOGRA', 1), ('centro', '', 2), ('13660-000', '', 2), ('porto', '', 2), ('ferreira', '', 2), ('sp', '', 2)]
#
# Entities [('r.cel.juvencio carneiro 410', 'LOGRA')]
# Tokens [('r.cel.juvencio', 'LOGRA', 3), ('carneiro', 'LOGRA', 1), ('410', 'LOGRA', 1), ('centro', '', 2), ('58900-000', '', 2), ('cajazeiras', '', 2), ('pb', '', 2)]
#
# Entities [('r.gov.manoel ribas 177', 'LOGRA')]
# Tokens [('r.gov.manoel', 'LOGRA', 3), ('ribas', 'LOGRA', 1), ('177', 'LOGRA', 1), ('a', '', 2), ('o', '', 2), ('lado', '', 2), ('do', '', 2), ('correio', '', 2), ('centro', '', 2), ('84220-000', '', 2), ('senges', '', 2), ('pr', '', 2)]
#
# Entities [('pca.flavio silvany 114', 'LOGRA')]
# Tokens [('pca.flavio', 'LOGRA', 3), ('silvany', 'LOGRA', 1), ('114', 'LOGRA', 1), ('centro', '', 2), ('46880-000', '', 2), ('itaberaba', '', 2), ('ba', '', 2)]
#
# Entities [('pca.da matriz 1', 'LOGRA')]
# Tokens [('pca.da', 'LOGRA', 3), ('matriz', 'LOGRA', 1), ('1', 'LOGRA', 1), ('centro', '', 2), ('63300-000', '', 2), ('lavras', '', 2), ('da', '', 2), ('mangabeira', '', 2), ('ce', '', 2)]
#
# Entities [('av.fernandes da cunha 58', 'LOGRA')]
# Tokens [('av.fernandes', 'LOGRA', 3), ('da', 'LOGRA', 1), ('cunha', 'LOGRA', 1), ('58', 'LOGRA', 1), ('mares', '', 2), ('40445-201', '', 2), ('salvador', '', 2), ('ba', '', 2)]
#
# Entities [('r.lindolfo simoes 102', 'LOGRA')]
# Tokens [('r.lindolfo', 'LOGRA', 3), ('simoes', 'LOGRA', 1), ('102', 'LOGRA', 1), ('centro', '', 2), ('57230-000', '', 2), ('coruripe', '', 2), ('al', '', 2)]
#
# Entities [('r.santos dumont 21', 'LOGRA')]
# Tokens [('r.santos', 'LOGRA', 3), ('dumont', 'LOGRA', 1), ('21', 'LOGRA', 1), ('centro', '', 2), ('85540-000', '', 2), ('mangueirinha', '', 2), ('pr', '', 2)]
#
# Entities [('r.jurubatuba 122', 'LOGRA')]
# Tokens [('r.jurubatuba', 'LOGRA', 3), ('122', 'LOGRA', 1), ('centro', '', 2), ('09725-620', '', 2), ('sao', '', 2), ('bernardo', '', 2), ('do', '', 2), ('campo', '', 2), ('sp', '', 2)]
#
# Entities [('pca.frei jose 61', 'LOGRA')]
# Tokens [('pca.frei', 'LOGRA', 3), ('jose', 'LOGRA', 1), ('61', 'LOGRA', 1), ('terreo', '', 2), ('centro', '', 2), ('49530-000', '', 2), ('ribeiropolis', '', 2), ('se', '', 2)]
#
# Entities [('av.gov.valadares 607', 'LOGRA')]
# Tokens [('av.gov.valadares', 'LOGRA', 3), ('607', 'LOGRA', 1), ('centro', '', 2), ('32900-000', '', 2), ('igarape', '', 2), ('mg', '', 2)]
#
# Entities [('r.borges de medeiros 120', 'LOGRA')]
# Tokens [('r.borges', 'LOGRA', 3), ('de', 'LOGRA', 1), ('medeiros', 'LOGRA', 1), ('120', 'LOGRA', 1), ('centro', '', 2), ('95880-000', '', 2), ('estrela', '', 2), ('rs', '', 2)]
# Entities [('r.des.souto maior 162', 'LOGRA')]
# Tokens [('r.des.souto', 'LOGRA', 3), ('maior', 'LOGRA', 1), ('162', 'LOGRA', 1), ('centro', '', 2), ('58013-190', '', 2), ('joao', '', 2), ('pessoa', '', 2), ('pb', '', 2)]
#
# Entities [('lote 4 loja 01', 'LOGRA')]
# Tokens [('lote', 'LOGRA', 3), ('4', 'LOGRA', 1), ('loja', 'LOGRA', 1), ('01', 'LOGRA', 1), ('a', '', 2), ('101', '', 2), ('setor', '', 2), ('hoteleiro', '', 2), ('central', '', 2), ('st', '', 2), ('central', '', 2), ('(', '', 2), ('gama', '', 2), (')', '', 2), ('72405-604', '', 2), ('brasilia', '', 2), ('(', '', 2), ('gama', '', 2), (')', '', 2), ('df', '', 2)]
#
# Entities [('av.benjamin pinto dias 1762', 'LOGRA')]
# Tokens [('av.benjamin', 'LOGRA', 3), ('pinto', 'LOGRA', 1), ('dias', 'LOGRA', 1), ('1762', 'LOGRA', 1), ('centro', '', 2), ('26130-000', '', 2), ('belford', '', 2), ('roxo', '', 2), ('rj', '', 2)]
#
# Entities [('av.brasil 1005', 'LOGRA')]
# Tokens [('av.brasil', 'LOGRA', 3), ('1005', 'LOGRA', 1), ('centro', '', 2), ('99170-000', '', 2), ('sertao', '', 2), ('rs', '', 2)]
#
# Entities [('avenida manoel monteiro 851 centro', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('manoel', 'LOGRA', 1), ('monteiro', 'LOGRA', 1), ('851', 'LOGRA', 1), ('centro', 'LOGRA', 1), ('75380-000', '', 2), ('trindade', '', 2), ('go', '', 2)]
#
# Entities [('r.dr.cunha junior 448', 'LOGRA')]
# Tokens [('r.dr.cunha', 'LOGRA', 3), ('junior', 'LOGRA', 1), ('448', 'LOGRA', 1), ('centro', '', 2), ('15170-000', '', 2), ('tanabi', '', 2), ('sp', '', 2)]
#
# Entities [('av.joaquim alves bento de lima 536', 'LOGRA')]
# Tokens [('av.joaquim', 'LOGRA', 3), ('alves', 'LOGRA', 1), ('bento', 'LOGRA', 1), ('de', 'LOGRA', 1), ('lima', 'LOGRA', 1), ('536', 'LOGRA', 1), ('cx.postal', '', 2), ('41', '', 2), ('centro', '', 2), ('86150-000', '', 2), ('alvorada', '', 2), ('do', '', 2), ('sul', '', 2), ('pr', '', 2)]
#
# Entities [('rua presidente vargas 537', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('presidente', 'LOGRA', 1), ('vargas', 'LOGRA', 1), ('537', 'LOGRA', 1), ('centro', '', 2), ('17690-000', '', 2), ('bastos', '', 2), ('sp', '', 2)]
#
# Entities [('av.pedro campos 779 sede', 'LOGRA')]
# Tokens [('av.pedro', 'LOGRA', 3), ('campos', 'LOGRA', 1), ('779', 'LOGRA', 1), ('sede', 'LOGRA', 1), ('centro', '', 2), ('78790-000', '', 2), ('itiquira', '', 2), ('mt', '', 2)]
#
# Entities [('av.pres.vargas 1333', 'LOGRA')]
# Tokens [('av.pres.vargas', 'LOGRA', 3), ('1333', 'LOGRA', 1), ('centro', '', 2), ('79730-000', '', 2), ('gloria', '', 2), ('de', '', 2), ('dourados', '', 2), ('ms', '', 2)]
#
# Entities [('pca.da liberdade 1', 'LOGRA')]
# Tokens [('pca.da', 'LOGRA', 3), ('liberdade', 'LOGRA', 1), ('1', 'LOGRA', 1), ('centro', '', 2), ('75780-000', '', 2), ('ipameri', '', 2), ('go', '', 2)]
#
# Entities [('r.pe.pedro domingues 59', 'LOGRA')]
# Tokens [('r.pe.pedro', 'LOGRA', 3), ('domingues', 'LOGRA', 1), ('59', 'LOGRA', 1), ('centro', '', 2), ('35995-000', '', 2), ('sao', '', 2), ('domingos', '', 2), ('do', '', 2), ('prata', '', 2), ('mg', '', 2)]
#
# Entities [('qd.g/', 'LOGRA')]
# Tokens [('qd.g', 'LOGRA', 3), ('/', 'LOGRA', 1), ('h', '', 2), ('s', '', 2), ('/', '', 2), ('n', '', 2), ('centro', '', 2), ('47300-000', '', 2), ('casa', '', 2), ('nova', '', 2), ('ba', '', 2)]
#
# Entities [('av.guilherme cotching 1819 v.maria', 'LOGRA')]
# Tokens [('av.guilherme', 'LOGRA', 3), ('cotching', 'LOGRA', 1), ('1819', 'LOGRA', 1), ('v.maria', 'LOGRA', 1), ('02113-017', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('av.internacional 1773', 'LOGRA')]
# Tokens [('av.internacional', 'LOGRA', 3), ('1773', 'LOGRA', 1), ('centro', '', 2), ('17780-000', '', 2), ('lucelia', '', 2), ('sp', '', 2)]
#
# Entities [('av.newton bello 1078', 'LOGRA')]
# Tokens [('av.newton', 'LOGRA', 3), ('bello', 'LOGRA', 1), ('1078', 'LOGRA', 1), ('centro', '', 2), ('65390-000', '', 2), ('santa', '', 2), ('luzia', '', 2), ('ma', '', 2)]
#
# Entities [('av.gov.pedro de toledo 1101 bonfim', 'LOGRA')]
# Tokens [('av.gov.pedro', 'LOGRA', 3), ('de', 'LOGRA', 1), ('toledo', 'LOGRA', 1), ('1101', 'LOGRA', 1), ('bonfim', 'LOGRA', 1), ('13070-751', '', 2), ('campinas', '', 2), ('sp', '', 2)]
#
# Entities [('av.sao joao 60', 'LOGRA')]
# Tokens [('av.sao', 'LOGRA', 3), ('joao', 'LOGRA', 1), ('60', 'LOGRA', 1), ('centro', '', 2), ('87175-000', '', 2), ('itambe', '', 2), ('pr', '', 2)]
#
# Entities [('pca.noe carvalho 673', 'LOGRA')]
# Tokens [('pca.noe', 'LOGRA', 3), ('carvalho', 'LOGRA', 1), ('673', 'LOGRA', 1), ('centro', '', 2), ('64760-000', '', 2), ('sao', '', 2), ('joao', '', 2), ('do', '', 2), ('piaui', '', 2), ('pi', '', 2)]
#
# Entities [('av.getulio vargas 1935', 'LOGRA')]
# Tokens [('av.getulio', 'LOGRA', 3), ('vargas', 'LOGRA', 1), ('1935', 'LOGRA', 1), ('centro', '', 2), ('65903-280', '', 2), ('imperatriz', '', 2), ('ma', '', 2)]
#
# Entities [('pca.gov.armando s.oliveira 240', 'LOGRA')]
# Tokens [('pca.gov.armando', 'LOGRA', 3), ('s.oliveira', 'LOGRA', 1), ('240', 'LOGRA', 1), ('centro', '', 2), ('13870-909', '', 2), ('sao', '', 2), ('joao', '', 2), ('da', '', 2), ('boa', '', 2), ('vista', '', 2), ('sp', '', 2)]
#
# Entities [('r.major afonso 55', 'LOGRA')]
# Tokens [('r.major', 'LOGRA', 3), ('afonso', 'LOGRA', 1), ('55', 'LOGRA', 1), ('centro', '', 2), ('37590-000', '', 2), ('jacutinga', '', 2), ('mg', '', 2)]
#
# Entities [('r.pref.joaquim salles 15', 'LOGRA')]
# Tokens [('r.pref.joaquim', 'LOGRA', 3), ('salles', 'LOGRA', 1), ('15', 'LOGRA', 1), ('centro', '', 2), ('89245-000', '', 2), ('araquari', '', 2), ('sc', '', 2)]
#
# Entities [('r.turiassu 1456 perdizes', 'LOGRA')]
# Tokens [('r.turiassu', 'LOGRA', 3), ('1456', 'LOGRA', 1), ('perdizes', 'LOGRA', 1), ('05005-000', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('av.pref.sebastiao fernandes 375', 'LOGRA')]
# Tokens [('av.pref.sebastiao', 'LOGRA', 3), ('fernandes', 'LOGRA', 1), ('375', 'LOGRA', 1), ('centro', '', 2), ('33200-000', '', 2), ('vespasiano', '', 2), ('mg', '', 2)]
#
# Entities [('r.cel.souza 135', 'LOGRA')]
# Tokens [('r.cel.souza', 'LOGRA', 3), ('135', 'LOGRA', 1), ('centro', '', 2), ('36600-000', '', 2), ('bicas', '', 2), ('mg', '', 2)]
#
# Entities [('av.sao paulo 1178', 'LOGRA')]
# Tokens [('av.sao', 'LOGRA', 3), ('paulo', 'LOGRA', 1), ('1178', 'LOGRA', 1), ('terreo', '', 2), ('centro', '', 2), ('87890-000', '', 2), ('terra', '', 2), ('rica', '', 2), ('pr', '', 2)]
#
# Entities [('r.joao pinheiro 29', 'LOGRA')]
# Tokens [('r.joao', 'LOGRA', 3), ('pinheiro', 'LOGRA', 1), ('29', 'LOGRA', 1), ('centro', '', 2), ('35430-020', '', 2), ('ponte', '', 2), ('nova', '', 2), ('mg', '', 2)]
#
# Entities [('av.alm.saldanha da gama 186 ponta', 'LOGRA')]
# Tokens [('av.alm.saldanha', 'LOGRA', 3), ('da', 'LOGRA', 1), ('gama', 'LOGRA', 1), ('186', 'LOGRA', 1), ('ponta', 'LOGRA', 1), ('da', '', 2), ('praia', '', 2), ('11030-401', '', 2), ('santos', '', 2), ('sp', '', 2)]
#
# Entities [('pca.juscelino kubistchek 82', 'LOGRA')]
# Tokens [('pca.juscelino', 'LOGRA', 3), ('kubistchek', 'LOGRA', 1), ('82', 'LOGRA', 1), ('centro', '', 2), ('39740-000', '', 2), ('guanhaes', '', 2), ('mg', '', 2)]
#
# Entities [('av.evencia brito 21', 'LOGRA')]
# Tokens [('av.evencia', 'LOGRA', 3), ('brito', 'LOGRA', 1), ('21', 'LOGRA', 1), ('prox.igreja', '', 2), ('nova', '', 2), ('centro', '', 2), ('48400-000', '', 2), ('ribeira', '', 2), ('do', '', 2), ('pombal', '', 2), ('ba', '', 2)]
#
# Entities [('r.rui barbosa 275 predio', 'LOGRA')]
# Tokens [('r.rui', 'LOGRA', 3), ('barbosa', 'LOGRA', 1), ('275', 'LOGRA', 1), ('predio', 'LOGRA', 1), ('centro', '', 2), ('47400-000', '', 2), ('xique-xique', '', 2), ('ba', '', 2)]
#
# Entities [('r.antonio honorio pires 45', 'LOGRA')]
# Tokens [('r.antonio', 'LOGRA', 3), ('honorio', 'LOGRA', 1), ('pires', 'LOGRA', 1), ('45', 'LOGRA', 1), ('terreo', '', 2), ('centro', '', 2), ('39150-000', '', 2), ('serro', '', 2), ('mg', '', 2)]
#
# Entities [('pca.cap.francisco souza meira 214', 'LOGRA')]
# Tokens [('pca.cap.francisco', 'LOGRA', 3), ('souza', 'LOGRA', 1), ('meira', 'LOGRA', 1), ('214', 'LOGRA', 1), ('centro', '', 2), ('46100-000', '', 2), ('brumado', '', 2), ('ba', '', 2)]
#
# Entities [('tv.mal.deodoro da fonseca 22', 'LOGRA')]
# Tokens [('tv.mal.deodoro', 'LOGRA', 3), ('da', 'LOGRA', 1), ('fonseca', 'LOGRA', 1), ('22', 'LOGRA', 1), ('centro', '', 2), ('49600-000', '', 2), ('nossa', '', 2), ('senhora', '', 2), ('das', '', 2), ('dores', '', 2), ('se', '', 2)]
#
# Entities [('r.andre de albuquerque 56', 'LOGRA')]
# Tokens [('r.andre', 'LOGRA', 3), ('de', 'LOGRA', 1), ('albuquerque', 'LOGRA', 1), ('56', 'LOGRA', 1), ('centro', '', 2), ('59190-000', '', 2), ('canguaretama', '', 2), ('rn', '', 2)]
#
# Entities [('r.sao bento 483', 'LOGRA')]
# Tokens [('r.sao', 'LOGRA', 3), ('bento', 'LOGRA', 1), ('483', 'LOGRA', 1), ('centro', '', 2), ('01011-100', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('pca.virginia heraclio 35', 'LOGRA')]
# Tokens [('pca.virginia', 'LOGRA', 3), ('heraclio', 'LOGRA', 1), ('35', 'LOGRA', 1), ('terreo', '', 2), ('centro', '', 2), ('55655-000', '', 2), ('cumaru', '', 2), ('pe', '', 2)]
#
# Entities [('r.duque de caxias 438', 'LOGRA')]
# Tokens [('r.duque', 'LOGRA', 3), ('de', 'LOGRA', 1), ('caxias', 'LOGRA', 1), ('438', 'LOGRA', 1), ('centro', '', 2), ('19300-000', '', 2), ('presidente', '', 2), ('bernardes', '', 2), ('sp', '', 2)]
#
# Entities [('av. claudionor barbieri 498', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('claudionor', 'LOGRA', 1), ('barbieri', 'LOGRA', 1), ('498', 'LOGRA', 1), ('centro', '', 2), ('17250-000', '', 2), ('bariri', '', 2), ('sp', '', 2)]
#
# Entities [('av.saul elkind 2196', 'LOGRA')]
# Tokens [('av.saul', 'LOGRA', 3), ('elkind', 'LOGRA', 1), ('2196', 'LOGRA', 1), ('pq.leblon', '', 2), ('86082-000', '', 2), ('londrina', '', 2), ('pr', '', 2)]
#
# Entities [('r.quinze de novembro 107', 'LOGRA')]
# Tokens [('r.quinze', 'LOGRA', 3), ('de', 'LOGRA', 1), ('novembro', 'LOGRA', 1), ('107', 'LOGRA', 1), ('centro', '', 2), ('88830-000', '', 2), ('morro', '', 2), ('da', '', 2), ('fumaca', '', 2), ('sc', '', 2)]
#
# Entities [('r.argemiro borges 206', 'LOGRA')]
# Tokens [('r.argemiro', 'LOGRA', 3), ('borges', 'LOGRA', 1), ('206', 'LOGRA', 1), ('terreo', '', 2), ('centro', '', 2), ('89480-000', '', 2), ('major', '', 2), ('vieira', '', 2), ('sc', '', 2)]
#
# Entities [('r.joao batista 12', 'LOGRA')]
# Tokens [('r.joao', 'LOGRA', 3), ('batista', 'LOGRA', 1), ('12', 'LOGRA', 1), ('centro', '', 2), ('55750-000', '', 2), ('surubim', '', 2), ('pe', '', 2)]
#
# Entities [('pca.tiradentes 410', 'LOGRA')]
# Tokens [('pca.tiradentes', 'LOGRA', 3), ('410', 'LOGRA', 1), ('1.andar', '', 2), ('centro', '', 2), ('80020-100', '', 2), ('curitiba', '', 2), ('pr', '', 2)]
#
# Entities [('r.barao de duprat 157', 'LOGRA')]
# Tokens [('r.barao', 'LOGRA', 3), ('de', 'LOGRA', 1), ('duprat', 'LOGRA', 1), ('157', 'LOGRA', 1), ('centro', '', 2), ('01023-001', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('av.pres.vargas 248', 'LOGRA')]
# Tokens [('av.pres.vargas', 'LOGRA', 3), ('248', 'LOGRA', 1), ('1.e', '', 2), ('2.andares', '', 2), ('campina', '', 2), ('66010-900', '', 2), ('belem', '', 2), ('pa', '', 2)]
#
# Entities [('pca.j.j.seabra 172', 'LOGRA')]
# Tokens [('pca.j.j.seabra', 'LOGRA', 3), ('172', 'LOGRA', 1), ('terreo', '', 2), ('centro', '', 2), ('45345-000', '', 2), ('jaguaquara', '', 2), ('ba', '', 2)]
#
# Entities [('r.arthur barth 475', 'LOGRA')]
# Tokens [('r.arthur', 'LOGRA', 3), ('barth', 'LOGRA', 1), ('475', 'LOGRA', 1), ('centro', '', 2), ('89515-000', '', 2), ('lebon', '', 2), ('regis', '', 2), ('sc', '', 2)]
#
# Entities [('av nova york 115 bonsucesso', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('nova', 'LOGRA', 1), ('york', 'LOGRA', 1), ('115', 'LOGRA', 1), ('bonsucesso', 'LOGRA', 1), ('21041-040', '', 2), ('rio', '', 2), ('de', '', 2), ('janeiro', '', 2), ('rj', '', 2)]
#
# Entities [('av afonso pena 5572', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('afonso', 'LOGRA', 1), ('pena', 'LOGRA', 1), ('5572', 'LOGRA', 1), ('ch', '', 2), ('cachoeira', '', 2), ('79040-010', '', 2), ('campo', '', 2), ('grande', '', 2), ('ms', '', 2)]
#
# Entities [('r.bom pastor 169', 'LOGRA')]
# Tokens [('r.bom', 'LOGRA', 3), ('pastor', 'LOGRA', 1), ('169', 'LOGRA', 1), ('terreo', '', 2), ('ipiranga', '', 2), ('04203-050', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('av.gustavo brigagao 1271', 'LOGRA')]
# Tokens [('av.gustavo', 'LOGRA', 3), ('brigagao', 'LOGRA', 1), ('1271', 'LOGRA', 1), ('centro', '', 2), ('87910-000', '', 2), ('santa', '', 2), ('isabel', '', 2), ('do', '', 2), ('ivai', '', 2), ('pr', '', 2)]
#
# Entities [('pca.castro alves 59', 'LOGRA')]
# Tokens [('pca.castro', 'LOGRA', 3), ('alves', 'LOGRA', 1), ('59', 'LOGRA', 1), ('terreo', '', 2), ('centro', '', 2), ('45970-000', '', 2), ('itanhem', '', 2), ('ba', '', 2)]
#
# Entities [('r.sa e albuquerque 417', 'LOGRA')]
# Tokens [('r.sa', 'LOGRA', 3), ('e', 'LOGRA', 1), ('albuquerque', 'LOGRA', 1), ('417', 'LOGRA', 1), ('jaragua', '', 2), ('57022-180', '', 2), ('maceio', '', 2), ('al', '', 2)]
#
# Entities [('pca.da matriz 17', 'LOGRA')]
# Tokens [('pca.da', 'LOGRA', 3), ('matriz', 'LOGRA', 1), ('17', 'LOGRA', 1), ('terreo', '', 2), ('centro', '', 2), ('45170-000', '', 2), ('tremedal', '', 2), ('ba', '', 2)]
#
# Entities [('r.cel.pena de moraes 227', 'LOGRA')]
# Tokens [('r.cel.pena', 'LOGRA', 3), ('de', 'LOGRA', 1), ('moraes', 'LOGRA', 1), ('227', 'LOGRA', 1), ('centro', '', 2), ('95180-000', '', 2), ('farroupilha', '', 2), ('rs', '', 2)]
#
# Entities [('av.liberato salzano 271', 'LOGRA')]
# Tokens [('av.liberato', 'LOGRA', 3), ('salzano', 'LOGRA', 1), ('271', 'LOGRA', 1), ('centro', '', 2), ('98970-000', '', 2), ('candido', '', 2), ('godoi', '', 2), ('rs', '', 2)]
#
# Entities [('pca.da matriz 75', 'LOGRA')]
# Tokens [('pca.da', 'LOGRA', 3), ('matriz', 'LOGRA', 1), ('75', 'LOGRA', 1), ('centro', '', 2), ('38200-000', '', 2), ('frutal', '', 2), ('mg', '', 2)]
#
# Entities [('pca.de santana 109', 'LOGRA')]
# Tokens [('pca.de', 'LOGRA', 3), ('santana', 'LOGRA', 1), ('109', 'LOGRA', 1), ('centro', '', 2), ('55400-000', '', 2), ('catende', '', 2), ('pe', '', 2)]
#
# Entities [('r.pedro pereira prado 42', 'LOGRA')]
# Tokens [('r.pedro', 'LOGRA', 3), ('pereira', 'LOGRA', 1), ('prado', 'LOGRA', 1), ('42', 'LOGRA', 1), ('centro', '', 2), ('49100-000', '', 2), ('sao', '', 2), ('cristovao', '', 2), ('se', '', 2)]
#
# Entities [('av. evandi americo comarela 441', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('evandi', 'LOGRA', 1), ('americo', 'LOGRA', 1), ('comarela', 'LOGRA', 1), ('441', 'LOGRA', 1), ('terreo', '', 2), ('centro', '', 2), ('29375-000', '', 2), ('venda', '', 2), ('nova', '', 2), ('do', '', 2), ('imigrante', '', 2), ('es', '', 2)]
#
# Entities [('av.cuiaba 985', 'LOGRA')]
# Tokens [('av.cuiaba', 'LOGRA', 3), ('985', 'LOGRA', 1), ('centro', '', 2), ('78700-090', '', 2), ('rondonopolis', '', 2), ('mt', '', 2)]
#
# Entities [('av.vol.fernando pinheiro franco 432 predio', 'LOGRA')]
# Tokens [('av.vol.fernando', 'LOGRA', 3), ('pinheiro', 'LOGRA', 1), ('franco', 'LOGRA', 1), ('432', 'LOGRA', 1), ('predio', 'LOGRA', 1), ('centro', '', 2), ('08710-500', '', 2), ('mogi', '', 2), ('das', '', 2), ('cruzes', '', 2), ('sp', '', 2)]
#
# Entities [('av.pres.castelo branco 421 proximo', 'LOGRA')]
# Tokens [('av.pres.castelo', 'LOGRA', 3), ('branco', 'LOGRA', 1), ('421', 'LOGRA', 1), ('proximo', 'LOGRA', 1), ('a', '', 2), ('pca.central', '', 2), ('centro', '', 2), ('68625-005', '', 2), ('paragominas', '', 2), ('pa', '', 2)]
#
# Entities [('r.onze de abril 769', 'LOGRA')]
# Tokens [('r.onze', 'LOGRA', 3), ('de', 'LOGRA', 1), ('abril', 'LOGRA', 1), ('769', 'LOGRA', 1), ('centro', '', 2), ('96270-000', '', 2), ('mostardas', '', 2), ('rs', '', 2)]
#
# Entities [('folha trinta e dois s/', 'LOGRA')]
# Tokens [('folha', 'LOGRA', 3), ('trinta', 'LOGRA', 1), ('e', 'LOGRA', 1), ('dois', 'LOGRA', 1), ('s', 'LOGRA', 1), ('/', 'LOGRA', 1), ('n', '', 2), ('qd.6', '', 2), ('lote', '', 2), ('52', '', 2), ('nova', '', 2), ('maraba', '', 2), ('68508-060', '', 2), ('maraba', '', 2), ('pa', '', 2)]
#
# Entities [('rua antonio campos 108', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('antonio', 'LOGRA', 1), ('campos', 'LOGRA', 1), ('108', 'LOGRA', 1), ('centro', '', 2), ('37275-000', '', 2), ('cristais', '', 2), ('mg', '', 2)]
#
# Entities [('r.dr.melo viana 294', 'LOGRA')]
# Tokens [('r.dr.melo', 'LOGRA', 3), ('viana', 'LOGRA', 1), ('294', 'LOGRA', 1), ('centro', '', 2), ('36400-000', '', 2), ('conselheiro', '', 2), ('lafaiete', '', 2), ('mg', '', 2)]
#
# Entities [('r.julio de castilhos 1183', 'LOGRA')]
# Tokens [('r.julio', 'LOGRA', 3), ('de', 'LOGRA', 1), ('castilhos', 'LOGRA', 1), ('1183', 'LOGRA', 1), ('centro', '', 2), ('96600-000', '', 2), ('cangucu', '', 2), ('rs', '', 2)]
#
# Entities [('pca.getulio vargas 124', 'LOGRA')]
# Tokens [('pca.getulio', 'LOGRA', 3), ('vargas', 'LOGRA', 1), ('124', 'LOGRA', 1), ('centro', '', 2), ('35740-000', '', 2), ('esmeraldas', '', 2), ('mg', '', 2)]
#
# Entities [('r.jose augusto chaves 468', 'LOGRA')]
# Tokens [('r.jose', 'LOGRA', 3), ('augusto', 'LOGRA', 1), ('chaves', 'LOGRA', 1), ('468', 'LOGRA', 1), ('centro', '', 2), ('38900-000', '', 2), ('bambui', '', 2), ('mg', '', 2)]
#
# Entities [('av.tapejara 153', 'LOGRA')]
# Tokens [('av.tapejara', 'LOGRA', 3), ('153', 'LOGRA', 1), ('centro', '', 2), ('87780-000', '', 2), ('paraiso', '', 2), ('do', '', 2), ('norte', '', 2), ('pr', '', 2)]
#
# Entities [('av.barao do rio branco 348', 'LOGRA')]
# Tokens [('av.barao', 'LOGRA', 3), ('do', 'LOGRA', 1), ('rio', 'LOGRA', 1), ('branco', 'LOGRA', 1), ('348', 'LOGRA', 1), ('centro', '', 2), ('89500-000', '', 2), ('cacador', '', 2), ('sc', '', 2)]
#
# Entities [('av.diogo garcia carmona 905', 'LOGRA')]
# Tokens [('av.diogo', 'LOGRA', 3), ('garcia', 'LOGRA', 1), ('carmona', 'LOGRA', 1), ('905', 'LOGRA', 1), ('centro', '', 2), ('15300-000', '', 2), ('general', '', 2), ('salgado', '', 2), ('sp', '', 2)]
#
# Entities [('r.conego jacinto 63', 'LOGRA')]
# Tokens [('r.conego', 'LOGRA', 3), ('jacinto', 'LOGRA', 1), ('63', 'LOGRA', 1), ('centro', '', 2), ('57260-000', '', 2), ('limoeiro', '', 2), ('de', '', 2), ('anadia', '', 2), ('al', '', 2)]
#
# Entities [('r.ten.jose teixeira 171', 'LOGRA')]
# Tokens [('r.ten.jose', 'LOGRA', 3), ('teixeira', 'LOGRA', 1), ('171', 'LOGRA', 1), ('centro', '', 2), ('28360-000', '', 2), ('bom', '', 2), ('jesus', '', 2), ('do', '', 2), ('itabapoana', '', 2), ('rj', '', 2)]
#
# Entities [('r.pe.gregorio couto 176', 'LOGRA')]
# Tokens [('r.pe.gregorio', 'LOGRA', 3), ('couto', 'LOGRA', 1), ('176', 'LOGRA', 1), ('centro', '', 2), ('35514-000', '', 2), ('itaguara', '', 2), ('mg', '', 2)]
# Entities [('av.trifon hanysz 189', 'LOGRA')]
# Tokens [('av.trifon', 'LOGRA', 3), ('hanysz', 'LOGRA', 1), ('189', 'LOGRA', 1), ('centro', '', 2), ('85170-000', '', 2), ('pinhao', '', 2), ('pr', '', 2)]
#
# Entities [('r.alfredo winck 758', 'LOGRA')]
# Tokens [('r.alfredo', 'LOGRA', 3), ('winck', 'LOGRA', 1), ('758', 'LOGRA', 1), ('centro', '', 2), ('99530-000', '', 2), ('chapada', '', 2), ('rs', '', 2)]
#
# Entities [('r.felipe schmidt 312', 'LOGRA')]
# Tokens [('r.felipe', 'LOGRA', 3), ('schmidt', 'LOGRA', 1), ('312', 'LOGRA', 1), ('esq.c', '', 2), ('/', '', 2), ('r.major', '', 2), ('vieira', '', 2), ('centro', '', 2), ('89460-000', '', 2), ('canoinhas', '', 2), ('sc', '', 2)]
#
# Entities [('av.nogueira acioly 1495', 'LOGRA')]
# Tokens [('av.nogueira', 'LOGRA', 3), ('acioly', 'LOGRA', 1), ('1495', 'LOGRA', 1), ('terreo', '', 2), ('centro', '', 2), ('63430-000', '', 2), ('ico', '', 2), ('ce', '', 2)]
#
# Entities [('r.dr.joao pessoa 677', 'LOGRA')]
# Tokens [('r.dr.joao', 'LOGRA', 3), ('pessoa', 'LOGRA', 1), ('677', 'LOGRA', 1), ('sala', '', 2), ('01', '', 2), ('centro', '', 2), ('96640-000', '', 2), ('rio', '', 2), ('pardo', '', 2), ('rs', '', 2)]
#
# Entities [('av.nilza de oliveira pipino 1807', 'LOGRA')]
# Tokens [('av.nilza', 'LOGRA', 3), ('de', 'LOGRA', 1), ('oliveira', 'LOGRA', 1), ('pipino', 'LOGRA', 1), ('1807', 'LOGRA', 1), ('centro', '', 2), ('85440-000', '', 2), ('ubirata', '', 2), ('pr', '', 2)]
#
# Entities [('r.guama 17 nucleo urbano', 'LOGRA')]
# Tokens [('r.guama', 'LOGRA', 3), ('17', 'LOGRA', 1), ('nucleo', 'LOGRA', 1), ('urbano', 'LOGRA', 1), ('carajas', '', 2), ('68516-000', '', 2), ('parauapebas', '', 2), ('pa', '', 2)]
#
# Entities [('r.dr.jose goncalves de sa 185 predio', 'LOGRA')]
# Tokens [('r.dr.jose', 'LOGRA', 3), ('goncalves', 'LOGRA', 1), ('de', 'LOGRA', 1), ('sa', 'LOGRA', 1), ('185', 'LOGRA', 1), ('predio', 'LOGRA', 1), ('centro', '', 2), ('48540-000', '', 2), ('jeremoabo', '', 2), ('ba', '', 2)]
#
# Entities [('pca.aarao lins de andrade 50', 'LOGRA')]
# Tokens [('pca.aarao', 'LOGRA', 3), ('lins', 'LOGRA', 1), ('de', 'LOGRA', 1), ('andrade', 'LOGRA', 1), ('50', 'LOGRA', 1), ('centro', '', 2), ('55641-080', '', 2), ('gravata', '', 2), ('pe', '', 2)]
#
# Entities [('pca.cel.amantino 3 centro', 'LOGRA')]
# Tokens [('pca.cel.amantino', 'LOGRA', 3), ('3', 'LOGRA', 1), ('centro', 'LOGRA', 1), ('36480-000', '', 2), ('piranga', '', 2), ('mg', '', 2)]
#
# Entities [('av.gov.osman loureiro 49', 'LOGRA')]
# Tokens [('av.gov.osman', 'LOGRA', 3), ('loureiro', 'LOGRA', 1), ('49', 'LOGRA', 1), ('terreo', '', 2), ('mangabeiras', '', 2), ('57037-630', '', 2), ('maceio', '', 2), ('al', '', 2)]
#
# Entities [('pca.frei felix 195', 'LOGRA')]
# Tokens [('pca.frei', 'LOGRA', 3), ('felix', 'LOGRA', 1), ('195', 'LOGRA', 1), ('centro', '', 2), ('39200-000', '', 2), ('corinto', '', 2), ('mg', '', 2)]
#
# Entities [('r.rio grande do norte 160', 'LOGRA')]
# Tokens [('r.rio', 'LOGRA', 3), ('grande', 'LOGRA', 1), ('do', 'LOGRA', 1), ('norte', 'LOGRA', 1), ('160', 'LOGRA', 1), ('centro', '', 2), ('79170-000', '', 2), ('sidrolandia', '', 2), ('ms', '', 2)]
#
# Entities [('r.wadih bacha 127', 'LOGRA')]
# Tokens [('r.wadih', 'LOGRA', 3), ('bacha', 'LOGRA', 1), ('127', 'LOGRA', 1), ('centro', '', 2), ('37480-000', '', 2), ('lambari', '', 2), ('mg', '', 2)]
#
# Entities [('r.pres.getulio vargas 100', 'LOGRA')]
# Tokens [('r.pres.getulio', 'LOGRA', 3), ('vargas', 'LOGRA', 1), ('100', 'LOGRA', 1), ('centro', '', 2), ('59215-000', '', 2), ('nova', '', 2), ('cruz', '', 2), ('rn', '', 2)]
#
# Entities [('r.paulo alves pinto 26', 'LOGRA')]
# Tokens [('r.paulo', 'LOGRA', 3), ('alves', 'LOGRA', 1), ('pinto', 'LOGRA', 1), ('26', 'LOGRA', 1), ('centro', '', 2), ('83702-240', '', 2), ('araucaria', '', 2), ('pr', '', 2)]
#
# Entities [('rua padre anchieta 261', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('padre', 'LOGRA', 1), ('anchieta', 'LOGRA', 1), ('261', 'LOGRA', 1), ('centro', '', 2), ('97970-000', '', 2), ('roque', '', 2), ('gonzales', '', 2), ('rs', '', 2)]
#
# Entities [('pca.pe.oliveira 890', 'LOGRA')]
# Tokens [('pca.pe.oliveira', 'LOGRA', 3), ('890', 'LOGRA', 1), ('centro', '', 2), ('49800-000', '', 2), ('porto', '', 2), ('da', '', 2), ('folha', '', 2), ('se', '', 2)]
#
# Entities [('r.gal.francisco glicerio 472 predio', 'LOGRA')]
# Tokens [('r.gal.francisco', 'LOGRA', 3), ('glicerio', 'LOGRA', 1), ('472', 'LOGRA', 1), ('predio', 'LOGRA', 1), ('centro', '', 2), ('08674-000', '', 2), ('suzano', '', 2), ('sp', '', 2)]
#
# Entities [('pca.lourival monte 22', 'LOGRA')]
# Tokens [('pca.lourival', 'LOGRA', 3), ('monte', 'LOGRA', 1), ('22', 'LOGRA', 1), ('terreo', '', 2), ('centro', '', 2), ('45300-000', '', 2), ('amargosa', '', 2), ('ba', '', 2)]
#
# Entities [('pca.barao do rio branco 39', 'LOGRA')]
# Tokens [('pca.barao', 'LOGRA', 3), ('do', 'LOGRA', 1), ('rio', 'LOGRA', 1), ('branco', 'LOGRA', 1), ('39', 'LOGRA', 1), ('centro', '', 2), ('48903-901', '', 2), ('juazeiro', '', 2), ('ba', '', 2)]
#
# Entities [('r.rui barbosa 134', 'LOGRA')]
# Tokens [('r.rui', 'LOGRA', 3), ('barbosa', 'LOGRA', 1), ('134', 'LOGRA', 1), ('centro', '', 2), ('45690-000', '', 2), ('una', '', 2), ('ba', '', 2)]
#
# Entities [('r. 10 de abril 602', 'LOGRA')]
# Tokens [('r.', 'LOGRA', 3), ('10', 'LOGRA', 1), ('de', 'LOGRA', 1), ('abril', 'LOGRA', 1), ('602', 'LOGRA', 1), ('centro', '', 2), ('13160-000', '', 2), ('artur', '', 2), ('nogueira', '', 2), ('sp', '', 2)]
#
# Entities [('pca.duque de caxias 25', 'LOGRA')]
# Tokens [('pca.duque', 'LOGRA', 3), ('de', 'LOGRA', 1), ('caxias', 'LOGRA', 1), ('25', 'LOGRA', 1), ('centro', '', 2), ('18310-000', '', 2), ('guapiara', '', 2), ('sp', '', 2)]
#
# Entities [('r.gal.sampaio 99', 'LOGRA')]
# Tokens [('r.gal.sampaio', 'LOGRA', 3), ('99', 'LOGRA', 1), ('centro', '', 2), ('96400-370', '', 2), ('bage', '', 2), ('rs', '', 2)]
#
# Entities [('r.sao benedito 1122', 'LOGRA')]
# Tokens [('r.sao', 'LOGRA', 3), ('benedito', 'LOGRA', 1), ('1122', 'LOGRA', 1), ('esq.c', '', 2), ('/', '', 2), ('tv.mendonca', '', 2), ('furtado', '', 2), ('centro', '', 2), ('68230-000', '', 2), ('almeirim', '', 2), ('pa', '', 2)]
#
# Entities [('r.pres.castelo branco 311', 'LOGRA')]
# Tokens [('r.pres.castelo', 'LOGRA', 3), ('branco', 'LOGRA', 1), ('311', 'LOGRA', 1), ('centro', '', 2), ('62270-000', '', 2), ('hidrolandia', '', 2), ('ce', '', 2)]
#
# Entities [('r.n.sra.da lapa 281', 'LOGRA')]
# Tokens [('r.n.sra.da', 'LOGRA', 3), ('lapa', 'LOGRA', 1), ('281', 'LOGRA', 1), ('lapa', '', 2), ('05072-000', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('pca.helena de oliveira ribeiro 22', 'LOGRA')]
# Tokens [('pca.helena', 'LOGRA', 3), ('de', 'LOGRA', 1), ('oliveira', 'LOGRA', 1), ('ribeiro', 'LOGRA', 1), ('22', 'LOGRA', 1), ('casa', '', 2), ('centro', '', 2), ('49390-000', '', 2), ('salgado', '', 2), ('se', '', 2)]
#
# Entities [('praca do barao', 'LOGRA')]
# Tokens [('praca', 'LOGRA', 3), ('do', 'LOGRA', 1), ('barao', 'LOGRA', 1), ('rio', '', 2), ('branco', '', 2), ('43', '', 2), ('terreo', '', 2), ('1', '', 2), ('2', '', 2), ('e', '', 2), ('3.andares', '', 2), ('centro', '', 2), ('45000-903', '', 2), ('vitoria', '', 2), ('da', '', 2), ('conquista', '', 2), ('ba', '', 2)]
#
# Entities [('r.conde de bonfim 369-a', 'LOGRA')]
# Tokens [('r.conde', 'LOGRA', 3), ('de', 'LOGRA', 1), ('bonfim', 'LOGRA', 1), ('369-a', 'LOGRA', 1), ('terreo', '', 2), ('1.e', '', 2), ('2.andares', '', 2), ('tijuca', '', 2), ('20520-051', '', 2), ('rio', '', 2), ('de', '', 2), ('janeiro', '', 2), ('rj', '', 2)]
#
# Entities [('pra�a prefeito', 'LOGRA'), ('364', 'LOGRA')]
# Tokens [('pra', 'LOGRA', 3), ('�', 'LOGRA', 1), ('a', 'LOGRA', 1), ('prefeito', 'LOGRA', 1), ('jos', '', 2), ('�', '', 2), ('maur', '', 2), ('�', '', 2), ('cio', '', 2), ('364', 'LOGRA', 3), ('centro', '', 2), ('76490-000', '', 2), ('mara', '', 2), ('rosa', '', 2), ('go', '', 2)]
#
# Entities [('av.benedito valadares 52', 'LOGRA')]
# Tokens [('av.benedito', 'LOGRA', 3), ('valadares', 'LOGRA', 1), ('52', 'LOGRA', 1), ('centro', '', 2), ('38190-000', '', 2), ('sacramento', '', 2), ('mg', '', 2)]
#
# Entities [('tv.da mangueira 40', 'LOGRA')]
# Tokens [('tv.da', 'LOGRA', 3), ('mangueira', 'LOGRA', 1), ('40', 'LOGRA', 1), ('centro', '', 2), ('58297-000', '', 2), ('rio', '', 2), ('tinto', '', 2), ('pb', '', 2)]
#
# Entities [('av.sete de setembro 1183', 'LOGRA')]
# Tokens [('av.sete', 'LOGRA', 3), ('de', 'LOGRA', 1), ('setembro', 'LOGRA', 1), ('1183', 'LOGRA', 1), ('comercial', '', 2), ('centro', '', 2), ('97560-000', '', 2), ('quarai', '', 2), ('rs', '', 2)]
#
# Entities [('av.dr.lisboa 333', 'LOGRA')]
# Tokens [('av.dr.lisboa', 'LOGRA', 3), ('333', 'LOGRA', 1), ('centro', '', 2), ('37550-000', '', 2), ('pouso', '', 2), ('alegre', '', 2), ('mg', '', 2)]
#
# Entities [('r.dr.jose torquato 327', 'LOGRA')]
# Tokens [('r.dr.jose', 'LOGRA', 3), ('torquato', 'LOGRA', 1), ('327', 'LOGRA', 1), ('terreo', '', 2), ('centro', '', 2), ('59920-000', '', 2), ('sao', '', 2), ('miguel', '', 2), ('rn', '', 2)]
#
# Entities [('pca.salviano leite 10', 'LOGRA')]
# Tokens [('pca.salviano', 'LOGRA', 3), ('leite', 'LOGRA', 1), ('10', 'LOGRA', 1), ('centro', '', 2), ('58765-000', '', 2), ('pianco', '', 2), ('pb', '', 2)]
#
# Entities [('r.deodoro de mendonca 398', 'LOGRA')]
# Tokens [('r.deodoro', 'LOGRA', 3), ('de', 'LOGRA', 1), ('mendonca', 'LOGRA', 1), ('398', 'LOGRA', 1), ('sao', '', 2), ('bras', '', 2), ('66090-150', '', 2), ('belem', '', 2), ('pa', '', 2)]
#
# Entities [('av santa marina 2618', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('santa', 'LOGRA', 1), ('marina', 'LOGRA', 1), ('2618', 'LOGRA', 1), ('2', '', 2), ('andar', '', 2), ('vl', '', 2), ('albertina', '', 2), ('02732-040', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]

# %%
base_teste_final[0]

# %%
phrase = "rua leonardo de freitas, 1444,   este levantamento de preços que inclui também produtos de higiene e de limpeza mostra recuo de 1,58 % em relação à sexta-feira anterior \n "

doc = nlp(phrase)
print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
print('Tokens', [(t.text, t.ent_type_, t.ent_iob) for t in doc])

# %%
from spacy.gold import GoldParse
from spacy.scorer import Scorer

def evaluate(ner_model, examples):
    scorer = Scorer()
    for input_, annot in examples:
        doc_gold_text = ner_model.make_doc(input_)
        gold = GoldParse(doc_gold_text, entities=annot)
        pred_value = ner_model(input_)
        scorer.score(pred_value, gold)
    return scorer.scores

# %%
# save model to output directory
if output_dir is not None:
    output_dir = Path(output_dir)
    if not output_dir.exists():
        output_dir.mkdir()
    nlp.to_disk(output_dir)
    print("Saved model to", output_dir)

# %%
loaded_model = spacy.load(output_dir)
evaluate(loaded_model, base_teste_final)
