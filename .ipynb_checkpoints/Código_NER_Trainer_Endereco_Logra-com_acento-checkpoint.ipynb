# %%
# Load Packages
from __future__ import unicode_literals, print_function

import plac #  wrapper over argparse
import random
from pathlib import Path
import spacy
from tqdm import tqdm, tqdm_notebook # loading bar 
import pandas as pd
import re
from pprint import pprint
from nltk.tokenize import sent_tokenize
import numpy as np

from spacy.util import minibatch, compounding

# %% [markdown]
# # Abrindo e gerando Datasets

# %% [markdown]
# ### Entidade logradouro

# %%
# Obtendo dados crus de endereço

dataset = pd.read_csv("201906AGENCIAS.CSV")
dset = dataset.iloc[:-2,4:10].values  # tipo nparray object
pd_dset = pd.DataFrame(dset) # caso queira visualizar

pd_dset['Join'] = pd_dset[pd_dset.columns[0:]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)
pd_dset.head(5)
# Out:
#                                           0  \
# 0  R.GUILHERME MOREIRA,315
# 1  AV.PRES.VARGAS,248
# 2  R.QUINZE DE NOVEMBRO,195
# 3  PCA.DAS QUATRO JORNADAS,11
# 4  SEXTA AVENIDA,600
#
#                                                    1  \
# 0  SUBLOJA,LOJA E 2.ANDAR                        ...
# 1  1.E 2.ANDARES                                 ...
# 2                                                ...
# 3  MEZANINO                                      ...
# 4  SECRETARIA DA EDUCACAO-TERREO                 ...
#
#                                 2          3  \
# 0  CENTRO                          69005-300
# 1  CAMPINA                         66010-900
# 2  CENTRO                          11010-908
# 3  CENTRO                          28010-000
# 4  CAB                             41745-002
#
#                                                    4   5  \
# 0  MANAUS                                        ...  AM
# 1  BELEM                                         ...  PA
# 2  SANTOS                                        ...  SP
# 3  CAMPOS DOS GOYTACAZES                         ...  RJ
# 4  SALVADOR                                      ...  BA
#
#                                                 Join
# 0  R.GUILHERME MOREIRA,315                 ;SUBLO...
# 1  AV.PRES.VARGAS,248                      ;1.E 2...
# 2  R.QUINZE DE NOVEMBRO,195                ;     ...
# 3  PCA.DAS QUATRO JORNADAS,11              ;MEZAN...
# 4  SEXTA AVENIDA,600                       ;SECRE...

# %%
# Tratando endereço completo do DataFrame
dset = np.array(pd_dset)
end_lista = []

for i in range(len(dset)):
    str_raw = dset[i][6]
    str_tratada = re.sub(r'[ ]{2,}', "",str_raw) # Tirando espaços excedentes no final do endereço
    str_tratada = re.sub(r'[;]{1,}', "; ", str_tratada) # Para complementos vazios, para não ter 2 ";"
    str_tratada = str_tratada.lower()
    
    end_lista.append(str_tratada)

end_lista[:3]
# Out:
# ['r.guilherme moreira,315; subloja,loja e 2.andar; centro; 69005-300; manaus; am',
#  'av.pres.vargas,248; 1.e 2.andares; campina; 66010-900; belem; pa',
#  'r.quinze de novembro,195; centro; 11010-908; santos; sp']

# %%
# Lógica para extrair posição do logradouro:
# Dividir a String inteira por ";", pegar o len do primeiro split
# len de LOGRA é de 0 até len do primeiro split

print(end_lista[0])
split = end_lista[0].split(";")
print(split)
print(split[0])
print(len(split[0]))
# Out:
# r.guilherme moreira,315; subloja,loja e 2.andar; centro; 69005-300; manaus; am
# ['r.guilherme moreira,315', ' subloja,loja e 2.andar', ' centro', ' 69005-300', ' manaus', ' am']
# r.guilherme moreira,315
# 23

# %%
# Extraindo iob com entidade apenas de logradouro

iob = []

for i in range(len(end_lista)):
    split = end_lista[i].split(";")
    len_logra = len(split[0])
    iob_dict = {"entities": [(0, len_logra-1,'LOGRA')]}
    end_lista[i] = end_lista[i].replace(";", " ")
    end_lista[i] = end_lista[i].replace(",", " ")
    end_lista[i] = re.sub(r'[ ]{2,}', " ", end_lista[i])

    
    tupla = (end_lista[i], iob_dict)
    iob.append(tupla)

FULL_DATA = iob

# %%
print(FULL_DATA[0])
print(FULL_DATA[1])
print(FULL_DATA[2])
print(FULL_DATA[5:15])
# Out:
# ('r.guilherme moreira 315 subloja loja e 2.andar centro 69005-300 manaus am', {'entities': [(0, 22, 'LOGRA')]})
# ('av.pres.vargas 248 1.e 2.andares campina 66010-900 belem pa', {'entities': [(0, 17, 'LOGRA')]})
# ('r.quinze de novembro 195 centro 11010-908 santos sp', {'entities': [(0, 23, 'LOGRA')]})
# [('av.rio branco 240 1.andar recife antigo 50030-310 recife pe', {'entities': [(0, 16, 'LOGRA')]}), ('av.santos dumont 2828 5.andar aldeota 60150-162 fortaleza ce', {'entities': [(0, 20, 'LOGRA')]}), ('pca.tiradentes 410 1.andar centro 80020-100 curitiba pr', {'entities': [(0, 17, 'LOGRA')]}), ('r.uruguai 185 5.andar centro 90010-901 porto alegre rs', {'entities': [(0, 12, 'LOGRA')]}), ('pca.1817 129 1.andar centro 58013-010 joao pessoa pb', {'entities': [(0, 11, 'LOGRA')]}), ('pca.odilon resende andrade 76 centro 37410-000 tres coracoes mg', {'entities': [(0, 28, 'LOGRA')]}), ('av fernandes lima 2591 terreo farol 57057-972 maceio al', {'entities': [(0, 22, 'LOGRA')]}), ('r.treze de junho 914 centro 79300-040 corumba ms', {'entities': [(0, 19, 'LOGRA')]}), ('av.leopoldino de oliveira 3635 centro 38010-000 uberaba mg', {'entities': [(0, 29, 'LOGRA')]}), ('pca.quinze de novembro 321 centro 88010-400 florianopolis sc', {'entities': [(0, 25, 'LOGRA')]})]

# %%
# Criação da base de teste e treinamento

n_test= 0.1 # Porcentagem para base de teste
test_n = round(len(FULL_DATA) * n_test)

# Divisao em Train Test Val

def gerador_bases(dataset, n):
    indices_random = random.sample(range(0,len(dataset)-1), n)
    base_teste_n = []
    base_treinamento_n = []
    
    for i in range(n):
        base_teste_n.append(dataset[indices_random[i]])

    for j in range(len(dataset)):
        if(j not in indices_random):
            base_treinamento_n.append(dataset[j])
            
    return base_teste_n, base_treinamento_n


base_teste, base_treinamento = gerador_bases(FULL_DATA, test_n)

random.shuffle(base_treinamento)
random.shuffle(base_teste)

print("Treinamento: " + str(len(base_treinamento)), "\nTeste: " + str(len(base_teste)), "\nTotal: " + str(len(FULL_DATA)))
# Out:
# Treinamento: 19202
# Teste: 2134
# Total: 21336

# %%
for i in range(5):
    print(base_treinamento[i])
# Out:
# ('praca benedito meirelles 186 centro 12570-000 aparecida sp', {'entities': [(0, 28, 'LOGRA')]})
# ('av.paulo de frontin 110 aterrado 27213-150 volta redonda rj', {'entities': [(0, 23, 'LOGRA')]})
# ('av.n.sra.de fatima 22-a centro 20240-051 rio de janeiro rj', {'entities': [(0, 22, 'LOGRA')]})
# ('av. independencia 98300-000 palmeira das missoes rs', {'entities': [(0, 16, 'LOGRA')]})
# ('avenida sua�una 374 quart 4212 qd 56 lt 15 vila aeroporto 13054-105 campinas sp', {'entities': [(0, 18, 'LOGRA')]})

# %% [markdown]
# # Carregando o modelo

# %%
# Define our variables

model = None
output_dir=Path(".")
n_iter= 100 # número de épocas
batch_size = 64

# %%
# Setting up the pipeline and entity recognizer.
if model is not None:
    nlp = spacy.load(model)  # load existing spacy model
    print("Loaded model '%s'" % model)
else:
    lan = 'pt'
    nlp = spacy.blank(lan)  # create blank Language class
    print("Created blank '%s' model" % lan)
    
if 'ner' not in nlp.pipe_names:
    ner = nlp.create_pipe('ner')
    nlp.add_pipe(ner)
    print('Added new NER')
else:
    ner = nlp.get_pipe('ner')
    print('Got an old NER')
# Out:
# Created blank 'pt' model
# Added new NER

# %%
# create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
if 'ner' not in nlp.pipe_names:
    ner = nlp.create_pipe('ner')
    nlp.add_pipe(ner, last=True)
# otherwise, get it so we can add labels
else:
    ner = nlp.get_pipe('ner')

# %% [markdown]
# ## Treinamento

# %%
print("Batch size: ", batch_size)
print("Épocas: ", n_iter)
print()

# add labels
for _, annotations in base_treinamento:
    for ent in annotations.get('entities'):
        ner.add_label(ent[2])


# get names of other pipes to disable them during training
other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
with nlp.disable_pipes(*other_pipes):  # only train NER
    optimizer = nlp.begin_training()
    for itn in range(n_iter):
        random.shuffle(base_treinamento)
        losses = {}
        batches = minibatch(base_treinamento, size=batch_size)
        
        for batch in batches:
            texts, annotations = zip(*batch)
            try:
                nlp.update(texts, annotations, sgd=optimizer, drop=0.2,
                       losses=losses)
            except:
                pass     
        
        print(itn+1, ' Losses', losses)
# Out:
# Batch size:  64
# Épocas:  100
#
# 1  Losses {'ner': 19831.867839641283}
# 2  Losses {'ner': 5587.187654880628}
# 3  Losses {'ner': 4747.712440041905}
# 4  Losses {'ner': 3571.2951006069256}
# 5  Losses {'ner': 3791.955800525956}
# 6  Losses {'ner': 3446.278985528668}
# 7  Losses {'ner': 3056.796404897451}
# 8  Losses {'ner': 2590.437319298614}
# 9  Losses {'ner': 2762.622550400089}
# 10  Losses {'ner': 2390.0576414050247}
# 11  Losses {'ner': 2435.0627649975263}
# 12  Losses {'ner': 2173.0066205404582}
# 13  Losses {'ner': 1949.3835919389064}
# 14  Losses {'ner': 1828.711330771129}
# 15  Losses {'ner': 1937.1560782559998}
# 16  Losses {'ner': 1548.47443502713}
# 17  Losses {'ner': 1584.1878045401488}
# 18  Losses {'ner': 1504.1001630591982}
# 19  Losses {'ner': 1638.68770458259}
# 20  Losses {'ner': 1309.914074565429}
# 21  Losses {'ner': 1318.906028696298}
# 22  Losses {'ner': 1441.0242280638136}
# 23  Losses {'ner': 1432.7379352941923}
# 24  Losses {'ner': 1230.5440113802708}
# 25  Losses {'ner': 1017.3780487214002}
# 26  Losses {'ner': 1090.4294242166748}
# 27  Losses {'ner': 1072.996670297827}
# 28  Losses {'ner': 918.3630690354507}
# 29  Losses {'ner': 834.2930748944128}
# 30  Losses {'ner': 953.0619607289549}
# 31  Losses {'ner': 883.5876348357539}
# 32  Losses {'ner': 776.7184595396554}
# 33  Losses {'ner': 963.7588485361675}
# 34  Losses {'ner': 1095.1503683521937}
# 35  Losses {'ner': 1054.4600125909408}
# 36  Losses {'ner': 907.3369122215535}
# 37  Losses {'ner': 719.0972829155087}
# 38  Losses {'ner': 814.7471457730735}
# 39  Losses {'ner': 755.3846195625254}
# 40  Losses {'ner': 754.9060270877688}
# 41  Losses {'ner': 699.4819861371727}
# 42  Losses {'ner': 687.9514213764606}
# 43  Losses {'ner': 832.7840987925424}
# 44  Losses {'ner': 827.0056527102786}
# 45  Losses {'ner': 944.9194628987302}
# 46  Losses {'ner': 732.1535657580007}
# 47  Losses {'ner': 709.9330960015245}
# 48  Losses {'ner': 663.0744219534861}
# 49  Losses {'ner': 610.4207182639755}
# 50  Losses {'ner': 748.8933928474615}
# 51  Losses {'ner': 680.0643811946636}
# 52  Losses {'ner': 680.5178167929579}
# 53  Losses {'ner': 911.1119679010632}
# 54  Losses {'ner': 687.564991834656}
# 55  Losses {'ner': 611.2783318811488}
# 56  Losses {'ner': 634.246859924329}
# 57  Losses {'ner': 711.4652580777561}
# 58  Losses {'ner': 619.6765224435188}
# 59  Losses {'ner': 613.2410749336549}
# 60  Losses {'ner': 582.0481721823925}
# 61  Losses {'ner': 624.1370209646035}
# 62  Losses {'ner': 655.9847701999273}
# 63  Losses {'ner': 618.0502168431773}
# 64  Losses {'ner': 621.2322059509096}
# 65  Losses {'ner': 696.6201029406249}
# 66  Losses {'ner': 539.695955749372}
# 67  Losses {'ner': 631.6073089679422}
# 68  Losses {'ner': 524.4567977327666}
# 69  Losses {'ner': 729.0524231484438}
# 70  Losses {'ner': 518.2211195969068}
# 71  Losses {'ner': 529.2044793203821}
# 72  Losses {'ner': 531.7353299988306}
# 73  Losses {'ner': 568.8617695587275}
# 74  Losses {'ner': 578.9137884499704}
# 75  Losses {'ner': 689.2273598819237}
# 76  Losses {'ner': 474.3500060128365}
# 77  Losses {'ner': 501.2666740129248}
# 78  Losses {'ner': 482.24739924886813}
# 79  Losses {'ner': 499.1991551403154}
# 80  Losses {'ner': 555.0603382471711}
# 81  Losses {'ner': 499.1835238886771}
# 82  Losses {'ner': 554.2829382396785}
# 83  Losses {'ner': 462.1137909798196}
# 84  Losses {'ner': 401.3057171653632}
# 85  Losses {'ner': 521.8898660096811}
# 86  Losses {'ner': 555.9437682550481}
# 87  Losses {'ner': 526.9343864678495}
# 88  Losses {'ner': 544.5556471621838}
# 89  Losses {'ner': 451.5360436281056}
# 90  Losses {'ner': 490.3179826654837}
# 91  Losses {'ner': 452.19186053080017}
# 92  Losses {'ner': 557.4624643906997}
# 93  Losses {'ner': 527.6460540913093}
# 94  Losses {'ner': 568.7086285689364}
# 95  Losses {'ner': 447.5586243404642}
# 96  Losses {'ner': 695.5171027887253}
# 97  Losses {'ner': 495.3701375126821}
# 98  Losses {'ner': 602.5314209057622}
# 99  Losses {'ner': 450.1197932247081}
# 100  Losses {'ner': 479.967905953185}

# %%
# test the trained model
for text, _ in base_teste:
    doc = nlp(text)
    print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
    print(text)
    print()
# Out:
# Entities [('av.goias 980', 'LOGRA')]
# av.goias 980 3.andar centro 74010-010 goiania go
#
# Entities [('rua xv de novembro 2.767', 'LOGRA')]
# rua xv de novembro 2.767 centro 80045-125 curitiba pr
#
# Entities [('rua carijos 871', 'LOGRA')]
# rua carijos 871 centro 30120-060 belo horizonte mg
#
# Entities [('av.dom pedro i 768', 'LOGRA')]
# av.dom pedro i 768 ipiranga 14055-630 ribeirao preto sp
#
# Entities [('av. parana 1026', 'LOGRA')]
# av. parana 1026 centro 87900-000 loanda pr
#
# Entities [('av. centauro 420', 'LOGRA')]
# av. centauro 420 centro 87265-000 quinta do sol pr
#
# Entities [('av. presidente vargas quadra 40', 'LOGRA')]
# av. presidente vargas quadra 40 lotes 9/10 jardim goias 75903-290 rio verde go
#
# Entities [('avenida presidentegetuilio vargas', 'LOGRA')]
# avenida presidentegetuilio vargas bela vista ii 45996-000 teixeira de freitas ba
#
# Entities [('av. rui barbosa 790', 'LOGRA')]
# av. rui barbosa 790 centro 28700-000 macae rj
#
# Entities [('av caminho de areia 234', 'LOGRA')]
# av caminho de areia 234 caminho de areia 40440-360 salvador ba
#
# Entities [('r.joao vieira machado 263', 'LOGRA')]
# r.joao vieira machado 263 centro 75815-000 itaja go
#
# Entities [('av.souza naves 1240', 'LOGRA')]
# av.souza naves 1240 (parte) cristo rei 80050-152 curitiba pr
#
# Entities [('avenida liberdade 1450', 'LOGRA')]
# avenida liberdade 1450 lojas 05/06 santa isabel 94480-500 viamao rs
#
# Entities [('rua engenheiro antonio penido', 'LOGRA')]
# rua engenheiro antonio penido centro 12701-050 cruzeiro sp
#
# Entities [('praca joao marques de oliveira 149', 'LOGRA')]
# praca joao marques de oliveira 149 centro 46140-000 livramento de nossa senhora ba
#
# Entities [('av.min.geraldo barreto sobral 160', 'LOGRA')]
# av.min.geraldo barreto sobral 160 jardins 49026-010 aracaju se
#
# Entities [('r.alcides forest 1580', 'LOGRA')]
# r.alcides forest 1580 sala 101 centro 95240-000 ipe rs
#
# Entities [('av. pompilio gomes sobrinho', 'LOGRA')]
# av. pompilio gomes sobrinho centro 94380-000 glorinha rs
#
# Entities [('avenida presidente kennedy 4121', 'LOGRA')]
# avenida presidente kennedy 4121 terreo - lojas 1005 e 1006 agua verde 80610-905 curitiba pr
#
# Entities [('av.das americas 331', 'LOGRA')]
# av.das americas 331 centro 19160-000 alvares machado sp
#
# Entities [('av.dos autonomistas 589', 'LOGRA')]
# av.dos autonomistas 589 vl yara 06020-000 osasco sp
#
# Entities [('est tindiba 2941', 'LOGRA')]
# est tindiba 2941 jacarepagua 22725-421 rio de janeiro rj
#
# Entities [('rua clelia 650', 'LOGRA')]
# rua clelia 650 vila romana 05042-000 sao paulo sp
#
# Entities [('rua gon�alves dias', 'LOGRA')]
# rua gon�alves dias centro 76801-076 porto velho ro
#
# Entities [('av. general pedro pinho 694', 'LOGRA')]
# av. general pedro pinho 694 pestana 06180-180 osasco sp
#
# Entities [('av.getulio vargas 1935', 'LOGRA')]
# av.getulio vargas 1935 centro 65903-280 imperatriz ma
#
# Entities [('r clotilde salgado zenha 160', 'LOGRA')]
# r clotilde salgado zenha 160 cidade baixa 45445-000 camamu ba
#
# Entities [('rua barao de itapetininga 107/111', 'LOGRA')]
# rua barao de itapetininga 107/111 centro 01042-001 sao paulo sp
#
# Entities [('alameda virgilio de andrade martins 6 b', 'LOGRA')]
# alameda virgilio de andrade martins 6 b centro 37418-000 sao tome das letras mg
#
# Entities [('rua joao pessoa 43', 'LOGRA')]
# rua joao pessoa 43 centro 58100-000 campina grande pb
#
# Entities [('avenida silvio sanson', 'LOGRA')]
# avenida silvio sanson centro 99200-000 guapore rs
#
# Entities [('rua sao joao 462', 'LOGRA')]
# rua sao joao 462 centro 14700-000 bebedouro sp
#
# Entities [('praca getulio vargas', 'LOGRA')]
# praca getulio vargas centro 65800-000 balsas ma
#
# Entities [('rua benjamin constant 1060', 'LOGRA')]
# rua benjamin constant 1060 terreo centro 68450-000 moju pa
#
# Entities [('av. sua�una 716', 'LOGRA')]
# av. sua�una 716 vila aeroporto 13054-105 campinas sp
#
# Entities [('av. 7 de setembro 865', 'LOGRA')]
# av. 7 de setembro 865 centro 97560-000 quarai rs
#
# Entities [('n�cleo', 'LOGRA')]
# n�cleo cidade de deus s/n� pr�dio rubi t�rreo sala 2 vila yara 06029-900 osasco sp
#
# Entities [('rua halfeld 592/600', 'LOGRA')]
# rua halfeld 592/600 60746948 centro 36013-000 juiz de fora mg
#
# Entities [('tv emidio martins ferreira', 'LOGRA')]
# tv emidio martins ferreira centro 68270-000 oriximina pa
#
# Entities [('rua alvaro coelho 300', 'LOGRA')]
# rua alvaro coelho 300 centro 63740-000 novo oriente ce
#
# Entities [('av.papa paulo vi 444', 'LOGRA')]
# av.papa paulo vi 444 jardim do trevo 13040-000 campinas sp
#
# Entities [('r.carlos weber 38', 'LOGRA')]
# r.carlos weber 38 centro 89295-000 rio negrinho sc
#
# Entities [('av. interventor manoel ribas 186', 'LOGRA')]
# av. interventor manoel ribas 186 centro 84600-000 uniao da vitoria pr
#
# Entities [('av.julio antonio thurler 159', 'LOGRA')]
# av.julio antonio thurler 159 olaria 28620-000 nova friburgo rj
#
# Entities [('p�a. da republica 466- esq. c/ rua xv de novembro', 'LOGRA')]
# p�a. da republica 466- esq. c/ rua xv de novembro centro 75503-260 itumbiara go
#
# Entities [('av.rondon pacheco 1001', 'LOGRA')]
# av.rondon pacheco 1001 tabajaras 38400-242 uberlandia mg
#
# Entities [('rua coronel moreira cesar 35', 'LOGRA')]
# rua coronel moreira cesar 35 centro 24440-400 sao goncalo rj
#
# Entities [('est santa isabel 3365', 'LOGRA')]
# est santa isabel 3365 vila sao carlos 08599-000 itaquaquecetuba sp
#
# Entities [('pca cel. estevam marcolino 300', 'LOGRA')]
# pca cel. estevam marcolino 300 centro 14415-000 patrocinio paulista sp
#
# Entities [('rua marechal floriano 94', 'LOGRA')]
# rua marechal floriano 94 centro 95700-112 bento goncalves rs
#
# Entities [('av.brig.faria lima 2006', 'LOGRA')]
# av.brig.faria lima 2006 jardim paulistano 01451-000 sao paulo sp
#
# Entities []
#  r rodoviarios 01 lj 07.01 cabula 41150-125 salvador ba
#
# Entities [('av.brasil 1650', 'LOGRA')]
# av.brasil 1650 centro 96503-490 cachoeira do sul rs
#
# Entities [('av. pres. castelo branco 1972', 'LOGRA')]
# av. pres. castelo branco 1972 centro 87560-000 ipora pr
#
# Entities [('quarta rua', 'LOGRA')]
# quarta rua centro 68870-000 soure pa
#
# Entities [('av.sete de setembro 509', 'LOGRA')]
# av.sete de setembro 509 centro 28013-331 campos dos goytacazes rj
#
# Entities [('av.jeronimo monteiro 1054', 'LOGRA')]
# av.jeronimo monteiro 1054 terreo gloria 29123-001 vila velha es
#
# Entities [('av.presidente vargas', 'LOGRA')]
# av.presidente vargas lj a sbl201 ssl centro 20071-000 rio de janeiro rj
#
# Entities [('br 116 km 11 n.22.881', 'LOGRA')]
# br 116 km 11 n.22.881 boxes tatuquara 81690-901 curitiba pr
#
# Entities [('av sete 487', 'LOGRA')]
# av sete 487 centro 38240-000 itapagipe mg
#
# Entities [('avenida mutinga 2474', 'LOGRA')]
# avenida mutinga 2474 jardim santo elias 05110-000 sao paulo sp
#
# Entities [('rua visconde de piraja 127', 'LOGRA')]
# rua visconde de piraja 127 centro 22410-000 rio de janeiro rj
#
# Entities [('avenida guajajaras 88', 'LOGRA')]
# avenida guajajaras 88 tirirical 65055-285 sao luis ma
#
# Entities [('av francisco porto (portinox)', 'LOGRA')]
# av francisco porto (portinox) qd g lt 112 jardins 49025-230 aracaju se
#
# Entities [('av manoel ribas santa', 'LOGRA')]
# av manoel ribas santa felicidade 82400-000 curitiba pr
#
# Entities [('av.anna claudina 411', 'LOGRA')]
# av.anna claudina 411 jd.estadio 17203-381 jau sp
#
# Entities [('rua tapajos quadra 4lote 1e compl lotes 01-04', 'LOGRA')]
# rua tapajos quadra 4lote 1e compl lotes 01-04 esquina com r vila bras�lia complemento 74911-820 aparecida de goiania go
#
# Entities [('av. luiz osorio 615', 'LOGRA')]
# av. luiz osorio 615 centro 16300-000 penapolis sp
#
# Entities [('av. xingu 232', 'LOGRA')]
# av. xingu 232 local xinguara 68540-000 xinguara pa
#
# Entities [('av. argentina', 'LOGRA')]
# av. argentina centro 98980-000 porto lucena rs
#
# Entities [('av.duque de caxias 20', 'LOGRA')]
# av.duque de caxias 20 ribeira 59012-200 natal rn
#
# Entities [('avenida governador jorge teixeira', 'LOGRA')]
# avenida governador jorge teixeira embratel 76820-116 porto velho ro
#
# Entities [('av.d.vicente zico s/', 'LOGRA')]
# av.d.vicente zico s/n antiga arterial dezoito coqueiro 67110-000 ananindeua pa
#
# Entities [('rua olavo barreto viana moinhos', 'LOGRA')]
# rua olavo barreto viana moinhos de vento 90570-070 porto alegre rs
#
# Entities [('av presidente vargas 678', 'LOGRA')]
# av presidente vargas 678 cidade nova 14401-120 franca sp
#
# Entities [('av antonio carlos 83', 'LOGRA')]
# av antonio carlos 83 360305 centro 38183-083 araxa mg
#
# Entities [('av.presidente getulio vargas 4155', 'LOGRA')]
# av.presidente getulio vargas 4155 centro 45995-002 teixeira de freitas ba
#
# Entities [('av. inoc�ncio serafico 3.585', 'LOGRA')]
# av. inoc�ncio serafico 3.585 vila silva ribeiro 06380-021 carapicuiba sp
#
# Entities [('rua gaviao peixoto 226', 'LOGRA')]
# rua gaviao peixoto 226 360305 icarai 24230-102 niteroi rj
#
# Entities [('praca bom jesus 69', 'LOGRA')]
# praca bom jesus 69 centro 35720-000 matozinhos mg
#
# Entities [('rua marechal deodoro 384 b', 'LOGRA')]
# rua marechal deodoro 384 b centro 37590-000 jacutinga mg
#
# Entities [('pca barao do rio branco 107', 'LOGRA')]
# pca barao do rio branco 107 centro 29780-000 sao gabriel da palha es
#
# Entities [('r.menino julio cesar 347', 'LOGRA')]
# r.menino julio cesar 347 sala estilo n sra rosario 88110-639 sao jose sc
#
# Entities [('av.dantas barreto 512', 'LOGRA')]
# av.dantas barreto 512 sala 410 santo antonio 50010-922 recife pe
#
# Entities [('pca.do centenario 645', 'LOGRA')]
# pca.do centenario 645 centro 77500-000 porto nacional to
#
# Entities [('rua ezequiel ramos 3-33/rua agenor meira 4-44', 'LOGRA')]
# rua ezequiel ramos 3-33/rua agenor meira 4-44 centro 17010-021 bauru sp
#
# Entities [('avenida dos bandeirantes 1856', 'LOGRA')]
# avenida dos bandeirantes 1856 vila olimpia 04553-002 sao paulo sp
#
# Entities [('av paulista 726', 'LOGRA')]
# av paulista 726 loja 1 bela vista 01310-100 sao paulo sp
#
# Entities [('qnn 30 area especial i lojas 1 2 3 e 101 - ceishop ceilandia 72220-309 brasilia (ceilandia) df', 'LOGRA')]
# qnn 30 area especial i lojas 1 2 3 e 101 - ceishop ceilandia 72220-309 brasilia (ceilandia) df
#
# Entities [('rua jorge antonio de oliveira 72', 'LOGRA')]
# rua jorge antonio de oliveira 72 centro 18157-000 capela do alto sp
#
# Entities [('rua padre joao porto 691', 'LOGRA')]
# rua padre joao porto 691 centro 35640-000 pompeu mg
#
# Entities [('av.sen.virgilio tavora 999', 'LOGRA')]
# av.sen.virgilio tavora 999 esq.c/av.dom luis meireles 60170-250 fortaleza ce
#
# Entities [('r.gal.francisco glicerio', 'LOGRA')]
# r.gal.francisco glicerio 472 predio centro 08674-000 suzano sp
# Entities [('r cazuza ramos', 'LOGRA')]
# r cazuza ramos cruzeiro 65590-000 barreirinhas ma
#
# Entities [('alameda dom pedro ii 21', 'LOGRA')]
# alameda dom pedro ii 21 batel 80420-060 curitiba pr
#
# Entities [('av. das americas', 'LOGRA')]
# av. das americas bloco 07 grupo 201 barra da tijuca 22640-102 rio de janeiro rj
#
# Entities [('rua joaquim floriano', 'LOGRA')]
# rua joaquim floriano 7� andar - cj. 71/72 itaim bibi 04534-004 sao paulo sp
#
# Entities [('av.ernani do amaral peixoto 347', 'LOGRA')]
# av.ernani do amaral peixoto 347 3 andar centro 24020-072 niteroi rj
#
# Entities [('av. flores da cunha 1939/rua exped.', 'LOGRA')]
# av. flores da cunha 1939/rua exped. c. pinheiro centro 99500-000 carazinho rs
#
# Entities [('rua cincinato braga 340', 'LOGRA')]
# rua cincinato braga 340 16� andar cj 162 bela vista 01333-010 sao paulo sp
#
# Entities [('rua mendes junior 654', 'LOGRA')]
# rua mendes junior 654 bras 03013-011 sao paulo sp
#
# Entities [('rua comendador ara�jo', 'LOGRA')]
# rua comendador ara�jo centro 80420-000 curitiba pr
#
# Entities [('av. de pinedo 505', 'LOGRA')]
# av. de pinedo 505 parte socorro 04764-001 sao paulo sp
#
# Entities [('alameda doutor carlos de carvalho 555', 'LOGRA')]
# alameda doutor carlos de carvalho 555 9� andar - cjs. 91 92 e 93 centro 80430-180 curitiba pr
#
# Entities [('rua sao paulo 112', 'LOGRA')]
# rua sao paulo 112 centro 49500-000 itabaiana se
#
# Entities [('rua dr cesar castiglioni jr. 215', 'LOGRA')]
# rua dr cesar castiglioni jr. 215 casa verde 02515-000 sao paulo sp
#
# Entities [('av.aires francisco de lima 63', 'LOGRA')]
# av.aires francisco de lima 63 centro 79140-000 nova alvorada do sul ms
#
# Entities [('r ushima kira granja', 'LOGRA')]
# r ushima kira granja viana 06709-048 cotia sp
#
# Entities [('r.quinze de novembro 70', 'LOGRA')]
# r.quinze de novembro 70 centro 16880-000 valparaiso sp
#
# Entities [('av. fernando costa 447', 'LOGRA')]
# av. fernando costa 447 vila jaiara 75064-780 anapolis go
#
# Entities [('rua coronel luiz pereira dos santos 243', 'LOGRA')]
# rua coronel luiz pereira dos santos 243 lote 01 quadra 10 centro 24890-000 tangua rj
#
# Entities [('av goias 368 esq.c/rua 18', 'LOGRA')]
# av goias 368 esq.c/rua 18 centro 76380-000 goianesia go
#
# Entities [('av. uruguai', 'LOGRA')]
# av. uruguai centro 98910-000 tres de maio rs
#
# Entities [('rua butant�', 'LOGRA')]
# rua butant� 192 pinheiros 05424-000 sao paulo sp
#
# Entities [('av.iguacu 370 qd.17', 'LOGRA')]
# av.iguacu 370 qd.17 centro 85790-000 capitao leonidas marques pr
#
# Entities [('av santa marina 2618', 'LOGRA')]
# av santa marina 2618 pavimento superior vl albertina 02732-040 sao paulo sp
#
# Entities [('rua carolina meier 28/a 30/a - 32', 'LOGRA')]
# rua carolina meier 28/a 30/a - 32 meier 20780-000 rio de janeiro rj
#
# Entities [('av. ramiro barcelos', 'LOGRA')]
# av. ramiro barcelos independencia 90000-000 porto alegre rs
#
# Entities [('pca. jose joaquim seabra 7', 'LOGRA')]
# pca. jose joaquim seabra 7 centro 46300-000 cacule ba
#
# Entities [('rua xv de novembro 212', 'LOGRA')]
# rua xv de novembro 212 centro 01013-000 sao paulo sp
#
# Entities [('pca.dr.mario rodrigues pereira 66', 'LOGRA')]
# pca.dr.mario rodrigues pereira 66 terreo centro 36415-000 congonhas mg
#
# Entities [('praca 28 de setembro 236', 'LOGRA')]
# praca 28 de setembro 236 360305 centro 36520-000 visconde do rio branco mg
#
# Entities [('av. emilio johnson', 'LOGRA')]
# av. emilio johnson vila santa terezinha 83501-000 almirante tamandare pr
#
# Entities [('praca nove de julho 100', 'LOGRA')]
# praca nove de julho 100 centro 18870-000 fartura sp
#
# Entities []
#  ruasete de setembro centro 96470-000 pinheiro machado rs
#
# Entities [('rua adelina de s� 284', 'LOGRA')]
# rua adelina de s� 284 parte centro 42800-060 camacari ba
#
# Entities [('campus universitario s/', 'LOGRA')]
# campus universitario s/n jardim america 96160-000 capao do leao rs
#
# Entities [('r.mal.deodoro 1149', 'LOGRA')]
# r.mal.deodoro 1149 centro 15900-000 taquaritinga sp
#
# Entities [('rua marechal deodoro', 'LOGRA')]
# rua marechal deodoro loja 101 centro 96810-062 santa cruz do sul rs
#
# Entities [('av coletora a quadra 10', 'LOGRA')]
# av coletora a quadra 10 joao alves filho 49160-000 nossa senhora do socorro se
#
# Entities [('rua barao rio branco', 'LOGRA')]
# rua barao rio branco centro 95970-000 mucum rs
#
# Entities [('av.estados unidos', 'LOGRA')]
# av.estados unidos 561-3.andar predio banco do brasil ag. comercio comercio 40010-904 salvador ba
#
# Entities [('av pedroso de morais', 'LOGRA')]
# av pedroso de morais pinheiros 05420-003 sao paulo sp
#
# Entities [('av. loureiro da silva', 'LOGRA')]
# av. loureiro da silva loja 102 cidade baixa 90050-240 porto alegre rs
#
# Entities [('praca dom lafayete libano 110', 'LOGRA')]
# praca dom lafayete libano 110 centro 15290-000 buritama sp
#
# Entities [('av. adolfo rodrigues 824', 'LOGRA')]
# av. adolfo rodrigues 824 centro 15440-000 nova granada sp
#
# Entities [('pca.bolivar andrade 20', 'LOGRA')]
# pca.bolivar andrade 20 centro 35537-000 passa tempo mg
#
# Entities [('avenida governador amaral peixoto 24', 'LOGRA')]
# avenida governador amaral peixoto 24 centro 26210-060 nova iguacu rj
#
# Entities [('r maria casusa feitosa', 'LOGRA')]
# r maria casusa feitosa jordanopolis 04830-000 sao paulo sp
#
# Entities [('av.jose fonseca e silva 568', 'LOGRA')]
# av.jose fonseca e silva 568 jd.patricia 38414-348 uberlandia mg
#
# Entities [('av. meira vasconcelos s/n', 'LOGRA')]
# av. meira vasconcelos s/n. centro 55720-000 joao alfredo pe
#
# Entities [('rua prof.maria amalia de faria gonfiant 194', 'LOGRA')]
# rua prof.maria amalia de faria gonfiant 194 centro 16850-000 lavinia sp
#
# Entities [('av.getulio vargas 610', 'LOGRA')]
# av.getulio vargas 610 centro 39314-000 chapada gaucha mg
#
# Entities [('av. jose dos santos e silva 797', 'LOGRA')]
# av. jose dos santos e silva 797 centro 64001-300 teresina pi
#
# Entities [('av princesa do sul 805', 'LOGRA')]
# av princesa do sul 805 jardim andere 37026-080 varginha mg
#
# Entities [('av.salvador furtado 58', 'LOGRA')]
# av.salvador furtado 58 centro 35420-000 mariana mg
#
# Entities [('rua joao botelho de andrade s/n', 'LOGRA')]
# rua joao botelho de andrade s/n quadra 64 lotes 1 e 2 centro 72930-000 alexania go
#
# Entities [('avenida parada pinto 747/749', 'LOGRA')]
# avenida parada pinto 747/749 vila nova cachoeirinha 02611-003 sao paulo sp
#
# Entities [('av. frei orestes girardi 859', 'LOGRA')]
# av. frei orestes girardi 859 centro 12460-000 campos do jordao sp
#
# Entities [('av. santo ant�nio 179', 'LOGRA')]
# av. santo ant�nio 179 360305 centro 55700-000 limoeiro pe
#
# Entities [('av. julio de castilhos', 'LOGRA')]
# av. julio de castilhos loja 01 centro 90030-131 porto alegre rs
#
# Entities [('rua comendador antonio alves', 'LOGRA')]
# rua comendador antonio alves centro 33600-000 pedro leopoldo mg
#
# Entities [('tv.manoel saraiva 314', 'LOGRA')]
# tv.manoel saraiva 314 centro 39950-000 rubim mg
#
# Entities [('r.jader moura 258', 'LOGRA')]
# r.jader moura 258 centro 35620-000 abaete mg
#
# Entities [('pca.francisco barreto 258', 'LOGRA')]
# pca.francisco barreto 258 conjunto 2 centro 14780-050 barretos sp
#
# Entities [('av. fernando osorio', 'LOGRA')]
# av. fernando osorio lj 18 centro 96020-152 pelotas rs
#
# Entities [('rua major felix moreira 85', 'LOGRA')]
# rua major felix moreira 85 centro 28970-000 araruama rj
#
# Entities [('av. brigadeiro luis antonio 1030', 'LOGRA')]
# av. brigadeiro luis antonio 1030 b. vista 01318-001 sao paulo sp
#
# Entities [('rua bispo dom jose 2146', 'LOGRA')]
# rua bispo dom jose 2146 batel 80440-080 curitiba pr
#
# Entities [('avenida das americas', 'LOGRA')]
# avenida das americas lj 104 e 105 lj d e e f sala 205 206 207 e 211 recreio dos bandeirantes 22790-701 rio de janeiro rj
#
# Entities [('srtvs qd.701 cj.d bloco b', 'LOGRA')]
# srtvs qd.701 cj.d bloco b loja 12 centro empresarial brasilia asa sul 70390-010 brasilia df
#
# Entities [('r.do catete 244', 'LOGRA')]
# r.do catete 244 terreo e 1.andar catete 22220-001 rio de janeiro rj
#
# Entities [('rua s�o jo�o cl�maco 602', 'LOGRA')]
# rua s�o jo�o cl�maco 602 s�o jo�o cl�maco 04255-000 sao paulo sp
#
# Entities [('av. bel tomaz landin 506', 'LOGRA')]
# av. bel tomaz landin 506 loteamento jd. lola 59290-000 sao goncalo do amarante rn
#
# Entities [('r.jose vieira bujary 165', 'LOGRA')]
# r.jose vieira bujary 165 centro 58915-000 uirauna pb
#
# Entities [('r.sinimbu 1601', 'LOGRA')]
# r.sinimbu 1601 sala 11 1.andar centro 95020-001 caxias do sul rs
#
# Entities [('av.dr.nelson d avila 203', 'LOGRA')]
# av.dr.nelson d avila 203 2.andar jd.sao dimas 12245-030 sao jose dos campos sp
#
# Entities [('rua serra dourada 234', 'LOGRA')]
# rua serra dourada 234 sao miguel paulista 80102-900 sao paulo sp
#
# Entities [('pra�a dr. jos� sacramento e silva 64', 'LOGRA')]
# pra�a dr. jos� sacramento e silva 64 centro 18540-000 porto feliz sp
#
# Entities [('av.anisio haddad 6951', 'LOGRA')]
# av.anisio haddad 6951 jd f fernandes 15090-305 sao jose do rio preto sp
#
# Entities [('av. antonio piranga 71', 'LOGRA')]
# av. antonio piranga 71 centro 09911-160 diadema sp
#
# Entities [('rua 15 de novembro 362', 'LOGRA')]
# rua 15 de novembro 362 centro 25804-000 tres rios rj
#
# Entities [('rua joaquim nabuco 951', 'LOGRA')]
# rua joaquim nabuco 951 centro 93310-002 novo hamburgo rs
#
# Entities [('pca.rodrigues de abreu 505', 'LOGRA')]
# pca.rodrigues de abreu 505 centro 13360-000 capivari sp
#
# Entities [('r.nicaragua 436', 'LOGRA')]
# r.nicaragua 436 penha 21020-050 rio de janeiro rj
#
# Entities [('rtreze de maio 149', 'LOGRA')]
# rtreze de maio 149 2� andar - en exclusivo vl galvao 07071-050 guarulhos sp
#
# Entities [('avenida governador julio campos', 'LOGRA')]
# avenida governador julio campos setor comercial 78550-276 sinop mt
#
# Entities [('rua pouso alegre 2342', 'LOGRA')]
# rua pouso alegre 2342 360305 horto 31015-030 belo horizonte mg
#
# Entities [('av. barreiras 871', 'LOGRA')]
# av. barreiras 871 mimoso do oeste 47850-000 luis eduardo magalhaes ba
#
# Entities [('av. rui barbosa 485', 'LOGRA')]
# av. rui barbosa 485 centro 19800-000 assis sp
#
# Entities [('r.antonio ciechanowski 2828', 'LOGRA')]
# r.antonio ciechanowski 2828 centro 85770-000 realeza pr
#
# Entities [('av. vinte e oito de agosto', 'LOGRA')]
# av. vinte e oito de agosto centro 15990-180 matao sp
#
# Entities [('r sete de setembro', 'LOGRA')]
# r sete de setembro centro historico 90010-191 porto alegre rs
#
# Entities [('av ledio joao martins 180', 'LOGRA')]
# av ledio joao martins 180 2� andar kobrasol 88101-100 sao jose sc
#
# Entities [('rodovia pr 82 km 01 s/', 'LOGRA')]
# rodovia pr 82 km 01 s/n 87485-000 douradina pr
#
# Entities [('rua guilherme rocha 45', 'LOGRA')]
# rua guilherme rocha 45 centro 60030-000 fortaleza ce
#
# Entities [('rua marechal floriano peixoto', 'LOGRA')]
# rua marechal floriano peixoto esq com rua andr� de barros centro 80010-130 curitiba pr
#
# Entities [('av.sao paulo 1178', 'LOGRA')]
# av.sao paulo 1178 terreo centro 87890-000 terra rica pr
# Entities [('avenida brasil', 'LOGRA')]
# avenida brasil lote 05 quadra 35 - nucleo urbano centro 68550-005 redencao pa
#
# Entities [('rua marechal deodoro 630', 'LOGRA')]
# rua marechal deodoro 630 5 andar - conjunto 502 centro 80010-010 curitiba pr
#
# Entities [('av.angelica 2011', 'LOGRA')]
# av.angelica 2011 santa cecilia 01227-200 sao paulo sp
#
# Entities [('av. t4 s/n�', 'LOGRA')]
# av. t4 s/n� esq. t63 - lotes 10/11 - quadra 141 - parte setor bueno 74230-035 goiania go
#
# Entities [('pca.patriarca jose bonifacio s/', 'LOGRA')]
# pca.patriarca jose bonifacio s/n ed.palacio da justica centro 11013-910 santos sp
#
# Entities [('r.trinta de dezembro 193', 'LOGRA')]
# r.trinta de dezembro 193 centro 88495-000 garopaba sc
#
# Entities [('av. jose paulino', 'LOGRA')]
# av. jose paulino centro 13140-000 paulinia sp
#
# Entities [('av. dom emanoel c/ av. progresso quadra s/', 'LOGRA')]
# av. dom emanoel c/ av. progresso quadra s/n sala 4 jardim sabi� 75250-000 senador canedo go
#
# Entities [('avmarechal mascarenhas de morais', 'LOGRA')]
# avmarechal mascarenhas de morais parte imbiribeira 51180-001 recife pe
#
# Entities [('rua jose de alencar', 'LOGRA')]
# rua jose de alencar menino de deus 90880-481 porto alegre rs
#
# Entities [('av. senador souza naves 690', 'LOGRA')]
# av. senador souza naves 690 centro 87740-000 sao joao do caiua pr
#
# Entities [('r.quinze de novembro 7900', 'LOGRA')]
# r.quinze de novembro 7900 centro 85010-000 guarapuava pr
#
# Entities [('av.pref.jose americo 46', 'LOGRA')]
# av.pref.jose americo 46 centro 59584-000 touros rn
#
# Entities [('avenida paulista', 'LOGRA')]
# avenida paulista lj 2 bela vista 01310-910 sao paulo sp
#
# Entities [('rua padre gregorio 137', 'LOGRA')]
# rua padre gregorio 137 centro 35514-000 itaguara mg
#
# Entities [('r.cel.manoel mourao 341', 'LOGRA')]
# r.cel.manoel mourao 341 centro 62230-000 ipueiras ce
#
# Entities [('rua aprigio de araujo 1044', 'LOGRA')]
# rua aprigio de araujo 1044 parte centro 14160-550 sertaozinho sp
#
# Entities [('av. dr. marcos paula raphael 10-10', 'LOGRA')]
# av. dr. marcos paula raphael 10-10 esquina com a rua izzat m saadeh nuc hab m dota 17026-610 bauru sp
#
# Entities [('av.das industrias 750', 'LOGRA')]
# av.das industrias 750 dist.industrial 94930-230 cachoeirinha rs
#
# Entities [('av. wladimir meirelles ferreira', 'LOGRA')]
# av. wladimir meirelles ferreira 18� andar jd. botanico 14021-630 ribeirao preto sp
#
# Entities [('rua joaquim nabuco 138', 'LOGRA')]
# rua joaquim nabuco 138 brooklin paulista 46210-001 sao paulo sp
#
# Entities [('r.joaquim freire s/', 'LOGRA')]
# r.joaquim freire s/n qd.18 lote 132 centro 73790-000 cavalcante go
#
# Entities [('avenida 3', 'LOGRA')]
# avenida 3 centro 13500-391 rio claro sp
#
# Entities [('av.cel.jose soares marcondes 246', 'LOGRA')]
# av.cel.jose soares marcondes 246 vila maristela 19020-120 presidente prudente sp
#
# Entities [('av.rio branco 721', 'LOGRA')]
# av.rio branco 721 cidade alta 59025-003 natal rn
#
# Entities [('av.sao luiz 147', 'LOGRA')]
# av.sao luiz 147 republica republica 01046-001 sao paulo sp
#
# Entities [('rua santos costa 66', 'LOGRA')]
# rua santos costa 66 centro 39170-000 rio vermelho mg
#
# Entities [('av.i quadra 102 lote 2', 'LOGRA')]
# av.i quadra 102 lote 2 jardim aureny iii (taqualto) 77062-020 palmas to
#
# Entities [('r.jose rolim de matos 74', 'LOGRA')]
# r.jose rolim de matos 74 centro 95580-000 tres cachoeiras rs
#
# Entities [('rua capitao felix 110', 'LOGRA')]
# rua capitao felix 110 pav ter lojas 13 14 e 15 - 6lnob-bl-nob e lj 16 bl nobre benfica 20920-310 rio de janeiro rj
#
# Entities [('r.epaminondas otoni 655', 'LOGRA')]
# r.epaminondas otoni 655 centro 39800-013 teofilo otoni mg
#
# Entities [('avenida getulio vargas', 'LOGRA')]
# avenida getulio vargas centro 65903-280 imperatriz ma
#
# Entities [('av.saul elkind 2196', 'LOGRA')]
# av.saul elkind 2196 pq.leblon 86082-000 londrina pr
#
# Entities [('av.santos dumont 5640', 'LOGRA')]
# av.santos dumont 5640 lojas 08 e 09 - dunas center papicu 60192-018 fortaleza ce
#
# Entities [('av rui barbosa', 'LOGRA')]
# av rui barbosa centro 75620-000 pontalina go
#
# Entities [('rua quatorze', 'LOGRA')]
# rua quatorze jardim santa maria 13504-710 rio claro sp
#
# Entities [('rua platina 1328', 'LOGRA')]
# rua platina 1328 calafate 30480-240 belo horizonte mg
#
# Entities [('rua afonso braz', 'LOGRA')]
# rua afonso braz vila nova concei��o 04511-011 sao paulo sp
#
# Entities [('r.cel.rupp 2597', 'LOGRA')]
# r.cel.rupp 2597 centro 89670-000 catanduvas sc
#
# Entities [('av.rio branco 477', 'LOGRA')]
# av.rio branco 477 2 pav. centro 59025-001 natal rn
#
# Entities [('rua 7 de setembro 80', 'LOGRA')]
# rua 7 de setembro 80 centro 84950-000 wenceslau braz pr
#
# Entities [('av.benjamim pinto dias 1565', 'LOGRA')]
# av.benjamim pinto dias 1565 centro 26130-000 belford roxo rj
#
# Entities [('pra�a dr. m�rio rodrigues pereira 58', 'LOGRA')]
# pra�a dr. m�rio rodrigues pereira 58 centro 36415-000 congonhas mg
#
# Entities [('av. primeiro de junho 455', 'LOGRA')]
# av. primeiro de junho 455 centro 35500-003 divinopolis mg
#
# Entities [('rua marechal deodoro 960', 'LOGRA')]
# rua marechal deodoro 960 mezanino centro 80060-010 curitiba pr
#
# Entities [('r.florencio domingues 111', 'LOGRA')]
# r.florencio domingues 111 centro 12995-000 pinhalzinho sp
#
# Entities [('avenida brasil', 'LOGRA')]
# avenida brasil jardim america 01430-000 sao paulo sp
#
# Entities [('rua dr. lucio malta 445', 'LOGRA')]
# rua dr. lucio malta 445 centro 12315-310 jacarei sp
#
# Entities [('av. vinte cinco de agosto 1927', 'LOGRA')]
# av. vinte cinco de agosto 1927 centro 78987-000 rolim de moura ro
#
# Entities [('rua ramiro barcelos 1436', 'LOGRA')]
# rua ramiro barcelos 1436 centro 95780-000 montenegro rs
#
# Entities [('av.cerro cora', 'LOGRA')]
# av.cerro cora vila romana 05061-050 sao paulo sp
#
# Entities [('rua 15 de novembro 339', 'LOGRA')]
# rua 15 de novembro 339 centro 98640-000 crissiumal rs
#
# Entities [('av.bernardo sayao', 'LOGRA')]
# av.bernardo sayao 300 predio centro 77455-000 alianca do tocantins to
#
# Entities [('luiz michielon 1116', 'LOGRA')]
# luiz michielon 1116 cruzeiro 95074-000 caxias do sul rs
#
# Entities [('av.guerino osvaldo 520', 'LOGRA')]
# av.guerino osvaldo 520 centro 13690-000 descalvado sp
#
# Entities [('av francisco bicalho 01', 'LOGRA')]
# av francisco bicalho 01 lj 01s santo cristo 20220-310 rio de janeiro rj
#
# Entities [('av. alberto andal� 3360', 'LOGRA')]
# av. alberto andal� 3360 t�rreo e 1� andar centro 15015-000 sao jose do rio preto sp
#
# Entities [('av.adolfo pinheiro 510', 'LOGRA')]
# av.adolfo pinheiro 510 santo amaro 04734-000 sao paulo sp
#
# Entities [('rua borges lagoa', 'LOGRA')]
# rua borges lagoa 10 andar conj. 101 e 102 vila clementino 04038-032 sao paulo sp
#
# Entities [('av.fernando luzzatto 260', 'LOGRA')]
# av.fernando luzzatto 260 centro 95320-000 nova prata rs
#
# Entities [('r.bernardo sayao 440 rod.br-010', 'LOGRA')]
# r.bernardo sayao 440 rod.br-010 centro 68675-000 mae do rio pa
#
# Entities [('rua capitao jeova collares 101', 'LOGRA')]
# rua capitao jeova collares 101 f/ 3a loja 01 a 06 centro 61942-460 maranguape ce
#
# Entities [('avenida bernardino de campos', 'LOGRA')]
# avenida bernardino de campos paraiso 04004-050 sao paulo sp
#
# Entities [('rua oliveira dos brejinhos 56', 'LOGRA')]
# rua oliveira dos brejinhos 56 centro 46530-000 boquira ba
#
# Entities [('av. dr. jos� monteiro machado c�sar', 'LOGRA')]
# av. dr. jos� monteiro machado c�sar loteamento joao t fernandes 12441-010 pindamonhangaba sp
#
# Entities [('rua visconde do rio branco 337', 'LOGRA')]
# rua visconde do rio branco 337 (parte) centro 12020-040 taubate sp
#
# Entities [('av.cristovao colombo 336', 'LOGRA')]
# av.cristovao colombo 336 funcionarios 30140-150 belo horizonte mg
#
# Entities [('pca.dr.emilio imbassahy 306', 'LOGRA')]
# pca.dr.emilio imbassahy 306 terreo centro 45900-000 caravelas ba
#
# Entities [('av. getulio vargas 2196', 'LOGRA')]
# av. getulio vargas 2196 centro 65903-280 imperatriz ma
#
# Entities [('rua bar�o de jundiai 1 andar', 'LOGRA')]
# rua bar�o de jundiai 1 andar centro 13200-002 jundiai sp
#
# Entities [('avenida soledade 11 andar', 'LOGRA')]
# avenida soledade 11 andar petropolis 90470-340 porto alegre rs
#
# Entities [('praca da republica 1151', 'LOGRA')]
# praca da republica 1151 centro 14200-000 sao simao sp
#
# Entities [('rua coronel batista carneiro', 'LOGRA')]
# rua coronel batista carneiro centro 58280-000 mamanguape pb
#
# Entities [('rua bueno de paiva 408', 'LOGRA')]
# rua bueno de paiva 408 centro 37660-000 paraisopolis mg
#
# Entities [('av.getulio vargas 60', 'LOGRA')]
# av.getulio vargas 60 centro 39827-000 pote mg
#
# Entities [('av. manoel goulart 1349', 'LOGRA')]
# av. manoel goulart 1349 centro 19015-240 presidente prudente sp
#
# Entities [('pca.pe.aleixo monteiro mafra 70/72', 'LOGRA')]
# pca.pe.aleixo monteiro mafra 70/72 sao miguel paulista 08011-010 sao paulo sp
#
# Entities [('rua barao do rio branco 401', 'LOGRA')]
# rua barao do rio branco 401 centro 19010-000 presidente prudente sp
#
# Entities [('tv manoel paiva da mota', 'LOGRA')]
# tv manoel paiva da mota centro 68690-000 acara pa
#
# Entities [('rua leonardo malcher 1862', 'LOGRA')]
# rua leonardo malcher 1862 centro 69015-000 manaus am
#
# Entities [('trv constantino nery s/', 'LOGRA')]
# trv constantino nery s/n centro 69200-000 borba am
#
# Entities [('av.olavo bilac 293', 'LOGRA')]
# av.olavo bilac 293 centro 15895-000 cedral sp
#
# Entities [('praca rui barbosa 220', 'LOGRA')]
# praca rui barbosa 220 dt05/10-a - sede centro 86800-700 apucarana pr
#
# Entities [('av.duque de caxias 527', 'LOGRA')]
# av.duque de caxias 527 centro 95750-000 salvador do sul rs
#
# Entities [('av. parada pinto 100', 'LOGRA')]
# av. parada pinto 100 v.nova cachoeirinha 02611-002 sao paulo sp
#
# Entities [('avenida costa e silva 393-a', 'LOGRA')]
# avenida costa e silva 393-a cachoeirinha 69065-080 manaus am
#
# Entities [('rua massanore nag�o 150', 'LOGRA')]
# rua massanore nag�o 150 centro 45995-021 teixeira de freitas ba
#
# Entities [('rua pres.vargas 578', 'LOGRA')]
# rua pres.vargas 578 centro 17690-000 bastos sp
#
# Entities [('av.bandeirantes vila pinheiro 13845-440 mogi-guacu sp', 'LOGRA')]
# av.bandeirantes vila pinheiro 13845-440 mogi-guacu sp
#
# Entities [('avenida wladimir meirelles ferreira loja 20', 'LOGRA')]
# avenida wladimir meirelles ferreira loja 20 jardim botanico 14021-630 ribeirao preto sp
#
# Entities [('avenida maria quiteria n� 1396', 'LOGRA')]
# avenida maria quiteria n� 1396 parte queimadinha 44050-228 feira de santana ba
#
# Entities [('av.sao joao 32', 'LOGRA')]
# av.sao joao 32 6.andar centro 01036-900 sao paulo sp
#
# Entities [('rua nove de julho', 'LOGRA')]
# rua nove de julho centro 14840-000 guariba sp
#
# Entities [('r.iguatemi 472', 'LOGRA')]
# r.iguatemi 472 centro 78350-000 brasnorte mt
#
# Entities [('pca.d.pedro segundo 180', 'LOGRA')]
# pca.d.pedro segundo 180 centro 37235-000 coqueiral mg
#
# Entities [('avenida ayrton senna n � 2150', 'LOGRA')]
# avenida ayrton senna n � 2150 bloco a lojas b.c.d.e - parte barra da tijuca 22775-900 rio de janeiro rj
#
# Entities [('av.batel 1095', 'LOGRA')]
# av.batel 1095 batel 80420-090 curitiba pr
#
# Entities []
#  area especial 2 setor sul 72405-610 brasilia (gama) df
# Entities [('avenida rep�blica do l�', 'LOGRA')]
# avenida rep�blica do l�bano salas 1705 e 1706 torre c pina 51110-160 recife pe
#
# Entities [('av. assis chateaubriand 264', 'LOGRA')]
# av. assis chateaubriand 264 floresta 30150-100 belo horizonte mg
#
# Entities [('rua alcebiades menezes 679', 'LOGRA')]
# rua alcebiades menezes 679 centro 15420-000 guaraci sp
#
# Entities [('av. brig. faria lima 2491', 'LOGRA')]
# av. brig. faria lima 2491 j paulistano 01452-000 sao paulo sp
#
# Entities [('rua dom pedro ii 109', 'LOGRA')]
# rua dom pedro ii 109 loja centro 36345-000 lagoa dourada mg
#
# Entities [('pra�a tiradentes 3', 'LOGRA')]
# pra�a tiradentes 3 centro 36400-000 conselheiro lafaiete mg
#
# Entities [('r dr ramiro de araujo filho 490', 'LOGRA')]
# r dr ramiro de araujo filho 490 vila formosa 13214-300 jundiai sp
#
# Entities [('av.getulio vargas 693', 'LOGRA')]
# av.getulio vargas 693 centro 29240-000 alfredo chaves es
#
# Entities [('av agua fria 1105', 'LOGRA')]
# av agua fria 1105 agua fria 02333-001 sao paulo sp
#
# Entities [('pca. gago coutinho s/', 'LOGRA')]
# pca. gago coutinho s/n aerop.luis e magalhaes lj.46 ter. sao cristovao 41510-045 salvador ba
#
# Entities [('pca.joao pessoa 39', 'LOGRA')]
# pca.joao pessoa 39 centro 55330-000 bom conselho pe
#
# Entities [('rua jo�o da cruz praia', 'LOGRA')]
# rua jo�o da cruz praia do canto 29055-620 vitoria es
#
# Entities [('av. presidente getulio vargas n. 216', 'LOGRA')]
# av. presidente getulio vargas n. 216 centro 29390-000 iuna es
#
# Entities [('avenida marechal c�mara 160 - loja e', 'LOGRA')]
# avenida marechal c�mara 160 - loja e centro 20020-080 rio de janeiro rj
#
# Entities [('rua felipe kops', 'LOGRA')]
# rua felipe kops centro centro 99725-000 tres arroios rs
#
# Entities [('r.jose mendonca 202', 'LOGRA')]
# r.jose mendonca 202 centro 88740-000 armazem sc
#
# Entities [('avenida manoel guirado segura 902', 'LOGRA')]
# avenida manoel guirado segura 902 quadra 38 lote 15 centro 19280-000 teodoro sampaio sp
#
# Entities [('av. santo amaro 7237', 'LOGRA')]
# av. santo amaro 7237 sto. amaro 47010-000 sao paulo sp
#
# Entities [('tv.boa ventura 26/b', 'LOGRA')]
# tv.boa ventura 26/b praia grande 65010-090 sao luis ma
#
# Entities [('pca jauru', 'LOGRA')]
# pca jauru taquara 22725-520 rio de janeiro rj
#
# Entities [('praca santa rita 41', 'LOGRA')]
# praca santa rita 41 centro 37540-000 santa rita do sapucai mg
#
# Entities [('saf sul qd.8 lote 1 bloco a', 'LOGRA')]
# saf sul qd.8 lote 1 bloco a mezanino ed.tst setor adm.federal sul 70070-600 brasilia df
#
# Entities [('av. salvador furtado 13', 'LOGRA')]
# av. salvador furtado 13 centro 35420-000 mariana mg
#
# Entities [('av.nova cantareira 317', 'LOGRA')]
# av.nova cantareira 317 agua fria 02331-000 sao paulo sp
#
# Entities [('avenida frei cirilo', 'LOGRA')]
# avenida frei cirilo lojas 39 40 e 41 b - pavimento terreo messejana 60840-285 fortaleza ce
#
# Entities [('av. olegario maciel 591', 'LOGRA')]
# av. olegario maciel 591 centro 30180-110 belo horizonte mg
#
# Entities [('r.ten.dantas 33', 'LOGRA')]
# r.ten.dantas 33 casa centro 55480-000 jurema pe
#
# Entities [('r.santos dumont 475', 'LOGRA')]
# r.santos dumont 475 centro 19700-000 paraguacu paulista sp
#
# Entities [('av.jeronimo de albuquerque 34', 'LOGRA')]
# av.jeronimo de albuquerque 34 cohab-anil 65051-210 sao luis ma
#
# Entities [('pca.jose dantas farias s/n', 'LOGRA')]
# pca.jose dantas farias s/n. centro 45590-000 dario meira ba
#
# Entities [('av.cruz das armas 949', 'LOGRA')]
# av.cruz das armas 949 cruz das armas 58085-000 joao pessoa pb
#
# Entities [('av. presidente vargas', 'LOGRA')]
# av. presidente vargas centro 68900-070 macapa ap
#
# Entities [('av. n. sra. do rocio 145', 'LOGRA')]
# av. n. sra. do rocio 145 centro 86340-000 sertaneja pr
#
# Entities [('avenida presidente', 'LOGRA')]
# avenida presidente juscelino kubitschek 11 andar edificio wtorre plaza jk torre d vila nova concei��o 04543-011 sao paulo sp
#
# Entities [('r clodomiro amazonas', 'LOGRA')]
# r clodomiro amazonas itaim bibi 04537-012 sao paulo sp
#
# Entities [('praca panamericana 100', 'LOGRA')]
# praca panamericana 100 alto de pinheiro 05461-000 sao paulo sp
#
# Entities [('avenida bady bassit', 'LOGRA')]
# avenida bady bassit centro 15015-700 sao jose do rio preto sp
#
# Entities [('rua bocaiuva 1973', 'LOGRA')]
# rua bocaiuva 1973 esq. c/ rua abilio oliveira 41 centro 88015-530 florianopolis sc
#
# Entities [('av independencia', 'LOGRA')]
# av independencia qd 67a lt setor aeroporto 74070-010 goiania go
#
# Entities [('rua dorgival pinheiro de souza 1140', 'LOGRA')]
# rua dorgival pinheiro de souza 1140 centro 65926-000 acailandia ma
#
# Entities [('av.graca aranha 1', 'LOGRA')]
# av.graca aranha 1 terreo interior do predio da firjan centro 20030-002 rio de janeiro rj
#
# Entities [('rua doutor jose paulo 111 e 111 a', 'LOGRA')]
# rua doutor jose paulo 111 e 111 a chac. seis de outubro 03509-040 sao paulo sp
#
# Entities [('pca.mons.zacarias luz s/', 'LOGRA')]
# pca.mons.zacarias luz s/n predio centro 48370-000 esplanada ba
#
# Entities [('av. deputado emilio carlos 3902', 'LOGRA')]
# av. deputado emilio carlos 3902 vl nova cachoeirinha 27200-000 sao paulo sp
#
# Entities [('av.manoel dias da silva 1121', 'LOGRA')]
# av.manoel dias da silva 1121 pituba 41830-000 salvador ba
#
# Entities [('praca beraldo arruda 82', 'LOGRA')]
# praca beraldo arruda 82 centro 16500-000 cafelandia sp
#
# Entities [('av sao luis rei de franca', 'LOGRA')]
# av sao luis rei de franca jardim eldorado 65067-205 sao luis ma
#
# Entities [('rua dr. santos 103', 'LOGRA')]
# rua dr. santos 103 360305 centro 39400-001 montes claros mg
#
# Entities [('av.gal.rodrigo otavio 3000', 'LOGRA')]
# av.gal.rodrigo otavio 3000 ufam-centro de convivencia japiim 69077-000 manaus am
#
# Entities [('av. jose conrado de araujo 202', 'LOGRA')]
# av. jose conrado de araujo 202 centro 49900-000 propria se
#
# Entities []
#  r joao de souza 34 centro 45530-000 itacare ba
#
# Entities [('pca.joao pinheiro 8', 'LOGRA')]
# pca.joao pinheiro 8 predio centro 35200-000 aimores mg
#
# Entities [('rua nossa sra imaculada', 'LOGRA')]
# rua nossa sra imaculada concei��o 110 km 18 06190-100 osasco sp
#
# Entities [('rua prudente de morais', 'LOGRA')]
# rua prudente de morais abadia 38026-250 uberaba mg
#
# Entities [('pra�a s�o sebasti�o 148', 'LOGRA')]
# pra�a s�o sebasti�o 148 centro 76335-000 uruana go
#
# Entities [('av. solar 31', 'LOGRA')]
# av. solar 31 set.urias magalhaes 74565-630 goiania go
#
# Entities [('av. anita garibaldi 325', 'LOGRA')]
# av. anita garibaldi 325 centro 89770-000 seara sc
#
# Entities [('av.com.alberto bonfiglioli 658/670', 'LOGRA')]
# av.com.alberto bonfiglioli 658/670 jd.bonfiglioli 05593-001 sao paulo sp
#
# Entities [('av.carlos gomes 741/757', 'LOGRA')]
# av.carlos gomes 741/757 conjunto 2 caiari 78900-030 porto velho ro
#
# Entities [('av nossa senhora de copacabana n� 542', 'LOGRA')]
# av nossa senhora de copacabana n� 542 lojas a/b - parte copacabana 22020-001 rio de janeiro rj
#
# Entities [('av desemb hugo simas 377', 'LOGRA')]
# av desemb hugo simas 377 bom retiro 80520-250 curitiba pr
#
# Entities [('r.prof.agnaldo viana pereira 52', 'LOGRA')]
# r.prof.agnaldo viana pereira 52 proximo ao forum centro 44350-000 governador mangabeira ba
#
# Entities [('praca duque de caxias 19', 'LOGRA')]
# praca duque de caxias 19 centro 18310-000 guapiara sp
#
# Entities [('rua boqueirao esq.c/rua major sezefredo s/n', 'LOGRA')]
# rua boqueirao esq.c/rua major sezefredo s/n. igara 92410-350 canoas rs
#
# Entities [('scs quadra 2', 'LOGRA')]
# scs quadra 2 blocob n.81 60746948 asa sul 70329-900 brasilia df
#
# Entities [('estrada dos bandeirantes 1430', 'LOGRA')]
# estrada dos bandeirantes 1430 lojas u v e x taquara 22710-113 rio de janeiro rj
#
# Entities [('r.sen.pinheiro machado 2146', 'LOGRA')]
# r.sen.pinheiro machado 2146 centro 85010-100 guarapuava pr
#
# Entities [('r.primeiro de marco 254 predio', 'LOGRA')]
# r.primeiro de marco 254 predio centro 35195-000 belo oriente mg
#
# Entities [('rua dr.julio siqueira maia q 80 - lotes 07 e 08', 'LOGRA')]
# rua dr.julio siqueira maia q 80 - lotes 07 e 08 centro 79130-000 rio brilhante ms
#
# Entities [('rua quatro de junho 414', 'LOGRA')]
# rua quatro de junho 414 centro 18260-000 porangaba sp
#
# Entities [('rua quinze de novembro', 'LOGRA')]
# rua quinze de novembro centro 85010-000 guarapuava pr
#
# Entities [('avenida dr. belmiro correia 504', 'LOGRA')]
# avenida dr. belmiro correia 504 novo do carmelo 54759-000 camaragibe pe
#
# Entities [('avenida rio branco 2 andar', 'LOGRA')]
# avenida rio branco 2 andar centro 20040-922 rio de janeiro rj
#
# Entities [('r.cel.fontenele de castro 170', 'LOGRA')]
# r.cel.fontenele de castro 170 em frente a pca.do seringueiro centro 69928-000 placido de castro ac
#
# Entities [('av. expedito garcia 32', 'LOGRA')]
# av. expedito garcia 32 campo grande 29146-200 cariacica es
#
# Entities [('av. goias 743', 'LOGRA')]
# av. goias 743 centro 75800-012 jatai go
#
# Entities [('rua joao felipe calmon 637', 'LOGRA')]
# rua joao felipe calmon 637 loja 2 centro 29900-010 linhares es
#
# Entities [('av. jo�o paulo ii 1344', 'LOGRA')]
# av. jo�o paulo ii 1344 vila regina 06813-265 embu das artes sp
#
# Entities [('rua voluntarios da patria 371-a', 'LOGRA')]
# rua voluntarios da patria 371-a botafogo 22270-000 rio de janeiro rj
#
# Entities [('rua campos salles', 'LOGRA')]
# rua campos salles centro 13230-005 campo limpo paulista sp
#
# Entities [('rua cel passos maia 405', 'LOGRA')]
# rua cel passos maia 405 centro 89820-000 xanxere sc
#
# Entities [('r.cel.francisco antonio 95', 'LOGRA')]
# r.cel.francisco antonio 95 centro 58600-000 santa luzia pb
#
# Entities [('av. sapopemba 8110/8111', 'LOGRA')]
# av. sapopemba 8110/8111 jardim planalto 03988-000 sao paulo sp
#
# Entities [('avenida ataulfo de paiva', 'LOGRA')]
# avenida ataulfo de paiva parte leblon 22440-034 rio de janeiro rj
#
# Entities [('r.dr.campos salles 164', 'LOGRA')]
# r.dr.campos salles 164 centro 13960-000 socorro sp
#
# Entities [('rua carlos gomes 31', 'LOGRA')]
# rua carlos gomes 31 centro 89160-000 rio do sul sc
#
# Entities [('estrada itaquera-guaianazes 2128', 'LOGRA')]
# estrada itaquera-guaianazes 2128 jardim helena 08420-000 sao paulo sp
#
# Entities [('av. joao pessoa 1318', 'LOGRA')]
# av. joao pessoa 1318 azenha 90040-001 porto alegre rs
#
# Entities [('av das nuvens 1andar', 'LOGRA')]
# av das nuvens 1andar aldeia da serra 06519-225 santana de parnaiba sp
#
# Entities [('rua jose bonifacio', 'LOGRA')]
# rua jose bonifacio centro 14240-000 cajuru sp
#
# Entities [('rua dos andradas', 'LOGRA')]
# rua dos andradas centro 97573-531 santana do livramento rs
#
# Entities [('rua marechal deodoro', 'LOGRA')]
# rua marechal deodoro centro 88200-000 tijucas sc
#
# Entities [('av. henry wall de carvalho', 'LOGRA')]
# av. henry wall de carvalho num 6121 lorival parente 64022-135 teresina pi
#
# Entities [('r.cardoso de almeida 299', 'LOGRA')]
# r.cardoso de almeida 299 perdizes 05013-000 sao paulo sp
#
# Entities [('av.julio da castilhos 301', 'LOGRA')]
# av.julio da castilhos 301 centro 97200-000 restinga seca rs
#
# Entities [('rua tuiuti 2208', 'LOGRA')]
# rua tuiuti 2208 conjunto 2 tatuape 03307-000 sao paulo sp
#
# Entities [('avenida julio de castilhos num 365', 'LOGRA')]
# avenida julio de castilhos num 365 centro 97200-000 restinga seca rs
# Entities [('praca da graca 340', 'LOGRA')]
# praca da graca 340 centro 64200-906 parnaiba pi
#
# Entities [('av. bar�o de itapura 2.145', 'LOGRA')]
# av. bar�o de itapura 2.145 jardim guanabara 13073-300 campinas sp
#
# Entities [('rua mmdc 569', 'LOGRA')]
# rua mmdc 569 paulic�ia 09690-000 sao bernardo do campo sp
#
# Entities [('r 13 de junho 168', 'LOGRA')]
# r 13 de junho 168 centro 79380-000 miranda ms
#
# Entities [('av. coracao eucaristico de jesus 317', 'LOGRA')]
# av. coracao eucaristico de jesus 317 coracao eucaristico de jesus 30535-460 belo horizonte mg
#
# Entities [('av.jose mol 216', 'LOGRA')]
# av.jose mol 216 terreo centro 35290-000 mantena mg
#
# Entities [('rua clemente �lvares 351', 'LOGRA')]
# rua clemente �lvares 351 centro 05074-050 sao paulo sp
#
# Entities [('praca barao do rio branco 1', 'LOGRA')]
# praca barao do rio branco 1 centro 48903-400 juazeiro ba
#
# Entities [('rua monsenhor rosa 1685', 'LOGRA')]
# rua monsenhor rosa 1685 1 andar centro 14400-670 franca sp
#
# Entities [('pca.domingos cabral 16', 'LOGRA')]
# pca.domingos cabral 16 casa centro 45615-000 buerarema ba
#
# Entities [('pca.miguel baracho 120', 'LOGRA')]
# pca.miguel baracho 120 centro 45680-000 urucuca ba
#
# Entities [('avenida plaza', 'LOGRA')]
# avenida plaza jardim paraiso 13302-100 itu sp
#
# Entities [('rua prof. marli carvalho pereira', 'LOGRA')]
# rua prof. marli carvalho pereira 2e praca miguel couto 10-ap 106 e 107-qd1a miguel couto 26150-560 nova iguacu rj
#
# Entities [('praca da matriz 233', 'LOGRA')]
# praca da matriz 233 centro 48860-000 queimadas ba
#
# Entities [('av. concordia 1039', 'LOGRA')]
# av. concordia 1039 centro 96540-000 agudo rs
#
# Entities [('rua antonio dias adorno 873 883 887', 'LOGRA')]
# rua antonio dias adorno 873 883 887 vila nogueira 09951-000 diadema sp
#
# Entities [('av. barao de maruim 135', 'LOGRA')]
# av. barao de maruim 135 centro 49010-340 aracaju se
#
# Entities [('av. 25 de julho', 'LOGRA')]
# av. 25 de julho 93950-000 dois irmaos rs
#
# Entities [('avenida gurgel do amaral', 'LOGRA')]
# avenida gurgel do amaral coa�u 60871-170 fortaleza ce
#
# Entities [('rua almirante gon�alves 35', 'LOGRA')]
# rua almirante gon�alves 35 a sala 201 copacabana 24466-315 rio de janeiro rj
#
# Entities [('av. brasil 455', 'LOGRA')]
# av. brasil 455 centro 86280-000 urai pr
#
# Entities [('r.cel.verissimo 1085', 'LOGRA')]
# r.cel.verissimo 1085 centro 97340-000 sao sepe rs
#
# Entities [('av. janio quadros 480', 'LOGRA')]
# av. janio quadros 480 centro 13190-000 monte mor sp
#
# Entities [('cng 4 lotes 17/18', 'LOGRA')]
# cng 4 lotes 17/18 taguatinga norte 72130-045 brasilia (taguatinga) df
#
# Entities [('av. gov. julio campos 1377', 'LOGRA')]
# av. gov. julio campos 1377 esq.c/r.das azaleias centro 78550-202 sinop mt
#
# Entities [('av joao ramalho s/n', 'LOGRA')]
# av joao ramalho s/n jardim monte castelo 17522-363 marilia sp
#
# Entities [('av. dr. joao vargens', 'LOGRA')]
# av. dr. joao vargens centro 45880-000 camacan ba
#
# Entities [('av prof carvalho pinto 180', 'LOGRA')]
# av prof carvalho pinto 180 regi�o central 07700-210 caieiras sp
#
# Entities [('av. diogo garcia carmona 941', 'LOGRA')]
# av. diogo garcia carmona 941 centro 15300-000 general salgado sp
#
# Entities [('r.gov.brasil caiado 817', 'LOGRA')]
# r.gov.brasil caiado 817 centro 77780-000 arapoema to
#
# Entities [('r. fulvio aducci 1229', 'LOGRA')]
# r. fulvio aducci 1229 loja 1 estreito 88075-001 florianopolis sc
#
# Entities [('rua bernardino de campos 2858', 'LOGRA')]
# rua bernardino de campos 2858 centro 15015-300 sao jose do rio preto sp
#
# Entities [('av. presidente vargas 383', 'LOGRA')]
# av. presidente vargas 383 centro 66010-000 belem pa
#
# Entities [('rua bento goncalves', 'LOGRA')]
# rua bento goncalves centro 93510-001 novo hamburgo rs
#
# Entities [('av.quinze de novembro 909', 'LOGRA')]
# av.quinze de novembro 909 centro 99490-000 tapera rs
#
# Entities [('av.saul elkind 1442', 'LOGRA')]
# av.saul elkind 1442 conj.hab.violim 86084-000 londrina pr
#
# Entities [('rua do fico 410', 'LOGRA')]
# rua do fico 410 sao joaquim 16050-387 aracatuba sp
#
# Entities [('rua barroso 101', 'LOGRA')]
# rua barroso 101 360305 centro 69007-000 manaus am
#
# Entities [('rua antonio de barros 356', 'LOGRA')]
# rua antonio de barros 356 tatuape 03089-000 sao paulo sp
#
# Entities [('av. presidente tancredo a. neves n� 976', 'LOGRA')]
# av. presidente tancredo a. neves n� 976 parte vila pires 06730-000 vargem grande paulista sp
#
# Entities [('avenida nove de julho 3186', 'LOGRA')]
# avenida nove de julho 3186 jardim paulista 01406-000 sao paulo sp
#
# Entities [('av oscar cardoso', 'LOGRA')]
# av oscar cardoso centro 45960-000 medeiros neto ba
#
# Entities [('rua dr. joao colin 259', 'LOGRA')]
# rua dr. joao colin 259 centro 89201-300 joinville sc
#
# Entities [('shc sw clsw bloco a - lj 5 a 7 e 14 a 16', 'LOGRA')]
# shc sw clsw bloco a - lj 5 a 7 e 14 a 16 setor sudoeste 70670-431 brasilia df
#
# Entities [('avenida doutor chucri zaidan', 'LOGRA')]
# avenida doutor chucri zaidan ed. golden tower - 17� andar chac. santo antonio 04711-130 sao paulo sp
#
# Entities [('av.vinte e nove de novembro 510', 'LOGRA')]
# av.vinte e nove de novembro 510 centro 87260-000 araruna pr
#
# Entities [('av.isabelita vieira 34', 'LOGRA')]
# ...
# av goncalo botelho de campos 2478 c rei 78118-071 varzea grande mt
#
# Entities [('alameda bahia 15', 'LOGRA')]
# alameda bahia 15 centro 15385-000 ilha solteira sp
#
# Entities [('rua quinze de novembro s/n', 'LOGRA')]
# rua quinze de novembro s/n. esq.c/rua gomes porto centro 25804-000 tres rios rj
#
# Entities [('dr hugo santos silva 887', 'LOGRA')]
# dr hugo santos silva 887 lt 11 vila agao 11250-000 bertioga sp
#
# Entities [('travessa jose do faro 15', 'LOGRA')]
# travessa jose do faro 15 centro 49010-120 aracaju se
#
# Entities [('avenida 85 quadra 221', 'LOGRA')]
# avenida 85 quadra 221 lote 19 setor marista 74160-010 goiania go
#
# Entities [('pca.tonico rabelo 181', 'LOGRA')]
# pca.tonico rabelo 181 centro 35582-000 pains mg
#
# Entities [('r.general glicerio 419', 'LOGRA')]
# r.general glicerio 419 terreo centro 09015-190 santo andre sp
#
# Entities [('rua goes calmom 251', 'LOGRA')]
# rua goes calmom 251 centro 44550-000 sao felipe ba
#
# Entities [('avenida jeronimo monteiro n� 52', 'LOGRA')]
# avenida jeronimo monteiro n� 52 centro 29450-970 apiaca es
#
# Entities [('r.vinte e um de abril 140', 'LOGRA')]
# r.vinte e um de abril 140 centro 16400-030 lins sp
#
# Entities [('largo do cambuci', 'LOGRA')]
# largo do cambuci cambuci 01523-010 sao paulo sp
#
# Entities [('rua monsenhor soares 263', 'LOGRA')]
# rua monsenhor soares 263 centro 18200-009 itapetininga sp
#
# Entities [('rua santo antonio', 'LOGRA')]
# rua santo antonio centro 95500-000 santo antonio da patrulha rs
#
# Entities [('r.dr.paulo ramos 572', 'LOGRA')]
# r.dr.paulo ramos 572 terreo centro 65760-000 presidente dutra ma
#
# Entities [('rua italina pereira motta 280', 'LOGRA')]
# rua italina pereira motta 280 jardim camburi 29090-370 vitoria es
#
# Entities [('rua carlos gomes', 'LOGRA')]
# rua carlos gomes auxiliadora 90480-003 porto alegre rs
#
# Entities [('rua conde de linhares', 'LOGRA')]
# rua conde de linhares cidade jardim 30380-030 belo horizonte mg
#
# Entities [('rua goias 358', 'LOGRA')]
# rua goias 358 centro 18570-000 conchas sp
#
# Entities [('r.uruguai 185 13.andar', 'LOGRA')]
# r.uruguai 185 13.andar centro 90010-901 porto alegre rs
#
# Entities [('rua antonio lapa', 'LOGRA')]
# rua antonio lapa condom�nio edif�cio wall street salas 904 e 905 cambu� 13025-240 campinas sp
#
# Entities [('travessa franscisco leonardo truda 40', 'LOGRA')]
# travessa franscisco leonardo truda 40 1� andar centro 90010-904 porto alegre rs
#
# Entities [('avenida conde da boa vista', 'LOGRA')]
# avenida conde da boa vista boa vista 50060-004 recife pe
#
# Entities [('rua padre albuquerque 54', 'LOGRA')]
# rua padre albuquerque 54 centro 18200-220 itapetininga sp
#
# Entities [('av. nove de julho 31', 'LOGRA')]
# av. nove de julho 31 centro 11920-000 iguape sp
#
# Entities [('avenida get�lio vargas n�. 1530', 'LOGRA')]
# avenida get�lio vargas n�. 1530 bairro novo 53030-905 olinda pe
#
# Entities [('rua valdemir leite soares 175', 'LOGRA')]
# rua valdemir leite soares 175 centro 56780-000 tabira pe
#
# Entities [('avenida tucuruvi', 'LOGRA')]
# avenida tucuruvi tucuruvi 02305-001 sao paulo sp
#
# Entities [('avenida bela aurora 5', 'LOGRA')]
# avenida bela aurora 5 centro 55400-000 catende pe
#
# Entities [('av. afonso pena', 'LOGRA')]
# av. afonso pena centro 95300-000 lagoa vermelha rs
#
# Entities [('rua cearense', 'LOGRA')]
# rua cearense centro 68860-000 salvaterra pa
#
# Entities [('av. afonso pena 611', 'LOGRA')]
# av. afonso pena 611 parte tirol 59020-100 natal rn
#
# Entities [('av. maria amalia lopes de azevedo 807', 'LOGRA')]
# av. maria amalia lopes de azevedo 807 vila albertina 02350-001 sao paulo sp
#
# Entities [('av. candido de abreu 427', 'LOGRA')]
# av. candido de abreu 427 centro 80530-000 curitiba pr
#
# Entities [('rua moreira cesar 1407', 'LOGRA')]
# rua moreira cesar 1407 pio x 94034-000 caxias do sul rs
#
# Entities [('rua dois de maio 715', 'LOGRA')]
# rua dois de maio 715 jacare 20961-160 rio de janeiro rj
#
# Entities [('av dom', 'LOGRA')]
# av dom lino centro 62900-000 russas ce
#
# Entities [('av.cel.lindolfo alves dias 723', 'LOGRA')]
# av.cel.lindolfo alves dias 723 centro 75850-000 caiaponia go
#
# Entities [('av. ant�nio pedro da silva 816', 'LOGRA')]
# av. ant�nio pedro da silva 816 centro 56200-000 ouricuri pe
#
# Entities [('av.nove de julho 1077', 'LOGRA')]
# av.nove de julho 1077 higienopolis 14015-170 ribeirao preto sp
# Entities [('av pires do rio', 'LOGRA')]
# av pires do rio jardim norma 08240-005 sao paulo sp
#
# Entities [('rua paulo do vale 55', 'LOGRA')]
# rua paulo do vale 55 centro 06804-010 embu das artes sp
#
# Entities [('av. rio branco 181-a', 'LOGRA')]
# av. rio branco 181-a centro 20040-000 rio de janeiro rj
#
# Entities [('rua paulo marques 434', 'LOGRA')]
# rua paulo marques 434 centro 62370-000 sao benedito ce
#
# Entities [('av.amaral peixoto 2', 'LOGRA')]
# av.amaral peixoto 2 centro 28380-000 natividade rj
#
# Entities [('rua nove de julho 947', 'LOGRA')]
# rua nove de julho 947 centro 15400-000 olimpia sp
#
# Entities [('av. bernardo sayao 1325', 'LOGRA')]
# av. bernardo sayao 1325 n. imperatriz 65907-000 imperatriz ma
#
# Entities [('av.noel nutels 1436', 'LOGRA')]
# av.noel nutels 1436 bloco 6 loja 1-a cidade nova i 69093-770 manaus am
#
# Entities [('rua miguel de carvalho 159', 'LOGRA')]
# rua miguel de carvalho 159 centro 28660-000 bom jardim rj
#
# Entities [('pca.juracy magalhaes 21', 'LOGRA')]
# pca.juracy magalhaes 21 centro 45280-000 iguai ba
#
# Entities [('av 401 sul avenida joaquim teotonio', 'LOGRA')]
# av 401 sul avenida joaquim teotonio segu plano diretor sul 77015-380 palmas to
#
# Entities [('r voluntarios da patria santana', 'LOGRA')]
# r voluntarios da patria santana 02010-400 sao paulo sp
#
# Entities [('av.mamore 2915', 'LOGRA')]
# av.mamore 2915 esq.com r.america do norte tres marias 76812-695 porto velho ro
#
# Entities [('rua joaquim floriano 413', 'LOGRA')]
# rua joaquim floriano 413 13� andar itaim bibi 04534-011 sao paulo sp
#
# Entities [('av.weimar goncalves torres 2965', 'LOGRA')]
# av.weimar goncalves torres 2965 1.andar - sala exclusivo centro 79800-025 dourados ms
#
# Entities [('av. nossa senhora medianeira 1844', 'LOGRA')]
# av. nossa senhora medianeira 1844 loja 101 centro 97060-002 santa maria rs
#
# Entities [('rua coronel augusto l.medrado 8', 'LOGRA')]
# rua coronel augusto l.medrado 8 centro 46760-000 ibicoara ba
#
# Entities [('rua joaquim rodrigues nogueira', 'LOGRA')]
# rua joaquim rodrigues nogueira centro 56280-000 araripina pe
#
# Entities [('av. das americas', 'LOGRA')]
# av. das americas lojas 104 e 105 barra da tijuca 22790-703 rio de janeiro rj
#
# Entities [('rua dr. carlos de campos 343', 'LOGRA')]
# rua dr. carlos de campos 343 americanopolis 03028-001 sao paulo sp
#
# Entities [('av. graca aranha 296-a', 'LOGRA')]
# av. graca aranha 296-a centro 20030-001 rio de janeiro rj
#
# Entities [('rua amador bueno 69', 'LOGRA')]
# rua amador bueno 69 centro 11013-151 santos sp
#
# Entities [('av.brigadeiro faria lima 2157', 'LOGRA')]
# av.brigadeiro faria lima 2157 3 andar jd.paulistano 01452-000 sao paulo sp
#
# Entities [('av. cuiaba 857', 'LOGRA')]
# av. cuiaba 857 60746948 centro 78700-090 rondonopolis mt
#
# Entities [('r.dr.ovidio pires de campos 225', 'LOGRA')]
# r.dr.ovidio pires de campos 225 cerqueira cesar 05403-905 sao paulo sp
#
# Entities [('av.bom clima', 'LOGRA')]
# av.bom clima bom clima 07196-220 guarulhos sp
#
# Entities [('avenida presidente antonio carlos 7716', 'LOGRA')]
# avenida presidente antonio carlos 7716 sao luiz 31270-000 belo horizonte mg
#
# Entities [('rua sebastiao jose rodrigues campos el', 'LOGRA')]
# rua sebastiao jose rodrigues campos el�seos 27542-060 resende rj
#
# Entities [('praca da republica 93', 'LOGRA')]
# praca da republica 93 centro 15800-105 catanduva sp
#
# Entities [('av. mal. rondon 101', 'LOGRA')]
# av. mal. rondon 101 lt 7 qd 23 centro 06093-020 osasco sp
#
# Entities [('avenida pedro taques', 'LOGRA')]
# avenida pedro taques 5� andar - sala 503 zona 10 87030-008 maringa pr
#
# Entities [('rua marechal floriano 28', 'LOGRA')]
# rua marechal floriano 28 porto novo 36660-000 alem paraiba mg
#
# Entities [('r.conselheiro franco 418', 'LOGRA')]
# r.conselheiro franco 418 centro 44002-272 feira de santana ba
#
# Entities [('av presidente vargas', 'LOGRA')]
# av presidente vargas centro 54515-070 cabo de santo agostinho pe
#
# Entities [('av. engenheiro luis carlos berrini 1645', 'LOGRA')]
# av. engenheiro luis carlos berrini 1645 cidade moncoes 04571-011 sao paulo sp
#
# Entities [('praca epitacio pessoa 108', 'LOGRA')]
# praca epitacio pessoa 108 centro 13730-037 mococa sp
#
# Entities [('avenida dezessete de agosto', 'LOGRA')]
# avenida dezessete de agosto parnamirim 52060-590 recife pe
#
# Entities [('rua major braga 731', 'LOGRA')]
# rua major braga 731 centro 13860-000 aguai sp
#
# Entities [('av.itapemirim 816', 'LOGRA')]
# av.itapemirim 816 itaipava 29338-000 itapemirim es
#
# Entities [('qnn 17 conjunto d lotes 2 e 4', 'LOGRA')]
# qnn 17 conjunto d lotes 2 e 4 ceilandia norte 72225-170 brasilia (ceilandia) df
#
# Entities [('avenida das am�ricas', 'LOGRA')]
# avenida das am�ricas bloco 2 lojas a/b salas 302 a 305 barra da tijuca 22640-102 rio de janeiro rj
#
# Entities [('avenida augusto de lima 744', 'LOGRA')]
# avenida augusto de lima 744 centro 30190-922 belo horizonte mg
#
# Entities [('av. santos dumont 230/r juazeiro do n. 185', 'LOGRA')]
# av. santos dumont 230/r juazeiro do n. 185 r carir jardim cumbica 72200-000 guarulhos sp
#
# Entities [('r.sto.antonio 732', 'LOGRA')]
# r.sto.antonio 732 centro 13400-315 piracicaba sp
#
# Entities [('avenida 2 de julho 478', 'LOGRA')]
# avenida 2 de julho 478 centro 45980-000 prado ba
#
# Entities [('rua daltro filho 458', 'LOGRA')]
# rua daltro filho 458 centro 98600-000 tres passos rs
#
# Entities [('rua castelo branco 215', 'LOGRA')]
# rua castelo branco 215 centro 78260-000 araputanga mt
#
# Entities [('rua moreira cesar', 'LOGRA')]
# rua moreira cesar centro 95034-000 caxias do sul rs
#
# Entities [('av. dom manuel s/n', 'LOGRA')]
# av. dom manuel s/n quadra 19 - lote 18 rodoviario 74430-180 goiania go
#
# Entities [('avenida andr� ara�jo n� 39', 'LOGRA')]
# avenida andr� ara�jo n� 39 aleixo 69060-000 manaus am
#
# Entities [('rua bispo dom jose conjunto 601', 'LOGRA')]
# rua bispo dom jose conjunto 601 centro 80440-080 curitiba pr
#
# Entities [('rua cel. jose teodoro 251', 'LOGRA')]
# rua cel. jose teodoro 251 centro 14680-000 jardinopolis sp
#
# Entities [('av pedro ludovico 2635 - qd 33 lt 24', 'LOGRA')]
# av pedro ludovico 2635 - qd 33 lt 24 setor araguaia 76240-000 aragarcas go
#
# Entities [('av.manoel dias da silva', 'LOGRA')]
# av.manoel dias da silva pituba 41830-001 salvador ba
#
# Entities [('avenidabrasil 614', 'LOGRA')]
# avenidabrasil 614 centro 78645-000 vila rica mt
#
# Entities [('rua constancio gomes', 'LOGRA')]
# rua constancio gomes centro 77710-000 pedro afonso to
#
# Entities [('avenida joao firmino 610', 'LOGRA')]
# avenida joao firmino 610 centro 98119-700 sao bernardo do campo sp
#
# Entities [('praca ruy barbosa a', 'LOGRA')]
# praca ruy barbosa a centro 45200-250 jequie ba
#
# Entities [('rua tenente viotte 515', 'LOGRA')]
# rua tenente viotte 515 centro 37460-000 passa quatro mg
#
# Entities [('avenida maringa', 'LOGRA')]
# avenida maringa jardim europa 87111-000 sarandi pr
#
# Entities [('av. rui barbosa 305', 'LOGRA')]
# av. rui barbosa 305 centro 38740-000 patrocinio mg
#
# Entities [('pca do centenario 365', 'LOGRA')]
# pca do centenario 365 centro 39300-000 sao francisco mg
#
# Entities [('avenida ernani do amaral peixoto n� 500', 'LOGRA')]
# avenida ernani do amaral peixoto n� 500 sobreloja ed. tower 500 centro 24020-077 niteroi rj
#
# Entities [('av.mal.deodoro 494', 'LOGRA')]
# av.mal.deodoro 494 jd.sta.clara 12080-080 taubate sp
#
# Entities [('av.tiradentes 1383', 'LOGRA')]
# av.tiradentes 1383 jardim shangri-la 86070-545 londrina pr
#
# Entities [('rua vinte e quatro de outubro', 'LOGRA')]
# rua vinte e quatro de outubro independencia 90510-002 porto alegre rs
#
# Entities [('r.alcides cursino', 'LOGRA')]
# r.alcides cursino 68 predio centro 56506-907 arcoverde pe
#
# Entities [('avenida nilo pecanha', 'LOGRA')]
# avenida nilo pecanha loja 1 - lote 3 centro 28970-000 araruama rj
#
# Entities [('r 403 s/n', 'LOGRA')]
# r 403 s/n quadra o/p lote 13/14 centro 47300-000 casa nova ba
#
# Entities [('rua getulio vargas 86', 'LOGRA')]
# rua getulio vargas 86 centro 28800-000 rio bonito rj
#
# Entities [('rua tancredo neves 125', 'LOGRA')]
# rua tancredo neves 125 centro 35670-000 mateus leme mg
#
# Entities [('rua beneditinos 28', 'LOGRA')]
# rua beneditinos 28 centro 20081-050 rio de janeiro rj
#
# Entities [('av. jaime brasil 381', 'LOGRA')]
# av. jaime brasil 381 centro 69301-350 boa vista rr
#
# Entities [('rua raul proen�a 425', 'LOGRA')]
# rua raul proen�a 425 centro 86270-000 sao jeronimo da serra pr
#
# Entities [('av.delfim moreira 390', 'LOGRA')]
# av.delfim moreira 390 centro 25953-181 teresopolis rj
#
# Entities [('av. getulio vargas 96760-000', 'LOGRA')]
# av. getulio vargas 96760-000 tapes rs
#
# Entities [('rua coronel aristiliano ramos 315', 'LOGRA')]
# rua coronel aristiliano ramos 315 centro 89110-000 gaspar sc
#
# Entities [('tv s�o felix', 'LOGRA')]
# tv s�o felix quadra 04 - lote 3 e 4 centro 68695-000 tailandia pa
#
# Entities [('av.francisco de paula leite', 'LOGRA')]
# av.francisco de paula leite 1719 sl.01 lotes 8 e 9 jardim california 13344-700 indaiatuba sp
#
# Entities [('av. benjamin constant 2010', 'LOGRA')]
# av. benjamin constant 2010 cambui 13025-005 campinas sp
#
# Entities [('av.brigadeiro faria lima 3930', 'LOGRA')]
# av.brigadeiro faria lima 3930 terreo esq.c/av.pres.j.kubitschek itaim bibi 04538-132 sao paulo sp
#
# Entities [('av.pres.kennedy 521', 'LOGRA')]
# av.pres.kennedy 521 centro 15760-000 urania sp
#
# Entities [('av.barao homem de melo', 'LOGRA')]
# av.barao homem de melo jardim america 30460-090 belo horizonte mg
#
# Entities [('avenida dom jos� tupinamb� da frota terreo', 'LOGRA')]
# avenida dom jos� tupinamb� da frota terreo e 1� pavimento centro 62011-040 sobral ce
#
# Entities [('ruacons. jose julio', 'LOGRA')]
# ruacons. jose julio centro 62010-820 sobral ce
#
# Entities [('rua xv de novembro 561', 'LOGRA')]
# rua xv de novembro 561 centro 96015-000 pelotas rs
#
# Entities [('av. farrapos 3852', 'LOGRA')]
# av. farrapos 3852 centro 90220-003 porto alegre rs
#
# Entities [('rua roland garros 1551', 'LOGRA')]
# rua roland garros 1551 jardim brasil 02235-001 sao paulo sp
#
# Entities [('r.sete de setembro 1041', 'LOGRA')]
# r.sete de setembro 1041 ed.aplub centro 90010-191 porto alegre rs
#
# Entities [('rua franklin siliprandi num 340', 'LOGRA')]
# rua franklin siliprandi num 340 centro 99680-000 constantina rs
#
# Entities [('r.mal.deodoro 520', 'LOGRA')]
# r.mal.deodoro 520 centro 84940-000 siqueira campos pr
#
# Entities [('pra�a sebasti�o vaz 64', 'LOGRA')]
# pra�a sebasti�o vaz 64 centro 75390-000 santa barbara de goias go
#
# Entities [('av. 31 de marco 805', 'LOGRA')]
# av. 31 de marco 805 centro 18110-005 votorantim sp
#
# Entities [('avenida das am�ricas', 'LOGRA')]
# avenida das am�ricas lojas 157 158 e 159 barra da tijuca 22640-102 rio de janeiro rj
#
# Entities [('av.brasil 1', 'LOGRA')]
# av.brasil 1 centro 78800-000 poxoreu mt
# Entities [('pca.manoel ribeiro soares 366', 'LOGRA')]
# pca.manoel ribeiro soares 366 centro 44620-000 baixa grande ba
#
# Entities [('pca.aprigio de toledo 40', 'LOGRA')]
# pca.aprigio de toledo 40 centro 12940-670 atibaia sp
#
# Entities [('r.coronel conrado caldeira 591', 'LOGRA')]
# r.coronel conrado caldeira 591 centro 14701-000 bebedouro sp
#
# Entities [('r cel jose dulce', 'LOGRA')]
# r cel jose dulce centro 78200-000 caceres mt
#
# Entities [('avenida princesa isabel', 'LOGRA')]
# avenida princesa isabel centro 47650-000 correntina ba
#
# Entities [('rua assis brasil 11', 'LOGRA')]
# rua assis brasil 11 sala 7 centro 95700-000 bento goncalves rs
#
# Entities [('rua santa rita 40', 'LOGRA')]
# rua santa rita 40 centro 75503-290 itumbiara go
#
# Entities [('avenida bento gonclaves 2072', 'LOGRA')]
# avenida bento gonclaves 2072 partenon 90650-003 porto alegre rs
#
# Entities [('av.mato grosso 329', 'LOGRA')]
# av.mato grosso 329 centro 78435-000 sao jose do rio claro mt
#
# Entities [('av.atlantica 440', 'LOGRA')]
# av.atlantica 440 cassino 96207-662 rio grande rs
#
# Entities [('av.minas gerais 330 qd.b lt.17 bl.3', 'LOGRA')]
# av.minas gerais 330 qd.b lt.17 bl.3 jundiai 75110-770 anapolis go
#
# Entities [('rua bento goncalves', 'LOGRA')]
# rua bento goncalves centro 97650-000 itaqui rs

# %%
phrase = "SHVP Rua 12 435 casa 22 lote 1"

doc = nlp(phrase)
print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
print('Tokens', [(t.text, t.ent_type_, t.ent_iob) for t in doc])
# Out:
# Entities [('SHVP Rua 12 435', 'LOGRA')]
# Tokens [('SHVP', 'LOGRA', 3), ('Rua', 'LOGRA', 1), ('12', 'LOGRA', 1), ('435', 'LOGRA', 1), ('casa', '', 2), ('22', '', 2), ('lote', '', 2), ('1', '', 2)]
