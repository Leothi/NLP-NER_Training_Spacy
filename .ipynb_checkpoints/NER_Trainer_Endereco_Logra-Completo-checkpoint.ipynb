# %%
# Load Packages
from __future__ import unicode_literals, print_function

import plac #  wrapper over argparse
import random
from pathlib import Path
import spacy
from tqdm import tqdm, tqdm_notebook # loading bar 
import pandas as pd
import re
from pprint import pprint
from nltk.tokenize import sent_tokenize
import numpy as np
import unicodedata
from spacy.util import minibatch, compounding
import ast as ast
import pickle

# %%
# Função para substituir acentos

def strip_accents(text):
    try:
        text = unicode(text, 'utf-8')
    except (TypeError, NameError): # unicode is a default on python 3 
        pass
    text = unicodedata.normalize('NFD', text)
    text = text.encode('ascii', 'ignore')
    text = text.decode("utf-8")
    
    return str(text)

# %% [markdown]
# # Abrindo e gerando Datasets

# %% [markdown]
# ### Entidade logradouro

# %%
with open ('Dataset_V2.0.txt', 'rb') as fp:
    dataset = pickle.load(fp)

print(len(dataset))
# Out:
# 128016

# %%
dataset[0]
# Out:
# ('R.GUILHERME MOREIRA,315 SUBLOJA,LOJA E 2.ANDAR 69005-300 MANAUS CENTRO AM',
#  {'entities': [(0, 23, 'END_LOG')]})

# %%
end_lista = []

for i in range(len(dataset)):
    str_tratada = dataset[i][0]
    str_tratada = str_tratada.lower() # Tudo em minúsculo
    str_tratada = strip_accents(str_tratada) # Substituição de acentos e caracteres diferentes
    
    end_lista.append(str_tratada)

# %%
end_lista[:3]
# Out:
# ['r.guilherme moreira,315 subloja,loja e 2.andar 69005-300 manaus centro am',
#  '69005-300 manaus am r.guilherme moreira,315 centro subloja,loja e 2.andar',
#  'r.guilherme moreira,315 centro 69005-300 subloja,loja e 2.andar manaus am']

# %%
iob = []

for i in range(len(dataset)):
    tupla = (end_lista[i], dataset[i][1])
    
    iob.append(tupla)
    
FULL_DATA = iob

# %%
print(FULL_DATA[0])
print(FULL_DATA[1])
print(FULL_DATA[2])
# Out:
# ('r.guilherme moreira,315 subloja,loja e 2.andar 69005-300 manaus centro am', {'entities': [(0, 23, 'END_LOG')]})
# ('69005-300 manaus am r.guilherme moreira,315 centro subloja,loja e 2.andar', {'entities': [(20, 43, 'END_LOG')]})
# ('r.guilherme moreira,315 centro 69005-300 subloja,loja e 2.andar manaus am', {'entities': [(0, 23, 'END_LOG')]})

# %%
# Criação da base de teste e treinamento

n_test= 0.1 # Porcentagem para base de teste
test_n = round(len(FULL_DATA) * n_test)

# Divisao em Train Test Val

def gerador_bases(dataset, n):
    indices_random = random.sample(range(0,len(dataset)-1), n)
    base_teste_n = []
    base_treinamento_n = []
    
    for i in range(n):
        base_teste_n.append(dataset[indices_random[i]])

    for j in range(len(dataset)):
        if(j not in indices_random):
            base_treinamento_n.append(dataset[j])
            
    return base_teste_n, base_treinamento_n


base_teste, base_treinamento = gerador_bases(FULL_DATA, test_n)

random.shuffle(base_treinamento)
random.shuffle(base_teste)

print("Treinamento: " + str(len(base_treinamento)), "\nTeste: " + str(len(base_teste)), "\nTotal: " + str(len(FULL_DATA)))
# Out:
# Treinamento: 115214
# Teste: 12802
# Total: 128016

# %%
for i in range(5):
    print(base_treinamento[i])
# Out:
# ('copacabana loja b 22070-012 avenida nossa senhora de copacabana rj rio de janeiro', {'entities': [(28, 63, 'END_LOG')]})
# ('cidade lider av. lider, 1690 sao paulo  08280-005 sp', {'entities': [(13, 28, 'END_LOG')]})
# ('28010-260 rj rua 13 de maio, 62/68  campos dos goytacazes centro', {'entities': [(13, 34, 'END_LOG')]})
# ('rua tiradentes, 88 92010-260 rs  canoas centro', {'entities': [(0, 18, 'END_LOG')]})
# ('centro 15470-000 palestina sp r.trinta de maio,1306', {'entities': [(31, 52, 'END_LOG')]})

# %% [markdown]
# # Carregando o modelo

# %%
# Define our variables

model = None
output_dir=Path(".")
n_iter= 50 # número de épocas
batch_size = 64

# %%
# Setting up the pipeline and entity recognizer.
if model is not None:
    nlp = spacy.load(model)  # load existing spacy model
    print("Loaded model '%s'" % model)
else:
    lan = 'pt'
    nlp = spacy.blank(lan)  # create blank Language class
    print("Created blank '%s' model" % lan)
    
if 'ner' not in nlp.pipe_names:
    ner = nlp.create_pipe('ner')
    nlp.add_pipe(ner)
    print('Added new NER')
else:
    ner = nlp.get_pipe('ner')
    print('Got an old NER')
# Out:
# Created blank 'pt' model
# Added new NER

# %%
# create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
if 'ner' not in nlp.pipe_names:
    ner = nlp.create_pipe('ner')
    nlp.add_pipe(ner, last=True)
# otherwise, get it so we can add labels
else:
    ner = nlp.get_pipe('ner')

# %% [markdown]
# ## Treinamento

# %%
print("Batch size: ", batch_size)
print("Épocas: ", n_iter)
print()

# add labels
for _, annotations in base_treinamento:
    for ent in annotations.get('entities'):
        ner.add_label(ent[2])


# get names of other pipes to disable them during training
other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
with nlp.disable_pipes(*other_pipes):  # only train NER
    optimizer = nlp.begin_training()
    for itn in range(n_iter):
        random.shuffle(base_treinamento)
        losses = {}
        batches = minibatch(base_treinamento, size=batch_size)
        
        for batch in batches:
            texts, annotations = zip(*batch)
            try:
                nlp.update(texts, annotations, sgd=optimizer, drop=0.2,
                       losses=losses)
            except:
                pass     
        
        print(itn+1, '\tLosses', losses)
# Out:
# Batch size:  64
# Épocas:  50
#
# 1 	Losses {'ner': 42198.45468182037}
# 2 	Losses {'ner': 15786.027301167687}
# 3 	Losses {'ner': 11318.14078434399}
# 4 	Losses {'ner': 9276.059837772344}
# 5 	Losses {'ner': 7768.1935773192445}
# 6 	Losses {'ner': 6665.725070077658}
# 7 	Losses {'ner': 6177.978693358606}
# 8 	Losses {'ner': 5330.289409730619}
# 9 	Losses {'ner': 4865.618877340154}
# 10 	Losses {'ner': 4627.8868527540335}
# 11 	Losses {'ner': 4232.631363280108}
# 12 	Losses {'ner': 4039.0372208517156}
# 13 	Losses {'ner': 3751.1298515168996}
# 14 	Losses {'ner': 3899.1217852767754}
# 15 	Losses {'ner': 3553.645807341747}
# 16 	Losses {'ner': 3576.0204861514985}
# 17 	Losses {'ner': 3335.4626899678005}
# 18 	Losses {'ner': 3236.7870245211852}
# 19 	Losses {'ner': 2782.49051973197}
# 20 	Losses {'ner': 3046.313139121491}
# 21 	Losses {'ner': 2743.878681170492}
# 22 	Losses {'ner': 2705.164181314526}
# 23 	Losses {'ner': 2671.8000133570417}
# 24 	Losses {'ner': 2606.145272408227}
# 25 	Losses {'ner': 2578.588505056689}
# 26 	Losses {'ner': 2373.476386297188}
# 27 	Losses {'ner': 2351.3883602147257}
# 28 	Losses {'ner': 2215.6738261561372}
# 29 	Losses {'ner': 2162.8321201890108}
# 30 	Losses {'ner': 2118.7182582895543}
# 31 	Losses {'ner': 2185.2253668102308}
# 32 	Losses {'ner': 1964.1023421704608}
# 33 	Losses {'ner': 2019.4304413283162}
# 34 	Losses {'ner': 1931.0946699029514}
# 35 	Losses {'ner': 1921.8304042882207}
# 36 	Losses {'ner': 1897.123395697572}
# 37 	Losses {'ner': 1700.3957719871826}
# 38 	Losses {'ner': 1590.0346970534724}
# 39 	Losses {'ner': 1840.1065831604844}
# 40 	Losses {'ner': 1775.9466259295048}
# 41 	Losses {'ner': 1632.3579460686074}
# 42 	Losses {'ner': 1626.7890251695433}
# 43 	Losses {'ner': 1664.3424491063186}
# 44 	Losses {'ner': 1576.5301437325604}
# 45 	Losses {'ner': 1596.8825787631076}
# 46 	Losses {'ner': 1472.7580764501847}
# 47 	Losses {'ner': 1526.7109608132878}
# 48 	Losses {'ner': 1494.9653283809766}
# 49 	Losses {'ner': 1445.8260235809344}
# 50 	Losses {'ner': 1422.4488034772119}

# %% [markdown]
# ## Salvando modelo

# %%
nlp.to_disk('../Saved_models/')

# %% [markdown]
# ## Teste

# %% [markdown]
# Base de Teste

# %%
# test the trained model
for text, _ in base_teste:
    doc = nlp(text)
    print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
    print(text)
    print()
# Out:
# Entities [('av. puglisi, 391', 'END_LOG')]
# guaruja av. puglisi, 391 sp 11410-001  centro
#
# Entities [('praca xv de novembro, 144', 'END_LOG')]
# mg oliveira  centro 35540-000 praca xv de novembro, 144
#
# Entities [('rua ceara, 2061', 'END_LOG')]
# 79021-000 quadra 21 lote 12 rua ceara, 2061 santa fe campo grande ms
#
# Entities [('avenida carlos botelho, 718', 'END_LOG')]
# sp  avenida carlos botelho, 718 so dimas 13416-145 piracicaba
#
# Entities [('praca da republica, 63', 'END_LOG')]
# praca da republica, 63 subsolo ao 2 pavimento centro sp santos 11013-010
#
# Entities [('rua visconde de piraj, 338 - loja e sob', 'END_LOG')]
# c/r joana angelica, 108 - ljs. a e b - sls.201/202 ipanema 22410-000 rio de janeiro rua visconde de piraj, 338 - loja e sob rj
#
# Entities [('praa dom bosco, 515', 'END_LOG')]
# go centro 75190-000 praa dom bosco, 515 leopoldo de bulhoes
#
# Entities [('av. rui barbosa, 305', 'END_LOG')]
# sp av. rui barbosa, 305 centro 06311-000 carapicuiba
#
# Entities [('av com. gustavo', 'END_LOG')]
# 57038-000 al maceio av com. gustavo paiva cruz das almas
#
# Entities [('shcs qd 514,bl.c,loja 55', 'END_LOG')]
# n.51-terreo-w3 sul,n.52 e 54 subsolo-w2 df shcs qd 514,bl.c,loja 55 brasilia a sul 70380-550
#
# Entities [('av.governador milton campos, 2576', 'END_LOG')]
# 39740-000  guanhaes av.governador milton campos, 2576 centro mg
#
# Entities [('avenida joao ribeiro', 'END_LOG')]
# 20750-092 rj pilares avenida joao ribeiro rio de janeiro
#
# Entities [('rua rio de janeiro', 'END_LOG')]
# rua rio de janeiro 15600-000 sp centro fernandopolis
#
# Entities [('rua mariano salmeron', 'END_LOG')]
# ed. leandro maciel siqueira campos se aracaju rua mariano salmeron 49075-370
#
# Entities [('r.oito,405', 'END_LOG')]
# 78635-000 agua boa mt centro r.oito,405 pca.da cultura
#
# Entities [('r.vol.da patria,1456/1458', 'END_LOG')]
# sao paulo santana sp 02010-300 r.vol.da patria,1456/1458
#
# Entities [('rua marechal deodoro da fonseca', 'END_LOG')]
# centro 2745, 2751 rua marechal deodoro da fonseca 15010-070 sp sao jose do rio preto
#
# Entities [('av.david vieira ney,264', 'END_LOG')]
# sao jose de uba  centro 28455-000 av.david vieira ney,264 rj
#
# Entities [('rod. amaral peixoto,', 'END_LOG')]
# 28890-000 rj rio das ostras com a rod amaral peixoto, 5287 - qd m - l 4 centro rod. amaral peixoto,
#
# Entities [('praca da independencia, 448', 'END_LOG')]
# espirito santo do pinhal centro 13990-000 sp praca da independencia, 448
#
# Entities [('avenida capito jose narciso, s/n', 'END_LOG')]
# centro se 49490-000 avenida capito jose narciso, s/n poco verde
#
# Entities [('av.pres.antonio carlos,51', 'END_LOG')]
# rio de janeiro castelo rj av.pres.antonio carlos,51 20020-010
#
# Entities [('pca. jose pedro antunes maciel', 'END_LOG')]
# feijo 69960-000 centro pca. jose pedro antunes maciel  ac
#
# Entities [('praca prefeito joao freire de', 'END_LOG')]
# 56180-000 pe carvalho, 287 cabrobo praca prefeito joao freire de centro
#
# Entities [('av.goias, 1312', 'END_LOG')]
# santa  paula  av.goias, 1312 sp 09521-300 sao caetano do sul
#
# Entities [('rua cesrio bastos', 'END_LOG')]
# itanhaem  centro rua cesrio bastos sp 11740-000
#
# Entities [('rua capitao antonio carlos', 'END_LOG')]
# quadra 8, salas 3 e 4 go sao domingos rua capitao antonio carlos 73860-000 centro
#
# Entities [('av rio branco, 138', 'END_LOG')]
# rj centro 20040-002 loja a av rio branco, 138 rio de janeiro
#
# Entities [('avenida 24 de outubro', 'END_LOG')]
# 74505-010 setor campinas go avenida 24 de outubro qd 37 lt 3/4 goiania
#
# Entities [('r.jose aquiles de sousa,530', 'END_LOG')]
# centro 64690-000  r.jose aquiles de sousa,530 pi fronteiras
#
# Entities [('av.prof.joao meneses,651', 'END_LOG')]
# 64770-000  sao raimundo nonato pi centro av.prof.joao meneses,651
#
# Entities [('av.cinco de marco,485', 'END_LOG')]
# pr pirai do sul av.cinco de marco,485 84240-000  centro
#
# Entities [('praa duque de caxias, 13', 'END_LOG')]
# rj praa duque de caxias, 13 cachoeiras de macacu 28680-000 centro
#
# Entities [('av. presidente vargas, 66', 'END_LOG')]
# centro av. presidente vargas, 66 pr astorga 86720-000
#
# Entities [('rua coronel quirino, 786', 'END_LOG')]
# esq.c/a rua gal.osorio sp 13025-001 campinas cambui rua coronel quirino, 786
#
# Entities [('rua coronel joaquim jose de oliveira, 50', 'END_LOG')]
# campinas taquaral rua coronel joaquim jose de oliveira, 50 sp 13090-230
#
# Entities [('srtvs', 'END_LOG')]
# asa norte 70340-000 df quadra 701, conjunto d, bloco b, lojas, 246 srtvs brasilia
#
# Entities [('av. das americas, 4200-bl 10-ljs.', 'END_LOG')]
# rj av. das americas, 4200-bl 10-ljs. barra da tijuca rio de janeiro 22631-004 101,102 e 103
#
# Entities [('rua cel. alfredo born, 223', 'END_LOG')]
# rs rua cel. alfredo born, 223  centro 96170-000 sao lourenco do sul
#
# Entities [('pa doze de outubro 130', 'END_LOG')]
# pa doze de outubro 130 sao sebastiao do passe 43850-000 centro ba
#
# Entities [('r.santa cruz,757', 'END_LOG')]
# mg varginha 37002-089 centro  r.santa cruz,757
#
# Entities [('avenida rio branco, 261', 'END_LOG')]
# rs centro  encruzilhada do sul 96610-000 avenida rio branco, 261
#
# Entities [('rua tres,', 'END_LOG')]
# goiania rua tres, setor central  go 74020-020
#
# Entities [('rua benedito leite', 'END_LOG')]
# balsas centro ma rua benedito leite 65800-000
#
# Entities [('seup/norte, quadra 513, bloco d, n.30', 'END_LOG')]
# asa norte seup/norte, quadra 513, bloco d, n.30 df brasilia 70760-530
#
# Entities [('av.cel.silva telles,234,esq.c/r.jose', 'END_LOG')]
# g.nogueira cambui campinas sp av.cel.silva telles,234,esq.c/r.jose 13024-000
#
# Entities [('avenida republica do libano', 'END_LOG')]
# sala 708 torre a empresarial rio mar trade avenida republica do libano recife pe 51110-160 bairro do pina
#
# Entities [('r.pref.assumpcao,284', 'END_LOG')]
# itatiaia r.pref.assumpcao,284 27580-000  centro rj
#
# Entities [('av humberto de alencar castelo branco', 'END_LOG')]
# av humberto de alencar castelo branco rj  sao goncalo 24420-465 rocha
#
# Entities [('rua herculano coelho de souza', 'END_LOG')]
# rua herculano coelho de souza cacador 1 andar sc reunidas 89500-000
#
# Entities [('rua bueno brandao 41', 'END_LOG')]
# tupaciguara mg centro 360305 38430-000 rua bueno brandao 41
#
# Entities [('avenida parana', 'END_LOG')]
# pr avenida parana zona iii umuarama 87502-000
#
# Entities [('trv lafayete cohim, 26', 'END_LOG')]
# ba 46800-000 trv lafayete cohim, 26 ruy barbosa centroi
#
# Entities [('av. das americas, 1901', 'END_LOG')]
# rj 22631-000 barra da tijuca rio de janeiro  av. das americas, 1901 bloco 1 - loja a
#
# Entities [('rua marechal deodoro, 313', 'END_LOG')]
# centro caconde 13770-000 rua marechal deodoro, 313 sp
#
# Entities [('r da quitanda', 'END_LOG')]
# centro r da quitanda 01012-010 93 sao paulo sp
#
# Entities [('rua marechal deodoro, 140', 'END_LOG')]
# sp centro  18770-000 rua marechal deodoro, 140 aguas de santa barbara
#
# Entities [('av.parada pinto, 2262', 'END_LOG')]
# sp vila nova cachoeirinha av.parada pinto, 2262 sao paulo 02611-001 lojas 240, 241, 242
#
# Entities [('avenida central', 'END_LOG')]
# 78643-000 setor f mt querencia qd 07 - lt 13 avenida central
#
# Entities [('rua cel. francisco soares, 243', 'END_LOG')]
# nova iguacu rj rua cel. francisco soares, 243 26220-031 centro
#
# Entities [('av. fernando correa da costa, 2988', 'END_LOG')]
# av. fernando correa da costa, 2988 coxipo da ponte 78070-001 mt  cuiaba
#
# Entities [('av. independencia 865/rua amelia', 'END_LOG')]
# pr fernandes 47 av. independencia 865/rua amelia bela vista do paraiso centro 86130-000
#
# Entities [('rua henrique coutinho, 901', 'END_LOG')]
# centro  guarapari 29200-190 es rua henrique coutinho, 901
#
# Entities [('avenida brasil, 1330', 'END_LOG')]
# avenida brasil, 1330 13188-252 jardim amanda ii  sp hortolandia
#
# Entities [('praa nippon, 81', 'END_LOG')]
# praa nippon, 81 02124-030 sp ant 5 sao paulo jd japo
#
# Entities [('pca. melo viana, 261', 'END_LOG')]
# caldas pca. melo viana, 261 centro 37780-000  mg
#
# Entities [('rua dona izabel, 570', 'END_LOG')]
# rua dona izabel, 570 sao carlos do ivai pr 87770-000  centro
#
# Entities [('rua valle porto, 8', 'END_LOG')]
# rua valle porto, 8  centro pr antonina 83370-000
#
# Entities [('r.rufino marques,4', 'END_LOG')]
# centro pedra pe r.rufino marques,4  55280-000
#
# Entities [('rua galeao carvalhal, 35', 'END_LOG')]
# sp gonzaga 11055-201 rua galeao carvalhal, 35 santos
#
# Entities [('r. mohamad said hedjazi, 63', 'END_LOG')]
# floresta r. mohamad said hedjazi, 63  sp juquia 11800-000
#
# Entities [('av.aristando ferreira lima,s/n', 'END_LOG')]
# bomba av.aristando ferreira lima,s/n centro parnamirim pe 56163-000
#
# Entities [('rua  francisco xavier de oliveira, lt ur', 'END_LOG')]
# campos belos rua  francisco xavier de oliveira, lt ur go setor aeroporto n 15 qd 15-c 73840-000
#
# Entities [('pca mons joao batista lisboa', 'END_LOG')]
# amparo centro sp pca mons joao batista lisboa 13900-080
#
# Entities [('av. pedro abrantes, 383', 'END_LOG')]
# malacacheta mg av. pedro abrantes, 383 39690-000 centro
#
# Entities [('praca getulio vargas,  20', 'END_LOG')]
# praca getulio vargas,  20 38500-000 monte carmelo  centro mg
#
# Entities [('praa raul leme, 265', 'END_LOG')]
# 12900-140  centro praa raul leme, 265 sp braganca paulista
#
# Entities [('rua schilling', 'END_LOG')]
# 05302-001 sao paulo  sp vila leopoldina rua schilling
#
# Entities [('rua sete de setembro, n 1073', 'END_LOG')]
# rua sete de setembro, n 1073 centro rs 90010-191 terreo - parte porto alegre
#
# Entities [('av. sete de setembro, 798', 'END_LOG')]
# bage centro  av. sete de setembro, 798 rs 96400-003
#
# Entities [('av pernambuco', 'END_LOG')]
# pa av pernambuco qd 72 - lt 15 68523-000 curionopolis centro
#
# Entities [('rua dr jose aureo bustamante 377', 'END_LOG')]
# 04710-090 bloco 1 - 3andar rua dr jose aureo bustamante 377 sp sao paulo santo amaro
#
# Entities [('av. cristiano machado, 4000, ljs. 150 a', 'END_LOG')]
# 31910-000 mg belo horizonte av. cristiano machado, 4000, ljs. 150 a 156 uniao
#
# Entities [('av coletora', 'END_LOG')]
# quadra 10 se nossa senhora do socorro 49160-000 av coletora a joao alves filho
#
# Entities [('av paulo de frontin, lt 25', 'END_LOG')]
# rj volta redonda aterrado 27213-150 av paulo de frontin, lt 25
#
# Entities [('r.gal.dantas,140', 'END_LOG')]
# 59460-000 r.gal.dantas,140 rn sao paulo do potengi centro
#
# Entities [('r.natalino cossi,30', 'END_LOG')]
# centro 29785-000 vila valerio r.natalino cossi,30  es
#
# Entities [('av nove de julho 441', 'END_LOG')]
# sp tupi paulista av nove de julho 441  centro 17930-000
#
# Entities [('av. ver. joaquim pereira barbosa, 143', 'END_LOG')]
# centro cajamar sp 07750-000  av. ver. joaquim pereira barbosa, 143
#
# Entities [('rua marcilio dias, 170', 'END_LOG')]
# rua marcilio dias, 170 11055-000 sp santos  gonzaga
#
# Entities [('pca.sao joao,140', 'END_LOG')]
# tarumirim mg  35140-000 centro pca.sao joao,140
#
# Entities [('av.dr.vital brasil, 333', 'END_LOG')]
# sao paulo sp av.dr.vital brasil, 333 05503-001 conjunto 2 butanta
#
# Entities [('rua sao jose, 23', 'END_LOG')]
# rj  28570-000 centro rua sao jose, 23 itaocara
#
# Entities [('rua conego pascoal, 69', 'END_LOG')]
# rua conego pascoal, 69 abare  ba 48680-000 centro
#
# Entities [('r.mons.borges carvalho,16', 'END_LOG')]
# 58125-000 pb alagoa nova  centro r.mons.borges carvalho,16
# Entities [('rua treze de maio, s/n', 'END_LOG')]
# ce rua treze de maio, s/n 62430-000  centro granja
#
# Entities [('av.eng.antonio de goes,60', 'END_LOG')]
# brasilia teimosa av.eng.antonio de goes,60 51010-000 pe recife 5.andar
#
# Entities [('rua joao cachoeira, 249', 'END_LOG')]
# vila nova conceicao sao paulo sp  rua joao cachoeira, 249 04535-010
#
# Entities [('estrada dos trs rios, n 62', 'END_LOG')]
# parte freguesia (jacarepagua) rio de janeiro rj estrada dos trs rios, n 62 22755-002
#
# Entities [('av. mauricio cardoso', 'END_LOG')]
# rs 99360-000  av. mauricio cardoso barros cassal
#
# Entities [('av. itaberaba, 5315, 5315-a, 5317', 'END_LOG')]
# av. itaberaba, 5315, 5315-a, 5317 02739-000 sp cachoeirinha sao paulo
#
# Entities [('avenida dom pedro ii, 4042', 'END_LOG')]
# mg  monsenhor messias avenida dom pedro ii, 4042 belo horizonte 30720-460
#
# Entities [('rua marechal izidoro lopes', 'END_LOG')]
# sp rua marechal izidoro lopes centro  06803-480 embu das artes
#
# Entities [('rodovia anhanguera km 98', 'END_LOG')]
# campinas rodovia anhanguera km 98 boa vista 13065-900 sp
#
# Entities [('av. andromeda, 1680', 'END_LOG')]
# cidade jardim sp  sao jose dos campos av. andromeda, 1680 12230-000
#
# Entities [('av brigadeiro faria lima, 3729', 'END_LOG')]
# 6pte, 7, 10pte, 11, 12pte, 13pte, 14 e 15 sao paulo itaim bibi av brigadeiro faria lima, 3729 04538-905 sp
#
# Entities [('av.pres.carlos luz,3001', 'END_LOG')]
# belo horizonte mg 31250-010 av.pres.carlos luz,3001 aparecida 2.piso,lojas 2102/2108
#
# Entities [('praa ricieri gianotti, 36', 'END_LOG')]
# centro sp 18550-000 boituva praa ricieri gianotti, 36
#
# Entities [('av. santo amaro, 4584', 'END_LOG')]
# 04702-002 sao paulo vila olimpia av. santo amaro, 4584 sp
#
# Entities [('av.duque de caxias,20', 'END_LOG')]
# 59012-200 natal av.duque de caxias,20 rn  ribeira
#
# Entities [('av. santos dumont', 'END_LOG')]
# aldeota av. santos dumont 60150-161 fortaleza ce terreo
#
# Entities [('rua capitao pedro augusto correa', 'END_LOG')]
# rua capitao pedro augusto correa carmo do rio claro mg centro 37150-000
#
# Entities [('rua parapu, 1.792', 'END_LOG')]
# sao paulo rua parapu, 1.792 itaberaba sp 02831-001
#
# Entities [('rua paula bueno', 'END_LOG')]
# taquaral campinas 13076-061 sp  rua paula bueno
#
# Entities [('av.manoel silveira de azevedo,3036', 'END_LOG')]
# av.manoel silveira de azevedo,3036  centro 95290-000 rs bom jesus
#
# Entities [('avenida das americas', 'END_LOG')]
# rj bl 22 lj 118/119/136/137 barra da tijuca avenida das americas rio de janeiro 22640-904
#
# Entities [('r.emilia marengo,260', 'END_LOG')]
# tatuape sp  03336-000 r.emilia marengo,260 sao paulo
#
# Entities [('rua conego moreau, 35', 'END_LOG')]
# rua conego moreau, 35 39391-000 bocaiuva centro  mg
#
# Entities [('r.cel.carlos pioli,183', 'END_LOG')]
# rio branco do sul centro pr r.cel.carlos pioli,183 83540-000
#
# Entities [('praca coronel antonio balbino, 273', 'END_LOG')]
# praca coronel antonio balbino, 273 47800-050 ba centro  barreiras
#
# Entities [('tv humaita, 3029', 'END_LOG')]
# pa 66093-048 belem terreo b marco tv humaita, 3029
#
# Entities [("estrada m'  boi mirim", 'END_LOG')]
# jardim das flores  04905-020 estrada m'  boi mirim sao paulo sp
#
# Entities [('rua theodoro pinheiro, 10', 'END_LOG')]
# irara rua theodoro pinheiro, 10  ba 44255-000 centro
#
# Entities [('av.pedro bueno, 1501, 1503, 1507, 1509 e', 'END_LOG')]
# 04342-011 av.pedro bueno, 1501, 1503, 1507, 1509 e sp 1511 jabaquara sao paulo
#
# Entities [('av  weimar goncalves torres,1815', 'END_LOG')]
# ms quadra 01 - lote 55 - lt/55 79800-011 av  weimar goncalves torres,1815 centro dourados
#
# Entities []
# 13450-001 centro  santa barbara d'oeste sp r d margarida
#
# Entities [('r.cel.jose custodio,73', 'END_LOG')]
# 37730-000 mg  centro r.cel.jose custodio,73 campestre
#
# Entities [('rua carlos de carvalho 3743', 'END_LOG')]
# pr centro rua carlos de carvalho 3743 85801-260  cascavel
#
# Entities [('r.epaminondas martins,9', 'END_LOG')]
# feijo 69960-000 ac r.epaminondas martins,9 centro
#
# Entities [('avenida claudio camelo timbo, 1136', 'END_LOG')]
# centro ce avenida claudio camelo timbo, 1136  hidrolandia 62270-000
#
# Entities [('av.agamenon magalhaes,3835', 'END_LOG')]
# boa vista 50070-160 av.agamenon magalhaes,3835  pe recife
#
# Entities [('r.miguel prisco,53', 'END_LOG')]
# 09400-110 ribeirao pires cto.comercial sp r.miguel prisco,53
#
# Entities [('r.cardoso de almeida,299', 'END_LOG')]
# sao paulo  sp r.cardoso de almeida,299 perdizes 05013-000
#
# Entities [('rua humberto pescarini, 300', 'END_LOG')]
# 13280-000 sp centro rua humberto pescarini, 300 vinhedo
#
# Entities [('av.getulio vargas,211', 'END_LOG')]
# criciuma av.getulio vargas,211 88801-500 centro sc 4 andar
#
# Entities [('tv 15 de novembro', 'END_LOG')]
# tv 15 de novembro centro pa  santarem 68005-290
#
# Entities [('r.do uruguai,521', 'END_LOG')]
# r.do uruguai,521 sion 30310-300  belo horizonte mg
#
# Entities [('av jos bonifcio', 'END_LOG')]
# 68570-000 pa centro sao geraldo do araguaia av jos bonifcio
#
# Entities [('praca vicentino rodrigues da cunha, 312', 'END_LOG')]
# praca vicentino rodrigues da cunha, 312 mg 38022-330 uberaba sao benedito
#
# Entities [('av.nacoes unidas,2901', 'END_LOG')]
# 93336-025 novo hamburgo r branco rs av.nacoes unidas,2901 2.pavimento
#
# Entities [('avenida itavuvu, 329', 'END_LOG')]
# sp 18075-042 sorocaba vila olimpia  avenida itavuvu, 329
#
# Entities [('rua bom jesus de pirapora, 2763', 'END_LOG')]
# 13206-305  jundiai vila rami rua bom jesus de pirapora, 2763 sp
#
# Entities [('r.benjamin constant,342', 'END_LOG')]
# ms centro 79220-000 r.benjamin constant,342  nioaque
#
# Entities [('av. guarulhos, 3797', 'END_LOG')]
# av. guarulhos, 3797 07031-001 sp ponte grande guarulhos
#
# Entities [('av ipiranga', 'END_LOG')]
# av ipiranga republica 01040-000 sao paulo  sp
#
# Entities [('av. cristovao colombo, 1360', 'END_LOG')]
# rs 90560-001 porto alegre av. cristovao colombo, 1360 floresta
#
# Entities [('av.vinte e dois de julho,665', 'END_LOG')]
# sc  irineopolis av.vinte e dois de julho,665 centro 89440-000
#
# Entities [('rua general francisco glicerio, 1600', 'END_LOG')]
# rua general francisco glicerio, 1600  suzano centro 86740-020 sp
#
# Entities [('av. farrapos, 2250', 'END_LOG')]
# porto alegre rs av. farrapos, 2250  90220-002 floresta
#
# Entities [('r.julio prestes,883', 'END_LOG')]
# sete barras r.julio prestes,883 sp 11910-000 centro
#
# Entities [('av. saturnino de brito', 'END_LOG')]
# vitoria 29055-180 es praia do canto av. saturnino de brito
#
# Entities [('rua figueira de melo, 383/a', 'END_LOG')]
# sao cristovao rj  rua figueira de melo, 383/a 20941-001 rio de janeiro
#
# Entities [('rua nereu ramos, 565', 'END_LOG')]
# 88780-000 sc imbituba rua nereu ramos, 565 centro
#
# Entities [('rua rosa raposo s/n', 'END_LOG')]
# araruama rua rosa raposo s/n centro  28970-000 rj
#
# Entities [('av. narciso silva', 'END_LOG')]
# capao do leao  96160-000 av. narciso silva centro rs
#
# Entities [('area especial 04, lote b', 'END_LOG')]
# df 71070-640 brasilia (guara) area especial 04, lote b guara ii loja 101 - trreo - ed. 03 irmos
#
# Entities [('rua general osorio, n 1041', 'END_LOG')]
# rua general osorio, n 1041 centro sp parte 13010-111 campinas
#
# Entities [('fraga de oliveira,  158/168', 'END_LOG')]
# esq. c/ a r. geraldo fraga de oliveira,  158/168 sp jardim sao luiz sao paulo r arlindo fraga de oliveira, n 5 05843-160
#
# Entities [('av. rubem bento alves, 1469', 'END_LOG')]
# 95041-410 rs caxias do sul sala 3 universitario av. rubem bento alves, 1469
#
# Entities [('r.landulfo alves,20', 'END_LOG')]
# r.landulfo alves,20 barra do mendes 44990-000 centro predio ba
#
# Entities [('rua 9c com avenida igualdade, 117', 'END_LOG')]
# 74930-170 quadra 92, lote 18 aparecida de goiania go setor garavelo rua 9c com avenida igualdade, 117
#
# Entities [('av. 20 de agosto, 1224', 'END_LOG')]
# catalao go centro 75701-010 av. 20 de agosto, 1224
#
# Entities [('av.afonso pena,2202', 'END_LOG')]
# av.afonso pena,2202 campo grande centro  79002-908 ms
#
# Entities [('avenida sete de setembro, 2775, lojas', 'END_LOG')]
# curitiba b25 e b26 centro pr 80230-010 avenida sete de setembro, 2775, lojas
#
# Entities [('av. venancio aires', 'END_LOG')]
# canoas rs 92110-000 niteri av. venancio aires
#
# Entities [('av. brasil, 800', 'END_LOG')]
# jardim brasil 13073-012  sp av. brasil, 800 campinas
#
# Entities [('av campos sales 515 / 519', 'END_LOG')]
# jd girassol  av campos sales 515 / 519 americana sp 13465-590
#
# Entities [('av filinto muller, 646', 'END_LOG')]
# av filinto muller, 646 centro-norte 78110-302  mt varzea grande
#
# Entities [('r.barbara de alencar,851', 'END_LOG')]
# 63100-901 centro ce  crato r.barbara de alencar,851
#
# Entities [('av.n.sra.de fatima,22-a', 'END_LOG')]
# rio de janeiro 20240-051 rj av.n.sra.de fatima,22-a centro
#
# Entities [('av republica do libano, 1513', 'END_LOG')]
# goiania  74125-125 av republica do libano, 1513 setor oeste go
#
# Entities [('r.s.francisco,315', 'END_LOG')]
# ce r.s.francisco,315 juazeiro do norte 63010-215  centro
#
# Entities [('av. dos imigrantes, 1340, sala 33 e 40', 'END_LOG')]
# edificio coml.jose pierini, terreo criciuma sc rio maina 88818-400 av. dos imigrantes, 1340, sala 33 e 40
#
# Entities [('av.t9, quadra 21, lotes 01/23', 'END_LOG')]
# 74333-010 goiania  av.t9, quadra 21, lotes 01/23 go jardim planalto
#
# Entities [('rua doutor jose malcher, 47', 'END_LOG')]
# pa  cidade alta monte alegre rua doutor jose malcher, 47 68220-000
#
# Entities [('av. bernarda laender, 183', 'END_LOG')]
# teofilo otoni  av. bernarda laender, 183 so diogo 39803-013 mg
#
# Entities [('pca.cesar cals,s/n', 'END_LOG')]
# guadalupe pca.cesar cals,s/n 64840-000 pi  centro
#
# Entities [('av guilherme cotching,1819', 'END_LOG')]
# av guilherme cotching,1819 02113-017 sao paulo sp vl maria 1 andar
#
# Entities [('rua 15 de janeiro, 181', 'END_LOG')]
# canoas rua 15 de janeiro, 181 92010-300 centro rs loja 01 - lote 12 - quadra 37
#
# Entities [('av. bernardo sayao, 1325', 'END_LOG')]
# n. imperatriz imperatriz ma 65907-000 av. bernardo sayao, 1325
#
# Entities [('rua coronel jose vicente, 02', 'END_LOG')]
# 58800-005 centro pb rua coronel jose vicente, 02 sousa
#
# Entities [('rua barao do rio branco, 1080', 'END_LOG')]
# go anapolis centro rua barao do rio branco, 1080 75025-040 60746948
#
# Entities [('av. giovanni gronchi, 5067', 'END_LOG')]
# sp vila andrade lote 1a - quadra 213 sao paulo av. giovanni gronchi, 5067 05724-003
#
# Entities [('r.getulio vargas,158', 'END_LOG')]
# mg minas novas 39650-000  centro r.getulio vargas,158
#
# Entities [('r.barao do rio branco,478', 'END_LOG')]
# 83900-000 centro pr sao mateus do sul  r.barao do rio branco,478
#
# Entities [('avenida presidente wilson, 82', 'END_LOG')]
# santos  sp 11065-200 avenida presidente wilson, 82 jose menino
#
# Entities [('avenida rui barbosa, 614', 'END_LOG')]
# centro avenida rui barbosa, 614 macae rj  27910-360
#
# Entities [('rua manoel francisco soares, 407', 'END_LOG')]
# es  itaguacu 29690-000 rua manoel francisco soares, 407 centro
#
# Entities [('r. dr. joao santos filho, 255', 'END_LOG')]
# casa forte 52060-904 pe recife r. dr. joao santos filho, 255 lojas 25 a 38 shoppi
#
# Entities [('rua da quitanda - 80.a', 'END_LOG')]
# centro rj rua da quitanda - 80.a 20091-000 rio de janeiro ssl/lj/mezanino
#
# Entities [('r.pamplona,822', 'END_LOG')]
# r.pamplona,822 sp  jd.paulista sao paulo 01405-001
# Entities [('av bertholdo costa', 'END_LOG')]
# maracana 68710-000 pa centro  av bertholdo costa
#
# Entities [('av. bezerra de menezes 1001', 'END_LOG')]
# 60000-000 ce av. bezerra de menezes 1001 fortaleza centro
#
# Entities [('avenida floriano peixoto', 'END_LOG')]
# am centro avenida floriano peixoto manaus 69005-070
#
# Entities [('av das americas', 'END_LOG')]
# 22631-004 barra da tijuca rio de janeiro rj  av das americas
#
# Entities [('rua goias, 775', 'END_LOG')]
# rua goias, 775 ouro verde sp  17920-000 centro
#
# Entities [('av major silvio de magalhes padilha,  5', 'END_LOG')]
# sao paulo 05693-000 av major silvio de magalhes padilha,  5 sp 1 andar morumbi
#
# Entities [('r.cinco,255', 'END_LOG')]
# to  77365-000 centro palmeiropolis r.cinco,255
#
# Entities [('r.gessyr goncalves fontes,55', 'END_LOG')]
# r.gessyr goncalves fontes,55 centro  sao joao de meriti rj 25520-570
#
# Entities [('av.bernardino de campos,250', 'END_LOG')]
# sao paulo  04004-040 av.bernardino de campos,250 paraiso sp
#
# Entities [('rua ernesto bassini', 'END_LOG')]
# santa tereza vitoria rua ernesto bassini loja 01 29026-841 es
#
# Entities [('rua haddock lobo,', 'END_LOG')]
# tijuca rua haddock lobo, rio de janeiro loja a 20260-141 rj
#
# Entities [('pca.tres de maio,400', 'END_LOG')]
# predio ba pca.tres de maio,400 centro serra dourada 47740-000
#
# Entities [('r.jose maria do sacramento,155', 'END_LOG')]
# r.jose maria do sacramento,155 39648-970 mg chapada do norte  centro
#
# Entities [('rua doze, 560', 'END_LOG')]
# 14790-000 guaira centro sp rua doze, 560
#
# Entities [('av. presidente lucena', 'END_LOG')]
# rs av. presidente lucena  ivoti 93900-000 centro
#
# Entities [('rua do passeio', 'END_LOG')]
# rj rua do passeio 20021-290 rio de janeiro centro 11. andar - parte
#
# Entities [('av. presidente vargas', 'END_LOG')]
# av. presidente vargas centro 98580-000  coronel bicaco rs
#
# Entities [('av. castelo branco, 406', 'END_LOG')]
# av. castelo branco, 406 mt  centro barra do bugres 78820-000
#
# Entities [('avenida aurlio brito, sn', 'END_LOG')]
# pi 64240-000 centro piracuruca  avenida aurlio brito, sn
#
# Entities [('av. raquel teixeira viana, 582', 'END_LOG')]
# av. raquel teixeira viana, 582  sete lagoas cana 35700-293 mg
#
# Entities [('pca.cesar cals,s/n', 'END_LOG')]
# pi guadalupe  64840-000 centro pca.cesar cals,s/n
#
# Entities [('rua belfort roxo, 146 a e 158 a', 'END_LOG')]
# rua belfort roxo, 146 a e 158 a rj  22020-010 rio de janeiro copacabana
#
# Entities [('rua japoranga, 781', 'END_LOG')]
# japuiba (cunhambebe) angra dos reis  rj rua japoranga, 781 23934-055
#
# Entities [('praa xv de novembro, 167', 'END_LOG')]
# prata praa xv de novembro, 167 centro 38140-000 mg
#
# Entities [('av tupi,', 'END_LOG')]
# 85504-000 pr pato branco av tupi, bortot
#
# Entities [('al dilson jatahy fonseca,', 'END_LOG')]
# stella maris quadra t lote 03 al dilson jatahy fonseca, salvador ba 41600-100
#
# Entities [('av.cons.rodrigues alves,640', 'END_LOG')]
# 04014-001 estacionamento proprio sp av.cons.rodrigues alves,640 sao paulo v.mariana
#
# Entities [('av.manoel dias da silva, 1121', 'END_LOG')]
# salvador pituba av.manoel dias da silva, 1121 ba 1 andar 41830-000
#
# Entities [('av. dom bosco', 'END_LOG')]
# es marilandia av. dom bosco  centro 29725-000
#
# Entities [('estr do coqueiro grande', 'END_LOG')]
# lj 51 52 cajazeiras 41342-315 salvador ba estr do coqueiro grande
#
# Entities [('rua felipe schmidt', 'END_LOG')]
# florianopolis rua felipe schmidt sala 05 centro sc 88010-000
#
# Entities [('avenida presidente vargas', 'END_LOG')]
# 93260-075 centro esteio rs avenida presidente vargas sala 18
#
# Entities [('rua jose cardoso de lima', 'END_LOG')]
# mimoso do oeste luis eduardo magalhaes  47850-000 ba rua jose cardoso de lima
#
# Entities [('rua odolfo medeiros', 'END_LOG')]
# ma rua odolfo medeiros 65980-000 centro  carolina
#
# Entities [('av fernando correa da costa', 'END_LOG')]
# av fernando correa da costa mt jd das americas lj 25/26 78060-600 cuiaba
#
# Entities [('avenida maria servidei demarchi', 'END_LOG')]
# demarchi avenida maria servidei demarchi sao bernardo do campo  sp 09820-000
#
# Entities [('av.pres.castelo branco,1754', 'END_LOG')]
# 14096-560 sp ribeirao preto  nova ribeirania av.pres.castelo branco,1754
#
# Entities [('av borges de medeiros, 635', 'END_LOG')]
# centro historico av borges de medeiros, 635 porto alegre 90020-023 rs 645
#
# Entities [('av. joo paulo ii, 1344', 'END_LOG')]
# av. joo paulo ii, 1344 embu das artes sp 06813-265 vila regina
#
# Entities [('av.iguau', 'END_LOG')]
# centro  mangueirinha pr 85540-000 av.iguau
#
# Entities [('praa flvio silvani, 130', 'END_LOG')]
# centro itaberaba 46880-970 praa flvio silvani, 130 ba
#
# Entities [('avenida rio xingu, lote 18, quadra 147', 'END_LOG')]
# 68380-000 pa setor 02 centro avenida rio xingu, lote 18, quadra 147 sao felix do xingu
#
# Entities [('rua francisco glicerio', 'END_LOG')]
# rua francisco glicerio centro 13250-330  itatiba sp
#
# Entities [('av paulista 1842', 'END_LOG')]
# 13109-410 cerqueira cesar sao paulo av paulista 1842 sp torre sul
#
# Entities [('av. dom pedro ii, 121', 'END_LOG')]
# jardim parte sp 09080-110 av. dom pedro ii, 121 santo andre
#
# Entities [('av. julio de castilho, 1.437', 'END_LOG')]
# campo grande ms  av. julio de castilho, 1.437 vila alba 79100-005
#
# Entities [('rua coronel pinto, 187', 'END_LOG')]
# rr parte rua coronel pinto, 187 centro 69301-150 boa vista
#
# Entities [('pca.das quatro jornadas,11', 'END_LOG')]
# rj mezanino centro pca.das quatro jornadas,11 campos dos goytacazes 28010-000
#
# Entities [('alameda barao de limeira, 966', 'END_LOG')]
# pavimento superior sp 01202-002 alameda barao de limeira, 966 campos eliseos sao paulo
#
# Entities [('av des. clotario portugal, 616', 'END_LOG')]
# centro pr 83601-320 av des. clotario portugal, 616 campo largo
#
# Entities [('rua xv de novembro', 'END_LOG')]
# 80045-270 rua xv de novembro pr  alto da rua xv curitiba
#
# Entities [('av. amaral peixoto, 858', 'END_LOG')]
# av. amaral peixoto, 858 centro volta redonda 27253-223 rj 360305
#
# Entities [('av senador lemos, s/n', 'END_LOG')]
# taperinha 68721-000 av senador lemos, s/n pa salinopolis
#
# Entities [('rua getulio marchetto', 'END_LOG')]
# 78535-000 centro marcelandia mt rua getulio marchetto
#
# Entities [('rua major idelfonso, 204', 'END_LOG')]
# rua major idelfonso, 204 63300-000 ce  centro lavras da mangabeira
#
# Entities [('av. sumare, n 403', 'END_LOG')]
# 05016-090 perdizes sao paulo av. sumare, n 403 parte sp
#
# Entities [('pca.da matriz,241', 'END_LOG')]
# centro sp olimpia 15400-000 pca.da matriz,241
#
# Entities [('av tanus saliba 32', 'END_LOG')]
# av tanus saliba 32 mg juatuba centro 35675-975
#
# Entities [('av.agamenon magalhaes,153', 'END_LOG')]
# loja 134-a recife pe sto.amaro av.agamenon magalhaes,153 50110-000
#
# Entities [('qe 07 - lote a', 'END_LOG')]
# df guara i  qe 07 - lote a 71000-000 brasilia (guara)
#
# Entities [('r.pe.pedro domingues,59', 'END_LOG')]
# mg  sao domingos do prata 35995-000 centro r.pe.pedro domingues,59
#
# Entities [('rua dr. alceu de campos rodrigues, 229', 'END_LOG')]
# rua dr. alceu de campos rodrigues, 229 sp vila olimpia sao paulo 04544-000
#
# Entities [('av. doutor julio maranhao, 238', 'END_LOG')]
# 54325-440 jaboatao dos guararapes av. doutor julio maranhao, 238 guararapes  pe
#
# Entities [('av.parque das aguas,143', 'END_LOG')]
# monteiro 58500-000  centro av.parque das aguas,143 pb
#
# Entities [('rua ten. nicolau maffei, 258', 'END_LOG')]
# rua ten. nicolau maffei, 258 presidente prudente sp 19010-010 centro
#
# Entities [('r.getulio vargas,37', 'END_LOG')]
# 45435-000 ba casa itubera centro r.getulio vargas,37
#
# Entities [('praca siqueira campos, 70', 'END_LOG')]
# centro 45600-928 itabuna  praca siqueira campos, 70 ba
#
# Entities [('av olinto meireles, 2600', 'END_LOG')]
# milionarios belo horizonte 30620-330 av olinto meireles, 2600  mg
#
# Entities [('pc cel labre, s/n', 'END_LOG')]
# am pc cel labre, s/n centro 69830-000 labrea
#
# Entities [('av tambore, 570', 'END_LOG')]
# 06460-000  sp tambor barueri av tambore, 570
#
# Entities [('setor de habit.coletiv. sul com. resid.', 'END_LOG')]
# asa sul 70350-535 df qd 506 - bl c - lj 33 setor de habit.coletiv. sul com. resid. brasilia
#
# Entities [('av. itaberaba, 1831', 'END_LOG')]
# av. itaberaba, 1831  freguesia do o 02734-000 sp sao paulo
#
# Entities [('avenida rui barbosa, 1275', 'END_LOG')]
# go  firminopolis centro 76105-000 avenida rui barbosa, 1275
#
# Entities [('avenida paulista, 1111 - 2 andar (parte)', 'END_LOG')]
# sp  bela vista avenida paulista, 1111 - 2 andar (parte) 13119-200 sao paulo
#
# Entities [('rua marechal deodoro, 384 b', 'END_LOG')]
# centro rua marechal deodoro, 384 b  mg 37590-000 jacutinga
#
# Entities [('r.tiradentes,442', 'END_LOG')]
# cravinhos r.tiradentes,442 14140-000 sp  centro
#
# Entities [('av. getulio vargas, 81', 'END_LOG')]
# 35290-000 mantena centro mg  av. getulio vargas, 81
#
# Entities [('rua conego lima, 54', 'END_LOG')]
# sp rua conego lima, 54 centro 12210-080 sao jose dos campos
#
# Entities [('av. eng. armando de arruda pereira, 707', 'END_LOG')]
# 13 andar - parte av. eng. armando de arruda pereira, 707 sao paulo jabaquara sp 04309-010
#
# Entities [('rua general camara', 'END_LOG')]
# centro rs  porto alegre 90010-230 rua general camara
#
# Entities [('avenida assis brasil 3940', 'END_LOG')]
# so sebastio porto alegre sala 04 - bloco e rs 91060-900 avenida assis brasil 3940
#
# Entities [('rua 1 de janeiro, 902/esq. florencio machado', 'END_LOG')]
# rua 1 de janeiro, 902/esq. florencio machado 77800-000 to araguaina centro
#
# Entities [('av. brasil, 6.177', 'END_LOG')]
# av. brasil, 6.177 cascavel 85801-000 pr centro
#
# Entities [('praca rodrigues de abreu, 445', 'END_LOG')]
# 13360-000 praca rodrigues de abreu, 445 capivari centro sp
#
# Entities [('rua pamplona', 'END_LOG')]
# jardim paulista 01405-001 rua pamplona sao paulo sp sala 42
#
# Entities [('av. prof. francisco morato 3209', 'END_LOG')]
# vila sonia  05521-000 sao paulo sp av. prof. francisco morato 3209
#
# Entities [('r carlos ferrari,  220', 'END_LOG')]
# centro  r carlos ferrari,  220 17400-000 sp garca
#
# Entities [('av. jornalista rubens de arruda ramos', 'END_LOG')]
# av. jornalista rubens de arruda ramos 88015-700 florianopolis centro sc
#
# Entities [('avenida doutor nilo peanha', 'END_LOG')]
# rs porto alegre 91330-001 avenida doutor nilo peanha chcara das pedras sala 503 - edifcio iguatemi corporate
#
# Entities [('av.estrada da batalha,239', 'END_LOG')]
# pe prazeres  54315-570 jaboatao dos guararapes av.estrada da batalha,239
#
# Entities [('rua 19 sul', 'END_LOG')]
# lote 16 - loja 2 - sul df 71940-720 rua 19 sul brasilia sul aguas claras
#
# Entities [('av. padre bernardo rech', 'END_LOG')]
# marata  rs centro 95793-000 av. padre bernardo rech
#
# Entities [('r bispo dom jose, 2133', 'END_LOG')]
# r bispo dom jose, 2133  curitiba pr 80440-080 batel
#
# Entities [('avenida sete de setembro, 4751', 'END_LOG')]
# avenida sete de setembro, 4751 80240-000 curitiba sobreloja, conjunto 02 pr batel
#
# Entities [('r.joao lopes de oliveira,192', 'END_LOG')]
# sp r.joao lopes de oliveira,192 14990-000  irapua centro
#
# Entities [('av. eng. armando de arruda pereira, 707', 'END_LOG')]
# jabaquara sao paulo sp 04309-010 av. eng. armando de arruda pereira, 707 13 andar
#
# Entities [('avenida braz leme,', 'END_LOG')]
# sao paulo 02022-020 avenida braz leme, loja 2 e 3  sp
#
# Entities [('saun quadra 5, bloco b, ed. bb', 'END_LOG')]
# brasilia df saun quadra 5, bloco b, ed. bb 70040-912 a norte torre central - 6 andar
#
# Entities [('av.longuinho vieira junior,684', 'END_LOG')]
# centro  colmeia av.longuinho vieira junior,684 77725-000 to
# Entities [('av.contagem, 1520, loja 1', 'END_LOG')]
# av.contagem, 1520, loja 1 sabara 34710-000 vila nova vista mg
#
# Entities [('rua engenheiro antonio penido', 'END_LOG')]
# cruzeiro sp rua engenheiro antonio penido centro 12701-050
#
# Entities [('trv juscelino kubitscheck,', 'END_LOG')]
# trv juscelino kubitscheck, dom eliseu 68633-000 pa centro
#
# Entities [('rua comendador araujo, 731', 'END_LOG')]
# 80420-000 rua comendador araujo, 731 batel curitiba pr
#
# Entities [('rua lourenco prado', 'END_LOG')]
# centro 17201-000  sp jau rua lourenco prado
#
# Entities [('r.vergueiro,4480', 'END_LOG')]
# r.vergueiro,4480  liberdade 01504-000 sp sao paulo
#
# Entities [('av.pres.kennedy,521', 'END_LOG')]
# centro urania  15760-000 av.pres.kennedy,521 sp
#
# Entities [('av. dr. cardoso de mello, 1.460', 'END_LOG')]
# 04548-005 sp vila olmpia sao paulo loja - parte av. dr. cardoso de mello, 1.460
#
# Entities [('av.pres.getulio vargas,488', 'END_LOG')]
# centro  av.pres.getulio vargas,488 27998-000 carapebus rj
#
# Entities [('av.prof. manoel jose pedroso, 1, 2, 3, 7', 'END_LOG')]
# 06717-100 cotia  av.prof. manoel jose pedroso, 1, 2, 3, 7 parque bahia sp
#
# Entities [('av.enio goncalves, 65', 'END_LOG')]
# av.enio goncalves, 65 centro santa juliana 38175-000 mg
#
# Entities [('r dr pedro estaquio vieira, s/n lt 16-22', 'END_LOG')]
# pe  55018-620 caruaru salgado r dr pedro estaquio vieira, s/n lt 16-22
#
# Entities [('rua dr. j. j. seabra, 239/241', 'END_LOG')]
# 40025-000 baixa dos sapateiros salvador rua dr. j. j. seabra, 239/241 ba
#
# Entities [('rua maraba, 178 e 180', 'END_LOG')]
# parauapebas da paz rua maraba, 178 e 180 68515-000 pa
#
# Entities [('av durval fraga', 'END_LOG')]
# av durval fraga muritiba ba 44340-000  centro
#
# Entities [('pc manoel cardoso souza,', 'END_LOG')]
# centro pc manoel cardoso souza,  49700-000 se capela
#
# Entities [('avenida julia freire', 'END_LOG')]
# joao pessoa pb loja 17 expedicionarios 58041-000 avenida julia freire
#
# Entities [('r.da passagem,95', 'END_LOG')]
# lojas a/b/c 22290-030 botafogo rj r.da passagem,95 rio de janeiro
#
# Entities [('av. getlio vargas, 146', 'END_LOG')]
# es  centro colatina av. getlio vargas, 146 29700-010
#
# Entities [('r.dr.jorge tibirica,980', 'END_LOG')]
# centro sp r.dr.jorge tibirica,980 13830-000  santo antonio de posse
#
# Entities [('avenida camapu', 'END_LOG')]
# novo aleixo manaus 69099-028 am avenida camapu
#
# Entities [('r.mal.cantuaria,172', 'END_LOG')]
# r.mal.cantuaria,172 urca  rio de janeiro 22291-060 rj
#
# Entities [('praca xv de novembro', 'END_LOG')]
# praca xv de novembro  centro sao jose do rio pardo sp 13720-000
#
# Entities [('avenida nossa senhora da penha', 'END_LOG')]
# loja 01 avenida nossa senhora da penha santa lucia 29056-923 es vitoria
#
# Entities [('av. julio borella', 'END_LOG')]
# 99150-000 rs   av. julio borella marau
#
# Entities [('avenida dona belmira marin', 'END_LOG')]
# 04846-010 441, 451 parque brasil sp avenida dona belmira marin sao paulo
#
# Entities [('av.das comunidades,70', 'END_LOG')]
# 88350-360 sc brusque av.das comunidades,70 centro
#
# Entities [('av. tenente marques, 5201', 'END_LOG')]
# ch solar i (fazendinha) santana de parnaiba av. tenente marques, 5201 salas 8/9 06530-001 sp
#
# Entities [('praa santos dumont, 70', 'END_LOG')]
# praa santos dumont, 70 gavea rio de janeiro rj 2 andar 22470-060
#
# Entities [('r.dr.joao colin,2525', 'END_LOG')]
# 89204-005  r.dr.joao colin,2525 america sc joinville
#
# Entities [('av luis tarquinio, 1764', 'END_LOG')]
# ba av luis tarquinio, 1764 pitangueiras lauro de freitas 42700-000
#
# Entities [('rua surubim', 'END_LOG')]
# sp andar 1 conjunto 11 - parte 04571-050 cidade moncoes sao paulo rua surubim
#
# Entities [('r.firmino pereira lacerda,216', 'END_LOG')]
# r.firmino pereira lacerda,216 77493-000 to  centro lagoa da confusao
#
# Entities [('av. arapongas', 'END_LOG')]
# pr av. arapongas centro arapongas  86700-050
#
# Entities [('rua francisco glicerio, 385', 'END_LOG')]
# itatiba rua francisco glicerio, 385 13250-330 sp centro
#
# Entities [('av.brig.faria lima,2886', 'END_LOG')]
# sao paulo jd.paulistano sp 01452-002 av.brig.faria lima,2886
#
# Entities [('av.pres.itamar franco,1710', 'END_LOG')]
# av.pres.itamar franco,1710  mg 36016-321 juiz de fora sao mateus
#
# Entities [('av. carlos lindenberg, 5417', 'END_LOG')]
# cobilndia vila velha av. carlos lindenberg, 5417  29111-165 es
#
# Entities [('rua jair martins mil homens', 'END_LOG')]
# sp salas 723, 724 e 725 - vila so jos rua jair martins mil homens 15090-080 sao jose do rio preto centro
#
# Entities [('pca.manuel de assis,81', 'END_LOG')]
# pca.manuel de assis,81 mg  igaratinga centro 35695-000
#
# Entities [('rua cel. juvencio carneiro, 356', 'END_LOG')]
# pb rua cel. juvencio carneiro, 356  cajazeiras 58900-000 centro
#
# Entities [('av. brigadeiro faria lima, 2157', 'END_LOG')]
# sao paulo 01452-000 av. brigadeiro faria lima, 2157 jardim paulistano sp
#
# Entities [('av. teresopolis', 'END_LOG')]
# av. teresopolis teresopolis 90870-001 rs porto alegre
#
# Entities [('pca.dr.francisco gualberto dantas fontes', 'END_LOG')]
# candeias ba centro  43800-000 pca.dr.francisco gualberto dantas fontes
#
# Entities [('av.benedito valadares,250', 'END_LOG')]
# av.benedito valadares,250 mg centro  35490-000 entre rios de minas
#
# Entities [('pca.da bandeira, 140', 'END_LOG')]
# ba centro potiragua 45790-000  pca.da bandeira, 140
#
# Entities [('praca marechal deodoro da fonseca, 333', 'END_LOG')]
# sp centro itapetininga 18200-000 praca marechal deodoro da fonseca, 333
#
# Entities [('praca ponce de leon,26', 'END_LOG')]
# centro  rj barra mansa praca ponce de leon,26 27330-490
#
# Entities [('rua floriano peixoto', 'END_LOG')]
# centro  ce 60025-130 rua floriano peixoto fortaleza
#
# Entities [('av.amazonas,81', 'END_LOG')]
# boa esperanca centro 87390-000 av.amazonas,81  pr
#
# Entities [('rua gaviao peixoto,', 'END_LOG')]
# icarai niteroi  rua gaviao peixoto, rj 24230-101
#
# Entities [('av. dom joo vi, 670', 'END_LOG')]
# sp diadema 09940-150  taboo av. dom joo vi, 670
#
# Entities [('rua visconde de inhauma, 1050', 'END_LOG')]
# vl. gerti 09571-470 rua visconde de inhauma, 1050  sp sao caetano do sul
#
# Entities [('rua barao do rio branco, 957', 'END_LOG')]
# 14160-570 sp centro (parte) sertaozinho rua barao do rio branco, 957
#
# Entities [('av. mogiana, 1.790', 'END_LOG')]
# sp 14075-260 ribeirao preto vila elisa av. mogiana, 1.790
#
# Entities [('r.itingucu,670', 'END_LOG')]
# sp sao paulo  v.re r.itingucu,670 03658-000
#
# Entities [('avenida getulio vargas', 'END_LOG')]
# avenida getulio vargas 44001-496 feira de santana ba centro lojas 01 ate 05
#
# Entities [('rua rsula paulino, 1177', 'END_LOG')]
# 30570-000 mg  betnia rua rsula paulino, 1177 belo horizonte
#
# Entities [('av. raul soares, 19', 'END_LOG')]
# av. raul soares, 19  manhumirim mg 36970-000 centro
#
# Entities [('pca.thales ribeiro goncalves,684', 'END_LOG')]
# centro  ma timbiras pca.thales ribeiro goncalves,684 65420-000
#
# Entities [('av. arouca, 634', 'END_LOG')]
# passos av. arouca, 634 mg 37900-152  centro
#
# Entities [('rua calos raymundi, 303', 'END_LOG')]
# centro rua calos raymundi, 303 99840-000 sananduva rs
#
# Entities [('praca americo turri, 17', 'END_LOG')]
# centro sao sebastiao da grama  13790-000 praca americo turri, 17 sp
#
# Entities [('avenida washington soares, 450', 'END_LOG')]
# avenida washington soares, 450 60811-340 ce lj 47 guararapes fortaleza
#
# Entities [('av. eng. armando de arruda pereira, 707', 'END_LOG')]
# av. eng. armando de arruda pereira, 707 13 andar - parte sp jabaquara sao paulo 04309-010
#
# Entities [('scn,qd.2,bloco a,4.andar,sala 401', 'END_LOG')]
# scn,qd.2,bloco a,4.andar,sala 401 ed.corporate financial center brasilia setor comercial norte 70712-900 df
#
# Entities [('largo da penha', 'END_LOG'), ('av. braz de pina, 131', 'END_LOG')]
# rj 21070-030 loja,sobreloja e ultimo pav. largo da penha rio de janeiro av. braz de pina, 131
#
# Entities [('estr.do mendanha,326', 'END_LOG')]
# rio de janeiro campo grande estr.do mendanha,326 rj  23087-284
#
# Entities [('av.segismundo pereira, 1126', 'END_LOG')]
# 38408-170 mg  av.segismundo pereira, 1126 uberlandia santa monica
#
# Entities [('r.israel tavares,33', 'END_LOG')]
# barra do choca ba 45120-000 r.israel tavares,33 centro terreo
#
# Entities [('rua gaviao peixoto,', 'END_LOG')]
# 24230-101 icarai niteroi rj rua gaviao peixoto,
#
# Entities [('rua 25 de agosto, 716/pca.mariano de h.', 'END_LOG')]
# centro cavalcante miracema do tocantins rua 25 de agosto, 716/pca.mariano de h. to 77650-000
#
# Entities [('rua padre mororo, 414', 'END_LOG')]
# 62250-000 ipu centro rua padre mororo, 414  ce
#
# Entities [('r. xv de novembro, 742', 'END_LOG')]
# blumenau sc centro r. xv de novembro, 742 89010-001
#
# Entities [('rua amazonas, n 3152', 'END_LOG')]
# rua amazonas, n 3152 vila muniz sp votuporanga parte 15505-208
#
# Entities [('avenida antonio carlos couto de barros,', 'END_LOG')]
# avenida antonio carlos couto de barros, jd conceio   sousas campinas 13105-000 sp qrt 80 q24-lt 1 mod
#
# Entities [('avenida nove de julho, 1356', 'END_LOG')]
# fatima do sul 79700-000  centro ms avenida nove de julho, 1356
#
# Entities [('praca coronel heitor antunes 67', 'END_LOG')]
# 39510-000 centro mg espinosa praca coronel heitor antunes 67
#
# Entities [('av. abido saad, 417', 'END_LOG')]
# es parque jacaraipe  29175-520 av. abido saad, 417 serra
#
# Entities [('r. v.r.branco, 360 - lj 221 a 224, 227 a', 'END_LOG')]
# rj 24020-002 shopping bay market r. v.r.branco, 360 - lj 221 a 224, 227 a niteroi centro
#
# Entities [('av. independncia, 413', 'END_LOG')]
# vila jaboticabeira sp taubate av. independncia, 413  12031-000
#
# Entities [('avenida_adolfo pinheiro, 159', 'END_LOG')]
# avenida_adolfo pinheiro, 159 sp  sao paulo santo amaro 04733-000
#
# Entities [('rua iguacu, 719', 'END_LOG')]
# centro pr rua iguacu, 719  83650-000 balsa nova
#
# Entities [('avenida presidente costa e silva, 80', 'END_LOG')]
# 11700-005 boqueirao sp avenida presidente costa e silva, 80 praia grande
#
# Entities [('av senador lemos', 'END_LOG')]
# belem 66113-000  av senador lemos pa telgrafo
#
# Entities [('av barao do rio branco', 'END_LOG')]
# sp av barao do rio branco 14870-780 jaboticabal centro
#
# Entities [('av demerval lobao veras 765', 'END_LOG')]
# campo maior centro pi 64280-000 av demerval lobao veras 765
#
# Entities [('av.pedras negras,744', 'END_LOG')]
# ro centro 76937-000 costa marques av.pedras negras,744
#
# Entities [('rua marechal deodoro, qd. 24', 'END_LOG')]
# go lotes 3 e 4 rua marechal deodoro, qd. 24 74340-065 parque anhanguera goiania
#
# Entities [('rua jose bonifacio, 584', 'END_LOG')]
# urupes sp  15850-000 centro rua jose bonifacio, 584
#
# Entities [('alameda rio negro, 161, loja comercial', 'END_LOG')]
# alameda rio negro, 161, loja comercial 2 edifcio west point sp barueri alphaville industrial 06454-000
#
# Entities [('av.dos holandeses,106', 'END_LOG')]
# sao luis av.dos holandeses,106  ma calhau 65071-380
#
# Entities [('rua lucivaldo curvello, 69', 'END_LOG')]
# ba  45375-000 centro planaltino rua lucivaldo curvello, 69
#
# Entities [('rua general canabarro, 500', 'END_LOG')]
# rio de janeiro maracana rua general canabarro, 500 2 andar rj 20271-900
#
# Entities [('rua das laranjeiras, 32 - loja a', 'END_LOG')]
# laranjeiras 22240-000  rio de janeiro rua das laranjeiras, 32 - loja a rj
# Entities [('av almirante barroso, 854', 'END_LOG')]
# av almirante barroso, 854 66093-020  marco belem pa
#
# Entities [('av. cidade jardin', 'END_LOG')]
# jardim paulistano av. cidade jardin sp sao paulo 01454-000
#
# Entities [('rua augusta, 1655', 'END_LOG')]
# consolao rua augusta, 1655 sao paulo  sp 01305-100
#
# Entities [('alameda itu, 852, 12 andar', 'END_LOG')]
# alameda itu, 852, 12 andar  sao paulo sp jardim paulista 01421-001
#
# Entities [('r.paula bueno,918', 'END_LOG')]
# taquaral campinas 13076-061 sp r.paula bueno,918
#
# Entities [('av. julio de castilho, 1.437', 'END_LOG')]
# vila alba ms campo grande 79100-005  av. julio de castilho, 1.437
#
# Entities [('av.centenario,2992', 'END_LOG')]
# 40140-902 ba av.centenario,2992 salvador barra 3.piso,loja a3c
#
# Entities [('pca.braulio cardoso,582', 'END_LOG')]
# 44905-000 pca.braulio cardoso,582 lapao terreo ba centro
#
# Entities [('av.joao mariano,361', 'END_LOG')]
# mg av.joao mariano,361 38760-000 serra do salitre centro predio
#
# Entities [('q 04, rea especial', 'END_LOG')]
# brasilia (sobradinho) q 04, rea especial 73025-040  centro de ensino mdio 01 df
#
# Entities [('av silva lobo 1400', 'END_LOG')]
# 30431-262  mg belo horizonte av silva lobo 1400 nova granada
#
# Entities [('av. maria servidei demarchi, 1361', 'END_LOG')]
# demarchi sp sao bernardo do campo  09820-000 av. maria servidei demarchi, 1361
#
# Entities [('rua do fico, 360', 'END_LOG')]
# aracatuba rua do fico, 360 nossa sra.aparecida sp  16050-387
#
# Entities [('est santa isabel, 3365', 'END_LOG')]
# vila sao carlos 08599-000 itaquaquecetuba est santa isabel, 3365  sp
#
# Entities [('rua independencia, 333', 'END_LOG')]
# 93010-001  sao leopoldo rua independencia, 333 centro rs
#
# Entities [('rua padre francisco', 'END_LOG')]
# mg centro rua padre francisco 35534-000  carmopolis de minas
#
# Entities [('rua jose alves costa, 698', 'END_LOG')]
# pr centro sao joao do ivai rua jose alves costa, 698 86930-000
#
# Entities [('rua sao matheus,506', 'END_LOG')]
# 36025-000 juiz de fora sao mateus mg rua sao matheus,506
#
# Entities [('av. joo vicente, 1223 e 1235', 'END_LOG')]
# rio de janeiro av. joo vicente, 1223 e 1235 bento ribeiro  rj 21331-260
#
# Entities [('cng 4, lotes 17/18', 'END_LOG')]
# cng 4, lotes 17/18 72130-045 brasilia (taguatinga) df  taguatinga norte
#
# Entities [('rua moises salomao', 'END_LOG')]
# so joo catalao go 75701-485 rua moises salomao
#
# Entities [('pa. manfredo ferreira de souza, 70', 'END_LOG')]
# centro  divisopolis 39912-000 pa. manfredo ferreira de souza, 70 mg
#
# Entities [('rua 1 de janeiro, n 319', 'END_LOG')]
# centro nova odessa 13460-000 sp rua 1 de janeiro, n 319
#
# Entities [('av. das amricas, 21.777', 'END_LOG')]
# 22790-851 lote 3 - parte av. das amricas, 21.777 recreio rj rio de janeiro
#
# Entities [('av dos estados unidos 1', 'END_LOG')]
# av dos estados unidos 1 40010-020 salvador comercio ba 360305
#
# Entities [('r.luiz niemeyer,54', 'END_LOG')]
# 89201-060 12.andar sc joinville centro r.luiz niemeyer,54
#
# Entities [('av. antonio trajano, 211', 'END_LOG')]
# av. antonio trajano, 211 ms centro tres lagoas  79600-000
#
# Entities [('av.  brigadeiro faria lima 1.478', 'END_LOG')]
# 01472-900  sao paulo av.  brigadeiro faria lima 1.478 jardim paulistano sp
#
# Entities [('av. nossa senhora da paz, 2443', 'END_LOG')]
# sao jose do rio preto  15055-500 av. nossa senhora da paz, 2443 vila maceno sp
#
# Entities [('qd 102 sul  av ns 02, lt 08', 'END_LOG')]
# qd 102 sul  av ns 02, lt 08 77020-008 plano diretor sul palmas to
#
# Entities [('av.dr.pereira barreto,79', 'END_LOG')]
# ...
#
# Entities [('av.domingos mariano, 214', 'END_LOG')]
# 27345-310 rj centro  av.domingos mariano, 214 barra mansa
#
# Entities [('av. joao luiz ferreira, 377', 'END_LOG')]
# centro 64800-000  pi av. joao luiz ferreira, 377 floriano
#
# Entities [('rua coronel oliveira, 132', 'END_LOG')]
# rua coronel oliveira, 132 andradas 37795-000 centro  mg
#
# Entities [('av.jose joaquim de almeida, 85', 'END_LOG')]
# av.jose joaquim de almeida, 85 vl.santa maria 77320-000 taguatinga to
#
# Entities [('av.henrique diniz,150', 'END_LOG')]
# centro antonio carlos 36220-000 mg av.henrique diniz,150
#
# Entities [('rua marques de pombal n 535', 'END_LOG')]
# boa vista rr marechal rondon rua marques de pombal n 535 a/b 69308-515
#
# Entities [('rua zacarias goes de vasconcelos s/n.', 'END_LOG')]
# pi 64500-000 centro rua zacarias goes de vasconcelos s/n. oeiras
#
# Entities [('av pst manoel avelino souza,2836', 'END_LOG')]
# rj av pst manoel avelino souza,2836 25250-000 xerem duque de caxias
#
# Entities [('av. brasil, 1800', 'END_LOG')]
# balneario camboriu sc  av. brasil, 1800 88330-000 centro
#
# Entities [('rua xv de novembro, 214', 'END_LOG')]
# sc 89200-000  centro joinville rua xv de novembro, 214
#
# Entities [('av. general carneiro', 'END_LOG')]
# vila lucy 18043-002  sorocaba sp av. general carneiro
#
# Entities [('r. saldanha da gama, 3954', 'END_LOG')]
# criciuma r. saldanha da gama, 3954 sc centro  88802-470
#
# Entities [('av luis muniz, 1030', 'END_LOG')]
# centro santa ines  av luis muniz, 1030 65300-000 ma
#
# Entities [('rua sao cristovao, 600', 'END_LOG')]
# rj  20940-000 rio de janeiro rua sao cristovao, 600 sao cristovao
#
# Entities [('rua almirante gonalves, 35 a', 'END_LOG')]
# copacabana 24466-315 sala 201 rio de janeiro rj rua almirante gonalves, 35 a
#
# Entities [('r.ovidio leme dos santos,140', 'END_LOG')]
# 18160-000 sp predio centro r.ovidio leme dos santos,140 salto de pirapora
#
# Entities [('av. cleriston andrade', 'END_LOG')]
# centro barreiras ba  av. cleriston andrade 47800-358
#
# Entities [('r dr bozano, 854', 'END_LOG')]
# r dr bozano, 854  97015-002 centro rs santa maria
#
# Entities [('praca siqueira campos, 114', 'END_LOG')]
# 45600-021 itabuna centro ba  praca siqueira campos, 114
#
# Entities [('av afonso pena 4360', 'END_LOG')]
# belo horizonte mangabeiras av afonso pena 4360 mg 30130-009
#
# Entities [('av.dos ipes', 'END_LOG')]
# 68515-000 pa nova carajas parauapebas lot.cidade jardim i, qd 16, lts 01 e 02 av.dos ipes
#
# Entities [('r.quinze de novembro,1860', 'END_LOG')]
# r.quinze de novembro,1860 pr sao jose dos pinhais  83005-000 centro
#
# Entities [('av.zumkeller, 217 ao 221', 'END_LOG')]
# av.zumkeller, 217 ao 221  sp sao paulo 02420-000 mandaqui
#
# Entities [('av. presidente vargas qd. 26 - lt.06-p', 'END_LOG')]
# av. presidente vargas qd. 26 - lt.06-p rio verde s.c.:01 75903-290 go jardim gois
#
# Entities [('rua coronel camargo,86', 'END_LOG')]
# 12260-000 rua coronel camargo,86 centro sp paraibuna
#
# Entities [('rua lauro sodre, 445', 'END_LOG')]
# botafogo 22290-070 loja 101 a 47 rio de janeiro rua lauro sodre, 445 rj
#
# Entities [('r.cel.juvencio de menezes,278', 'END_LOG')]
# esq.c/r.dr.sansao gomes ac centro tarauaca r.cel.juvencio de menezes,278 69970-000
#
# Entities [('r.dr.melo viana,294', 'END_LOG')]
# conselheiro lafaiete mg centro  r.dr.melo viana,294 36400-000
#
# Entities [('av. desemb. rivadavia licinio miranda, 76', 'END_LOG')]
# go centro 73840-000 campos belos av. desemb. rivadavia licinio miranda, 76
#
# Entities [('trevo rubem braga,1', 'END_LOG')]
# 29313-815 trevo rubem braga,1  waldir furtado de amorim cachoeiro de itapemirim es
#
# Entities [('r.pref.inacio claudino,78', 'END_LOG')]
# terreo pb centro soledade r.pref.inacio claudino,78 58155-000
#
# Entities []
# maragogi centro 57955-000 al r dr francisca holanda cavalcante s/n
# Entities [('rua joao pessoa, 2008', 'END_LOG')]
# bairro da velha rua joao pessoa, 2008 sc  blumenau 89036-001
#
# Entities [('rua benfica, 1121', 'END_LOG')]
# 50720-001 pe rua benfica, 1121  recife madalena
#
# Entities [('avenida giovanni gronchi', 'END_LOG')]
# sao paulo ljs 160 a 163 sp 05724-003 vila andrade avenida giovanni gronchi
#
# Entities [('tv.felipe camarao,10', 'END_LOG')]
# centro  bom conselho tv.felipe camarao,10 55330-000 pe
#
# Entities [('r. prof. pedro viriato parigot de souza', 'END_LOG')]
# r. prof. pedro viriato parigot de souza  mossungue pr 81200-100 curitiba
#
# Entities [('rua visconde de piraja', 'END_LOG')]
# 22410-001 rua visconde de piraja loja a ipanema rj rio de janeiro
#
# Entities [('av.pres.itamar franco,2530', 'END_LOG')]
# av.pres.itamar franco,2530 s mateus mg 36025-290  juiz de fora
#
# Entities [('av. do comercio, 456', 'END_LOG')]
# santo augusto 98590-000 av. do comercio, 456 centro  rs
#
# Entities [('rua expedicionarios paulistas,473', 'END_LOG')]
# sp rua expedicionarios paulistas,473  luis antonio 14210-000 centro
#
# Entities [('r.olavo bilac,298', 'END_LOG')]
# am tefe em frente a pca.tulio azevedo 69470-000 centro r.olavo bilac,298
#
# Entities [('pca.cel.flavio fernandes,39', 'END_LOG')]
# mg monsenhor paulo centro 37405-000 pca.cel.flavio fernandes,39
#
# Entities [('rua sete de setembro, 601', 'END_LOG')]
# centro rs porto alegre rua sete de setembro, 601 trreo 90010-190
#
# Entities [('av. aristides de melo, 280', 'END_LOG')]
# mg av. aristides de melo, 280 38840-000  carmo do paranaiba centro
#
# Entities [('rua pasteur, 463', 'END_LOG')]
# rua pasteur, 463 80250-080 batel curitiba pr 2 andar, conjunto 204
#
# Entities [('rua cel. luiz da cunha  n 642', 'END_LOG')]
# rua cel. luiz da cunha  n 642 14050-040 sp vila tibrio  ribeirao preto
#
# Entities [('rua joao dalpasquale, 240', 'END_LOG')]
# dois vizinhos  85660-000 rua joao dalpasquale, 240 pr centro
#
# Entities [('av. assis brasil, 3940', 'END_LOG')]
# 12 andar rs av. assis brasil, 3940 porto alegre 91010-003 passo d'areia
#
# Entities [('rua so pedro, 1.228', 'END_LOG')]
# itarare  centro sp 18460-000 rua so pedro, 1.228
#
# Entities [('av. brasil, 4040', 'END_LOG')]
# av. brasil, 4040 pr centro 85812-003 cascavel
#
# Entities [('av.jeronimo monteiro,38/64', 'END_LOG')]
# alegre centro es 29500-000 av.jeronimo monteiro,38/64
#
# Entities [('alameda carlos de carvalho', 'END_LOG')]
# pr batel alameda carlos de carvalho  80730-200 curitiba
#
# Entities [('rua vereador antonio camilo nogeira, 437', 'END_LOG')]
# centro  rua vereador antonio camilo nogeira, 437 19220-000 narandiba sp
#
# Entities [('r almirante barroso,  1062', 'END_LOG')]
# 85851-010 centro  r almirante barroso,  1062 foz do iguacu pr
#
# Entities [('avenida das amricas, 500', 'END_LOG')]
# rio de janeiro rj 22640-904  avenida das amricas, 500 bloco 23 - lojas 103, 104 e 105
#
# Entities [('rua cachoeira, 514', 'END_LOG')]
# rua cachoeira, 514 sp guarulhos 07080-000  jd.rosa de franca
#
# Entities [('rua barao do triunfo, 511', 'END_LOG')]
# brooklin paulista sp rua barao do triunfo, 511  sao paulo 04602-002
#
# Entities [('rua cel. valencio carneiro, 158', 'END_LOG')]
# sp candido mota 19880-000 rua cel. valencio carneiro, 158 centro
#
# Entities [('av agua fria, 1105', 'END_LOG')]
# 02333-001 agua fria  sao paulo sp av agua fria, 1105
#
# Entities [('rua visconde de inhauma, 134-c', 'END_LOG')]
# rua visconde de inhauma, 134-c 20091-000 rj rio de janeiro centro
#
# Entities [('av.ana costa,486', 'END_LOG')]
# 11060-002 sp terreo santos gonzaga av.ana costa,486
#
# Entities [('travessa franscisco leonardo truda, 40', 'END_LOG')]
# rs travessa franscisco leonardo truda, 40 centro 1 andar 90010-904 porto alegre
#
# Entities [('rua raul pompeia, 557', 'END_LOG')]
# cidade industrial rua raul pompeia, 557  pr 81250-320 curitiba
#
# Entities [('av. conselheiro aguiar, 4.310', 'END_LOG')]
# av. conselheiro aguiar, 4.310 51021-020 boa viagem parte recife pe
#
# Entities [('av. julio borella, 805', 'END_LOG')]
# rs centro 99150-000 av. julio borella, 805 marau
#
# Entities [('avenida mogiana, 1700 e 1710', 'END_LOG')]
# ribeirao preto  14075-270 avenida mogiana, 1700 e 1710 sp vila elisa
#
# Entities [('rua vicente linhares, n 500', 'END_LOG')]
# pilotis (trreo) e mezanino fortaleza ce aldeota rua vicente linhares, n 500 60135-270
#
# Entities [('av so gabriel', 'END_LOG')]
# sao paulo itaim bibi 01435-001 sp 12 andar av so gabriel
#
# Entities [('avenida ribeiro junior, 218', 'END_LOG')]
# 69400-000  am centro avenida ribeiro junior, 218 manacapuru
#
# Entities [('av. paulista', 'END_LOG')]
# bela vista av. paulista sao paulo sp 8 andar, cj. 821/823 01311-915
#
# Entities [('av.anhanguera,14404', 'END_LOG')]
# av.anhanguera,14404 capuava 74450-010 sala 258,portal shopping go goiania
#
# Entities [('av. itaberaba 1942', 'END_LOG')]
# sao paulo  av. itaberaba 1942 nossa senhora do o 02739-000 sp
#
# Entities [('rua almirante j. marques de leao, 41', 'END_LOG')]
# 40140-230 barra salvador rua almirante j. marques de leao, 41  ba
#
# Entities [('avenida 31 de maro', 'END_LOG')]
# sp avenida 31 de maro centro 18110-005 votorantim
#
# Entities [('rua comendador jose pereira, 316', 'END_LOG')]
# pe casa f 08 - lot. bela vista maracuja rua comendador jose pereira, 316 55500-000 escada
#
# Entities [('rua cupertino durao', 'END_LOG')]
# lojas d,e,f,g rj 22441-030 rua cupertino durao leblon rio de janeiro
#
# Entities [('avenida ana costa, 185', 'END_LOG')]
# avenida ana costa, 185  gonzaga sp santos 11060-001
#
# Entities [('rua jose de alencar, 357', 'END_LOG')]
# ce rua jose de alencar, 357 62400-000  centro camocim
#
# Entities [('av. getlio vargas, 320', 'END_LOG')]
# 89120-000 av. getlio vargas, 320 timbo  sc centro
#
# Entities [('rua prof. honrio silvestre, 37', 'END_LOG')]
# 28495-000 aperibe rua prof. honrio silvestre, 37 centro  rj
#
# Entities [('av. presidente vargas, 2.205', 'END_LOG')]
# jardim amrica 14020-260  ribeirao preto sp av. presidente vargas, 2.205
#
# Entities [('av. savio gama, 1726', 'END_LOG')]
# rj av. savio gama, 1726 volta redonda retiro 27261-020
#
# Entities [('rua alvaro mendes, n 1140', 'END_LOG')]
# teresina parte pi rua alvaro mendes, n 1140 centro 64000-060
#
# Entities [('av.cupece, 5919/5919', 'END_LOG')]
# av.cupece, 5919/5919 jardim miriam sp  04365-001 sao paulo
#
# Entities [('av. santos dumont, 90/100', 'END_LOG')]
# jardim paulista sp 12215-651  sao jose dos campos av. santos dumont, 90/100
#
# Entities [('avenida presidente juscelino kubitschek', 'END_LOG')]
# vila nova conceio avenida presidente juscelino kubitschek 26 andar (parte) sp sao paulo 04543-907
#
# Entities [('rua do sol, 297', 'END_LOG')]
# 57020-070 centro rua do sol, 297 maceio  al
#
# Entities [('rua freitas de oliveira, 203', 'END_LOG')]
# rua freitas de oliveira, 203 ibirite 32400-000 mg  centro
#
# Entities [('r ramos ferreira, 596 - trreo', 'END_LOG')]
# r ramos ferreira, 596 - trreo  69010-120 am centro manaus
#
# Entities [('av. brigadeiro faria lima', 'END_LOG')]
# sp 3144    / 7 andar 01451-000 sao paulo jardim paulistano av. brigadeiro faria lima
#
# Entities [('rua 13 de maio, 62/68', 'END_LOG')]
# rua 13 de maio, 62/68 centro  rj campos dos goytacazes 28010-260
#
# Entities [('rua suzana dias, 369', 'END_LOG')]
# 06500-000 centro sp santana de parnaiba rua suzana dias, 369
#
# Entities [('r.antonio maia,833', 'END_LOG')]
# sp r.antonio maia,833 sao paulo vl perus 05204-000
#
# Entities [('rua estados unidos', 'END_LOG')]
# sp  rua estados unidos sao paulo 01427-000 jardim amrica
#
# Entities [('est tindiba, 1645', 'END_LOG')]
# 22740-361  rio de janeiro est tindiba, 1645 rj pechincha
#
# Entities [('rua doutor ulhoa cintra', 'END_LOG')]
# rua doutor ulhoa cintra  mogi-mirim 13800-061 centro sp
#
# Entities [('r.vol.da patria,1769', 'END_LOG')]
# sp  r.vol.da patria,1769 02011-300 sao paulo santana
#
# Entities [('av.prof.luciano gualberto,600', 'END_LOG')]
# sao paulo 05508-010 butanta av.prof.luciano gualberto,600  sp
#
# Entities [('r dos bandeirantes, 985', 'END_LOG')]
# ba 40260-000  matatu r dos bandeirantes, 985 salvador
#
# Entities [('r felipe cardoso,', 'END_LOG')]
# lj 13 17 a 23 e 25 23515-000 rj r felipe cardoso, rio de janeiro santa cruz
#
# Entities [('av manoel ribas', 'END_LOG')]
# 85055-010 conradinho av manoel ribas  pr guarapuava
#
# Entities [('av senador teotonio vilela', 'END_LOG')]
# av senador teotonio vilela sao paulo 48010-000 nao ha sp cidade dutra
#
# Entities [('rua benjamim constant, 1850', 'END_LOG')]
# rs porto alegre floresta 90550-002  rua benjamim constant, 1850
#
# Entities [('av. fernando correa da costa, 2988', 'END_LOG')]
# av. fernando correa da costa, 2988 cuiaba coxipo da ponte mt 78070-001
#
# Entities [('avenida governador parigot de souza, 579', 'END_LOG')]
# pr ,  sala 01 zona 01 87013-300 maringa avenida governador parigot de souza, 579
#
# Entities [('pa xv de novembro, 166', 'END_LOG')]
# centro sc florianopolis  pa xv de novembro, 166 88010-400
#
# Entities [('r.pinheiro machado,2264', 'END_LOG')]
# 97700-000  rs santiago centro r.pinheiro machado,2264
#
# Entities [('rua sao pedro, 112', 'END_LOG')]
# sao joao de meriti 25515-270  rj centro rua sao pedro, 112
#
# Entities [('rua municipal marginal, 23.750', 'END_LOG')]
# sp cotia 06715-125 moinho velho  rua municipal marginal, 23.750
#
# Entities [('r fernando cabral, 196', 'END_LOG')]
# pb pedras de fogo 58328-000 centro r fernando cabral, 196
#
# Entities [('av. 9 de abril,2180', 'END_LOG')]
# 11500-000  sp av. 9 de abril,2180 centro cubatao
#
# Entities [('rua conego peregrino,1625', 'END_LOG')]
# patrocinio paulista  rua conego peregrino,1625 sp 14415-000 centro
#
# Entities [('av. praia de belas', 'END_LOG')]
# 90110-000 praia de belas av. praia de belas porto alegre rs
#
# Entities [('r.assis figueiredo,986', 'END_LOG')]
# centro  pocos de caldas r.assis figueiredo,986 mg 37701-000
#
# Entities [('av. 7 de setembro', 'END_LOG')]
# centro 68540-000 av. 7 de setembro  pa conceicao do araguaia
#
# Entities [('r manoel guedes correia gondim lt 474', 'END_LOG')]
# r manoel guedes correia gondim lt 474 pe centro 55920-000  itambe
#
# Entities [('av.de pinedo,239', 'END_LOG')]
# sp av.de pinedo,239 sao paulo 04764-001 socorro
#
# Entities [('av.afonso pena 5572', 'END_LOG')]
# 79040-010  campo grande chacara cachoeira ms av.afonso pena 5572
#
# Entities [('rua borges de medeiros', 'END_LOG')]
# 95020-310 centro caxias do sul rua borges de medeiros rs loja trrea
#
# Entities [('av. pres. castelo branco, 56', 'END_LOG')]
# igrejinha 95650-000 av. pres. castelo branco, 56 centro rs
#
# Entities [('pca.sete de setembro,196', 'END_LOG')]
# centro  pi 64900-000 pca.sete de setembro,196 bom jesus
#
# Entities [('rua  29 de abril, 549', 'END_LOG')]
# guaratuba  centro rua  29 de abril, 549 pr 83280-000
#
# Entities [('av. engenheiro max de souza, 1449', 'END_LOG')]
# 88080-000 florianopolis  coqueiros av. engenheiro max de souza, 1449 sc
#
# Entities [('av.castelo branco', 'END_LOG')]
# 65393-000 buriticupu av.castelo branco  centro ma
#
# Entities [('r.eduardo diehl,169', 'END_LOG')]
# sc riqueza  89895-000 r.eduardo diehl,169 centro
#
# Entities [('rua teodorico-tourinho, 303', 'END_LOG')]
# centro rua teodorico-tourinho, 303 39800-010 mg  teofilo otoni
#
# Entities [('av.antonelo de messina, 1151', 'END_LOG')]
# 02318-000  sao paulo vila paulistana sp av.antonelo de messina, 1151
#
# Entities [('praa cnego lima, 132 e 136', 'END_LOG')]
# sp sao jose dos campos 12210-080 praa cnego lima, 132 e 136 centro
#
# Entities [('praca nove de julho, 168', 'END_LOG')]
# sp 14580-000 centro guara praca nove de julho, 168
#
# Entities [('rua cel.pilad rebua, 1942', 'END_LOG')]
# 79290-000 centro  ms bonito rua cel.pilad rebua, 1942
#
# Entities [('shcs cr quadra 0503', 'END_LOG')]
# bloco b lj 015 df shcs cr quadra 0503 brasilia 70331-520 asa sul
#
# Entities [('av do forte 1628 / 1638', 'END_LOG')]
# rs  vl ipiranga 91360-001 porto alegre av do forte 1628 / 1638
#
# Entities [('av. cesar lattes, qd. 71, lts. 19/20', 'END_LOG')]
# 74363-400  goiania novo horizonte av. cesar lattes, qd. 71, lts. 19/20 go
# Entities [('avenida imirim, 1166/1170 - parte', 'END_LOG')]
# 02464-100 casa verde  sp sao paulo avenida imirim, 1166/1170 - parte
#
# Entities [('av raimundo pereira de magalhes, 12.367', 'END_LOG')]
# 02938-000 sao paulo pirituba av raimundo pereira de magalhes, 12.367 terreo - parte sp
#
# Entities [('lgo.sao joao,2', 'END_LOG')]
# 18700-210 centro sp  avare lgo.sao joao,2
#
# Entities [('praa belarmino essado, 62', 'END_LOG')]
# 75400-000 centro inhumas go praa belarmino essado, 62
#
# Entities [('r.rio grande do sul,822', 'END_LOG')]
# r.rio grande do sul,822 75650-000  morrinhos centro go

# %% [markdown]
# Frase qualquer

# %%
phrase = "SHVP Rua 12 435 casa 22 lote 1"

doc = nlp(phrase)
print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
print(phrase)
# Out:
# Entities [('SHVP Rua 12 435', 'LOGRA')]
# SHVP Rua 12 435 casa 22 lote 1
