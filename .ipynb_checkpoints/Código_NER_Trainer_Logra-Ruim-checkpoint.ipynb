# %%
# Load Packages
from __future__ import unicode_literals, print_function

import plac #  wrapper over argparse
import random
from pathlib import Path
import spacy
from tqdm import tqdm, tqdm_notebook # loading bar 
import pandas as pd
import re
from pprint import pprint
from nltk.tokenize import sent_tokenize
import numpy as np

from spacy.util import minibatch, compounding

# %% [markdown]
# # Abrindo e gerando Datasets

# %% [markdown]
# ### Entidade logradouro

# %%
# Obtendo dados crus de endereço

dataset = pd.read_csv("201906AGENCIAS.CSV")
dset = dataset.iloc[:-2,4:10].values  # tipo nparray object
pd_dset = pd.DataFrame(dset) # caso queira visualizar

pd_dset['Join'] = pd_dset[pd_dset.columns[0:]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)
pd_dset.head(5)
# Out:
#                                           0  \
# 0  R.GUILHERME MOREIRA,315
# 1  AV.PRES.VARGAS,248
# 2  R.QUINZE DE NOVEMBRO,195
# 3  PCA.DAS QUATRO JORNADAS,11
# 4  SEXTA AVENIDA,600
#
#                                                    1  \
# 0  SUBLOJA,LOJA E 2.ANDAR                        ...
# 1  1.E 2.ANDARES                                 ...
# 2                                                ...
# 3  MEZANINO                                      ...
# 4  SECRETARIA DA EDUCACAO-TERREO                 ...
#
#                                 2          3  \
# 0  CENTRO                          69005-300
# 1  CAMPINA                         66010-900
# 2  CENTRO                          11010-908
# 3  CENTRO                          28010-000
# 4  CAB                             41745-002
#
#                                                    4   5  \
# 0  MANAUS                                        ...  AM
# 1  BELEM                                         ...  PA
# 2  SANTOS                                        ...  SP
# 3  CAMPOS DOS GOYTACAZES                         ...  RJ
# 4  SALVADOR                                      ...  BA
#
#                                                 Join
# 0  R.GUILHERME MOREIRA,315                 ;SUBLO...
# 1  AV.PRES.VARGAS,248                      ;1.E 2...
# 2  R.QUINZE DE NOVEMBRO,195                ;     ...
# 3  PCA.DAS QUATRO JORNADAS,11              ;MEZAN...
# 4  SEXTA AVENIDA,600                       ;SECRE...

# %%
# Tratando endereço completo do DataFrame
dset = np.array(pd_dset)
end_lista = []

for i in range(len(dset)):
    str_raw = dset[i][6]
    str_tratada = re.sub(r'[ ]{2,}', "",str_raw) # Tirando espaços excedentes no final do endereço
    str_tratada = re.sub(r'[;]{1,}', "; ", str_tratada) # Para complementos vazios, para não ter 2 ";"
    str_tratada = str_tratada.lower()
    
    end_lista.append(str_tratada)

end_lista[:3]
# Out:
# ['r.guilherme moreira,315; subloja,loja e 2.andar; centro; 69005-300; manaus; am',
#  'av.pres.vargas,248; 1.e 2.andares; campina; 66010-900; belem; pa',
#  'r.quinze de novembro,195; centro; 11010-908; santos; sp']

# %%
# Lógica para extrair posição do logradouro:
# Dividir a String inteira por ";", pegar o len do primeiro split
# len de LOGRA é de 0 até len do primeiro split

print(end_lista[0])
split = end_lista[0].split(";")
print(split)
print(split[0])
print(len(split[0]))
# Out:
# r.guilherme moreira,315; subloja,loja e 2.andar; centro; 69005-300; manaus; am
# ['r.guilherme moreira,315', ' subloja,loja e 2.andar', ' centro', ' 69005-300', ' manaus', ' am']
# r.guilherme moreira,315
# 23

# %%
# Extraindo iob com entidade apenas de logradouro

iob = []

for i in range(len(end_lista)):
    split = end_lista[i].split(";")
    len_logra = len(split[0])
    iob_dict = {"entities": [(0, len_logra-1,'LOGRA')]}
    end_lista[i] = end_lista[i].replace(";", " ")
    end_lista[i] = end_lista[i].replace(",", " ")
    end_lista[i] = re.sub(r'[ ]{2,}', " ", end_lista[i])

    
    tupla = (end_lista[i], iob_dict)
    iob.append(tupla)

FULL_DATA = iob

# %%
print(FULL_DATA[0])
print(FULL_DATA[1])
print(FULL_DATA[2])
print(FULL_DATA[5:15])
# Out:
# ('r.guilherme moreira 315 subloja loja e 2.andar centro 69005-300 manaus am', {'entities': [(0, 22, 'LOGRA')]})
# ('av.pres.vargas 248 1.e 2.andares campina 66010-900 belem pa', {'entities': [(0, 17, 'LOGRA')]})
# ('r.quinze de novembro 195 centro 11010-908 santos sp', {'entities': [(0, 23, 'LOGRA')]})
# [('av.rio branco 240 1.andar recife antigo 50030-310 recife pe', {'entities': [(0, 16, 'LOGRA')]}), ('av.santos dumont 2828 5.andar aldeota 60150-162 fortaleza ce', {'entities': [(0, 20, 'LOGRA')]}), ('pca.tiradentes 410 1.andar centro 80020-100 curitiba pr', {'entities': [(0, 17, 'LOGRA')]}), ('r.uruguai 185 5.andar centro 90010-901 porto alegre rs', {'entities': [(0, 12, 'LOGRA')]}), ('pca.1817 129 1.andar centro 58013-010 joao pessoa pb', {'entities': [(0, 11, 'LOGRA')]}), ('pca.odilon resende andrade 76 centro 37410-000 tres coracoes mg', {'entities': [(0, 28, 'LOGRA')]}), ('av fernandes lima 2591 terreo farol 57057-972 maceio al', {'entities': [(0, 22, 'LOGRA')]}), ('r.treze de junho 914 centro 79300-040 corumba ms', {'entities': [(0, 19, 'LOGRA')]}), ('av.leopoldino de oliveira 3635 centro 38010-000 uberaba mg', {'entities': [(0, 29, 'LOGRA')]}), ('pca.quinze de novembro 321 centro 88010-400 florianopolis sc', {'entities': [(0, 25, 'LOGRA')]})]

# %%
# Criação da base de teste e treinamento

n_test= 0.1 # Porcentagem para base de teste
test_n = round(len(FULL_DATA) * n_test)

# Divisao em Train Test Val

def gerador_bases(dataset, n):
    indices_random = random.sample(range(0,len(dataset)-1), n)
    base_teste_n = []
    base_treinamento_n = []
    
    for i in range(n):
        base_teste_n.append(dataset[indices_random[i]])

    for j in range(len(dataset)):
        if(j not in indices_random):
            base_treinamento_n.append(dataset[j])
            
    return base_teste_n, base_treinamento_n


base_teste, base_treinamento = gerador_bases(FULL_DATA, test_n)

random.shuffle(base_treinamento)
random.shuffle(base_teste)

print("Treinamento: " + str(len(base_treinamento)), "\nTeste: " + str(len(base_teste)), "\nTotal: " + str(len(FULL_DATA)))
# Out:
# Treinamento: 19202
# Teste: 2134
# Total: 21336

# %%
for i in range(5):
    print(base_treinamento[i])
# Out:
# ('rua joaquim medeiros 189 centro 17350-000 igaracu do tiete sp', {'entities': [(0, 24, 'LOGRA')]})
# ('r.jader moura 258 centro 35620-000 abaete mg', {'entities': [(0, 16, 'LOGRA')]})
# ('rua gaviao peixoto icarai 24230-103 niteroi rj', {'entities': [(0, 17, 'LOGRA')]})
# ('av.nove de julho 443 terreo e 1.andar centro 08550-100 poa sp', {'entities': [(0, 19, 'LOGRA')]})
# ('av.prof.mario werneck 1893 buritis 30455-610 belo horizonte mg', {'entities': [(0, 25, 'LOGRA')]})

# %% [markdown]
# # Carregando o modelo

# %%
# Define our variables

model = None
output_dir=Path(".")
n_iter= 100 # número de épocas
batch_size = 32

# %%
# Setting up the pipeline and entity recognizer.
if model is not None:
    nlp = spacy.load(model)  # load existing spacy model
    print("Loaded model '%s'" % model)
else:
    lan = 'pt'
    nlp = spacy.blank(lan)  # create blank Language class
    print("Created blank '%s' model" % lan)
    
if 'ner' not in nlp.pipe_names:
    ner = nlp.create_pipe('ner')
    nlp.add_pipe(ner)
    print('Added new NER')
else:
    ner = nlp.get_pipe('ner')
    print('Got an old NER')
# Out:
# Created blank 'pt' model
# Added new NER

# %%
# create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
if 'ner' not in nlp.pipe_names:
    ner = nlp.create_pipe('ner')
    nlp.add_pipe(ner, last=True)
# otherwise, get it so we can add labels
else:
    ner = nlp.get_pipe('ner')

# %% [markdown]
# ## Treinamento

# %%
print("Batch size: ", batch_size)
print("Épocas: ", n_iter)
print()

# add labels
for _, annotations in base_treinamento:
    for ent in annotations.get('entities'):
        ner.add_label(ent[2])


# get names of other pipes to disable them during training
other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
with nlp.disable_pipes(*other_pipes):  # only train NER
    optimizer = nlp.begin_training()
    for itn in range(n_iter):
        random.shuffle(base_treinamento)
        losses = {}
        batches = minibatch(base_treinamento, size=batch_size)
        
        for batch in batches:
            texts, annotations = zip(*batch)
            try:
                nlp.update(texts, annotations, sgd=optimizer, drop=0.2,
                       losses=losses)
            except:
                pass     
        
        print(itn+1, ' Losses', losses)
# Out:
# Batch size:  32
# Épocas:  100
#
# 1  Losses {'ner': 14458.030195211553}
# 2  Losses {'ner': 5221.318508767399}
# 3  Losses {'ner': 4712.164904081836}
# 4  Losses {'ner': 4133.068568746017}
# 5  Losses {'ner': 3684.138504928653}
# 6  Losses {'ner': 3062.260736042569}
# 7  Losses {'ner': 2894.6741197825754}
# 8  Losses {'ner': 2802.222336271253}
# 9  Losses {'ner': 2553.5831083378944}
# 10  Losses {'ner': 2607.1828144210135}
# 11  Losses {'ner': 2445.9992045489607}
# 12  Losses {'ner': 2195.895211429094}
# 13  Losses {'ner': 2224.368353143533}
# 14  Losses {'ner': 1836.4398862616627}
# 15  Losses {'ner': 1900.8895455258848}
# 16  Losses {'ner': 1828.6064544790343}
# 17  Losses {'ner': 1810.696801848172}
# 18  Losses {'ner': 1624.0787790485062}
# 19  Losses {'ner': 1688.6859203911642}
# 20  Losses {'ner': 1360.8176866249817}
# 21  Losses {'ner': 1467.181350005152}
# 22  Losses {'ner': 1519.873482694738}
# 23  Losses {'ner': 1411.9510929618027}
# 24  Losses {'ner': 1208.8751359337207}
# 25  Losses {'ner': 1252.8895861123806}
# 26  Losses {'ner': 1208.1600241696199}
# 27  Losses {'ner': 1094.5671742861275}
# 28  Losses {'ner': 1058.6059312998807}
# 29  Losses {'ner': 1136.9798963310827}
# 30  Losses {'ner': 1170.0012125429948}
# 31  Losses {'ner': 1179.3981441155258}
# 32  Losses {'ner': 1110.1500109415688}
# 33  Losses {'ner': 1232.7442930410725}
# 34  Losses {'ner': 1076.4040582352266}
# 35  Losses {'ner': 1068.8832268459428}
# 36  Losses {'ner': 1131.5778583787885}
# 37  Losses {'ner': 925.2430057048718}
# 38  Losses {'ner': 1037.7468458291055}
# 39  Losses {'ner': 1042.4737171767445}
# 40  Losses {'ner': 779.1880175979377}
# 41  Losses {'ner': 872.0990972633962}
# 42  Losses {'ner': 933.4400248162867}
# 43  Losses {'ner': 727.3967615495416}
# 44  Losses {'ner': 809.0990515652359}
# 45  Losses {'ner': 1021.9209369615226}
# 46  Losses {'ner': 913.4686173816237}
# 47  Losses {'ner': 967.115576513532}
# 48  Losses {'ner': 818.7815740459251}
# 49  Losses {'ner': 856.5047758230387}
# 50  Losses {'ner': 1191.6074547480914}
# 51  Losses {'ner': 924.5667502855459}
# 52  Losses {'ner': 883.5955295126256}
# 53  Losses {'ner': 844.9163495203819}
# 54  Losses {'ner': 797.4366436519821}
# 55  Losses {'ner': 843.5578627515828}
# 56  Losses {'ner': 861.9919017219003}
# 57  Losses {'ner': 897.1537614692055}
# 58  Losses {'ner': 930.6319233051992}
# 59  Losses {'ner': 736.6092890637467}
# 60  Losses {'ner': 601.4618937460954}
# 61  Losses {'ner': 659.2412887181}
# 62  Losses {'ner': 803.7551050554379}
# 63  Losses {'ner': 862.9934383813459}
# 64  Losses {'ner': 765.5849309410886}
# 65  Losses {'ner': 599.8178069447413}
# 66  Losses {'ner': 673.0623683747872}
# 67  Losses {'ner': 812.4010272066118}
# 68  Losses {'ner': 671.8990373817699}
# 69  Losses {'ner': 656.4493913525779}
# 70  Losses {'ner': 886.2364147186413}
# 71  Losses {'ner': 751.4469102928985}
# 72  Losses {'ner': 672.520342274489}
# 73  Losses {'ner': 717.9893780150101}
# 74  Losses {'ner': 704.2556797362269}
# 75  Losses {'ner': 728.2848861448409}
# 76  Losses {'ner': 604.1737656894816}
# 77  Losses {'ner': 714.5548405319167}
# 78  Losses {'ner': 669.3161349490533}
# 79  Losses {'ner': 527.4466459213342}
# 80  Losses {'ner': 715.6074630044325}
# 81  Losses {'ner': 578.0477655042894}
# 82  Losses {'ner': 557.4721944856266}
# 83  Losses {'ner': 622.5220755829716}
# 84  Losses {'ner': 572.4608385373477}
# 85  Losses {'ner': 720.2713273333927}
# 86  Losses {'ner': 577.1829563935668}
# 87  Losses {'ner': 610.965788540217}
# 88  Losses {'ner': 471.82602215449845}
# 89  Losses {'ner': 569.0636573495158}
# 90  Losses {'ner': 568.0802905264492}
# 91  Losses {'ner': 558.4141653705814}
# 92  Losses {'ner': 510.3583337035938}
# 93  Losses {'ner': 506.74141281853133}
# 94  Losses {'ner': 658.5029919418305}
# 95  Losses {'ner': 455.9513813553393}
# 96  Losses {'ner': 507.9300365997434}
# 97  Losses {'ner': 506.1196730419299}
# 98  Losses {'ner': 732.5691754193028}
# 99  Losses {'ner': 511.19965056443596}
# 100  Losses {'ner': 551.6219375735294}

# %% [markdown]
# ## Teste

# %%
# test the trained model
for text, _ in base_teste:
    doc = nlp(text)
    print(text)
    print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
    print()
# Out:
# pra�a doutor olavo guimar�es centro 14350-000 altinopolis sp
# Entities [('pra�a doutor olavo guimar�es', 'LOGRA')]
#
# rua treze de maio 14 centro 13840-000 mogi-guacu sp
# Entities [('rua treze de maio 14', 'LOGRA')]
#
# r santos barreto lj 603 santo agostinho 30170-070 belo horizonte mg
# Entities [('r santos barreto', 'LOGRA')]
#
# r.paulino nogueira 271 benfica 60020-270 fortaleza ce
# Entities [('r.paulino nogueira 271', 'LOGRA')]
#
# pca.dep.jose alves de assis 8 st central 75830-074 mineiros go
# Entities [('pca.dep.jose alves de assis 8', 'LOGRA')]
#
# boulevard vinte e oito de setembro 293-a vila isabel 20551-030 rio de janeiro rj
# Entities [('boulevard vinte e oito de setembro 293-a', 'LOGRA')]
#
# r sebastiao jose rodrigues campos eliseos 27542-060 resende rj
# Entities [('r sebastiao jose rodrigues', 'LOGRA')]
#
# rua souza dutra lojas 1 e 5 estreito 88070-605 florianopolis sc
# Entities [('rua souza dutra', 'LOGRA')]
#
# avenida silves cachoeirinha 69065-080 manaus am
# Entities [('avenida silves', 'LOGRA')]
#
# av. nestor gomes n. 248 centro 29295-000 vargem alta es
# Entities [('av. nestor gomes n. 248', 'LOGRA')]
#
# praca raimundo p. de magalhaes 158 centro 45260-000 pocoes ba
# Entities [('praca raimundo p. de magalhaes 158', 'LOGRA')]
#
# rua quintino bocaiuva 178 centro 13250-000 itatiba sp
# Entities [('rua quintino bocaiuva 178', 'LOGRA')]
#
# rua epitacio pessoa 75 centro 63500-000 iguatu ce
# Entities [('rua epitacio pessoa 75', 'LOGRA')]
#
# setor c-norte �rea especial 24 72115-902 brasilia (taguatinga) df
# Entities [('setor c-norte �rea especial', 'LOGRA')]
#
# av. aristides de melo 635 centro 38840-000 carmo do paranaiba mg
# Entities [('av. aristides de melo 635', 'LOGRA')]
#
# avenida coronel frederico linck ideal 93336-002 novo hamburgo rs
# Entities [('avenida coronel frederico linck', 'LOGRA')]
#
# av das palmeiras centro 68450-000 moju pa
# Entities [('av das palmeiras', 'LOGRA')]
#
# av. marechal floriano peixoto num 70 centro 89130-000 indaial sc
# Entities [('av. marechal floriano peixoto num 70', 'LOGRA')]
#
# av. eng� roberto freire capim macio 59078-600 natal rn
# Entities [('av. eng� roberto freire', 'LOGRA')]
#
# praca mal deodoro da fonseca centro 49600-000 nossa senhora das dores se
# Entities [('praca mal deodoro da fonseca', 'LOGRA')]
#
# avenida duque de caxias santa efigenia 01214-000 sao paulo sp
# Entities [('avenida duque de caxias', 'LOGRA')]
#
# avenida fernandes lima 2410 farol 57050-000 maceio al
# Entities [('avenida fernandes lima 2410', 'LOGRA')]
#
# rua gregorio ramalho 44 itaquera 08210-430 sao paulo sp
# Entities [('rua gregorio ramalho 44', 'LOGRA')]
#
# rua barao de cotegipe 86-a calcada 40410-001 salvador ba
# Entities [('rua barao de cotegipe 86-a', 'LOGRA')]
#
# avenida seme sim�o jardim bot�nico 38410-675 uberlandia mg
# Entities [('avenida seme sim�o', 'LOGRA')]
#
# est tres rios freguesia (jacarepag 22745-004 rio de janeiro rj
# Entities [('est tres rios freguesia', 'LOGRA')]
#
# av dr odilon de amorim q 41 lote 01/03 parque veiga jardim 74954-290 aparecida de goiania go
# Entities [('av dr odilon de amorim q 41 lote 01/03', 'LOGRA')]
#
# av. governador valadares centro 32600-222 betim mg
# Entities [('av. governador valadares', 'LOGRA')]
#
# praca sao sebastiao 236 centro 76335-000 uruana go
# Entities [('praca sao sebastiao 236', 'LOGRA')]
#
# r. 10 de abril 602 centro 13160-000 artur nogueira sp
# Entities [('r. 10 de abril 602', 'LOGRA')]
#
# rua gabriel andrade junqueira centro 36700-000 leopoldina mg
# Entities [('rua gabriel andrade junqueira', 'LOGRA')]
#
# av.gaspar dutra 1124 qd.73 lote 10 centro 78540-000 claudia mt
# Entities [('av.gaspar dutra 1124', 'LOGRA')]
#
# av.francisco sa 1255 e 1259 lojas 1 e 2 gutierrez 30430-040 belo horizonte mg
# Entities [('av.francisco sa 1255 e 1259', 'LOGRA')]
#
# r.sto.antonio 432 terreo campina 66010-105 belem pa
# Entities [('r.sto.antonio 432', 'LOGRA')]
#
# praca getulio vargas centro 35570-000 formiga mg
# Entities [('praca getulio vargas', 'LOGRA')]
#
# av. jundiai 1184 anhangabau 13208-053 jundiai sp
# Entities [('av. jundiai 1184', 'LOGRA')]
#
# r.rene bittencourt 371 dist.industrial sta.cruz 23565-200 rio de janeiro rj
# Entities [('r.rene bittencourt 371', 'LOGRA')]
#
# r.dois 232 centro 14620-000 orlandia sp
# Entities [('r.dois 232', 'LOGRA')]
#
# r.germano volkart 103 centro 95660-000 tres coroas rs
# Entities [('r.germano volkart 103', 'LOGRA')]
#
# av.zelina 710/714 vila zelina 03143-000 sao paulo sp
# Entities [('av.zelina 710/714', 'LOGRA')]
#
# rua furtado belem 40 centro 69140-000 nhamunda am
# Entities [('rua furtado belem 40', 'LOGRA')]
#
# rua antonio carlos sprotte 182 centro 89245-000 araquari sc
# Entities [('rua antonio carlos sprotte 182', 'LOGRA')]
#
# rua santos dumont 555 centro 89900-000 sao miguel d'oeste sc
# Entities [('rua santos dumont 555', 'LOGRA')]
#
# av goethe 20 rio branco 90430-100 porto alegre rs
# Entities [('av goethe 20', 'LOGRA')]
#
# avenida orlando mascarenhas pereira centro 79570-000 aparecida do taboado ms
# Entities [('avenida orlando mascarenhas pereira', 'LOGRA')]
#
# rua barao de itapetininga 213 centro 01042-001 sao paulo sp
# Entities [('rua barao de itapetininga 213', 'LOGRA')]
#
# avenida doutor vital brasil butant� 05503-000 sao paulo sp
# Entities [('avenida doutor vital brasil', 'LOGRA')]
#
# r.benjamin constant 342 centro 79220-000 nioaque ms
# Entities [('r.benjamin constant 342', 'LOGRA')]
#
# av.prof.vicente rao 2345 jd.petropolis 04636-003 sao paulo sp
# Entities [('av.prof.vicente rao 2345', 'LOGRA')]
#
# rodovia br 316 km 4 s/n centro 67030-970 ananindeua pa
# Entities [('rodovia br 316 km 4 s/n', 'LOGRA')]
#
# av.bandeirantes vila pinheiro 13845-440 mogi-guacu sp
# Entities [('av.bandeirantes vila', 'LOGRA')]
#
# avenida prefeito erasto gaertner bacacheri 82510-160 curitiba pr
# Entities [('avenida prefeito', 'LOGRA')]
#
# r joao cachoeira 754 piso superior vl n conceicao 04535-002 sao paulo sp
# Entities [('r joao cachoeira 754', 'LOGRA')]
#
# av.heraclito rollemberg 1.800 farolandia 49030-640 aracaju se
# Entities [('av.heraclito rollemberg 1.800', 'LOGRA')]
#
# av do forte 1638 vila ipiranga 91360-001 porto alegre rs
# Entities [('av do forte 1638', 'LOGRA')]
#
# p�a dr. luciano esteves dos santos 210 centro 13480-048 limeira sp
# Entities [('p�a dr. luciano esteves dos santos 210', 'LOGRA')]
#
# praca cel odilon coelho 217 centro 39517-000 porteirinha mg
# Entities [('praca cel odilon coelho 217', 'LOGRA')]
#
# avenida weimar gon�alves torre 470 centro 79950-000 navirai ms
# Entities [('avenida weimar gon�alves torre 470', 'LOGRA')]
#
# av. getulio vargas 115 centro 87010-000 maringa pr
# Entities [('av. getulio vargas 115', 'LOGRA')]
#
# praca epitacio pessoa 108 centro 13730-037 mococa sp
# Entities [('praca epitacio pessoa 108', 'LOGRA')]
#
# av afonso pena 4360 mangabeiras 30130-009 belo horizonte mg
# Entities [('av afonso pena 4360', 'LOGRA')]
#
# av.princesa isabel 427 mezanino centro 29010-361 vitoria es
# Entities [('av.princesa isabel 427', 'LOGRA')]
#
# av.sapopemba 4159 terreo v.diva 03374-000 sao paulo sp
# Entities [('av.sapopemba 4159', 'LOGRA')]
#
# av felipe tiago gomes centro 75980-000 parauna go
# Entities [('av felipe tiago gomes', 'LOGRA')]
#
# av. anchieta 219 centro 13015-000 campinas sp
# Entities [('av. anchieta 219', 'LOGRA')]
#
# rua da conceicao 361 360305 centro 63180-000 juazeiro do norte ce
# Entities [('rua da conceicao 361', 'LOGRA')]
#
# av parque centro 69100-006 itacoatiara am
# Entities [('av parque', 'LOGRA')]
#
# r gaviao peixoto 194 lj 101 icarai 24230-102 niteroi rj
# Entities [('r gaviao peixoto 194', 'LOGRA')]
#
# rua olavo ludovico de almeida 800 1 pav. setor oeste 74110-090 goiania go
# Entities [('rua olavo ludovico de almeida 800', 'LOGRA')]
#
# r.vinte e tres de maio 107 v.tereza 09606-000 sao bernardo do campo sp
# Entities [('r.vinte e tres de maio 107', 'LOGRA')]
#
# rua edgar pires de castro 1029 aberta dos morros 91787-235 porto alegre rs
# Entities [('rua edgar pires de castro 1029', 'LOGRA')]
#
# av. central 510 centro 71710-200 brasilia (nucleo bandeirante) df
# Entities [('av. central 510', 'LOGRA')]
#
# avenida hugo musso praia da costa 29101-287 vila velha es
# Entities [('avenida hugo musso', 'LOGRA')]
#
# av. dr. jose augusto moreira 1201 casa caiada 53130-410 olinda pe
# Entities [('av. dr. jose augusto moreira 1201', 'LOGRA')]
#
# rua bar�o do rio branco n� 904 parte centro 60025-060 fortaleza ce
# Entities [('rua bar�o do rio branco n� 904', 'LOGRA')]
#
# av. pres. juscelino kubitschek 2041/2235 bloco a (parte) vila ol�mpia 04543-011 sao paulo sp
# Entities [('av. pres. juscelino kubitschek 2041/2235', 'LOGRA')]
#
# r.sen.clodomir cardoso 1420 cangalheiro volta redonda 65606-530 caxias ma
# Entities [('r.sen.clodomir cardoso 1420', 'LOGRA')]
#
# av. do caf� torre a 5� e 6� andares conj. 502 601 e 602 vila guarani 04311-900 sao paulo sp
# Entities [('av. do caf� torre', 'LOGRA')]
#
# avenida paulista 2� andar bela vista 01310-916 sao paulo sp
# Entities [('avenida paulista', 'LOGRA')]
#
# av. rui barbosa 144 sao francisco 24250-000 niteroi rj
# Entities [('av. rui barbosa 144', 'LOGRA')]
#
# rua xv de novembro 728 parte centro 89010-000 blumenau sc
# Entities [('rua xv de novembro 728', 'LOGRA')]
#
# rua sao louren�o 97980-000 sao paulo das missoes rs
# Entities [('rua sao louren', 'LOGRA')]
#
# rua 15 de novembro 140 centro 14920-000 nova europa sp
# Entities [('rua 15 de novembro 140', 'LOGRA')]
#
# r prof joao falarz 991 cidade industrial 81280-270 curitiba pr
# Entities [('r prof joao falarz 991', 'LOGRA')]
#
# shcs qd.504 bl.b lj.55/56 terreo e subsolo asa sul 70331-525 brasilia df
# Entities [('shcs qd.504 bl.b lj.55/56 terreo e', 'LOGRA')]
#
# av virgilio melo franco 348 360305 centro 37420-000 cambuquira mg
# Entities [('av virgilio melo franco 348', 'LOGRA')]
#
# av. rio branco 532 89500-000 cacador sc
# Entities [('av. rio branco 532', 'LOGRA')]
#
# rua jacaranda 231 esq.c/rua inglaterra 250 eucaliptos 83820-000 fazenda rio grande pr
# Entities [('rua jacaranda 231', 'LOGRA')]
# r prof francisco fonseca 88 lj 1 28990-000 saquarema rj
# Entities [('r prof francisco fonseca 88', 'LOGRA')]
#
# r amador bueno centro 14010-070 ribeirao preto sp
# Entities [('r amador bueno', 'LOGRA')]
#
# av alvares cabral 476 centro 30170-000 belo horizonte mg
# Entities [('av alvares cabral 476', 'LOGRA')]
#
# av. carlos gomes auxiliadora 90480-003 porto alegre rs
# Entities [('av. carlos gomes', 'LOGRA')]
#
# pca.joao pessoa s/n terreo junto a sec.mun.saude centro 75680-000 corumbaiba go
# Entities [('pca.joao pessoa s/', 'LOGRA')]
#
# n�cleo cidade de deus s/n� pr�dio rubi t�rreo sala 2 vila yara 06029-900 osasco sp
# Entities [('n�cleo', 'LOGRA')]
#
# av. presidente vargas 1361 centro 79730-000 gloria de dourados ms
# Entities [('av. presidente vargas 1361', 'LOGRA')]
#
# av.tropical s/n qd.23 lote 4/6 esq.c/r.102 jd.tropical 74946-540 aparecida de goiania go
# Entities [('av.tropical s/', 'LOGRA')]
#
# rua visconde de piraja 495/499/499a - sobreloja ipanema 22410-003 rio de janeiro rj
# Entities [('rua visconde de piraja 495/499/499a -', 'LOGRA')]
#
# praca sao sebastiao 66 centro 15110-000 guapiacu sp
# Entities [('praca sao sebastiao 66', 'LOGRA')]
#
# r.nelsino ravagnani 1077 v.sao jose 86165-000 florestopolis pr
# Entities [('r.nelsino ravagnani 1077', 'LOGRA')]
#
# rua boa vista 356 - 7.andar centro 10140-000 sao paulo sp
# Entities [('rua boa vista 356 - 7.andar', 'LOGRA')]
#
# qc.4 lote 5 s/n setor central 73750-040 planaltina go
# Entities [('qc.4 lote 5 s/n', 'LOGRA')]
#
# av. salgado filho 1.444 centro 07115-000 guarulhos sp
# Entities [('av. salgado filho 1.444', 'LOGRA')]
#
# rua joao pessoa s/n - edf. walter franco terreo centro 49010-130 aracaju se
# Entities [('rua joao pessoa s/n - edf. walter', 'LOGRA')]
#
# rua mariz e barros 32/40 pra�a da bandeira 20270-001 rio de janeiro rj
# Entities [('rua mariz e barros 32/40', 'LOGRA')]
#
# rua heitor penteado 1433 sumarezinho 05437-001 sao paulo sp
# Entities [('rua heitor penteado 1433', 'LOGRA')]
#
# rua 7 de setembro 224 centro 68430-000 igarape-miri pa
# Entities [('rua 7 de setembro 224', 'LOGRA')]
#
# av professor carvalho pinto 210 r central 07700-210 caieiras sp
# Entities [('av professor carvalho pinto 210', 'LOGRA')]
#
# av duque de caxias 431 360305 deodoro 21615-220 rio de janeiro rj
# Entities [('av duque de caxias 431', 'LOGRA')]
#
# r.felipe dos santos 528 comercial centro 16230-000 piacatu sp
# Entities [('r.felipe dos santos 528', 'LOGRA')]
#
# av.getulio vargas 159 centro 95690-000 rolante rs
# Entities [('av.getulio vargas 159', 'LOGRA')]
#
# av.vinte e nove de novembro 510 centro 87260-000 araruna pr
# Entities [('av.vinte e nove de novembro 510', 'LOGRA')]
#
# praca apolinario rebelo 36 centro 57700-000 vicosa al
# Entities [('praca apolinario rebelo 36', 'LOGRA')]
#
# r.ten.camargo 1815 centro 85601-610 francisco beltrao pr
# Entities [('r.ten.camargo 1815', 'LOGRA')]
#
# rua general vitorino 1231 6 regimento de cavalaria blindada restinga seca 97542-311 alegrete rs
# Entities [('rua general vitorino 1231', 'LOGRA')]
#
# r.pref.inacio claudino 78 terreo centro 58155-000 soledade pb
# Entities [('r.pref.inacio claudino 78', 'LOGRA')]
#
# rua conde de bonfim 193-a tijuca 20520-050 rio de janeiro rj
# Entities [('rua conde de bonfim 193-a', 'LOGRA')]
#
# av.pres.vargas 248 3.andar s.publico belem campina 66010-900 belem pa
# Entities [('av.pres.vargas 248', 'LOGRA')]
#
# rua da mooca mooca 03104-000 sao paulo sp
# Entities [('rua da mooca', 'LOGRA')]
#
# rua afonso bras 473 vila nova conceicao 04511-011 sao paulo sp
# Entities [('rua afonso bras 473', 'LOGRA')]
#
# r.dr.sales de oliveira 551 v.industrial 13035-270 campinas sp
# Entities [('r.dr.sales de oliveira 551', 'LOGRA')]
#
# rua dr. joao machado num 961 centro 95940-000 arroio do meio rs
# Entities [('rua dr. joao machado num 961', 'LOGRA')]
#
# av candido de abreu centro civico 80530-906 curitiba pr
# Entities [('av candido de abreu', 'LOGRA')]
#
# av sumare 1130 perdizes 05016-110 sao paulo sp
# Entities [('av sumare 1130', 'LOGRA')]
#
# av.sumare 1231 perdizes 05016-110 sao paulo sp
# Entities [('av.sumare 1231', 'LOGRA')]
#
# r.bento goncalves 783 centro 95520-000 osorio rs
# Entities [('r.bento goncalves 783', 'LOGRA')]
#
# r.santos dumont 2746 12.andar - sala exclusivo zona 01 87013-050 maringa pr
# Entities [('r.santos dumont 2746', 'LOGRA')]
#
# av. centenario 3773 parte centro 88801-000 criciuma sc
# Entities [('av. centenario 3773', 'LOGRA')]
#
# av. jo�o xxiii parque das americas 38045-100 uberaba mg
# Entities [('av. jo�o xxiii', 'LOGRA')]
#
# av. paulo souto centro 45807-000 santa cruz cabralia ba
# Entities [('av. paulo souto', 'LOGRA')]
#
# scn - quadra 2 - bloco a sala 403 - ed. corporate financial center a norte 70712-900 brasilia df
# Entities [('scn - quadra 2 - bloco a sala 403 - ed. corporate', 'LOGRA')]
#
# avenida rio branco 6 a centro 65465-000 cantanhede ma
# Entities [('avenida rio branco 6', 'LOGRA')]
#
# av. independ�ncia universit�rio 96815-000 santa cruz do sul rs
# Entities [('av. independ�ncia universit�rio 96815-000 santa cruz do sul rs', 'LOGRA')]
#
# av. dep. esteves rodrigues 570 centro 39400-215 montes claros mg
# Entities [('av. dep. esteves rodrigues 570', 'LOGRA')]
#
# r.victorino cardoso 235 loja 8 jd.camburi 29090-820 vitoria es
# Entities [('r.victorino cardoso 235', 'LOGRA')]
#
# av.conselheiro aguiar 2159 1 pavimento boa viagem 51111-011 recife pe
# Entities [('av.conselheiro aguiar 2159', 'LOGRA')]
#
# avenida dos autonomistas n� 2344 parte centro 06090-010 osasco sp
# Entities [('avenida dos autonomistas n� 2344', 'LOGRA')]
#
# rua olimp�adas 360 lojas 128/129 vila ol�mpia 04551-000 sao paulo sp
# Entities [('rua olimp�adas 360', 'LOGRA')]
#
# rua augusto maynard 97 centro 49500-000 itabaiana se
# Entities [('rua augusto maynard 97', 'LOGRA')]
#
# av.francisco assis p.oliveira 149 centro 18120-000 mairinque sp
# Entities [('av.francisco assis p.oliveira 149', 'LOGRA')]
#
# rua percilio santana 188 centro 47990-000 formosa do rio preto ba
# Entities [('rua percilio santana 188', 'LOGRA')]
#
# rua do carmo 8 8o. andar centro 20011-020 rio de janeiro rj
# Entities [('rua do carmo 8 8o. andar', 'LOGRA')]
#
# rua belo horizonte 82 sala 1 centro 83860-000 pien pr
# Entities [('rua belo horizonte 82', 'LOGRA')]
#
# av miguel stefano 2029/2031 saude 04301-012 sao paulo sp
# Entities [('av miguel stefano 2029/2031', 'LOGRA')]
#
# rua conde de bonfim n� 685 lojas a e b - parte tijuca 20520-052 rio de janeiro rj
# Entities [('rua conde de bonfim n� 685', 'LOGRA')]
#
# r.andre de albuquerque 56 centro 59190-000 canguaretama rn
# Entities [('r.andre de albuquerque 56', 'LOGRA')]
#
# rua jo�o pereira de vargas nova sapucaia 93230-210 sapucaia do sul rs
# Entities [('rua jo�o pereira de vargas', 'LOGRA')]
#
# r.jeronimo vervloet 178 centro 29650-000 santa teresa es
# Entities [('r.jeronimo vervloet 178', 'LOGRA')]
#
# av j 473 - sn - av 1 qd 6 lt 21 e 22 taioca de fora 49160-971 nossa senhora do socorro se
# Entities [('av j 473 - sn - av 1', 'LOGRA')]
#
# av.ildefonso carneiro 399 terreo centro 75813-000 cacu go
# Entities [('av.ildefonso carneiro 399', 'LOGRA')]
#
# pca.euclides pepino 22 centro 87280-000 iretama pr
# Entities [('pca.euclides pepino 22', 'LOGRA')]
#
# rua joao rosa 289 centro 32900-000 igarape mg
# Entities [('rua joao rosa 289', 'LOGRA')]
#
# pca major jose pedro 17 centro 13730-000 mococa sp
# Entities [('pca major jose pedro 17', 'LOGRA')]
#
# av.dr.oscar geyer 436 centro 84640-000 bituruna pr
# Entities [('av.dr.oscar geyer 436', 'LOGRA')]
#
# rfelicio marcondes 391 terreo centro 07010-030 guarulhos sp
# Entities [('rfelicio marcondes 391', 'LOGRA')]
#
# av professor roberto frade monte marieta 14783-226 barretos sp
# Entities [('av professor roberto', 'LOGRA')]
#
# r francisco gurgel valente centro 63560-000 acopiara ce
# Entities [('r francisco gurgel valente', 'LOGRA')]
#
# travessa jose zipperer 111 parte centro 89290-000 sao bento do sul sc
# Entities [('travessa jose zipperer 111', 'LOGRA')]
#
# rua sete de setembro 500 (parte) centro 13465-320 americana sp
# Entities [('rua sete de setembro 500', 'LOGRA')]
#
# av. navarro de andrade 610 centro 15775-000 santa fe do sul sp
# Entities [('av. navarro de andrade 610', 'LOGRA')]
#
# rua azevedo soares 190 centro 78510-100 franco da rocha sp
# Entities [('rua azevedo soares 190', 'LOGRA')]
#
# r.dr.cunha junior 448 centro 15170-000 tanabi sp
# Entities [('r.dr.cunha junior 448', 'LOGRA')]
#
# rua comendador araujo esq com rua coronel dulc�dio centro 80420-000 curitiba pr
# Entities [('rua comendador araujo esq com rua coronel', 'LOGRA')]
#
# av. fl�vio ribeiro coutinho 805 shopping centro 58037-000 joao pessoa pb
# Entities [('av. fl�vio ribeiro coutinho 805', 'LOGRA')]
#
# rua joaquim antonio 243 centro 37588-000 ipuiuna mg
# Entities [('rua joaquim antonio 243', 'LOGRA')]
#
# rua araguari 801 vila uberabinha 04514-041 sao paulo sp
# Entities [('rua araguari 801', 'LOGRA')]
#
# rua conde de parnaiba 104 centro 13800-140 mogi-mirim sp
# Entities [('rua conde de parnaiba 104', 'LOGRA')]
#
# av. brasil 4040 centro 85812-003 cascavel pr
# Entities [('av. brasil 4040', 'LOGRA')]
#
# av. professor nathan chaves 171 centro 18180-000 tapirai sp
# Entities [('av. professor nathan chaves 171', 'LOGRA')]
#
# r.gastao penalva 119 andarai 20540-220 rio de janeiro rj
# Entities [('r.gastao penalva 119', 'LOGRA')]
#
# av. brigadeiro faria lima 2189 parte jardim paulistano 01452-000 sao paulo sp
# Entities [('av. brigadeiro faria lima 2189', 'LOGRA')]
#
# r professora hilda cunha centro 18760-000 cerqueira cesar sp
# Entities [('r professora hilda cunha', 'LOGRA')]
#
# av. brigadeiro faria lima 4.andar itaim bibi 04538-133 sao paulo sp
# Entities [('av. brigadeiro faria lima 4.andar', 'LOGRA')]
#
# av.cel.antonino 194 cel.antonino 79022-000 campo grande ms
# Entities [('av.cel.antonino 194', 'LOGRA')]
#
# av. maria coelho aguiar 215 blocog centro 05805-000 sao paulo sp
# Entities [('av. maria coelho aguiar 215', 'LOGRA')]
#
# rua rangel pestana centro 13201-000 jundiai sp
# Entities [('rua rangel pestana', 'LOGRA')]
#
# av des. maynard 74 siqueira campos 49055-210 aracaju se
# Entities [('av des. maynard 74', 'LOGRA')]
# av. joao pessoa 649 centro 84570-000 mallet pr
# Entities [('av. joao pessoa 649', 'LOGRA')]
#
# rua volunt�rios da p�tria 1284 6.� andar - conjuntos 606 e 607 santana 02010-200 sao paulo sp
# Entities [('rua volunt�rios da p�tria 1284', 'LOGRA')]
#
# rua barao de jundiai centro 13208-001 jundiai sp
# Entities [('rua barao de jundiai', 'LOGRA')]
#
# scr/sul quadra 511 bloco b loja 15 asa sul 70361-520 brasilia df
# Entities [('scr/sul quadra 511 bloco b loja 15', 'LOGRA')]
#
# scn quadra 4 bloco b petala c loja 86 setor coml.norte 70714-900 brasilia df
# Entities [('scn quadra 4 bloco b petala c', 'LOGRA')]
#
# av felinto rego centro 64120-000 uniao pi
# Entities [('av felinto rego', 'LOGRA')]
#
# av.brasil 888 lojas 02 e 03 santa efigenia 30140-001 belo horizonte mg
# Entities [('av.brasil 888', 'LOGRA')]
#
# avengenheiro roberto freire capim macio 59082-095 natal rn
# Entities [('avengenheiro roberto freire', 'LOGRA')]
#
# rua julio noroes ed. ant�nio a. araripe centro 63150-000 campos sales ce
# Entities [('rua julio noroes ed. ant�nio a. araripe', 'LOGRA')]
#
# avenida visconde do rio branco lojas 245-a 252 253 254 255 e 256 centro 24020-007 niteroi rj
# Entities [('avenida visconde do rio branco', 'LOGRA')]
#
# av. ataulfo de paiva 983 loja b e 1003 leblon 22440-031 rio de janeiro rj
# Entities [('av. ataulfo de paiva 983', 'LOGRA')]
#
# rua 29 de abril centro 98865-000 sao miguel das missoes rs
# Entities [('rua 29 de abril', 'LOGRA')]
#
# av. minas gerais 160 - qd. b lt. 11 jundia� 75110-770 anapolis go
# Entities [('av. minas gerais 160 - qd. b lt.', 'LOGRA')]
#
# av. presidente medici 137/143 jardim mutinga 06268-000 osasco sp
# Entities [('av. presidente medici 137/143', 'LOGRA')]
#
# pca.da independencia s/n casa centro 43900-000 sao francisco do conde ba
# Entities [('pca.da independencia s/', 'LOGRA')]
#
# av.longuinho vieira junior 684 centro 77725-000 colmeia to
# Entities [('av.longuinho vieira junior 684', 'LOGRA')]
#
# r.sen.pinheiro machado 2146 centro 85010-100 guarapuava pr
# Entities [('r.sen.pinheiro machado 2146', 'LOGRA')]
#
# rua m. j. f�lix moreira 421 centro 28970-000 araruama rj
# Entities [('rua m. j. f�lix moreira 421', 'LOGRA')]
#
# rua joaquim floriano 12� andar - conjunto 121 itaim bibi 04534-000 sao paulo sp
# Entities [('rua joaquim floriano', 'LOGRA')]
#
# travessa jose do faro 15 centro 49010-120 aracaju se
# Entities [('travessa jose do faro 15', 'LOGRA')]
#
# pca.da matriz s/n qd 38 lt 180 centro centro 44230-000 amelia rodrigues ba
# Entities [('pca.da matriz s/', 'LOGRA')]
#
# pra�a municipal lote 01 bloco a f�rum milton sebasti�o barbosa 70075-901 brasilia df
# Entities [('pra�a municipal lote 01 bloco a', 'LOGRA')]
#
# rua aymor� s/n centro 68193-000 novo progresso pa
# Entities [('rua aymor� s/', 'LOGRA')]
#
# praca serra lima 637 360305 centro 35010-250 governador valadares mg
# Entities [('praca serra lima 637', 'LOGRA')]
#
# rua paulo de frontin aterrado 27213-270 volta redonda rj
# Entities [('rua paulo de frontin', 'LOGRA')]
#
# pra�a frei eug�nio sao benedito 38010-280 uberaba mg
# Entities [('pra�a frei eug', 'LOGRA')]
#
# av chico brito - quadra 52 lotes 01 02 loteamento planalto iv residencial mota 65975-000 estreito ma
# Entities [('av chico brito - quadra 52', 'LOGRA')]
#
# rua 3 centro 78635-000 agua boa mt
# Entities [('rua 3', 'LOGRA')]
#
# av.aricanduva 5555 arco a v.aricanduva 03527-000 sao paulo sp
# Entities [('av.aricanduva 5555', 'LOGRA')]
#
# av. cristo rei s/n / rua getulio vargas centro 68590-000 jacunda pa
# Entities [('av. cristo rei s/n', 'LOGRA')]
#
# av. goias 500 centro 76590-000 sao miguel do araguaia go
# Entities [('av. goias 500', 'LOGRA')]
#
# r.erno dahmer 502 esq.c/pedro schneider languiru 95890-000 teutonia rs
# Entities [('r.erno dahmer 502', 'LOGRA')]
#
# av.paulo de frontin 110 aterrado 27213-150 volta redonda rj
# Entities [('av.paulo de frontin 110', 'LOGRA')]
#
# av.pelinca 142 loja 1 pelinca 28035-053 campos dos goytacazes rj
# Entities [('av.pelinca 142 loja 1', 'LOGRA')]
#
# travessa oliveira bello sobreloja - parte centro 80020-030 curitiba pr
# Entities [('travessa oliveira bello', 'LOGRA')]
#
# rua d. manuel silveira delboux 40 centro 85900-000 toledo pr
# Entities [('rua d. manuel silveira delboux 40', 'LOGRA')]
#
# rua mal floriano 349 96200-380 rio grande rs
# Entities [('rua mal floriano 349', 'LOGRA')]
#
# rua verissimo prado 157 centro 13520-000 sao pedro sp
# Entities [('rua verissimo prado 157', 'LOGRA')]
#
# avenida francisco matarazzo 1400 1 andar cj 11 edificio milano a branca 05001-903 sao paulo sp
# Entities [('avenida francisco matarazzo 1400', 'LOGRA')]
#
# av ver.joao fernandes da silva 253 vl virginia 08576-000 itaquaquecetuba sp
# Entities [('av ver.joao fernandes da silva 253', 'LOGRA')]
#
# praca felipe santos centro 47650-000 correntina ba
# Entities [('praca felipe santos', 'LOGRA')]
#
# av.prof.ana maria silvestre adade s/n puc campinas parque das universidades 13086-130 campinas sp
# Entities [('av.prof.ana maria silvestre adade s/', 'LOGRA')]
#
# rua olavo bilac 44 centro 16010-050 aracatuba sp
# Entities [('rua olavo bilac 44', 'LOGRA')]
#
# r.honorata luiza teixeira 3 centro 37115-000 monte belo mg
# Entities [('r.honorata luiza teixeira 3', 'LOGRA')]
#
# av. panama 22 piraveve 79740-000 ivinhema ms
# Entities [('av. panama 22', 'LOGRA')]
#
# rua joaquim da silva reis 446 centro 84900-000 ibaiti pr
# Entities [('rua joaquim da silva reis 446', 'LOGRA')]
#
# av carlos gomes 222 14� andar b. auxiliadora ed. opus one auxiliadora 90480-000 porto alegre rs
# Entities [('av carlos gomes 222', 'LOGRA')]
#
# av. crist�v�o colombo n. 2830 conjunto 903 floresta 96560-002 porto alegre rs
# Entities [('av. crist�v�o colombo n. 2830', 'LOGRA')]
#
# rua dr. joao colin 259 centro 89201-300 joinville sc
# Entities [('rua dr. joao colin 259', 'LOGRA')]
#
# pca.bernardino v.dos santos 84 centro 75950-000 jandaia go
# Entities [('pca.bernardino v.dos santos 84', 'LOGRA')]
#
# r.jose barone mercadante 700 centro 15440-000 nova granada sp
# Entities [('r.jose barone mercadante 700', 'LOGRA')]
#
# rua independencia 09 centro 13240-000 jarinu sp
# Entities [('rua independencia 09', 'LOGRA')]
#
# rua gessyr gon�alves fontes n� 100 parte centro 25520-570 sao joao de meriti rj
# Entities [('rua gessyr gon�alves fontes n� 100', 'LOGRA')]
#
# av. brigadeiro faria lima n� 3900 10� andar-cond.edif.pedro mariz-b31 itaim bibi 04538-132 sao paulo sp
# Entities [('av. brigadeiro faria lima n� 3900', 'LOGRA')]
#
# av denise cristina rocha guadalajara (justinopolis) 33900-001 ribeirao das neves mg
# Entities [('av denise cristina rocha guadalajara (', 'LOGRA')]
#
# av guilherme cotching 1819 2 andar vl maria 02113-017 sao paulo sp
# Entities [('av guilherme cotching 1819', 'LOGRA')]
#
# av monteiro lobato macedo 07112-000 guarulhos sp
# Entities [('av monteiro', 'LOGRA')]
#
# praca ruy barbosa 14 centro 14540-000 igarapava sp
# Entities [('praca ruy barbosa 14', 'LOGRA')]
#
# rua marechal deodoro 170 3 pavimento centro 80010-010 curitiba pr
# Entities [('rua marechal deodoro 170', 'LOGRA')]
#
# rua duque de caxias 1632 centro 97500-180 uruguaiana rs
# Entities [('rua duque de caxias 1632', 'LOGRA')]
#
# rua pereira de rezende 700 centro 17350-000 igaracu do tiete sp
# Entities [('rua pereira de rezende 700', 'LOGRA')]
#
# av nove de julho 1700 qd 10 jardim america 14020-170 ribeirao preto sp
# Entities [('av nove de julho 1700', 'LOGRA')]
#
# rua padre carapuceiro 777 lojas 213/214 boa viagem 51020-900 recife pe
# Entities [('rua padre carapuceiro 777', 'LOGRA')]
#
# avenida zeca abreu s/n quadra 13 lote 08 centro 68560-000 santana do araguaia pa
# Entities [('avenida zeca abreu s/n', 'LOGRA')]
#
# avenida jose paulino sta cecilia 13140-320 paulinia sp
# Entities [('avenida jose paulino sta', 'LOGRA')]
#
# rua floriano peixoto 633 centro 63500-000 iguatu ce
# Entities [('rua floriano peixoto 633', 'LOGRA')]
#
# pra�a rio branco centro 49830-000 gararu se
# Entities [('pra�a rio branco', 'LOGRA')]
#
# av. bernardo say�o n�s 1343 e 1347 centro 65907-000 imperatriz ma
# Entities [('av. bernardo say�o n�s 1343 e 1347', 'LOGRA')]
#
# av. dr. chucri zaidan bloco b andar 3 4 e 7 vila cordeiro 04583-110 sao paulo sp
# Entities [('av. dr. chucri zaidan bloco b andar 3 4', 'LOGRA')]
#
# av angelica 1937 6�andar consolacao 01227-200 sao paulo sp
# Entities [('av angelica 1937', 'LOGRA')]
#
# av.delfim moreira 650 centro 25953-235 teresopolis rj
# Entities [('av.delfim moreira 650', 'LOGRA')]
#
# rua leonardo malcher 1862 centro 69015-000 manaus am
# Entities [('rua leonardo malcher 1862', 'LOGRA')]
#
# rua 15 de novembro 124 centro 83880-000 rio negro pr
# Entities [('rua 15 de novembro 124', 'LOGRA')]
#
# rua sidonio pais 37 ls slj ssl cascadura 21350-031 rio de janeiro rj
# Entities [('rua sidonio pais 37', 'LOGRA')]
#
# av. brasil 3817 centro 87501-000 umuarama pr
# Entities [('av. brasil 3817', 'LOGRA')]
#
# r.jorge lacerda 285 sala centro 88445-000 leoberto leal sc
# Entities [('r.jorge lacerda 285', 'LOGRA')]
#
# rua halfeld 592/600 60746948 centro 36013-000 juiz de fora mg
# Entities [('rua halfeld 592/600', 'LOGRA')]
#
# rua general telles 1226 360305 centro 18602-903 botucatu sp
# Entities [('rua general telles 1226', 'LOGRA')]
#
# r.vinte e seis 797 centro 14780-100 barretos sp
# Entities [('r.vinte e seis 797', 'LOGRA')]
#
# av. angelica 1.212 parte santa cecilia 01228-100 sao paulo sp
# Entities [('av. angelica 1.212', 'LOGRA')]
#
# av. gomes de matos 1554 montese 60410-001 fortaleza ce
# Entities [('av. gomes de matos 1554', 'LOGRA')]
#
# av nacoes unidas 7� andar brooklin novo 04578-000 sao paulo sp
# Entities [('av nacoes unidas', 'LOGRA')]
#
# rua jose bocchiglieri 48/50 vila sao jose 04836-000 sao paulo sp
# Entities [('rua jose bocchiglieri 48/50', 'LOGRA')]
#
# av. 16 de setembro 40 centro 38420-000 monte alegre de minas mg
# Entities [('av. 16 de setembro 40', 'LOGRA')]
#
# av. presidente getulio vargas centro 99670-000 ronda alta rs
# Entities [('av. presidente getulio vargas', 'LOGRA')]
#
# r dr joao guiao 786 vila virginia 14030-440 ribeirao preto sp
# Entities [('r dr joao guiao 786', 'LOGRA')]
#
# rua padre eust�quio 2760 padre eust�quio 30720-100 belo horizonte mg
# Entities [('rua padre eust�quio 2760', 'LOGRA')]
#
# rua julio de castilhos 95600-000 taquara rs
# Entities [('rua julio de castilhos 95600-000', 'LOGRA')]
#
# av. dr. joao vargens centro 45880-000 camacan ba
# Entities [('av. dr. joao vargens', 'LOGRA')]
# av brasil lj 109-07 a 11 guadalupe 21670-000 rio de janeiro rj
# Entities [('av brasil lj 109-07 a 11', 'LOGRA')]
#
# avenida copacabana balne�rio monte carlo 11925-000 ilha comprida sp
# Entities [('avenida copacabana balne', 'LOGRA')]
#
# rua presidente costa e silva centro 68527-000 abel figueiredo pa
# Entities [('rua presidente costa e silva', 'LOGRA')]
#
# av. jones dos santos neves 88 centro 29960-000 conceicao da barra es
# Entities [('av. jones dos santos neves 88', 'LOGRA')]
#
# pca.pedro gomes 274 terreo centro 42600-000 madre de deus ba
# Entities [('pca.pedro gomes 274', 'LOGRA')]
#
# av.portugal 519 centro 09041-321 santo andre sp
# Entities [('av.portugal 519', 'LOGRA')]
#
# rua cedros 301 centro 78520-000 guaranta do norte mt
# Entities [('rua cedros 301', 'LOGRA')]
#
# av. dantas barreto 1024 sao jose 50020-000 recife pe
# Entities [('av. dantas barreto 1024', 'LOGRA')]
#
# av.das americas 16691 lojas a b c d e r. ministro a.baleeiro 840 ljs.f g e h recreio dos bandeirantes 22790-701 rio de janeiro rj
# Entities [('av.das americas 16691', 'LOGRA')]
#
# avenida bernardo say�o 1.790 vila carajas 65907-300 imperatriz ma
# Entities [('avenida bernardo say�o 1.790', 'LOGRA')]
#
# rua augusta 1655 consola��o 01305-100 sao paulo sp
# Entities [('rua augusta 1655', 'LOGRA')]
#
# estrada get�lio vargas 1.306 centro 26525-010 rio de janeiro rj
# Entities [('estrada get�lio vargas 1.306', 'LOGRA')]
#
# r do tesouro pq santos dumont 06754-190 taboao da serra sp
# Entities [('r do tesouro', 'LOGRA')]
#
# avenidae esq. c/rua 72n 2 centro 75890-000 sao simao go
# Entities [('avenidae esq. c/rua 72n', 'LOGRA')]
#
# pca. charles muller 108 pacaembu 01234-010 sao paulo sp
# Entities [('pca. charles muller 108', 'LOGRA')]
#
# av. alvaro otacilio 3309 jatiuca 57035-000 maceio al
# Entities [('av. alvaro otacilio 3309', 'LOGRA')]
#
# avenida presidente juscelino kubitschek 2041 e 2235 bloco a 18� andar vila ol�mpia 04543-011 sao paulo sp
# Entities [('avenida presidente juscelino kubitschek 2041 e 2235', 'LOGRA')]
#
# av independencia 543 centro 97650-000 itaqui rs
# Entities [('av independencia 543', 'LOGRA')]
#
# av. pereira barreto 1286 para�so 09190-210 santo andre sp
# Entities [('av. pereira barreto 1286', 'LOGRA')]
#
# av. getulio vargas 470 funcionarios 30112-020 belo horizonte mg
# Entities [('av. getulio vargas 470', 'LOGRA')]
#
# rua dr brandao 54 360305 centro 37400-000 campanha mg
# Entities [('rua dr brandao 54', 'LOGRA')]
#
# r.dr.jose joaquim seabra 1449 baixa dos sapateiros 40025-000 salvador ba
# Entities [('r.dr.jose joaquim seabra 1449', 'LOGRA')]
#
# pca.pe.alderigi 77 centro 37775-000 santa rita de caldas mg
# Entities [('pca.pe.alderigi 77', 'LOGRA')]
#
# avenida presidente juscelino kubitschek 145515 andar itaim bibi 04543-011 sao paulo sp
# Entities [('avenida presidente juscelino kubitschek', 'LOGRA')]
#
# av. mato grosso 212-s centro 78455-000 lucas do rio verde mt
# Entities [('av. mato grosso 212-s', 'LOGRA')]
#
# avenida antonio carlos 652 centro 37730-000 campestre mg
# Entities [('avenida antonio carlos 652', 'LOGRA')]
#
# rua doutor alfredo backer 605 parte alcantara 24710-395 sao goncalo rj
# Entities [('rua doutor alfredo backer 605', 'LOGRA')]
#
# av. 15 de novembro centro 99490-000 tapera rs
# Entities [('av. 15 de novembro', 'LOGRA')]
#
# av.bezerra de menezes 2461 defronte ao north-shopping parquelandia 60325-004 fortaleza ce
# Entities [('av.bezerra de menezes 2461', 'LOGRA')]
#
# avenida das amoreiras jardim do lago 13050-035 campinas sp
# Entities [('avenida das amoreiras', 'LOGRA')]
#
# av.duque de caxias 448 centro 87013-180 maringa pr
# Entities [('av.duque de caxias 448', 'LOGRA')]
#
# praca osvaldo cruz 143 paraiso 04004-070 sao paulo sp
# Entities [('praca osvaldo cruz 143', 'LOGRA')]
#
# av. modolo s/n� lote 130 pedra azul arace 29278-000 domingos martins es
# Entities [('av. modolo s/n�', 'LOGRA')]
#
# pc general valadao 3� andar centro 49010-906 aracaju se
# Entities [('pc general valadao 3� andar', 'LOGRA')]
#
# av. rio branco 193 - 1. e 2. subsolos - ljs.2 e 3 centro 20040-008 rio de janeiro rj
# Entities [('av. rio branco 193 - 1. e 2.', 'LOGRA')]
#
# av.teixeira e souza 527 centro 28907-410 cabo frio rj
# Entities [('av.teixeira e souza 527', 'LOGRA')]
#
# alameda terracota piso s�o paulo cer�mica 09531-190 sao caetano do sul sp
# Entities [('alameda terracota piso s', 'LOGRA')]
#
# av cons moreira de barros 2841 lauzane paulista 02430-001 sao paulo sp
# Entities [('av cons moreira de barros 2841', 'LOGRA')]
#
# rua nove de julho sala 27 centro 32800-000 vinhedo sp
# Entities [('rua nove de julho', 'LOGRA')]
#
# rua cap. gabriel 262 centro 07011-010 guarulhos sp
# Entities [('rua cap. gabriel 262', 'LOGRA')]
#
# av castanheiras s/n lj 68 norte (aguas claras) 71900-100 brasilia df
# Entities [('av castanheiras s/', 'LOGRA')]
#
# av. dr. silveira neto centro 99840-000 sananduva rs
# Entities [('av. dr. silveira neto', 'LOGRA')]
#
# rua carlos alberto de souza parracho 69 centro 45848-000 itabela ba
# Entities [('rua carlos alberto de souza parracho 69', 'LOGRA')]
#
# av. presidente roosevelt 621 centro 17900-000 dracena sp
# Entities [('av. presidente roosevelt 621', 'LOGRA')]
#
# av corifeu de azevedo marques 5963 vila lageado 05339-005 sao paulo sp
# Entities [('av corifeu de azevedo marques 5963', 'LOGRA')]
#
# r. governador valadares n� 165 centro 39680-000 capelinha mg
# Entities [('r. governador valadares n� 165', 'LOGRA')]
#
# avenida sto. antonio 194 centro 55700-000 limoeiro pe
# Entities [('avenida sto. antonio 194', 'LOGRA')]
#
# rua 7 de setembro 1762 centro 68370-000 altamira pa
# Entities [('rua 7 de setembro 1762', 'LOGRA')]
#
# av. rodrigues alves 18-80 higienopolis 17013-000 bauru sp
# Entities [('av. rodrigues alves 18-80', 'LOGRA')]
#
# av.raul veiga 135 centro 28540-000 cordeiro rj
# Entities [('av.raul veiga 135', 'LOGRA')]
#
# av.presidente kennedy 2528 agua verde 80610-010 curitiba pr
# Entities [('av.presidente kennedy 2528', 'LOGRA')]
#
# rua assis freitas centro 96495-000 candiota rs
# Entities [('rua assis freitas', 'LOGRA')]
#
# rua do sol 192 centro 57020-070 maceio al
# Entities [('rua do sol 192', 'LOGRA')]
#
# rua magalh�es barata centro 68470-000 oeiras do para pa
# Entities [('rua magalh�es barata', 'LOGRA')]
#
# r.otaviano santos lisboa 82 terreo centro 45460-000 wenceslau guimaraes ba
# Entities [('r.otaviano santos lisboa 82', 'LOGRA')]
#
# avenida mario ferreira 142 centro 75180-000 silvania go
# Entities [('avenida mario ferreira 142', 'LOGRA')]
#
# av.dario antunes da rosa 173 centro 97385-000 vila nova do sul rs
# Entities [('av.dario antunes da rosa 173', 'LOGRA')]
#
# avenida jos� odorizzi 151 portaria 8 (p36-10) vila euro 09810-902 sao bernardo do campo sp
# Entities [('avenida jos� odorizzi 151', 'LOGRA')]
#
# av. fernando ferrari 2033 goiabeiras 29075-051 vitoria es
# Entities [('av. fernando ferrari 2033', 'LOGRA')]
#
# av. antonio piranga 171 centro 09911-160 diadema sp
# Entities [('av. antonio piranga 171', 'LOGRA')]
#
# s. educacional lotes c/d centro de ensino fundamental 4 73310-150 brasilia (planaltina) df
# Entities [('s. educacional lotes c/d centro de ensino fundamental 4 73310-150 brasilia (planaltina', 'LOGRA')]
#
# rua da bahia 951 1 andar centro 30160-011 belo horizonte mg
# Entities [('rua da bahia 951', 'LOGRA')]
#
# rua 25 de dezembro 1119 centro 85950-000 palotina pr
# Entities [('rua 25 de dezembro 1119', 'LOGRA')]
#
# rua clemente alvares 368 lapa 05074-050 sao paulo sp
# Entities [('rua clemente alvares 368', 'LOGRA')]
#
# av.presidente vargas quadra 40 lotes 9/10 1 andar jd.goias 75903-290 rio verde go
# Entities [('av.presidente vargas quadra 40', 'LOGRA')]
#
# av. goias 409 centro 76380-000 goianesia go
# Entities [('av. goias 409', 'LOGRA')]
#
# av pres.vargas centro 68637-000 ipixuna do para pa
# Entities [('av pres.vargas', 'LOGRA')]
#
# praca rui barbosa 92 centro 45570-000 ipiau ba
# Entities [('praca rui barbosa 92', 'LOGRA')]
#
# r.dr.alfredo guedes 40 predio centro 13710-000 tambau sp
# Entities [('r.dr.alfredo guedes 40', 'LOGRA')]
#
# rua pouso alegre 2342 360305 horto 31015-030 belo horizonte mg
# Entities [('rua pouso alegre 2342', 'LOGRA')]
#
# sbs quadra 1 bloco a lote 31 terreo setor banc�rio sul asa sul 70073-900 brasilia df
# Entities [('sbs quadra 1 bloco a lote 31 terreo setor banc�rio sul asa sul 70073-900 brasilia df', 'LOGRA')]
#
# pca.aprigio de toledo 40 centro 12940-670 atibaia sp
# Entities [('pca.aprigio de toledo 40', 'LOGRA')]
#
# r.janio quadros 47 centro 38320-000 santa vitoria mg
# Entities [('r.janio quadros 47', 'LOGRA')]
#
# av rui barbosa 100 centro 88801-120 criciuma sc
# Entities [('av rui barbosa 100', 'LOGRA')]
#
# avenida fernando costa 610 vila jaiara 75064-780 anapolis go
# Entities [('avenida fernando costa 610', 'LOGRA')]
#
# av castanheira parque da ladeira 68473-000 novo repartimento pa
# Entities [('av castanheira', 'LOGRA')]
#
# rua aristides lobo loja a / 241 - lojas a rio comprido 20250-450 rio de janeiro rj
# Entities [('rua aristides lobo', 'LOGRA')]
#
# av.treze de maio 393 centro 79965-000 itaquirai ms
# Entities [('av.treze de maio 393', 'LOGRA')]
#
# rua barao de campinas 376 centro 13480-210 limeira sp
# Entities [('rua barao de campinas 376', 'LOGRA')]
#
# r.halfeld 770 calcadao centro 36010-003 juiz de fora mg
# Entities [('r.halfeld 770', 'LOGRA')]
#
# av. washington luiz 2455 60746948 jardim marajoara 04662-002 sao paulo sp
# Entities [('av. washington luiz 2455', 'LOGRA')]
#
# avenida rio madeira 3288 lojas 201/02 flodoaldo pontes pinto 76820-408 porto velho ro
# Entities [('avenida rio madeira 3288', 'LOGRA')]
#
# av. jose de alencar 614 menino deus 90880-480 porto alegre rs
# Entities [('av. jose de alencar 614', 'LOGRA')]
#
# rua sao martinho num 1088 centro 14850-000 pradopolis sp
# Entities [('rua sao martinho num 1088', 'LOGRA')]
#
# rua torres goncalves 236 esq.r.valentim zambonatto centro 99700-000 erechim rs
# Entities [('rua torres goncalves 236', 'LOGRA')]
#
# avenida alvares cabral 1� andar lourdes 30170-915 belo horizonte mg
# Entities [('avenida alvares cabral', 'LOGRA')]
#
# praca joao lisboa 177 terreo/subsolo centro 65010-310 sao luis ma
# Entities [('praca joao lisboa 177', 'LOGRA')]
#
# av francisco porto 902 treze de julho 49020-570 aracaju se
# Entities [('av francisco porto 902', 'LOGRA')]
# rua getulio vargas 663 centro 19260-000 mirante do paranapanema sp
# Entities [('rua getulio vargas 663', 'LOGRA')]
#
# praca luiz gama 8/1 largo do tanque 40357-300 salvador ba
# Entities [('praca luiz gama 8/1', 'LOGRA')]
#
# av. princesa isabel 1.298 perequ� 11630-000 ilhabela sp
# Entities [('av. princesa isabel 1.298', 'LOGRA')]
#
# rua marechal deodoro da fonseca centro 95760-000 sao sebastiao do cai rs
# Entities [('rua marechal deodoro da fonseca', 'LOGRA')]
#
# shd bloco j/a st. comercial central 73310-200 brasilia (planaltina) df
# Entities [('shd bloco j/a', 'LOGRA')]
#
# av.brig.luis antonio 3370 prox.ginasio ibirapuera jd.paulista 01402-001 sao paulo sp
# Entities [('av.brig.luis antonio 3370', 'LOGRA')]
#
# rua voluntarios da patria bl 1 lj a botafogo 22270-010 rio de janeiro rj
# Entities [('rua voluntarios da patria bl 1', 'LOGRA')]
#
# r.marechal deodoro 748 esq.c/r.cons.laurindo centro 80010-010 curitiba pr
# Entities [('r.marechal deodoro 748', 'LOGRA')]
#
# r.manoel sobral 553 centro 64400-000 amarante pi
# Entities [('r.manoel sobral 553', 'LOGRA')]
#
# av. independencia 890 independencia 90035-072 porto alegre rs
# Entities [('av. independencia 890', 'LOGRA')]
#
# av. rodolfo mallard 177 centro 39270-000 pirapora mg
# Entities [('av. rodolfo mallard 177', 'LOGRA')]
#
# av. dr. j�lio maranh�o 887 ed. jeanne d �rc lojas 02 a 05 e aptos. 102 e 103 prazeres 54340-740 jaboatao dos guararapes pe
# Entities [('av. dr. j�lio maranh�', 'LOGRA')]
#
# r julio conceicao 438 terreo varejo b retiro 01126-000 sao paulo sp
# Entities [('r julio conceicao 438', 'LOGRA')]
#
# rua estado de israel 975 vila clementino 04022-002 sao paulo sp
# Entities [('rua estado de israel 975', 'LOGRA')]
#
# pca joaquim carlos garcia 354 centro 15430-000 altair sp
# Entities [('pca joaquim carlos garcia 354', 'LOGRA')]
#
# av.vigario joao jose rodrigues 120/124 vila arens 13200-000 jundiai sp
# Entities [('av.vigario joao jose rodrigues 120/124', 'LOGRA')]
#
# r.gal.flores da cunha 416 centro 96890-000 sinimbu rs
# Entities [('r.gal.flores da cunha 416', 'LOGRA')]
#
# r.mal.deodoro 400-e ed.executivo piemonte 1.andar centro 89802-140 chapeco sc
# Entities [('r.mal.deodoro 400-e', 'LOGRA')]
#
# avenida da saudade 888 ponte preta 13041-670 campinas sp
# Entities [('avenida da saudade 888', 'LOGRA')]
#
# av italia 1579 jardim das na��es 12030-212 taubate sp
# Entities [('av italia 1579', 'LOGRA')]
#
# rua joaquim nabuco 138 brooklin pta. 04621-001 sao paulo sp
# Entities [('rua joaquim nabuco 138', 'LOGRA')]
#
# rua piranga 5 lojas f g h meier 20720-030 rio de janeiro rj
# Entities [('rua piranga 5 lojas f g h', 'LOGRA')]
#
# av. dr. pereira vergueiro s/n� vila nhocun� 03563-000 sao paulo sp
# Entities [('av. dr. pereira vergueiro s/n�', 'LOGRA')]
#
# rua do catete 222-a catete 22220-001 rio de janeiro rj
# Entities [('rua do catete 222-a', 'LOGRA')]
#
# r.jeronimo monteiro 190 centro 29620-000 itarana es
# Entities [('r.jeronimo monteiro 190', 'LOGRA')]
#
# av.castro alves 465 somenzari 17506-000 marilia sp
# Entities [('av.castro alves 465', 'LOGRA')]
#
# av.vilarinho 1450 pq.sao pedro(venda nova) 31610-070 belo horizonte mg
# Entities [('av.vilarinho 1450', 'LOGRA')]
#
# av.jorge lacerda 1128 centro 88443-000 vidal ramos sc
# Entities [('av.jorge lacerda 1128', 'LOGRA')]
#
# rua br�s cubas 119 vila nova 11013-163 santos sp
# Entities [('rua br�s cubas 119', 'LOGRA')]
#
# avenida do rio pequeno 865 360305 butant� 05379-000 sao paulo sp
# Entities [('avenida do rio pequeno 865', 'LOGRA')]
#
# r maria de lourdes s/n centro 62280-000 santa quiteria ce
# Entities [('r maria de lourdes s/n', 'LOGRA')]
#
# av.jose pinheiro borges s/n. pav.terreo vl.campanela 08220-900 sao paulo sp
# Entities [('av.jose pinheiro borges s/n', 'LOGRA')]
#
#  r hortencias jardim do estadio 09175-500 santo andre sp
# Entities []
#
# r siqueira campos 75 bosque 19010-060 presidente prudente sp
# Entities [('r siqueira campos 75', 'LOGRA')]
#
# r.d.anesia castelo 1 centro 63610-000 mombaca ce
# Entities [('r.d.anesia castelo 1', 'LOGRA')]
#
# avenida mutinga 2474 jardim santo elias 05110-000 sao paulo sp
# Entities [('avenida mutinga 2474', 'LOGRA')]
#
# rodovia stael mary bicalho m magalh�es loja 1 belvedere 30320-760 belo horizonte mg
# Entities [('rodovia stael mary bicalho m magalh�', 'LOGRA')]
#
# rua juvencio de araujo figueiredo num 633 a 651 vila perus 52041-400 sao paulo sp
# Entities [('rua juvencio de araujo figueiredo num 633 a 651', 'LOGRA')]
#
# rua amandau 118 centro 98960-000 santo cristo rs
# Entities [('rua amandau 118', 'LOGRA')]
#
# estrada uniao e industria 10322 10328 10336 e 10340 itaipava 25730-745 petropolis rj
# Entities [('estrada uniao e industria 10322', 'LOGRA')]
#
# rua da matriz centro 99835-000 aurea rs
# Entities [('rua da matriz', 'LOGRA')]
#
# av.guilherme cotching 1556 v.maria 02113-012 sao paulo sp
# Entities [('av.guilherme cotching 1556', 'LOGRA')]
#
# rua conceicao 380 centro 84130-000 palmeira pr
# Entities [('rua conceicao 380', 'LOGRA')]
#
# rua marechal rondon matinha 68415-000 limoeiro do ajuru pa
# Entities [('rua marechal rondon', 'LOGRA')]
#
# av.vinte e nove de dezembro 327 centro 88485-000 sao bonifacio sc
# Entities [('av.vinte e nove de dezembro 327', 'LOGRA')]
#
# rua presidente vargas 786 centro 37170-000 boa esperanca mg
# Entities [('rua presidente vargas 786', 'LOGRA')]
#
# pca.dr.garcia coutinho 373/1 esq.c/r.bom jesus 373 centro 37550-000 pouso alegre mg
# Entities [('pca.dr.garcia coutinho 373/1', 'LOGRA')]
#
# av.vale do pimenta parte 2 10 qd.01 olho d'agua prq atlantico 65066-160 sao luis ma
# Entities [('av.vale do pimenta parte 2', 'LOGRA')]
#
# r. herculino otaviano 868 terreo centro 85440-000 ubirata pr
# Entities [('r. herculino otaviano 868', 'LOGRA')]
#
# r.dr.julio dos reis filho 55 centro 18960-000 bernardino de campos sp
# Entities [('r.dr.julio dos reis filho 55', 'LOGRA')]
#
# avenida carlos lindemberg lj b gloria 29122-355 vila velha es
# Entities [('avenida carlos lindemberg', 'LOGRA')]
#
# avenida sao joao 1187 novo oriente 86039-290 londrina pr
# Entities [('avenida sao joao 1187', 'LOGRA')]
#
# av. herm�genes coelho 2085 centro 76100-000 sao luis de montes belos go
# Entities [('av. herm�genes coelho 2085', 'LOGRA')]
#
# praca marco antonio primon maestre 250 limao 02710-030 sao paulo sp
# Entities [('praca marco antonio primon maestre 250', 'LOGRA')]
#
# r.aurelino leal 41/43 centro 24020-110 niteroi rj
# Entities [('r.aurelino leal 41/43', 'LOGRA')]
#
# avenida brasil lote 05 quadra 35 - nucleo urbano centro 68550-005 redencao pa
# Entities [('avenida brasil lote 05 quadra 35 -', 'LOGRA')]
#
# r.das nossa senhora merces 1039 vl merces 04165-001 sao paulo sp
# Entities [('r.das nossa senhora merces 1039', 'LOGRA')]
#
# avenida nossa senhora de copacabana loja copacabana 22050-002 rio de janeiro rj
# Entities [('avenida nossa senhora de copacabana', 'LOGRA')]
#
# av. portugal 895 centro 09040-011 santo andre sp
# Entities [('av. portugal 895', 'LOGRA')]
#
# rua venancio aires 353 centro 97010-001 santa maria rs
# Entities [('rua venancio aires 353', 'LOGRA')]
#
# rua ten. nicolau maffei 258 centro 19010-010 presidente prudente sp
# Entities [('rua ten. nicolau maffei 258', 'LOGRA')]
#
# rua 1� de janeiro n� 319 centro 13460-000 nova odessa sp
# Entities [('rua 1� de janeiro n� 319', 'LOGRA')]
#
# rua frei caneca 1380 conjunto 31/e- ed. crystal tower consola��o 01307-002 sao paulo sp
# Entities [('rua frei caneca 1380', 'LOGRA')]
#
# av. de pinedo 505 parte socorro 04764-001 sao paulo sp
# Entities [('av. de pinedo 505', 'LOGRA')]
#
# r jeronimo coelho 205 parte centro 88010-030 florianopolis sc
# Entities [('r jeronimo coelho 205', 'LOGRA')]
#
# rua senador pedro lago 72 centro 44700-000 jacobina ba
# Entities [('rua senador pedro lago 72', 'LOGRA')]
#
# rua altino arantes 555 centro 18970-000 chavantes sp
# Entities [('rua altino arantes 555', 'LOGRA')]
#
# rua rio jurua 30 terreo central 68900-012 macapa ap
# Entities [('rua rio jurua 30', 'LOGRA')]
#
# rua presidente nereu ramos 128 centro 88502-170 lages sc
# Entities [('rua presidente nereu ramos 128', 'LOGRA')]
#
# av major amarantes 3271 centro 78950-000 vilhena ro
# Entities [('av major amarantes 3271', 'LOGRA')]
#
# r.salvador roberto 1375 centro 39260-000 varzea da palma mg
# Entities [('r.salvador roberto 1375', 'LOGRA')]
#
# estrada mirandela 165 centro 26520-330 nilopolis rj
# Entities [('estrada mirandela 165', 'LOGRA')]
#
# avenida brigadeiro faria lima 9� andar itam bibi 04538-133 sao paulo sp
# Entities [('avenida brigadeiro faria lima', 'LOGRA')]
#
# scr/norte q. 502 bl. b asa norte 70730-517 brasilia df
# Entities [('scr/norte q. 502', 'LOGRA')]
#
# rua rio de janeiro 750 2.andar centro 30160-041 belo horizonte mg
# ...
#
# avenida tancredo neves setor institucional 76872-854 ariquemes ro
# Entities [('avenida tancredo neves', 'LOGRA')]
#
# av eng. luiz carlos berrini 5� andar - conjs 51 e 52 - edif�cio berrini one cidade mon��es 04571-010 sao paulo sp
# Entities [('av eng. luiz carlos berrini', 'LOGRA')]
#
# r.jose sponchiado 154 centro 99830-000 gaurama rs
# Entities [('r.jose sponchiado 154', 'LOGRA')]
#
# r.sao jose 358 centro 36500-000 uba mg
# Entities [('r.sao jose 358', 'LOGRA')]
#
# rua xv de novembro centro 83414-000 colombo pr
# Entities [('rua xv de novembro', 'LOGRA')]
#
# av.sete de setembro 2775 7 andar - sala 9138 reboucas 80230-010 curitiba pr
# Entities [('av.sete de setembro 2775', 'LOGRA')]
#
# rua nove de agosto 108 centro 45818-000 porto seguro ba
# Entities [('rua nove de agosto 108', 'LOGRA')]
#
# av santos dumont s/n rodoviaria 65278-000 turiacu ma
# Entities [('av santos dumont s/n', 'LOGRA')]
#
# av.oscar ornelas 350 centro 37880-000 cabo verde mg
# Entities [('av.oscar ornelas 350', 'LOGRA')]
#
# rua dr. jorge tibirica 679 centro 13830-000 santo antonio de posse sp
# Entities [('rua dr. jorge tibirica 679', 'LOGRA')]
#
# alameda rio negro n� 585 edif�cio ja�ari - bloco a - loja 02 00000-000 barueri sp
# Entities [('alameda rio negro n� 585', 'LOGRA')]
#
# rua das laranjeiras 495/rua gal glicerio 32 laranjeiras 22240-002 rio de janeiro rj
# Entities [('rua das laranjeiras 495/rua gal', 'LOGRA')]
#
# alameda santos 2313 e 2315 cerqueira cesar 14190-020 sao paulo sp
# Entities [('alameda santos 2313 e 2315', 'LOGRA')]
#
# rua 7 de setembro ed. crist. launizen centro 58400-105 campina grande pb
# Entities [('rua 7 de setembro ed. crist.', 'LOGRA')]
#
# rua antonio lourenco xavier 142 centro 12120-970 tremembe sp
# Entities [('rua antonio lourenco xavier 142', 'LOGRA')]
#
# rua francisco glicerio centro 13250-330 itatiba sp
# Entities [('rua francisco glicerio', 'LOGRA')]
#
# av. dr silvio bezerra de melo centro 59380-000 currais novos rn
# Entities [('av. dr silvio bezerra de melo', 'LOGRA')]
#
# av.joao vargens 89 centro 45880-000 camacan ba
# Entities [('av.joao vargens 89', 'LOGRA')]
#
# av.getulio vargas 641 funcionarios 30112-020 belo horizonte mg
# Entities [('av.getulio vargas 641', 'LOGRA')]
#
# av das nuvens 1andar aldeia da serra 06519-225 santana de parnaiba sp
# Entities [('av das nuvens 1andar', 'LOGRA')]
#
# rua sete de setembro 601 t�rreo centro 90010-190 porto alegre rs
# Entities [('rua sete de setembro 601', 'LOGRA')]
#
# av. antonio afonso de lima 365 parte centro 07400-000 aruja sp
# Entities [('av. antonio afonso de lima 365', 'LOGRA')]
#
# praca dr. souto soares s/n. centro 46930-000 palmeiras ba
# Entities [('praca dr. souto soares s/n', 'LOGRA')]
#
# avenida presidente kennedy centro 77500-000 porto nacional to
# Entities [('avenida presidente kennedy', 'LOGRA')]
#
# av. henrique de holanda vit�ria park shopping loja 2005 1� piso reden��o 55612-901 vitoria de santo antao pe
# Entities [('av. henrique de holanda vit�ria', 'LOGRA')]
#
# r.pres.backer 54 lojas 101/102 icarai 24220-041 niteroi rj
# Entities [('r.pres.backer 54', 'LOGRA')]
#
# av.manoel ribas 515 centro 85580-000 itapejara d'oeste pr
# Entities [('av.manoel ribas 515', 'LOGRA')]
#
# pc gov. luiz cavalcanti s/n centro 57360-000 girau do ponciano al
# Entities [('pc gov. luiz cavalcanti s/n', 'LOGRA')]
#
# av. mal. ribas j�nior 35 centro 76180-000 nazario go
# Entities [('av. mal. ribas j�nior 35', 'LOGRA')]
#
# rua maria prestes maia vila guilherme 02047-000 sao paulo sp
# Entities [('rua maria prestes maia', 'LOGRA')]
#
# rua xv de novembro 7290 centro 85010-000 guarapuava pr
# Entities [('rua xv de novembro 7290', 'LOGRA')]
#
# r.sta.terezinha 721 pca.antonio joaquim moura andrade centro 16901-006 andradina sp
# Entities [('r.sta.terezinha 721', 'LOGRA')]
#
# av. comendador santanna 1154 capao redondo 05866-000 sao paulo sp
# Entities [('av. comendador santanna 1154', 'LOGRA')]
#
# av. professor alfonso bovero 1.221 parte perdizes 05019-011 sao paulo sp
# Entities [('av. professor alfonso bovero 1.221', 'LOGRA')]
#
# av pres kennedy 5152 / 5156/ 5166 / 517 tupi 11703-200 praia grande sp
# Entities [('av pres kennedy 5152 / 5156/ 5166 / 517', 'LOGRA')]
#
# avenida dos bragas 115 centro 39700-000 pecanha mg
# Entities [('avenida dos bragas 115', 'LOGRA')]
#
# praca 15 de novembro 60 centro 13720-000 sao jose do rio pardo sp
# Entities [('praca 15 de novembro 60', 'LOGRA')]
#
# av.antonio sales 55 centro 62680-000 paracuru ce
# Entities [('av.antonio sales 55', 'LOGRA')]
#
# r.garcia lorca 301 loja 33 pauliceia 09695-000 sao bernardo do campo sp
# Entities [('r.garcia lorca 301 loja 33', 'LOGRA')]
#
# rua ushima kira 87 granja viana 06709-048 cotia sp
# Entities [('rua ushima kira 87', 'LOGRA')]
#
# av.major sales 697 terreo centro 62650-000 uruburetama ce
# Entities [('av.major sales 697', 'LOGRA')]
#
# av. rio das pedras 1879/1889 jd.aricanduva 03453-100 sao paulo sp
# Entities [('av. rio das pedras 1879/1889', 'LOGRA')]
#
# av.irmaos guinle 901 60746948 centro 26323-130 queimados rj
# Entities [('av.irmaos guinle 901', 'LOGRA')]
#
# rua major matheus 236 vila dos lavradores 18609-083 botucatu sp
# Entities [('rua major matheus 236', 'LOGRA')]
#
# r.ernest renan 1366 paraisopolis 05659-020 sao paulo sp
# Entities [('r.ernest renan 1366', 'LOGRA')]
#
# rua rui barbosa 45 centro 64000-090 teresina pi
# Entities [('rua rui barbosa 45', 'LOGRA')]
#
# rua princesa isabel cidade alta 59025-400 natal rn
# Entities [('rua princesa isabel', 'LOGRA')]
#
# av. fernando guilhon 4.950 centro 67200-000 marituba pa
# Entities [('av. fernando guilhon 4.950', 'LOGRA')]
#
# av teixeira e souza braga 28909-001 cabo frio rj
# Entities [('av teixeira e souza', 'LOGRA')]
#
# rua boa vista 280 7� andar centro 01014-000 sao paulo sp
# Entities [('rua boa vista 280', 'LOGRA')]
#
# rua geovani marinho de melo 323 anexo - parte mangabeira 58056-350 joao pessoa pb
# Entities [('rua geovani marinho de melo 323', 'LOGRA')]
#
# r.do comercio 170 centro 57340-000 feira grande al
# Entities [('r.do comercio 170', 'LOGRA')]
#
# rua 7 de setembro centro 85900-220 toledo pr
# Entities [('rua 7 de setembro', 'LOGRA')]
#
# av. getulio vargas 204 centro 45810-000 porto seguro ba
# Entities [('av. getulio vargas 204', 'LOGRA')]
#
# avenida narciso silva 1830 centro 96160-000 capao do leao rs
# Entities [('avenida narciso silva 1830', 'LOGRA')]
#
# rua waldemar carlos pereira 509 v.matilde 03533-001 sao paulo sp
# Entities [('rua waldemar carlos pereira 509', 'LOGRA')]
#
# av.jose maria fernandes 162 pq.novo mundo 02185-030 sao paulo sp
# Entities [('av.jose maria fernandes 162', 'LOGRA')]
#
# estrada raul veiga alcantara 24730-060 sao goncalo rj
# Entities [('estrada raul veiga', 'LOGRA')]
#
# av sete 487 centro 38240-000 itapagipe mg
# Entities [('av sete 487', 'LOGRA')]
#
# av. brasil 470 centro 85200-000 pitanga pr
# Entities [('av. brasil 470', 'LOGRA')]
#
# av. sapopemba 4.089 loja e sobreloja - parte sapopemba 03374-000 sao paulo sp
# Entities [('av. sapopemba 4.089', 'LOGRA')]
#
# av. ayrton senna da silva 1511 loja 41 - c/d tude bastos (s�tio do campo) 11726-000 praia grande sp
# Entities [('av. ayrton senna da silva 1511', 'LOGRA')]
#
# avenida republica do libano qd d2 lt 24e setor oeste 74125-125 goiania go
# Entities [('avenida republica do libano qd d2 lt 24e', 'LOGRA')]
#
# av.brasil 390 centro 79740-000 ivinhema ms
# Entities [('av.brasil 390', 'LOGRA')]
#
# av. rodrigues da fonseca vila nova 91740-800 porto alegre rs
# Entities [('av. rodrigues da fonseca', 'LOGRA')]
#
# pca.tiradentes 410 2.andar centro 80020-100 curitiba pr
# Entities [('pca.tiradentes 410', 'LOGRA')]
#
# avenida do farol s/n lojas 31 32 33 34 shopping armazem da vila praia do forte 48280-000 mata de sao joao ba
# Entities [('avenida do farol s/n', 'LOGRA')]
#
# av.ragueb chohfi 7001 jd.tres marias 08375-000 sao paulo sp
# Entities [('av.ragueb chohfi 7001', 'LOGRA')]
#
# rua sao cristovao 600 conjunto 2 sao cristovao 20940-000 rio de janeiro rj
# Entities [('rua sao cristovao 600', 'LOGRA')]
#
# rua carlos gomes n� 09 periperi 40725-610 salvador ba
# Entities [('rua carlos gomes n� 09', 'LOGRA')]
#
# av.leopoldo peres 583 educandos 69070-250 manaus am
# Entities [('av.leopoldo peres 583', 'LOGRA')]
#
# rua 01 s/n quadra 56 - lote 22 jardim do oriente 72870-201 valparaiso de goias go
# Entities [('rua 01 s/n', 'LOGRA')]
#
# pra�a padre dami�o 67 360305 vila prudente 03126-050 sao paulo sp
# Entities [('pra�a padre dami�o 67', 'LOGRA')]
#
# rua abdalla miguel sarraff 212 centro 84550-000 reboucas pr
# Entities [('rua abdalla miguel sarraff 212', 'LOGRA')]
#
# av.santos dumont 2889 1.andar esq.c/des.moreira-loja 1 aldeota 60150-161 fortaleza ce
# Entities [('av.santos dumont 2889', 'LOGRA')]
#
# rua borges de medeiros 2581 centro 95670-000 gramado rs
# Entities [('rua borges de medeiros 2581', 'LOGRA')]
# av. barao do rio branco 419 centro 89500-000 cacador sc
# Entities [('av. barao do rio branco 419', 'LOGRA')]
#
# av. benjamin pinto dias 1647 parte belford roxo 26130-000 belford roxo rj
# Entities [('av. benjamin pinto dias 1647', 'LOGRA')]
#
# r sao sebastiao centro 14015-040 ribeirao preto sp
# Entities [('r sao sebastiao', 'LOGRA')]
#
# rua presidente kennedy 1051 centro 93806-346 sapiranga rs
# Entities [('rua presidente kennedy 1051', 'LOGRA')]
#
# r pres vargas lt 07a qd m centro 35460-000 brumadinho mg
# Entities [('r pres vargas', 'LOGRA')]
#
# rua santo antonio 118 centro 18185-000 pilar do sul sp
# Entities [('rua santo antonio 118', 'LOGRA')]
#
# shc/sw clsw 304 bloco b lojas c/numeros pares de 32 a 50) setor sudoeste 70670-622 brasilia df
# Entities [('shc/sw clsw 304', 'LOGRA')]
#
# ltm merepe s/n lt 3a q a2 porto de galinhas 55590-000 ipojuca pe
# Entities [('ltm merepe s/n', 'LOGRA')]
#
# av. santos dumont 2834 c/av.desem.moreira aldeota 60150-161 fortaleza ce
# Entities [('av. santos dumont 2834', 'LOGRA')]
#
# rua cel. pena de moraes 95180-000 farroupilha rs
# Entities [('rua cel. pena de moraes 95180-000', 'LOGRA')]
#
# av. gentil bittencourt nazare 66040-172 belem pa
# Entities [('av. gentil bittencourt', 'LOGRA')]
#
# pca.mons.jose m.de santana 27 centro 49980-000 neopolis se
# Entities [('pca.mons.jose m.de santana 27', 'LOGRA')]
#
# rua boqueir�o 351 igara 92410-350 canoas rs
# Entities [('rua boqueir�o 351', 'LOGRA')]
#
# av. pontes vieira 2000 dionisio torres 60130-241 fortaleza ce
# Entities [('av. pontes vieira 2000', 'LOGRA')]
#
# rua da mooca 2479 mooca 03103-003 sao paulo sp
# Entities [('rua da mooca 2479', 'LOGRA')]
#
# r. adhemar da silva 1087 kobrasol 88101-091 sao jose sc
# Entities [('r. adhemar da silva 1087', 'LOGRA')]
#
# av. presidente kennedy 1804 loja e sobreloja - parte centro 25020-001 duque de caxias rj
# Entities [('av. presidente kennedy 1804', 'LOGRA')]
#
# rua euclides faria 2 / 4 ramos 21060-100 rio de janeiro rj
# Entities [('rua euclides faria 2 / 4', 'LOGRA')]
#
# rua dr.reinaldo schmithausen 2160 cordeiros 88310-003 itajai sc
# Entities [('rua dr.reinaldo schmithausen 2160', 'LOGRA')]
#
# rua bar�o do rio branco centro 68440-000 abaetetuba pa
# Entities [('rua bar�o do rio branco', 'LOGRA')]
#
# av belem 241 centro 68488-000 breu branco pa
# Entities [('av belem 241', 'LOGRA')]
#
# av.cons.nebias 164 esq.c/setesetembr paqueta 11015-000 santos sp
# Entities [('av.cons.nebias 164', 'LOGRA')]
#
# rua. barao de studart 2105 - loja 1 jardim tavora 60120-002 fortaleza ce
# Entities [('rua. barao de studart 2105 - loja 1', 'LOGRA')]
#
# rua leopoldo peres 922 educandos 69070-250 manaus am
# Entities [('rua leopoldo peres 922', 'LOGRA')]
#
# av brasil jardim america 01430-001 sao paulo sp
# Entities [('av brasil', 'LOGRA')]
#
# av.parada pinto 2262 lojas 240 241 242 vila nova cachoeirinha 02611-001 sao paulo sp
# Entities [('av.parada pinto 2262', 'LOGRA')]
#
# rua conde do bonfim 38 tijuca 20520-053 rio de janeiro rj
# Entities [('rua conde do bonfim 38', 'LOGRA')]
#
# rua 1. de janeiro 50 centro 77650-000 miracema do tocantins to
# Entities [('rua 1. de janeiro 50', 'LOGRA')]
#
# pca. capitao joao pinto fontao 45 centro 13880-000 vargem grande do sul sp
# Entities [('pca. capitao joao pinto fontao 45', 'LOGRA')]
#
# r dr jose peroba 244 stiep 41770-235 salvador ba
# Entities [('r dr jose peroba 244', 'LOGRA')]
#
# rua dr alfredo backer 376 alcantara 24452-005 sao goncalo rj
# Entities [('rua dr alfredo backer 376', 'LOGRA')]
#
# pca.pe.leonardo 48 centro 12970-000 piracaia sp
# Entities [('pca.pe.leonardo 48', 'LOGRA')]
#
# rua gessyr goncalves fontes 146 centro 25520-570 sao joao de meriti rj
# Entities [('rua gessyr goncalves fontes 146', 'LOGRA')]
#
# av. nove de julho 580 centro 16880-000 valparaiso sp
# Entities [('av. nove de julho 580', 'LOGRA')]
#
# av.brigadeiro jose vicente de faria lima 1129 jardim maria augusta 12070-000 taubate sp
# Entities [('av.brigadeiro jose vicente de faria lima 1129', 'LOGRA')]
#
# av. capitao jose narciso s/n centro 49490-000 poco verde se
# Entities [('av. capitao jose narciso s/n', 'LOGRA')]
#
# r.rio jurua 30 3.andar - sala exclusivo central 68900-012 macapa ap
# Entities [('r.rio jurua 30', 'LOGRA')]
#
# rua general netto 1122 centro 96100-000 pelotas rs
# Entities [('rua general netto 1122', 'LOGRA')]
#
# rua 4 n. 271 centro 38910-000 iguatama mg
# Entities [('rua 4 n. 271', 'LOGRA')]
#
# rua paula souza 73 centro 01027-001 sao paulo sp
# Entities [('rua paula souza 73', 'LOGRA')]
#
# av.nereu ramos 3367 meia praia 88220-000 itapema sc
# Entities [('av.nereu ramos 3367', 'LOGRA')]
#
# av.getulio vargas 60 centro 39827-000 pote mg
# Entities [('av.getulio vargas 60', 'LOGRA')]
#
# pca.dom jose gaspar 106 republica 01047-010 sao paulo sp
# Entities [('pca.dom jose gaspar 106', 'LOGRA')]
#
# rua samuel klabin 794 centro 84261-050 telemaco borba pr
# Entities [('rua samuel klabin 794', 'LOGRA')]
#
# rua prefeito pedro moreira borges centro 37542-000 estiva mg
# Entities [('rua prefeito pedro moreira borges', 'LOGRA')]
#
# rua jose vasconcelos 1237 centro 15740-000 dolcinopolis sp
# Entities [('rua jose vasconcelos 1237', 'LOGRA')]
#
# rua cap. deslandes 66 centro 29300-190 cachoeiro de itapemirim es
# Entities [('rua cap. deslandes 66', 'LOGRA')]
#
# r.parapua 7/9 itaberaba 02831-000 sao paulo sp
# Entities [('r.parapua 7/9', 'LOGRA')]
#
# av. paulo faccini 352 jdim. s.paulo 07111-000 guarulhos sp
# Entities [('av. paulo faccini 352', 'LOGRA')]
#
# r ribeiro de barros centro 14820-000 americo brasiliense sp
# Entities [('r ribeiro de barros', 'LOGRA')]
#
# praca eduardo rudge 14 pari 03028-010 sao paulo sp
# Entities [('praca eduardo rudge 14', 'LOGRA')]
#
# av.goias 980 terreo e sobreloja centro 74010-010 goiania go
# Entities [('av.goias 980', 'LOGRA')]
#
# av.joao cesar de oliveira 3435 loja 101 santa cruz industrial 32340-001 contagem mg
# Entities [('av.joao cesar de oliveira 3435', 'LOGRA')]
#
#  rua felipe schmidt 1531 centro 89570-000 catanduvas sc
# Entities []
#
# av. governador amaral peixoto 471 centro 26210-060 nova iguacu rj
# Entities [('av. governador amaral peixoto 471', 'LOGRA')]
#
# r dom marcos barbosa lj j e k cidade nova 20211-178 rio de janeiro rj
# Entities [('r dom marcos barbosa', 'LOGRA')]
#
# av.ex-combatentes s/n centro 47520-000 ibotirama ba
# Entities [('av.ex-combatentes s/', 'LOGRA')]
#
# r.um 151 qd.9 lote 1 centro 75570-000 bom jesus de goias go
# Entities [('r.um 151', 'LOGRA')]
#
# avenida azenha 855 azenha 90160-002 porto alegre rs
# Entities [('avenida azenha 855', 'LOGRA')]
#
# r.cons.franco 418 centro 44002-272 feira de santana ba
# Entities [('r.cons.franco 418', 'LOGRA')]
#
# av.wilson alvarenga 49 loja 1 v.regina 35970-000 barao de cocais mg
# Entities [('av.wilson alvarenga 49', 'LOGRA')]
#
# av.dos holandeses s/n qd.9 lote 11 loteamento boa vista sao marcos 65075-650 sao luis ma
# Entities [('av.dos holandeses s/', 'LOGRA')]
#
# r.floriano peixoto 44 centro 16010-220 aracatuba sp
# Entities [('r.floriano peixoto 44', 'LOGRA')]
#
# av. joao gualberto 1740 juveve 80030-001 curitiba pr
# Entities [('av. joao gualberto 1740', 'LOGRA')]
#
# pca.pe.aleixo monteiro mafra 70/72 sao miguel paulista 08011-010 sao paulo sp
# Entities [('pca.pe.aleixo monteiro mafra 70/72', 'LOGRA')]
#
# r.dr.silva martins 210 centro 65520-000 brejo ma
# Entities [('r.dr.silva martins 210', 'LOGRA')]
#
# rua domingos lopes 741 madureira 21310-120 rio de janeiro rj
# Entities [('rua domingos lopes 741', 'LOGRA')]
#
# av otavio mangabeira centro 45860-000 canavieiras ba
# Entities [('av otavio mangabeira', 'LOGRA')]
#
# av. santos dumont terreo aldeota 60150-161 fortaleza ce
# Entities [('av. santos dumont', 'LOGRA')]

# %%
ph ="""
        "PREFEITURA DE Certidão de Dados Cadastrais do Imóvel - IPTU 2017\n\nSÃO PAULO\n\nFAZENDA",
        "Cadastro do Imóvel: 067.061.0048-1",
        "| Local do Imóvel:",
        "| AVJACANA, 764- AP 104 E VG",
        "BLOCO 1 UP LIFE SAO PAULO CEP 02273-001\nImóvel localizado na 22 Subdivisão da Zona Urbana",
        "| Endereço para entrega da notificação:",
        "| AVJACANA, 764- AP 104 E VG",
        "| BLOCO1 UPLIFE SAO PAULO CEP 02273-001",
        "| Contribuinte(s):",
        "| AGUA DAS FLORES EMPREENDIMENTOS IMOB LTDA",
        "| Dados cadastrais do terreno:",
        "| Área incorporada (m?): 1.669 Testada (m): 0,00",
        "| Área não incorporada (m?): 0 Fração ideal: 0,0024",
        "| Área total (m?): 7.669",
        "| Dados cadastrais da construção:",
        "| Área construída (m?):\n\n88\n\nPadrão da construção:\n\n2-C",
        "Área ocupada pela construção (m?): 5.134 Uso: residência",
        "| Ano da construção corrigido: 2016",
        "| Valores de m? (R$):",
        "| - de terreno: 700,00",
        "| - da construção: 1.508,00",
        "| Valores para fins de cálculo do IPTU (R$):",
        "| - da área incorporada: 23.675,00",
        "- da área não incorporada: 0,00",
        "| - da construção: 131.377,00",
        "|| Base de cálculo do IPTU: 155.052,00",
        "Ressalvado o direito da Fazenda Pública do Município de São Paulo atualizar os dados constantes do Cadastro\nImobiliário Fiscal, apurados ou verificados a qualquer tempo, inclusive em relação ao exercício abrangido por\nesta certidão, a Secretaria Municipal da Fazenda CERTIFICA que os dados cadastrais acima foram utilizados no\nlançamento do Imposto Predial e Territorial Urbano do imóvel do exercício de 2017.",
        "Certidão expedida via Internet - Portaria SF nº 008/2004, de 28/01/2004.",
        "A autenticidade desta certidão poderá ser confirmada, até o dia 05/02/2018, em",
        "http://www .prefeitura.sp.gov.br/cidade/secretarias/financas/servicos/certidoes/",
        "| Data de Emissão: 07/11/2017",
        "| Número do Documento: 2.2017.001599486-1",
        "|| Solicitante: PAULO AFONSO DECICINO (CPF 892.407.408-30)"
    """

# %%
def regex(str_):
    ph_tratada = str_.replace("\"", "")
    ph_tratada = ph_tratada.replace("-", " ")
    ph_tratada = ph_tratada.replace("|", "")
    ph_tratada = ph_tratada.replace(",", "")
    ph_tratada = ph_tratada.replace(":", "")
    ph_tratada = ph_tratada.replace(".", "")
    ph_tratada = ph_tratada.replace("  ", "")
    ph_tratada = ph_tratada.lower()
    ph_tratada = re.sub(r'[\n]+', " ", ph_tratada)
    ph_tratada = re.sub(r'^[ ]+', "", ph_tratada)

    return ph_tratada

# %%
doc_ph = nlp(ph_tratada)
print('Entities', [(ent.text, ent.label_) for ent in doc_ph.ents])

# %%
phrase = regex("Qne 20 numero 12 teste 123 ")

doc = nlp(phrase)
print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
print(phrase)
# Out:
# Entities [('qne 20 numero 12 teste 123', 'LOGRA')]
# qne 20 numero 12 teste 123
