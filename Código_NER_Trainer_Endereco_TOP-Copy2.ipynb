# %%
# Load Packages
from __future__ import unicode_literals, print_function

import plac #  wrapper over argparse
import random
from pathlib import Path
import spacy
from tqdm import tqdm, tqdm_notebook # loading bar 
import pandas as pd
import re
from pprint import pprint
from nltk.tokenize import sent_tokenize
import numpy as np

from spacy.util import minibatch, compounding

# %% [markdown]
# # Abrindo e gerando Datasets

# %% [markdown]
# ### Entidade logradouro

# %%
# Obtendo dados crus de endereço

dataset = pd.read_csv("201906AGENCIAS.CSV")
dset = dataset.iloc[:-2,4:10].values  # tipo nparray object
pd_dset = pd.DataFrame(dset) # caso queira visualizar

pd_dset['Join'] = pd_dset[pd_dset.columns[0:]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)
pd_dset.head(5)
# Out:
#                                           0  \
# 0  R.GUILHERME MOREIRA,315
# 1  AV.PRES.VARGAS,248
# 2  R.QUINZE DE NOVEMBRO,195
# 3  PCA.DAS QUATRO JORNADAS,11
# 4  SEXTA AVENIDA,600
#
#                                                    1  \
# 0  SUBLOJA,LOJA E 2.ANDAR                        ...
# 1  1.E 2.ANDARES                                 ...
# 2                                                ...
# 3  MEZANINO                                      ...
# 4  SECRETARIA DA EDUCACAO-TERREO                 ...
#
#                                 2          3  \
# 0  CENTRO                          69005-300
# 1  CAMPINA                         66010-900
# 2  CENTRO                          11010-908
# 3  CENTRO                          28010-000
# 4  CAB                             41745-002
#
#                                                    4   5  \
# 0  MANAUS                                        ...  AM
# 1  BELEM                                         ...  PA
# 2  SANTOS                                        ...  SP
# 3  CAMPOS DOS GOYTACAZES                         ...  RJ
# 4  SALVADOR                                      ...  BA
#
#                                                 Join
# 0  R.GUILHERME MOREIRA,315                 ;SUBLO...
# 1  AV.PRES.VARGAS,248                      ;1.E 2...
# 2  R.QUINZE DE NOVEMBRO,195                ;     ...
# 3  PCA.DAS QUATRO JORNADAS,11              ;MEZAN...
# 4  SEXTA AVENIDA,600                       ;SECRE...

# %%
# Tratando endereço completo do DataFrame
dset = np.array(pd_dset)
end_lista = []

for i in range(len(dset)):
    str_raw = dset[i][6]
    str_tratada = re.sub(r'[ ]{2,}', "",str_raw) # Tirando espaços excedentes no final do endereço
    str_tratada = re.sub(r'[;]{1,}', "; ", str_tratada) # Para complementos vazios, para não ter 2 ";"
    str_tratada = str_tratada.lower()
    
    end_lista.append(str_tratada)

end_lista[:3]
# Out:
# ['r.guilherme moreira,315; subloja,loja e 2.andar; centro; 69005-300; manaus; am',
#  'av.pres.vargas,248; 1.e 2.andares; campina; 66010-900; belem; pa',
#  'r.quinze de novembro,195; centro; 11010-908; santos; sp']

# %%
# Lógica para extrair posição do logradouro:
# Dividir a String inteira por ";", pegar o len do primeiro split
# len de LOGRA é de 0 até len do primeiro split

print(end_lista[0])
split = end_lista[0].split(";")
print(split)
print(split[0])
print(len(split[0]))
# Out:
# r.guilherme moreira,315; subloja,loja e 2.andar; centro; 69005-300; manaus; am
# ['r.guilherme moreira,315', ' subloja,loja e 2.andar', ' centro', ' 69005-300', ' manaus', ' am']
# r.guilherme moreira,315
# 23

# %%
# Extraindo iob com entidade apenas de logradouro

iob = []

for i in range(len(end_lista)):
    split = end_lista[i].split(";")
    len_logra = len(split[0])
    iob_dict = {"entities": [(0, len_logra-1,'LOGRA')]}
    end_lista[i] = end_lista[i].replace(";", " ")
    end_lista[i] = end_lista[i].replace(",", " ")
    end_lista[i] = re.sub(r'[ ]{2,}', " ", end_lista[i])

    
    tupla = (end_lista[i], iob_dict)
    iob.append(tupla)

FULL_DATA = iob

# %%
print(FULL_DATA[0])
print(FULL_DATA[1])
print(FULL_DATA[2])
print(FULL_DATA[5:15])
# Out:
# ('r.guilherme moreira 315 subloja loja e 2.andar centro 69005-300 manaus am', {'entities': [(0, 22, 'LOGRA')]})
# ('av.pres.vargas 248 1.e 2.andares campina 66010-900 belem pa', {'entities': [(0, 17, 'LOGRA')]})
# ('r.quinze de novembro 195 centro 11010-908 santos sp', {'entities': [(0, 23, 'LOGRA')]})
# [('av.rio branco 240 1.andar recife antigo 50030-310 recife pe', {'entities': [(0, 16, 'LOGRA')]}), ('av.santos dumont 2828 5.andar aldeota 60150-162 fortaleza ce', {'entities': [(0, 20, 'LOGRA')]}), ('pca.tiradentes 410 1.andar centro 80020-100 curitiba pr', {'entities': [(0, 17, 'LOGRA')]}), ('r.uruguai 185 5.andar centro 90010-901 porto alegre rs', {'entities': [(0, 12, 'LOGRA')]}), ('pca.1817 129 1.andar centro 58013-010 joao pessoa pb', {'entities': [(0, 11, 'LOGRA')]}), ('pca.odilon resende andrade 76 centro 37410-000 tres coracoes mg', {'entities': [(0, 28, 'LOGRA')]}), ('av fernandes lima 2591 terreo farol 57057-972 maceio al', {'entities': [(0, 22, 'LOGRA')]}), ('r.treze de junho 914 centro 79300-040 corumba ms', {'entities': [(0, 19, 'LOGRA')]}), ('av.leopoldino de oliveira 3635 centro 38010-000 uberaba mg', {'entities': [(0, 29, 'LOGRA')]}), ('pca.quinze de novembro 321 centro 88010-400 florianopolis sc', {'entities': [(0, 25, 'LOGRA')]})]

# %%
# Criação da base de teste e treinamento

n_test= 0.1 # Porcentagem para base de teste
test_n = round(len(FULL_DATA) * n_test)

# Divisao em Train Test Val

def gerador_bases(dataset, n):
    indices_random = random.sample(range(0,len(dataset)-1), n)
    base_teste_n = []
    base_treinamento_n = []
    
    for i in range(n):
        base_teste_n.append(dataset[indices_random[i]])

    for j in range(len(dataset)):
        if(j not in indices_random):
            base_treinamento_n.append(dataset[j])
            
    return base_teste_n, base_treinamento_n


base_teste, base_treinamento = gerador_bases(FULL_DATA, test_n)

random.shuffle(base_treinamento)
random.shuffle(base_teste)

print("Treinamento: " + str(len(base_treinamento)), "\nTeste: " + str(len(base_teste)), "\nTotal: " + str(len(FULL_DATA)))
# Out:
# Treinamento: 19202
# Teste: 2134
# Total: 21336

# %%
for i in range(5):
    print(base_treinamento[i])
# Out:
# ('avenida �lvaro guimaraes 493 planalto 09890-002 sao bernardo do campo sp', {'entities': [(0, 28, 'LOGRA')]})
# ('rua 1. de maio 161 centro 85875-000 santa terezinha de itaipu pr', {'entities': [(0, 18, 'LOGRA')]})
# ('rua senador melo viana 158 centro 35740-000 esmeraldas mg', {'entities': [(0, 26, 'LOGRA')]})
# ('r.da conceicao 1270 centro 55540-000 palmares pe', {'entities': [(0, 18, 'LOGRA')]})
# ('r.jurubatuba 122 centro 09725-620 sao bernardo do campo sp', {'entities': [(0, 15, 'LOGRA')]})

# %% [markdown]
# # Carregando o modelo

# %%
# Define our variables

model = None
output_dir=Path(".")
n_iter= 100 # número de épocas
batch_size = 128

# %%
# Setting up the pipeline and entity recognizer.
if model is not None:
    nlp = spacy.load(model)  # load existing spacy model
    print("Loaded model '%s'" % model)
else:
    lan = 'pt'
    nlp = spacy.blank(lan)  # create blank Language class
    print("Created blank '%s' model" % lan)
    
if 'ner' not in nlp.pipe_names:
    ner = nlp.create_pipe('ner')
    nlp.add_pipe(ner)
    print('Added new NER')
else:
    ner = nlp.get_pipe('ner')
    print('Got an old NER')
# Out:
# Created blank 'pt' model
# Added new NER

# %%
# create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
if 'ner' not in nlp.pipe_names:
    ner = nlp.create_pipe('ner')
    nlp.add_pipe(ner, last=True)
# otherwise, get it so we can add labels
else:
    ner = nlp.get_pipe('ner')

# %% [markdown]
# ## Treinamento

# %%
print("Batch size: ", batch_size)
print("Épocas: ", n_iter)
print()

# add labels
for _, annotations in base_treinamento:
    for ent in annotations.get('entities'):
        ner.add_label(ent[2])


# get names of other pipes to disable them during training
other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
with nlp.disable_pipes(*other_pipes):  # only train NER
    optimizer = nlp.begin_training()
    for itn in range(n_iter):
        random.shuffle(base_treinamento)
        losses = {}
        batches = minibatch(base_treinamento, size=batch_size)
        
        for batch in batches:
            texts, annotations = zip(*batch)
            try:
                nlp.update(texts, annotations, sgd=optimizer, drop=0.2,
                       losses=losses)
            except:
                pass     
        
        print(itn+1, ' Losses', losses)
# Out:
# Batch size:  128
# Épocas:  100
#
# 1  Losses {'ner': 606.939372012857}
# 2  Losses {'ner': 638.5511046016755}
# 3  Losses {'ner': 766.4913897201557}
# 4  Losses {'ner': 609.2352539531776}
# 5  Losses {'ner': 559.8214193022287}
# 6  Losses {'ner': 588.6410193874871}
# 7  Losses {'ner': 547.6508409419387}
# 8  Losses {'ner': 455.7239492321868}
# 9  Losses {'ner': 413.08838508261584}
# 10  Losses {'ner': 601.2567512689601}
# 11  Losses {'ner': 730.5993479874415}
# 12  Losses {'ner': 643.234945708369}
# 13  Losses {'ner': 649.6897828269329}
# 14  Losses {'ner': 442.4402852816947}
# 15  Losses {'ner': 565.8306506229433}
# 16  Losses {'ner': 565.1473455251715}
# 17  Losses {'ner': 541.1816364927284}
# 18  Losses {'ner': 489.57522128769125}
# 19  Losses {'ner': 408.41610793219195}
# 20  Losses {'ner': 541.9054432752819}
# 21  Losses {'ner': 535.6802834143369}
# 22  Losses {'ner': 442.6166852567742}
# 23  Losses {'ner': 584.8445779486016}
# 24  Losses {'ner': 537.4697011536322}
# 25  Losses {'ner': 507.19692543824726}
# 26  Losses {'ner': 542.1651882210977}
# 27  Losses {'ner': 474.8798630586126}
# 28  Losses {'ner': 420.31973297188824}
# 29  Losses {'ner': 360.4692311289519}
# 30  Losses {'ner': 451.46121556488674}
# 31  Losses {'ner': 394.66758250929763}
# 32  Losses {'ner': 353.82776414658304}
# 33  Losses {'ner': 475.3454806007766}
# 34  Losses {'ner': 352.63418982663376}
# 35  Losses {'ner': 472.8174258261218}
# 36  Losses {'ner': 408.92735674062624}
# 37  Losses {'ner': 468.61980972151764}
# 38  Losses {'ner': 500.52993615679947}
# 39  Losses {'ner': 315.23894409058494}
# 40  Losses {'ner': 379.0686882068366}
# 41  Losses {'ner': 475.1021611411}
# 42  Losses {'ner': 436.23489741732396}
# 43  Losses {'ner': 425.3802617993006}
# 44  Losses {'ner': 384.4651112023543}
# 45  Losses {'ner': 399.3180741109506}
# 46  Losses {'ner': 378.68213101414426}
# 47  Losses {'ner': 342.7315798629093}
# 48  Losses {'ner': 431.6871561259582}
# 49  Losses {'ner': 299.8603523736106}
# 50  Losses {'ner': 254.5602592448746}
# 51  Losses {'ner': 327.5922848221768}
# 52  Losses {'ner': 437.26337611818934}
# 53  Losses {'ner': 324.12366954460265}
# 54  Losses {'ner': 362.99408967810234}
# 55  Losses {'ner': 440.70920004563413}
# 56  Losses {'ner': 427.67681606799175}
# 57  Losses {'ner': 265.9514916406029}
# 58  Losses {'ner': 311.74374069757636}
# 59  Losses {'ner': 427.85776210428713}
# 60  Losses {'ner': 332.64213737251254}
# 61  Losses {'ner': 439.3908786886177}
# 62  Losses {'ner': 345.67698779174384}
# 63  Losses {'ner': 344.9175543000451}
# 64  Losses {'ner': 295.88120257134534}
# 65  Losses {'ner': 305.69291310144376}
# 66  Losses {'ner': 323.0875884275341}
# 67  Losses {'ner': 361.3749141500162}
# 68  Losses {'ner': 322.54775522347893}
# 69  Losses {'ner': 357.90687277333234}
# 70  Losses {'ner': 364.1080111222399}
# 71  Losses {'ner': 336.5889710473571}
# 72  Losses {'ner': 295.93348461356055}
# 73  Losses {'ner': 391.06973328596075}
# 74  Losses {'ner': 283.7278977834155}
# 75  Losses {'ner': 261.2544320760868}
# 76  Losses {'ner': 426.91607296017514}
# 77  Losses {'ner': 331.9038973461606}
# 78  Losses {'ner': 325.6828636653327}
# 79  Losses {'ner': 261.93927532264803}
# 80  Losses {'ner': 270.4374220855121}
# 81  Losses {'ner': 296.68905856830906}
# 82  Losses {'ner': 266.7110498187421}
# 83  Losses {'ner': 423.50335838795684}
# 84  Losses {'ner': 367.4925812469849}
# 85  Losses {'ner': 577.1461415425623}
# 86  Losses {'ner': 353.76022053485366}
# 87  Losses {'ner': 439.1761677102738}
# 88  Losses {'ner': 271.7533190055666}
# 89  Losses {'ner': 443.4557788498653}
# 90  Losses {'ner': 433.3549529558602}
# 91  Losses {'ner': 274.3189958350042}
# 92  Losses {'ner': 322.3900963822788}
# 93  Losses {'ner': 320.2926244360099}
# 94  Losses {'ner': 299.25798559533655}
# 95  Losses {'ner': 327.74228486901177}
# 96  Losses {'ner': 297.9718123694623}
# 97  Losses {'ner': 300.04274138214737}
# 98  Losses {'ner': 443.8308764245819}
# 99  Losses {'ner': 278.26914683809116}
# 100  Losses {'ner': 389.6114126970777}

# %%
# test the trained model
for text, _ in base_teste:
    doc = nlp(text)
    print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
    print('Tokens', [(t.text, t.ent_type_, t.ent_iob) for t in doc])
    print()
# Out:
# Entities [('av. ipiranga loja 149', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('ipiranga', 'LOGRA', 1), ('loja', 'LOGRA', 1), ('149', 'LOGRA', 1), ('jardim', '', 2), ('botanico', '', 2), ('90610-000', '', 2), ('porto', '', 2), ('alegre', '', 2), ('rs', '', 2)]
#
# Entities [('avenida presidentegetuilio vargas bela', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('presidentegetuilio', 'LOGRA', 1), ('vargas', 'LOGRA', 1), ('bela', 'LOGRA', 1), ('vista', '', 2), ('ii', '', 2), ('45996-000', '', 2), ('teixeira', '', 2), ('de', '', 2), ('freitas', '', 2), ('ba', '', 2)]
#
# Entities [('rua f quadra 128 - lote', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('f', 'LOGRA', 1), ('quadra', 'LOGRA', 1), ('128', 'LOGRA', 1), ('-', 'LOGRA', 1), ('lote', 'LOGRA', 1), ('13', '', 2), ('uniao', '', 2), ('68515-000', '', 2), ('parauapebas', '', 2), ('pa', '', 2)]
#
# Entities [('rua brigadeiro franco 2300', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('brigadeiro', 'LOGRA', 1), ('franco', 'LOGRA', 1), ('2300', 'LOGRA', 1), ('lojas', '', 2), ('337', '', 2), ('e', '', 2), ('338', '', 2), ('piso', '', 2), ('l', '', 2), ('3', '', 2), ('centro', '', 2), ('80250-903', '', 2), ('curitiba', '', 2), ('pr', '', 2)]
#
# Entities [('av. honorio fraga n� 259', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('honorio', 'LOGRA', 1), ('fraga', 'LOGRA', 1), ('n', 'LOGRA', 1), ('�', 'LOGRA', 1), ('259', 'LOGRA', 1), ('centro', '', 2), ('29745-000', '', 2), ('sao', '', 2), ('domingos', '', 2), ('do', '', 2), ('norte', '', 2), ('es', '', 2)]
#
# Entities [('av frei raimundo lambezart', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('frei', 'LOGRA', 1), ('raimundo', 'LOGRA', 1), ('lambezart', 'LOGRA', 1), ('cidade', '', 2), ('nova', '', 2), ('68501-680', '', 2), ('maraba', '', 2), ('pa', '', 2)]
#
# Entities [('r.sao francisco xavier 1244', 'LOGRA')]
# Tokens [('r.sao', 'LOGRA', 3), ('francisco', 'LOGRA', 1), ('xavier', 'LOGRA', 1), ('1244', 'LOGRA', 1), ('centro', '', 2), ('78870-000', '', 2), ('paranatinga', '', 2), ('mt', '', 2)]
#
# Entities [('av. 25', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('25', 'LOGRA', 1), ('de', '', 2), ('julho', '', 2), ('93950-000', '', 2), ('dois', '', 2), ('irmaos', '', 2), ('rs', '', 2)]
#
# Entities [('av.antonio carlos paniago 261', 'LOGRA')]
# Tokens [('av.antonio', 'LOGRA', 3), ('carlos', 'LOGRA', 1), ('paniago', 'LOGRA', 1), ('261', 'LOGRA', 1), ('terreo', '', 2), ('centro', '', 2), ('75855-000', '', 2), ('doverlandia', '', 2), ('go', '', 2)]
#
# Entities [('rua senador pompeu 970', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('senador', 'LOGRA', 1), ('pompeu', 'LOGRA', 1), ('970', 'LOGRA', 1), ('centro', '', 2), ('60025-000', '', 2), ('fortaleza', '', 2), ('ce', '', 2)]
#
# Entities [('av. getulio vargas 681', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('getulio', 'LOGRA', 1), ('vargas', 'LOGRA', 1), ('681', 'LOGRA', 1), ('funcionarios', '', 2), ('30112-020', '', 2), ('belo', '', 2), ('horizonte', '', 2), ('mg', '', 2)]
#
# Entities [('rua julio de castilhos', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('julio', 'LOGRA', 1), ('de', 'LOGRA', 1), ('castilhos', 'LOGRA', 1), ('centro', '', 2), ('96600-000', '', 2), ('cangucu', '', 2), ('rs', '', 2)]
#
# Entities [('av paraguassu', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('paraguassu', 'LOGRA', 1), ('centro', '', 2), ('95555-000', '', 2), ('capao', '', 2), ('da', '', 2), ('canoa', '', 2), ('rs', '', 2)]
#
# Entities [('rua jose bonifacio', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('jose', 'LOGRA', 1), ('bonifacio', 'LOGRA', 1), ('centro', '', 2), ('99890-000', '', 2), ('maximiliano', '', 2), ('de', '', 2), ('almeida', '', 2), ('rs', '', 2)]
#
# Entities [('av nossa senhora da paz', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('nossa', 'LOGRA', 1), ('senhora', 'LOGRA', 1), ('da', 'LOGRA', 1), ('paz', 'LOGRA', 1), ('jardim', '', 2), ('alto', '', 2), ('alegre', '', 2), ('15055-500', '', 2), ('sao', '', 2), ('jose', '', 2), ('do', '', 2), ('rio', '', 2), ('preto', '', 2), ('sp', '', 2)]
#
# Entities [('rua engenheiro portela 588', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('engenheiro', 'LOGRA', 1), ('portela', 'LOGRA', 1), ('588', 'LOGRA', 1), ('centro', '', 2), ('75024-100', '', 2), ('anapolis', '', 2), ('go', '', 2)]
#
# Entities [('via anchieta 2027', 'LOGRA')]
# Tokens [('via', 'LOGRA', 3), ('anchieta', 'LOGRA', 1), ('2027', 'LOGRA', 1), ('moinho', '', 2), ('velho', '', 2), ('04247-002', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('rua do expedicion�rio 655', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('do', 'LOGRA', 1), ('expedicion', 'LOGRA', 1), ('�', 'LOGRA', 1), ('rio', 'LOGRA', 1), ('655', 'LOGRA', 1), ('centro', '', 2), ('19900-041', '', 2), ('ourinhos', '', 2), ('sp', '', 2)]
#
# Entities [('av. santo antonio 66', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('santo', 'LOGRA', 1), ('antonio', 'LOGRA', 1), ('66', 'LOGRA', 1), ('santo', '', 2), ('antonio', '', 2), ('55293-000', '', 2), ('garanhuns', '', 2), ('pe', '', 2)]
#
# Entities [('r.caldas junior 121', 'LOGRA')]
# Tokens [('r.caldas', 'LOGRA', 3), ('junior', 'LOGRA', 1), ('121', 'LOGRA', 1), ('c', '', 2), ('historico', '', 2), ('90010-260', '', 2), ('porto', '', 2), ('alegre', '', 2), ('rs', '', 2)]
#
# Entities [('rua do orfanato', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('do', 'LOGRA', 1), ('orfanato', 'LOGRA', 1), ('vila', '', 2), ('prudente', '', 2), ('03131-010', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('av. carlos botelho 200', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('carlos', 'LOGRA', 1), ('botelho', 'LOGRA', 1), ('200', 'LOGRA', 1), ('centro', '', 2), ('13460-000', '', 2), ('nova', '', 2), ('odessa', '', 2), ('sp', '', 2)]
#
# Entities [('rua benjamim duarte 146', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('benjamim', 'LOGRA', 1), ('duarte', 'LOGRA', 1), ('146', 'LOGRA', 1), ('centro', '', 2), ('88240-000', '', 2), ('sao', '', 2), ('joao', '', 2), ('batista', '', 2), ('sc', '', 2)]
#
# Entities [('av.dr.mendel steinbruch s/', 'LOGRA')]
# Tokens [('av.dr.mendel', 'LOGRA', 3), ('steinbruch', 'LOGRA', 1), ('s', 'LOGRA', 1), ('/', 'LOGRA', 1), ('n', '', 2), ('ceasa', '', 2), ('pajucara', '', 2), ('61932-971', '', 2), ('maracanau', '', 2), ('ce', '', 2)]
#
# Entities [('rua itingu�u 840', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('itingu', 'LOGRA', 1), ('�', 'LOGRA', 1), ('u', 'LOGRA', 1), ('840', 'LOGRA', 1), ('vila', '', 2), ('re', '', 2), ('03658-000', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('rua rui barbosa 96', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('rui', 'LOGRA', 1), ('barbosa', 'LOGRA', 1), ('96', 'LOGRA', 1), ('centro', '', 2), ('55641-100', '', 2), ('gravata', '', 2), ('pe', '', 2)]
#
# Entities [('r.joaquim moreira s/', 'LOGRA')]
# Tokens [('r.joaquim', 'LOGRA', 3), ('moreira', 'LOGRA', 1), ('s', 'LOGRA', 1), ('/', 'LOGRA', 1), ('n', '', 2), ('centro', '', 2), ('62920-000', '', 2), ('quixere', '', 2), ('ce', '', 2)]
#
# Entities [('r thome franco', 'LOGRA')]
# Tokens [('r', 'LOGRA', 3), ('thome', 'LOGRA', 1), ('franco', 'LOGRA', 1), ('centro', '', 2), ('12940-918', '', 2), ('atibaia', '', 2), ('sp', '', 2)]
#
# Entities [('av prestes maia 894', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('prestes', 'LOGRA', 1), ('maia', 'LOGRA', 1), ('894', 'LOGRA', 1), ('2', '', 2), ('�', '', 2), ('andar', '', 2), ('centro', '', 2), ('01031-000', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('av.dr. chucri zaidan 940', 'LOGRA')]
# Tokens [('av.dr', 'LOGRA', 3), ('.', 'LOGRA', 1), ('chucri', 'LOGRA', 1), ('zaidan', 'LOGRA', 1), ('940', 'LOGRA', 1), ('18', '', 2), ('�', '', 2), ('andar', '', 2), ('-', '', 2), ('conjunto', '', 2), ('181', '', 2), ('vila', '', 2), ('cordeiro', '', 2), ('04583-110', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('rua padre misael gomes 639', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('padre', 'LOGRA', 1), ('misael', 'LOGRA', 1), ('gomes', 'LOGRA', 1), ('639', 'LOGRA', 1), ('centro', '', 2), ('63250-000', '', 2), ('milagres', '', 2), ('ce', '', 2)]
#
# Entities [('av santos dumont 51', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('santos', 'LOGRA', 1), ('dumont', 'LOGRA', 1), ('51', 'LOGRA', 1), ('lote', '', 2), ('3', '', 2), ('centro', '', 2), ('25900-000', '', 2), ('mage', '', 2), ('rj', '', 2)]
#
# Entities [('av.rui barbosa 566', 'LOGRA')]
# Tokens [('av.rui', 'LOGRA', 3), ('barbosa', 'LOGRA', 1), ('566', 'LOGRA', 1), ('centro', '', 2), ('14740-000', '', 2), ('viradouro', '', 2), ('sp', '', 2)]
#
# Entities [('praca evangelino meireles 50-a', 'LOGRA')]
# Tokens [('praca', 'LOGRA', 3), ('evangelino', 'LOGRA', 1), ('meireles', 'LOGRA', 1), ('50-a', 'LOGRA', 1), ('centro', '', 2), ('72800-000', '', 2), ('luziania', '', 2), ('go', '', 2)]
#
# Entities [('rua floriano peixoto', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('floriano', 'LOGRA', 1), ('peixoto', 'LOGRA', 1), ('centro', '', 2), ('69820-000', '', 2), ('canutama', '', 2), ('am', '', 2)]
#
# Entities [('av. joao pedro cardoso 375', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('joao', 'LOGRA', 1), ('pedro', 'LOGRA', 1), ('cardoso', 'LOGRA', 1), ('375', 'LOGRA', 1), ('prq', '', 2), ('.', '', 2), ('jabaquara', '', 2), ('43550-000', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('rua floriano peixoto', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('floriano', 'LOGRA', 1), ('peixoto', 'LOGRA', 1), ('sala', '', 2), ('601', '', 2), ('e', '', 2), ('602', '', 2), ('centro', '', 2), ('89010-500', '', 2), ('blumenau', '', 2), ('sc', '', 2)]
#
# Entities [('av. santa leopoldina n� 840', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('santa', 'LOGRA', 1), ('leopoldina', 'LOGRA', 1), ('n', 'LOGRA', 1), ('�', 'LOGRA', 1), ('840', 'LOGRA', 1), ('28127603', '', 2), ('coqueiral', '', 2), ('de', '', 2), ('itaparica', '', 2), ('29102-040', '', 2), ('vila', '', 2), ('velha', '', 2), ('es', '', 2)]
#
# Entities [('r. exped. jacupiranguenses 34', 'LOGRA')]
# Tokens [('r.', 'LOGRA', 3), ('exped', 'LOGRA', 1), ('.', 'LOGRA', 1), ('jacupiranguenses', 'LOGRA', 1), ('34', 'LOGRA', 1), ('centro', '', 2), ('11940-000', '', 2), ('jacupiranga', '', 2), ('sp', '', 2)]
#
# Entities [('avenida kennedy 191', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('kennedy', 'LOGRA', 1), ('191', 'LOGRA', 1), ('jardim', '', 2), ('do', '', 2), ('mar', '', 2), ('09726-260', '', 2), ('sao', '', 2), ('bernardo', '', 2), ('do', '', 2), ('campo', '', 2), ('sp', '', 2)]
#
# Entities [('av. rio branco 116', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('rio', 'LOGRA', 1), ('branco', 'LOGRA', 1), ('116', 'LOGRA', 1), ('5', '', 2), ('andar', '', 2), ('centro', '', 2), ('20040-001', '', 2), ('rio', '', 2), ('de', '', 2), ('janeiro', '', 2), ('rj', '', 2)]
#
# Entities [('pra�a c�nego eli�de nunes arouche', 'LOGRA')]
# Tokens [('pra', 'LOGRA', 3), ('�', 'LOGRA', 1), ('a', 'LOGRA', 1), ('c', 'LOGRA', 1), ('�', 'LOGRA', 1), ('nego', 'LOGRA', 1), ('eli', 'LOGRA', 1), ('�', 'LOGRA', 1), ('de', 'LOGRA', 1), ('nunes', 'LOGRA', 1), ('arouche', 'LOGRA', 1), ('centro', '', 2), ('65350-000', '', 2), ('vitoria', '', 2), ('do', '', 2), ('mearim', '', 2), ('ma', '', 2)]
#
# Entities [('avenida brasil', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('brasil', 'LOGRA', 1), ('centro', '', 2), ('86840-000', '', 2), ('faxinal', '', 2), ('pr', '', 2)]
#
# Entities [('av major novaes', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('major', 'LOGRA', 1), ('novaes', 'LOGRA', 1), ('centro', '', 2), ('12701-330', '', 2), ('cruzeiro', '', 2), ('sp', '', 2)]
#
# Entities [('av. rio branco 134-a', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('rio', 'LOGRA', 1), ('branco', 'LOGRA', 1), ('134-a', 'LOGRA', 1), ('centro', '', 2), ('20040-002', '', 2), ('rio', '', 2), ('de', '', 2), ('janeiro', '', 2), ('rj', '', 2)]
#
# Entities []
# Tokens [('104', '', 2), ('sul', '', 2), ('r.', '', 2), ('se', '', 2), ('1conj', '', 2), ('02', '', 2), ('-', '', 2), ('acse', '', 2), ('01', '', 2), ('lote', '', 2), ('01', '', 2), ('plano', '', 2), ('diretor', '', 2), ('sul', '', 2), ('77020-014', '', 2), ('palmas', '', 2), ('to', '', 2)]
#
# Entities [('rua joao candido da camara 328', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('joao', 'LOGRA', 1), ('candido', 'LOGRA', 1), ('da', 'LOGRA', 1), ('camara', 'LOGRA', 1), ('328', 'LOGRA', 1), ('jardim', '', 2), ('america', '', 2), ('79804-000', '', 2), ('dourados', '', 2), ('ms', '', 2)]
#
# Entities [('av. rui barbosa 21', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('rui', 'LOGRA', 1), ('barbosa', 'LOGRA', 1), ('21', 'LOGRA', 1), ('88801-120', '', 2), ('criciuma', '', 2), ('sc', '', 2)]
#
# Entities [('av presidente itamar franco lojas 115/116', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('presidente', 'LOGRA', 1), ('itamar', 'LOGRA', 1), ('franco', 'LOGRA', 1), ('lojas', 'LOGRA', 1), ('115/116', 'LOGRA', 1), ('cascatinha', '', 2), ('36033-318', '', 2), ('juiz', '', 2), ('de', '', 2), ('fora', '', 2), ('mg', '', 2)]
#
# Entities [('rua rio grande do sul esq. c/rua', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('rio', 'LOGRA', 1), ('grande', 'LOGRA', 1), ('do', 'LOGRA', 1), ('sul', 'LOGRA', 1), ('esq', 'LOGRA', 1), ('.', 'LOGRA', 1), ('c', 'LOGRA', 1), ('/', 'LOGRA', 1), ('rua', 'LOGRA', 1), ('barao', '', 2), ('de', '', 2), ('garca', '', 2), ('centro', '', 2), ('78640-000', '', 2), ('canarana', '', 2), ('mt', '', 2)]
#
# Entities [('r zilda 578 / 582', 'LOGRA')]
# Tokens [('r', 'LOGRA', 3), ('zilda', 'LOGRA', 1), ('578', 'LOGRA', 1), ('/', 'LOGRA', 1), ('582', 'LOGRA', 1), ('casa', '', 2), ('verde', '', 2), ('alta', '', 2), ('02545-000', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('r.sao vicente de paula 17', 'LOGRA')]
# Tokens [('r.sao', 'LOGRA', 3), ('vicente', 'LOGRA', 1), ('de', 'LOGRA', 1), ('paula', 'LOGRA', 1), ('17', 'LOGRA', 1), ('centro', '', 2), ('47940-000', '', 2), ('wanderley', '', 2), ('ba', '', 2)]
#
# Entities [('av.dr.arnaldo 351', 'LOGRA')]
# Tokens [('av.dr.arnaldo', 'LOGRA', 3), ('351', 'LOGRA', 1), ('terreo', '', 2), ('pacaembu', '', 2), ('01246-000', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('av. maximiliano gaidzinski 98', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('maximiliano', 'LOGRA', 1), ('gaidzinski', 'LOGRA', 1), ('98', 'LOGRA', 1), ('centro', '', 2), ('88845-000', '', 2), ('cocal', '', 2), ('do', '', 2), ('sul', '', 2), ('sc', '', 2)]
#
# Entities [('r.mal.floriano peixoto 241', 'LOGRA')]
# Tokens [('r.mal.floriano', 'LOGRA', 3), ('peixoto', 'LOGRA', 1), ('241', 'LOGRA', 1), ('centro', '', 2), ('89130-000', '', 2), ('indaial', '', 2), ('sc', '', 2)]
#
# Entities [('av. nossa senhora da luz 214', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('nossa', 'LOGRA', 1), ('senhora', 'LOGRA', 1), ('da', 'LOGRA', 1), ('luz', 'LOGRA', 1), ('214', 'LOGRA', 1), ('centro', '', 2), ('85530-000', '', 2), ('clevelandia', '', 2), ('pr', '', 2)]
#
# Entities [('rua benedito rego 1400', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('benedito', 'LOGRA', 1), ('rego', 'LOGRA', 1), ('1400', 'LOGRA', 1), ('centro', '', 2), ('64120-000', '', 2), ('uniao', '', 2), ('pi', '', 2)]
#
# Entities [('rua voluntarios da patria 1909', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('voluntarios', 'LOGRA', 1), ('da', 'LOGRA', 1), ('patria', 'LOGRA', 1), ('1909', 'LOGRA', 1), ('conjunto', '', 2), ('2', '', 2), ('santana', '', 2), ('02011-400', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('av. jos� tozzi 1.779', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('jos', 'LOGRA', 1), ('�', 'LOGRA', 1), ('tozzi', 'LOGRA', 1), ('1.779', 'LOGRA', 1), ('centro', '', 2), ('29930-245', '', 2), ('sao', '', 2), ('mateus', '', 2), ('es', '', 2)]
#
# Entities [('estr.dos tres rios 223', 'LOGRA')]
# Tokens [('estr.dos', 'LOGRA', 3), ('tres', 'LOGRA', 1), ('rios', 'LOGRA', 1), ('223', 'LOGRA', 1), ('loja', '', 2), ('a', '', 2), ('bloco', '', 2), ('1', '', 2), ('freguesia', '', 2), ('/', '', 2), ('jacarepagua', '', 2), ('22755-001', '', 2), ('rio', '', 2), ('de', '', 2), ('janeiro', '', 2), ('rj', '', 2)]
#
# Entities [('av.min.leonor barreto franco 1348', 'LOGRA')]
# Tokens [('av.min.leonor', 'LOGRA', 3), ('barreto', 'LOGRA', 1), ('franco', 'LOGRA', 1), ('1348', 'LOGRA', 1), ('centro', '', 2), ('49790-000', '', 2), ('aquidaba', '', 2), ('se', '', 2)]
#
# Entities [('r.democrito pinto 410', 'LOGRA')]
# Tokens [('r.democrito', 'LOGRA', 3), ('pinto', 'LOGRA', 1), ('410', 'LOGRA', 1), ('terreo', '', 2), ('centro', '', 2), ('63960-000', '', 2), ('banabuiu', '', 2), ('ce', '', 2)]
#
# Entities [('av.getulio vargas 166', 'LOGRA')]
# Tokens [('av.getulio', 'LOGRA', 3), ('vargas', 'LOGRA', 1), ('166', 'LOGRA', 1), ('pca.da', '', 2), ('matriz', '', 2), ('centro', '', 2), ('64190-000', '', 2), ('batalha', '', 2), ('pi', '', 2)]
#
# Entities [('r.nereu ramos 185', 'LOGRA')]
# Tokens [('r.nereu', 'LOGRA', 3), ('ramos', 'LOGRA', 1), ('185', 'LOGRA', 1), ('centro', '', 2), ('88770-000', '', 2), ('imarui', '', 2), ('sc', '', 2)]
# Entities [('pca.dr.henrique sampaio 150', 'LOGRA')]
# Tokens [('pca.dr.henrique', 'LOGRA', 3), ('sampaio', 'LOGRA', 1), ('150', 'LOGRA', 1), ('centro', '', 2), ('45745-000', '', 2), ('ibicarai', '', 2), ('ba', '', 2)]
#
# Entities [('av. expedito garcia 75', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('expedito', 'LOGRA', 1), ('garcia', 'LOGRA', 1), ('75', 'LOGRA', 1), ('campo', '', 2), ('grande', '', 2), ('29140-000', '', 2), ('cariacica', '', 2), ('es', '', 2)]
#
# Entities [('avenida antonio cunha 700', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('antonio', 'LOGRA', 1), ('cunha', 'LOGRA', 1), ('700', 'LOGRA', 1), ('centro', '', 2), ('84200-000', '', 2), ('jaguariaiva', '', 2), ('pr', '', 2)]
#
# Entities [('alameda dos maracatins 634/636', 'LOGRA')]
# Tokens [('alameda', 'LOGRA', 3), ('dos', 'LOGRA', 1), ('maracatins', 'LOGRA', 1), ('634/636', 'LOGRA', 1), ('indian', '', 2), ('�', '', 2), ('polis', '', 2), ('04089-001', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('avenida antonio lemos', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('antonio', 'LOGRA', 1), ('lemos', 'LOGRA', 1), ('nova', '', 2), ('bras', '', 2), ('�', '', 2), ('lia', '', 2), ('68790-000', '', 2), ('santa', '', 2), ('isabel', '', 2), ('do', '', 2), ('para', '', 2), ('pa', '', 2)]
#
# Entities [('av.treze de maio 193', 'LOGRA')]
# Tokens [('av.treze', 'LOGRA', 3), ('de', 'LOGRA', 1), ('maio', 'LOGRA', 1), ('193', 'LOGRA', 1), ('centro', '', 2), ('45850-000', '', 2), ('itagimirim', '', 2), ('ba', '', 2)]
#
# Entities [('av. evandi americo comarela 305', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('evandi', 'LOGRA', 1), ('americo', 'LOGRA', 1), ('comarela', 'LOGRA', 1), ('305', 'LOGRA', 1), ('venda', '', 2), ('nova', '', 2), ('29375-000', '', 2), ('venda', '', 2), ('nova', '', 2), ('do', '', 2), ('imigrante', '', 2), ('es', '', 2)]
#
# Entities [('rua joao clementino 73', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('joao', 'LOGRA', 1), ('clementino', 'LOGRA', 1), ('73', 'LOGRA', 1), ('centro', '', 2), ('56300-000', '', 2), ('petrolina', '', 2), ('pe', '', 2)]
#
# Entities [('r.quinze de novembro 364', 'LOGRA')]
# Tokens [('r.quinze', 'LOGRA', 3), ('de', 'LOGRA', 1), ('novembro', 'LOGRA', 1), ('364', 'LOGRA', 1), ('centro', '', 2), ('centro', '', 2), ('84530-000', '', 2), ('teixeira', '', 2), ('soares', '', 2), ('pr', '', 2)]
#
# Entities [('rua dutra', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('dutra', 'LOGRA', 1), ('de', '', 2), ('andrade', '', 2), ('96470-000', '', 2), ('pinheiro', '', 2), ('machado', '', 2), ('rs', '', 2)]
#
# Entities [('rua antonio sim�o mauad', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('antonio', 'LOGRA', 1), ('sim', 'LOGRA', 1), ('�', 'LOGRA', 1), ('o', 'LOGRA', 1), ('mauad', 'LOGRA', 1), ('centro', '', 2), ('37500-180', '', 2), ('itajuba', '', 2), ('mg', '', 2)]
#
# Entities [('av.dep.jamel cecilio 1429', 'LOGRA')]
# Tokens [('av.dep.jamel', 'LOGRA', 3), ('cecilio', 'LOGRA', 1), ('1429', 'LOGRA', 1), ('qd.', '', 2), ('f42-a', '', 2), ('lotes', '', 2), ('53-55', '', 2), ('setor', '', 2), ('sul', '', 2), ('74085-580', '', 2), ('goiania', '', 2), ('go', '', 2)]
#
# Entities [('rua sete de setembro centro hist�', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('sete', 'LOGRA', 1), ('de', 'LOGRA', 1), ('setembro', 'LOGRA', 1), ('centro', 'LOGRA', 1), ('hist', 'LOGRA', 1), ('�', 'LOGRA', 1), ('rico', '', 2), ('90010-190', '', 2), ('porto', '', 2), ('alegre', '', 2), ('rs', '', 2)]
#
# Entities [('av.anhanguera quadra 98', 'LOGRA')]
# Tokens [('av.anhanguera', 'LOGRA', 3), ('quadra', 'LOGRA', 1), ('98', 'LOGRA', 1), ('lote', '', 2), ('5', '', 2), ('n.', '', 2), ('8603', '', 2), ('setor', '', 2), ('campinas', '', 2), ('74503-101', '', 2), ('goiania', '', 2), ('go', '', 2)]
#
# Entities [('av.mal.candido rondon 97', 'LOGRA')]
# Tokens [('av.mal.candido', 'LOGRA', 3), ('rondon', 'LOGRA', 1), ('97', 'LOGRA', 1), ('centro', '', 2), ('85840-000', '', 2), ('ceu', '', 2), ('azul', '', 2), ('pr', '', 2)]
#
# Entities [('alameda santos 466', 'LOGRA')]
# Tokens [('alameda', 'LOGRA', 3), ('santos', 'LOGRA', 1), ('466', 'LOGRA', 1), ('4', '', 2), ('�', '', 2), ('andar', '', 2), ('-', '', 2), ('parte', '', 2), ('cerqueira', '', 2), ('c', '', 2), ('�', '', 2), ('sar', '', 2), ('01418-000', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('avenida republica do chile 330', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('republica', 'LOGRA', 1), ('do', 'LOGRA', 1), ('chile', 'LOGRA', 1), ('330', 'LOGRA', 1), ('centro', '', 2), ('20031-170', '', 2), ('rio', '', 2), ('de', '', 2), ('janeiro', '', 2), ('rj', '', 2)]
#
# Entities [('rua borges de medeiros 466', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), 
 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('artur', 'LOGRA', 1), ('costa', 'LOGRA', 1), ('silva', 'LOGRA', 1), ('5', 'LOGRA', 1), ('centro', '', 2), ('35938-000', '', 2), ('bela', '', 2), ('vista', '', 2), ('de', '', 2), ('minas', '', 2), ('mg', '', 2)]
#
# Entities [('praca serra lima 644', 'LOGRA')]
# Tokens [('praca', 'LOGRA', 3), ('serra', 'LOGRA', 1), ('lima', 'LOGRA', 1), ('644', 'LOGRA', 1), ('centro', '', 2), ('35010-250', '', 2), ('governador', '', 2), ('valadares', '', 2), ('mg', '', 2)]
#
# Entities [('pca.dr.luciano esteves 9', 'LOGRA')]
# Tokens [('pca.dr.luciano', 'LOGRA', 3), ('esteves', 'LOGRA', 1), ('9', 'LOGRA', 1), ('1', '', 2), ('andar', '', 2), ('centro', '', 2), ('13480-048', '', 2), ('limeira', '', 2), ('sp', '', 2)]
#
# Entities [('av. amaral peixoto 424', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('amaral', 'LOGRA', 1), ('peixoto', 'LOGRA', 1), ('424', 'LOGRA', 1), ('centro', '', 2), ('27253-220', '', 2), ('volta', '', 2), ('redonda', '', 2), ('rj', '', 2)]
#
# Entities [('rua quinze de novembro s/n', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('quinze', 'LOGRA', 1), ('de', 'LOGRA', 1), ('novembro', 'LOGRA', 1), ('s', 'LOGRA', 1), ('/', 'LOGRA', 1), ('n', 'LOGRA', 1), ('.', '', 2), ('centro', '', 2), ('24020-125', '', 2), ('niteroi', '', 2), ('rj', '', 2)]
#
# Entities [('praca dom pedro ii 75', 'LOGRA')]
# Tokens [('praca', 'LOGRA', 3), ('dom', 'LOGRA', 1), ('pedro', 'LOGRA', 1), ('ii', 'LOGRA', 1), ('75', 'LOGRA', 1), ('centro', '', 2), ('37701-035', '', 2), ('pocos', '', 2), ('de', '', 2), ('caldas', '', 2), ('mg', '', 2)]
#
# Entities [('av.cupece 3249', 'LOGRA')]
# Tokens [('av.cupece', 'LOGRA', 3), ('3249', 'LOGRA', 1), ('jd.prudencia', '', 2), ('04365-001', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('unb sg 11', 'LOGRA')]
# Tokens [('unb', 'LOGRA', 3), ('sg', 'LOGRA', 1), ('11', 'LOGRA', 1), ('campus', '', 2), ('universit', '', 2), ('�', '', 2), ('rio', '', 2), ('bl', '', 2), ('.', '', 2), ('m', '', 2), ('�', '', 2), ('ltiplos', '', 2), ('usos', '', 2), ('70910-900', '', 2), ('brasilia', '', 2), ('df', '', 2)]
#
# Entities [('av.brasilia lojas 1 e 2', 'LOGRA')]
# Tokens [('av.brasilia', 'LOGRA', 3), ('lojas', 'LOGRA', 1), ('1', 'LOGRA', 1), ('e', 'LOGRA', 1), ('2', 'LOGRA', 1), ('s', '', 2), ('�', '', 2), ('o', '', 2), ('benedito', '', 2), ('33110-580', '', 2), ('santa', '', 2), ('luzia', '', 2), ('mg', '', 2)]
#
# Entities [('rua capit�o deslandes 53', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), 
 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('clemente', 'LOGRA', 1), ('�', 'LOGRA', 1), ('lvares', 'LOGRA', 1), ('351', 'LOGRA', 1), ('centro', '', 2), ('05074-050', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('rua dr.maruri', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('dr.maruri', 'LOGRA', 1), ('centro', '', 2), ('89700-000', '', 2), ('concordia', '', 2), ('sc', '', 2)]
#
# Entities [('r.frei elseario buffon 194', 'LOGRA')]
# Tokens [('r.frei', 'LOGRA', 3), ('elseario', 'LOGRA', 1), ('buffon', 'LOGRA', 1), ('194', 'LOGRA', 1), ('terreo', '', 2), ('centro', '', 2), ('84935-000', '', 2), ('tomazina', '', 2), ('pr', '', 2)]
#
# Entities [('r.floriano peixoto 761', 'LOGRA')]
# Tokens [('r.floriano', 'LOGRA', 3), ('peixoto', 'LOGRA', 1), ('761', 'LOGRA', 1), ('centro', '', 2), ('13300-005', '', 2), ('itu', '', 2), ('sp', '', 2)]
#
# Entities [('r. jose f.carvalho s/n�', 'LOGRA')]
# Tokens [('r.', 'LOGRA', 3), ('jose', 'LOGRA', 1), ('f.carvalho', 'LOGRA', 1), ('s', 'LOGRA', 1), ('/', 'LOGRA', 1), ('n', 'LOGRA', 1), ('�', 'LOGRA', 1), ('esq', '', 2), ('.', '', 2), ('c/', '', 2), ('r.', '', 2), ('cel', '', 2), ('.', '', 2), ('aristides', '', 2), ('centro', '', 2), ('76400-000', '', 2), ('uruacu', '', 2), ('go', '', 2)]
#
# Entities [('av centenario s/n', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('centenario', 'LOGRA', 1), ('s', 'LOGRA', 1), ('/', 'LOGRA', 1), ('n', 'LOGRA', 1), ('operaria', '', 2), ('nova', '', 2), ('88809-000', '', 2), ('criciuma', '', 2), ('sc', '', 2)]
#
# Entities [('praca santa isabel 302', 'LOGRA')]
# Tokens [('praca', 'LOGRA', 3), ('santa', 'LOGRA', 1), ('isabel', 'LOGRA', 1), ('302', 'LOGRA', 1), ('centro', '', 2), ('15870-000', '', 2), ('catigua', '', 2), ('sp', '', 2)]
#
# Entities [('pca.dep.darcy marinho 16', 'LOGRA')]
# Tokens [('pca.dep.darcy', 'LOGRA', 3), ('marinho', 'LOGRA', 1), ('16', 'LOGRA', 1), ('centro', '', 2), ('77900-000', '', 2), ('tocantinopolis', '', 2), ('to', '', 2)]
#
# Entities [('rua conselheiro moreira de barros 409', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('conselheiro', 'LOGRA', 1), ('moreira', 'LOGRA', 1), ('de', 'LOGRA', 1), ('barros', 'LOGRA', 1), ('409', 'LOGRA', 1), ('santana', '', 2), ('02018-011', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('pra�a roberto cintra n� 392', 'LOGRA')]
# Tokens [('pra', 'LOGRA', 3), ('�', 'LOGRA', 1), ('a', 'LOGRA', 1), ('roberto', 'LOGRA', 1), ('cintra', 'LOGRA', 1), ('n', 'LOGRA', 1), ('�', 'LOGRA', 1), ('392', 'LOGRA', 1), ('centro', '', 2), ('44600-000', '', 2), ('ipira', '', 2), ('ba', '', 2)]
#
# Entities [('rua parana 185', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('parana', 'LOGRA', 1), ('185', 'LOGRA', 1), ('centro', '', 2), ('84900-000', '', 2), ('ibaiti', '', 2), ('pr', '', 2)]
#
# Entities [('rua rui barbosa', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('rui', 'LOGRA', 1), ('barbosa', 'LOGRA', 1), ('centro', '', 2), ('14840-000', '', 2), ('guariba', '', 2), ('sp', '', 2)]
#
# Entities [('av prof jos� bareto 25', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('prof', 'LOGRA', 1), ('jos', 'LOGRA', 1), ('�', 'LOGRA', 1), ('bareto', 'LOGRA', 1), ('25', 'LOGRA', 1), ('centro', '', 2), ('06703-001', '', 2), ('cotia', '', 2), ('sp', '', 2)]
#
# Entities [('av.conselheiro carrao 1950', 'LOGRA')]
# Tokens [('av.conselheiro', 'LOGRA', 3), ('carrao', 'LOGRA', 1), ('1950', 'LOGRA', 1), ('bras', '', 2), ('03402-001', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('rua riachuelo 70/74', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('riachuelo', 'LOGRA', 1), ('70/74', 'LOGRA', 1), ('se', '', 2), ('01007-000', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
# Entities [('rua dona chiquinha de mattos', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('dona', 'LOGRA', 1), ('chiquinha', 'LOGRA', 1), ('de', 'LOGRA', 1), ('mattos', 'LOGRA', 1), ('centro', '', 2), ('12020-010', '', 2), ('taubate', '', 2), ('sp', '', 2)]
#
# Entities [('av. em�lio bosco 201', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('em', 'LOGRA', 1), ('�', 'LOGRA', 1), ('lio', 'LOGRA', 1), ('bosco', 'LOGRA', 1), ('201', 'LOGRA', 1), ('condom', '', 2), ('�', '', 2), ('nio', '', 2), ('coronel', '', 2), ('jardim', '', 2), ('morumbi', '', 2), ('13180-000', '', 2), ('sumare', '', 2), ('sp', '', 2)]
#
# Entities [('avenida das na��', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('das', 'LOGRA', 1), ('na', 'LOGRA', 1), ('�', 'LOGRA', 1), ('�', 'LOGRA', 1), ('es', '', 2), ('unidas', '', 2), ('12559', '', 2), ('brooklin', '', 2), ('paulista', '', 2), ('04578-903', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('pca.pref.mario carneiro 23', 'LOGRA')]
# Tokens [('pca.pref.mario', 'LOGRA', 3), ('carneiro', 'LOGRA', 1), ('23', 'LOGRA', 1), ('centro', '', 2), ('35610-000', '', 2), ('dores', '', 2), ('do', '', 2), ('indaia', '', 2), ('mg', '', 2)]
#
# Entities [('av. moises lupion 580', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('moises', 'LOGRA', 1), ('lupion', 'LOGRA', 1), ('580', 'LOGRA', 1), ('centro', '', 2), ('87360-000', '', 2), ('goioere', '', 2), ('pr', '', 2)]
#
# Entities [('av. presidente medici 268', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('presidente', 'LOGRA', 1), ('medici', 'LOGRA', 1), ('268', 'LOGRA', 1), ('parque', '', 2), ('piaui', '', 2), ('65636-010', '', 2), ('timon', '', 2), ('ma', '', 2)]
#
# Entities [('av. presidente getulio vargas 89', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), 
 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('jorge', 'LOGRA', 1), ('zipperer', 'LOGRA', 1), ('358', 'LOGRA', 1), ('centro', '', 2), ('89295-971', '', 2), ('rio', '', 2), ('negrinho', '', 2), ('sc', '', 2)]
#
# Entities [('av. celso garcia 3863', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('celso', 'LOGRA', 1), ('garcia', 'LOGRA', 1), ('3863', 'LOGRA', 1), ('tatuap', '', 2), ('�', '', 2), ('03063-000', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('rua sinimbu 2678', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('sinimbu', 'LOGRA', 1), ('2678', 'LOGRA', 1), ('centro', '', 2), ('95020-510', '', 2), ('caxias', '', 2), ('do', '', 2), ('sul', '', 2), ('rs', '', 2)]
#
# Entities [('r coronel jose galdino 416', 'LOGRA')]
# Tokens [('r', 'LOGRA', 3), ('coronel', 'LOGRA', 1), ('jose', 'LOGRA', 1), ('galdino', 'LOGRA', 1), ('416', 'LOGRA', 1), ('bosque', '', 2), ('69900-640', '', 2), ('rio', '', 2), ('branco', '', 2), ('ac', '', 2)]
#
# Entities [('rua joaquim vieira 85', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('joaquim', 'LOGRA', 1), ('vieira', 'LOGRA', 1), ('85', 'LOGRA', 1), ('centro', '', 2), ('45530-000', '', 2), ('itacare', '', 2), ('ba', '', 2)]
#
# Entities [('av. conceicao qd. 54 lt. 17', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('conceicao', 'LOGRA', 1), ('qd', 'LOGRA', 1), ('.', 'LOGRA', 1), ('54', 'LOGRA', 1), ('lt', 'LOGRA', 1), ('.', 'LOGRA', 1), ('17', 'LOGRA', 1), ('centro', '', 2), ('72900-000', '', 2), ('santo', '', 2), ('antonio', '', 2), ('do', '', 2), ('descoberto', '', 2), ('go', '', 2)]
#
# Entities [('rua br�s cubas 119', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('br', 'LOGRA', 1), ('�', 'LOGRA', 1), ('s', 'LOGRA', 1), ('cubas', 'LOGRA', 1), ('119', 'LOGRA', 1), ('vila', '', 2), ('nova', '', 2), ('11013-163', '', 2), ('santos', '', 2), ('sp', '', 2)]
#
# Entities [('r. bonaire 153', 'LOGRA')]
# Tokens [('r.', 'LOGRA', 3), ('bonaire', 'LOGRA', 1), ('153', 'LOGRA', 1), ('centro', '', 2), ('65930-000', '', 2), ('acailandia', '', 2), ('ma', '', 2)]
#
# Entities [('av. general david sarnoff 06', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('general', 'LOGRA', 1), ('david', 'LOGRA', 1), ('sarnoff', 'LOGRA', 1), ('06', 'LOGRA', 1), ('cidade', '', 2), ('industrial', '', 2), ('32210-110', '', 2), ('contagem', '', 2), ('mg', '', 2)]
#
# Entities [('av. governador mario covas jr 01 lj 75', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('governador', 'LOGRA', 1), ('mario', 'LOGRA', 1), ('covas', 'LOGRA', 1), ('jr', 'LOGRA', 1), ('01', 'LOGRA', 1), ('lj', 'LOGRA', 1), ('75', 'LOGRA', 1), ('mau', '', 2), ('�', '', 2), ('plaza', '', 2), ('shopping', '', 2), ('centro', '', 2), ('93900-400', '', 2), ('maua', '', 2), ('sp', '', 2)]
#
# Entities [('rua jarbas passarinho', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), 
 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('rep', 'LOGRA', 1), ('�', 'LOGRA', 1), ('blica', 'LOGRA', 1), ('do', 'LOGRA', 1), ('l', 'LOGRA', 1), ('�', 'LOGRA', 1), ('bano', 'LOGRA', 1), ('loja', 'LOGRA', 1), ('5019', 'LOGRA', 1), ('sc', 'LOGRA', 1), ('505', 'LOGRA', 1), ('piso', '', 2), ('g1', '', 2), ('pina', '', 2), ('51110-160', '', 2), ('recife', '', 2), ('pe', '', 2)]
#
# Entities [('av.cel.antonio duarte 43', 'LOGRA')]
# Tokens [('av.cel.antonio', 'LOGRA', 3), ('duarte', 'LOGRA', 1), ('43', 'LOGRA', 1), ('centro', '', 2), ('29280-000', '', 2), ('iconha', '', 2), ('es', '', 2)]
#
# Entities [('avenida duque de caxias 596', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('duque', 'LOGRA', 1), ('de', 'LOGRA', 1), ('caxias', 'LOGRA', 1), ('596', 'LOGRA', 1), ('santa', '', 2), ('efigenia', '', 2), ('01214-000', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('av. firmino teixeira griffo n� 10', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('firmino', 'LOGRA', 1), ('teixeira', 'LOGRA', 1), ('griffo', 'LOGRA', 1), ('n', 'LOGRA', 1), ('�', 'LOGRA', 1), ('10', 'LOGRA', 1), ('centro', '', 2), ('29630-000', '', 2), ('brejetuba', '', 2), ('es', '', 2)]
#
# Entities [('av itapemirim 559', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('itapemirim', 'LOGRA', 1), ('559', 'LOGRA', 1), ('praia', '', 2), ('de', '', 2), ('itaipava', '', 2), ('29330-000', '', 2), ('itapemirim', '', 2), ('es', '', 2)]
#
# Entities [('av. praia de belas n� 1181', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('praia', 'LOGRA', 1), ('de', 'LOGRA', 1), ('belas', 'LOGRA', 1), ('n', 'LOGRA', 1), ('�', 'LOGRA', 1), ('1181', 'LOGRA', 1), ('loja', '', 2), ('1009', '', 2), ('praia', '', 2), ('de', '', 2), ('belas', '', 2), ('90110-001', '', 2), ('porto', '', 2), ('alegre', '', 2), ('rs', '', 2)]
#
# Entities [('pca.mal.eduardo gomes 50', 'LOGRA')]
# Tokens [('pca.mal.eduardo', 'LOGRA', 3), ('gomes', 'LOGRA', 1), ('50', 'LOGRA', 1), ('pca.quero-quero', '', 2), ('campus', '', 2), ('cta', '', 2), ('12228-615', '', 2), ('sao', '', 2), ('jose', '', 2), ('dos', '', 2), ('campos', '', 2), ('sp', '', 2)]
#
# Entities [('r.mariz e barros 1000/1004', 'LOGRA')]
# Tokens [('r.mariz', 'LOGRA', 3), ('e', 'LOGRA', 1), ('barros', 'LOGRA', 1), ('1000/1004', 'LOGRA', 1), ('tijuca', '', 2), ('20270-002', '', 2), ('rio', '', 2), ('de', '', 2), ('janeiro', '', 2), ('rj', '', 2)]
#
# Entities [('av. xv de novembro 81/85', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('xv', 'LOGRA', 1), ('de', 'LOGRA', 1), ('novembro', 'LOGRA', 1), ('81/85', 'LOGRA', 1), ('vila', '', 2), ('romanipolis', '', 2), ('08500-405', '', 2), ('ferraz', '', 2), ('de', '', 2), ('vasconcelos', '', 2), ('sp', '', 2)]
#
# Entities [('rua real grandeza 219', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('real', 'LOGRA', 1), ('grandeza', 'LOGRA', 1), ('219', 'LOGRA', 1), ('bloco', '', 2), ('c', '', 2), ('botafogo', '', 2), ('22283-900', '', 2), ('rio', '', 2), ('de', '', 2), ('janeiro', '', 2), ('rj', '', 2)]
#
# Entities [('av doutor helio ribeiro 487', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('doutor', 'LOGRA', 1), ('helio', 'LOGRA', 1), ('ribeiro', 'LOGRA', 1), ('487', 'LOGRA', 1), ('edificio', '', 2), ('concorde', '', 2), ('-', '', 2), ('04', '', 2), ('�', '', 2), ('andar', '', 2), ('-', '', 2), ('esc', '', 2), ('.', '', 2), ('mpe', '', 2), ('res', '', 2), ('paiaguas', '', 2), ('78048-250', '', 2), ('cuiaba', '', 2), ('mt', '', 2)]
#
# Entities [('rua delegado pinto de toledo 3032', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('delegado', 'LOGRA', 1), ('pinto', 'LOGRA', 1), ('de', 'LOGRA', 1), ('toledo', 'LOGRA', 1), ('3032', 'LOGRA', 1), ('centro', '', 2), ('15010-080', '', 2), ('sao', '', 2), ('jose', '', 2), ('do', '', 2), ('rio', '', 2), ('preto', '', 2), ('sp', '', 2)]
#
# Entities [('rua firmino pantoja s/n', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('firmino', 'LOGRA', 1), ('pantoja', 'LOGRA', 1), ('s', 'LOGRA', 1), ('/', 'LOGRA', 1), ('n', 'LOGRA', 1), ('.', '', 2), ('centro', '', 2), ('65295-000', '', 2), ('carutapera', '', 2), ('ma', '', 2)]
#
# Entities [('pra�a do mercado 103', 'LOGRA')]
# Tokens [('pra', 'LOGRA', 3), ('�', 'LOGRA', 1), ('a', 'LOGRA', 1), ('do', 'LOGRA', 1), ('mercado', 'LOGRA', 1), ('103', 'LOGRA', 1), ('centro', '', 2), ('49810-000', '', 2), ('poco', '', 2), ('redondo', '', 2), ('se', '', 2)]
#
# Entities [('av.pio xii', 'LOGRA')]
# Tokens [('av.pio', 'LOGRA', 3), ('xii', 'LOGRA', 1), ('esq.c', '', 2), ('/', '', 2), ('rua', '', 2), ('da', '', 2), ('imprensa', '', 2), ('quadra', '', 2), ('1', '', 2), ('lotes', '', 2), ('5/6', '', 2), ('vl.aurora', '', 2), ('oeste', '', 2), ('74425-098', '', 2), ('goiania', '', 2), ('go', '', 2)]
#
# Entities [('avenida angelica', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('angelica', 'LOGRA', 1), ('consolacao', '', 2), ('01228-200', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('avenida tenente marques 1780', 'LOGRA')]
# ...
#
# Entities [('av.brasil 1', 'LOGRA')]
# Tokens [('av.brasil', 'LOGRA', 3), ('1', 'LOGRA', 1), ('centro', '', 2), ('78800-000', '', 2), ('poxoreu', '', 2), ('mt', '', 2)]
#
# Entities [('praca sen eneas araujo 38', 'LOGRA')]
# Tokens [('praca', 'LOGRA', 3), ('sen', 'LOGRA', 1), ('eneas', 'LOGRA', 1), ('araujo', 'LOGRA', 1), ('38', 'LOGRA', 1), ('centro', '', 2), ('57500-000', '', 2), ('santana', '', 2), ('do', '', 2), ('ipanema', '', 2), ('al', '', 2)]
#
# Entities [('avenida 136', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('136', 'LOGRA', 1), ('2', '', 2), ('�', '', 2), ('andar', '', 2), ('st', '', 2), ('marista', '', 2), ('74180-040', '', 2), ('goiania', '', 2), ('go', '', 2)]
#
# Entities [('largo do arouche 155', 'LOGRA')]
# Tokens [('largo', 'LOGRA', 3), ('do', 'LOGRA', 1), ('arouche', 'LOGRA', 1), ('155', 'LOGRA', 1), ('republica', '', 2), ('01219-001', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [
 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('bernardino', 'LOGRA', 1), ('de', 'LOGRA', 1), ('lima', 'LOGRA', 1), ('paes', 'LOGRA', 1), ('49', 'LOGRA', 1), ('centro', '', 2), ('12990-000', '', 2), ('pedra', '', 2), ('bela', '', 2), ('sp', '', 2)]
#
# Entities [('r.sena madureira 43', 'LOGRA')]
# Tokens [('r.sena', 'LOGRA', 3), ('madureira', 'LOGRA', 1), ('43', 'LOGRA', 1), ('pontilhao', '', 2), ('36202-360', '', 2), ('barbacena', '', 2), ('mg', '', 2)]
#
# Entities [('av. rio branco 828', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('rio', 'LOGRA', 1), ('branco', 'LOGRA', 1), ('828', 'LOGRA', 1), ('centro', '', 2), ('96450-000', '', 2), ('dom', '', 2), ('pedrito', '', 2), ('rs', '', 2)]
#
# Entities [('av.reginaldo lemes da silva 564', 'LOGRA')]
# Tokens [('av.reginaldo', 'LOGRA', 3), ('lemes', 'LOGRA', 1), ('da', 'LOGRA', 1), ('silva', 'LOGRA', 1), ('564', 'LOGRA', 1), ('predio', '', 2), ('centro', '', 2), ('79215-000', '', 2), ('dois', '', 2), ('irmaos', '', 2), ('do', '', 2), ('buriti', '', 2), ('ms', '', 2)]
#
# Entities [('r.nelsino ravagnani 1077', 'LOGRA')]
# Tokens [('r.nelsino', 'LOGRA', 3), ('ravagnani', 'LOGRA', 1), ('1077', 'LOGRA', 1), ('v.sao', '', 2), ('jose', '', 2), ('86165-000', '', 2), ('florestopolis', '', 2), ('pr', '', 2)]
#
# Entities [('rua mal. floriano peixoto 5760', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('mal', 'LOGRA', 1), ('.', 'LOGRA', 1), ('floriano', 'LOGRA', 1), ('peixoto', 'LOGRA', 1), ('5760', 'LOGRA', 1), ('vl', '', 2), ('.', '', 2), ('haver', '', 2), ('81630-000', '', 2), ('curitiba', '', 2), ('pr', '', 2)]
#
# Entities [('rua14 de marco - base fluvial', 'LOGRA')]
# Tokens [('rua14', 'LOGRA', 3), ('de', 'LOGRA', 1), ('marco', 'LOGRA', 1), ('-', 'LOGRA', 1), ('base', 'LOGRA', 1), ('fluvial', 'LOGRA', 1), ('ladario', '', 2), ('centro', '', 2), ('79370-000', '', 2), ('ladario', '', 2), ('ms', '', 2)]
#
# Entities [('av manoel ribas 5788', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('manoel', 'LOGRA', 1), ('ribas', 'LOGRA', 1), ('5788', 'LOGRA', 1), ('santa', '', 2), ('felicidade', '', 2), ('82400-000', '', 2), ('curitiba', '', 2), ('pr', '', 2)]
#
# Entities [('rodovia br 316 km 1', 'LOGRA')]
# Tokens [('rodovia', 'LOGRA', 3), ('br', 'LOGRA', 1), ('316', 'LOGRA', 1), ('km', 'LOGRA', 1), ('1', 'LOGRA', 1), ('atalaia', '', 2), ('67013-000', '', 2), ('ananindeua', '', 2), ('pa', '', 2)]
#
# Entities [('rua republica arabe da siria', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('republica', 'LOGRA', 1), ('arabe', 'LOGRA', 1), ('da', 'LOGRA', 1), ('siria', 'LOGRA', 1), ('loja', '', 2), ('a', '', 2), ('portuguesa', '', 2), ('21931-370', '', 2), ('rio', '', 2), ('de', '', 2), ('janeiro', '', 2), ('rj', '', 2)]
#
# Entities [('rua xv de novembro 44', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('xv', 'LOGRA', 1), ('de', 'LOGRA', 1), ('novembro', 'LOGRA', 1), ('44', 'LOGRA', 1), ('centro', '', 2), ('89665-000', '', 2), ('capinzal', '', 2), ('sc', '', 2)]
#
# Entities [('av das am�ricas 500', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('das', 'LOGRA', 1), ('am', 'LOGRA', 1), ('�', 'LOGRA', 1), ('ricas', 'LOGRA', 1), ('500', 'LOGRA', 1), ('bloco', '', 2), ('22lojas', '', 2), ('118/119/136/137', '', 2), ('barra', '', 2), ('da', '', 2), ('tijuca', '', 2), ('22640-904', '', 2), ('rio', '', 2), ('de', '', 2), ('janeiro', '', 2), ('rj', '', 2)]
#
# Entities [('pca.ruy barbosa s/', 'LOGRA')]
# Tokens [('pca.ruy', 'LOGRA', 3), ('barbosa', 'LOGRA', 1), ('s', 'LOGRA', 1), ('/', 'LOGRA', 1), ('n', '', 2), ('terreo', '', 2), ('centro', '', 2), ('48430-000', '', 2), ('paripiranga', '', 2), ('ba', '', 2)]
#
# Entities [('av.brasil 6546', 'LOGRA')]
# Tokens [('av.brasil', 'LOGRA', 3), ('6546', 'LOGRA', 1), ('quadra', '', 2), ('32', '', 2), ('datas', '', 2), ('1', '', 2), ('e', '', 2), ('2', '', 2), ('zona', '', 2), ('6', '', 2), ('87015-281', '', 2), ('maringa', '', 2), ('pr', '', 2)]
#
# Entities [('r.manoel teixeira 104', 'LOGRA')]
# Tokens [('r.manoel', 'LOGRA', 3), ('teixeira', 'LOGRA', 1), ('104', 'LOGRA', 1), ('centro', '', 2), ('62690-000', '', 2), ('trairi', '', 2), ('ce', '', 2)]
#
# Entities [('avenida assis brasil', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('assis', 'LOGRA', 1), ('brasil', 'LOGRA', 1), ('cristo', '', 2), ('redentor', '', 2), ('91140-001', '', 2), ('porto', '', 2), ('alegre', '', 2), ('rs', '', 2)]
#
# Entities [('av. conceicao 4625', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('conceicao', 'LOGRA', 1), ('4625', 'LOGRA', 1), ('jd', '', 2), ('japao', '', 2), ('02135-002', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('r.julio noroes 433', 'LOGRA')]
# Tokens [('r.julio', 'LOGRA', 3), ('noroes', 'LOGRA', 1), ('433', 'LOGRA', 1), ('centro', '', 2), ('63150-000', '', 2), ('campos', '', 2), ('sales', '', 2), ('ce', '', 2)]
#
# Entities [('rua barao de campinas 376', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('barao', 'LOGRA', 1), ('de', 'LOGRA', 1), ('campinas', 'LOGRA', 1), ('376', 'LOGRA', 1), ('centro', '', 2), ('13480-210', '', 2), ('limeira', '', 2), ('sp', '', 2)]
#
# Entities [('r.n.sra.da lapa 281', 'LOGRA')]
# Tokens [('r.n.sra.da', 'LOGRA', 3), ('lapa', 'LOGRA', 1), ('281', 'LOGRA', 1), ('lapa', '', 2), ('05072-000', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('avenida parada pinto', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('parada', 'LOGRA', 1), ('pinto', 'LOGRA', 1), ('lj', '', 2), ('03', '', 2), ('vl', '', 2), ('nova', '', 2), ('cachoeirinha', '', 2), ('02611-000', '', 2), ('sao', '', 2), ('paulo', '', 2), ('sp', '', 2)]
#
# Entities [('av. presidente lucena', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('presidente', 'LOGRA', 1), ('lucena', 'LOGRA', 1), ('centro', '', 2), ('93900-000', '', 2), ('ivoti', '', 2), ('rs', '', 2)]
#
# Entities [('av getulio vargas', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('getulio', 'LOGRA', 1), ('vargas', 'LOGRA', 1), ('centro', '', 2), ('83301-010', '', 2), ('piraquara', '', 2), ('pr', '', 2)]
#
# Entities [('rua do com�rcio n� 288', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('do', 'LOGRA', 1), ('com', 'LOGRA', 1), ('�', 'LOGRA', 1), ('rcio', 'LOGRA', 1), ('n', 'LOGRA', 1), ('�', 'LOGRA', 1), ('288', 'LOGRA', 1), ('conjunto', '', 2), ('castelo', '', 2), ('branco', '', 2), ('parque', '', 2), ('10de', '', 2), ('novembro', '', 2), ('69055-000', '', 2), ('manaus', '', 2), ('am', '', 2)]
#
# Entities [('rua guilherme shell 3950', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('guilherme', 'LOGRA', 1), ('shell', 'LOGRA', 1), ('3950', 'LOGRA', 1), ('v', '', 2), ('comando', '', 2), ('aereo', '', 2), ('regional', '', 2), ('centro', '', 2), ('92200-630', '', 2), ('canoas', '', 2), ('rs', '', 2)]
#
# Entities [('rua dr. joaquim manoel', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('dr', 'LOGRA', 1), ('.', 'LOGRA', 1), ('joaquim', 'LOGRA', 1), ('manoel', 'LOGRA', 1), ('centro', '', 2), ('46430-000', '', 2), ('guanambi', '', 2), ('ba', '', 2)]
#
# Entities [('av. joao paulo iis/n. quadra 24', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('joao', 'LOGRA', 1), ('paulo', 'LOGRA', 1), ('iis', 'LOGRA', 1), ('/', 'LOGRA', 1), ('n', 'LOGRA', 1), ('.', 'LOGRA', 1), ('quadra', 'LOGRA', 1), ('24', 'LOGRA', 1), ('centro', '', 2), ('69730-000', '', 2), ('novo', '', 2), ('airao', '', 2), ('am', '', 2)]
#
# Entities [('av. vereador toaldo tulio 3101', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('vereador', 'LOGRA', 1), ('toaldo', 'LOGRA', 1), ('tulio', 'LOGRA', 1), ('3101', 'LOGRA', 1), ('sao', '', 2), ('braz', '', 2), ('82300-000', '', 2), ('curitiba', '', 2), ('pr', '', 2)]
#
# Entities [('av. ozy mendonca de lima 513', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('ozy', 'LOGRA', 1), ('mendonca', 'LOGRA', 1), ('de', 'LOGRA', 1), ('lima', 'LOGRA', 1), ('513', 'LOGRA', 1), ('centro', '', 2), ('83900-000', '', 2), ('sao', '', 2), ('mateus', '', 2), ('do', '', 2), ('sul', '', 2), ('pr', '', 2)]
#
# Entities [('scn qd.01 bloco e lojas 165', 'LOGRA')]
# Tokens [('scn', 'LOGRA', 3), ('qd.01', 'LOGRA', 1), ('bloco', 'LOGRA', 1), ('e', 'LOGRA', 1), ('lojas', 'LOGRA', 1), ('165', 'LOGRA', 1), ('170', '', 2), ('e', '', 2), ('175', '', 2), ('edif.central', '', 2), ('setor', '', 2), ('coml.norte', '', 2), ('70354-530', '', 2), ('brasilia', '', 2), ('df', '', 2)]
#
# Entities [('rua general netto 1122', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('general', 'LOGRA', 1), ('netto', 'LOGRA', 1), ('1122', 'LOGRA', 1), ('centro', '', 2), ('96100-000', '', 2), ('pelotas', '', 2), ('rs', '', 2)]
#
# Entities [('av mal campos 1355', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('mal', 'LOGRA', 1), ('campos', 'LOGRA', 1), ('1355', 'LOGRA', 1), ('santa', '', 2), ('cecilia', '', 2), ('29043-260', '', 2), ('vitoria', '', 2), ('es', '', 2)]
#
# Entities [('r pres.epitacio pessoa', 'LOGRA')]
# Tokens [('r', 'LOGRA', 3), ('pres.epitacio', 'LOGRA', 1), ('pessoa', 'LOGRA', 1), ('centro', '', 2), ('58700-020', '', 2), ('patos', '', 2), ('pb', '', 2)]
# Entities [('av mister hull padre andrade', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('mister', 'LOGRA', 1), ('hull', 'LOGRA', 1), ('padre', 'LOGRA', 1), ('andrade', 'LOGRA', 1), ('antonio', '', 2), ('bezerra', '', 2), ('60356-412', '', 2), ('fortaleza', '', 2), ('ce', '', 2)]
#
# Entities [('avenida ministro geraldo barreto sobral', 'LOGRA')]
# Tokens [('avenida', 'LOGRA', 3), ('ministro', 'LOGRA', 1), ('geraldo', 'LOGRA', 1), ('barreto', 'LOGRA', 1), ('sobral', 'LOGRA', 1), ('jardins', '', 2), ('49026-010', '', 2), ('aracaju', '', 2), ('se', '', 2)]
#
# Entities [('rua olavo barreto viana', 'LOGRA')]
# Tokens [('rua', 'LOGRA', 3), ('olavo', 'LOGRA', 1), ('barreto', 'LOGRA', 1), ('viana', 'LOGRA', 1), ('moinhos', '', 2), ('de', '', 2), ('vento', '', 2), ('90570-070', '', 2), ('porto', '', 2), ('alegre', '', 2), ('rs', '', 2)]
#
# Entities [('av julio borella 1085', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('julio', 'LOGRA', 1), ('borella', 'LOGRA', 1), ('1085', 'LOGRA', 1), ('centro', '', 2), ('99150-000', '', 2), ('marau', '', 2), ('rs', '', 2)]
#
# Entities [('av. 29 de agosto 240', 'LOGRA')]
# Tokens [('av', 'LOGRA', 3), ('.', 'LOGRA', 1), ('29', 'LOGRA', 1), ('de', 'LOGRA', 1), ('agosto', 'LOGRA', 1), ('240', 'LOGRA', 1), ('parte', '', 2), ('centro', '', 2), ('13610-210', '', 2), ('leme', '', 2), ('sp', '', 2)]

# %%
phrase = "QNE 20 12  teste de endereço pedro leonardo"

doc = nlp(phrase)
print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
print('Tokens', [(t.text, t.ent_type_, t.ent_iob) for t in doc])
# Out:
# Entities [('QNE 20 12  ', 'LOGRA')]
# Tokens [('QNE', 'LOGRA', 3), ('20', 'LOGRA', 1), ('12', 'LOGRA', 1), (' ', 'LOGRA', 1), ('teste', '', 2), ('de', '', 2), ('endereço', '', 2), ('pedro', '', 2), ('leonardo', '', 2)]

# %%
from spacy.gold import GoldParse
from spacy.scorer import Scorer

def evaluate(ner_model, examples):
    scorer = Scorer()
    for input_, annot in examples:
        doc_gold_text = ner_model.make_doc(input_)
        gold = GoldParse(doc_gold_text, entities=annot)
        pred_value = ner_model(input_)
        scorer.score(pred_value, gold)
    return scorer.scores

# %%
# save model to output directory
if output_dir is not None:
    output_dir = Path(output_dir)
    if not output_dir.exists():
        output_dir.mkdir()
    nlp.to_disk(output_dir)
    print("Saved model to", output_dir)

# %%
loaded_model = spacy.load(output_dir)
evaluate(loaded_model, base_teste_final)
