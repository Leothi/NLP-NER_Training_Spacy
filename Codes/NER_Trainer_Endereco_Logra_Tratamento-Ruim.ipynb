# %%
# Load Packages
from __future__ import unicode_literals, print_function

import plac #  wrapper over argparse
import random
from pathlib import Path
import spacy
from tqdm import tqdm, tqdm_notebook # loading bar 
import pandas as pd
import re
from pprint import pprint
from nltk.tokenize import sent_tokenize
import numpy as np
import unicodedata
from spacy.util import minibatch, compounding

# %%
# Função para substituir acentos

def strip_accents(text):
    try:
        text = unicode(text, 'utf-8')
    except (TypeError, NameError): # unicode is a default on python 3 
        pass
    text = unicodedata.normalize('NFD', text)
    text = text.encode('ascii', 'ignore')
    text = text.decode("utf-8")
    
    return str(text)

# %% [markdown]
# # Abrindo e gerando Datasets

# %% [markdown]
# ### Entidade logradouro

# %%
# Obtendo dados crus de endereço

dataset = pd.read_csv("../Datasets/201906AGENCIAS.CSV")
dset = dataset.iloc[:-2,4:10].values  # tipo nparray object
pd_dset = pd.DataFrame(dset) # caso queira visualizar

pd_dset['Join'] = pd_dset[pd_dset.columns[0:]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)
pd_dset.head(5)
# Out:
#                                           0  \
# 0  R.GUILHERME MOREIRA,315
# 1  AV.PRES.VARGAS,248
# 2  R.QUINZE DE NOVEMBRO,195
# 3  PCA.DAS QUATRO JORNADAS,11
# 4  SEXTA AVENIDA,600
#
#                                                    1  \
# 0  SUBLOJA,LOJA E 2.ANDAR                        ...
# 1  1.E 2.ANDARES                                 ...
# 2                                                ...
# 3  MEZANINO                                      ...
# 4  SECRETARIA DA EDUCACAO-TERREO                 ...
#
#                                 2          3  \
# 0  CENTRO                          69005-300
# 1  CAMPINA                         66010-900
# 2  CENTRO                          11010-908
# 3  CENTRO                          28010-000
# 4  CAB                             41745-002
#
#                                                    4   5  \
# 0  MANAUS                                        ...  AM
# 1  BELEM                                         ...  PA
# 2  SANTOS                                        ...  SP
# 3  CAMPOS DOS GOYTACAZES                         ...  RJ
# 4  SALVADOR                                      ...  BA
#
#                                                 Join
# 0  R.GUILHERME MOREIRA,315                 ;SUBLO...
# 1  AV.PRES.VARGAS,248                      ;1.E 2...
# 2  R.QUINZE DE NOVEMBRO,195                ;     ...
# 3  PCA.DAS QUATRO JORNADAS,11              ;MEZAN...
# 4  SEXTA AVENIDA,600                       ;SECRE...

# %%
# Tratando endereço completo do DataFrame
dset = np.array(pd_dset)
end_lista = []

for i in range(len(dset)):
    str_raw = dset[i][6]
    str_tratada = re.sub(r'[ ]{2,}', "",str_raw) # Tirando espaços excedentes no final do endereço
    str_tratada = re.sub(r'[;]{1,}', "; ", str_tratada) # Para complementos vazios, para não ter 2 ";"
    str_tratada = str_tratada.lower()
    str_tratada = str_tratada.replace(",", ", ")
    str_tratada = str_tratada.replace(".", " ")
    str_tratada = strip_accents(str_tratada)
    str_tratada = re.sub(r'[ ]{2,}', " ", str_tratada)

    end_lista.append(str_tratada)

end_lista[:3]
# Out:
# ['r guilherme moreira, 315; subloja, loja e 2 andar; centro; 69005-300; manaus; am',
#  'av pres vargas, 248; 1 e 2 andares; campina; 66010-900; belem; pa',
#  'r quinze de novembro, 195; centro; 11010-908; santos; sp']

# %%
# Lógica para extrair posição do logradouro:
# Dividir a String inteira por ";", pegar o len do primeiro split
# len de LOGRA é de 0 até len do primeiro split

print(end_lista[0])
split = end_lista[0].split(";")
print(split)
print(split[0])
print(len(split[0]))
# Out:
# r guilherme moreira, 315; subloja, loja e 2 andar; centro; 69005-300; manaus; am
# ['r guilherme moreira, 315', ' subloja, loja e 2 andar', ' centro', ' 69005-300', ' manaus', ' am']
# r guilherme moreira, 315
# 24

# %%
# Extraindo iob com entidade apenas de logradouro e fazendo mais tratamentos de texto

iob = []

for i in range(len(end_lista)):
    split = end_lista[i].split(";")
    len_logra = len(split[0])
    iob_dict = {"entities": [(0, len_logra-1,'LOGRA')]}
    end_lista[i] = end_lista[i].replace(";", " ")
    end_lista[i] = end_lista[i].replace("  ", " ")
#     end_lista[i] = end_lista[i].replace(",", " ")
    end_lista[i] = re.sub(r'^[ ]+', "", end_lista[i])
    
    tupla = (end_lista[i], iob_dict)
    iob.append(tupla)

FULL_DATA = iob[:2000]

# %%
print(FULL_DATA[0])
print(FULL_DATA[1])
print(FULL_DATA[2])
print(FULL_DATA[15])
# Out:
# ('r guilherme moreira, 315 subloja, loja e 2 andar centro 69005-300 manaus am', {'entities': [(0, 23, 'LOGRA')]})
# ('av pres vargas, 248 1 e 2 andares campina 66010-900 belem pa', {'entities': [(0, 18, 'LOGRA')]})
# ('r quinze de novembro, 195 centro 11010-908 santos sp', {'entities': [(0, 24, 'LOGRA')]})
# ('r sao bento, 483 centro 01011-100 sao paulo sp', {'entities': [(0, 15, 'LOGRA')]})

# %%
# Criação da base de teste e treinamento

n_test= 0.1 # Porcentagem para base de teste
test_n = round(len(FULL_DATA) * n_test)

# Divisao em Train Test Val

def gerador_bases(dataset, n):
    indices_random = random.sample(range(0,len(dataset)-1), n)
    base_teste_n = []
    base_treinamento_n = []
    
    for i in range(n):
        base_teste_n.append(dataset[indices_random[i]])

    for j in range(len(dataset)):
        if(j not in indices_random):
            base_treinamento_n.append(dataset[j])
            
    return base_teste_n, base_treinamento_n


base_teste, base_treinamento = gerador_bases(FULL_DATA, test_n)

random.shuffle(base_treinamento)
random.shuffle(base_teste)

print("Treinamento: " + str(len(base_treinamento)), "\nTeste: " + str(len(base_teste)), "\nTotal: " + str(len(FULL_DATA)))
# Out:
# Treinamento: 1800
# Teste: 200
# Total: 2000

# %%
for i in range(10):
    print(base_treinamento[i])
# Out:
# ('r alfredo backer, 536 loja a alcantara 24452-005 sao goncalo rj', {'entities': [(0, 20, 'LOGRA')]})
# ('av miguel varlez, 136 centro 11660-650 caraguatatuba sp', {'entities': [(0, 20, 'LOGRA')]})
# ('av pres vargas, 1184 terreo centro 99670-000 ronda alta rs', {'entities': [(0, 19, 'LOGRA')]})
# ('pca mons jose candido, 156 centro 63870-000 boa viagem ce', {'entities': [(0, 25, 'LOGRA')]})
# ('r pres backer, 124 icarai 24220-041 niteroi rj', {'entities': [(0, 17, 'LOGRA')]})
# ('av sete de setembro, 285 centro 84430-000 imbituva pr', {'entities': [(0, 23, 'LOGRA')]})
# ('r cel otavio magalhaes, 1 centro 77330-000 arraias to', {'entities': [(0, 24, 'LOGRA')]})
# ('pca jesuino braga, s/n centro 39320-000 ubai mg', {'entities': [(0, 21, 'LOGRA')]})
# ('r gal joao antonio, 1232 centro 97420-000 sao vicente do sul rs', {'entities': [(0, 23, 'LOGRA')]})
# ('pca epitacio pessoa, 35 centro 58360-000 itabaiana pb', {'entities': [(0, 22, 'LOGRA')]})

# %% [markdown]
# # Carregando o modelo

# %%
# Define our variables

model = None
output_dir=Path(".")
n_iter= 100 # número de épocas
batch_size = 32

# %%
# Setting up the pipeline and entity recognizer.
if model is not None:
    nlp = spacy.load(model)  # load existing spacy model
    print("Loaded model '%s'" % model)
else:
    lan = 'pt'
    nlp = spacy.blank(lan)  # create blank Language class
    print("Created blank '%s' model" % lan)
    
if 'ner' not in nlp.pipe_names:
    ner = nlp.create_pipe('ner')
    nlp.add_pipe(ner)
    print('Added new NER')
else:
    ner = nlp.get_pipe('ner')
    print('Got an old NER')
# Out:
# Created blank 'pt' model
# Added new NER

# %%
# create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
if 'ner' not in nlp.pipe_names:
    ner = nlp.create_pipe('ner')
    nlp.add_pipe(ner, last=True)
# otherwise, get it so we can add labels
else:
    ner = nlp.get_pipe('ner')

# %% [markdown]
# ## Treinamento

# %%
print("Batch size: ", batch_size)
print("Épocas: ", n_iter)
print()

# add labels
for _, annotations in base_treinamento:
    for ent in annotations.get('entities'):
        ner.add_label(ent[2])


# get names of other pipes to disable them during training
other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
with nlp.disable_pipes(*other_pipes):  # only train NER
    optimizer = nlp.begin_training()
    for itn in range(n_iter):
        random.shuffle(base_treinamento)
        losses = {}
        batches = minibatch(base_treinamento, size=batch_size)
        
        for batch in batches:
            texts, annotations = zip(*batch)
            try:
                nlp.update(texts, annotations, sgd=optimizer, drop=0.2,
                       losses=losses)
            except:
                pass     

        print(itn+1, ' Losses', losses)
# Out:
# Batch size:  32
# Épocas:  100
#
# 1  Losses {'ner': 2435.022968630853}
# 2  Losses {'ner': 813.3478246242817}
# 3  Losses {'ner': 699.3845468441936}
# 4  Losses {'ner': 493.97414442750977}
# 5  Losses {'ner': 352.7640323690594}
# 6  Losses {'ner': 282.43375146954423}
# 7  Losses {'ner': 253.60709409248008}
# 8  Losses {'ner': 331.67538340570957}
# 9  Losses {'ner': 217.42224349688374}
# 10  Losses {'ner': 186.22437523244457}
# 11  Losses {'ner': 245.84279787426843}
# 12  Losses {'ner': 263.14719206791546}
# 13  Losses {'ner': 236.48850227981185}
# 14  Losses {'ner': 272.5537822099532}
# 15  Losses {'ner': 578.3159944579454}
# 16  Losses {'ner': 187.0266775181807}
# 17  Losses {'ner': 318.3468696755638}
# 18  Losses {'ner': 451.4351607002218}
# 19  Losses {'ner': 1573.3701293687984}
# 20  Losses {'ner': 1173.192375302517}
# 21  Losses {'ner': 307.4629575553915}
# 22  Losses {'ner': 1627.3042210866274}
# 23  Losses {'ner': 371.37306874492845}
# 24  Losses {'ner': 98.09769787657342}
# 25  Losses {'ner': 1232.5004165957976}
# 26  Losses {'ner': 448.8010579964818}
# 27  Losses {'ner': 435.27722816887}
# 28  Losses {'ner': 309.71830181506357}
# 29  Losses {'ner': 172.69079841391044}
# 30  Losses {'ner': 203.0951562830324}
# 31  Losses {'ner': 255.96694138195636}
# 32  Losses {'ner': 429.44037164143225}
# 33  Losses {'ner': 860.1313432326731}
# 34  Losses {'ner': 420.0184952704502}
# 35  Losses {'ner': 377.74870702478836}
# 36  Losses {'ner': 240.6895278242003}
# 37  Losses {'ner': 153.07805014957825}
# 38  Losses {'ner': 121.7675480684366}
# 39  Losses {'ner': 1255.1433010996018}
# 40  Losses {'ner': 278.5731086430121}
# 41  Losses {'ner': 147.62820892840068}
# 42  Losses {'ner': 118.42722157019129}
# 43  Losses {'ner': 101.52387430587704}
# 44  Losses {'ner': 137.53877333388792}
# 45  Losses {'ner': 146.47791560012055}
# 46  Losses {'ner': 145.428250863087}
# 47  Losses {'ner': 113.8883037439632}
# 48  Losses {'ner': 155.69888180004034}
# 49  Losses {'ner': 121.66794904303721}
# 50  Losses {'ner': 155.83343359494734}
# 51  Losses {'ner': 289.14308979303865}
# 52  Losses {'ner': 81.9126598461656}
# 53  Losses {'ner': 213.1353239429937}
# 54  Losses {'ner': 173.54298112700667}
# 55  Losses {'ner': 150.18004810113015}
# 56  Losses {'ner': 284.2848353937582}
# 57  Losses {'ner': 228.63606202197286}
# 58  Losses {'ner': 77.18455747338093}
# 59  Losses {'ner': 399.1412931261503}
# 60  Losses {'ner': 240.35617501496932}
# 61  Losses {'ner': 228.14516782769596}
# 62  Losses {'ner': 113.32914935963282}
# 63  Losses {'ner': 381.85977299300407}
# 64  Losses {'ner': 74.66927817781249}
# 65  Losses {'ner': 50.64682497707135}
# 66  Losses {'ner': 98.52184642803232}
# 67  Losses {'ner': 183.295725576354}
# 68  Losses {'ner': 330.30201710773656}
# 69  Losses {'ner': 127.7646077320641}
# 70  Losses {'ner': 132.79055960785675}
# 71  Losses {'ner': 38.98286384932664}
# 72  Losses {'ner': 90.15325066476284}
# 73  Losses {'ner': 62.4797259088079}
# 74  Losses {'ner': 114.2214296125667}
# 75  Losses {'ner': 147.56942859280915}
# 76  Losses {'ner': 224.67461524460964}
# 77  Losses {'ner': 603.2492894493029}
# 78  Losses {'ner': 90.79776797236816}
# 79  Losses {'ner': 64.36595903567104}
# 80  Losses {'ner': 97.93515305543286}
# 81  Losses {'ner': 87.43274852644281}
# 82  Losses {'ner': 53.90954251106548}
# 83  Losses {'ner': 130.59975351863383}
# 84  Losses {'ner': 131.50456078391818}
# 85  Losses {'ner': 308.81426822789376}
# 86  Losses {'ner': 220.52224642398232}
# 87  Losses {'ner': 184.10211804136884}
# 88  Losses {'ner': 186.6053731180859}
# 89  Losses {'ner': 287.5432464440295}
# 90  Losses {'ner': 249.53626304640932}
# 91  Losses {'ner': 246.304289730826}
# 92  Losses {'ner': 181.33714254656547}
# 93  Losses {'ner': 207.50453789110614}
# 94  Losses {'ner': 183.38311756236502}
# 95  Losses {'ner': 171.20575836739056}
# 96  Losses {'ner': 209.41664332660892}
# 97  Losses {'ner': 133.47849858109805}
# 98  Losses {'ner': 149.0356006621191}
# 99  Losses {'ner': 166.60368747563138}
# 100  Losses {'ner': 148.44532715533086}

# %% [markdown]
# ## Teste

# %%
for each in base_treinamento[:10]:
    print(each)
# Out:
# ('av cel martiniano, 417 centro 59300-000 caico rn', {'entities': [(0, 21, 'LOGRA')]})
# ('r gal bocaiuva, 2 centro 23815-310 itaguai rj', {'entities': [(0, 16, 'LOGRA')]})
# ('av landulfo alves, 46 centro 48602-900 paulo afonso ba', {'entities': [(0, 20, 'LOGRA')]})
# ('av mario melo, 400-b centro 53610-605 igarassu pe', {'entities': [(0, 19, 'LOGRA')]})
# ('r pref jose vieira, 140 centro 36780-000 astolfo dutra mg', {'entities': [(0, 22, 'LOGRA')]})
# ('av tiradentes, 119 centro 57360-000 girau do ponciano al', {'entities': [(0, 17, 'LOGRA')]})
# ('r joao de paiva, s/n centro 59182-000 monte alegre rn', {'entities': [(0, 19, 'LOGRA')]})
# ('r mariz e barros, 13 loja a pca da bandeira 20270-005 rio de janeiro rj', {'entities': [(0, 19, 'LOGRA')]})
# ('av mal floriano peixoto, 1750 em frente a pca da matriz centro 68600-000 braganca pa', {'entities': [(0, 28, 'LOGRA')]})
# ('r pe feijo, 423 predio centro 95190-000 sao marcos rs', {'entities': [(0, 14, 'LOGRA')]})

# %%
# Com base de teste
for text, _ in base_teste:
    doc = nlp(text)
    
    print(text)
    print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
#     print('Tokens', [(t.text, t.ent_type_, t.ent_iob) for t in doc])
    print()
# Out:
# r quinze de novembro, 160 centro 99770-000 aratiba rs
# Entities [('r quinze de novembro, 160 centro 99770-000', 'LOGRA')]
#
# av carlos hugueney, 876 centro 78780-000 alto araguaia mt
# Entities [('av carlos hugueney, 876 centro', 'LOGRA')]
#
# avquinze de novembro, 116 centro 06850-100 itapecerica da serra sp
# Entities [('avquinze de novembro, 116 centro 06850-100', 'LOGRA')]
#
# av siqueira campos, 169 predio centro 55665-000 camocim de sao felix pe
# Entities [('av siqueira campos, 169 predio', 'LOGRA')]
#
# av rui barbosa, 75 qd 38, lote 5 centro 75940-000 edeia go
# Entities [('av rui barbosa, 75 qd 38', 'LOGRA')]
#
# r cel alexandrino, 860 centro 62800-000 aracati ce
# Entities [('r cel alexandrino, 860 centro', 'LOGRA')]
#
# r agripio teodorio soares, 157 centro 62260-000 reriutaba ce
# Entities [('r agripio teodorio soares, 157', 'LOGRA')]
#
# r dr orlando teixeira, 29 terreo centro 48410-000 cicero dantas ba
# Entities [('r dr orlando teixeira, 29 terreo', 'LOGRA')]
#
# r mal deodoro, 451 centro 95760-000 sao sebastiao do cai rs
# Entities [('r mal deodoro, 451 centro 95760-000', 'LOGRA')]
#
# r aurelio rosa, 137 centro 38550-000 coromandel mg
# Entities [('r aurelio rosa, 137 centro', 'LOGRA')]
#
# pca dr ozy teixeira, 46 centro 96610-000 encruzilhada do sul rs
# Entities [('pca dr ozy teixeira, 46 centro', 'LOGRA')]
#
# r da saudade, 2 centro 55340-000 aguas belas pe
# Entities [('r da saudade, 2 centro', 'LOGRA')]
#
# av brasil, 946 centro 98801-590 santo angelo rs
# Entities [('av brasil, 946 centro 98801-590', 'LOGRA')]
#
# av sete de setembro, 735 terreo e 1 a sobreloja d julho 40060-000 salvador ba
# Entities [('av sete de setembro, 735 terreo', 'LOGRA')]
#
# av central, 625/635 nuc bandeirante 71710-520 brasilia (nucleo bandeirante) df
# Entities [('av central, 625/635 nuc', 'LOGRA')]
#
# r carlos dietzsch, 137 via rapida centro-bairro portao 80330-000 curitiba pr
# Entities [('r carlos dietzsch, 137 via rapida centro-bairro portao', 'LOGRA')]
#
# r quinze de novembro, 793 terreo centro 97400-000 sao pedro do sul rs
# Entities [('r quinze de novembro, 793 terreo', 'LOGRA')]
#
# rua quatro, 600 centro 76590-000 sao miguel do araguaia go
# Entities [('rua quatro, 600 centro', 'LOGRA')]
#
# av nilopecanha, 108 centro 27600-000 valenca rj
# Entities [('av nilopecanha, 108 centro 27600-000', 'LOGRA')]
#
# r benjamin constant, 258 zona urbana centro 59330-000 jucurutu rn
# Entities [('r benjamin constant, 258 zona urbana', 'LOGRA')]
#
# tv da mangueira, 40 centro 58297-000 rio tinto pb
# Entities [('tv da mangueira, 40 centro', 'LOGRA')]
#
# r dr cunha lima, 237 centro 58397-000 areia pb
# Entities [('r dr cunha lima, 237 centro', 'LOGRA')]
#
# av sao sebastiao, 117 centro 55840-000 lagoa do itaenga pe
# Entities [('av sao sebastiao, 117 centro', 'LOGRA')]
#
# pca dom jose de hass, 158 centro 39820-000 novo cruzeiro mg
# Entities [('pca dom jose de hass, 158 centro 39820-000', 'LOGRA')]
#
# pca n sra do rosario, 578 centro 54110-130 jaboatao dos guararapes pe
# Entities [('pca n sra do rosario, 578 centro 54110-130', 'LOGRA')]
#
# r demerval amaral, 35 terreo centro 29560-000 guacui es
# Entities [('r demerval amaral, 35 terreo', 'LOGRA')]
#
# pca barao do rio branco, 39 centro 48903-901 juazeiro ba
# Entities [('pca barao do rio branco, 39 centro', 'LOGRA')]
#
# r prof salatiel almeida, 18 centro 37890-000 muzambinho mg
# Entities [('r prof salatiel almeida, 18 centro', 'LOGRA')]
#
# r manoel cavalcante, 45 em frente a pca de alimentacao centro 58770-000 coremas pb
# Entities [('r manoel cavalcante, 45 em', 'LOGRA')]
#
# r juscelino kubitschek, 1119 centro 65707-000 pio xii ma
# Entities [('r juscelino kubitschek, 1119 centro', 'LOGRA')]
#
# av porto alegre, 980 centro 99965-000 agua santa rs
# Entities [('av porto alegre, 980 centro 99965-000', 'LOGRA')]
#
# r barao do rio branco, 1175 centro 89136-000 rodeio sc
# Entities [('r barao do rio branco, 1175 centro', 'LOGRA')]
#
# pca jose de resende paiva, 18 centro 37002-030 varginha mg
# Entities [('pca jose de resende paiva, 18 centro', 'LOGRA')]
#
# r pe joao maria, s/n centro 59550-000 joao camara rn
# Entities [('r pe joao maria, s/', 'LOGRA')]
#
# av brasil, 1716 centro 85892-000 santa helena pr
# Entities [('av brasil, 1716 centro', 'LOGRA')]
#
# pca gov valadares, 171 centro 38170-000 perdizes mg
# Entities [('pca gov valadares, 171', 'LOGRA')]
#
# av farmaceutico joviano, 394 centro 39830-000 itambacuri mg
# Entities [('av farmaceutico joviano, 394 centro', 'LOGRA')]
#
# pca antonio amado, 78 centro 28390-000 porciuncula rj
# Entities [('pca antonio amado, 78 centro', 'LOGRA')]
#
# r felisberto fonseca, 200 centro 38750-000 presidente olegario mg
# Entities [('r felisberto fonseca, 200 centro 38750-000', 'LOGRA')]
#
# av gov osman loureiro, 49 terreo mangabeiras 57037-630 maceio al
# Entities [('av gov osman loureiro, 49 terreo', 'LOGRA')]
#
# av jose bonifacio, 14 centro 96360-000 pedro osorio rs
# Entities [('av jose bonifacio, 14 centro', 'LOGRA')]
#
# av gov portela, 1274 centro 26221-030 nova iguacu rj
# Entities [('av gov portela, 1274 centro', 'LOGRA')]
#
# r dr luis bastos do prado, 1317 centro 94010-020 gravatai rs
# Entities [('r dr luis bastos do prado, 1317 centro', 'LOGRA')]
#
# av jose mol, 216 terreo centro 35290-000 mantena mg
# Entities [('av jose mol, 216 terreo centro', 'LOGRA')]
#
# pca sete de setembro, 112 terreo centro 44190-000 santo estevao ba
# Entities [('pca sete de setembro, 112 terreo', 'LOGRA')]
#
# r d abadia, 229 centro 75660-000 buriti alegre go
# Entities [('r d abadia, 229 centro 75660-000', 'LOGRA')]
#
# pca delmiro gouveia, 59 centro 57480-000 delmiro gouveia al
# Entities [('pca delmiro gouveia, 59 centro', 'LOGRA')]
#
# av cel lindolfo alves dias, 723 centro 75850-000 caiaponia go
# Entities [('av cel lindolfo alves dias, 723 centro 75850-000', 'LOGRA')]
#
# r vinte e um de abril, 140 centro 16400-030 lins sp
# Entities [('r vinte e um de abril, 140 centro 16400-030', 'LOGRA')]
#
# r mal deodoro, 259 centro 13720-000 sao jose do rio pardo sp
# Entities [('r mal deodoro, 259 centro 13720-000', 'LOGRA')]
#
# av augusto mendes dos santos, 963 centro 87340-000 mambore pr
# Entities [('av augusto mendes dos santos, 963 centro 87340-000', 'LOGRA')]
#
# av nestor frederico henn, 1791 centro 96880-000 vera cruz rs
# Entities [('av nestor frederico henn, 1791 centro', 'LOGRA')]
#
# av dr joao pessoa, 41 predio comercial centro 45360-000 maracas ba
# Entities [('av dr joao pessoa, 41 predio', 'LOGRA')]
#
# pca silvio garcez, 165 centro 49120-000 itaporanga d'ajuda se
# Entities [('pca silvio garcez, 165 centro 49120-000', 'LOGRA')]
#
# av joao antonio, 537 terreo centro 96900-000 sobradinho rs
# Entities [('av joao antonio, 537 terreo centro', 'LOGRA')]
#
# av irmaos piccoli, 130 terreo centro 89642-000 tangara sc
# Entities [('av irmaos piccoli, 130 terreo centro', 'LOGRA')]
#
# r paulo mendonca, 284 centro 78280-000 mirassol d'oeste mt
# Entities [('r paulo mendonca, 284 centro', 'LOGRA')]
#
# r paulino vieira, 155 terreo, 1 e 2 andares centro 45600-912 itabuna ba
# Entities [('r paulino vieira, 155 terreo,', 'LOGRA')]
#
# avenida stelio machado loureiro, 1 130 centro 17860-000 pacaembu sp
# Entities [('avenida stelio machado loureiro, 1 130', 'LOGRA')]
#
# av brig luiz antonio, 557 prox ao teatro abril bela vista 01317-000 sao paulo sp
# Entities [('av brig luiz antonio, 557 prox a', 'LOGRA')]
#
# av doca paraiba, 100 centro 62670-000 sao goncalo do amarante ce
# Entities [('av doca paraiba, 100 centro 62670-000', 'LOGRA')]
#
# r candido de souza, 289 centro 13760-000 tapiratiba sp
# Entities [('r candido de souza, 289 centro 13760-000', 'LOGRA')]
#
# av gov valadares, 194 centro 35588-000 arcos mg
# Entities [('av gov valadares, 194 centro', 'LOGRA')]
#
# av manoel borba, 53 terreo centro 56460-000 petrolandia pe
# Entities [('av manoel borba, 53 terreo', 'LOGRA')]
#
# pca ver mario rocha, 73 centro 35010-390 governador valadares mg
# Entities [('pca ver mario rocha, 73 centro', 'LOGRA')]
#
# av duque de caxias, 492 v militar deodoro 21615-220 rio de janeiro rj
# Entities [('av duque de caxias, 492 v militar', 'LOGRA')]
#
# r mal deodoro, 557 centro 86960-000 barbosa ferraz pr
# Entities [('r mal deodoro, 557 centro 86960-000', 'LOGRA')]
#
# pca pedro caldeira, 7 centro 39390-000 bocaiuva mg
# Entities [('pca pedro caldeira, 7 centro', 'LOGRA')]
#
# r barao do rio branco, 173 centro 79480-000 rio verde de mato grosso ms
# Entities [('r barao do rio branco, 173 centro 79480-000', 'LOGRA')]
#
# pca gago coutinho, s/n aerop luis e magalhaes, lj 46, ter  sao cristovao 41510-045 salvador ba
# Entities [('pca gago coutinho, s/', 'LOGRA')]
#
# av assis brasil, 2487 passo da areia 91010-006 porto alegre rs
# Entities [('av assis brasil, 2487 passo', 'LOGRA')]
#
# av jabaquara, 424 mirandopolis 04046-000 sao paulo sp
# Entities [('av jabaquara, 424 mirandopolis 04046-000', 'LOGRA')]
#
# rua presidente vargas, 537 centro 17690-000 bastos sp
# Entities [('rua presidente vargas, 537 centro 17690-000', 'LOGRA')]
#
# r vigario antunes, 201 predio centro 35550-000 itapecerica mg
# Entities [('r vigario antunes, 201 predio', 'LOGRA')]
#
# av braulio cavalcante, 607 centro 57400-000 pao de acucar al
# Entities [('av braulio cavalcante, 607 centro', 'LOGRA')]
#
# pca da matriz, 47 centro 64235-000 cocal pi
# Entities [('pca da matriz, 47 centro', 'LOGRA')]
#
# av jose vicente m vasconcelos, 401 terreo centro 55720-000 joao alfredo pe
# Entities [('av jose vicente m vasconcelos, 401 terreo', 'LOGRA')]
#
# r mal castelo branco, 373 centro 96950-000 arroio do tigre rs
# Entities [('r mal castelo branco, 373 centro', 'LOGRA')]
#
# r cel pedro bogea, 210 centro 65715-000 lago da pedra ma
# Entities [('r cel pedro bogea, 210 centro 65715-000', 'LOGRA')]
#
# pca sao benedito, 1451 dist de posto da mata centro 45928-000 nova vicosa ba
# Entities [('pca sao benedito, 1451 dist', 'LOGRA')]
#
# av leopoldino de oliveira, 3635 centro 38010-000 uberaba mg
# Entities [('av leopoldino de oliveira, 3635 centro', 'LOGRA')]
#
# av francisco sa, 955 gutierrez 30441-021 belo horizonte mg
# Entities [('av francisco sa, 955 gutierrez 30441-021', 'LOGRA')]
#
# av antonio carlos magalhaes, s/n predio centro 48700-000 serrinha ba
# Entities [('av antonio carlos magalhaes, s/', 'LOGRA')]
#
# r costa barros, 895 v alpina 03210-000 sao paulo sp
# Entities [('r costa barros, 895 v', 'LOGRA')]
#
# pca dr paterson, 11/12 lgo da graca graca 40150-066 salvador ba
# Entities [('pca dr paterson, 11/12 lgo', 'LOGRA')]
#
# av amazonas, 81 centro 87390-000 boa esperanca pr
# Entities [('av amazonas, 81 centro', 'LOGRA')]
#
# pca nove de julho, 122 centro 14870-325 jaboticabal sp
# Entities [('pca nove de julho, 122 centro', 'LOGRA')]
#
# av rui barbosa, 566 centro 14740-000 viradouro sp
# Entities [('av rui barbosa, 566 centro 14740-000', 'LOGRA')]
#
# r fanoel do ouro, 560 centro 79790-000 deodapolis ms
# Entities [('r fanoel do ouro, 560 centro 79790-000', 'LOGRA')]
#
# av frei orestes girardi, 837 v abernessia 12460-000 campos do jordao sp
# Entities [('av frei orestes girardi, 837 v', 'LOGRA')]
#
# av duque de caxias, 20 ribeira 59012-200 natal rn
# Entities [('av duque de caxias, 20 ribeira', 'LOGRA')]
#
# pca da matriz, 1 centro 63300-000 lavras da mangabeira ce
# Entities [('pca da matriz, 1 centro', 'LOGRA')]
#
# pca vinte e oito de setembro, 113 centro 36520-000 visconde do rio branco mg
# Entities [('pca vinte e oito de setembro, 113 centro', 'LOGRA')]
#
# av bias fortes, 81 centro 39880-000 aguas formosas mg
# Entities [('av bias fortes, 81 centro', 'LOGRA')]
#
# av francisca das chagas, s/n casa centro 65840-000 sao raimundo das mangabeiras ma
# Entities [('av francisca das chagas, s/', 'LOGRA')]
# av juscelino kubitschek, 3543 v portes 85865-000 foz do iguacu pr
# Entities [('av juscelino kubitschek, 3543 v', 'LOGRA')]
#
# pca euvaldo lodi, 35 barra da tijuca 22640-010 rio de janeiro rj
# Entities [('pca euvaldo lodi, 35 barra', 'LOGRA')]
#
# av goncalves dias, 1052 centro 65110-000 sao jose de ribamar ma
# Entities [('av goncalves dias, 1052 centro', 'LOGRA')]
#
# av mal candido rondon, 97 centro 85840-000 ceu azul pr
# Entities [('av mal candido rondon, 97 centro', 'LOGRA')]
#
# r jeronimo vervloet, 178 centro 29650-000 santa teresa es
# Entities [('r jeronimo vervloet, 178 centro', 'LOGRA')]
#
# r dez, 150 ed do forum setor oeste 74120-020 goiania go
# Entities [('r dez, 150 ed do forum', 'LOGRA')]
#
# r cel vidal ramos, 349 centro 89520-000 curitibanos sc
# Entities [('r cel vidal ramos, 349 centro', 'LOGRA')]
#
# pca mario dourado sobrinho, 100 centro 44900-000 irece ba
# Entities [('pca mario dourado sobrinho, 100 centro', 'LOGRA')]
#
# av rodolfo guimaraes, 673 centro 17380-000 brotas sp
# Entities [('av rodolfo guimaraes, 673 centro 17380-000', 'LOGRA')]
#
# av rio branco, 1002 esquina centro 96450-000 dom pedrito rs
# Entities [('av rio branco, 1002 esquina', 'LOGRA')]
#
# r des souto maior, 162 centro 58013-190 joao pessoa pb
# Entities [('r des souto maior, 162 centro 58013-190', 'LOGRA')]
#
# av dos imigrantes, 630 ao lado do lojao das fabricas centro 68145-000 medicilandia pa
# Entities [('av dos imigrantes, 630 a', 'LOGRA')]
#
# pca odilon resende andrade, 76 centro 37410-000 tres coracoes mg
# Entities [('pca odilon resende andrade, 76 centro', 'LOGRA')]
#
# av parana, 78 esq c/r rio grande do sul centro 78640-000 canarana mt
# Entities [('av parana, 78 esq c', 'LOGRA')]
#
# av estados unidos, 258 ed cidade de aracaju comercio 40010-902 salvador ba
# Entities [('av estados unidos, 258 ed cidade', 'LOGRA')]
#
# r pe raposo, 29 mooca 03118-000 sao paulo sp
# Entities [('r pe raposo, 29 mooca', 'LOGRA')]
#
# r jose piovezana, 267 das gracas 35370-000 rio casca mg
# Entities [('r jose piovezana, 267 das gracas 35370-000', 'LOGRA')]
#
# r barao do paraim, 10 esq c/av curimata centro 64960-000 curimata pi
# Entities [('r barao do paraim, 10 esq c', 'LOGRA')]
#
# av antonio j de moura andrade, 1400 esq c/r prof joao de lima paes centro 79750-000 nova andradina ms
# Entities [('av antonio j de moura andrade, 1400 esq c', 'LOGRA')]
#
# av arapongas, 68 centro 86701-000 arapongas pr
# Entities [('av arapongas, 68 centro', 'LOGRA')]
#
# pca bias fortes, 119 centro 36190-970 merces mg
# Entities [('pca bias fortes, 119 centro', 'LOGRA')]
#
# pca evangelino meireles, 208 centro 72800-680 luziania go
# Entities [('pca evangelino meireles, 208 centro 72800-680', 'LOGRA')]
#
# avenida adelino americo azevedo, 160 centro 76550-000 porangatu go
# Entities [('avenida adelino americo azevedo, 160 centro 76550-000', 'LOGRA')]
#
# r jose de alencar, 54 centro 62400-000 camocim ce
# Entities [('r jose de alencar, 54 centro', 'LOGRA')]
#
# r do comercio, 81 predio centro 57250-000 campo alegre al
# Entities [('r do comercio, 81 predio', 'LOGRA')]
#
# r barao do rio branco, 1060 centro 96470-000 pinheiro machado rs
# Entities [('r barao do rio branco, 1060 centro', 'LOGRA')]
#
# av carlos chagas filho, 373 predio ccs, bloco l ilha do fundao 21941-902 rio de janeiro rj
# Entities [('av carlos chagas filho, 373 predio', 'LOGRA')]
#
# av joao pinheiro, 2982 sto antonio 34800-000 caete mg
# Entities [('av joao pinheiro, 2982 sto', 'LOGRA')]
#
# av sao carlos, 1040 centro 13560-010 sao carlos sp
# Entities [('av sao carlos, 1040 centro', 'LOGRA')]
#
# rua quarenta e cinco, 809 centro 76680-000 itapuranga go
# Entities [('rua quarenta e cinco, 809 centro', 'LOGRA')]
#
# av pres vargas, 1590 v tonani i 79825-090 dourados ms
# Entities [('av pres vargas, 1590 v', 'LOGRA')]
#
# avenida tocantins centro 76400-000 uruacu go
# Entities [('avenida tocantins centro 76400-000', 'LOGRA')]
#
# av jeronimo monteiro, 640 centro 29100-401 vila velha es
# Entities [('av jeronimo monteiro, 640 centro 29100-401', 'LOGRA')]
#
# praca beraldo arruda, 82 centro 16500-000 cafelandia sp
# Entities [('praca beraldo arruda, 82 centro', 'LOGRA')]
#
# av rio branco, 502 centro 65725-000 pedreiras ma
# Entities [('av rio branco, 502 centro 65725-000', 'LOGRA')]
#
# av oscar ornelas, 350 centro 37880-000 cabo verde mg
# Entities [('av oscar ornelas, 350 centro', 'LOGRA')]
#
# av antonio ferreira sobrinho, 1025 centro 78820-000 jaciara mt
# Entities [('av antonio ferreira sobrinho, 1025 centro', 'LOGRA')]
#
# pca sao sebastiao, 60 centro 46390-000 ibiassuce ba
# Entities [('pca sao sebastiao, 60 centro', 'LOGRA')]
#
# r emilia marengo, 260 tatuape 03336-000 sao paulo sp
# Entities [('r emilia marengo, 260 tatuape', 'LOGRA')]
#
# av fernandes da cunha, 58 mares 40445-201 salvador ba
# Entities [('av fernandes da cunha, 58 mares', 'LOGRA')]
#
# al mamore, 989 terreo, ed crystal tower alphaville 06454-040 barueri sp
# Entities [('al mamore, 989 terreo, ed crystal', 'LOGRA')]
#
# r sao paulo, 1015 centro 87300-390 campo mourao pr
# Entities [('r sao paulo, 1015 centro', 'LOGRA')]
#
# r dezessete de dezembro, 90 centro 35547-000 carmo da mata mg
# Entities [('r dezessete de dezembro, 90 centro', 'LOGRA')]
#
# r dep raimundo chaves, 215 obidos centro 68250-000 obidos pa
# Entities [('r dep raimundo chaves, 215 obidos centro', 'LOGRA')]
#
# av dionisio bentes, 151 prox correio quatro bocas 68682-000 tome-acu pa
# Entities [('av dionisio bentes, 151 prox correio', 'LOGRA')]
#
# pca cel amantino, 3 centro 36480-000 piranga mg
# Entities [('pca cel amantino, 3 centro', 'LOGRA')]
#
# av trifon hanysz, 189 centro 85170-000 pinhao pr
# Entities [('av trifon hanysz, 189 centro 85170-000', 'LOGRA')]
#
# r da liberdade, 239 predio centro 65665-000 sao joao dos patos ma
# Entities [('r da liberdade, 239 predio centro', 'LOGRA')]
#
# r adelina de sa, s/n centro 42800-060 camacari ba
# Entities [('r adelina de sa, s/', 'LOGRA')]
#
# r isaias correa, 52 centro 35774-000 paraopeba mg
# Entities [('r isaias correa, 52 centro', 'LOGRA')]
#
# av glaycon de paiva, 74 terreo centro 69301-250 boa vista rr
# Entities [('av glaycon de paiva, 74 terreo', 'LOGRA')]
#
# r cel guilherme, 7 centro 35330-000 inhapim mg
# Entities [('r cel guilherme, 7 centro', 'LOGRA')]
#
# r joao dos anjos reis, 19 esq c/tv joao cancio centro 68655-000 irituia pa
# Entities [('r joao dos anjos reis, 19 esq c', 'LOGRA')]
#
# rua conego peregrino, 1625 centro 14415-000 patrocinio paulista sp
# Entities [('rua conego peregrino, 1625 centro', 'LOGRA')]
#
# av epitacio pessoa, 76 terreo centro 58700-020 patos pb
# Entities [('av epitacio pessoa, 76 terreo', 'LOGRA')]
#
# pca sta luzia, 1 centro 62760-000 baturite ce
# Entities [('pca sta luzia, 1 centro', 'LOGRA')]
#
# avenida getlio vargas, 6 centro 76420-000 niquelandia go
# Entities [('avenida getlio vargas, 6 centro', 'LOGRA')]
#
# r dom jackson berenguer prado, 519 terreo centro 48500-000 euclides da cunha ba
# Entities [('r dom jackson berenguer prado, 519 terreo', 'LOGRA')]
#
# av tucuruvi, 469 tucuruvi 02305-001 sao paulo sp
# Entities [('av tucuruvi, 469 tucuruvi', 'LOGRA')]
#
# r bento goncalves, 516 4 e 5 andares centro 99010-010 passo fundo rs
# Entities [('r bento goncalves, 516 4 e', 'LOGRA')]
#
# pca sete de setembro, 196 centro 64900-000 bom jesus pi
# Entities [('pca sete de setembro, 196 centro', 'LOGRA')]
#
# av aristando ferreira lima, s/n bomba centro 56163-000 parnamirim pe
# Entities [('av aristando ferreira lima, s/', 'LOGRA')]
#
# r jorge lacerda, 1168 centro 89930-000 sao jose do cedro sc
# Entities [('r jorge lacerda, 1168 centro', 'LOGRA')]
#
# pca conego siqueira, 37 centro 12530-000 cunha sp
# Entities [('pca conego siqueira, 37 centro', 'LOGRA')]
#
# r lobo da costa, 1315 3, 4 e 5 andar centro 96010-150 pelotas rs
# Entities [('r lobo da costa, 1315 3, 4 e', 'LOGRA')]
#
# pca eduardo ribeiro, 331 esq c/jonathas pedrosa centro 69151-030 parintins am
# Entities [('pca eduardo ribeiro, 331 esq c', 'LOGRA')]
#
# pca getulio vargas, 41 centro 39935-000 santo antonio do jacinto mg
# Entities [('pca getulio vargas, 41 centro', 'LOGRA')]
#
# pca dr gouveia, 98 centro 37757-000 poco fundo mg
# Entities [('pca dr gouveia, 98 centro', 'LOGRA')]
#
# r getulio vargas, 85 centro 88340-347 camboriu sc
# Entities [('r getulio vargas, 85 centro', 'LOGRA')]
#
# sepn, qd 504, bloco b ed virgo, terreo asa norte 70730-522 brasilia df
# Entities [('sepn, qd 504, bloco b', 'LOGRA')]
#
# r joao ferreira dos santos, s/n centro 63595-000 catarina ce
# Entities [('r joao ferreira dos santos, s/', 'LOGRA')]
#
# r pe freire de menezes, 10 centro 49520-000 campo do brito se
# Entities [('r pe freire de menezes, 10 centro', 'LOGRA')]
#
# av dom pedro segundo, 410 centro 68440-000 abaetetuba pa
# Entities [('av dom pedro segundo, 410', 'LOGRA')]
#
# av carlos fernandes, 736 centro 14610-000 ipua sp
# Entities [('av carlos fernandes, 736 centro', 'LOGRA')]
#
# r guanabara, 65 predio da pref municipal centro 39625-000 itaobim mg
# Entities [('r guanabara, 65 predio', 'LOGRA')]
#
# av brasil, 1490 centro 87800-000 rondon pr
# Entities [('av brasil, 1490 centro', 'LOGRA')]
#
# av londrina, 638 centro 87970-000 nova londrina pr
# Entities [('av londrina, 638 centro 87970-000', 'LOGRA')]
#
# rua tomaz de campos, 1 centro 76510-000 crixas go
# Entities [('rua tomaz de campos, 1 centro', 'LOGRA')]
#
# r coronel teixeira oliveira, 28 esq c/av getulio vargas centro 88160-130 biguacu sc
# Entities [('r coronel teixeira oliveira, 28 esq c', 'LOGRA')]
#
# av dr francisco correia, 329 centro 54735-903 sao lourenco da mata pe
# Entities [('av dr francisco correia, 329 centro', 'LOGRA')]
#
# r princesa isabel, 563 centro 17930-000 tupi paulista sp
# Entities [('r princesa isabel, 563 centro 17930-000', 'LOGRA')]
#
# av parana, 330 centro 85470-000 catanduvas pr
# Entities [('av parana, 330 centro', 'LOGRA')]
#
# av getulio vargas, 798 centro 89835-000 sao domingos sc
# Entities [('av getulio vargas, 798 centro 89835-000', 'LOGRA')]
#
# av pres vargas, 8/11 centro 19470-000 presidente epitacio sp
# Entities [('av pres vargas, 8/11 centro', 'LOGRA')]
#
# av brasil, 5746 centro 85812-001 cascavel pr
# Entities [('av brasil, 5746 centro', 'LOGRA')]
#
# pca dr alcides marques, 5 centro 96300-000 jaguarao rs
# Entities [('pca dr alcides marques, 5 centro', 'LOGRA')]
#
# r cel alcantara, 276 centro 86400-000 jacarezinho pr
# Entities [('r cel alcantara, 276 centro', 'LOGRA')]
#
# r mirador, 87 centro 89150-000 presidente getulio sc
# Entities [('r mirador, 87 centro', 'LOGRA')]
#
# r comend parada, 29 centro 18170-000 piedade sp
# Entities [('r comend parada, 29 centro', 'LOGRA')]
#
# av getulio vargas, 396 centro 89120-000 timbo sc
# Entities [('av getulio vargas, 396 centro', 'LOGRA')]
#
# r oito, 405 pca da cultura centro 78635-000 agua boa mt
# Entities [('r oito, 405 pca da cultura', 'LOGRA')]
#
# av rio branco, 117 centro 95720-000 garibaldi rs
# Entities [('av rio branco, 117 centro', 'LOGRA')]
#
# pca da basilica, 105 terreo centro 62700-000 caninde ce
# Entities [('pca da basilica, 105 terreo', 'LOGRA')]
#
# av sete de setembro, 273 centro 88710-000 treze de maio sc
# Entities [('av sete de setembro, 273 centro 88710-000', 'LOGRA')]
#
# av municipal, 1174 em frente a pca central centro 78250-000 pontes e lacerda mt
# Entities [('av municipal, 1174 em', 'LOGRA')]
#
# pca graciliano de freitas, 22 centro 48010-110 alagoinhas ba
# Entities [('pca graciliano de freitas, 22 centro', 'LOGRA')]
#
# praca gerson veronesi ferracini, 30 centro 17830-000 florida paulista sp
# Entities [('praca gerson veronesi ferracini, 30 centro', 'LOGRA')]
#
# r joaquim benedito da silva, 948 centro 65600-050 caxias ma
# Entities [('r joaquim benedito da silva, 948 centro 65600-050', 'LOGRA')]
#
# r felicio marcondes, 391 centro 07010-030 guarulhos sp
# Entities [('r felicio marcondes, 391 centro', 'LOGRA')]
#
# av antonio afonso de lima, 475 terreo centro 07400-000 aruja sp
# Entities [('av antonio afonso de lima, 475 terreo centro', 'LOGRA')]
#
# pca da matriz, 75 centro 38200-000 frutal mg
# Entities [('pca da matriz, 75 centro', 'LOGRA')]
#
# av mato grosso, 950 esq c/av sergipe centro 78285-000 sao jose dos quatro marcos mt
# Entities [('av mato grosso, 950 esq c', 'LOGRA')]
# r cel jose dulce, 234 centro 78200-000 caceres mt
# Entities [('r cel jose dulce, 234 centro', 'LOGRA')]
#
# r pres vargas, 29 terreo centro 29400-000 mimoso do sul es
# Entities [('r pres vargas, 29 terreo', 'LOGRA')]
#
# r assis brasil, 67 centro 95185-000 carlos barbosa rs
# Entities [('r assis brasil, 67 centro', 'LOGRA')]

# %%
# Função para tratamento de texto de entrada

def regex(str_):
    ph_tratada = str_.replace("\"", "")
    ph_tratada = ph_tratada.replace("-", " ")
    ph_tratada = ph_tratada.replace("|", "")
    ph_tratada = ph_tratada.replace(",", "")
    ph_tratada = ph_tratada.replace(":", "")
    ph_tratada = ph_tratada.replace(".", "")
    ph_tratada = ph_tratada.replace("  ", "")
    ph_tratada = ph_tratada.lower()
    ph_tratada = re.sub(r'[\n]+', " ", ph_tratada)
    ph_tratada = re.sub(r'^[ ]+', "", ph_tratada)

    ph_tratada = strip_accents(ph_tratada
                              )    
    return ph_tratada

# %%
# Com texto IPTU

ph ="""
        "PREFEITURA DE Certidão de Dados Cadastrais do Imóvel - IPTU 2017\n\nSÃO PAULO\n\nFAZENDA",
        "Cadastro do Imóvel: 067.061.0048-1",
        "| Local do Imóvel:",
        "| AVJACANA, 764- AP 104 E VG",
        "BLOCO 1 UP LIFE SAO PAULO CEP 02273-001\nImóvel localizado na 22 Subdivisão da Zona Urbana",
        "| Endereço para entrega da notificação:",
        "| AVJACANA, 764- AP 104 E VG",
        "| BLOCO1 UPLIFE SAO PAULO CEP 02273-001",
        "| Contribuinte(s):",
        "| AGUA DAS FLORES EMPREENDIMENTOS IMOB LTDA",
        "| Dados cadastrais do terreno:",
        "| Área incorporada (m?): 1.669 Testada (m): 0,00",
        "| Área não incorporada (m?): 0 Fração ideal: 0,0024",
        "| Área total (m?): 7.669",
        "| Dados cadastrais da construção:",
        "| Área construída (m?):\n\n88\n\nPadrão da construção:\n\n2-C",
        "Área ocupada pela construção (m?): 5.134 Uso: residência",
        "| Ano da construção corrigido: 2016",
        "| Valores de m? (R$):",
        "| - de terreno: 700,00",
        "| - da construção: 1.508,00",
        "| Valores para fins de cálculo do IPTU (R$):",
        "| - da área incorporada: 23.675,00",
        "- da área não incorporada: 0,00",
        "| - da construção: 131.377,00",
        "|| Base de cálculo do IPTU: 155.052,00",
        "Ressalvado o direito da Fazenda Pública do Município de São Paulo atualizar os dados constantes do Cadastro\nImobiliário Fiscal, apurados ou verificados a qualquer tempo, inclusive em relação ao exercício abrangido por\nesta certidão, a Secretaria Municipal da Fazenda CERTIFICA que os dados cadastrais acima foram utilizados no\nlançamento do Imposto Predial e Territorial Urbano do imóvel do exercício de 2017.",
        "Certidão expedida via Internet - Portaria SF nº 008/2004, de 28/01/2004.",
        "A autenticidade desta certidão poderá ser confirmada, até o dia 05/02/2018, em",
        "http://www .prefeitura.sp.gov.br/cidade/secretarias/financas/servicos/certidoes/",
        "| Data de Emissão: 07/11/2017",
        "| Número do Documento: 2.2017.001599486-1",
        "|| Solicitante: PAULO AFONSO DECICINO (CPF 892.407.408-30)"
    """

# %%
ph_tratada = regex(ph)
print(ph_tratada)

# %%
doc_ph = nlp(ph_tratada)
print('Entities', [(ent.text, ent.label_) for ent in doc_ph.ents])

# %%
# Com texto qualquer

phrase = regex("QNE 20, 12 leonardo a a ")

doc = nlp(phrase)
print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
print('Tokens', [(t.text, t.ent_type_, t.ent_iob) for t in doc])
# Out:
# Entities [('qne 20 12 leonardo', 'LOGRA')]
# Tokens [('qne', 'LOGRA', 3), ('20', 'LOGRA', 1), ('12', 'LOGRA', 1), ('leonardo', 'LOGRA', 1), ('a', '', 2), ('a', '', 2)]
