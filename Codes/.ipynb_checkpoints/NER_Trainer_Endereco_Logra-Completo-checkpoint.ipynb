# %%
# Load Packages
from __future__ import unicode_literals, print_function

import plac #  wrapper over argparse
import random
from pathlib import Path
import spacy
from tqdm import tqdm, tqdm_notebook # loading bar 
import pandas as pd
import re
from pprint import pprint
from nltk.tokenize import sent_tokenize
import numpy as np
import unicodedata
from spacy.util import minibatch, compounding
import ast as ast
import pickle

# %%
# Função para substituir acentos

def strip_accents(text):
    try:
        text = unicode(text, 'utf-8')
    except (TypeError, NameError): # unicode is a default on python 3 
        pass
    text = unicodedata.normalize('NFD', text)
    text = text.encode('ascii', 'ignore')
    text = text.decode("utf-8")
    
    return str(text)

# %% [markdown]
# # Abrindo e gerando Datasets

# %% [markdown]
# ### Entidade logradouro

# %%
with open ('../Datasets/Dataset_V2.0.txt', 'rb') as fp:
    dataset = pickle.load(fp)

print(len(dataset))
# Out:
# 128016

# %%
dataset[0]
# Out:
# ('R.GUILHERME MOREIRA,315 SUBLOJA,LOJA E 2.ANDAR 69005-300 MANAUS CENTRO AM',
#  {'entities': [(0, 23, 'END_LOG')]})

# %%
end_lista = []

for i in range(len(dataset)):
    str_tratada = dataset[i][0]
    str_tratada = str_tratada.lower() # Tudo em minúsculo
    str_tratada = strip_accents(str_tratada) # Substituição de acentos e caracteres diferentes
    
    end_lista.append(str_tratada)

# %%
end_lista[:3]
# Out:
# ['r.guilherme moreira,315 subloja,loja e 2.andar 69005-300 manaus centro am',
#  '69005-300 manaus am r.guilherme moreira,315 centro subloja,loja e 2.andar',
#  'r.guilherme moreira,315 centro 69005-300 subloja,loja e 2.andar manaus am']

# %%
iob = []

for i in range(len(dataset)):
    tupla = (end_lista[i], dataset[i][1])
    
    iob.append(tupla)
    
FULL_DATA = iob

# %%
print(FULL_DATA[0])
print(FULL_DATA[1])
print(FULL_DATA[2])
# Out:
# ('r.guilherme moreira,315 subloja,loja e 2.andar 69005-300 manaus centro am', {'entities': [(0, 23, 'END_LOG')]})
# ('69005-300 manaus am r.guilherme moreira,315 centro subloja,loja e 2.andar', {'entities': [(20, 43, 'END_LOG')]})
# ('r.guilherme moreira,315 centro 69005-300 subloja,loja e 2.andar manaus am', {'entities': [(0, 23, 'END_LOG')]})

# %%
# Criação da base de teste e treinamento

n_test= 0.1 # Porcentagem para base de teste
test_n = round(len(FULL_DATA) * n_test)

# Divisao em Train Test Val

def gerador_bases(dataset, n):
    indices_random = random.sample(range(0,len(dataset)-1), n)
    base_teste_n = []
    base_treinamento_n = []
    
    for i in range(n):
        base_teste_n.append(dataset[indices_random[i]])

    for j in range(len(dataset)):
        if(j not in indices_random):
            base_treinamento_n.append(dataset[j])
            
    return base_teste_n, base_treinamento_n


base_teste, base_treinamento = gerador_bases(FULL_DATA, test_n)

random.shuffle(base_treinamento)
random.shuffle(base_teste)

print("Treinamento: " + str(len(base_treinamento)), "\nTeste: " + str(len(base_teste)), "\nTotal: " + str(len(FULL_DATA)))
# Out:
# Treinamento: 115214
# Teste: 12802
# Total: 128016

# %%
for i in range(5):
    print(base_treinamento[i])
# Out:
# ('av. guajajaras, 200 tirirical ma 65055-285 quadra 220 - lojas 01 e 02 sao luis', {'entities': [(0, 19, 'END_LOG')]})
# ('cambe centro avenida inglaterra  86181-000 pr', {'entities': [(13, 31, 'END_LOG')]})
# ('centro sp mogi das cruzes 08710-500 av.vol.fernando p.franco,432 sala exclusivo', {'entities': [(36, 64, 'END_LOG')]})
# ('79965-000 itaquirai ms av.treze de maio,393 centro', {'entities': [(24, 44, 'END_LOG')]})
# ('rua dos andradas 1143 90020-015 rs porto alegre centro', {'entities': [(0, 21, 'END_LOG')]})

# %% [markdown]
# # Criando o modelo

# %%
# Define our variables

model = None
output_dir=Path(".")
n_iter= 250 # número de épocas
batch_size = 64

# %%
# Setting up the pipeline and entity recognizer.
if model is not None:
    nlp = spacy.load(model)  # load existing spacy model
    print("Loaded model '%s'" % model)
else:
    lan = 'pt'
    nlp = spacy.blank(lan)  # create blank Language class
    print("Created blank '%s' model" % lan)
    
if 'ner' not in nlp.pipe_names:
    ner = nlp.create_pipe('ner')
    nlp.add_pipe(ner)
    print('Added new NER')
else:
    ner = nlp.get_pipe('ner')
    print('Got an old NER')
# Out:
# Created blank 'pt' model
# Added new NER

# %%
# create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
if 'ner' not in nlp.pipe_names:
    ner = nlp.create_pipe('ner')
    nlp.add_pipe(ner, last=True)
# otherwise, get it so we can add labels
else:
    ner = nlp.get_pipe('ner')

# %% [markdown]
# ## Treinamento

# %%
print("Batch size: ", batch_size)
print("Épocas: ", n_iter)
print()

# add labels
for _, annotations in base_treinamento:
    for ent in annotations.get('entities'):
        ner.add_label(ent[2])


# get names of other pipes to disable them during training
other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
with nlp.disable_pipes(*other_pipes):  # only train NER
    optimizer = nlp.begin_training()
    for itn in range(n_iter):
        random.shuffle(base_treinamento)
        losses = {}
        batches = minibatch(base_treinamento, size=batch_size)
        
        for batch in batches:
            texts, annotations = zip(*batch)
            try:
                nlp.update(texts, annotations, sgd=optimizer, drop=0.2,
                       losses=losses)
            except:
                pass     
        
        print(itn+1, '\tLosses', losses)
# Out:
# Batch size:  64
# Épocas:  250
#
# 1 	Losses {'ner': 42406.08663019806}
# 2 	Losses {'ner': 15049.701008918018}
# 3 	Losses {'ner': 11350.498958502678}
# 4 	Losses {'ner': 9064.326153172273}
# 5 	Losses {'ner': 7616.480735804446}
# 6 	Losses {'ner': 6346.333682917659}
# 7 	Losses {'ner': 5661.365211955623}
# 8 	Losses {'ner': 5224.147627824183}
# 9 	Losses {'ner': 4786.875430345193}
# 10 	Losses {'ner': 4257.502126250984}
# 11 	Losses {'ner': 4274.676365970277}
# 12 	Losses {'ner': 4122.700997887913}
# 13 	Losses {'ner': 3948.6326896470528}
# 14 	Losses {'ner': 3632.2018594776814}
# 15 	Losses {'ner': 3526.779333861872}
# 16 	Losses {'ner': 3383.506706048531}
# 17 	Losses {'ner': 3158.5789782703105}
# 18 	Losses {'ner': 3201.920417003539}
# 19 	Losses {'ner': 2990.0705192696396}
# 20 	Losses {'ner': 2834.5102037985994}
# 21 	Losses {'ner': 2756.1972640193785}
# 22 	Losses {'ner': 2706.5008327412083}
# 23 	Losses {'ner': 2496.563174540845}
# 24 	Losses {'ner': 2471.653247965368}
# 25 	Losses {'ner': 2648.209574222119}
# 26 	Losses {'ner': 2483.1289684104268}
# 27 	Losses {'ner': 2156.933221281615}
# 28 	Losses {'ner': 2166.5255439578086}
# 29 	Losses {'ner': 2173.083603918467}
# 30 	Losses {'ner': 1919.6414052955172}
# 31 	Losses {'ner': 2023.4620142894455}
# 32 	Losses {'ner': 2039.7772441708175}
# 33 	Losses {'ner': 1828.530154705936}
# 34 	Losses {'ner': 1989.8112817316737}
# 35 	Losses {'ner': 2109.3392405462537}
# 36 	Losses {'ner': 1675.7605350462418}
# 37 	Losses {'ner': 1841.9268426814826}
# 38 	Losses {'ner': 1732.8327592214616}
# 39 	Losses {'ner': 1794.768681030883}
# 40 	Losses {'ner': 1557.1326398087692}
# 41 	Losses {'ner': 1638.444511050231}
# 42 	Losses {'ner': 1591.0145975254895}
# 43 	Losses {'ner': 1547.5575577257061}
# 44 	Losses {'ner': 1472.0709530255758}
# 45 	Losses {'ner': 1507.447548473527}
# 46 	Losses {'ner': 1444.9024645322343}
# 47 	Losses {'ner': 1442.2851083920582}
# 48 	Losses {'ner': 1378.4004397217204}
# 49 	Losses {'ner': 1205.5679207608455}
# 50 	Losses {'ner': 1503.6744793885996}
# 51 	Losses {'ner': 1453.3336576213915}
# 52 	Losses {'ner': 1422.9923247503782}
# 53 	Losses {'ner': 1469.912262748522}
# 54 	Losses {'ner': 1253.6208105738556}
# 55 	Losses {'ner': 1280.5897774616644}
# 56 	Losses {'ner': 1221.1982606246731}
# 57 	Losses {'ner': 1261.9524689767377}
# 58 	Losses {'ner': 1136.7130352965933}
# 59 	Losses {'ner': 1138.3850789624514}
# 60 	Losses {'ner': 1195.6830896126298}
# 61 	Losses {'ner': 1263.8739468063961}
# 62 	Losses {'ner': 1230.8818959792213}
# 63 	Losses {'ner': 1164.4786311928399}
# 64 	Losses {'ner': 1129.2927513342393}
# 65 	Losses {'ner': 1092.2092815119793}
# 66 	Losses {'ner': 1086.9829152669413}
# 67 	Losses {'ner': 1094.5522045999483}
# 68 	Losses {'ner': 996.3300139540197}
# 69 	Losses {'ner': 1077.551111971591}
# 70 	Losses {'ner': 1156.7047853621907}
# 71 	Losses {'ner': 1046.7192822243246}
# 72 	Losses {'ner': 1095.9483035406936}
# 73 	Losses {'ner': 961.4995513896317}
# 74 	Losses {'ner': 1038.4090642019091}
# 75 	Losses {'ner': 976.4780417582507}
# 76 	Losses {'ner': 1005.7807937758485}
# 77 	Losses {'ner': 1038.7742017236296}
# 78 	Losses {'ner': 1042.6150945164793}
# 79 	Losses {'ner': 1061.8793884249194}
# 80 	Losses {'ner': 992.2793080797192}
# 81 	Losses {'ner': 967.044065252622}
# 82 	Losses {'ner': 909.8014248432327}
# 83 	Losses {'ner': 898.3365747215985}
# 84 	Losses {'ner': 906.577145193919}
# 85 	Losses {'ner': 1041.0604752016166}
# 86 	Losses {'ner': 1035.7976610388428}
# 87 	Losses {'ner': 993.9588466562337}
# 88 	Losses {'ner': 912.0694355557945}
# 89 	Losses {'ner': 815.527721567467}
# 90 	Losses {'ner': 866.0826037425405}
# 91 	Losses {'ner': 904.3481649225726}
# 92 	Losses {'ner': 835.4383911289021}
# 93 	Losses {'ner': 844.8151533509098}
# 94 	Losses {'ner': 901.0846870463008}
# 95 	Losses {'ner': 1016.8700128092488}
# 96 	Losses {'ner': 841.1072866056569}
# 97 	Losses {'ner': 859.062603388897}
# 98 	Losses {'ner': 872.1821087678433}
# 99 	Losses {'ner': 796.2495322120342}
# 100 	Losses {'ner': 798.621301417063}
# 101 	Losses {'ner': 828.8117185828247}
# 102 	Losses {'ner': 819.4685240542404}
# 103 	Losses {'ner': 720.5094776321529}
# 104 	Losses {'ner': 822.4341650934541}
# 105 	Losses {'ner': 826.1179772181661}
# 106 	Losses {'ner': 893.4732589140681}
# 107 	Losses {'ner': 843.8032567326724}
# 108 	Losses {'ner': 813.6131053986865}
# 109 	Losses {'ner': 933.7145691225817}
# 110 	Losses {'ner': 813.676154453244}
# 111 	Losses {'ner': 869.6716065013437}
# 112 	Losses {'ner': 724.5856974937378}
# 113 	Losses {'ner': 735.7160163280395}
# 114 	Losses {'ner': 763.0086864921834}
# 115 	Losses {'ner': 755.3322405052247}
# 116 	Losses {'ner': 770.8266088402904}
# 117 	Losses {'ner': 698.4980975845567}
# 118 	Losses {'ner': 844.7434941102857}
# 119 	Losses {'ner': 860.3499595282128}
# 120 	Losses {'ner': 757.8396055988424}
# 121 	Losses {'ner': 663.0677190508317}
# 122 	Losses {'ner': 729.0145222965069}
# 123 	Losses {'ner': 789.8254007597143}
# 124 	Losses {'ner': 714.5859607628205}
# 125 	Losses {'ner': 839.1906625979681}
# 126 	Losses {'ner': 683.1258565265852}
# 127 	Losses {'ner': 739.0238978462997}
# 128 	Losses {'ner': 860.1232432076637}
# 129 	Losses {'ner': 737.0575497118558}
# 130 	Losses {'ner': 654.981063944982}
# 131 	Losses {'ner': 705.942597164196}
# 132 	Losses {'ner': 696.2399446488224}
# 133 	Losses {'ner': 764.6909507431178}
# 134 	Losses {'ner': 716.2969833236184}
# 135 	Losses {'ner': 701.4037732173545}
# 136 	Losses {'ner': 691.4073999537544}
# 137 	Losses {'ner': 666.5788400037477}
# 138 	Losses {'ner': 709.973285130076}
# 139 	Losses {'ner': 695.9138392721328}
# 140 	Losses {'ner': 702.6888440931646}
# 141 	Losses {'ner': 662.2707827868568}
# 142 	Losses {'ner': 708.4116391068925}
# 143 	Losses {'ner': 656.7871119572487}
# 144 	Losses {'ner': 632.7949267674071}
# 145 	Losses {'ner': 642.0970715046215}
# 146 	Losses {'ner': 643.8965375825337}
# 147 	Losses {'ner': 665.9924460581312}
# 148 	Losses {'ner': 615.2992523100663}
# 149 	Losses {'ner': 692.5235070330417}
# 150 	Losses {'ner': 589.748061915894}
# 151 	Losses {'ner': 533.8768786086019}
# 152 	Losses {'ner': 601.9989854943084}
# 153 	Losses {'ner': 719.6810730394243}
# 154 	Losses {'ner': 668.7716169661188}
# 155 	Losses {'ner': 678.6438135146809}
# 156 	Losses {'ner': 696.7218006937313}
# 157 	Losses {'ner': 593.6800780539935}
# 158 	Losses {'ner': 712.0333118740195}
# 159 	Losses {'ner': 654.6500249257625}
# 160 	Losses {'ner': 590.6015710568219}
# 161 	Losses {'ner': 566.3214692426042}
# 162 	Losses {'ner': 613.0445617170009}
# 163 	Losses {'ner': 687.7406284796724}
# 164 	Losses {'ner': 636.4752442335853}
# 165 	Losses {'ner': 615.6160575102782}
# 166 	Losses {'ner': 656.2595184956624}
# 167 	Losses {'ner': 602.8429359999234}
# 168 	Losses {'ner': 590.5764222857912}
# 169 	Losses {'ner': 657.5585611557044}
# 170 	Losses {'ner': 587.3125557521719}
# 171 	Losses {'ner': 665.652166157172}
# 172 	Losses {'ner': 687.0676370875863}
# 173 	Losses {'ner': 562.9520150552345}
# 174 	Losses {'ner': 553.9719293420214}
# 175 	Losses {'ner': 583.6406763513967}
# 176 	Losses {'ner': 570.6713811380292}
# 177 	Losses {'ner': 611.9938526960909}
# 178 	Losses {'ner': 570.1137387421837}
# 179 	Losses {'ner': 718.7640358023206}
# 180 	Losses {'ner': 685.0514396153209}
# 181 	Losses {'ner': 609.8546562143239}
# 182 	Losses {'ner': 776.9517135487498}
# 183 	Losses {'ner': 596.3103152689026}
# 184 	Losses {'ner': 707.7494961997885}
# 185 	Losses {'ner': 630.3133105184021}
# 186 	Losses {'ner': 563.106738980538}
# 187 	Losses {'ner': 619.266427464063}
# 188 	Losses {'ner': 658.0956590735551}
# 189 	Losses {'ner': 543.3396738124054}
# 190 	Losses {'ner': 635.017862207942}
# 191 	Losses {'ner': 691.6144941075469}
# 192 	Losses {'ner': 544.8210739387615}
# 193 	Losses {'ner': 698.0963245625283}
# 194 	Losses {'ner': 685.3029590108283}
# 195 	Losses {'ner': 634.8049483626309}
# 196 	Losses {'ner': 578.5835953610349}
# 197 	Losses {'ner': 522.8231390413498}
# 198 	Losses {'ner': 543.1955693555861}
# 199 	Losses {'ner': 619.0852577705389}
# 200 	Losses {'ner': 612.6247089612568}
# 201 	Losses {'ner': 610.94411616964}
# 202 	Losses {'ner': 525.3687022186407}
# 203 	Losses {'ner': 635.2934606420214}
# 204 	Losses {'ner': 520.6760042393202}
# 205 	Losses {'ner': 617.1136729482183}
# 206 	Losses {'ner': 593.9410087197715}
# 207 	Losses {'ner': 630.8456086298997}
# 208 	Losses {'ner': 474.63771731125905}
# 209 	Losses {'ner': 610.4643588143468}
# 210 	Losses {'ner': 568.1123322577898}
# 211 	Losses {'ner': 522.7588557303599}
# 212 	Losses {'ner': 575.77444185329}
# 213 	Losses {'ner': 563.0215611536013}
# 214 	Losses {'ner': 520.6180420960169}
# 215 	Losses {'ner': 659.9350522392068}
# 216 	Losses {'ner': 579.6235185133171}
# 217 	Losses {'ner': 564.095032943676}
# 218 	Losses {'ner': 562.1823636748845}
# 219 	Losses {'ner': 547.6217024772541}
# 220 	Losses {'ner': 511.5338387494853}
# 221 	Losses {'ner': 578.3926111448992}
# 222 	Losses {'ner': 596.0341605029375}
# 223 	Losses {'ner': 579.7318777297733}
# 224 	Losses {'ner': 557.1131084603004}
# 225 	Losses {'ner': 472.17445095570025}
# 226 	Losses {'ner': 541.1947102670923}
# 227 	Losses {'ner': 585.7414298735154}
# 228 	Losses {'ner': 608.1470068059665}
# 229 	Losses {'ner': 595.8964407480152}
# 230 	Losses {'ner': 519.5385208411714}
# 231 	Losses {'ner': 633.3852996582453}
# 232 	Losses {'ner': 549.4795733238786}
# 233 	Losses {'ner': 623.8059795845331}
# 234 	Losses {'ner': 535.1691910501901}
# 235 	Losses {'ner': 525.7145849011621}
# 236 	Losses {'ner': 584.1992667302761}
# 237 	Losses {'ner': 574.5143701610921}
# 238 	Losses {'ner': 570.551773341677}
# 239 	Losses {'ner': 549.3727815956624}
# 240 	Losses {'ner': 571.8637855774624}
# 241 	Losses {'ner': 569.291021802538}
# 242 	Losses {'ner': 544.4269000476987}
# 243 	Losses {'ner': 580.7830708803855}
# 244 	Losses {'ner': 609.6801619897508}
# 245 	Losses {'ner': 582.6008007143879}
# 246 	Losses {'ner': 559.5158020099808}
# 247 	Losses {'ner': 585.9292063741624}
# 248 	Losses {'ner': 508.29856865150197}
# 249 	Losses {'ner': 502.41319064485964}
# 250 	Losses {'ner': 577.8884168084447}

# %% [markdown]
# ## Salvando modelo

# %%
nlp.to_disk('../Saved_models/')

# %% [markdown]
# ## Carregando modelo para teste
# #### Executar até antes de `Criando o modelo` caso já tenha treinado anteriormente.

# %%
nlp = spacy.load('../Saved_models/')

# %% [markdown]
# ## Teste

# %% [markdown]
# Base de Teste

# %%
# test the trained model
for text, _ in base_teste:
    doc = nlp(text)
    print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
    print(text)
    print()
# Out:
# Entities [('r minas gerais', 'END_LOG')]
# centro  r minas gerais pr 86010-905 londrina
#
# Entities [('avenida fernando vilela, 1510', 'END_LOG')]
# uberlandia martins  38400-458 mg avenida fernando vilela, 1510
#
# Entities [('rua dr.joao de azevedo,601', 'END_LOG')]
# 37500-017  itajuba mg centro rua dr.joao de azevedo,601
#
# Entities [('pca.pref.euclides a.fabris,151', 'END_LOG')]
# ms navirai  centro 79950-000 pca.pref.euclides a.fabris,151
#
# Entities [('av.governador jorge teixeira, 2419', 'END_LOG')]
# 76888-000 centro ro av.governador jorge teixeira, 2419 monte negro
#
# Entities [('rua prudente de morais', 'END_LOG')]
# abadia 38026-250 mg uberaba rua prudente de morais
#
# Entities [('av. tomaz edison', 'END_LOG')]
# av. tomaz edison rs  sao leopoldo 93125-140 scharlau
#
# Entities [('rodovia raposo tavares (km 23), 23600', 'END_LOG')]
# rodovia raposo tavares (km 23), 23600 lageadinho 06709-015 sp cotia lojas 362, 363
#
# Entities [('avenida governador agamenon magalhes', 'END_LOG')]
# recife 50070-255 avenida governador agamenon magalhes paissandu  pe
#
# Entities [('rua riachuelo 482', 'END_LOG')]
# 17201-340 centro sp  jau rua riachuelo 482
#
# Entities [('rua gustavo maciel, esq.c/ rua vivaldo g', 'END_LOG')]
# jardim estoril bauru  17016-200 rua gustavo maciel, esq.c/ rua vivaldo g sp
#
# Entities [('tv lauro sodre', 'END_LOG')]
# tucurui tv lauro sodre jaqueira 68458-010 pa
#
# Entities [('av.conselheiro carrao,2411', 'END_LOG')]
# sp av.conselheiro carrao,2411 03402-002 2.andar vl carrao sao paulo
#
# Entities [('avenida santo antonio', 'END_LOG')]
# 84430-000 centro imbituva avenida santo antonio  pr
#
# Entities [('av. bernardo vieira de melo', 'END_LOG')]
# pe 54410-010 piedade jaboatao dos guararapes av. bernardo vieira de melo
#
# Entities [('av.juscelino kubitschek de', 'END_LOG')]
# cidade industrial av.juscelino kubitschek de curitiba pr 81170-300 oliveira,11800
#
# Entities [('av. cavalhada, 2710', 'END_LOG')]
# cavalhada 09174-000 rs  av. cavalhada, 2710 porto alegre
#
# Entities [('avenida farrapos, num 3665', 'END_LOG')]
# 90220-007 porto alegre avenida farrapos, num 3665 rs  sao geraldo
#
# Entities [('av pau brasil', 'END_LOG')]
# aguas claras brasilia (aguas claras) 71926-000 av pau brasil df loja 21, 34 e 35
#
# Entities [('rua leopoldo couto de magalhes jr.', 'END_LOG')]
# sp itaim bibi sao paulo 04542-000 rua leopoldo couto de magalhes jr. 10 andar (parte) e 12 a 14 andares (partes)
#
# Entities [('rua cosme ferreira marques, 108', 'END_LOG')]
# rn centro santa cruz  rua cosme ferreira marques, 108 59200-000
#
# Entities [('av. d. pedro i, 668', 'END_LOG')]
# av. d. pedro i, 668 santo andre sp  vila pires 91300-000
#
# Entities [('pca.agamenon magalhaes, 39', 'END_LOG')]
# 55570-000 pca.agamenon magalhaes, 39  pe centro rio formoso
#
# Entities [('av.tancredo neves,2267', 'END_LOG')]
# chupinguaia ro av.tancredo neves,2267 76990-000 lote 8, quadra 37 setor misto
#
# Entities [('rua bento dias, num 246', 'END_LOG')]
# sp centro capivari 13360-000 rua bento dias, num 246 360305
#
# Entities [('r sebastiao jose rodrigues', 'END_LOG')]
# 27542-060 r sebastiao jose rodrigues  campos eliseos rj resende
#
# Entities [('saf sul', 'END_LOG')]
# df quadra 2, bloco d, sala 403, 4 andar 70070-600 saf sul zona civico-adm brasilia
#
# Entities [('av. joaquim leite, 561', 'END_LOG')]
# barra mansa av. joaquim leite, 561 27345-391 centro  rj
#
# Entities [('estrada joao de oliveira remiao', 'END_LOG')]
# 91560-000 porto alegre estrada joao de oliveira remiao lomba do pinheiro rs
#
# Entities [('av. jose ferreira da costa, 725', 'END_LOG')]
# costa rica  centro ms 79420-000 av. jose ferreira da costa, 725
#
# Entities [('rua irineu vilela veiga, 82', 'END_LOG')]
# 89270-000 guaramirim rua irineu vilela veiga, 82 centro  sc
#
# Entities [('rua alagoas,', 'END_LOG')]
# belo horizonte loja 04 - shopping 5 avenida rua alagoas, 30130-913 funcionrios mg
#
# Entities [('rua moacyr pereira junior, 52', 'END_LOG')]
# sc rua moacyr pereira junior, 52 lagoa da conceicao 88062-025  florianopolis
#
# Entities [('av. brasil, 1621', 'END_LOG')]
# alto piquiri 87580-000 dist brasilandia av. brasil, 1621  pr
#
# Entities [('rua  heitor penteado, 1833/rua juatiba', 'END_LOG')]
# sao paulo sumarezinho 60746948 sp 05437-002 rua  heitor penteado, 1833/rua juatiba
#
# Entities [('rua barao do rio branco s/n.', 'END_LOG')]
# ap 68980-000 centro oiapoque rua barao do rio branco s/n.
#
# Entities [('rua visconde de inhama, 37 - a', 'END_LOG')]
# centro ss e slj rua visconde de inhama, 37 - a rio de janeiro rj 20091-007
#
# Entities [('r.antonio guedes alcoforado,26', 'END_LOG')]
# pedro canario predio,terreo es 29970-000 r.antonio guedes alcoforado,26 centro
#
# Entities [('rua marechal  rondon, 1.672', 'END_LOG')]
# 79002-000  centro rua marechal  rondon, 1.672 ms campo grande
#
# Entities [('praa getlio vargas', 'END_LOG')]
# 68830-000 ponta de pedras  pa praa getlio vargas centro
#
# Entities [('av. ernani do amaral peixoto', 'END_LOG')]
# lj ab centro 24020-075 rj niteroi av. ernani do amaral peixoto
#
# Entities [('avenida floriano peixoto, 09', 'END_LOG')]
# al 57200-000 avenida floriano peixoto, 09 penedo centro 360305
#
# Entities [('rua narciso sturlini, 92', 'END_LOG')]
# rua narciso sturlini, 92  osasco 06018-090 centro sp
#
# Entities [('av. brasil, 165', 'END_LOG')]
# mg centro  av. brasil, 165 extrema 37640-000
#
# Entities [('av.contorno oeste,s/n', 'END_LOG')]
# ma 65053-570 av.contorno oeste,s/n pq.aurora qd.18,lotes 3/4 sao luis
#
# Entities [('av.pref.ulisses de n.bione,365-a', 'END_LOG')]
# centro pe 56170-000 oroco av.pref.ulisses de n.bione,365-a
#
# Entities [('pca. guarda-mor f.j. pinheiro, 272', 'END_LOG')]
# 75640-000 go piracanjuba  pca. guarda-mor f.j. pinheiro, 272 centro
#
# Entities [('av. prudente de morais, 1555', 'END_LOG')]
# belo horizonte 30380-000 av. prudente de morais, 1555  mg santo antonio
#
# Entities [('av.goias, 414', 'END_LOG')]
# 74010-010 av.goias, 414 go  goiania centro
#
# Entities [('rua viuva olinda watter', 'END_LOG')]
# erebango rs rua viuva olinda watter 99920-000 sala 17 centro
#
# Entities [('av. dr. chucri zaidan', 'END_LOG')]
# sp sao paulo 04583-110 1 andar, bl a chacara sto antonio av. dr. chucri zaidan
#
# Entities [('praca primeiro de maio, 33', 'END_LOG')]
# mg 35180-018 timoteo centro  praca primeiro de maio, 33
#
# Entities [('av ipiranga, 67', 'END_LOG')]
# 81 s loja 01046-010 sp republica sao paulo av ipiranga, 67
#
# Entities [('pc castelo branco', 'END_LOG')]
# pc castelo branco alta floresta d'oeste ro 76954-000  centro
#
# Entities [('av. expedito garcia, 60', 'END_LOG')]
# es cariacica campo grande av. expedito garcia, 60 29146-200 terreo e sobreloja parte
#
# Entities [('rua eloi teixeira, 414', 'END_LOG')]
# 26383-080 queimados rua eloi teixeira, 414  rj centro
#
# Entities [('r. major antonio candido branquinho, 337', 'END_LOG')]
# 14470-000 r. major antonio candido branquinho, 337  centro pedregulho sp
#
# Entities [('rua mal floriano peixoto, 134', 'END_LOG')]
# 89251-150  centro sc rua mal floriano peixoto, 134 jaragua do sul
#
# Entities [('pca. tefilo batista de melo, 67', 'END_LOG')]
# itabi se 49870-000 centro pca. tefilo batista de melo, 67
#
# Entities [('rua quintino bocaiuva, 580', 'END_LOG')]
# moinhos de vento 90440-050 rua quintino bocaiuva, 580  porto alegre rs
#
# Entities [('rua conego anibal m. difracia, 1075', 'END_LOG')]
# sc  rua conego anibal m. difracia, 1075 pinheirinho 88800-000 criciuma
#
# Entities [('av.getulio vargas, 1015', 'END_LOG')]
# pi av.getulio vargas, 1015 canto do buriti  64890-000 centro
#
# Entities [('rua onze de agosto, 232', 'END_LOG')]
# 18270-000  tatui centro rua onze de agosto, 232 sp
#
# Entities [('av.barao de gurgueia,3500', 'END_LOG')]
# teresina av.barao de gurgueia,3500 vermelha pi  64018-500
#
# Entities [('rua general osrio', 'END_LOG')]
# palmeira das missoes  centro 98300-000 rs rua general osrio
#
# Entities [('avenida governador valadares', 'END_LOG')]
# 32600-222 betim avenida governador valadares loja 1 centro mg
#
# Entities [('r armando salles de oliveira,  1947', 'END_LOG')]
# r armando salles de oliveira,  1947 1953 q59 l24/2 sp cidade nova i 13334-160 indaiatuba
#
# Entities [('rua joo pereira de vargas', 'END_LOG')]
# 93230-210 sapucaia do sul rua joo pereira de vargas rs nova sapucaia
#
# Entities [('rua edgar pires de castro', 'END_LOG')]
# porto alegre aberta dos morros 1029 91787-235 rs rua edgar pires de castro
#
# Entities [('rua joaquim vieira, 85', 'END_LOG')]
# centro rua joaquim vieira, 85 45530-000  itacare ba
#
# Entities [('avenida leao machado, 100, loja p21', 'END_LOG')]
# avenida leao machado, 100, loja p21 parque continental sp 05328-020 sao paulo
#
# Entities [('rua leonardo malcher, 1862', 'END_LOG')]
# am manaus 69015-000 centro  rua leonardo malcher, 1862
#
# Entities [('r pedro bini, 136 esq r duque caxias', 'END_LOG')]
# r pedro bini, 136 esq r duque caxias centro 99490-000 rs tapera
#
# Entities [('avenida antonio carlos magalhaes', 'END_LOG')]
# itaigara avenida antonio carlos magalhaes 41825-904 loja 2 ba salvador
#
# Entities [('av dep emilio carlos 1861', 'END_LOG')]
# 02721-100  av dep emilio carlos 1861 sp sao paulo limo
#
# Entities [('av. brasil, 1071', 'END_LOG')]
# 15370-000 centro av. brasil, 1071 pereira barreto sp
#
# Entities [('rua benjamin constant, 396', 'END_LOG')]
# 90550-000  so joo rua benjamin constant, 396 porto alegre rs
#
# Entities [('rua lindolfo simoes, 330', 'END_LOG')]
# al centro coruripe 57230-000  rua lindolfo simoes, 330
#
# Entities [('rua tripoli', 'END_LOG')]
# sao paulo 05303-020 1 andar rua tripoli sp vila leopoldina
#
# Entities [('avenida doutor nilo peanha', 'END_LOG')]
# 91330-001 sala 503 - edifcio iguatemi corporate rs avenida doutor nilo peanha chcara das pedras porto alegre
#
# Entities [('r voluntarios da patria, 1769', 'END_LOG')]
# 02011-300 1 andar sao paulo sp santana r voluntarios da patria, 1769
#
# Entities [('rua verissimo prado, 157', 'END_LOG')]
# sp  sao pedro 13520-000 rua verissimo prado, 157 centro
#
# Entities [('rua pavao, 505 / 515', 'END_LOG')]
# 45160-110  rua pavao, 505 / 515 indianopolis sp sao paulo
#
# Entities [('rua do passeio', 'END_LOG')]
# 11. andar - parte rj rua do passeio centro 20021-290 rio de janeiro
#
# Entities [('av.piracicaba,594', 'END_LOG')]
# av.piracicaba,594 2.pavimento 13480-743 sp vl s joao limeira
#
# Entities [('av eduardo elias zahran 1804', 'END_LOG')]
# qd 1 lt x jd tv morena 79051-000 ms campo grande av eduardo elias zahran 1804
#
# Entities [('rua 10, 553/av. nove', 'END_LOG')]
# 15495-000 rua 10, 553/av. nove  riolandia centro sp
#
# Entities [('r bento de arruda camargo, 1680', 'END_LOG')]
# jardim santana  sp r bento de arruda camargo, 1680 13088-650 campinas
#
# Entities [('av barao do rio branco, 1225', 'END_LOG')]
# av barao do rio branco, 1225 16901-050 centro  andradina sp
#
# Entities [('r.gal.pereira da silva,171', 'END_LOG')]
# niteroi 24220-030 r.gal.pereira da silva,171 rj icarai
#
# Entities [('av doutor olivio lira sn', 'END_LOG')]
# av doutor olivio lira sn  vila velha 29101-260 praia da costa es
#
# Entities [('r.rio branco,371', 'END_LOG')]
# r.rio branco,371 09710-090 centro sp  sao bernardo do campo
#
# Entities [('av.frei serafim,2170', 'END_LOG')]
# terreo av.frei serafim,2170 centro 64001-020 teresina pi
# Entities [('avenida joo ramalho', 'END_LOG')]
# nucleo habitacional nova maril avenida joo ramalho 17522-363  sp marilia
#
# Entities [('rua do comercio, 184', 'END_LOG')]
# centro 65365-000 rua do comercio, 184  ma ze doca
#
# Entities [('rua presidente tancredo neves, 360', 'END_LOG')]
# centro rua presidente tancredo neves, 360 37580-000 mg monte siao parte
#
# Entities [('rua gaspar martins, 133', 'END_LOG')]
# 97540-000 alegrete rs centro  rua gaspar martins, 133
#
# Entities [('rua dos expedicionario', 'END_LOG')]
# rua dos expedicionario  centro 95990-000 ilopolis rs
#
# Entities [('av washington luis,', 'END_LOG')]
# sp 11055-001 boqueirao santos av washington luis,
#
# Entities [('avenida antonio abrahao caram, 820', 'END_LOG')]
# belo horizonte lojas 04, 05, 06, 07, 11, 12, 13 e 14 sao jose 31275-000 mg avenida antonio abrahao caram, 820
#
# Entities [('loja 200, rua 12', 'END_LOG')]
# 27260-315 loja 200, rua 12 rj vl.santa cecilia volta redonda
#
# Entities [('avenida marechal rondon', 'END_LOG')]
# mt avenida marechal rondon 78250-000  pontes e lacerda centro
#
# Entities [('rua candido bueno, 898', 'END_LOG')]
# sp rua candido bueno, 898  centro 13910-033 jaguariuna
#
# Entities [('rua capito martinho, 555', 'END_LOG')]
# 79500-000 ms  centro paranaiba rua capito martinho, 555
#
# Entities [('avenida central, 1.337', 'END_LOG')]
# 15570-000 avenida central, 1.337  sp cardoso centro
#
# Entities [('rua manoel valdomiro de macedo, 2470', 'END_LOG')]
# pr 81170-150 cidade industrial rua manoel valdomiro de macedo, 2470  curitiba
#
# Entities [('rua deputado sales filho, 231', 'END_LOG')]
# 17800-000 sp adamantina rua deputado sales filho, 231 centro
#
# Entities [('pca.n.sra.do rosario,s/n', 'END_LOG')]
# rn 59507-970 centro alto do rodrigues  pca.n.sra.do rosario,s/n
#
# Entities [('r senador antonio lemos', 'END_LOG')]
# 68745-010  r senador antonio lemos castanhal centro pa
#
# Entities [('rua dr. joaquim manoel', 'END_LOG')]
# ba 46430-000 centro rua dr. joaquim manoel  guanambi
#
# Entities [('av.plinio dantas saldanha,135', 'END_LOG')]
# av.plinio dantas saldanha,135 jardim de piranhas centro 59324-000  rn
#
# Entities [('rua joinville, 3600', 'END_LOG')]
# rua joinville, 3600 sao jose dos pinhais  sao pedro 83020-000 pr
#
# Entities [('av.denise cristina da rocha,427', 'END_LOG')]
# santa branca 33800-000 av.denise cristina da rocha,427 ribeirao das neves  mg
#
# Entities [('r.dos marianis,996', 'END_LOG')]
# barra predio centro 47100-000 ba r.dos marianis,996
#
# Entities [('av.gov.pedro de toledo,1101', 'END_LOG')]
# av.gov.pedro de toledo,1101 13070-751  bonfim sp campinas
#
# Entities [('av.longuinho lemes do prado,878', 'END_LOG')]
# go 75865-000 gouvelandia av.longuinho lemes do prado,878 centro
#
# Entities [('rua siqueira campos', 'END_LOG')]
# araguatins 77950-000 to centro  rua siqueira campos
#
# Entities [('praca brasilia', 'END_LOG')]
# praca brasilia cafelandia pr 85415-000  centro
#
# Entities [('rua  quintino bocaiuva', 'END_LOG')]
# rua  quintino bocaiuva 14955-000  centro borborema sp
#
# Entities [('av. bernardo vieira de melo,', 'END_LOG')]
# pe av. bernardo vieira de melo,  jaboatao dos guararapes centro 54410-010
#
# Entities [('av ministro joao alberto, 27', 'END_LOG')]
# 78600-000 centro mt barra do garcas  av ministro joao alberto, 27
#
# Entities [('av.caraiba,875', 'END_LOG')]
# ed.cobre - distrito de pilar jaguarari ba nucleo res.pilar av.caraiba,875 48967-000
#
# Entities [('rua barao do rio branco, 1080', 'END_LOG')]
# go rua barao do rio branco, 1080 conjunto 2 anapolis 75025-040 setor central
#
# Entities [('rua presidente vargas, 472', 'END_LOG')]
# es domingos martins  rua presidente vargas, 472 centro 29270-000
#
# Entities [('av rui barbosa, 663', 'END_LOG')]
# rio verde av rui barbosa, 663 setor central go 75901-250
#
# Entities [('av. manoel dias da silva, 1.083', 'END_LOG')]
# pituba 41830-000 salvador av. manoel dias da silva, 1.083  ba
#
# Entities [('av.firmino maia,46', 'END_LOG')]
# vicosa centro al av.firmino maia,46  57700-000
#
# Entities [('av.sta.catarina,509', 'END_LOG')]
# 89885-000 sao carlos av.sta.catarina,509 sc  centro
#
# Entities [('praa dr. genserico nunes de oliveira, 4', 'END_LOG')]
# praa dr. genserico nunes de oliveira, 4 36820-000  centro mg divino
#
# Entities [('av. vinte cinco de agosto, 1927', 'END_LOG')]
# centro 78987-000 ro av. vinte cinco de agosto, 1927 rolim de moura
#
# Entities [('praca alexandre szundy, 15', 'END_LOG')]
# 360305 praca alexandre szundy, 15 centro itapecerica mg 35550-000
#
# Entities [('av. paulista, 1111', 'END_LOG')]
# sp cerqueira cesar sao paulo 01311-920  2 andar-parte av. paulista, 1111
#
# Entities [('r.santos dumont,2746', 'END_LOG')]
# 87013-050 r.santos dumont,2746 pr maringa 12.andar - sala exclusivo zona 01
#
# Entities [('rua conselheiro ribas, 459', 'END_LOG')]
# 05093-060 sao paulo  vila anastcio sp rua conselheiro ribas, 459
#
# Entities [('r cel baleco, s/n', 'END_LOG')]
# centro 63150-000 r cel baleco, s/n campos sales  ce
#
# Entities [('rua engenheiro antunes, 222', 'END_LOG')]
# mg teofilo otoni rua engenheiro antunes, 222 39800-019 centro 360305
#
# Entities [('av. goias, 653', 'END_LOG')]
# av. goias, 653 setor central goiania parte 74015-200 go
#
# Entities [('av. dr pereira barreto', 'END_LOG')]
# centro av. dr pereira barreto maues am 69190-000
#
# Entities [('rua da passagem, 123', 'END_LOG')]
# rua da passagem, 123 22290-030 rj botafogo lojas a e b rio de janeiro
#
# Entities [('rua barao de melgaco, 3735', 'END_LOG')]
# rua barao de melgaco, 3735 boa esperanca mt 78068-650 cuiaba mezanino
#
# Entities [('qne 27, lote 10, loja 1', 'END_LOG')]
# brasilia (taguatinga)  qne 27, lote 10, loja 1 taguatinga norte 72125-270 df
#
# Entities [('rodovia presidente dutra', 'END_LOG')]
# sp guarulhos jardim cumbica 07183-903 km 214 rodovia presidente dutra
#
# Entities [('r.emerenciana,58', 'END_LOG')]
# pb r.emerenciana,58 terreo pocinhos centro 58150-000
#
# Entities [('praa getlio vargas', 'END_LOG')]
# praa getlio vargas 68830-000 centro  pa ponta de pedras
#
# Entities [('av.prof.ana maria silvestre adade,s/n', 'END_LOG')]
# sp parque das universidades puc campinas 13086-130 campinas av.prof.ana maria silvestre adade,s/n
#
# Entities [('av.dom bosco,357', 'END_LOG')]
# es  29725-000 av.dom bosco,357 marilandia centro
#
# Entities [('av coronel martiniano', 'END_LOG')]
# 59300-000 rn  caico av coronel martiniano centro
#
# Entities [('av.deputado esteves rodrigues,834', 'END_LOG')]
# 39400-215 av.deputado esteves rodrigues,834 centro montes claros mg
#
# Entities [('alameda 31 de outubro,201', 'END_LOG')]
# timoteo centro alameda 31 de outubro,201 mg lote a012 35180-014
#
# Entities [('rua comendador viana, 256', 'END_LOG')]
# centro  34505-340 rua comendador viana, 256 sabara mg
#
# Entities [('av.brasil,991', 'END_LOG')]
# sao lourenco d'oeste av.brasil,991 89990-000 centro sc esq.c/r.duque de caxias
#
# Entities [('r.borges de medeiros,120', 'END_LOG')]
# rs estrela  centro 95880-000 r.borges de medeiros,120
#
# Entities [('rua 20', 'END_LOG')]
# quadra 22 lotes 03 e 04 rua 20 go sao simao setor residencial cemig 75890-000
#
# Entities [('rua assis ribeiro, 169', 'END_LOG')]
# rj rua assis ribeiro, 169 itaperuna centro 28300-000
#
# Entities [('av brigadeiro faria lima,', 'END_LOG')]
# av brigadeiro faria lima, 01451-001 jardim paulistano sao paulo sp 1790 - parte
#
# Entities [('av. doutor claudio jose gueiros leite', 'END_LOG')]
# av. doutor claudio jose gueiros leite pe janga 53439-000  paulista
#
# Entities [('cidade de deus', 'END_LOG')]
# cidade de deus sp vila yara osasco  60029-000
#
# Entities [('r getulio vargas 157', 'END_LOG')]
# r getulio vargas 157 camboriu centro  sc 88340-000
#
# Entities [('rua januaria, 196', 'END_LOG')]
# itacarambi rua januaria, 196 39470-000  centro mg
#
# Entities [('r  voluntarios de sao paulo, 2975', 'END_LOG')]
# 15015-200 3. andar sao jose do rio preto centro sp r  voluntarios de sao paulo, 2975
#
# Entities [('av.joao durval carneiro, 3686', 'END_LOG')]
# coronel jose pinto ba 44037-010 av.joao durval carneiro, 3686 feira de santana
#
# Entities [('tv.duque de caxias,54', 'END_LOG')]
# tv.duque de caxias,54 centro 99290-000 rs vanini
#
# Entities [('avenida guilherme cotching, n 1873', 'END_LOG')]
# 02113-017 parte sp vila maria avenida guilherme cotching, n 1873 sao paulo
#
# Entities [('rua baraldi, 1.002', 'END_LOG')]
# parte 09510-005 rua baraldi, 1.002 centro sp sao caetano do sul
#
# Entities [('av. celso garcia, 351', 'END_LOG')]
# bras sao paulo  av. celso garcia, 351 sp 03015-000
#
# Entities [('av alderico bandeira de lima', 'END_LOG')]
# av alderico bandeira de lima 83430-000 pr lt 04 qd 15 jardim paulista campina grande do sul
#
# Entities [('r. almirante barroso, 1062', 'END_LOG')]
# pr centro foz do iguacu  r. almirante barroso, 1062 85851-010
#
# Entities [('avenida higienopolis,', 'END_LOG')]
# pr centro avenida higienopolis, londrina 86020-907 loja 02
#
# Entities [('av.afonso pena,826', 'END_LOG')]
# rn natal av.afonso pena,826 tirol 59020-100
#
# Entities [('rua do passeio', 'END_LOG')]
# centro 20021-290 rj rio de janeiro rua do passeio 11. andar - parte
#
# Entities [('rua gorgonio jose de araujo, 93', 'END_LOG')]
# 44571-355 ba centro santo antonio de jesus rua gorgonio jose de araujo, 93
#
# Entities [('rua teodoro sampaio, 1118', 'END_LOG')]
# sao paulo rua teodoro sampaio, 1118 05406-050 sp pinheiros
#
# Entities [('av.mons.scalabrini,693', 'END_LOG')]
# 99200-000  guapore centro rs av.mons.scalabrini,693
#
# Entities [('rua nove de julho', 'END_LOG')]
# sp guariba rua nove de julho centro  14840-000
#
# Entities [('r.sen.flaquer,140', 'END_LOG')]
# r.sen.flaquer,140 centro 09010-160  sp santo andre
#
# Entities [('rua senador flaquer', 'END_LOG')]
# centro rua senador flaquer santo andre 09010-160 1 andar sp
#
# Entities [('estrada do galeo, 2.743', 'END_LOG')]
# 21931-383  estrada do galeo, 2.743 rio de janeiro ilha do governador rj
#
# Entities [('rua lucivaldo curvello, 69', 'END_LOG')]
# ba rua lucivaldo curvello, 69  planaltino centro 45375-000
#
# Entities [('av santos dumont', 'END_LOG')]
# fortaleza av santos dumont 60150-165  aldeota ce
#
# Entities [('av tomas espindola, 155/171', 'END_LOG')]
# av tomas espindola, 155/171 farol 57051-000  al maceio
#
# Entities [('av. prof. alfonso bovero, 1221', 'END_LOG')]
# v.pompeia sao paulo av. prof. alfonso bovero, 1221 sp  05019-011
#
# Entities [('av.pres.itamar franco,1710', 'END_LOG')]
# av.pres.itamar franco,1710  mg 36016-321 juiz de fora sao mateus
#
# Entities [('rua cardoso de morais, 61', 'END_LOG')]
# rio de janeiro bonsucesso rj loja a - parte 21032-000 rua cardoso de morais, 61
#
# Entities [('av. cincinato pinto, 53', 'END_LOG')]
# 57020-050 av. cincinato pinto, 53  al centro maceio
#
# Entities [('r.dr.ary coelho de oliveira,70', 'END_LOG')]
# 79190-000 centro r.dr.ary coelho de oliveira,70 terenos  ms
#
# Entities [('rua senador dantas', 'END_LOG')]
# 20031-202 0015 - lj ss jirau rua senador dantas rj rio de janeiro centro
# Entities [('rua buarque de macedo, 3098', 'END_LOG')]
# 95720-000 garibaldi rs rua buarque de macedo, 3098 centro
#
# Entities [('r.quinze de novembro,s/n', 'END_LOG')]
# 68580-000 em frente a prefeitura r.quinze de novembro,s/n centro itupiranga pa
#
# Entities [('rua odolfo medeiros', 'END_LOG')]
# carolina ma  65980-000 centro rua odolfo medeiros
#
# Entities [('av.tropical,s/n', 'END_LOG')]
# jd.tropical av.tropical,s/n go 74946-540 aparecida de goiania qd.23,lote 4/6,esq.c/r.102
#
# Entities [('recanto das emas - qd.205', 'END_LOG')]
# recanto das emas 72610-501 recanto das emas - qd.205 brasilia av.recanto das emas - lt 01/02 - lj 04 df
#
# Entities [('r.sao joao batista,2234', 'END_LOG')]
# 85350-000 r.sao joao batista,2234 pr  nova laranjeiras centro
#
# Entities [('av. dr. soares de oliveira, 57', 'END_LOG')]
# centro sp  ituverava 14500-000 av. dr. soares de oliveira, 57
#
# Entities [('r.laudelino freire,202', 'END_LOG')]
# lagarto terreo r.laudelino freire,202 centro se 49400-000
#
# Entities [('rua jose clemente, 420', 'END_LOG')]
# 69010-070 rua jose clemente, 420  manaus am centro
#
# Entities [('r.sete de setembro,100', 'END_LOG')]
# 14300-000 r.sete de setembro,100 centro  sp batatais
#
# Entities [('av.pres.vargas,1', 'END_LOG')]
# sao geraldo do araguaia 68570-000 av.pres.vargas,1 pa  centro
#
# Entities [('av.prof.francisco morato,2004/2016', 'END_LOG')]
# sao paulo av.prof.francisco morato,2004/2016 butanta 05512-200 sp
#
# Entities [('rua lautert filho', 'END_LOG')]
# 95860-000 rua lautert filho taquari rs  centro
#
# Entities [('rua francisco real, 566', 'END_LOG')]
# rj rio de janeiro padre miguel rua francisco real, 566  21715-422
#
# Entities [('rua mateus leme, 2372', 'END_LOG')]
# 80530-010  rua mateus leme, 2372 pr curitiba centro civico
#
# Entities [('av.cel.jose soares marcondes,3350', 'END_LOG')]
# presidente prudente jd.bongiovani sp av.cel.jose soares marcondes,3350  19050-230
#
# Entities [('r cel quirino', 'END_LOG')]
# sp  campinas cambui 13025-001 r cel quirino
#
# Entities [('avenida julio trois 2032', 'END_LOG')]
# varzea avenida julio trois 2032 sao borja v comando aereo regional rs 97670-000
#
# Entities [('r. 13 de junho, 877, ed. albert sabin', 'END_LOG')]
# mt 78020-000 r. 13 de junho, 877, ed. albert sabin  cuiaba cuiaba
#
# Entities [('rua presidente epitacio pessoa, 61', 'END_LOG')]
# rua presidente epitacio pessoa, 61  centro 89251-100 sc jaragua do sul
#
# Entities [('av.jk, quadra 104 norte, cj 1, lt 28a', 'END_LOG')]
# plano diretor norte palmas antiga acne 1 to av.jk, quadra 104 norte, cj 1, lt 28a 77006-014
#
# Entities [('av. brasilia, q.33 ,lt. 07', 'END_LOG')]
# 75940-000 go av. brasilia, q.33 ,lt. 07  edeia centro
#
# Entities [("av.princesa d'oeste,912", 'END_LOG')]
# campinas sp 13100-040  av.princesa d'oeste,912 jd paraiso
#
# Entities [('av.republica do libano,1921', 'END_LOG')]
# go goiania 74125-125 qd. 03, lote 42 setor oeste av.republica do libano,1921
#
# Entities [('r treze de maio', 'END_LOG')]
# 13840-015 centro sp r treze de maio  mogi-guacu
#
# Entities [('r.paula bueno,918', 'END_LOG')]
# campinas 13076-061 sp r.paula bueno,918  taquaral
#
# Entities [('rua cel.oliveira, 334', 'END_LOG')]
# rua cel.oliveira, 334 centro 37795-000  mg andradas
#
# Entities [('rua sete de setembro, 1080', 'END_LOG')]
# centro 90101-191 rua sete de setembro, 1080 (parte) rs porto alegre
#
# Entities [('av.rodoviaria,1200', 'END_LOG')]
# sao mateus do maranhao centro  av.rodoviaria,1200 ma 65470-000
#
# Entities [('av.thiago ferreira, 955', 'END_LOG')]
# sp (vicente de carvalho) vila alice 11450-003 av.thiago ferreira, 955 guaruja
#
# Entities [('avenida  mucio jose reis', 'END_LOG')]
# centro  avenida  mucio jose reis mg 35700-640 sete lagoas
#
# Entities [('av. afonso pena, 3436', 'END_LOG')]
# av. afonso pena, 3436 79002-074 ms campo grande centro
#
# Entities [('rua aurelio figueiredo, 40 a', 'END_LOG')]
# campo grande rua aurelio figueiredo, 40 a 23052-000 rj rio de janeiro
#
# Entities [('r.sebastiao lopes carvalho,303', 'END_LOG')]
# r.sebastiao lopes carvalho,303 mg  centro vicosa 36570-000
#
# Entities [('rua saul brandalise', 'END_LOG')]
# rua saul brandalise centro sc videira  89560-000
#
# Entities [('praca 22 de novembro, 45', 'END_LOG')]
# praca 22 de novembro, 45 maua sp 93101-000 centro
#
# Entities [('av. cleriston andrade', 'END_LOG')]
# centro barreiras  ba 47800-358 av. cleriston andrade
#
# Entities [('rua  maranhao, 1003', 'END_LOG')]
# distrito do jacare rua  maranhao, 1003 13315-000 sp cabreuva
#
# Entities [('av. sen. salgado filho 2234 lj s01', 'END_LOG')]
# rn 59064-900 av. sen. salgado filho 2234 lj s01 candelria natal alameda de servios do piso  l1
#
# Entities [('rua xv de novembro', 'END_LOG')]
# pr centro curitiba 80020-310 rua xv de novembro
#
# Entities [('rua dr campos salles', 'END_LOG')]
# socorro 13960-000 centro  rua dr campos salles sp
#
# Entities [('rua pereira de rezende 700', 'END_LOG')]
# igaracu do tiete rua pereira de rezende 700 centro  sp 17350-000
#
# Entities [('r gal oswaldo pinto da veiga', 'END_LOG')]
# rj  27260-140 vila santa cecilia r gal oswaldo pinto da veiga volta redonda
#
# Entities [('av.  weyne cavalcante', 'END_LOG')]
# 68537-000 av.  weyne cavalcante pa  canaa dos carajas centro
#
# Entities [('av. professor nathan chaves, 171', 'END_LOG')]
# 18180-000 tapirai av. professor nathan chaves, 171 sp centro
#
# Entities [('r.halfeld,770', 'END_LOG')]
# juiz de fora 36010-003 r.halfeld,770 centro calcadao mg
#
# Entities [('avenida julia freire', 'END_LOG')]
# joao pessoa pb loja 17 expedicionarios 58041-000 avenida julia freire
#
# Entities [('rua serra do japi, n 143', 'END_LOG')]
# rua serra do japi, n 143 03309-000 sao paulo 147 - parte sp vila gomes cardim
#
# Entities [('rua maria marcolina, 647', 'END_LOG')]
# sao paulo  sp bras 03011-001 rua maria marcolina, 647
#
# Entities [('r general glicerio, 419', 'END_LOG')]
# santo andre centro terreo - mpe santo andre r general glicerio, 419 sp 09015-190
#
# Entities [('av.goias, 414, esq.c/ruas 3 e 7, 2 andar', 'END_LOG')]
# go centro av.goias, 414, esq.c/ruas 3 e 7, 2 andar goiania  74563-220
#
# Entities [('rua marechal floriano, 58', 'END_LOG')]
# bento goncalves centro pav.superior rs 95700-000 rua marechal floriano, 58
#
# Entities [('rua octavio forghiere, 72', 'END_LOG')]
# sala 41 - edificio city hall rua octavio forghiere, 72 guarulhos jardim gumercindo sp 07090-070
#
# Entities [('av.n.sra.de copacabana,1292', 'END_LOG')]
# av.n.sra.de copacabana,1292 copacabana  rio de janeiro 22070-012 rj
#
# Entities [('av. tocantis, 58', 'END_LOG')]
# centro uruacu 76400-000 go  av. tocantis, 58
#
# Entities [('rua quatorze de julho, 1198', 'END_LOG')]
# vila gomes 13870-684 sao joao da boa vista rua quatorze de julho, 1198  sp
#
# Entities [('rua leopoldina salgado, 251', 'END_LOG')]
# ceres rua leopoldina salgado, 251 76300-000 centro go
#
# Entities [('pca.joao pastorinho de assuncao s/n.', 'END_LOG')]
# centro  45465-000 ba teolandia pca.joao pastorinho de assuncao s/n.
#
# Entities [('rua baraldi, 1.002', 'END_LOG')]
# parte centro rua baraldi, 1.002 09510-005 sao caetano do sul sp
#
# Entities [('avenida parana', 'END_LOG')]
# pr  jaguapita avenida parana 86610-000 centro
#
# Entities [('avenida rio branco,', 'END_LOG')]
# rj centro salas 908, 909, 910 e 911 avenida rio branco, rio de janeiro 20040-005
#
# Entities [('av. antonio batista arantes, qd. 23', 'END_LOG')]
# centro av. antonio batista arantes, qd. 23 piracanjuba 75640-000 go lote 269
#
# Entities [('rua tiradentes, 42', 'END_LOG')]
# itabira centro rua tiradentes, 42 mg 35900-013
#
# Entities [('av.rodoviaria, 1238', 'END_LOG')]
# centro av.rodoviaria, 1238 65470-000 ma  sao mateus do maranhao
#
# Entities [('rua espirito santo, 1176', 'END_LOG')]
# mg centro  rua espirito santo, 1176 belo horizonte 30160-031
#
# Entities [('rua sinimbu', 'END_LOG')]
# rua sinimbu 95020-000 nossa senhora de lourdes caxias do sul rs salas 01, 02
#
# Entities [('r.minas gerais,1305', 'END_LOG')]
# r.minas gerais,1305  centro ms 79490-000 sao gabriel do oeste
#
# Entities [('av. desembargador mario da silva nunes,', 'END_LOG')]
# jardim limoeiro jardim limoeiro av. desembargador mario da silva nunes, es serra 29164-044
#
# Entities [('rua oswaldo cruz', 'END_LOG')]
# ce  centro itapipoca rua oswaldo cruz 62500-000
#
# Entities [('praa dr. jos sacramento e silva, 64', 'END_LOG')]
# praa dr. jos sacramento e silva, 64 porto feliz centro 18540-000 sp
#
# Entities [('avenida paulista, 1111 - 2 andar (parte)', 'END_LOG')]
# bela vista  avenida paulista, 1111 - 2 andar (parte) 13119-200 sao paulo sp
#
# Entities [('av gov. agamenon magalhaes, 153', 'END_LOG')]
# pe recife 50110-900  av gov. agamenon magalhaes, 153 santo amaro
#
# Entities [('av.sen.joaquim miguel siqueira,25', 'END_LOG')]
# 12327-695 centro  sp av.sen.joaquim miguel siqueira,25 jacarei
#
# Entities [('s. hospitalar oeste,', 'END_LOG')]
# 73310-000 s. hospitalar oeste, av. wl4, rea especial df brasilia (planaltina)
#
# Entities [('av.prof.alfonso bovero, 1333', 'END_LOG')]
# vila pompeia sao paulo 05019-011 av.prof.alfonso bovero, 1333 pavimento superior sp
#
# Entities [('pc padre joao menendes,', 'END_LOG')]
# 08970-000 sp salesopolis centro pc padre joao menendes,
#
# Entities [('rua barao de alagoas, 23', 'END_LOG')]
# al 57160-000 centro rua barao de alagoas, 23 marechal deodoro
#
# Entities [('rua tenente jung 366', 'END_LOG')]
# rua tenente jung 366 rs 2 andar, sala 4 santo cristo 98960-000 centro
#
# Entities [('r.da assembleia,98', 'END_LOG')]
# rj r.da assembleia,98 20011-970 rio de janeiro centro loja,sobreloja e subsolo
#
# Entities [('rua marechal deodoro,240', 'END_LOG')]
# rua marechal deodoro,240  curitiba pr centro 80010-010
#
# Entities [('av paes de barros, 2621', 'END_LOG')]
# prq mooca av paes de barros, 2621 03149-100 sp  sao paulo
#
# Entities [('av. prudente de morais, 3488', 'END_LOG')]
# av. prudente de morais, 3488 natal 59054-700 lagoa nova parte rn
#
# Entities [('av.abilon de souza naves,641', 'END_LOG')]
# 85400-000 pr centro av.abilon de souza naves,641  guaraniacu
#
# Entities [('rua pref mariano procopio de araujo', 'END_LOG')]
# carvalho, 39 sp rua pref mariano procopio de araujo 11630-000 pereque ilhabela
#
# Entities [('praca dr. anisio jose moreira, 22-31', 'END_LOG')]
# praca dr. anisio jose moreira, 22-31 mirassol  sp centro 15130-000
#
# Entities [('r eng trindade, 99', 'END_LOG')]
# lj a r eng trindade, 99 rio de janeiro campo grande 23050-290 rj
#
# Entities [('rua fernando correa da costa, 495', 'END_LOG')]
# rua fernando correa da costa, 495  centro rondonopolis 78740-000 mt
#
# Entities [('rua dos guaranis, 504', 'END_LOG')]
# mg centro 30120-040 5 andar rua dos guaranis, 504 belo horizonte
#
# Entities [('rua conselheiro crispiniano,64', 'END_LOG')]
# sao paulo sp centro  10370-000 rua conselheiro crispiniano,64
#
# Entities [('av.brigadeiro faria lima', 'END_LOG')]
# jardim paulistano  av.brigadeiro faria lima sp 01452-002 sao paulo
#
# Entities [('av.padre jorge summerer', 'END_LOG')]
# centro 19500-000 sp  martinopolis av.padre jorge summerer
#
# Entities [('av. sete de setembro, 1544', 'END_LOG')]
# 07064-002 vila galvao sp guarulhos  av. sete de setembro, 1544
#
# Entities [('av. joao wallig,', 'END_LOG')]
# porto alegre passo d'areia rs av. joao wallig, loja 1255 91349-900
#
# Entities [('avenida sapopemba, 13.486', 'END_LOG')]
# so mateus avenida sapopemba, 13.486  sao paulo 03989-010 sp
#
# Entities [('rua 3, 1625', 'END_LOG')]
# 77690-000 to rua 3, 1625 colinas do tocantins centro
#
# Entities [('rua benedito do vale, s/n', 'END_LOG')]
# medicilandia pa  68145-000 centro rua benedito do vale, s/n
#
# Entities [('r.pinheiro machado,1079', 'END_LOG')]
# 98010-750 centro  rs cruz alta r.pinheiro machado,1079
# Entities [('rua artur bernardes, 210', 'END_LOG')]
# campo belo rua artur bernardes, 210 37270-000 mg  centro
#
# Entities []
# 83704-580 araucaria r irma elizabeth werka 88 pr fazenda velha
#
# Entities [('rua 24 de outubro, 1025 e 1031', 'END_LOG')]
# 90510-003  porto alegre rs rua 24 de outubro, 1025 e 1031 moinhos de vento
#
# Entities [('rua manoel matheus, 169', 'END_LOG')]
# 13280-000 sp rua manoel matheus, 169 centro  vinhedo
#
# Entities [('av.sete de setembro,645', 'END_LOG')]
# centro 75610-000 av.sete de setembro,645 go joviania
#
# Entities [('praa antonio mouro guimares, 222', 'END_LOG')]
# praa antonio mouro guimares, 222 mg contagem 32210-170 subsolo - loja e 1 andar - parte cidade industrial
#
# Entities [('r dr thibau', 'END_LOG')]
# nova iguacu rj centro 26255-160 0153 / 0161 / 0163 r dr thibau
#
# Entities [('av.ataulfo de paiva,980', 'END_LOG')]
# leblon 22440-035 av.ataulfo de paiva,980 rio de janeiro  rj
#
# Entities [('av. brasil, 2668', 'END_LOG')]
# 69036-110 manaus compensa am  av. brasil, 2668
#
# Entities [('rod br-316,s/n', 'END_LOG')]
# km 0 lote 1/10 castanheira 66645-000 pa belem rod br-316,s/n
#
# Entities [('av dr joao guilhermino, 46', 'END_LOG')]
# sp av dr joao guilhermino, 46 sao jose dos campos centro  12210-130
#
# Entities [('av. presidente vargas, 672', 'END_LOG')]
# camaqua av. presidente vargas, 672  centro rs 96180-000
#
# Entities [('rua presidente vargas, 288', 'END_LOG')]
# centro 35460-000 rua presidente vargas, 288  brumadinho mg
#
# Entities [('praa prefeito jos maurcio, 364', 'END_LOG')]
# praa prefeito jos maurcio, 364 76490-000 mara rosa go  centro
#
# Entities [('av.pres.vargas,1', 'END_LOG')]
# 68570-000 pa  av.pres.vargas,1 centro sao geraldo do araguaia
#
# Entities [('av. adolfo rodrigues, 850', 'END_LOG')]
# nova granada  sp 15440-000 centro av. adolfo rodrigues, 850
#
# Entities [('pca.sao jose,111', 'END_LOG')]
# ba centro gandu pca.sao jose,111  45450-000
#
# Entities [('av independencia, 841', 'END_LOG')]
# av independencia, 841  jardim independencia 13031-001 taubate sp
#
# Entities [('av. guapira, 2460', 'END_LOG')]
# sao paulo 02265-002 sp jacana  av. guapira, 2460
#
# Entities [('av. vol. fernando p. franco, 472', 'END_LOG')]
# 08710-500  av. vol. fernando p. franco, 472 centro sp mogi das cruzes
#
# Entities [('av.brasil, 1122', 'END_LOG')]
# jardim america 01430-001 pavimento terreo sao paulo sp av.brasil, 1122
#
# Entities [('praa pres. getulio vargas, 76', 'END_LOG')]
# centro rj praa pres. getulio vargas, 76  nova friburgo 28610-175
#
# Entities [('r oswaldo cruz,328', 'END_LOG')]
# soledade  50050-220 pe r oswaldo cruz,328 recife
#
# Entities [('av.mal.cordeiro de farias,855', 'END_LOG')]
# centro av.mal.cordeiro de farias,855 coelho neto 65620-000 ma
#
# Entities [('av.porto alegre,980', 'END_LOG')]
# centro 99965-000 agua santa av.porto alegre,980  rs
#
# Entities [('rua sete de setembro, 1445', 'END_LOG')]
# centro pr  rua sete de setembro, 1445 manoel ribas 85260-000
#
# Entities [('av doutor nilo peanha, n 2900', 'END_LOG')]
# andar 10 e 11 conj 1001 a 1004 conj 1101 a 1104 91330-001 chacara das pedras av doutor nilo peanha, n 2900 porto alegre rs
#
# Entities [('av. vinte e oito de maro, 96', 'END_LOG')]
# av. vinte e oito de maro, 96  28020-740 rj centro campos dos goytacazes
#
# Entities [('av soledade', 'END_LOG')]
# 90470-340 11. andar petropolis porto alegre rs av soledade
#
# Entities [('avenida duque de caxias 344', 'END_LOG')]
# fragata pelotas 96030-002 9 batalho de infantaria motorizado rs avenida duque de caxias 344
#
# Entities [('av.jorge amado,975', 'END_LOG')]
# jardins se 49025-330  aracaju av.jorge amado,975
#
# Entities [('av.ataulfo de paiva, 802-loja e loja a', 'END_LOG')]
# av.ataulfo de paiva, 802-loja e loja a rio de janeiro  leblon 22440-032 rj
#
# Entities [('av ver. abel ferreira, 110', 'END_LOG')]
# vila regente feijo  sao paulo av ver. abel ferreira, 110 00334-000 sp
#
# Entities [('rua general osorio, 898', 'END_LOG')]
# centro  rua general osorio, 898 96600-000 rs cangucu
#
# Entities [('av. paulista, 1159, loja i', 'END_LOG')]
# sp 01311-200  av. paulista, 1159, loja i sao paulo b. vista
#
# Entities [('av ipiranga, 67', 'END_LOG')]
# 81 s loja av ipiranga, 67 sao paulo sp republica 01046-010
#
# Entities [('rua major pompeu, 425', 'END_LOG')]
# 17340-000 centro  sp barra bonita rua major pompeu, 425
#
# Entities [('rua amador bueno', 'END_LOG')]
# terreo santo amaro 04752-901 rua amador bueno sao paulo sp
#
# Entities [('av.rodolfo baldi, 1006', 'END_LOG')]
# av.rodolfo baldi, 1006 15880-000 tabapua sp  centro
#
# Entities [('rua benicio freire, 44', 'END_LOG')]
# 49290-000 se centro rua benicio freire, 44 itabaianinha
#
# Entities [('rua  paulo emanuel de almeida', 'END_LOG')]
# rua  paulo emanuel de almeida sp  18053-505 wanel ville sorocaba
#
# Entities [('avenida repblica do lbano', 'END_LOG')]
# bairro do pina 51110-160 pe recife avenida repblica do lbano torre c, sala 1707
#
# Entities [('pca.do mercado,s/n', 'END_LOG')]
# 46438-000 ba predio centro iuiu pca.do mercado,s/n
#
# Entities [('av.rotary internacional 629', 'END_LOG')]
# av.rotary internacional 629 centro 78365-000 sapezal mt
#
# Entities [('av. bernardo vieira de melo, 4152-a', 'END_LOG')]
# jaboatao dos guararapes 54420-010 pe piedade av. bernardo vieira de melo, 4152-a
#
# Entities [('avenida  e,  esq. c/rua 72  n 2', 'END_LOG')]
# 75890-000 centro avenida  e,  esq. c/rua 72  n 2 sao simao go
#
# Entities [('r.gov.brasil caiado,817', 'END_LOG')]
# centro r.gov.brasil caiado,817 arapoema  to 77780-000
#
# Entities [('rua artur bernardes, 210', 'END_LOG')]
# mg 37270-000 rua artur bernardes, 210  centro campo belo
#
# Entities [('av pres juscelino kubitschek,2041', 'END_LOG')]
# 04543-011 vila nova conceicao sp av pres juscelino kubitschek,2041  sao paulo
#
# Entities [('rua manoel cicero de lima, 95', 'END_LOG')]
# centro 59200-000  rua manoel cicero de lima, 95 rn santa cruz
#
# Entities [('r goncalves ledo', 'END_LOG')]
# ce pl g-a centro 60110-261 r goncalves ledo fortaleza
#
# Entities [('rua treze de maio', 'END_LOG')]
# rua treze de maio 13720-000 sao jose do rio pardo sp centro
#
# Entities [('estrada engenho da pedra 1727', 'END_LOG')]
# rio de janeiro rj 20550-013  olaria estrada engenho da pedra 1727
#
# Entities [('pca.nossa senhora da guia, 1', 'END_LOG')]
# rj 23860-000 centro mangaratiba pca.nossa senhora da guia, 1
#
# Entities [('rua capitao joao ramos, 120', 'END_LOG')]
# centro 12281-520 sp rua capitao joao ramos, 120 cacapava
#
# Entities [('rua sete de setembro, 3500, loja 203', 'END_LOG')]
# governador valadares  mg rua sete de setembro, 3500, loja 203 centro 35010-173
#
# Entities [('r.dr.jose torquato,327', 'END_LOG')]
# sao miguel rn r.dr.jose torquato,327 terreo 59920-000 centro
#
# Entities [('avenida sete de setembro', 'END_LOG')]
# dois de julho  avenida sete de setembro 40060-001 salvador ba
#
# Entities [('rua tenente nicolau maffei, 286', 'END_LOG')]
# sp 19010-010 centro presidente prudente rua tenente nicolau maffei, 286 2 andar
#
# Entities [('av maranho 446', 'END_LOG')]
# 76450-000 av maranho 446 go  minacu centro
#
# Entities [('rua do catete, 228', 'END_LOG')]
# rio de janeiro rj 22220-001 laranjeiras rua do catete, 228 loja 117
#
# Entities [('av.bel.tomaz landim,100', 'END_LOG')]
# igapo 59104-000 rn av.bel.tomaz landim,100 natal
#
# Entities [('av. epitacio pessoa, 2760', 'END_LOG')]
# pb tambauzinho  58040-000 av. epitacio pessoa, 2760 joao pessoa
#
# Entities [('av. duque de caxias', 'END_LOG')]
# 21615-220 av. duque de caxias rj deodoro rio de janeiro
#
# Entities [('tv.vilhena alves,354', 'END_LOG')]
# prox.sec.de educacao centro 68780-000 tv.vilhena alves,354 vigia pa
#
# Entities [('av.das americas,3434', 'END_LOG')]
# rj av.das americas,3434 rio de janeiro 22640-102 bloco 3,loja 101 barra da tijuca
#
# Entities [('r.sao paulo,151', 'END_LOG')]
# r.sao paulo,151 mg 35500-006  centro divinopolis
#
# Entities [('avenida antonio nunes de souza', 'END_LOG')]
# avenida antonio nunes de souza  88845-000 cocal do sul sc centro
#
# Entities [('rua paulino correa da silva', 'END_LOG')]
# sala 01 97690-000 rua paulino correa da silva garruchos centro rs
#
# Entities [('rua tiradentes,', 'END_LOG')]
# contagem mg rua tiradentes,  32230-020 bairro industrial
#
# Entities [('av.w3, norte set.n, q 513, s.32', 'END_LOG')]
# brasilia 70380-570 df asa norte av.w3, norte set.n, q 513, s.32
#
# Entities [('av.dr.alberto de oliveira,85', 'END_LOG')]
# bonito 55680-000 av.dr.alberto de oliveira,85 pe centro
#
# Entities [('av.ibirapuera,1983', 'END_LOG')]
# sao paulo indianopolis  av.ibirapuera,1983 04029-100 sp
#
# Entities [('av.mal.rondon, esq.c/rua joao pessoa', 'END_LOG')]
# guiratinga  av.mal.rondon, esq.c/rua joao pessoa 78760-000 mt centro
#
# Entities [('avenida rotary, 383', 'END_LOG')]
# rj  sao joao da barra avenida rotary, 383 centro 28200-000
#
# Entities [('av.conselheiro aguiar, 2159, 1 pavimento', 'END_LOG')]
# pe boa viagem av.conselheiro aguiar, 2159, 1 pavimento 51111-011  recife
#
# Entities [('av rio das pedras', 'END_LOG')]
# sao paulo 03453-100 sp av rio das pedras 1889 jardim aricanduva
#
# Entities [('r padre justino cortegens,255', 'END_LOG')]
# r padre justino cortegens,255 jd c florianopolis sao jose sc 88111-150
#
# Entities [('av brasil', 'END_LOG')]
# 78530-000 centro mt av brasil peixoto de azevedo
#
# Entities [('praca hercilio luz, 5', 'END_LOG')]
# sc mafra 89300-000 praca hercilio luz, 5 centro
#
# Entities [('praa coronel antnio lopes, 25', 'END_LOG')]
# mg 39848-000 centro  sao jose do divino praa coronel antnio lopes, 25
#
# Entities [('rua olavo bilac, 514', 'END_LOG')]
# centro 16400-000 sp  rua olavo bilac, 514 lins
#
# Entities [('rua jose maria passos', 'END_LOG')]
# rua jose maria passos palmeira dos indios al centr0 57600-030
#
# Entities [('av presidente vargas', 'END_LOG')]
# rio de janeiro 20091-060 rj av presidente vargas centro
#
# Entities [('praa padre miguel, 163 - parte', 'END_LOG')]
# itu centro praa padre miguel, 163 - parte 13300-169  sp
#
# Entities [('r.rockefeller,651', 'END_LOG')]
# pr r.rockefeller,651  curitiba 80230-130 reboucas
#
# Entities [('av.gal.afonso albuquerque lima,s/n', 'END_LOG')]
# 60822-325 cambeba av.gal.afonso albuquerque lima,s/n ce  fortaleza
#
# Entities [('av. coronel carneiro junior, 326', 'END_LOG')]
# mg 37500-018 itajuba centro  av. coronel carneiro junior, 326
#
# Entities [('rua bento francisco ramos, 90', 'END_LOG')]
# rua bento francisco ramos, 90 quissama centro 28735-000 rj
# Entities [('sain bl. f', 'END_LOG')]
# sain bl. f 70620-000  df brasilia ed. sede terracap
#
# Entities [('av. monsenhor eduardo, 2.111', 'END_LOG')]
# e rua guapore, 88 38401-239 mg uberlandia santa rosa av. monsenhor eduardo, 2.111
#
# Entities [('avenida so paulo', 'END_LOG')]
# sp cidade so jorge 09111-410 santo andre avenida so paulo
#
# Entities [('av dos imigrantes sn esq c rua dr freita', 'END_LOG')]
# 12902-000 braganca paulista centro  av dos imigrantes sn esq c rua dr freita sp
#
# Entities [('avenida anhanguera q-61 lt- 83e n 4463', 'END_LOG')]
# goiania go 74043-011  setor central avenida anhanguera q-61 lt- 83e n 4463
#
# Entities [('av. getlio vargas, 110', 'END_LOG')]
# 86820-000 california pr centro av. getlio vargas, 110
#
# Entities [('avenida brasil', 'END_LOG')]
# avenida brasil centro  pr paranacity 87660-000
#
# Entities [('av.sao joao, esq. com av.pereira campos', 'END_LOG')]
# av.sao joao, esq. com av.pereira campos jacarei sao joao sp 12322-000
#
# Entities [('avenida independencia, 1850', 'END_LOG')]
# 14025-230 avenida independencia, 1850 ribeirao preto sp alto da boa vista
#
# Entities [('rod augusto montenegro,', 'END_LOG')]
# pa  parque verde belem 66635-110 rod augusto montenegro,
#
# Entities [('avenida weimar goncalves torres', 'END_LOG')]
# ms avenida weimar goncalves torres navirai centro 79950-000
#
# Entities [('av. estados unidos, 14', 'END_LOG')]
# 40010-020 av. estados unidos, 14 salvador centro ba
#
# Entities [('av tocantins q 16', 'END_LOG')]
# centro 72975-000 cocalzinho de goias av tocantins q 16  go
#
# Entities [('av. cincinato pinto, 53', 'END_LOG')]
# maceio 57020-050 al av. cincinato pinto, 53 centro
#
# Entities [('praca jose henrique pereira, 150', 'END_LOG')]
# centro es marechal floriano  praca jose henrique pereira, 150 29255-000
#
# Entities [('pca.dom epaminondas,84', 'END_LOG')]
# 3.andar centro taubate pca.dom epaminondas,84 12010-020 sp
#
# Entities [('via anchieta, 900', 'END_LOG')]
# 04246-000 sp sacoma via anchieta, 900 sao paulo
#
# Entities [('av.dorival caymmi,1120', 'END_LOG')]
# av.dorival caymmi,1120 41635-150 salvador itapua ba
#
# Entities [('av. cavalhada', 'END_LOG')]
# cavalhada 91740-001 porto alegre av. cavalhada rs
#
# Entities [('avenida praia de itapoan', 'END_LOG')]
# avenida praia de itapoan ba vilas do atlntico lote 02,03, 59 e 60 42700-000 lauro de freitas
#
# Entities [('palcio costa e silva, trreo,', 'END_LOG')]
# df 70075-901 praa do buriti  brasilia palcio costa e silva, trreo,
#
# Entities [('rua marechal deodoro, 64', 'END_LOG')]
# sp aracatuba 1 and centro 16010-300 rua marechal deodoro, 64
#
# Entities [('av parana,', 'END_LOG')]
# 86610-000 av parana, centro  pr jaguapita
#
# Entities [('rua rafael langoni, 82', 'END_LOG')]
# sapucaia rj 25880-000  centro rua rafael langoni, 82
#
# Entities [('av. sibipiruna, lotes 13,15,17 e 21', 'END_LOG')]
# brasilia (aguas claras) av. sibipiruna, lotes 13,15,17 e 21 00000-000  df
#
# Entities [('av pres.costa e silva', 'END_LOG')]
# mg so pedro  av pres.costa e silva juiz de fora 36037-000
#
# Entities [('av. governador portela, 158', 'END_LOG')]
# rj  centro av. governador portela, 158 27123-000 barra do pirai
#
# Entities [('r alexandre dumas, 1.671', 'END_LOG')]
# r alexandre dumas, 1.671 ch sto antonio (z sul) ala a, trreo sao paulo 04717-004 sp
#
# Entities [('r.euclides da cunha,525', 'END_LOG')]
# 79020-230 jd estados  r.euclides da cunha,525 ms campo grande
#
# Entities [('av. sumare, n. 1130', 'END_LOG')]
# sp 10000-000 perdizes  av. sumare, n. 1130 sao paulo
#
# Entities [('av. ana costa,  481', 'END_LOG')]
# sp  gonzaga 11060-003 av. ana costa,  481 santos
#
# Entities [('avenida sebastio coelho de souza, 73', 'END_LOG')]
# 29820-000 centro es agua doce do norte avenida sebastio coelho de souza, 73
#
# Entities [('rua sao paulo,1365', 'END_LOG')]
# centro  rua sao paulo,1365 15670-000 populina sp
#
# Entities [('rua augusto de vasconcelos, 254', 'END_LOG')]
# rj 254 - fundos rio de janeiro 23050-340 rua augusto de vasconcelos, 254 campo grande
#
# Entities [('espl ministerios - ed. emfa', 'END_LOG')]
# espl ministerios - ed. emfa 70049-900 brasilia espl ministerios  df
#
# Entities [('rua marcilio dias, 2875', 'END_LOG')]
# rua marcilio dias, 2875 santo antonio 89204-002 sc sl 01 e sl 02 joinville
#
# Entities [('rua cap augusto de almeida, 440', 'END_LOG')]
# 14735-000 centro severinia rua cap augusto de almeida, 440 sp
#
# Entities [('avenida coronel antonino', 'END_LOG')]
# 79010-000 ms coronel antonino campo grande avenida coronel antonino quadra 13 lote 4b
#
# Entities [('rua armando de barros, 633', 'END_LOG')]
# sp centro  rua armando de barros, 633 botucatu 18600-050
#
# Entities [('av. ten. laudelino f. do amaral, 559', 'END_LOG')]
# sao paulo sp vila jacui  08060-000 av. ten. laudelino f. do amaral, 559
#
# Entities [('av. dr. cristiano guimares, 1691', 'END_LOG')]
# 31720-300  planalto belo horizonte mg av. dr. cristiano guimares, 1691
#
# Entities [('avenida dom pedro i,  3336', 'END_LOG')]
# sp vila pires santo andre 09130-400 avenida dom pedro i,  3336
#
# ...
#
# Entities [('av. prof carmem carneiro, 316', 'END_LOG')]
# av. prof carmem carneiro, 316 rj  28080-425 pq. jardim carioca campos dos goytacazes
#
# Entities [('av das flores', 'END_LOG')]
# 78043-172 av das flores jd cuiaba mt ed. sb medical & business center - 9. andar cuiaba
#
# Entities [('scs-b, quadra 9, lote c', 'END_LOG')]
# parque da cidade df scs-b, quadra 9, lote c 70308-200 torre c, sala 1104, ed. parque da cidade corporate brasilia
#
# Entities [('rua francisco ferreira alves, 190', 'END_LOG')]
# sp conchal  13810-000 centro rua francisco ferreira alves, 190
#
# Entities [('rua visconde de piraja', 'END_LOG')]
# rj rio de janeiro lj rua visconde de piraja 22410-001 ipanema
#
# Entities [('av conde francisco matarazzo ,s/n', 'END_LOG')]
# sao caetano do sul fundacao 09520-120 av conde francisco matarazzo ,s/n sp
#
# Entities [('avenida ministro geraldo barreto sobral,', 'END_LOG')]
# aracaju grageru salas 1206 e 1207 - centro emp. jfc trade center 49027-255 se avenida ministro geraldo barreto sobral,
#
# Entities [('rua osvaldo aranha, 1209', 'END_LOG')]
# rs venancio aires 95800-000  rua osvaldo aranha, 1209 centro
#
# Entities [('estrada rio so paulo, 4.000', 'END_LOG')]
# estrada rio so paulo, 4.000 26250-570 nova iguacu rj parque todos os santos
#
# Entities [('pca.dr.henrique sampaio,150', 'END_LOG')]
# 45745-000 pca.dr.henrique sampaio,150 ibicarai ba centro
#
# Entities [('av.gov.magalhaes barata, 554', 'END_LOG')]
# sao bras  pa belem 66060-281 av.gov.magalhaes barata, 554
#
# Entities [('av. brig. faria lima, 2491', 'END_LOG')]
# av. brig. faria lima, 2491 sp j paulistano sao paulo  01452-000
#
# Entities [('rua nicola pelanda, 4775', 'END_LOG')]
# rua nicola pelanda, 4775 pr umbara  81940-000 curitiba
# Entities [('r prof francisco fonseca, 88', 'END_LOG')]
# lj 1  rj saquarema r prof francisco fonseca, 88 28990-000
#
# Entities [('av.pres.vargas,1047', 'END_LOG')]
# rs 98580-000 coronel bicaco centro  av.pres.vargas,1047
#
# Entities [('av governador pedro de toledo,1099', 'END_LOG')]
# 13070-751 bonfim sp av governador pedro de toledo,1099 complexo do bonfim - 4.andar campinas
#
# Entities [('r.barao do rio branco,1321', 'END_LOG')]
# 60025-061 terreo r.barao do rio branco,1321 centro fortaleza ce
#
# Entities [('rua manoel machado borges, 146', 'END_LOG')]
# rua manoel machado borges, 146  75950-000 jandaia centro go
#
# Entities [('av. herculano bandeira, 749', 'END_LOG')]
# av. herculano bandeira, 749 recife 51110-131 pe pina
#
# Entities [('rua bocaiva, n 1600', 'END_LOG')]
# 88015-530 rua bocaiva, n 1600 sc centro  florianopolis
#
# Entities [('rua do acar, 363', 'END_LOG')]
# 13454-178 santa barbara d'oeste  rua do acar, 363 sp jardim prola
#
# Entities [('av washington luis', 'END_LOG')]
# 04627-005 sao paulo av washington luis sp  santo amaro
#
# Entities [('rua silva bueno, 1319', 'END_LOG')]
# sp ipiranga  rua silva bueno, 1319 sao paulo 04208-501
#
# Entities [('av. guarda mor lobo viana, 153', 'END_LOG')]
# sp av. guarda mor lobo viana, 153 centro  11600-000 sao sebastiao
#
# Entities [('rua filinto muller,885', 'END_LOG')]
# ms rua filinto muller,885  centro coxim 79400-000
#
# Entities [('r.do livramento,120', 'END_LOG')]
# do subsolo ao 3.andar 57020-913 centro r.do livramento,120 maceio al
#
# Entities [('rua pedro manvailler n 3809, quadra c l', 'END_LOG')]
# 79990-970  amambai rua pedro manvailler n 3809, quadra c l ms centro
#
# Entities [('rua coronel honorio palma, 408', 'END_LOG')]
# rua coronel honorio palma, 408 centro sp 14350-000 altinopolis
#
# Entities [('av governador rondon pacheco, 4671', 'END_LOG')]
# 38400-766 conjunto bandeirantes av governador rondon pacheco, 4671 mg uberlandia loja 01
#
# Entities [('rua coronel antonio fernandes, 207', 'END_LOG')]
# inhapim rua coronel antonio fernandes, 207 35330-000  mg centro
#
# Entities [('r. florianpolis, 191', 'END_LOG')]
# 88200-000  sc centro tijucas r. florianpolis, 191
#
# Entities [('av do forte 1763', 'END_LOG')]
# porto alegre rs av do forte 1763 91360-001 vila ipiranga
#
# Entities [('av gov. bias fortes,', 'END_LOG')]
# mg 36204-168 av gov. bias fortes, caminho novo  barbacena
#
# Entities [('rua augusto de vasconcelos, n 239', 'END_LOG')]
# rio de janeiro rj campo grande 23050-340 rua augusto de vasconcelos, n 239 parte
#
# Entities [('rua da consolacao, 2411 - 2.andar', 'END_LOG')]
# sp  13011-000 rua da consolacao, 2411 - 2.andar sao paulo consolacao
#
# Entities [('rua novo hamburgo, 610', 'END_LOG')]
# rua novo hamburgo, 610  portao 93180-000 centro rs
#
# Entities []
# 01310-200 sao paulo av. paulista, 2300, conjunto 42, 4 anda sp
#
# Entities [('av. jos tozzi, 1.779', 'END_LOG')]
# centro sao mateus 29930-245 es av. jos tozzi, 1.779
#
# Entities [('r.halfeld', 'END_LOG')]
# centro juiz de fora 4.andar 36010-003 r.halfeld mg
#
# Entities [('av. getulio vargas, 5375', 'END_LOG')]
# mg joao monlevade centro av. getulio vargas, 5375 35930-000
#
# Entities [('praca raul leme, 190', 'END_LOG')]
# praca raul leme, 190 centro 12900-000  braganca paulista sp
#
# Entities [('av.general pedro pinho,641', 'END_LOG')]
# 06180-180 pestana 1.andar av.general pedro pinho,641 osasco sp
#
# Entities [('rua baro de mau', 'END_LOG')]
# maua rua baro de mau  jardim maring sp 09340-440
#
# Entities [('rua voluntarios da patria, 2225 e 2229', 'END_LOG')]
# sp santana rua voluntarios da patria, 2225 e 2229 sao paulo 02011-500
#
# Entities [('r.climaco barbosa,63', 'END_LOG')]
# sp sao paulo  r.climaco barbosa,63 01523-000 cambuci
#
# Entities [('rua geovani marinho de melo, 323', 'END_LOG')]
# joao pessoa anexo - parte 58056-350 pb mangabeira rua geovani marinho de melo, 323
#
# Entities [('r dr curvelo cavalcante', 'END_LOG')]
# rj  centro 23810-200 r dr curvelo cavalcante itaguai
#
# Entities [('av.euclides da cunha, 365', 'END_LOG')]
# graca 40150-120 salvador ba av.euclides da cunha, 365
#
# Entities [('rua leopoldo couto de magalhes jr.', 'END_LOG')]
# 04542-000 rua leopoldo couto de magalhes jr. sp sao paulo itaim bibi 16 (parte), 17 e 18 (parte) andares
#
# Entities [('avenida john boyd dunlop, 350', 'END_LOG')]
# campinas jardim pauliceia  avenida john boyd dunlop, 350 sp 13060-803
#
# Entities [('av. imbassay, 31 - centro', 'END_LOG')]
# dias d'avila  centro ba av. imbassay, 31 - centro 42850-000
#
# Entities [('av. getlio vargas, 303', 'END_LOG')]
# av. getlio vargas, 303 centro  feira de santana ba 44001-525
#
# Entities [('av.otacilio vieira campos,41', 'END_LOG')]
# santa margarida av.otacilio vieira campos,41 centro 36910-000  mg
#
# Entities [('rua felipe dos santos, 519', 'END_LOG')]
# lourdes belo horizonte rua felipe dos santos, 519 30180-160 mg 60746948
#
# Entities [('setor de habit.coletiv. sul com. resid.', 'END_LOG')]
# setor de habit.coletiv. sul com. resid. asa sul brasilia df 70350-535 qd 506 - bl c - lj 33
#
# Entities [('rua 10 de abril, 128', 'END_LOG')]
# 11800-000 centro sp  juquia rua 10 de abril, 128
#
# Entities [('rua da assembleia', 'END_LOG')]
# rio de janeiro 20011-000 rj 66, loja a rua da assembleia centro
#
# Entities [('lgo.sete setembro,s/n', 'END_LOG')]
# sp lgo.sete setembro,s/n se  sao paulo 01501-050
#
# Entities [('av.imperatriz leopoldina - 201', 'END_LOG')]
# sp 05305-010 sao paulo  vila hambuuguesa av.imperatriz leopoldina - 201
#
# Entities [('av. coronel victor dumoncel', 'END_LOG')]
# rs santa barbara do sul 98240-000 centro  av. coronel victor dumoncel
#
# Entities [('rua tutia, 1160', 'END_LOG')]
# sp paraiso rua tutia, 1160 sao paulo 04007-005
#
# Entities [('pca joaquim carlos garcia, 354', 'END_LOG')]
# pca joaquim carlos garcia, 354 sp centro altair 15430-000
#
# Entities [('rua cumaru', 'END_LOG')]
# loteamento alphaville campinas rua cumaru 13098-324 lote g2-17 sp campinas
#
# Entities [('av.bertino warmling,995', 'END_LOG')]
# 85670-000 salto do lontra centro  av.bertino warmling,995 pr
#
# Entities [('rua padre miguelinho, 80 - 10. andar', 'END_LOG')]
# 88010-550  sc rua padre miguelinho, 80 - 10. andar florianopolis centro
#
# Entities [('av.jose rodrigues naves', 'END_LOG')]
# vila padre pelagio goianira 75370-000 av.jose rodrigues naves quadra 8, lote 1, salas 2 e 3 go
#
# Entities [('seup/norte, quadra 513, bloco d, n.30', 'END_LOG')]
# brasilia seup/norte, quadra 513, bloco d, n.30 asa norte df 70760-530
#
# Entities [('praca santos dumont,3999', 'END_LOG')]
# centro umuarama pr praca santos dumont,3999  87501-260
#
# Entities [('av saturnino rangel mauro, n 900', 'END_LOG')]
# vila velha 29102-034  av saturnino rangel mauro, n 900  itaparica es
#
# Entities [('av.barros reis, 3029', 'END_LOG')]
# av.barros reis, 3029 ba salvador 40310-010 pau miudo
#
# Entities [('rua benedito valadares, 272', 'END_LOG')]
# mg  rua benedito valadares, 272 35290-000 centro mantena
#
# Entities [('r.galvao bueno,218', 'END_LOG')]
# 01506-000  liberdade sp sao paulo r.galvao bueno,218
#
# Entities [('av.albino de almeida,182', 'END_LOG')]
# campos eliseos  rj av.albino de almeida,182 resende 27542-070
#
# Entities [('av.noel nutels,1436', 'END_LOG')]
# manaus 69093-770 cidade nova i bloco 6,loja 1-a av.noel nutels,1436 am
#
# Entities [('av. ceci, 1850', 'END_LOG')]
# 06460-120 barueri tambor sp  av. ceci, 1850
#
# Entities [('av. vasco da gama, n 2.526', 'END_LOG')]
# ba 40286-000 av. vasco da gama, n 2.526 brotas salvador
#
# Entities [('r bento goncalves 516', 'END_LOG')]
# centro 5 andar 99010-010 r bento goncalves 516 passo fundo rs
#
# Entities [('rua nove', 'END_LOG')]
# rua nove primeiro de maio 86140-000 centro  pr
#
# Entities [('rua general furtado nascimento', 'END_LOG')]
# sp alto de pinheiros rua general furtado nascimento 05465-070 sao paulo lote 1 / sala 05
#
# Entities [('r.cel.jose freire,110', 'END_LOG')]
# 63460-000  centro r.cel.jose freire,110 pereiro ce
#
# Entities [('praca da republica, 1151', 'END_LOG')]
# sao simao centro  14200-000 sp praca da republica, 1151
#
# Entities [('rua sacramento, 70', 'END_LOG')]
# sp 12010-010  rua sacramento, 70 taubate centro
#
# Entities [('praca umbelina bueno, 275', 'END_LOG')]
# 13820-000 centro  jaguariuna praca umbelina bueno, 275 sp
#
# Entities [('rua vicente feliciano, 29', 'END_LOG')]
# 48890-000 valente ba  centro rua vicente feliciano, 29
#
# Entities [('r.cons.moreira de barros,569', 'END_LOG')]
# sao paulo r.cons.moreira de barros,569 sta.terezinha-santana sp 02018-011
#
# Entities [('rua ceara, 2061', 'END_LOG')]
# campo grande rua ceara, 2061 ms 79021-000 quadra 21 lote 12 santa fe
#
# Entities [('av. dom pedro ii', 'END_LOG')]
# av. dom pedro ii  ba eunapolis centro 45820-081
#
# Entities [('rua duque de caxias', 'END_LOG')]
# 99750-000 erval grande  rs  rua duque de caxias
#
# Entities [('pc da se, 111 and 5 sala 01', 'END_LOG')]
# se sao paulo 01001-001 sp  pc da se, 111 and 5 sala 01
#
# Entities [('av.brasil,1670', 'END_LOG')]
# balneario camboriu sc av.brasil,1670 centro 1.andar 88330-050
#
# Entities [('av.antonio j.de moura andrade,1400', 'END_LOG')]
# nova andradina av.antonio j.de moura andrade,1400 esq.c/r.prof.joao de lima paes centro 79750-000 ms
#
# Entities [('rua gustavo armbrust', 'END_LOG')]
# sp 13092-106 conjunto 501, ed. 575 norte sul rua gustavo armbrust campinas nova campinas
#
# Entities [('av.rio branco,134', 'END_LOG')]
# centro av.rio branco,134 rio de janeiro rj loja a,1 e 2ss,sl e 1,2 e 3pav. 20040-002
#
# Entities [('praca conego vitor, 203', 'END_LOG')]
# tres pontas centro 37190-000  praca conego vitor, 203 mg
#
# Entities [('r. roxo moreira, s/n', 'END_LOG')]
# sp campinas cidade universitaria  13083-590 r. roxo moreira, s/n
#
# Entities [('av. das araucarias 5126', 'END_LOG')]
# sala 6 araucaria pr 83707-000 thomaz coelho av. das araucarias 5126
#
# Entities [('av. jones dos santos neves', 'END_LOG')]
# es av. jones dos santos neves sernamby  sao mateus 29930-440
#
# Entities [('rua dr. getulio portela, 203', 'END_LOG')]
# rua dr. getulio portela, 203 campos altos centro mg 38970-000
#
# Entities [('av. 19 de agosto 433', 'END_LOG')]
# pr 87360-000 goioere centro  av. 19 de agosto 433
#
# Entities [('r.ernest renan,1366', 'END_LOG')]
# r.ernest renan,1366 sp sao paulo paraisopolis  05659-020
#
# Entities [('rua 31 de marco, 152', 'END_LOG')]
# 35180-028 timoteo mg rua 31 de marco, 152 centro
#
# Entities [('praa dr. alcides mosconi, 85', 'END_LOG')]
# mg 37795-000 praa dr. alcides mosconi, 85 centro andradas parte
#
# Entities [('avenida estados unidos', 'END_LOG')]
# 40010-906 salvador parte da loja 001, edif. cidade do salvador, ala a comrcio avenida estados unidos ba
#
# Entities [('av.presidente vargas,2344', 'END_LOG')]
# rs av.presidente vargas,2344 93260-005 esteio centro
#
# Entities [('r quinze de dezembro, 147', 'END_LOG')]
# go anapolis  75024-070 centro r quinze de dezembro, 147
#
# Entities [('av.automovel clube', 'END_LOG')]
# av.automovel clube 25565-172 lt 2 qd 9 sao joao de meriti rj jd jose bonifacio
#
# Entities [('avenida manoel bento da cruz', 'END_LOG')]
# 16300-000 sp penapolis  centro avenida manoel bento da cruz
#
# Entities [('rua dona balbina n 506', 'END_LOG')]
# centro porto ferreira 13660-000  sp rua dona balbina n 506
#
# Entities [('av presidente getulio vargas, 276', 'END_LOG')]
# centro mg santos dumont 1 andar 36240-000 av presidente getulio vargas, 276
#
# Entities [('r.frei elseario buffon,194', 'END_LOG')]
# terreo 84935-000 tomazina centro pr r.frei elseario buffon,194
#
# Entities [('pca.ruy barbosa,s/n', 'END_LOG')]
# centro 48430-000 ba pca.ruy barbosa,s/n paripiranga terreo
#
# Entities [('rua 15 de novembro', 'END_LOG')]
# 89010-000 blumenau centro rua 15 de novembro sala 27 sc
#
# Entities [('av.atlantica - 1620', 'END_LOG')]
# rio de janeiro rj av.atlantica - 1620  copacabana 22021-000
#
# Entities [('av.sete de setembro, 895/923', 'END_LOG')]
# 69005-140 av.sete de setembro, 895/923 centro am  manaus
# Entities [('avenida deputado borsari neto', 'END_LOG')]
# pr 87113-300 jardim independencia  sarandi avenida deputado borsari neto
#
# Entities [('av. t 07, quadra 41, lote 2, nr. 933', 'END_LOG')]
# 74210-265  go goiania setor bueno av. t 07, quadra 41, lote 2, nr. 933
#
# Entities [('rua baro do amazonas, 1253', 'END_LOG')]
# rs rua baro do amazonas, 1253 petrpolis porto alegre  90670-004
#
# Entities [('qd.1102 sul,av.teotonio segurado,s/n', 'END_LOG')]
# palmas plano diretor sul conj.1,lote 11 77024-002 qd.1102 sul,av.teotonio segurado,s/n to
#
# Entities [('rua prefeito wilson damiao, 120', 'END_LOG')]
# raul soares mg rua prefeito wilson damiao, 120  centro 35350-000
#
# Entities [('av. brigadeiro faria lima, 2668', 'END_LOG')]
# 01451-000 sao paulo sp  av. brigadeiro faria lima, 2668 jardim paulistano
#
# Entities [('av morumbi 7710', 'END_LOG')]
# santo amaro sp av morumbi 7710  04703-000 sao paulo
#
# Entities [('rua dom pedro ii', 'END_LOG')]
# rua dom pedro ii aracatuba sp  16010-470 centro
#
# Entities [('r.dr.hildebrando r.de moura,58', 'END_LOG')]
# sumidouro centro rj 28637-000  r.dr.hildebrando r.de moura,58
#
# Entities [('av. almirante barroso', 'END_LOG')]
# rj av. almirante barroso rio de janeiro 20031-918 centro 22 andar
#
# Entities [('av.brasilia, 630', 'END_LOG')]
# sp diadema 09931-400 campanario  av.brasilia, 630
#
# Entities [('rua fernandes tourinho', 'END_LOG')]
# rua fernandes tourinho 30112-000 funcionrios belo horizonte mg 13 andar
#
# Entities [('avenida das naes unidas', 'END_LOG')]
# brooklin 11 andar sp avenida das naes unidas 04578-000 sao paulo
#
# Entities [('rua julio de castilhos', 'END_LOG')]
# rs novo hamburgo 93510-130 centro  rua julio de castilhos
#
# Entities [('sdn conj. nac. brasilia', 'END_LOG')]
# df 70077-900 sdn conj. nac. brasilia asa norte brasilia lojas  98,99, 110 a 117 e 119
#
# Entities [('av. brigadeiro everaldo breves, 316', 'END_LOG')]
# av. brigadeiro everaldo breves, 316 59140-200 centro  rn parnamirim
#
# Entities [('av. tiradentes, 1200', 'END_LOG')]
# marilia sp  sao lucas 17519-000 av. tiradentes, 1200
#
# Entities [('rua coronel astriclinio', 'END_LOG')]
# pe palmares 55540-000  rua coronel astriclinio centro
#
# Entities [('av.ex-combatentes,s/n', 'END_LOG')]
# centro 47520-000 ibotirama  ba av.ex-combatentes,s/n
#
# Entities [('rua pimenta de padua, 957', 'END_LOG')]
# rua pimenta de padua, 957 centro sao sebastiao do paraiso mg 37950-000
#
# Entities [('avenida so geraldo', 'END_LOG')]
# centro 45000-480 avenida so geraldo  vitoria da conquista ba
#
# Entities [('av. presidente altino, 791', 'END_LOG')]
# 05323-001 sp jaguar  sao paulo av. presidente altino, 791
#
# Entities [('r mexico', 'END_LOG')]
# centro rj rio de janeiro r mexico loja e sobreloja esq c a  r santa luzia, 760 loja 20031-144

# %% [markdown]
# Frase qualquer

# %%
phrase = "SHVP Rua 12 435 casa 22 lote 1"

doc = nlp(phrase)
print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
print(phrase)
# Out:
# Entities [('Rua 12 435', 'END_LOG')]
# SHVP Rua 12 435 casa 22 lote 1
