# %%
# Load Packages
from __future__ import unicode_literals, print_function

import plac #  wrapper over argparse
import random
from pathlib import Path
import spacy
from tqdm import tqdm, tqdm_notebook # loading bar 
import pandas as pd
import re
from pprint import pprint
from nltk.tokenize import sent_tokenize
import numpy as np
import unicodedata
from spacy.util import minibatch, compounding
import ast as ast
import pickle

# %%
# Função para substituir acentos

def strip_accents(text):
    try:
        text = unicode(text, 'utf-8')
    except (TypeError, NameError): # unicode is a default on python 3 
        pass
    text = unicodedata.normalize('NFD', text)
    text = text.encode('ascii', 'ignore')
    text = text.decode("utf-8")
    
    return str(text)

# %% [markdown]
# # Abrindo e gerando Datasets

# %% [markdown]
# ### Entidade logradouro

# %%
with open ('../Datasets/Dataset_V2.0.txt', 'rb') as fp:
    dataset = pickle.load(fp)

print(len(dataset))
# Out:
# 128016

# %%
dataset[0]
# Out:
# ('R.GUILHERME MOREIRA,315 SUBLOJA,LOJA E 2.ANDAR 69005-300 MANAUS CENTRO AM',
#  {'entities': [(0, 23, 'END_LOG')]})

# %%
end_lista = []

for i in range(len(dataset)):
    str_tratada = dataset[i][0]
    str_tratada = str_tratada.lower() # Tudo em minúsculo
    str_tratada = strip_accents(str_tratada) # Substituição de acentos e caracteres diferentes
    
    end_lista.append(str_tratada)

# %%
end_lista[:3]
# Out:
# ['r.guilherme moreira,315 subloja,loja e 2.andar 69005-300 manaus centro am',
#  '69005-300 manaus am r.guilherme moreira,315 centro subloja,loja e 2.andar',
#  'r.guilherme moreira,315 centro 69005-300 subloja,loja e 2.andar manaus am']

# %%
iob = []

for i in range(len(dataset)):
    tupla = (end_lista[i], dataset[i][1])
    
    iob.append(tupla)
    
FULL_DATA = iob

# %%
print(FULL_DATA[0])
print(FULL_DATA[1])
print(FULL_DATA[2])
# Out:
# ('r.guilherme moreira,315 subloja,loja e 2.andar 69005-300 manaus centro am', {'entities': [(0, 23, 'END_LOG')]})
# ('69005-300 manaus am r.guilherme moreira,315 centro subloja,loja e 2.andar', {'entities': [(20, 43, 'END_LOG')]})
# ('r.guilherme moreira,315 centro 69005-300 subloja,loja e 2.andar manaus am', {'entities': [(0, 23, 'END_LOG')]})

# %%
# Criação da base de teste e treinamento

n_test= 0.1 # Porcentagem para base de teste
test_n = round(len(FULL_DATA) * n_test)

# Divisao em Train Test Val

def gerador_bases(dataset, n):
    indices_random = random.sample(range(0,len(dataset)-1), n)
    base_teste_n = []
    base_treinamento_n = []
    
    for i in range(n):
        base_teste_n.append(dataset[indices_random[i]])

    for j in range(len(dataset)):
        if(j not in indices_random):
            base_treinamento_n.append(dataset[j])
            
    return base_teste_n, base_treinamento_n


base_teste, base_treinamento = gerador_bases(FULL_DATA, test_n)

random.shuffle(base_treinamento)
random.shuffle(base_teste)

print("Treinamento: " + str(len(base_treinamento)), "\nTeste: " + str(len(base_teste)), "\nTotal: " + str(len(FULL_DATA)))
# Out:
# Treinamento: 115214
# Teste: 12802
# Total: 128016

# %%
for i in range(5):
    print(base_treinamento[i])
# Out:
# ('21041-010 rj pa das naes 180 bonsucesso rio de janeiro', {'entities': [(14, 29, 'END_LOG')]})
# ('itatiba centro  sp praca da bandeira, 51 13250-329', {'entities': [(19, 40, 'END_LOG')]})
# ('centro av. dr. edilson pontes, 138 46140-000 ba  livramento de nossa senhora', {'entities': [(7, 34, 'END_LOG')]})
# ('centro 14580-000 sp praca 9 de julho, 102  guara', {'entities': [(20, 41, 'END_LOG')]})
# ('21070-030 av. bras de pina - 24-a bras de pina rio de janeiro  rj', {'entities': [(10, 33, 'END_LOG')]})

# %% [markdown]
# # Criando o modelo

# %%
# Define our variables

model = None
output_dir=Path(".")
n_iter= 50 # número de épocas
batch_size = 64

# %%
# Setting up the pipeline and entity recognizer.
if model is not None:
    nlp = spacy.load(model)  # load existing spacy model
    print("Loaded model '%s'" % model)
else:
    lan = 'pt'
    nlp = spacy.blank(lan)  # create blank Language class
    print("Created blank '%s' model" % lan)
    
if 'ner' not in nlp.pipe_names:
    ner = nlp.create_pipe('ner')
    nlp.add_pipe(ner)
    print('Added new NER')
else:
    ner = nlp.get_pipe('ner')
    print('Got an old NER')
# Out:
# Created blank 'pt' model
# Added new NER

# %%
# create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
if 'ner' not in nlp.pipe_names:
    ner = nlp.create_pipe('ner')
    nlp.add_pipe(ner, last=True)
# otherwise, get it so we can add labels
else:
    ner = nlp.get_pipe('ner')

# %% [markdown]
# ## Treinamento

# %%
print("Batch size: ", batch_size)
print("Épocas: ", n_iter)
print()

# add labels
for _, annotations in base_treinamento:
    for ent in annotations.get('entities'):
        ner.add_label(ent[2])


# get names of other pipes to disable them during training
other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
with nlp.disable_pipes(*other_pipes):  # only train NER
    optimizer = nlp.begin_training()
    for itn in range(n_iter):
        random.shuffle(base_treinamento)
        losses = {}
        batches = minibatch(base_treinamento, size=batch_size)
        
        for batch in batches:
            texts, annotations = zip(*batch)
            try:
                nlp.update(texts, annotations, sgd=optimizer, drop=0.2,
                       losses=losses)
            except:
                pass     
        
        print(itn+1, '\tLosses', losses)
# Out:
# Batch size:  64
# Épocas:  50
#
# 1 	Losses {'ner': 42198.45468182037}
# 2 	Losses {'ner': 15786.027301167687}
# 3 	Losses {'ner': 11318.14078434399}
# 4 	Losses {'ner': 9276.059837772344}
# 5 	Losses {'ner': 7768.1935773192445}
# 6 	Losses {'ner': 6665.725070077658}
# 7 	Losses {'ner': 6177.978693358606}
# 8 	Losses {'ner': 5330.289409730619}
# 9 	Losses {'ner': 4865.618877340154}
# 10 	Losses {'ner': 4627.8868527540335}
# 11 	Losses {'ner': 4232.631363280108}
# 12 	Losses {'ner': 4039.0372208517156}
# 13 	Losses {'ner': 3751.1298515168996}
# 14 	Losses {'ner': 3899.1217852767754}
# 15 	Losses {'ner': 3553.645807341747}
# 16 	Losses {'ner': 3576.0204861514985}
# 17 	Losses {'ner': 3335.4626899678005}
# 18 	Losses {'ner': 3236.7870245211852}
# 19 	Losses {'ner': 2782.49051973197}
# 20 	Losses {'ner': 3046.313139121491}
# 21 	Losses {'ner': 2743.878681170492}
# 22 	Losses {'ner': 2705.164181314526}
# 23 	Losses {'ner': 2671.8000133570417}
# 24 	Losses {'ner': 2606.145272408227}
# 25 	Losses {'ner': 2578.588505056689}
# 26 	Losses {'ner': 2373.476386297188}
# 27 	Losses {'ner': 2351.3883602147257}
# 28 	Losses {'ner': 2215.6738261561372}
# 29 	Losses {'ner': 2162.8321201890108}
# 30 	Losses {'ner': 2118.7182582895543}
# 31 	Losses {'ner': 2185.2253668102308}
# 32 	Losses {'ner': 1964.1023421704608}
# 33 	Losses {'ner': 2019.4304413283162}
# 34 	Losses {'ner': 1931.0946699029514}
# 35 	Losses {'ner': 1921.8304042882207}
# 36 	Losses {'ner': 1897.123395697572}
# 37 	Losses {'ner': 1700.3957719871826}
# 38 	Losses {'ner': 1590.0346970534724}
# 39 	Losses {'ner': 1840.1065831604844}
# 40 	Losses {'ner': 1775.9466259295048}
# 41 	Losses {'ner': 1632.3579460686074}
# 42 	Losses {'ner': 1626.7890251695433}
# 43 	Losses {'ner': 1664.3424491063186}
# 44 	Losses {'ner': 1576.5301437325604}
# 45 	Losses {'ner': 1596.8825787631076}
# 46 	Losses {'ner': 1472.7580764501847}
# 47 	Losses {'ner': 1526.7109608132878}
# 48 	Losses {'ner': 1494.9653283809766}
# 49 	Losses {'ner': 1445.8260235809344}
# 50 	Losses {'ner': 1422.4488034772119}

# %% [markdown]
# ## Salvando modelo

# %%
nlp.to_disk('../Saved_models/')

# %% [markdown]
# ## Carregando modelo para teste
# #### Executar até antes de `Criando o modelo` caso já tenha treinado anteriormente.

# %%
nlp = spacy.load('../Saved_models/')

# %% [markdown]
# ## Teste

# %% [markdown]
# Base de Teste

# %%
# test the trained model
for text, _ in base_teste:
    doc = nlp(text)
    print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
    print(text)
    print()
# Out:
# Entities [('av barao do rio branco', 'END_LOG')]
# av barao do rio branco centro  14870-780 sp jaboticabal
#
# Entities [('rua cel jose fortes', 'END_LOG')]
# esperantina 64180-000 centro pi  rua cel jose fortes
#
# Entities [('rua da praia, 153', 'END_LOG')]
# rua da praia, 153 pe recife 50020-550 sao jose
#
# Entities [('av. antonio de goes', 'END_LOG')]
# pe av. antonio de goes pina sala 508 - ed. international trade center 51110-000 recife
#
# Entities [('av. aroeira, 441', 'END_LOG')]
# av. aroeira, 441 go rubiataba  centro 76350-000
#
# Entities [('r estefano jose vanolli,', 'END_LOG')]
# sc  sao vicente itajai 88309-201 r estefano jose vanolli,
#
# Entities [('av. claudionor barbieri, 498', 'END_LOG')]
# centro sp 17250-000 av. claudionor barbieri, 498  bariri
#
# Entities [('avenida presidente vargas 25', 'END_LOG')]
# centro mg avenida presidente vargas 25 36415-000 congonhas
#
# Entities [('av.pres.vargas,730', 'END_LOG')]
# rio de janeiro av.pres.vargas,730 rj centro 11.andar 20071-001
#
# Entities [('r.otacilio negrao de lima,77', 'END_LOG')]
# centro 32400-000  r.otacilio negrao de lima,77 mg ibirite
#
# Entities [('av.princesa isabel,678', 'END_LOG')]
# itabuna ba av.princesa isabel,678 cto.adm.pref.municipal banco raso 45607-291
#
# Entities [('praca andradas, 70', 'END_LOG')]
# 82 centro praca andradas, 70 barbacena mg 36200-008
#
# Entities [('av.selim jose de sales, 785', 'END_LOG')]
# mg ipatinga canaa av.selim jose de sales, 785 35164-213
#
# Entities [('av. engenheiro luiz carlos berrini, 1645', 'END_LOG')]
# chcara itaim 04571-011 4 andar e terreo av. engenheiro luiz carlos berrini, 1645 sao paulo sp
#
# Entities [('r.washington luiz,356/364', 'END_LOG')]
# centro 13770-000 r.washington luiz,356/364  sp caconde
#
# Entities [('rua belo horizonte', 'END_LOG')]
# centro mg padre paraiso rua belo horizonte  39818-000
#
# Entities [('av. rodrigues alves, n. 97', 'END_LOG')]
# cruzeiro do sul centro av. rodrigues alves, n. 97  69980-000 ac
#
# Entities [('r.quinze de novembro,2636', 'END_LOG')]
# r.quinze de novembro,2636 80045-270 pr alto da xv curitiba
#
# Entities [('av.sen.souza naves,236', 'END_LOG')]
# joaquim tavora centro av.sen.souza naves,236  86455-000 pr
#
# Entities [('av portugal, 1374', 'END_LOG')]
# sp  santo andre centro av portugal, 1374 09041-320
#
# Entities [('estrada dos tres rios,', 'END_LOG')]
# freguesia parte rio de janeiro 22745-005 estrada dos tres rios, rj
#
# Entities [('sain projeo i', 'END_LOG')]
# brasilia 70620-000 ed. procuradoria geral do df  sain projeo i df
#
# Entities [('av.benjamim pinto dias,1724', 'END_LOG')]
# 26130-000 belford roxo rj  av.benjamim pinto dias,1724 centro
#
# Entities [('r.cel.niederauer,1681', 'END_LOG')]
# 97015-123 santa maria r.cel.niederauer,1681 centro rs
#
# Entities [('via anchieta,1454/1462', 'END_LOG')]
# via anchieta,1454/1462 sp moinho velho 04246-001 sao paulo
#
# Entities [('av. erasmo braga, 277-a, sl e ss', 'END_LOG')]
# rj  av. erasmo braga, 277-a, sl e ss rio de janeiro centro 20020-000
#
# Entities [('rua barao do rio branco, 1582', 'END_LOG')]
# rua barao do rio branco, 1582 centro campo grande ms  79002-171
#
# Entities [('av.rio branco - 161/a', 'END_LOG')]
# 20040-007 av.rio branco - 161/a  rio de janeiro centro rj
#
# Entities [('av. cezario de melo, 3166', 'END_LOG')]
# 23050-100 rio de janeiro campo grande  av. cezario de melo, 3166 rj
#
# Entities [('r jovino fernandes salles', 'END_LOG')]
# r jovino fernandes salles  37130-000  mg alfenas
#
# Entities [('av.pres.vargas,168', 'END_LOG')]
# es av.pres.vargas,168  afonso claudio 29600-000 centro
#
# Entities [('av. julio de castilhos', 'END_LOG')]
# tres passos 98600-000 centro rs  av. julio de castilhos
#
# Entities [('av. das americas, 3959 - loja 101', 'END_LOG')]
# rj rio de janeiro av. das americas, 3959 - loja 101  barra da tijuca 22631-003
#
# Entities [('rua quintino maudonnet, 835', 'END_LOG')]
# sp rua quintino maudonnet, 835 panorama centro 17980-000
#
# Entities [('rua padre antonio, 365', 'END_LOG')]
# rua padre antonio, 365 pr alto da gloria  80030-100 curitiba
#
# Entities [('av. benedito valadares, 95', 'END_LOG')]
# 38190-000 mg av. benedito valadares, 95  sacramento centro
#
# Entities [('av.jabaquara, 1182', 'END_LOG')]
# pavimento superior sp sao paulo jabaquara 04046-200 av.jabaquara, 1182
#
# Entities [('av. agamenon magalhaes, 789', 'END_LOG')]
# centro  av. agamenon magalhaes, 789 salgueiro pe 56000-000
#
# Entities [('rua francisco miguel,561/579', 'END_LOG')]
# campo limpo paulista sp 13210-001 centro qd b rua francisco miguel,561/579
#
# Entities [('rua voluntrios da ptria, 1512', 'END_LOG')]
# sp santana sao paulo 02010-300 rua voluntrios da ptria, 1512 360305
#
# Entities [('av luiz magalhaes, 1325', 'END_LOG')]
# se itabaiana 49500-000 av luiz magalhaes, 1325  marianga
#
# Entities [('r.dr.monteiro,582', 'END_LOG')]
# arroio grande  rs 96330-000 r.dr.monteiro,582 centro
#
# Entities [('rua paula sousa, 61', 'END_LOG')]
# luz 01027-001  sp rua paula sousa, 61 sao paulo
#
# Entities [('av. jabaquara, 1182', 'END_LOG')]
# 04046-200 sao paulo sp saude  av. jabaquara, 1182
#
# Entities [('av.antonio carlos,6627', 'END_LOG')]
# av.antonio carlos,6627 mg campus ufmg pampulha pampulha 31270-901 belo horizonte
#
# Entities [('av. mateo bei, 1.178', 'END_LOG')]
# 03949-100 sao paulo av. mateo bei, 1.178 sp so mateus
#
# Entities [('av. inocencio serafico', 'END_LOG')]
# carapicuiba av. inocencio serafico 06380-021 vila silva ribeiro  sp
#
# Entities [('r.gov.brasil caiado,817', 'END_LOG')]
# 77780-000 to r.gov.brasil caiado,817 arapoema centro
#
# Entities [('av tancredo neves', 'END_LOG')]
# caminho das arvores ba salvador av tancredo neves 41820-908
#
# Entities [('rua paulo lopes, 400', 'END_LOG')]
# centro 75920-000 santa helena de goias rua paulo lopes, 400  go
#
# Entities [('r vicente da fontoura,', 'END_LOG')]
# rio branco r vicente da fontoura, rs porto alegre  90640-001
#
# Entities [('rua dr. abreu de lima, 244', 'END_LOG')]
# centro rua dr. abreu de lima, 244 bom jesus do itabapoana rj 28360-000
#
# Entities [('estrada do pau ferro,74/78', 'END_LOG')]
# rio de janeiro jacarepagua estrada do pau ferro,74/78 22743-051 rj
#
# Entities [('rua barbara de alencar, 55', 'END_LOG')]
# rua barbara de alencar, 55 centro 60140-000 ce  fortaleza
#
# Entities [('rua marechal deodoro, 665', 'END_LOG')]
# curitiba  pr rua marechal deodoro, 665 centro 80020-320
#
# Entities [('avenida paulista , 2240', 'END_LOG')]
# sp cerqueira cesar sao paulo avenida paulista , 2240 01310-300 13 andar
#
# Entities [('alameda pedro calil, 43', 'END_LOG')]
# 08557-105 alameda pedro calil, 43 poa sp  vila acacias
#
# Entities []
# centro rs 96225-000 sao jose do norte r gal osorio,
#
# Entities [('av.aquidab', 'END_LOG')]
# 13026-510 centro av.aquidab campinas  sp
#
# Entities [('av. brig. luiz antonio, 3394', 'END_LOG')]
# 01402-001 60746948 jardim paulista sao paulo av. brig. luiz antonio, 3394 sp
#
# Entities [('av. sete de setembro', 'END_LOG')]
# rs estancia velha 93600-000 av. sete de setembro
#
# Entities [('av.alberto maranhao,1582', 'END_LOG')]
# 59600-972 rn mossoro av.alberto maranhao,1582  centro
#
# Entities [('rua cicero castilho cunha', 'END_LOG')]
# centro  sud mennucci sp rua cicero castilho cunha 15360-000
#
# Entities [('av.dr.pedro jorge,23', 'END_LOG')]
# 26383-060 centro rj queimados lojas 1/3,terreo av.dr.pedro jorge,23
#
# Entities [('rua sao jose, 435', 'END_LOG')]
# mg centro  36500-000 uba rua sao jose, 435
#
# Entities [('av.prof.francisco morato,3405', 'END_LOG')]
# av.prof.francisco morato,3405 v.sonia sp 05521-000 sao paulo
#
# Entities [('sia, s/n', 'END_LOG')]
# sia sul sia, s/n 71200-055 brasilia qd. 5c ae 17/18 - loja 195 df
#
# Entities [('pca.da independencia,20', 'END_LOG')]
# pca.da independencia,20 braco do trombudo  sc centro 89178-000
#
# Entities [('rua placido caldas, 384', 'END_LOG')]
# jandaia do sul pr 86900-000 rua placido caldas, 384 centro
#
# Entities [('av.jose i.barros,4', 'END_LOG')]
# go inaciolandia centro av.jose i.barros,4  75550-000
#
# Entities [('r.bernardes de faria,129', 'END_LOG')]
# centro 35570-000 mg formiga r.bernardes de faria,129
#
# Entities [('rua pinto de figueiredo, 64', 'END_LOG')]
# tijuca rio de janeiro  rj 20511-240 rua pinto de figueiredo, 64
#
# Entities [('av.gradenor de melo,48', 'END_LOG')]
# 35190-000 av.gradenor de melo,48 centro mg iapu
#
# Entities [('av.vol.fernando pinheiro franco,432', 'END_LOG')]
# predio 08710-500 centro av.vol.fernando pinheiro franco,432 mogi das cruzes sp
#
# Entities [('rua cajuru, 913', 'END_LOG')]
# rua cajuru, 913 sp sao paulo  03057-000 belenzinho
#
# Entities [('rua amador bueno, 605', 'END_LOG')]
# rua amador bueno, 605 14010-070 ribeirao preto  centro sp
#
# Entities [('av. xingu, 232', 'END_LOG')]
# 68540-000 local xinguara  xinguara av. xingu, 232 pa
#
# Entities [('rua dom pedro ii, 109', 'END_LOG')]
# mg loja rua dom pedro ii, 109 lagoa dourada 36345-000 centro
#
# Entities [('avenida 19, 981', 'END_LOG')]
# barretos centro  14780-300 sp avenida 19, 981
#
# Entities [('r.duque de caxias,103', 'END_LOG')]
# 55200-000  centro pe r.duque de caxias,103 pesqueira
#
# Entities [('rua joo da cruz', 'END_LOG')]
# vitoria praia do canto rua joo da cruz  29055-620 es
#
# Entities [('av. da saudade, 1421', 'END_LOG')]
# ribeirao preto sp  av. da saudade, 1421 14080-000 campos eliseos
#
# Entities [('av.barao do triunfo, 445', 'END_LOG')]
# pb  joao pessoa av.barao do triunfo, 445 58010-400 varadouro
#
# Entities [('rua presidente dutra, 285', 'END_LOG')]
# sc 88860-000 sideropolis rua presidente dutra, 285 centro
#
# Entities [('av getulio vargas, 443', 'END_LOG')]
# av getulio vargas, 443 colatina 29700-017 centro es
#
# Entities [('avenida mozart pinheiro de lucena, 1970', 'END_LOG')]
# vila velha 60347-452 ce  fortaleza avenida mozart pinheiro de lucena, 1970
#
# Entities [('av. rio branco, 319', 'END_LOG')]
# centro ma 65725-500  pedreiras av. rio branco, 319
#
# Entities [('av.ataulfo de paiva - 1175', 'END_LOG')]
# rj rio de janeiro  av.ataulfo de paiva - 1175 22440-032 freguesia da gavea
#
# Entities [('rua piranga, 5, lojas f, g, h', 'END_LOG')]
# rua piranga, 5, lojas f, g, h rio de janeiro rj meier 20720-030
#
# Entities [('rua rangel pestana, 394 - parte', 'END_LOG')]
# jundiai 13201-000 rua rangel pestana, 394 - parte sp centro
#
# Entities [('pca.aarao lins de andrade,50', 'END_LOG')]
# gravata pca.aarao lins de andrade,50 centro  55641-080 pe
#
# Entities [('avenida yervant kissajikian, 1801/1803/1', 'END_LOG')]
# sao paulo americanpolis sp  avenida yervant kissajikian, 1801/1803/1 04428-010
#
# Entities [('rua 11', 'END_LOG')]
# setor central 74015-170 goiania go  rua 11
# Entities [('av. gois', 'END_LOG')]
# 09521-310 sp santo antonio  av. gois sao caetano do sul
#
# Entities [('estrada das lagrimas, 425', 'END_LOG')]
# sao caetano do sul  sp jardim so caetano estrada das lagrimas, 425 09581-300
#
# Entities [('av. sta leopoldina, n 1440', 'END_LOG')]
# av. sta leopoldina, n 1440 es loja 02 coqueiral de itaparica 29102-200 vila velha
#
# Entities [('alameda baro de piracicaba', 'END_LOG')]
# campos eliseos 4 andar - lado b 01216-012 alameda baro de piracicaba sp sao paulo
#
# Entities [('av.pres.getulio vargas,42', 'END_LOG')]
# av.pres.getulio vargas,42  centro pr cruz machado 84620-000
#
# Entities [('av parob 534/548', 'END_LOG')]
# sao leopoldo scharlau q1028 / lt 10/11 rs 93125-000 av parob 534/548
#
# Entities [('rua barao de melgaco, 3475', 'END_LOG')]
# cuiaba 78005-908 mt centro norte rua barao de melgaco, 3475
#
# Entities [('r. antonio joaquim de borba, 518', 'END_LOG')]
# centro  76680-000 itapuranga r. antonio joaquim de borba, 518 go
#
# Entities [('r rua da bahia 2500', 'END_LOG')]
# 30160-019 r rua da bahia 2500 mg belo horizonte 8 andar lourdes
#
# Entities [('av guarapiranga, 1970', 'END_LOG')]
# vila socorro  sp 04902-005 av guarapiranga, 1970 sao paulo
#
# Entities [('av.paulista,2300', 'END_LOG')]
# av.paulista,2300 sao paulo 1.andar,ed.sao luiz(recepcao 1 sp bela vista 01310-300
#
# Entities [('av.mato grosso,950', 'END_LOG')]
# mt 78285-000 sao jose dos quatro marcos esq.c/av.sergipe centro av.mato grosso,950
#
# Entities [('praca 9 de julho, 102', 'END_LOG')]
# praca 9 de julho, 102 sp centro 14580-000 guara
#
# Entities [('avenida tancredo neves n. 148', 'END_LOG')]
# 41828-900  pituba salvador ba avenida tancredo neves n. 148
#
# Entities [('avenida so paulo', 'END_LOG')]
# esquina com a rua rui barbosa centro cacoal 76963-761 ro avenida so paulo
#
# Entities [('rua mal floriano 349', 'END_LOG')]
# rs rio grande   96200-380 rua mal floriano 349
#
# Entities [('r.goncalves dias,20', 'END_LOG')]
# 38500-000 mg monte carmelo r.goncalves dias,20 centro
#
# Entities [('scr/sul, quadra 511, bloco b', 'END_LOG')]
# asa sul scr/sul, quadra 511, bloco b loja 15 70361-520 brasilia df
#
# Entities [('rua padre reus, 350', 'END_LOG')]
# rua padre reus, 350 rs centro 99400-000 espumoso
#
# Entities [('pca. cel. tancredo franca, 05', 'END_LOG')]
# pca. cel. tancredo franca, 05 38195-000 centro  mg conquista
#
# Entities [('av. gov. roberto silveira, 2366', 'END_LOG')]
# rj av. gov. roberto silveira, 2366 nova friburgo duas pedras  28635-000
#
# Entities [('estrada do galeao,2787', 'END_LOG')]
# rj 21941-005 portuguesa rio de janeiro  estrada do galeao,2787
#
# Entities [('rua major silvino silva, 43', 'END_LOG')]
# mg rua major silvino silva, 43 quadra 36 35660-016 centro para de minas
#
# Entities [('av.primo alberto bodanese,786', 'END_LOG')]
# sc quilombo av.primo alberto bodanese,786 centro sala 89850-000
#
# Entities [('rua pedroso de moraes, 2750', 'END_LOG')]
# rua pedroso de moraes, 2750 05420-003 pinheiros sp sao paulo
#
# Entities [('av.pres.vargas,290-a', 'END_LOG')]
# centro  20091-905 rio de janeiro rj av.pres.vargas,290-a
#
# Entities [('rua iguatemi', 'END_LOG')]
# sp sao paulo 01451-011  itaim bibi rua iguatemi
#
# Entities [('pa. visconde do rio preto, 222', 'END_LOG')]
# centro pa. visconde do rio preto, 222  27600-000 valenca rj
#
# Entities [('pca.conego joao rodrigues melo,105', 'END_LOG')]
# 55370-000 sao bento do una  centro pca.conego joao rodrigues melo,105 pe
#
# Entities [('avenida governador bley', 'END_LOG')]
# avenida governador bley vitoria es 29010-902 n 186, loja 03 centro
#
# Entities [('rua libero badar', 'END_LOG')]
# 24 andar - conj. 2401 - edifcio mercantil finasa sao paulo 01009-000 sp centro rua libero badar
#
# Entities [('pca.pe.domingos segurado,156', 'END_LOG')]
# centro pca.pe.domingos segurado,156  sp joanopolis 12980-000
#
# Entities [('av. fernando costa, 447', 'END_LOG')]
# vila jaiara anapolis go 75064-780 av. fernando costa, 447
#
# Entities [('rua felipe dos santos, 647', 'END_LOG')]
# 16230-000  rua felipe dos santos, 647 centro piacatu sp
#
# Entities [('av.do forte,1819', 'END_LOG')]
# rs vila ipiranga av.do forte,1819  91360-001 porto alegre
#
# Entities [('av.rep.do libano,1875', 'END_LOG')]
# go setor oeste ed.vera lucia av.rep.do libano,1875 74115-924 goiania
#
# Entities [('avenida brasil, n 519', 'END_LOG')]
# campo verde centro  avenida brasil, n 519 mt 78840-000
#
# Entities [('av.tiradentes, 191', 'END_LOG')]
# centro anapolis av.tiradentes, 191 go 75040-010
#
# Entities [('rua heitor penteado,', 'END_LOG')]
# sumarezinho lj sao paulo 05437-001 sp rua heitor penteado,
#
# Entities [('r.iguatemi,472', 'END_LOG')]
# mt r.iguatemi,472  78350-000 centro brasnorte
#
# Entities [('rua juscelino kubitschek', 'END_LOG')]
# ba quijingue 48830-000  rua juscelino kubitschek centro
#
# Entities [('r.n.sra.da lapa,281', 'END_LOG')]
# sp lapa 05072-000 sao paulo r.n.sra.da lapa,281
#
# Entities [('pca. capitao policarpo rocha, 70', 'END_LOG')]
# pca. capitao policarpo rocha, 70 mg centro  carandai 36280-000
#
# Entities [('alameda vieira de carvalho', 'END_LOG')]
# 09210-630 sp esq c/ r porto seguro santa terezinha santo andre alameda vieira de carvalho
#
# Entities [('av. ludovico da riva neto, 2114', 'END_LOG')]
# alta floresta av. ludovico da riva neto, 2114 mt centro  78580-000
#
# Entities [('av.pacaembu - 1306', 'END_LOG')]
# 01234-000  av.pacaembu - 1306 sao paulo pacaembu sp
#
# Entities [('praa coronel antnio lopes, 25', 'END_LOG')]
# mg sao jose do divino praa coronel antnio lopes, 25  39848-000 centro
#
# Entities [('av. eng. armando de arruda pereira, 707', 'END_LOG')]
# 04309-010 av. eng. armando de arruda pereira, 707 13 andar sp sao paulo jabaquara
#
# Entities [('av.getulio vargas,336', 'END_LOG')]
# sombrio sc 88960-000  centro av.getulio vargas,336
#
# Entities [('rua apiacs', 'END_LOG')]
# taquara rj rua apiacs 22730-190 rio de janeiro
#
# Entities [('rua guilherme shell 3950', 'END_LOG')]
# centro rua guilherme shell 3950 rs canoas v comando aereo regional 92200-630
#
# Entities [('av.nossa sra.de copacabana, 1380', 'END_LOG')]
# av.nossa sra.de copacabana, 1380 rio de janeiro 2 pavimento rj copacabana 22070-012
#
# Entities [('rua julio de castilhos, 268', 'END_LOG')]
# rs  canela centro 95680-000 rua julio de castilhos, 268
#
# Entities [('av. raul soares, 104', 'END_LOG')]
# 35200-000 mg  centro av. raul soares, 104 aimores
#
# Entities [('r pernambuco 1153', 'END_LOG')]
# centro r pernambuco 1153 87705-000 pr paranavai
#
# Entities [('pca.pe.fialho,72', 'END_LOG')]
# centro 35367-000 comercial mg pca.pe.fialho,72 matipo
#
# Entities [('rua consolao', 'END_LOG')]
# sao paulo consolao sp rua consolao 01302-904 conjunto 112 - 11.andar
#
# Entities [('r.major afonso,55', 'END_LOG')]
# jacutinga mg r.major afonso,55 centro  37590-000
#
# Entities [('av. ivar saldanha, 6723 a', 'END_LOG')]
# santa rita ma av. ivar saldanha, 6723 a  centro 65145-000
#
# Entities [('rua xv de novembro, 142', 'END_LOG')]
# coari  am rua xv de novembro, 142 centro 69460-000
#
# Entities [('avenida n. senhora de copacabana, 921', 'END_LOG')]
# 22020-001 rj rio de janeiro  avenida n. senhora de copacabana, 921 copacabana
#
# Entities [('r.eleonora cintra,112', 'END_LOG')]
# r.eleonora cintra,112 03337-000 sao paulo  analia franco sp
#
# Entities [('praca dom ferrao, 49', 'END_LOG')]
# campanha  centro 37400-000 mg praca dom ferrao, 49
#
# Entities [('rua bento de abreu, 480', 'END_LOG')]
# 14825-000 sp rua bento de abreu, 480  santa lucia centro
#
# Entities [('rua conde de linhares', 'END_LOG')]
# cidade jardim rua conde de linhares belo horizonte mg 30380-030
#
# Entities [('pc.vigario antonio joaquim,22', 'END_LOG')]
# centro mossoro 2.andar 59600-520 pc.vigario antonio joaquim,22 rn
#
# Entities [('rua venancio aires 353', 'END_LOG')]
# 97010-001 centro rs santa maria  rua venancio aires 353
#
# Entities [('av. pref. olavo gomes de oliveira,1940', 'END_LOG')]
# cruzeiro pouso alegre 60746948 mg 37550-000 av. pref. olavo gomes de oliveira,1940
#
# Entities [('av. nova cantareira, 580', 'END_LOG')]
# sao paulo 02330-000  av. nova cantareira, 580 tucuruvi sp
#
# Entities [('r.barao do rio branco,390-a', 'END_LOG')]
# avai 16680-000 centro  r.barao do rio branco,390-a sp
#
# Entities [('rua regina matos, 101', 'END_LOG')]
# centro es 29890-000  rua regina matos, 101 montanha
#
# Entities [('rua f', 'END_LOG')]
# parauapebas pa 68515-000 uniao rua f
#
# Entities [('av. milton campos, 2579', 'END_LOG')]
# mg av. milton campos, 2579 guanhaes centro  39740-000
#
# Entities [('r.fernando caldas carneiro da silva,848', 'END_LOG')]
# r.fernando caldas carneiro da silva,848 rj 28735-000  quissama sitio
#
# Entities [('av penha de franca,549', 'END_LOG')]
# 03606-010 p franca sp sao paulo av penha de franca,549 1 andar
#
# Entities [('rua barao do rio branco, 637', 'END_LOG')]
# sp centro rua barao do rio branco, 637 birigui 16200-001
#
# Entities [('av.castelo branco,s/n', 'END_LOG')]
# 65393-000 av.castelo branco,s/n ma buriticupu centro
#
# Entities [('av getulio vargas 384', 'END_LOG')]
# mt quilombro av getulio vargas 384 cuiaba 78043-415
#
# Entities [('av.professor joao moraes de sousa,345', 'END_LOG')]
# av.professor joao moraes de sousa,345 santa luzia do parua  65272-000 centro ma
#
# Entities [('av nova york 115', 'END_LOG')]
# rj av nova york 115  rio de janeiro bonsucesso 21041-040
#
# Entities [('av ernani cardoso 49-51', 'END_LOG')]
# 360305 rj 21310-310 av ernani cardoso 49-51 cascadura rio de janeiro
#
# Entities [('av. bom jesus, 1265', 'END_LOG')]
# pontes e lacerda  78250-000 mt av. bom jesus, 1265 centro
#
# Entities [('rua sao joao,420', 'END_LOG')]
# 14700-010 bebedouro  centro sp rua sao joao,420
#
# Entities [('r cinco de maio', 'END_LOG')]
# r cinco de maio centro pe goiana  55900-000
#
# Entities [('r ricardo neves - qd 3 lt 1', 'END_LOG')]
# centro 76510-000 crixas  r ricardo neves - qd 3 lt 1 go
#
# Entities [('av inglaterra', 'END_LOG')]
# 86181-000 av inglaterra centro cambe pr
#
# Entities [('avenida kennedy, n 271', 'END_LOG')]
# avenida kennedy, n 271 sp sao bernardo do campo jardim do mar parte 09726-260
# Entities [('praca sao joao batista, 86', 'END_LOG')]
# santa luzia praca sao joao batista, 86  mg sao joao batista 33030-790
#
# Entities [('avenida coronel antonino', 'END_LOG')]
# 79010-000 ms campo grande quadra 13 lote 4b coronel antonino avenida coronel antonino
#
# Entities [('rua major matheus, 635', 'END_LOG')]
# botucatu vila dos lavradores sp  18609-083 rua major matheus, 635
#
# Entities [('praa jos prado alves, s/n', 'END_LOG')]
# ba 44718-000 ourolandia praa jos prado alves, s/n  centro
#
# Entities [('av. iguau,703', 'END_LOG')]
# pr av. iguau,703 mangueirinha centro 85540-000
#
# Entities [('pca.leonor kaupa,100,lojas 373,374,', 'END_LOG')]
# jd.da saude sao paulo pca.leonor kaupa,100,lojas 373,374, 04151-100 375 e 376 sp
#
# Entities [('praa cnego albino campos', 'END_LOG')]
# ma centro 65485-000 itapecuru mirim praa cnego albino campos
#
# Entities [('praa melo peixoto, 177', 'END_LOG')]
# centro (parte) praa melo peixoto, 177 sp ourinhos 19900-060
#
# Entities [('av.eng.domingos ferreira,2180', 'END_LOG')]
# recife pe 51111-020 av.eng.domingos ferreira,2180  boa viagem
#
# Entities [('rua jacaranda, 231', 'END_LOG')]
# pr esq.c/rua inglaterra, 250 fazenda rio grande rua jacaranda, 231 83820-000 eucaliptos
#
# Entities [('pca.cesario amarante,72', 'END_LOG')]
# sc sao joaquim centro pca.cesario amarante,72  88600-000
#
# Entities [('avenida assis brasil, 6.215 - loja 01', 'END_LOG')]
# rs avenida assis brasil, 6.215 - loja 01 91110-001 porto alegre sarandi
#
# Entities [("av.princesa d'oeste, 1129", 'END_LOG')]
# av.princesa d'oeste, 1129  sp campinas 13026-137 jardim proenca
#
# Entities [('rua marselha, 145', 'END_LOG')]
# londrina pr 86041-140 sala 6 rua marselha, 145 jardim pizza
#
# Entities [('rua mendes junior, 654', 'END_LOG')]
# rua mendes junior, 654 03013-011 bras  sp sao paulo
#
# Entities [('av mal tito', 'END_LOG')]
# av mal tito 08010-090 sp 701 so miguel paulista sao paulo
#
# Entities [('av. nossa sra. de copacabana, 830', 'END_LOG')]
# rio de janeiro copacabana loja a - parte rj av. nossa sra. de copacabana, 830 22050-001
#
# Entities [('r xv de novembro, 1190', 'END_LOG')]
# r xv de novembro, 1190 centro 18730-000 sp  itai
#
# Entities [('av joao correa esquina rua joao xxii sn', 'END_LOG')]
# av joao correa esquina rua joao xxii sn rs 93020-690 centro  sao leopoldo
#
# Entities [('rua cardoso de morais, 221', 'END_LOG')]
# rio de janeiro 21032-000 rj rua cardoso de morais, 221 bonsucesso a
#
# Entities [('avenida dos palmares, 264', 'END_LOG')]
# 68450-000 pedreira avenida dos palmares, 264 moju pa
#
# Entities [('avenida patrcio lima, 579', 'END_LOG')]
# humaita tubarao avenida patrcio lima, 579 sc 88704-410
#
# Entities [('avenida marechal floriano peixoto', 'END_LOG')]
# pr 81630-900 avenida marechal floriano peixoto hauer  curitiba
#
# Entities [('av.ernani do amaral peixoto,84', 'END_LOG')]
# centro niteroi av.ernani do amaral peixoto,84 24020-074  rj
#
# Entities [('rua padre rolim,', 'END_LOG')]
# belo horizonte mg  rua padre rolim, santa efigenia 30130-090
#
# Entities [('av.afonso pena, 3880', 'END_LOG')]
# av.afonso pena, 3880 mg mangabeiras 30130-008  belo horizonte
#
# Entities [('r.francisco ferreira alves,298', 'END_LOG')]
# centro sp r.francisco ferreira alves,298 conchal predio 13835-000
#
# Entities [('av. silva lobo,', 'END_LOG')]
# 30460-000 av. silva lobo, mg belo horizonte  nova granada
#
# Entities [('av. presidente vargas, 463 - 13 andar', 'END_LOG')]
# rio de janeiro rj av. presidente vargas, 463 - 13 andar centro 20071-003
#
# Entities [('av. castro alves,', 'END_LOG')]
# centro 44190-000  ba santo estevao av. castro alves,
#
# Entities [('rua riachuelo, 458', 'END_LOG')]
# 64200-280  pi parnaiba centro rua riachuelo, 458
#
# Entities [('av.ayrton senna, 742', 'END_LOG')]
# rj 25850-000 av.ayrton senna, 742 centro  paraiba do sul
#
# Entities [('rua joao pessoa', 'END_LOG')]
# 57020-010 rua joao pessoa  maceio al centro
#
# Entities [('avenida presidente kennedy', 'END_LOG')]
# avenida presidente kennedy 24445-795 rj lojas 118 at 126 sao goncalo estrela do norte
#
# Entities [('rua quinta, s/n', 'END_LOG')]
# pa soure  centro 68870-000 rua quinta, s/n
#
# Entities [('avenida camapu', 'END_LOG')]
# manaus 69099-028 avenida camapu am novo aleixo
#
# Entities [('rua dr. ataliba leonel, 711', 'END_LOG')]
# sp taquarituba 18740-000  rua dr. ataliba leonel, 711 centro
#
# Entities [('pca cel paiva goncalves 80', 'END_LOG')]
# mimoso do sul es centro pca cel paiva goncalves 80  29400-000
#
# Entities [('r.dos bancos,s/n', 'END_LOG')]
# rj rio de janeiro r.dos bancos,s/n ed.12 a,ilha das cobras 20180-001 centro
#
# Entities [('av.cronge da silveira,450', 'END_LOG')]
# 68445-000 pa barcarena av.cronge da silveira,450  centro
#
# Entities [('rua do fico 410', 'END_LOG')]
# sp sao joaquim aracatuba rua do fico 410 16050-387
#
# Entities [('avenida nilo pecanha', 'END_LOG')]
# avenida nilo pecanha 28970-000 loja 1 - lote 3 rj araruama centro
#
# Entities [('r.quinze de novembro,63', 'END_LOG')]
# salete sc r.quinze de novembro,63 centro 89196-000
#
# Entities [('av.prof.joao meneses,651', 'END_LOG')]
# pi  av.prof.joao meneses,651 centro 64770-000 sao raimundo nonato
#
# Entities [('av. nestor fred. henn', 'END_LOG')]
# rs  96880-000 centro av. nestor fred. henn vera cruz
#
# Entities [('avenida afonso pena, 3504', 'END_LOG')]
# ms sala 78 - 7 andar - ed. empire center centro campo grande 79002-075 avenida afonso pena, 3504
#
# Entities [('r. francisco nunes de moraes, 37', 'END_LOG')]
# sao jose do calcado centro 29470-000 es  r. francisco nunes de moraes, 37
#
# Entities [('rua imperador dom pedro ii', 'END_LOG')]
# santo antonio recife 50010-240  pe rua imperador dom pedro ii
#
# Entities [('rua benjamin da silva, 1874', 'END_LOG')]
# 69150-000 parintins am  rua benjamin da silva, 1874 centro
#
# Entities [('praca ademar de barros, 122', 'END_LOG')]
# sp santa adelia praca ademar de barros, 122 15950-000  centro
#
# Entities [('avenida rio branco', 'END_LOG')]
# 19 e 20 andares centro rio de janeiro 20040-004 rj avenida rio branco
#
# Entities [('r.dr.luis bastos do prado,1317', 'END_LOG')]
# centro r.dr.luis bastos do prado,1317 94010-020 gravatai  rs
#
# Entities [('r. rosa guimaraes, q. 45, lts. e e g', 'END_LOG')]
# acreuna go 75960-000 r. rosa guimaraes, q. 45, lts. e e g centro
#
# Entities [('pca.joao paulo segundo,26/70', 'END_LOG')]
# centro pca.joao paulo segundo,26/70 al taquarana 57640-000
#
# Entities [('r.sete de setembro,128', 'END_LOG')]
# recife boa vista  r.sete de setembro,128 50060-070 pe
#
# Entities [('rua joaquim floriano', 'END_LOG')]
# 04534-012 itaim bibi pavimento superior rua joaquim floriano sao paulo sp
#
# Entities [('rua floriano peixoto', 'END_LOG')]
# 16010-220 centro rua floriano peixoto sp  aracatuba
#
# Entities [('quadra 48, lote', 'END_LOG')]
# centro santo antonio do descoberto quadra 48, lote 72900-970 go
#
# Entities [('rua daltro filho, 458', 'END_LOG')]
# tres passos centro  rua daltro filho, 458 98600-000 rs
#
# Entities [('av. castelo branco, 545', 'END_LOG')]
# av. castelo branco, 545 horto  ipatinga mg 35160-294
#
# Entities [('av getulio vargas quadra, s/n', 'END_LOG')]
# 17018-711  vila aviacao sp av getulio vargas quadra, s/n bauru
#
# Entities [('pca.bolivar andrade,20', 'END_LOG')]
# mg pca.bolivar andrade,20 passa tempo centro 35537-000
#
# Entities [('rua estados unidos, 1821', 'END_LOG')]
# sp rua estados unidos, 1821  jardim america sao paulo 01427-002
#
# Entities [('rua tenente coronel britto', 'END_LOG')]
# rua tenente coronel britto centro  santa cruz do sul 96810-030 rs
#
# Entities [('av.moraes sales, 668', 'END_LOG')]
# av.moraes sales, 668 pav.superior campinas sp centro 13010-000
#
# Entities [('avenida amazona', 'END_LOG')]
# lucas do rio verde 78455-000 sala 3 mt centro avenida amazona
#
# Entities [('praca conego joaquim alves, 80', 'END_LOG')]
# centro sp praca conego joaquim alves, 80  batatais 14300-000
#
# Entities [('av. miguel estfno, 2.309', 'END_LOG')]
# sao paulo parte saude 04301-012 sp av. miguel estfno, 2.309
#
# Entities [('av.jose maria fernandes,162', 'END_LOG')]
# sao paulo 02185-030 pq.novo mundo av.jose maria fernandes,162  sp
#
# Entities [('r.jose rolim de matos,74', 'END_LOG')]
# 95580-000 rs r.jose rolim de matos,74 tres cachoeiras centro
#
# Entities [('av prudente de morais,', 'END_LOG')]
# natal lagoa seca av prudente de morais,  rn 59022-305
#
# Entities [('rua boa vista, 238', 'END_LOG')]
# sp embu-guacu  69000-000 centro rua boa vista, 238
#
# Entities [('rua tenente camargo, 1733', 'END_LOG')]
# rua tenente camargo, 1733 francisco beltrao pr 85601-610 centro
#
# Entities [('r.acre,s/n', 'END_LOG')]
# centro agrovila 9 r.acre,s/n 47630-000 serra do ramalho ba
#
# Entities [('rua nove de julho', 'END_LOG')]
# centro salto sp 13320-005 rua nove de julho
#
# Entities [('av winston churchill 2255', 'END_LOG')]
# av winston churchill 2255 81150-050 curitiba  pinheirinho pr
#
# Entities [('pc dr. botelho egas,', 'END_LOG')]
# guararema  08900-000 pc dr. botelho egas, sp centro
#
# Entities [('praca coronel alexandre moreira, 58', 'END_LOG')]
# centro 44630-000 praca coronel alexandre moreira, 58 ba  mairi
#
# Entities [('r.cons.rufino,572', 'END_LOG')]
# 38730-000 centro mg guimarania r.cons.rufino,572
#
# Entities [('rua machado bittencourt, 28', 'END_LOG')]
# 26900-000 miguel pereira centro rj rua machado bittencourt, 28 loja 1
#
# Entities [('av francisco bicalho, 01 lj 01s', 'END_LOG')]
# 20220-310  santo cristo rj rio de janeiro av francisco bicalho, 01 lj 01s
#
# Entities [('av.marechal tito, 4260', 'END_LOG')]
# sp sao paulo av.marechal tito, 4260 itaim paulista  08115-000
#
# Entities [('av des santos neves', 'END_LOG')]
# es 29055-723  av des santos neves praia do canto vitoria
#
# Entities [('av. mutinga, 2555', 'END_LOG')]
# sao paulo  sp av. mutinga, 2555 pirituba 05110-000
#
# Entities [('av. padre trajano 30', 'END_LOG')]
# av. padre trajano 30 esq.c/rua robson r.r.barbosa posse centro go 73900-000
#
# Entities [('av. goias, 1934', 'END_LOG')]
# 77400-000 av. goias, 1934 gurupi centro to
#
# Entities [('rua cnego pimentel, 427', 'END_LOG')]
# barcarena vila dos cabanos 68445-000 pa rua cnego pimentel, 427
#
# Entities [('pca.dr.miguel pereira,87', 'END_LOG')]
# centro 36790-000 mirai mg  pca.dr.miguel pereira,87
#
# Entities [('praca 1817, 81', 'END_LOG')]
# 58013-010 centro praca 1817, 81  pb joao pessoa
#
# Entities [('av. curitiba, 705', 'END_LOG')]
# tapira  av. curitiba, 705 87830-000 pr centro
#
# Entities [('rua cnego caspary', 'END_LOG')]
# centro sala 01 rs 95795-000 sao vendelino rua cnego caspary
#
# Entities [('pa melo palheta,134', 'END_LOG')]
# 87600-000  centro pa melo palheta,134 pr nova esperanca
#
# Entities [('avenida dos autonomistas, 5436', 'END_LOG')]
# sp 06194-050 osasco quitauna avenida dos autonomistas, 5436
#
# Entities [('av.sen.salgado filho,s/n', 'END_LOG')]
# 59064-901 natal rn cto.administrativo sethas av.sen.salgado filho,s/n lagoa nova
#
# Entities [('rua jnio quadros quadra 2-d, lote 01', 'END_LOG')]
# rua jnio quadros quadra 2-d, lote 01 confresa centro 78652-000  mt
#
# Entities [('pca.joao thiago dos santos, 36', 'END_LOG')]
# centro ba lauro de freitas pca.joao thiago dos santos, 36 42700-000
#
# Entities [('r.barao mesquita,248-a', 'END_LOG')]
# rio de janeiro r.barao mesquita,248-a tijuca  20540-003 rj
#
# Entities [('rua itapeva, 260', 'END_LOG')]
# sao paulo sp 01332-000 bela vista rua itapeva, 260
# Entities [('rua duque de caxias', 'END_LOG')]
# rs 90010-282 rua duque de caxias centro centro porto alegre
#
# Entities [('avenida prudente de morais, n 384', 'END_LOG')]
# sp avenida prudente de morais, n 384 13309-050 vila nova  itu
#
# Entities [('r.jorge elias seba,725', 'END_LOG')]
# ms 79611-080  tres lagoas r.jorge elias seba,725 jd.alvorada
#
# Entities [('praa pio x, 118', 'END_LOG')]
# 20091-040 rj 6 andar praa pio x, 118 centro rio de janeiro
#
# Entities [('r.luiz gama,58', 'END_LOG')]
# sp guarulhos r.luiz gama,58 07010-050  centro
#
# Entities [('praca sao sebastiao, 66', 'END_LOG')]
# sp centro guapiacu praca sao sebastiao, 66 15110-000
#
# Entities [('av. goias quadra 7, lote 66 e, n.531', 'END_LOG')]
# 74005-010 go  goiania av. goias quadra 7, lote 66 e, n.531 setor central
#
# Entities [('rua  guapeva leste, 103 qd 32, lote', 'END_LOG')]
# chapadao do ceu go  75828-000 centro rua  guapeva leste, 103 qd 32, lote
#
# Entities [('r.parana,229', 'END_LOG')]
# ibaiti 84900-000 pr centro  r.parana,229
#
# Entities [('r jeronimo coelho, 205', 'END_LOG')]
# parte 88010-030 centro sc florianopolis r jeronimo coelho, 205
#
# Entities [('av. inocencio serafico', 'END_LOG')]
# vila silva ribeiro carapicuiba 06380-021  sp av. inocencio serafico
#
# Entities [('rua dos ferroviarios, 50', 'END_LOG')]
# rua dos ferroviarios, 50 centro rs  esteio 93250-000
#
# Entities [('praca padre manoel da nobrega, 21-7/9/16', 'END_LOG')]
# sao paulo centro praca padre manoel da nobrega, 21-7/9/16 10150-100 andar sp
#
# Entities [('av. republica do chile, 230, loja 101', 'END_LOG')]
# 20031-170 terreo rj centro rio de janeiro av. republica do chile, 230, loja 101
#
# Entities [('pca dr augusto silva', 'END_LOG')]
# 37200-000 mg centro  lavras pca dr augusto silva
#
# Entities [('estr.francisco cruz nunes,5770', 'END_LOG')]
# rj loja 101 estr.francisco cruz nunes,5770 niteroi 24350-310 piratininga
#
# Entities [('av.gal.rodrigo otavio,3000', 'END_LOG')]
# av.gal.rodrigo otavio,3000 japiim ufam-centro de convivencia am 69077-000 manaus
#
# Entities [('rua mariz e barros, 856', 'END_LOG')]
# loja a rio de janeiro maracana rj 20270-002 rua mariz e barros, 856
#
# Entities [('rua  quinze de novembro, 70', 'END_LOG')]
# itajai sc rua  quinze de novembro, 70 centro  88301-420
#
# Entities [('r.jundiai,328', 'END_LOG')]
# 59020-120 natal r.jundiai,328 rn  tirol
#
# Entities [('av.julio antonio thurler,159', 'END_LOG')]
# olaria  av.julio antonio thurler,159 28620-000 nova friburgo rj
#
# Entities [('avenida constantino nery', 'END_LOG')]
# chapada sala 1309 avenida constantino nery manaus am 69050-001
#
# Entities [('av.expedito garcia,315', 'END_LOG')]
# 29146-201 campo grande av.expedito garcia,315  es cariacica
#
# Entities [('av. higienopolis, 224', 'END_LOG')]
# pr centro 86020-080  londrina av. higienopolis, 224
#
# Entities [('rua coronel marcos rovares, 309', 'END_LOG')]
# rua coronel marcos rovares, 309 sc 88820-000 icara centro
#
# Entities [('r.quinze de novembro,107', 'END_LOG')]
# 88830-000 centro  morro da fumaca sc r.quinze de novembro,107
#
# Entities [('rua marechal deodoro, 419', 'END_LOG')]
# rua marechal deodoro, 419  sp sao bernardo do campo 09710-010 centro
#
# Entities [('r.vinte e oito de outubro,691', 'END_LOG')]
# 18087-080 sp sorocaba r.vinte e oito de outubro,691 1.andar jd.do passo
#
# Entities [('r. josefina ludovico de almeida, s/n esq', 'END_LOG')]
# 75460-000 go r. josefina ludovico de almeida, s/n esq neropolis  parque das americas
#
# Entities [('av.pres.carlos luz,3001', 'END_LOG')]
# mg 2.piso,lojas 2102/2108 31250-010 aparecida av.pres.carlos luz,3001 belo horizonte
#
# Entities [('avenida brasilia', 'END_LOG')]
# 85884-000 avenida brasilia pr centro medianeira
#
# Entities [('r.quinze de novembro,382', 'END_LOG')]
# centro  r.quinze de novembro,382 sp bocaina 17240-000
#
# Entities [('av. prof. alfonso bovero, 1060', 'END_LOG')]
# vila pompeia sp sao paulo av. prof. alfonso bovero, 1060 05019-010
#
# Entities [('rua 3,', 'END_LOG')]
# 78635-000 centro  mt rua 3, agua boa
#
# Entities [('av. guilherme winter', 'END_LOG')]
# rs av. guilherme winter bom principio centro 95765-000
#
# Entities [('av.sete de setembro, 509', 'END_LOG')]
# av.sete de setembro, 509 rj campos dos goytacazes centro 28013-331
#
# Entities [('avenida da saudade, n 1550', 'END_LOG')]
# campos eliseos 14085-000 sp  avenida da saudade, n 1550 ribeirao preto
#
# Entities [('rua francisco real, 566', 'END_LOG')]
# rj rio de janeiro padre miguel rua francisco real, 566  21715-422
#
# Entities [('avenida porto alegre', 'END_LOG')]
# 78890-000 avenida porto alegre mt centro sorriso
#
# Entities [('av. saudade, 935', 'END_LOG')]
# av. saudade, 935 ribeirao preto sp campos eliseos 14100-000
#
# Entities [('av ceara 2412', 'END_LOG')]
# rio branco 69900-448 bosque av ceara 2412 ac
#
# Entities [('r.cel.jose custodio,73', 'END_LOG')]
# 37730-000 centro  r.cel.jose custodio,73 mg campestre
#
# Entities [('r.brasil,495', 'END_LOG')]
# r.brasil,495 aracatuba sao joao sp 16025-010
#
# Entities [('km 0,terminal maritimo bom despacho s/n.', 'END_LOG')]
# ba bom despacho  44460-000 km 0,terminal maritimo bom despacho s/n. itaparica
#
# Entities [('rua presidente nereu, 327', 'END_LOG')]
# rua presidente nereu, 327 sc ituporanga 88400-000 centro
#
# Entities [('rua maria amlia de azevedo, 1006 a 1008', 'END_LOG')]
# rua maria amlia de azevedo, 1006 a 1008 sp 02350-001 vila albertina sao paulo
#
# Entities [('av. augusto de lima, 1800', 'END_LOG')]
# belo horizonte av. augusto de lima, 1800  mg 30190-916 barro preto
#
# Entities [('av. brasil, 1305', 'END_LOG')]
# pr cambara 86390-000 centro  av. brasil, 1305
#
# Entities [('praca firmo de queiroz', 'END_LOG')]
# pr 84400-000  centro praca firmo de queiroz prudentopolis
#
# Entities [('av.presidente bandeira, 372', 'END_LOG')]
# natal alecrim av.presidente bandeira, 372 rn 59040-200 2.andar-sala escritorio estilo
#
# Entities [('av. doutor jose augusto moreira, 1195', 'END_LOG')]
# av. doutor jose augusto moreira, 1195 pe olinda casa caiada 53130-410
#
# Entities [('rua romualdo lopes canado', 'END_LOG')]
# lojas 1,2,3 e 4 belo horizonte castelo 30840-460 rua romualdo lopes canado mg
#
# Entities [('av.teixeira de barros, s/n', 'END_LOG')]
# 13574-033 sp av.teixeira de barros, s/n sao carlos vila prado
#
# Entities [('avenida presidente juscelino kubitschek', 'END_LOG')]
# itaim bibi sp 1455  15 andar avenida presidente juscelino kubitschek 04543-011 sao paulo
#
# Entities [('av brigadeiro faria lima, 3400', 'END_LOG')]
# 18 andar itaim bibi av brigadeiro faria lima, 3400 04538-132 sao paulo sp
#
# Entities [('avenida rio branco, 70', 'END_LOG')]
# rj 3. andar rio de janeiro 20040-000 avenida rio branco, 70 centro
#
# Entities [('rua sete de setembro, 99 - sala 1601', 'END_LOG')]
# 20050-000 rua sete de setembro, 99 - sala 1601 rio de janeiro rj centro
#
# Entities [('rua domingos rosolia, 150', 'END_LOG')]
# 05567-000 sp rua domingos rosolia, 150 sao paulo jardim so jorge
#
# Entities [('avenida santo amaro', 'END_LOG')]
# avenida santo amaro  04556-300 brooklin paulista sp sao paulo
#
# Entities [('avenida fernandes de andrade, 974', 'END_LOG')]
# quitandinha 83840-000 pr avenida fernandes de andrade, 974 centro
#
# Entities [('r.conego vasconcelos,186', 'END_LOG')]
# bangu r.conego vasconcelos,186 21810-012 rj  rio de janeiro
#
# Entities [('avenida rio branco,', 'END_LOG')]
# 59025-002 avenida rio branco, rn  natal cidade alta
#
# Entities [('praca tiradentes, 32/rua senador rocha', 'END_LOG')]
# lagoa praca tiradentes, 32/rua senador rocha centro mg 35400-000 ouro preto
#
# Entities [('avenida presidente vargas, 2164', 'END_LOG')]
# avenida presidente vargas, 2164 14025-700  ribeirao preto sp centro
#
# Entities [('rua carijos, 2095', 'END_LOG')]
# sp 91800-010 vila linda rua carijos, 2095 santo andre
#
# Entities [('rua goncalves figueira, 009', 'END_LOG')]
# montes claros mg centro rua goncalves figueira, 009 terceiro andar 39400-006
#
# Entities [('r.da padroeira,499', 'END_LOG')]
# r.da padroeira,499 sp 13201-026  centro jundiai
#
# Entities [('av. jair dantas, 361', 'END_LOG')]
# caete av. jair dantas, 361 34800-000 jose brandao mg
#
# Entities [('srl, s/n', 'END_LOG')]
# df brasilia qd.2 - cj.a - lote 41 srl, s/n planaltina 73350-201
#
# Entities [('av.mario melo, 400', 'END_LOG')]
# 53600-000 av.mario melo, 400 igarassu pe  centro
#
# Entities [('praca charles miller', 'END_LOG')]
# 01234-010 sp  sao paulo praca charles miller pacaembu
#
# Entities [('r.dep.nacip raydan,49', 'END_LOG')]
# mg  r.dep.nacip raydan,49 centro santa maria do suacui 39780-000
#
# Entities [('av. mal camara, 160-a, sala 210', 'END_LOG')]
# centro av. mal camara, 160-a, sala 210 rj rio de janeiro 20020-080 360305
#
# Entities [('r.quinze de novembro,103', 'END_LOG')]
# 55900-000  centro goiana pe r.quinze de novembro,103
#
# Entities [('av.mato grosso,329', 'END_LOG')]
# centro mt sao jose do rio claro av.mato grosso,329 78435-000
#
# Entities [('av dom helder camara,', 'END_LOG')]
# rj abolicao rio de janeiro av dom helder camara, 20751-002
#
# Entities [('av maria coelho aguiar, 215', 'END_LOG')]
# av maria coelho aguiar, 215 sao paulo 05805-000 jd s luis sp 8.andar - sala exclusivo 5 - bloco d
#
# Entities [('tv.mariano candido de almeida,21', 'END_LOG')]
# afua tv.mariano candido de almeida,21 centro em frente a sefa 68890-000 pa
#
# Entities [('praa da repblica s/n', 'END_LOG')]
# 68170-000 praa da repblica s/n juruti pa centro
#
# Entities [('rua julio de castilhos, 2818', 'END_LOG')]
# taquara  centro rua julio de castilhos, 2818 95600-000 rs
#
# Entities [('r.delfino conti,306', 'END_LOG')]
# trindade r.delfino conti,306 florianopolis sc 88040-370 campus ufsc
#
# Entities [('av.sao leopoldo,340', 'END_LOG')]
# rs campo bom centro 93700-000 av.sao leopoldo,340
#
# Entities [('rua carijs,1665', 'END_LOG')]
# rua carijs,1665  vila linda 09180-001 santo andre sp
#
# Entities [('rua ezequiel ramos', 'END_LOG')]
# centro bauru sp  rua ezequiel ramos 17010-021
#
# Entities [('av.marica, 180-a', 'END_LOG')]
# av.marica, 180-a rj alcantara sao goncalo  24756-280
#
# Entities [('rua marques do herval, 1344', 'END_LOG')]
# 95020-260 rs caxias do sul centro 1 andar rua marques do herval, 1344
#
# Entities [('pca. roberto da silveira, 24', 'END_LOG')]
# rj centro pca. roberto da silveira, 24 duque de caxias  25000-000
#
# Entities [('ncleo cidade de deus, s/n', 'END_LOG')]
# 06029-900 osasco vila yara prdio rubi, trreo, sala 2 sp ncleo cidade de deus, s/n
#
# Entities [('avenida pietro petri', 'END_LOG')]
# mairipora  terra preta 07600-000 sp avenida pietro petri
#
# Entities [('rua castro alves', 'END_LOG')]
# euclides da cunha  48500-000 rua castro alves ba centro
#
# Entities [('rua marechal deodoro, 806', 'END_LOG')]
# rua marechal deodoro, 806 86430-000 pr santo antonio da platina centro
#
# Entities [('rua paraba, 1000', 'END_LOG')]
# 30130-141 mg funcionrios rua paraba, 1000 belo horizonte 13 e 14 andares
#
# Entities [('rua marilia, num 297', 'END_LOG')]
# juiz de fora rua marilia, num 297 36090-330 mg benfica
#
# Entities [('r.sen.leite,768', 'END_LOG')]
# 65415-000 centro ma r.sen.leite,768 coroata
#
# Entities [('av. rui barbosa, 2.367', 'END_LOG')]
# sp 12212-000 av. rui barbosa, 2.367 sao jose dos campos  santana
#
# Entities [('av. cel. sezefredo fagundes, 2520/2528', 'END_LOG')]
# tucuruvi  av. cel. sezefredo fagundes, 2520/2528 sp 23060-000 sao paulo
#
# Entities [('rua viriato bandeira, 680', 'END_LOG')]
# 79400-000 centro rua viriato bandeira, 680 coxim ms
#
# Entities [('avenida general atade teive, 3997', 'END_LOG')]
# avenida general atade teive, 3997 rr asa branca 69309-000  boa vista
# Entities [('av. sete de setembro, 1544', 'END_LOG')]
# 07064-002 sp av. sete de setembro, 1544  guarulhos vila galvao
#
# Entities [('av.pedro taques,434', 'END_LOG')]
# zona 07 av.pedro taques,434 87030-000 maringa  pr
#
# Entities [('avenida duque de caxias,', 'END_LOG')]
# santa efigenia 01214-000 avenida duque de caxias, sao paulo sp
#
# Entities [('av j 473 - sn - av 1 qd 6 lt 21 e 22', 'END_LOG')]
# se nossa senhora do socorro av j 473 - sn - av 1 qd 6 lt 21 e 22 taioca de fora 49160-971
#
# Entities [('praca getulio vargas, 251', 'END_LOG')]
# 35521-000  mg centro praca getulio vargas, 251 bonfim
#
# Entities [('pca.joao americo de oliveira s/n.', 'END_LOG')]
# pca.joao americo de oliveira s/n.  tapiramuta ba centro 44840-000
#
# Entities [('av.jatuarana, 4474', 'END_LOG')]
# av.jatuarana, 4474 caladinho  76808-110 porto velho ro
#
# Entities [('pc marechal bezerril', 'END_LOG')]
# ce centro vicosa do ceara 62300-000  pc marechal bezerril
#
# Entities [('rua nossa senhora da lapa, 432', 'END_LOG')]
# sp rua nossa senhora da lapa, 432  sao paulo lapa 05072-000
#
# Entities [('av.abido saad, 348', 'END_LOG')]
# serra parque jacaraipe es  29175-520 av.abido saad, 348
#
# Entities [('rua augusta, 1655', 'END_LOG')]
# rua augusta, 1655 sp 01305-100 sao paulo consolao
#
# Entities [('rua dr. otavio lamartine', 'END_LOG')]
# jardim do serido rua dr. otavio lamartine 59343-000 rn centro ed. j. medeiros
#
# Entities [('rua amando de barros, 717', 'END_LOG')]
# botucatu 18600-050 rua amando de barros, 717  centro sp
#
# Entities [('rua coelho lisboa', 'END_LOG')]
# 03323-040 tatuap sao paulo sp 245/247 rua coelho lisboa
#
# Entities [('avenida castelo branco, num 13', 'END_LOG')]
# avenida castelo branco, num 13 sao jose  35182-054 timoteo mg
#
# Entities [('avenida bezerra de menezes', 'END_LOG')]
# so gerardo 60325-001 fortaleza ce  avenida bezerra de menezes
#
# Entities [('avenida santos dumont, 203 / 205 / 215', 'END_LOG')]
# avenida santos dumont, 203 / 205 / 215 stio paecara-vic.de carvalho 11460-001 sp guaruja
#
# Entities [('rua sete de abril, 345', 'END_LOG')]
# 01043-000 rua sete de abril, 345 sp sao paulo 360305 centro
#
# Entities [('av. epaminondas fritz, 255', 'END_LOG')]
# 85160-000 pr  cantagalo centro av. epaminondas fritz, 255
#
# Entities [('rua padre roque, 1782', 'END_LOG')]
# sp 13800-207 mogi-mirim jardim aurea rua padre roque, 1782
#
# Entities [('r. governador valfredo siqueira, 15', 'END_LOG')]
# pe r. governador valfredo siqueira, 15  centro 56700-000 sao jose do egito
#
# Entities [('av municipal q 87 lote 07', 'END_LOG')]
# pontes e lacerda 78250-000 centro mt  av municipal q 87 lote 07
#
# Entities [('rua assis brasil, 11 sala 7', 'END_LOG')]
# bento goncalves rs centro 95700-000  rua assis brasil, 11 sala 7
#
# Entities [('av.ewerton xavier, 1469,ljs. 101,102,103', 'END_LOG')]
# niteroi rj itaipu edificio portucale 24340-105 av.ewerton xavier, 1469,ljs. 101,102,103
#
# Entities [('r voluntarios da patria', 'END_LOG')]
# botafogo 198 22270-012 rio de janeiro r voluntarios da patria rj
#
# Entities [('av dr joao guilhermino', 'END_LOG')]
# centro  sp sao jose dos campos 12210-131 av dr joao guilhermino
#
# Entities [('avenida so joo', 'END_LOG')]
# 12242-840 sp avenida so joo 994 sao jose dos campos
#
# Entities [('al gabriel monteiro da silva', 'END_LOG')]
# jardim america sao paulo sp 01442-000 al gabriel monteiro da silva
#
# Entities [('av. 1 de junho, 325', 'END_LOG')]
# mg 360305 divinopolis av. 1 de junho, 325 centro 03550-000
#
# Entities [('rua francisco glicerio, 385', 'END_LOG')]
# itatiba rua francisco glicerio, 385 13250-330 sp centro
#
# Entities [('av t 2, 1620 quadra 41 - lote 19', 'END_LOG')]
# setor bueno 74215-005 av t 2, 1620 quadra 41 - lote 19  go goiania
#
# Entities [('rua mariano procpio 830', 'END_LOG')]
# 36035-780 juiz de fora 4 brigada de infantaria motorizada mg  rua mariano procpio 830
#
# Entities [('avenida fernando ferrari, 845', 'END_LOG')]
# goiabeiras  avenida fernando ferrari, 845 es 29075-053 vitoria
#
# Entities [('avenida comendador dante carraro', 'END_LOG')]
# sp carapicuiba avenida comendador dante carraro cidade ariston-estela azevedo 06396-000
#
# Entities [('rua brs cubas, 119', 'END_LOG')]
# santos  vila nova 11013-163 sp rua brs cubas, 119
#
# Entities [('rua governador portela, 15', 'END_LOG')]
# barra do pirai rj rua governador portela, 15 centro 27123-000
#
# Entities [('viaduto nove de julho', 'END_LOG')]
# sp centro sao paulo viaduto nove de julho 01050-060
#
# Entities [('av.jose pinheiro borges s/n.,pav.terreo', 'END_LOG')]
# 08220-900 sao paulo vl.campanela sp  av.jose pinheiro borges s/n.,pav.terreo
#
# Entities [('av durval fraga', 'END_LOG')]
# muritiba 44340-000 av durval fraga centro  ba
#
# Entities [('rua joao moreira salles, 731', 'END_LOG')]
# rua joao moreira salles, 731 mg cambui 37600-000 vl nossa sra aparecida
#
# Entities [('praa francisco antonio da silva, 825', 'END_LOG')]
# 64770-000 sao raimundo nonato pi praa francisco antonio da silva, 825 centro
#
# Entities [('rua n. sra. das graas, 346 - loja', 'END_LOG')]
# rua n. sra. das graas, 346 - loja 25515-001 centro  rj sao joao de meriti
#
# Entities [('r.francisco bras,s/n', 'END_LOG')]
# ap r.francisco bras,s/n centro qd.6,lote 123,setor 12 68945-000 pedra branca do amapari
#
# Entities [('rua  portugal', 'END_LOG')]
# rua  portugal  cerejeiras setor b 76997-000 ro
#
# Entities [('av.sao joao,60', 'END_LOG')]
# pr 87175-000 itambe centro av.sao joao,60
#
# Entities [('av. solon lucena', 'END_LOG')]
# centro pb 58700-004  patos av. solon lucena
#
# Entities [('rua doutor batista laper, 10', 'END_LOG')]
# rua doutor batista laper, 10 loja 01 e 02 28650-000 duas barras centro rj
#
# Entities [('avenida maringa', 'END_LOG')]
# 87111-000 sarandi avenida maringa  jardim europa pr
#
# Entities [('av.brasil,269', 'END_LOG')]
# ...
#
# Entities [('av.santos dumont, 2110', 'END_LOG')]
# av.santos dumont, 2110 ce 60150-160 centro fortaleza
#
# Entities [('r.do comercio,1465', 'END_LOG')]
# 99950-000 rs tapejara  centro r.do comercio,1465
#
# Entities [('av.republica argentina, 4357', 'END_LOG')]
# pr 81050-000 av.republica argentina, 4357  curitiba novo mundo
#
# Entities [('av. mandacaru', 'END_LOG')]
# av. mandacaru vila santa izabel 87080-000 maringa pr
#
# Entities [('praa xv de novembro, 167', 'END_LOG')]
# prata praa xv de novembro, 167 centro 38140-000 mg
#
# Entities [('av.dos autonomistas,2789', 'END_LOG')]
# av.dos autonomistas,2789  centro sp osasco 06090-020
#
# Entities [('rua xv de novembro, 920, salas 202/203', 'END_LOG')]
# blumenau 89010-002 centro sc rua xv de novembro, 920, salas 202/203
#
# Entities [('av. ricardo jafet, 3314', 'END_LOG')]
# sp vila firmiano pinto 04123-020 av. ricardo jafet, 3314 sao paulo
#
# Entities [('rua otacilio medeiros de almeida', 'END_LOG')]
# rs macambara 97645-000 centro rua otacilio medeiros de almeida
#
# Entities [('avenida charles schnneider', 'END_LOG')]
# taubate avenida charles schnneider sp  12040-000 parque senhor do bonfim
#
# Entities [('rua xv de novembro, 185', 'END_LOG')]
# 17240-000 bocaina sp rua xv de novembro, 185  centro
#
# Entities [('rua direita da piedade,25', 'END_LOG')]
# 40070-190 salvador barris 4.andar - ala a ba rua direita da piedade,25
#
# Entities [('av. barao de capanema', 'END_LOG')]
# av. barao de capanema centro pa  capanema 68700-005
#
# Entities [('praca rui barbosa, 14', 'END_LOG')]
# centro sp igarapava  praca rui barbosa, 14 14540-000
#
# Entities [('avenida dr neto, 282', 'END_LOG')]
# centro ipora avenida dr neto, 282 76200-000 go
#
# Entities [('r.campos sales,211/221', 'END_LOG')]
# 06401-000 r.campos sales,211/221  centro barueri sp
#
# Entities [('rua tenente coronel britto', 'END_LOG')]
# rua tenente coronel britto  rs centro 96810-030 santa cruz do sul
#
# Entities [('rua bom jesus de pirapora, 1842, 1848', 'END_LOG')]
# jundiai 13206-480 vl.loureiro  sp rua bom jesus de pirapora, 1842, 1848
#
# Entities [('avenida otto niemeyer', 'END_LOG')]
# porto alegre tristeza rs avenida otto niemeyer  91910-001
# Entities [('rua itupava, 634 a 664', 'END_LOG')]
# pr alto da xv curitiba rua itupava, 634 a 664  80040-000
#
# Entities [('av. pinto alves, 22', 'END_LOG')]
# timbauba 55870-000  pe centro av. pinto alves, 22
#
# Entities [('av. paulista, 2.212', 'END_LOG')]
# bela vista  01310-300 sao paulo sp av. paulista, 2.212
#
# Entities [('av. ns-04, qd. 106 sul, alameda 06,lt 2a', 'END_LOG')]
# 77020-066 to 60746948 palmas centro av. ns-04, qd. 106 sul, alameda 06,lt 2a
#
# Entities [('r  felicio marcondes, 391', 'END_LOG')]
# 07010-030 r  felicio marcondes, 391 sp guarulhos centro terreo
#
# Entities [('avenida nossa senhora de copacabana', 'END_LOG')]
# loja rio de janeiro rj 22050-002 copacabana avenida nossa senhora de copacabana
#
# Entities [('av.emilio arroyo hernandes,2661', 'END_LOG')]
# sp pozzobon votuporanga lt.18 av.emilio arroyo hernandes,2661 15503-027
#
# Entities [('rua jorge zipperer, 302', 'END_LOG')]
# centro rio negrinho rua jorge zipperer, 302  sc 89330-000
#
# Entities [('av emilio arroyo hernandes,', 'END_LOG')]
# pozzobon  15503-027 sp av emilio arroyo hernandes, votuporanga
#
# Entities [('r voluntarios da patria', 'END_LOG')]
# santana r voluntarios da patria sp sao paulo 02010-400
#
# Entities [('avenida parana', 'END_LOG')]
# avenida parana  cianorte zona 1 pr 87200-248
#
# Entities [('rua dr. antonio dorta, 107', 'END_LOG')]
# porto calvo centro  al 57900-000 rua dr. antonio dorta, 107
#
# Entities [('rua julio de castilhos, 189', 'END_LOG')]
# rs 96810-010 santa cruz do sul rua julio de castilhos, 189 centro
#
# Entities [('rua amazonas', 'END_LOG')]
# patrimonio novo sp votuporanga rua amazonas 15500-004
#
# Entities [('rua prudente de morais', 'END_LOG')]
# rua prudente de morais 13400-315 centro piracicaba  sp
#
# Entities [('praca bom jesus, 79', 'END_LOG')]
# go  75025-050 centro anapolis praca bom jesus, 79
#
# Entities [('rua do comercio, n 144', 'END_LOG')]
# centro rua do comercio, n 144 rj angra dos reis 23900-563 152 - parte
#
# Entities [('rua celino de menezes s/n.', 'END_LOG')]
# carauari 69500-000  rua celino de menezes s/n. centro am
#
# Entities [('rua bento goncalves', 'END_LOG')]
# 97650-000 centro rs rua bento goncalves itaqui
#
# Entities [('av.sete de setembro,626', 'END_LOG')]
# av.sete de setembro,626 centro conceicao do araguaia  pa 68540-000
#
# Entities [('avenida nove de julho, 46', 'END_LOG')]
# centro al avenida nove de julho, 46 junqueiro 57270-000
#
# Entities [('rua conceicao, 233', 'END_LOG')]
# rua conceicao, 233  13010-050 centro campinas sp
#
# Entities [('rua oratorio, 1570', 'END_LOG')]
# rua oratorio, 1570 parque das nacoes santo andre sp 92800-000
#
# Entities [('r. rosa guimaraes, q. 45, lts. e e g', 'END_LOG')]
# r. rosa guimaraes, q. 45, lts. e e g centro acreuna  go 75960-000
#
# Entities [('av. rui barbosa, 790', 'END_LOG')]
# av. rui barbosa, 790 centro 28700-000 rj  macae
#
# Entities [('av gal flores da cunha, 3758', 'END_LOG')]
# av gal flores da cunha, 3758 rs 94950-001  vila bom principio cachoeirinha
#
# Entities [('av.brasil, 530', 'END_LOG')]
# mg 30140-001 belo horizonte sao lucas  av.brasil, 530
#
# Entities [('alameda dos jamaris 330', 'END_LOG')]
# 04078-000 sao paulo sp indianopolis alameda dos jamaris 330
#
# Entities [('rua cel. joaquim floriano, 263', 'END_LOG')]
# sp rua cel. joaquim floriano, 263 centro sao manuel  18650-000
#
# Entities [('av. getulio vargas', 'END_LOG')]
# av. getulio vargas tapes rs   96760-000
#
# Entities [('av.miguel estefno,2103', 'END_LOG')]
# sao paulo saude sp  04301-012 av.miguel estefno,2103
#
# Entities [('rua dos expedicionario', 'END_LOG')]
# centro 95990-000 rs ilopolis  rua dos expedicionario
#
# Entities [('avenida dr. sylvio lofego botelho, 553', 'END_LOG')]
# boa vista 69301-330 centro rr avenida dr. sylvio lofego botelho, 553
#
# Entities [('av. gramado', 'END_LOG')]
# 103 rs 95925-000 progresso av. gramado centro
#
# Entities [('av vereador valdemar cordeiro de moraes', 'END_LOG')]
# 55370-000 centro av vereador valdemar cordeiro de moraes sao bento do una pe
#
# Entities [('rua carlos gomes', 'END_LOG')]
# porto alegre 90480-003  rua carlos gomes auxiliadora rs
#
# Entities [('av julio de castilho, 1831', 'END_LOG')]
# campo grande 79100-005 ms av julio de castilho, 1831  vl alba
#
# Entities [('av.longuinho vieira junior,684', 'END_LOG')]
# colmeia av.longuinho vieira junior,684 77725-000 to  centro
#
# Entities [('rua estados unidos, 1721', 'END_LOG')]
# sp sao paulo jardim america parte rua estados unidos, 1721 01427-002
#
# Entities [('avenida rangel pestana, 2.296', 'END_LOG')]
# sao paulo  sp avenida rangel pestana, 2.296 bras 03002-000
#
# Entities [('rua frei caneca', 'END_LOG')]
# sala 816/817 rua frei caneca 01307-003 sao paulo centro sp
#
# Entities [('av luis de almeida couto sn', 'END_LOG')]
# 35215-000 viana  av luis de almeida couto sn ma centro
#
# Entities [('av. das amoreiras,', 'END_LOG')]
# av. das amoreiras, campinas parque industrial sp 13031-435
#
# Entities [('av. joaquim porto villanova', 'END_LOG')]
# 91410-400 av. joaquim porto villanova rs jardim do salso  porto alegre
#
# Entities [('av pres epitacio pessoa', 'END_LOG')]
# 58042-006 tambauzinho pb joao pessoa av pres epitacio pessoa
#
# Entities [('av dos estados, s/n', 'END_LOG')]
# porto alegre rs av dos estados, s/n 90201-970  anchieta
#
# Entities [('estrada caetano monteiro', 'END_LOG')]
# rj  niteroi estrada caetano monteiro badu 24320-570
#
# Entities [('av. coronel antonino, 593', 'END_LOG')]
# 79010-000 av. coronel antonino, 593  ms coronel antonino campo grande
#
# Entities [('av perimetral norte s/n', 'END_LOG')]
# 74463-330 setor candida de moraes go av perimetral norte s/n goiania quadra 03b  lote 10/11
#
# Entities [('praa lourdita raposa, s/n', 'END_LOG')]
# buriti bravo  ma 65685-000 buriti bravo praa lourdita raposa, s/n
#
# Entities [('r.prof.lelio gama,105', 'END_LOG')]
# centro rj 5.andar rio de janeiro r.prof.lelio gama,105 20031-080
#
# Entities [('av.goias,980', 'END_LOG')]
# go 3.andar 74010-010 centro goiania av.goias,980
#
# Entities [('av. dr. soares de oliveira, 57', 'END_LOG')]
# ituverava av. dr. soares de oliveira, 57  14500-000 sp centro
#
# Entities [('rua rui barbosa,251', 'END_LOG')]
# pe 52011-000 rua rui barbosa,251 gracas  recife
#
# Entities [('av. general camara, 708', 'END_LOG')]
# cruz alta rs av. general camara, 708  98025-780 centro
#
# Entities [('av.rangel pestana - 1244', 'END_LOG')]
# sp av.rangel pestana - 1244 03002-000 bras sao paulo
#
# Entities [('av.fernando correa da costa, 4501', 'END_LOG')]
# cuiaba av.fernando correa da costa, 4501 78080-000 ch pinheiros mt
#
# Entities [('rua comendador araujo', 'END_LOG')]
# curitiba rua comendador araujo batel 80420-063  pr
#
# Entities [('av. santos dumont', 'END_LOG')]
# ce terreo fortaleza av. santos dumont 60150-161 aldeota
#
# Entities [('rua pinheiros - 57', 'END_LOG')]
# pinheiros  05422-010 sp sao paulo rua pinheiros - 57
#
# Entities [('av djalma batista, 1661 lj 225 a 228', 'END_LOG')]
# chapada av djalma batista, 1661 lj 225 a 228 am 69050-010 manaus
#
# Entities [('rua guarani, 303', 'END_LOG')]
# centro rua guarani, 303 85501-050 pr pato branco
#
# Entities [('av.gov.valadares,194', 'END_LOG')]
# av.gov.valadares,194 centro mg arcos 35588-000
#
# Entities [('av.conego joao lima, 782', 'END_LOG')]
# quadra w, lote 4 araguaina vila rosario to 77823-010 av.conego joao lima, 782
#
# Entities [('av. vinte e seis de marco', 'END_LOG')]
# sp av. vinte e seis de marco  centro 06401-050 barueri
#
# Entities [('rua 15, n 163', 'END_LOG')]
# caiaponia go rua 15, n 163 75850-000  centro
#
# Entities [('rua princesa isabel', 'END_LOG')]
# rn  59025-400 cidade alta natal rua princesa isabel
#
# Entities [('rua do rcio', 'END_LOG')]
# 04552-000 8 andar - conjuntos 81 e 82 - ed. atrium ix sp sao paulo rua do rcio vila olmpia
#
# Entities [('avenida afonso pena', 'END_LOG')]
# avenida afonso pena mg belo horizonte 30130-009  cruzeiro
#
# Entities [('av.brasil, 1122', 'END_LOG')]
# sao paulo av.brasil, 1122 01430-001 pavimento terreo jardim america sp
#
# Entities [('avenida engenheiro luiz carlos berrini', 'END_LOG')]
# avenida engenheiro luiz carlos berrini cidade mones 04571-010 esq com rua furnas sao paulo sp
#
# Entities [('r.margarino alves brandao,551', 'END_LOG')]
# 79920-000  centro laguna carapa r.margarino alves brandao,551 ms
#
# Entities [('rua dr  curvelo cavalcanti', 'END_LOG')]
# centro itaguai rj rua dr  curvelo cavalcanti 23810-201
#
# Entities [('rua recife, 416', 'END_LOG')]
# am adrianopolis manaus 69057-000 esq.c/r.sao luis e marciano armond rua recife, 416
#
# Entities [('r das rosas, 43', 'END_LOG')]
# r das rosas, 43 rj rio de janeiro 21330-680 parte vila valqueire
#
# Entities [('rua  sete de setembro', 'END_LOG')]
# rs  96470-000 pinheiro machado centro  rua  sete de setembro
#
# Entities [('avenida afonso pena', 'END_LOG')]
# ms santa f avenida afonso pena 79031-010 loja 01 campo grande
#
# Entities [('r.do comercio,45', 'END_LOG')]
# r.do comercio,45 seara sc 89770-000 centro
#
# Entities [('avenida erasmo braga, 115 4 andar', 'END_LOG')]
# rio de janeiro avenida erasmo braga, 115 4 andar 20020-903 centro rj
#
# Entities [('r.tiradentes,2007', 'END_LOG')]
# r.tiradentes,2007 mg 32230-020 industrial contagem
#
# Entities [('r.brasilia,346', 'END_LOG')]
# r.brasilia,346 itacarambi mg centro 39470-000 1.andar
#
# Entities [('rodovia sc-403, num 6200', 'END_LOG')]
# sc rodovia sc-403, num 6200 88058-000 ingleses do rio vermelho esquina c/ rua manoel ramos de souza florianopolis
#
# Entities [('avenida ruy pereira dos santos', 'END_LOG')]
# rn massaranduba sao goncalo do amarante avenida ruy pereira dos santos 59290-000
#
# Entities [('r.gov.valadares,14', 'END_LOG')]
# 37476-000 cristina centro terreo r.gov.valadares,14 mg
#
# Entities [('pca.manoel alves lira, 6', 'END_LOG')]
# pca.manoel alves lira, 6 santa cruz da vitoria centro ba 45725-000
#
# Entities [('av. das americas', 'END_LOG')]
# rj rio de janeiro 22793-081 av. das americas barra da tijuca - bloco 1 loja 140,141,142,143,113 e 114
#
# Entities [('av.rio grande do sul,90-e', 'END_LOG')]
# av.rio grande do sul,90-e 78455-000  centro lucas do rio verde mt
#
# Entities [('pca.da bandeira,228', 'END_LOG')]
# centro mg pca.da bandeira,228 cachoeira de minas 37545-000
#
# Entities [('av.carlos hugueney,876', 'END_LOG')]
# mt av.carlos hugueney,876 centro  alto araguaia 78780-000
#
# Entities [('r.antonio de barros,468', 'END_LOG')]
# r.antonio de barros,468 sao paulo sp  03089-000 tatuape
#
# Entities [('av. barao do rio branco 2519', 'END_LOG')]
# av. barao do rio branco 2519 36010-311 juiz de fora centro mg
#
# Entities [('av. presidente castelo branco, 2046', 'END_LOG')]
# pr av. presidente castelo branco, 2046 87560-000 centro ipora
#
# Entities [('praa janurio valrio, 200', 'END_LOG')]
# 35668-000 centro praa janurio valrio, 200 mg conceicao do para
#
# Entities [('av. 27 de maro,', 'END_LOG')]
# 59584-000 av. 27 de maro, rn touros centro
#
# Entities [('r.dr.carvalho de mendonca,325', 'END_LOG')]
# r.dr.carvalho de mendonca,325 sp 11070-101 v.belmiro santos
#
# Entities [('praca otavio mangabeira, 108', 'END_LOG')]
# ba itabuna 45600-190 360305 praca otavio mangabeira, 108 centro
#
# Entities [('av. ayrton senna, 542', 'END_LOG')]
# av. ayrton senna, 542 centro parte paraiba do sul rj 25850-000
#
# Entities [('av. conselheiro rodrigues alves, n 65', 'END_LOG')]
# sp sao paulo 04014-010  vila mariana av. conselheiro rodrigues alves, n 65
#
# Entities [('rua moraes do rego, 108', 'END_LOG')]
# sp vila industrial  rua moraes do rego, 108 aluminio 18125-000
#
# Entities [('pca.luiz teofilo s/n.', 'END_LOG')]
# centro 45320-000 pca.luiz teofilo s/n. santa ines ba
# Entities [('r.frei gaspar,433', 'END_LOG')]
# centro  sao vicente 11310-060 r.frei gaspar,433 sp
#
# Entities [('praa alfredo egydio de souza aranha, 10', 'END_LOG')]
# sp praa alfredo egydio de souza aranha, 10 parque jabaquara 04344-902 0  torre conceio - 9 andar sao paulo
#
# Entities [('av. sao paulo, 925', 'END_LOG')]
# 18013-002  sp av. sao paulo, 925 sorocaba alem ponte
#
# Entities [('pca.cirilo sabath,s/n', 'END_LOG')]
# centro iaciara  go 73920-000 pca.cirilo sabath,s/n
#
# Entities [('avenida porto alegre', 'END_LOG')]
# sorriso avenida porto alegre mt 78890-000 centro
#
# Entities [('praca panamericana, 100', 'END_LOG')]
# sao paulo 05461-000 alto de pinheiros praca panamericana, 100 sp pavimento superior
#
# Entities [('rua humaita, 135-a - loja a', 'END_LOG')]
# rio de janeiro rua humaita, 135-a - loja a botafogo rj 22261-000
#
# Entities [('av. getulio vargas', 'END_LOG')]
# imperatriz beira rio  ma av. getulio vargas 65900-120
#
# Entities [('praa cvica , rea especial 4, lotes 3a', 'END_LOG')]
# go praa cvica , rea especial 4, lotes 3a 73750-005 setor oeste planaltina
#
# Entities [('r voluntarios da patria, 479', 'END_LOG')]
# rj  rio de janeiro r voluntarios da patria, 479 humaita 22270-007
#
# Entities [('rua dr. xavier da silva, 834', 'END_LOG')]
# rua dr. xavier da silva, 834 centro  86410-000 pr ribeirao claro
#
# Entities [('av. gov.pedro de toledo, 1243', 'END_LOG')]
# av. gov.pedro de toledo, 1243 campinas bonfim 13070-000  sp
#
# Entities [('rua ibitirama, 88', 'END_LOG')]
# 03134-000 sao paulo sp rua ibitirama, 88 vila prudente pav. superior
#
# Entities [('rua bom jesus de pirapora, 2763', 'END_LOG')]
# rua bom jesus de pirapora, 2763 13206-305 jundiai vila rami  sp
#
# Entities [('rua dr. zoilo meira simoes, 461', 'END_LOG')]
# figueira 84286-000  rua dr. zoilo meira simoes, 461 centro pr
#
# Entities [('av. t 07, quadra 41, lote 2, nr. 933', 'END_LOG')]
# setor bueno av. t 07, quadra 41, lote 2, nr. 933 go goiania 74210-265
#
# Entities [('pca.joao maccagnan,350', 'END_LOG')]
# pca.joao maccagnan,350 agua doce 89654-000 centro sc
#
# Entities [('av.juscelino kubitscheck, 1220', 'END_LOG')]
# dom eliseu  centro av.juscelino kubitscheck, 1220 pa 68633-000
#
# Entities [('av. cel norberto lima, 34', 'END_LOG')]
# conceicao do araguaia 68540-000  av. cel norberto lima, 34 centro pa
#
# Entities [('av joao cesar de oliveira', 'END_LOG')]
# 00000-000  av joao cesar de oliveira contagem eldorado mg
#
# Entities [('av.dr.olavo guimaraes,250', 'END_LOG')]
# sp v.arens av.dr.olavo guimaraes,250 jundiai 13201-760
#
# Entities [('avenida joao firmino, 610', 'END_LOG')]
# sp centro  sao bernardo do campo avenida joao firmino, 610 98119-700

# %% [markdown]
# Frase qualquer

# %%
phrase = "SHVP Rua 12 435 casa 22 lote 1"

doc = nlp(phrase)
print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
print(phrase)
# Out:
# Entities [('Rua 12 435', 'END_LOG')]
# SHVP Rua 12 435 casa 22 lote 1
