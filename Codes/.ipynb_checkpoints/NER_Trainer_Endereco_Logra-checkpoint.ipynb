# %%
# Load Packages
from __future__ import unicode_literals, print_function

import plac #  wrapper over argparse
import random
from pathlib import Path
import spacy
from tqdm import tqdm, tqdm_notebook # loading bar 
import pandas as pd
import re
from pprint import pprint
from nltk.tokenize import sent_tokenize
import numpy as np
import unicodedata
from spacy.util import minibatch, compounding

# %%
# Função para substituir acentos

def strip_accents(text):
    try:
        text = unicode(text, 'utf-8')
    except (TypeError, NameError): # unicode is a default on python 3 
        pass
    text = unicodedata.normalize('NFD', text)
    text = text.encode('ascii', 'ignore')
    text = text.decode("utf-8")
    
    return str(text)

# %% [markdown]
# # Abrindo e gerando Datasets

# %% [markdown]
# ### Entidade logradouro

# %%
# Obtendo dados crus de endereço

dataset = pd.read_csv("../Datasets/201906AGENCIAS.CSV")
dset = dataset.iloc[:-2,4:10].values  # tipo nparray object
pd_dset = pd.DataFrame(dset) # caso queira visualizar

pd_dset['Join'] = pd_dset[pd_dset.columns[0:]].apply(
    lambda x: ';'.join(x.dropna().astype(str)),
    axis=1
)
pd_dset.head(5)
# Out:
#                                           0  \
# 0  R.GUILHERME MOREIRA,315
# 1  AV.PRES.VARGAS,248
# 2  R.QUINZE DE NOVEMBRO,195
# 3  PCA.DAS QUATRO JORNADAS,11
# 4  SEXTA AVENIDA,600
#
#                                                    1  \
# 0  SUBLOJA,LOJA E 2.ANDAR                        ...
# 1  1.E 2.ANDARES                                 ...
# 2                                                ...
# 3  MEZANINO                                      ...
# 4  SECRETARIA DA EDUCACAO-TERREO                 ...
#
#                                 2          3  \
# 0  CENTRO                          69005-300
# 1  CAMPINA                         66010-900
# 2  CENTRO                          11010-908
# 3  CENTRO                          28010-000
# 4  CAB                             41745-002
#
#                                                    4   5  \
# 0  MANAUS                                        ...  AM
# 1  BELEM                                         ...  PA
# 2  SANTOS                                        ...  SP
# 3  CAMPOS DOS GOYTACAZES                         ...  RJ
# 4  SALVADOR                                      ...  BA
#
#                                                 Join
# 0  R.GUILHERME MOREIRA,315                 ;SUBLO...
# 1  AV.PRES.VARGAS,248                      ;1.E 2...
# 2  R.QUINZE DE NOVEMBRO,195                ;     ...
# 3  PCA.DAS QUATRO JORNADAS,11              ;MEZAN...
# 4  SEXTA AVENIDA,600                       ;SECRE...

# %%
# Tratando endereço completo do DataFrame
dset = np.array(pd_dset)
end_lista = []

for i in range(len(dset)):
    str_raw = dset[i][6]
    str_tratada = re.sub(r'[ ]{2,}', "",str_raw) # Tirando espaços excedentes no final do endereço
    str_tratada = re.sub(r'[;]{1,}', "; ", str_tratada) # Para complementos vazios, para não ter 2 ";"
    str_tratada = str_tratada.lower() # Tudo em minúsculo
    str_tratada = strip_accents(str_tratada) # Substituição de acentos e caracteres diferentes
    
    end_lista.append(str_tratada)

end_lista[:3]
# Out:
# ['r.guilherme moreira,315; subloja,loja e 2.andar; centro; 69005-300; manaus; am',
#  'av.pres.vargas,248; 1.e 2.andares; campina; 66010-900; belem; pa',
#  'r.quinze de novembro,195; centro; 11010-908; santos; sp']

# %%
# Lógica para extrair posição do logradouro:
# Dividir a String inteira por ";", pegar o len do primeiro split
# len de LOGRA é de 0 até len do primeiro split

print(end_lista[0])
split = end_lista[0].split(";")
print(split)
print(split[0])
print(len(split[0]))
# Out:
# r.guilherme moreira,315; subloja,loja e 2.andar; centro; 69005-300; manaus; am
# ['r.guilherme moreira,315', ' subloja,loja e 2.andar', ' centro', ' 69005-300', ' manaus', ' am']
# r.guilherme moreira,315
# 23

# %%
# Extraindo iob com entidade apenas de logradouro

iob = []

for i in range(len(end_lista)):
    split = end_lista[i].split(";")
    len_logra = len(split[0])
    iob_dict = {"entities": [(0, len_logra-1,'LOGRA')]}
    
    end_lista[i] = end_lista[i].replace(";", " ")
    end_lista[i] = end_lista[i].replace(",", " ")
    end_lista[i] = re.sub(r'[ ]{2,}', " ", end_lista[i])

    
    tupla = (end_lista[i], iob_dict)
    iob.append(tupla)

FULL_DATA = iob

# %%
print(FULL_DATA[0])
print(FULL_DATA[1])
print(FULL_DATA[2])
print(FULL_DATA[5:15])
# Out:
# ('r.guilherme moreira 315 subloja loja e 2.andar centro 69005-300 manaus am', {'entities': [(0, 22, 'LOGRA')]})
# ('av.pres.vargas 248 1.e 2.andares campina 66010-900 belem pa', {'entities': [(0, 17, 'LOGRA')]})
# ('r.quinze de novembro 195 centro 11010-908 santos sp', {'entities': [(0, 23, 'LOGRA')]})
# [('av.rio branco 240 1.andar recife antigo 50030-310 recife pe', {'entities': [(0, 16, 'LOGRA')]}), ('av.santos dumont 2828 5.andar aldeota 60150-162 fortaleza ce', {'entities': [(0, 20, 'LOGRA')]}), ('pca.tiradentes 410 1.andar centro 80020-100 curitiba pr', {'entities': [(0, 17, 'LOGRA')]}), ('r.uruguai 185 5.andar centro 90010-901 porto alegre rs', {'entities': [(0, 12, 'LOGRA')]}), ('pca.1817 129 1.andar centro 58013-010 joao pessoa pb', {'entities': [(0, 11, 'LOGRA')]}), ('pca.odilon resende andrade 76 centro 37410-000 tres coracoes mg', {'entities': [(0, 28, 'LOGRA')]}), ('av fernandes lima 2591 terreo farol 57057-972 maceio al', {'entities': [(0, 22, 'LOGRA')]}), ('r.treze de junho 914 centro 79300-040 corumba ms', {'entities': [(0, 19, 'LOGRA')]}), ('av.leopoldino de oliveira 3635 centro 38010-000 uberaba mg', {'entities': [(0, 29, 'LOGRA')]}), ('pca.quinze de novembro 321 centro 88010-400 florianopolis sc', {'entities': [(0, 25, 'LOGRA')]})]

# %%
# Criação da base de teste e treinamento

n_test= 0.1 # Porcentagem para base de teste
test_n = round(len(FULL_DATA) * n_test)

# Divisao em Train Test Val

def gerador_bases(dataset, n):
    indices_random = random.sample(range(0,len(dataset)-1), n)
    base_teste_n = []
    base_treinamento_n = []
    
    for i in range(n):
        base_teste_n.append(dataset[indices_random[i]])

    for j in range(len(dataset)):
        if(j not in indices_random):
            base_treinamento_n.append(dataset[j])
            
    return base_teste_n, base_treinamento_n


base_teste, base_treinamento = gerador_bases(FULL_DATA, test_n)

random.shuffle(base_treinamento)
random.shuffle(base_teste)

print("Treinamento: " + str(len(base_treinamento)), "\nTeste: " + str(len(base_teste)), "\nTotal: " + str(len(FULL_DATA)))
# Out:
# Treinamento: 19202
# Teste: 2134
# Total: 21336

# %%
for i in range(5):
    print(base_treinamento[i])
# Out:
# ('rua presidente lucena 3586 centro 93600-000 estancia velha rs', {'entities': [(0, 26, 'LOGRA')]})
# ('rua 15 de novembro 99450-000 selbach rs', {'entities': [(0, 17, 'LOGRA')]})
# ('av.dom pedro ii 688 centro 27570-000 porto real rj', {'entities': [(0, 19, 'LOGRA')]})
# ('rua getulio vargas 220 centro 84320-000 reserva pr', {'entities': [(0, 22, 'LOGRA')]})
# ('av.mal.deodoro 494 jd.sta.clara 12080-080 taubate sp', {'entities': [(0, 17, 'LOGRA')]})

# %% [markdown]
# # Carregando o modelo

# %%
# Define our variables

model = None
output_dir=Path(".")
n_iter= 50 # número de épocas
batch_size = 64

# %%
# Setting up the pipeline and entity recognizer.
if model is not None:
    nlp = spacy.load(model)  # load existing spacy model
    print("Loaded model '%s'" % model)
else:
    lan = 'pt'
    nlp = spacy.blank(lan)  # create blank Language class
    print("Created blank '%s' model" % lan)
    
if 'ner' not in nlp.pipe_names:
    ner = nlp.create_pipe('ner')
    nlp.add_pipe(ner)
    print('Added new NER')
else:
    ner = nlp.get_pipe('ner')
    print('Got an old NER')
# Out:
# Created blank 'pt' model
# Added new NER

# %%
# create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
if 'ner' not in nlp.pipe_names:
    ner = nlp.create_pipe('ner')
    nlp.add_pipe(ner, last=True)
# otherwise, get it so we can add labels
else:
    ner = nlp.get_pipe('ner')

# %% [markdown]
# ## Treinamento

# %%
print("Batch size: ", batch_size)
print("Épocas: ", n_iter)
print()

# add labels
for _, annotations in base_treinamento:
    for ent in annotations.get('entities'):
        ner.add_label(ent[2])


# get names of other pipes to disable them during training
other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
with nlp.disable_pipes(*other_pipes):  # only train NER
    optimizer = nlp.begin_training()
    for itn in range(n_iter):
        random.shuffle(base_treinamento)
        losses = {}
        batches = minibatch(base_treinamento, size=batch_size)
        
        for batch in batches:
            texts, annotations = zip(*batch)
            try:
                nlp.update(texts, annotations, sgd=optimizer, drop=0.2,
                       losses=losses)
            except:
                pass     
        
        print(itn+1, '\tLosses', losses)
# Out:
# Batch size:  64
# Épocas:  50
#
# 1 	Losses {'ner': 22742.978502177502}
# 2 	Losses {'ner': 5340.102163684356}
# 3 	Losses {'ner': 3915.55731439995}
# 4 	Losses {'ner': 3848.1426914783983}
# 5 	Losses {'ner': 2895.59729868274}
# 6 	Losses {'ner': 2770.908736658325}
# 7 	Losses {'ner': 2939.555244507386}
# 8 	Losses {'ner': 2445.8564750558967}
# 9 	Losses {'ner': 2000.2272698108936}
# 10 	Losses {'ner': 1895.2004724781914}
# 11 	Losses {'ner': 1818.435842381205}
# 12 	Losses {'ner': 1955.8044033745732}
# 13 	Losses {'ner': 1544.8910712737256}
# 14 	Losses {'ner': 1595.870967454392}
# 15 	Losses {'ner': 1390.3102541812393}
# 16 	Losses {'ner': 1333.1235490445886}
# 17 	Losses {'ner': 1522.3777476201228}
# 18 	Losses {'ner': 1526.1900846198741}
# 19 	Losses {'ner': 1318.576249844566}
# 20 	Losses {'ner': 1174.933684216256}
# 21 	Losses {'ner': 1429.9398950556222}
# 22 	Losses {'ner': 1153.740232717059}
# 23 	Losses {'ner': 1303.05390478852}
# 24 	Losses {'ner': 1144.7554400201461}
# 25 	Losses {'ner': 945.9118389115044}
# 26 	Losses {'ner': 859.3334675713861}
# 27 	Losses {'ner': 847.8903763397926}
# 28 	Losses {'ner': 972.2663662885692}
# 29 	Losses {'ner': 742.3278510768132}
# 30 	Losses {'ner': 853.2616664282983}
# 31 	Losses {'ner': 816.634617900049}
# 32 	Losses {'ner': 798.3098443051819}
# 33 	Losses {'ner': 734.2916003090329}
# 34 	Losses {'ner': 714.7649326181938}
# 35 	Losses {'ner': 635.8678410689454}
# 36 	Losses {'ner': 823.4571420966743}
# 37 	Losses {'ner': 612.0787460031071}
# 38 	Losses {'ner': 752.2864760812338}
# 39 	Losses {'ner': 630.3081580357789}
# 40 	Losses {'ner': 726.8248285353492}
# 41 	Losses {'ner': 578.8008762261492}
# 42 	Losses {'ner': 648.1499445807958}
# 43 	Losses {'ner': 602.6417518092787}
# 44 	Losses {'ner': 628.5807514870794}
# 45 	Losses {'ner': 618.1186589240541}
# 46 	Losses {'ner': 696.6017530992842}
# 47 	Losses {'ner': 576.6666882344449}
# 48 	Losses {'ner': 668.5711732704773}
# 49 	Losses {'ner': 792.8194524585755}
# 50 	Losses {'ner': 764.2769611799573}

# %% [markdown]
# ## Teste

# %% [markdown]
# Base de Teste

# %%
# test the trained model
for text, _ in base_teste:
    doc = nlp(text)
    print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
    print(text)
    print()
# Out:
# Entities [('r do ouvidor', 'LOGRA')]
# r do ouvidor lj/ss - jirau centro 20040-031 rio de janeiro rj
#
# Entities [('pca. joviniano f. de oliveira s/n', 'LOGRA')]
# pca. joviniano f. de oliveira s/n centro 49580-000 areia branca se
#
# Entities [('av orival cndido luz de oliveira 5245', 'LOGRA')]
# av orival cndido luz de oliveira 5245 so vicente 94060-001 gravatai rs
#
# Entities [('rua desemb. medeiros correia s/n', 'LOGRA')]
# rua desemb. medeiros correia s/n centro 56200-000 ouricuri pe
#
# Entities [('rua fioravante milanez 159', 'LOGRA')]
# rua fioravante milanez 159 centro 92010-240 canoas rs
#
# Entities [('rua coronel quirino 786', 'LOGRA')]
# rua coronel quirino 786 esq.c/a rua gal.osorio cambui 13025-001 campinas sp
#
# Entities [('rua castro alves 1847', 'LOGRA')]
# rua castro alves 1847 centro 85801-150 cascavel pr
#
# Entities [('rua rsula paulino 1177', 'LOGRA')]
# rua rsula paulino 1177 betnia 30570-000 belo horizonte mg
#
# Entities [('pca.barao de cambui 189', 'LOGRA')]
# pca.barao de cambui 189 centro 37980-000 cassia mg
#
# Entities [('rua coronel joo camargos 56', 'LOGRA')]
# rua coronel joo camargos 56 centro 32040-620 contagem mg
#
# Entities [('av.casa grande 2591', 'LOGRA')]
# av.casa grande 2591 jd.portinari 09961-350 diadema sp
#
# Entities [('r.juiz de fora 16', 'LOGRA')]
# r.juiz de fora 16 centro 35146-000 sao joao do oriente mg
#
# Entities [('av. iacanga 251', 'LOGRA')]
# av. iacanga 251 parte vila molon 13468-590 americana sp
#
# Entities [('av. ari ribeiro valado filho 767', 'LOGRA')]
# av. ari ribeiro valado filho 767 centro 73770-000 alto paraiso de goias go
#
# Entities [('r.uruguai 185 - 2.andar 2.andar', 'LOGRA')]
# r.uruguai 185 - 2.andar 2.andar centro 90010-140 porto alegre rs
#
# Entities [('scs quadra 4 bloco a', 'LOGRA')]
# scs quadra 4 bloco a ed.vera cruz-s asa sul 70304-913 brasilia df
#
# Entities [('rua quinze de novembro s/n', 'LOGRA')]
# rua quinze de novembro s/n. esq.c/rua gomes porto centro 25804-000 tres rios rj
#
# Entities [('rua jeronimo rosado', 'LOGRA')]
# rua jeronimo rosado centro 59695-000 barauna rn
#
# Entities [('r onze de agosto 140', 'LOGRA')]
# r onze de agosto 140 centro 18270-001 tatui sp
#
# Entities [('avenida delfim moreira quadra 22 lote 1', 'LOGRA')]
# avenida delfim moreira quadra 22 lote 1 centro 86350-000 santa mariana pr
#
# Entities [('av.cel.cordeiro 496', 'LOGRA')]
# av.cel.cordeiro 496 centro 64255-000 pedro ii pi
#
# Entities [('rua henrique schamadeke', 'LOGRA')]
# rua henrique schamadeke centro 98750-000 ajuricaba rs
#
# Entities [('av. nossa senhora do carmo 344', 'LOGRA')]
# av. nossa senhora do carmo 344 centro 76340-000 carmo do rio verde go
#
# Entities [('r.barao do amazonas 1347', 'LOGRA')]
# r.barao do amazonas 1347 centro 97770-000 nova esperanca do sul rs
#
# Entities [('r.das laranjeiras 408 410-lojas', 'LOGRA')]
# r.das laranjeiras 408 410-lojas laranjeiras 22240-000 rio de janeiro rj
#
# Entities [('r.da balanca 2-a', 'LOGRA')]
# r.da balanca 2-a predio centro 65370-000 pindare mirim ma
#
# Entities [('praa silvio de castro ribeiro 6', 'LOGRA')]
# praa silvio de castro ribeiro 6 centro 76330-000 jaragua go
#
# Entities [('rua manoel aguiar 37', 'LOGRA')]
# rua manoel aguiar 37 centro 12850-000 bananal sp
#
# Entities [('avenida salime nacif', 'LOGRA')]
# avenida salime nacif baixada 36900-000 manhuacu mg
#
# Entities [('av.sete de setembro dois de', 'LOGRA')]
# av.sete de setembro dois de julho 40060-001 salvador ba
#
# Entities [('av. pedroso de moraes 494', 'LOGRA')]
# av. pedroso de moraes 494 pinheiros 05420-000 sao paulo sp
#
# Entities [('r.exuperio miranda 10 proximo ao', 'LOGRA')]
# r.exuperio miranda 10 proximo ao mercado municipal centro 45225-000 jitauna ba
#
# Entities [('av.sumare 1231', 'LOGRA')]
# av.sumare 1231 perdizes 05016-110 sao paulo sp
#
# Entities [('av santos dumont', 'LOGRA')]
# av santos dumont coco 60192-022 fortaleza ce
#
# Entities [('rua major claudiano 1932', 'LOGRA')]
# rua major claudiano 1932 centro 14400-690 franca sp
#
# Entities [('avenida parigot de souza', 'LOGRA')]
# avenida parigot de souza vila industrial 85904-270 toledo pr
#
# Entities [('av.erasto gaertner 160', 'LOGRA')]
# av.erasto gaertner 160 bacacheri 82510-160 curitiba pr
#
# Entities [('praa coronel benjamim guimares', 'LOGRA')]
# praa coronel benjamim guimares edifcio all business center sala 1.201 funcionrios 30130-030 belo horizonte mg
#
# Entities [('av francisco ferreira lopes 2737/rua schwartzmann', 'LOGRA')]
# av francisco ferreira lopes 2737/rua schwartzmann centro 88500-000 mogi das cruzes sp
#
# Entities [('av. sapopemba 2923', 'LOGRA')]
# av. sapopemba 2923 vila diva 03345-001 sao paulo sp
#
# Entities [('r maranhao 167', 'LOGRA')]
# r maranhao 167 pinheiro machado 97030-350 santa maria rs
#
# Entities [('av.d.perola byington 1395', 'LOGRA')]
# av.d.perola byington 1395 centro 87540-000 perola pr
#
# Entities [('av nove de julho 1650', 'LOGRA')]
# av nove de julho 1650 loja 1c chacara urbana 13208-010 jundiai sp
#
# Entities [('avenida teotonio vilela 89', 'LOGRA')]
# avenida teotonio vilela 89 centro 46875-000 itatim ba
#
# Entities [('rua baro de jacegua', 'LOGRA')]
# rua baro de jacegua ponta d'areia 24048-900 niteroi rj
#
# Entities [('av dona belmira marin 20282040', 'LOGRA')]
# av dona belmira marin 20282040 parque brasil 04846-000 sao paulo sp
#
# Entities [('rua monsenhor rosa 1659', 'LOGRA')]
# rua monsenhor rosa 1659 centro 14400-670 franca sp
#
# Entities [('av. ruda q. 41-a lts. 01/02', 'LOGRA')]
# av. ruda q. 41-a lts. 01/02 vila brasilia 74905-760 aparecida de goiania go
#
# Entities [('av. afonso pena 745', 'LOGRA')]
# av. afonso pena 745 terreo 1 2 3 e 4 andares centro 38400-130 uberlandia mg
#
# Entities [('avenida juscelino kubitschek 1400', 'LOGRA')]
# avenida juscelino kubitschek 1400 3 4 e 5 andares itaim bibi 04543-000 sao paulo sp
#
# Entities [('rua elpidio de almeida 125', 'LOGRA')]
# rua elpidio de almeida 125 catole 58410-298 campina grande pb
#
# Entities [('av cleto campelo', 'LOGRA')]
# av cleto campelo centro 54800-000 moreno pe
#
# Entities [('rua bueno de paiva 408', 'LOGRA')]
# rua bueno de paiva 408 centro 37660-000 paraisopolis mg
#
# Entities [('pca comendador martins set 1 q 10', 'LOGRA')]
# pca comendador martins set 1 q 10 lot 11 centro 13315-000 cabreuva sp
#
# Entities [('rea urbana 01', 'LOGRA')]
# rea urbana 01 q. 302 trreo ed. forum de samambaia 72300-630 brasilia (samambaia) df
#
# Entities [('av. duque de caxias 5-50', 'LOGRA')]
# av. duque de caxias 5-50 alto da cidade 17040-341 bauru sp
#
# Entities [('r.dr.alfredo guedes 40', 'LOGRA')]
# r.dr.alfredo guedes 40 centro 13710-000 tambau sp
#
# Entities [('av. brasil 2105', 'LOGRA')]
# av. brasil 2105 vila operria 87050-000 maringa pr
#
# Entities [('avenida pedro adams filho n 3233', 'LOGRA')]
# avenida pedro adams filho n 3233 ptria nova 93320-004 novo hamburgo rs
#
# Entities [('pca.do comercio 55', 'LOGRA')]
# pca.do comercio 55 centro 44970-000 ibipeba ba
#
# Entities [('av. antonio carlos magalhes 3.359', 'LOGRA')]
# av. antonio carlos magalhes 3.359 lojas 2 e 3 parque bela vista 40280-000 salvador ba
#
# Entities [('av. marechal tito num 4027', 'LOGRA')]
# av. marechal tito num 4027 itaim paulista 81151-000 sao paulo sp
#
# Entities [('av. das americas 15545', 'LOGRA')]
# av. das americas 15545 rec.dos bandeirantes 22790-700 rio de janeiro rj
#
# Entities [('av.saul elkind 1510', 'LOGRA')]
# av.saul elkind 1510 conjunto habitacional violim 86084-000 londrina pr
#
# Entities [('r.vinte e quatro de maio 330', 'LOGRA')]
# r.vinte e quatro de maio 330 centro 69010-080 manaus am
#
# Entities [('av.manoel ribas 1556', 'LOGRA')]
# av.manoel ribas 1556 merces 80810-000 curitiba pr
#
# Entities [('avenida santos dumont 2500', 'LOGRA')]
# avenida santos dumont 2500 lj 8 a 14 aldeota 60150-161 fortaleza ce
#
# Entities [('r.ceferino barbosa 401', 'LOGRA')]
# r.ceferino barbosa 401 centro 99360-000 barros cassal rs
#
# Entities [('rua ismael lobo', 'LOGRA')]
# rua ismael lobo centro 88495-000 garopaba sc
#
# Entities [('rua coronel altino de freitas ed', 'LOGRA')]
# rua coronel altino de freitas ed. antnio loureiro centro 39400-023 montes claros mg
#
# Entities [('rua quinze de novembro 849', 'LOGRA')]
# rua quinze de novembro 849 segundo piso centro 89010-001 blumenau sc
#
# Entities [('av. andr arajo 87', 'LOGRA')]
# av. andr arajo 87 aleixo 69060-000 manaus am
#
# Entities [('av.dr.jesuino marcondes machado 160', 'LOGRA')]
# av.dr.jesuino marcondes machado 160 nova campinas 13092-108 campinas sp
#
# Entities [('rua sete de setembro', 'LOGRA')]
# rua sete de setembro centro 90010-191 porto alegre rs
#
# Entities [('av rio das pedras 3460', 'LOGRA')]
# av rio das pedras 3460 jd aricanduva 03930-300 sao paulo sp
# Entities [('av.prof.ana maria silvestre adade s/n', 'LOGRA')]
# av.prof.ana maria silvestre adade s/n puc campinas parque das universidades 13086-130 campinas sp
#
# Entities [('rua izabel bueno 775', 'LOGRA')]
# rua izabel bueno 775 jaragu 31270-030 belo horizonte mg
#
# Entities [('av.senador levindo coelho 1923', 'LOGRA')]
# av.senador levindo coelho 1923 vale do jatoba 30664-030 belo horizonte mg
#
# Entities [('pca.pe.mateus 239', 'LOGRA')]
# pca.pe.mateus 239 predio centro 44571-350 santo antonio de jesus ba
#
# Entities [('av pres valentim', 'LOGRA')]
# av pres valentim gentil centro 14900-000 itapolis sp
#
# Entities [('av. couto de magalhes 2.815', 'LOGRA')]
# av. couto de magalhes 2.815 centro norte 78110-400 varzea grande mt
#
# Entities [('avenida do contorno 7777', 'LOGRA')]
# avenida do contorno 7777 1 andar lourdes 30110-051 belo horizonte mg
#
# Entities [('av. ibirapuera 2220', 'LOGRA')]
# av. ibirapuera 2220 indianopolis 04028-001 sao paulo sp
#
# Entities [('av.patricio lima 1101', 'LOGRA')]
# av.patricio lima 1101 humaita 88704-410 tubarao sc
#
# Entities [('av joao ramalho 1779', 'LOGRA')]
# av joao ramalho 1779 parque sao vicente 09371-520 maua sp
#
# Entities [('r jose vedovatto 1790', 'LOGRA')]
# r jose vedovatto 1790 jardim denadai 13181-440 sumare sp
#
# Entities [('rodovia br 381 n.723', 'LOGRA')]
# rodovia br 381 n.723 60746948 inconfidentes 32223-570 contagem mg
#
# Entities [('av.afonso pena 745', 'LOGRA')]
# av.afonso pena 745 centro 38390-000 centralina mg
#
# Entities [('av. iva 426', 'LOGRA')]
# av. iva 426 centro 87155-000 doutor camargo pr
#
# Entities [('avenida santos dumont n 501', 'LOGRA')]
# avenida santos dumont n 501 loja 10 - parte centro 42700-000 lauro de freitas ba
#
# Entities [('av.juvenal de castro 137', 'LOGRA')]
# av.juvenal de castro 137 centro 62880-000 horizonte ce
#
# Entities [('r 04 de dezembro', 'LOGRA')]
# r 04 de dezembro centro 87660-000 paranacity pr
#
# Entities [('rua quintino bocaiuva 580', 'LOGRA')]
# rua quintino bocaiuva 580 moinhos de vento 90440-050 porto alegre rs
#
# Entities [('rua olegrio maciel', 'LOGRA')]
# rua olegrio maciel centro centro 38700-122 patos de minas mg
#
# Entities [('rua baro de penedo', 'LOGRA')]
# rua baro de penedo centro 57020-340 maceio al
#
# Entities [('alameda barao de limeira 966', 'LOGRA')]
# alameda barao de limeira 966 pavimento superior campos eliseos 01202-002 sao paulo sp
#
# Entities [('avenida ayrton senna parte 3 bloco', 'LOGRA')]
# avenida ayrton senna parte 3 bloco itanhang sala 3105 barra da tijuca 22775-003 rio de janeiro rj
#
# Entities [('av. agamenon magalhes 1029', 'LOGRA')]
# av. agamenon magalhes 1029 mauricio de nassau 55014-000 caruaru pe
#
# Entities [('av.pres.vargas 963', 'LOGRA')]
# av.pres.vargas 963 centro 14860-000 barrinha sp
#
# Entities [('praca dos andradas 165', 'LOGRA')]
# praca dos andradas 165 centro 36200-000 barbacena mg
#
# Entities [('rua santa cruz 151', 'LOGRA')]
# rua santa cruz 151 centro 34000-000 nova lima mg
#
# Entities [('rua mexico 90', 'LOGRA')]
# rua mexico 90 centro 20031-141 rio de janeiro rj
#
# Entities [('largo do cambuci', 'LOGRA')]
# largo do cambuci cambuci 01523-010 sao paulo sp
#
# Entities [('av.vicente de carvalho 1578', 'LOGRA')]
# av.vicente de carvalho 1578 penha circular 21210-001 rio de janeiro rj
#
# Entities [('praca getulio vargas 25', 'LOGRA')]
# praca getulio vargas 25 centro 85539-000 clevelandia pr
#
# Entities [('estrada dos tres rios', 'LOGRA')]
# estrada dos tres rios parte freguesia 22745-005 rio de janeiro rj
#
# Entities [('rua dr.jose cezario bastos 138', 'LOGRA')]
# rua dr.jose cezario bastos 138 centro 11740-000 itanhaem sp
#
# Entities [('av. joao pessoa 1318', 'LOGRA')]
# av. joao pessoa 1318 azenha 90040-001 porto alegre rs
#
# Entities [('est taipas 355', 'LOGRA')]
# est taipas 355 jardim sao joao 02995-145 sao paulo sp
#
# Entities [('av.feliciano sodre 750', 'LOGRA')]
# av.feliciano sodre 750 agrioes 25953-670 teresopolis rj
#
# Entities [('rua dr joao pinheiro 281', 'LOGRA')]
# rua dr joao pinheiro 281 das gracas 35370-000 rio casca mg
#
# Entities [('rua bernardino fernandes nunes', 'LOGRA')]
# rua bernardino fernandes nunes salas 51 e 52 cidade jardim 13566-490 sao carlos sp
#
# Entities [('rua uruguai 155', 'LOGRA')]
# rua uruguai 155 centro 90010-140 porto alegre rs
#
# Entities [('r pedro de toledo 436 a 446/450', 'LOGRA')]
# r pedro de toledo 436 a 446/450 vila clementino 04039-001 sao paulo sp
#
# Entities [('avenida parnamirim 380', 'LOGRA')]
# avenida parnamirim 380 parnamirim 52060-000 recife pe
#
# Entities [('rua belo horizonte 82', 'LOGRA')]
# rua belo horizonte 82 sala 1 centro 83860-000 pien pr
#
# Entities [('rua coronel cazuzinha s/n', 'LOGRA')]
# rua coronel cazuzinha s/n. centro 46400-000 caetite ba
#
# Entities [('avenida getulio vargas 2795', 'LOGRA')]
# avenida getulio vargas 2795 qd h lt 36 niteri 92110-330 canoas rs
#
# Entities [('rua sete de setembro 599', 'LOGRA')]
# rua sete de setembro 599 centro 19700-000 paraguacu paulista sp
#
# Entities [('rua conego moreau 35', 'LOGRA')]
# rua conego moreau 35 centro 39391-000 bocaiuva mg
#
# Entities [('av.gov. flavio ribeiro coutinho 321', 'LOGRA')]
# av.gov. flavio ribeiro coutinho 321 manaira 58037-000 joao pessoa pb
#
# Entities [('av minas gerais 1313', 'LOGRA')]
# av minas gerais 1313 nossa senhora das gracas 35060-360 governador valadares mg
#
# Entities [('av presidente juscelino kubitschek', 'LOGRA')]
# av presidente juscelino kubitschek corao eucarstico 30535-485 belo horizonte mg
#
# Entities [('av. adolfo pinheiro 1912', 'LOGRA')]
# av. adolfo pinheiro 1912 parte santo amaro 04734-003 sao paulo sp
#
# Entities [('avenida independencia', 'LOGRA')]
# avenida independencia salas 402 e 403 - head tower cidade alta 13419-155 piracicaba sp
#
# Entities [('rua vieira machado 415', 'LOGRA')]
# rua vieira machado 415 centro 29480-000 muqui es
#
# Entities [('av.aclimacao - 651', 'LOGRA')]
# av.aclimacao - 651 aclimacao 01531-001 sao paulo sp
#
# Entities [('rua frei caneca 53/55', 'LOGRA')]
# rua frei caneca 53/55 centro 20211-005 rio de janeiro rj
#
# Entities [('avenida general carlos cavalcanti 1313', 'LOGRA')]
# avenida general carlos cavalcanti 1313 uvaranas 84025-000 ponta grossa pr
#
# Entities [('av.teotonio segurado 202 norte cj.1', 'LOGRA')]
# av.teotonio segurado 202 norte cj.1 lote 4 centro 77061-002 palmas to
#
# Entities [('avenida copacabana', 'LOGRA')]
# avenida copacabana balnerio monte carlo 11925-000 ilha comprida sp
#
# Entities [('r da quitanda 89-93', 'LOGRA')]
# r da quitanda 89-93 centro 01012-010 sao paulo sp
#
# Entities [('rua presidente vargas 596', 'LOGRA')]
# rua presidente vargas 596 centro 25802-200 tres rios rj
#
# Entities [('r.brasil 148', 'LOGRA')]
# r.brasil 148 centro 19830-000 echapora sp
#
# Entities [('av.antonio carlos magalhaes 580', 'LOGRA')]
# av.antonio carlos magalhaes 580 centro 46250-000 presidente janio quadros ba
#
# Entities [('pca. rui barbosa 752', 'LOGRA')]
# pca. rui barbosa 752 centro 86410-000 ribeirao claro pr
#
# Entities [('rua antonio agu n. 750/rua andre manojo', 'LOGRA')]
# rua antonio agu n. 750/rua andre manojo centro 06093-006 osasco sp
#
# Entities [('av.erasto gaertner 209', 'LOGRA')]
# av.erasto gaertner 209 1 andar bacacheri 82510-160 curitiba pr
#
# Entities [('av. presidente', 'LOGRA')]
# av. presidente kennedy esquina com rua carlos gomes cidade ocian 11705-000 praia grande sp
#
# Entities [('av eng. armando de arruda pereira 657', 'LOGRA')]
# av eng. armando de arruda pereira 657 jabaquara 04309-010 sao paulo sp
#
# Entities [('r.juvenal de melo senra 407', 'LOGRA')]
# r.juvenal de melo senra 407 belvedere 30320-660 belo horizonte mg
#
# Entities [('av. julio de castilho 210 / rua 3 de outubro', 'LOGRA')]
# av. julio de castilho 210 / rua 3 de outubro centro 95400-000 sao francisco de paula rs
#
# Entities [('rua a 126', 'LOGRA')]
# rua a 126 nova colonia 27570-000 porto real rj
#
# Entities [('av leitao da silva 1295', 'LOGRA')]
# av leitao da silva 1295 gurigica gurigica 29046-005 vitoria es
#
# Entities [('rua apresidente castelo 11', 'LOGRA')]
# rua apresidente castelo 11 centro 65716-000 paulo ramos ma
#
# Entities [('r.cel.lago junior 29', 'LOGRA')]
# r.cel.lago junior 29 centro 65515-000 buriti ma
#
# Entities [('r.paulo deslandes 35', 'LOGRA')]
# r.paulo deslandes 35 v.isa 35044-190 governador valadares mg
#
# Entities [('rua voluntarios da patria 1909', 'LOGRA')]
# rua voluntarios da patria 1909 conjunto 2 santana 02011-400 sao paulo sp
#
# Entities [('rua arthur bernardes num 527', 'LOGRA')]
# rua arthur bernardes num 527 centro 37970-000 pratapolis mg
# Entities [('av. liberdade 1030', 'LOGRA')]
# av. liberdade 1030 liberdade 15020-010 sao paulo sp
#
# Entities [('av. silva lobo', 'LOGRA')]
# av. silva lobo nova granada 30460-000 belo horizonte mg
#
# Entities [('avenida sete de setembro 2469', 'LOGRA')]
# avenida sete de setembro 2469 vitria 40080-003 salvador ba
#
# Entities [('praca juarez de souza 158', 'LOGRA')]
# praca juarez de souza 158 centro 47820-000 sao desiderio ba
#
# Entities [('r.vol.de sao paulo 2857 ao lado da catedral', 'LOGRA')]
# r.vol.de sao paulo 2857 ao lado da catedral centro 15015-200 sao jose do rio preto sp
#
# Entities [('rua juvenal de campos 981', 'LOGRA')]
# rua juvenal de campos 981 centro 14550-000 aramina sp
#
# Entities [('rua dr. rodrigues alves 886', 'LOGRA')]
# rua dr. rodrigues alves 886 centro 15820-000 pirangi sp
#
# Entities [('av. duque de caxias 1601', 'LOGRA')]
# av. duque de caxias 1601 jardim petropolis 86015-000 londrina pr
#
# Entities [('av. goias 743', 'LOGRA')]
# av. goias 743 centro 75800-012 jatai go
#
# Entities [('rua freitas de oliveira 203', 'LOGRA')]
# rua freitas de oliveira 203 centro 32400-000 ibirite mg
#
# Entities [('rua joao pessoa 147/151', 'LOGRA')]
# rua joao pessoa 147/151 centro 11010-150 santos sp
#
# Entities [('av. assis brasil', 'LOGRA')]
# av. assis brasil centro 95585-000 arroio do sal rs
#
# Entities [('av bruno zuttion', 'LOGRA')]
# av bruno zuttion centro 85770-000 realeza pr
#
# Entities [('sai/so area 6580 loja 118-i', 'LOGRA')]
# sai/so area 6580 loja 118-i parkshopping guar 71219-900 brasilia (guara) df
#
# Entities [('rua 22 537', 'LOGRA')]
# rua 22 537 360305 centro 38300-076 ituiutaba mg
#
# Entities [('cnb 12 lotes 17 e 18', 'LOGRA')]
# cnb 12 lotes 17 e 18 loja 01 - trreo taguatinga norte 72115-125 brasilia (taguatinga) df
#
# Entities [('r.pres.manoel f.de campos sales 1-c', 'LOGRA')]
# r.pres.manoel f.de campos sales 1-c jd.veraneio 79031-300 campo grande ms
#
# Entities [('av. londrina 678', 'LOGRA')]
# av. londrina 678 centro 87111-220 sarandi pr
#
# Entities [('avenida paranagua', 'LOGRA')]
# avenida paranagua vila paranagu 03806-010 sao paulo sp
#
# Entities [('praca tomaz barbosa', 'LOGRA')]
# praca tomaz barbosa centro 62700-000 caninde ce
#
# Entities [('rua do principe 547', 'LOGRA')]
# rua do principe 547 centro 89201-000 joinville sc
#
# Entities [('rua farroupilha 250', 'LOGRA')]
# rua farroupilha 250 centro 85880-000 sao miguel do iguacu pr
#
# Entities [('av. santos dumont condomnio shopping e feiraloja 7', 'LOGRA')]
# av. santos dumont condomnio shopping e feiraloja 7 estrada do coco 42700-000 lauro de freitas ba
#
# Entities [('rua xv de novembro', 'LOGRA')]
# rua xv de novembro centro 96310-000 herval rs
#
# Entities [('avenida senador salgado filho n 229', 'LOGRA')]
# avenida senador salgado filho n 229 loja centro 90010-221 porto alegre rs
#
# Entities [('av. cndido de abreu 745', 'LOGRA')]
# av. cndido de abreu 745 centro cvico 80530-000 curitiba pr
#
# Entities [('pca roberto silveira 15', 'LOGRA')]
# pca roberto silveira 15 centro 25070-005 duque de caxias rj
#
# Entities [('rua cardoso de almeida 1301', 'LOGRA')]
# rua cardoso de almeida 1301 perdizes 05013-001 sao paulo sp
#
# Entities [('praa ladislau cavalcanti s/n', 'LOGRA')]
# praa ladislau cavalcanti s/n centro 48370-000 esplanada ba
#
# Entities [('avenida governador julio campos', 'LOGRA')]
# avenida governador julio campos centro 78550-000 sinop mt
#
# Entities [('r.sete de setembro s/', 'LOGRA')]
# r.sete de setembro s/n centro 65284-000 governador nunes freire ma
#
# Entities [('rua piracicaba', 'LOGRA')]
# rua piracicaba cidade primavera i 78850-000 primavera do leste mt
#
# Entities [('r osmar semmer', 'LOGRA')]
# r osmar semmer centro 89340-000 itaiopolis sc
#
# Entities [('av. monteiro lobato 5251', 'LOGRA')]
# av. monteiro lobato 5251 360305 cidade jardim cumbica 07180-000 guarulhos sp
#
# Entities [('setor norte com local 114 lt d', 'LOGRA')]
# setor norte com local 114 lt d lj 2 pav - terreo e superior santa maria 72544-204 brasilia df
#
# Entities [('shcs cr qd 510 bloco b w3', 'LOGRA')]
# shcs cr qd 510 bloco b w3 loja 75 asa sul 70360-525 brasilia df
#
# Entities [('rua dr. melo viana 91', 'LOGRA')]
# rua dr. melo viana 91 centro 37200-000 lavras mg
#
# Entities [('pca.garcia paes leme 130', 'LOGRA')]
# pca.garcia paes leme 130 centro 25850-000 paraiba do sul rj
#
# Entities [('r.pe.joao madruga 110', 'LOGRA')]
# r.pe.joao madruga 110 predio centro 58275-000 itapororoca pb
#
# Entities [('ruacel joao camilo', 'LOGRA')]
# ruacel joao camilo centro 75240-000 bela vista de goias go
#
# Entities [('av.pedro segundo 266', 'LOGRA')]
# av.pedro segundo 266 centro 37470-000 sao lourenco mg
#
# Entities [('r.rocha pontual 82', 'LOGRA')]
# r.rocha pontual 82 centro 55515-000 amaraji pe
#
# Entities [('av ver. jorge de souza 597', 'LOGRA')]
# av ver. jorge de souza 597 centro 06803-270 embu das artes sp
#
# Entities [('av.colares moreira s/', 'LOGRA')]
# av.colares moreira s/n qd.ac 1 lote 1 renascenca ii 65075-441 sao luis ma
#
# Entities [('scn qd.2 bloco d loja t 43/53', 'LOGRA')]
# scn qd.2 bloco d loja t 43/53 terreo shopping liberty mall setor comercial norte 70712-904 brasilia df
#
# Entities [('av.governador celso ramos 1098', 'LOGRA')]
# av.governador celso ramos 1098 centro 89248-000 garuva sc
#
# Entities [('av. julio de castilhos 1565', 'LOGRA')]
# av. julio de castilhos 1565 cinquentenario 95010-003 caxias do sul rs
#
# Entities [('rua e 427', 'LOGRA')]
# rua e 427 cidade nova 68515-000 parauapebas pa
#
# Entities [('av.londres 616', 'LOGRA')]
# av.londres 616 bonsucesso 21041-030 rio de janeiro rj
#
# Entities [('rua sao', 'LOGRA')]
# rua sao loureno 97980-000 sao paulo das missoes rs
#
# Entities [('av. antonio carlos magalhaes', 'LOGRA')]
# av. antonio carlos magalhaes loja 6 itaigara 41825-900 salvador ba
#
# Entities [('rua da conceicao 361', 'LOGRA')]
# rua da conceicao 361 360305 centro 63180-000 juazeiro do norte ce
#
# Entities [('r.mariz e barros 13', 'LOGRA')]
# r.mariz e barros 13 loja a pca.da bandeira 20270-005 rio de janeiro rj
#
# Entities [('rua timbiras 3109', 'LOGRA')]
# rua timbiras 3109 sala 203 barro preto 30140-062 belo horizonte mg
#
# Entities [('rua comendador custodio num 70', 'LOGRA')]
# rua comendador custodio num 70 centro 12620-000 piquete sp
#
# Entities [('rua general marques 1112', 'LOGRA')]
# rua general marques 1112 centro 97670-000 sao borja rs
#
# Entities [('av. antonio piranga 433', 'LOGRA')]
# av. antonio piranga 433 centro 09911-160 diadema sp
#
# Entities [('rua marechal deodoro 673', 'LOGRA')]
# rua marechal deodoro 673 1 andar centro 09710-011 sao bernardo do campo sp
#
# Entities [('r felicio marcondes', 'LOGRA')]
# r felicio marcondes centro 07010-030 guarulhos sp
#
# Entities [('rua dias da cruz 240', 'LOGRA')]
# rua dias da cruz 240 meier 20720-012 rio de janeiro rj
#
# Entities [('rua dr. joao colin 259', 'LOGRA')]
# rua dr. joao colin 259 centro 89201-300 joinville sc
#
# Entities [('alameda barao de limeira 830', 'LOGRA')]
# alameda barao de limeira 830 e 836 campos eliseos 12020-020 sao paulo sp
#
# Entities [('rua totonho filgueira 365', 'LOGRA')]
# rua totonho filgueira 365 centro 63180-000 barbalha ce
#
# Entities [('av.sao miguel 4606', 'LOGRA')]
# av.sao miguel 4606 ponte rasa 03870-000 sao paulo sp
#
# Entities [('av. soares', 'LOGRA')]
# av. soares lopes cidade nova 45652-065 ilheus ba
#
# Entities [('rua taipas 432', 'LOGRA')]
# rua taipas 432 v.barcelona 09560-200 sao caetano do sul sp
#
# Entities [('av.juscelino kubitschek 904', 'LOGRA')]
# av.juscelino kubitschek 904 predio centro 78810-000 juscimeira mt
#
# Entities [('rua joaquim nabuco 951', 'LOGRA')]
# rua joaquim nabuco 951 centro 93310-002 novo hamburgo rs
#
# Entities [('praca frederico lundgren g/1', 'LOGRA')]
# praca frederico lundgren g/1 centro 53401-250 paulista pe
#
# Entities [('avenida nogueira da gama', 'LOGRA')]
# avenida nogueira da gama loja 2 centro 29900-040 linhares es
#
# Entities [('av.jabaquara 1337', 'LOGRA')]
# av.jabaquara 1337 mirandopolis 04046-200 sao paulo sp
#
# Entities [('praca comendador emilio pedutti 59', 'LOGRA')]
# praca comendador emilio pedutti 59 centro 18600-410 botucatu sp
#
# Entities [('av. dom pedro ii 424', 'LOGRA')]
# av. dom pedro ii 424 centro 68440-000 abaetetuba pa
#
# Entities [('avenida rui barbosa', 'LOGRA')]
# avenida rui barbosa heliopolis 55296-300 garanhuns pe
#
# Entities [('scs quadra 6 bloco a', 'LOGRA')]
# scs quadra 6 bloco a loja 76 centro 70300-500 brasilia df
#
# Entities [('rua 83 quadra f-13 lote 25', 'LOGRA')]
# rua 83 quadra f-13 lote 25 setor sul 74083-230 goiania go
#
# Entities [('rua major jose inacio - 2066', 'LOGRA')]
# rua major jose inacio - 2066 centro 13560-160 sao carlos sp
#
# Entities [('av. conselheiro carrao 3062', 'LOGRA')]
# av. conselheiro carrao 3062 chacara california 03402-003 sao paulo sp
#
# Entities [('r.j.j.seabra 31', 'LOGRA')]
# r.j.j.seabra 31 centro 45638-000 coaraci ba
#
# Entities [('avenida coronel silva telles', 'LOGRA')]
# avenida coronel silva telles lt 1 quarteiro410 cambu 13024-001 campinas sp
#
# Entities [('av. guapira 2.383', 'LOGRA')]
# av. guapira 2.383 parte tucuruvi 02265-002 sao paulo sp
#
# Entities [('rua barao de souza leao', 'LOGRA')]
# rua barao de souza leao quadra 8 lotes 8 ao 15 boa viagem 51030-300 recife pe
#
# Entities [('av.geraldo romano 88', 'LOGRA')]
# av.geraldo romano 88 centro 39860-000 nanuque mg
#
# Entities [('r.antonio maia 833', 'LOGRA')]
# r.antonio maia 833 vl perus 05204-000 sao paulo sp
#
# Entities [('rua lauro muller 20 and sala 2001', 'LOGRA')]
# rua lauro muller 20 and sala 2001 botafogo 22290-160 rio de janeiro rj
#
# Entities [('rua professor alosio pessoa de arajo', 'LOGRA')]
# rua professor alosio pessoa de arajo loja 1-b - bloco hotel boa viagem 51021-410 recife pe
#
# Entities [('av agamenon', 'LOGRA')]
# av agamenon magalhes prado 55642-210 gravata pe
#
# Entities [('rua sao francisco 993 e 1065', 'LOGRA')]
# rua sao francisco 993 e 1065 centro 57300-085 arapiraca al
#
# Entities [('avenida venancio aires s/n 10', 'LOGRA')]
# avenida venancio aires s/n 10 circunscrio do servio militar centro 98801-660 santo angelo rs
#
# Entities [('rua imp. pedro segundo 255', 'LOGRA')]
# rua imp. pedro segundo 255 loja santo antonio 50010-240 recife pe
#
# Entities [('pc.vigario antonio joaquim 22', 'LOGRA')]
# pc.vigario antonio joaquim 22 2.andar - sala exclusivo centro 59600-520 mossoro rn
#
# Entities [('av. lvaro otaclio 4065', 'LOGRA')]
# av. lvaro otaclio 4065 loja 01 jatica 57036-850 maceio al
#
# Entities [('av.mons.felix 554', 'LOGRA')]
# av.mons.felix 554 iraja 21235-110 rio de janeiro rj
#
# Entities [('rua pres.vargas 578', 'LOGRA')]
# rua pres.vargas 578 centro 17690-000 bastos sp
#
# Entities [('rua dondon feitosa 200', 'LOGRA')]
# rua dondon feitosa 200 centro 63660-000 taua ce
#
# Entities [('av.cinco 535', 'LOGRA')]
# av.cinco 535 centro 13500-380 rio claro sp
#
# Entities [('av. generoso marques 444', 'LOGRA')]
# av. generoso marques 444 centro 85550-000 coronel vivida pr
#
# Entities [('rua delamare 1067', 'LOGRA')]
# rua delamare 1067 centro 79300-000 corumba ms
#
# Entities [('r.dr.alberto torres 4', 'LOGRA')]
# r.dr.alberto torres 4 centro 28400-000 sao fidelis rj
#
# Entities [('praa da repblica 322', 'LOGRA')]
# praa da repblica 322 parte setor central 75503-260 itumbiara go
#
# Entities [('r.barao do rio branco 514', 'LOGRA')]
# r.barao do rio branco 514 junto a camara de vereadores centro 98130-000 julio de castilhos rs
#
# Entities [('av.antonio carlos 170', 'LOGRA')]
# av.antonio carlos 170 centro 38183-083 araxa mg
#
# Entities [('rua tete bezerra 658', 'LOGRA')]
# rua tete bezerra 658 centro 62640-000 pentecoste ce
#
# Entities [('avenida rebouas', 'LOGRA')]
# avenida rebouas pinheiros 05401-350 sao paulo sp
#
# Entities [('shis qi 5 bloco f lojas 17/125', 'LOGRA')]
# shis qi 5 bloco f lojas 17/125 centro comercial gilberto salomao lago sul 71615-560 brasilia df
#
# Entities [('praca tiradentes 195', 'LOGRA')]
# praca tiradentes 195 centro 35130-000 engenheiro caldas mg
#
# Entities [('av. presidente altino 791', 'LOGRA')]
# av. presidente altino 791 jaguar 05323-001 sao paulo sp
#
# Entities [('praca da piedade 25', 'LOGRA')]
# praca da piedade 25 centro 49400-000 lagarto se
#
# Entities [('av. ludovico da riva neto 2114', 'LOGRA')]
# av. ludovico da riva neto 2114 centro 78580-000 alta floresta mt
#
# Entities [('r.frei elseario buffon 194', 'LOGRA')]
# r.frei elseario buffon 194 terreo centro 84935-000 tomazina pr
#
# Entities [('av vitoria 2257', 'LOGRA')]
# av vitoria 2257 consolao 29045-473 vitoria es
#
# Entities [('est manoel de sa s/n', 'LOGRA')]
# est manoel de sa s/n area a-3 lote xv 26165-135 belford roxo rj
#
# Entities [('av. presidente getlio vargas 780', 'LOGRA')]
# av. presidente getlio vargas 780 centro 86770-000 santa fe pr
#
# Entities [('av. santa catarina', 'LOGRA')]
# av. santa catarina vila santa catarina 04378-100 sao paulo sp
#
# Entities [('rua cardoso de morais 524', 'LOGRA')]
# rua cardoso de morais 524 lojas b e c - parte bonsucesso 21032-000 rio de janeiro rj
#
# Entities [('av. pedro lvares cabral 2.481', 'LOGRA')]
# av. pedro lvares cabral 2.481 telgrafo 66113-190 belem pa
#
# Entities [('av conde francisco matarazzo s/n', 'LOGRA')]
# av conde francisco matarazzo s/n fundacao 09520-120 sao caetano do sul sp
#
# Entities [('av. parada pinto 217', 'LOGRA')]
# av. parada pinto 217 nova cachoeirinha 02611-002 sao paulo sp
#
# Entities [('rua pamplona 1370', 'LOGRA')]
# rua pamplona 1370 jardim paulista 01405-002 sao paulo sp
#
# Entities [('rua filipinas 458', 'LOGRA')]
# rua filipinas 458 vila centenario 82960-180 curitiba pr
#
# Entities [('rua quintino bocaiuva', 'LOGRA')]
# rua quintino bocaiuva centro 86020-150 londrina pr
#
# Entities [('rua xv de novembro', 'LOGRA')]
# rua xv de novembro parque santa monica 13561-206 sao carlos sp
#
# Entities [('av professor francisco morato 2004', 'LOGRA')]
# av professor francisco morato 2004 butanta 05512-200 sao paulo sp
#
# Entities [('av.gomes de castro 46', 'LOGRA')]
# av.gomes de castro 46 terreo-sala escritorio estilo centro 65020-230 sao luis ma
#
# Entities [('av. imperatriz leopoldina 640', 'LOGRA')]
# av. imperatriz leopoldina 640 vila nova 13073-010 campinas sp
#
# Entities [('r.jose niero 136', 'LOGRA')]
# r.jose niero 136 centro 13290-000 louveira sp
#
# Entities [('rua anchieta 18', 'LOGRA')]
# rua anchieta 18 12 andar centro 01016-030 sao paulo sp
#
# Entities [('av. solon lucena', 'LOGRA')]
# av. solon lucena centro 58700-004 patos pb
#
# Entities [('av. higienopolis 70', 'LOGRA')]
# av. higienopolis 70 parte vila boa vista 09190-360 santo andre sp
#
# Entities [('av arnolfo azevedo', 'LOGRA')]
# av arnolfo azevedo pacaembu 01236-030 sao paulo sp
#
# Entities [('rua 203', 'LOGRA')]
# rua 203 cidade operaria 65058-172 sao luis ma
#
# Entities [('rua joaquim nabuco a', 'LOGRA')]
# rua joaquim nabuco a centro 93310-002 novo hamburgo rs
#
# Entities [('est santa isabel 3365', 'LOGRA')]
# est santa isabel 3365 vila sao carlos 08599-000 itaquaquecetuba sp
#
# Entities [('rua joao moreira sales 169', 'LOGRA')]
# rua joao moreira sales 169 centro 37600-000 cambui mg
# Entities [('est coari mamia', 'LOGRA')]
# est coari mamia uniao 69460-000 coari am
#
# Entities [('praca rui barbosa 220', 'LOGRA')]
# praca rui barbosa 220 dt05/10-a - sede centro 86800-700 apucarana pr
#
# Entities [('avenida joao batista leal 34', 'LOGRA')]
# avenida joao batista leal 34 centro 11740-000 itanhaem sp
#
# Entities [('av pres.getulio vargas 2963', 'LOGRA')]
# av pres.getulio vargas 2963 bela vista ii 45996-000 teixeira de freitas ba
#
# Entities [('r.dr.afranio h.lemos 510', 'LOGRA')]
# r.dr.afranio h.lemos 510 centro 99220-000 dois lajeados rs
#
# Entities [('avenida brasilia 6.179', 'LOGRA')]
# avenida brasilia 6.179 novo mundo 81020-010 curitiba pr
#
# Entities [('rua bueno brandao 41', 'LOGRA')]
# rua bueno brandao 41 360305 centro 38430-000 tupaciguara mg
#
# Entities [('rua coronel quirino n 838', 'LOGRA')]
# rua coronel quirino n 838 cambu 13025-001 campinas sp
#
# Entities [('avenida joao pinheiro', 'LOGRA')]
# avenida joao pinheiro lourdes 30130-188 belo horizonte mg
#
# Entities [('praca nereu ramos 176', 'LOGRA')]
# praca nereu ramos 176 centro 88160-000 biguacu sc
#
# Entities [('alameda mato grosso 71', 'LOGRA')]
# alameda mato grosso 71 centro 15385-000 ilha solteira sp
#
# Entities [('rua senador alencar 144', 'LOGRA')]
# rua senador alencar 144 60746948 centro 60030-050 fortaleza ce
#
# Entities [('r.bueno de aguiar 9', 'LOGRA')]
# r.bueno de aguiar 9 centro 13260-000 morungaba sp
#
# Entities [('rua jose maria passos centr0', 'LOGRA')]
# rua jose maria passos centr0 57600-030 palmeira dos indios al
#
# Entities [('rua coronel alfredo nascimento 67', 'LOGRA')]
# rua coronel alfredo nascimento 67 distr. de sousas 13130-000 campinas sp
#
# Entities [('praca giovanni breda 1916', 'LOGRA')]
# praca giovanni breda 1916 assuncao 98503-100 sao bernardo do campo sp
#
# Entities [('av.antonio j.de moura andrade 1400', 'LOGRA')]
# av.antonio j.de moura andrade 1400 esq.c/r.prof.joao de lima paes centro 79750-000 nova andradina ms
#
# Entities [('r.vol.nelio guimaraes 370', 'LOGRA')]
# r.vol.nelio guimaraes 370 centro 14660-000 sales oliveira sp
#
# Entities [('r.cantagalo 74 15.e', 'LOGRA')]
# r.cantagalo 74 15.e 16.andares tatuape 03319-000 sao paulo sp
#
# Entities [('rua parana 185', 'LOGRA')]
# rua parana 185 centro 84900-000 ibaiti pr
#
# Entities [('avenida paulo faccini 904', 'LOGRA')]
# avenida paulo faccini 904 centro 07111-000 guarulhos sp
#
# Entities [('av.fernando guilhon 4520', 'LOGRA')]
# av.fernando guilhon 4520 centro 67200-000 marituba pa
#
# Entities [('rua carlos dietzsch 120', 'LOGRA')]
# rua carlos dietzsch 120 portao 80330-000 curitiba pr
#
# Entities [('av. farroupilha', 'LOGRA')]
# av. farroupilha centro 97610-000 sao francisco de assis rs
#
# Entities [('av. itamarati 2.373/2.377', 'LOGRA')]
# av. itamarati 2.373/2.377 pq. erasmo assuno 09271-410 santo andre sp
#
# Entities [('avenida lins de vasconcelos', 'LOGRA')]
# avenida lins de vasconcelos cambuci 01538-000 sao paulo sp
#
# Entities [('av. brigadeiro faria lima', 'LOGRA')]
# av. brigadeiro faria lima jardim paulistano 01452-000 sao paulo sp
#
# Entities [('av. washington luiz sn', 'LOGRA')]
# av. washington luiz sn vila congonhas 04626-911 sao paulo sp
#
# Entities [('r azuloes coluna 24', 'LOGRA')]
# r azuloes coluna 24 sala 324 jardim renascenca 65045-060 sao luis ma
#
# Entities [('av. nove de julho 1105', 'LOGRA')]
# av. nove de julho 1105 higienopolis 14015-170 ribeirao preto sp
#
# Entities [('av.getulio vargas 211', 'LOGRA')]
# av.getulio vargas 211 5.andar centro 88801-500 criciuma sc
#
# Entities [('r visconde do rio branco', 'LOGRA')]
# r visconde do rio branco centro 83005-420 sao jose dos pinhais pr
#
# Entities [('r.vinte e dois s/', 'LOGRA')]
# r.vinte e dois s/n qd.36 lotes 14/17 independencia 74967-150 aparecida de goiania go
#
# Entities [('av. paulista 2319', 'LOGRA')]
# av. paulista 2319 cerqueira cesar 13113-000 sao paulo sp
#
# Entities [('tv.da mangueira 40', 'LOGRA')]
# tv.da mangueira 40 centro 58297-000 rio tinto pb
#
# Entities [('av.brasil centro 11800-000', 'LOGRA')]
# av.brasil centro 11800-000 juquia sp
#
# Entities [('praca getulio vargas', 'LOGRA')]
# praca getulio vargas centro 35570-000 formiga mg
#
# Entities [('av. benedito valadares 737', 'LOGRA')]
# av. benedito valadares 737 centro 35590-000 lagoa da prata mg
#
# Entities [('av. sampaio vidal 746', 'LOGRA')]
# av. sampaio vidal 746 centro 17500-021 marilia sp
#
# Entities [('r rev americo vespucio cabral', 'LOGRA')]
# r rev americo vespucio cabral centro 94410-300 viamao rs
#
# Entities [('rua julio de castilhos 2831', 'LOGRA')]
# rua julio de castilhos 2831 centro 95600-000 taquara rs
#
# Entities [('av. romao s. rocha q-h lts. 1-2-16', 'LOGRA')]
# av. romao s. rocha q-h lts. 1-2-16 vila maria 76420-000 niquelandia go
#
# Entities [('rua 13 de maio 165', 'LOGRA')]
# rua 13 de maio 165 elias fausto 13340-000 elias fausto sp
#
# Entities [('rua odilon santos 76', 'LOGRA')]
# rua odilon santos 76 rio vermelho 41940-350 salvador ba
#
# Entities [('av. antonio f. sobrinho 985', 'LOGRA')]
# av. antonio f. sobrinho 985 centro 78820-000 jaciara mt
#
# Entities [('shis qi 05 bloco f', 'LOGRA')]
# shis qi 05 bloco f loja 77 - centro comercial lago sul 71615-560 brasilia df
#
# Entities [('rua do ouvidor 63_a', 'LOGRA')]
# rua do ouvidor 63_a centro 20040-030 rio de janeiro rj
#
# Entities [('av conde ribeiro do valle', 'LOGRA')]
# av conde ribeiro do valle lj 02 03 e 04 centro 37800-000 guaxupe mg
#
# Entities [('quadra 2 - conjunto a', 'LOGRA')]
# quadra 2 - conjunto a lote 16 s/n setor sul gama setor sul - gama 72415-100 brasilia (gama) df
#
# Entities [('rua dona primitiva vianco n 824', 'LOGRA')]
# rua dona primitiva vianco n 824 esq. com a rua euclides da cunha - parte centro 06016-008 osasco sp
#
# Entities [('av.itabuna 2721', 'LOGRA')]
# av.itabuna 2721 brasil 45000-000 vitoria da conquista ba
#
# Entities [('av. getulio', 'LOGRA')]
# av. getulio vargas 95995-000 arvorezinha rs
#
# Entities [('rua dr joo guio', 'LOGRA')]
# rua dr joo guio vila virginia 14030-440 ribeirao preto sp
#
# Entities [('av.rui barbosa s/n', 'LOGRA')]
# av.rui barbosa s/n lote 10 a 12 quadra 2 canoeiro 65940-000 grajau ma
#
# Entities [('av. barao de maruim 334', 'LOGRA')]
# av. barao de maruim 334 centro 49010-340 aracaju se
#
# Entities [('rua ushima kira 20', 'LOGRA')]
# rua ushima kira 20 granja viana 06709-048 cotia sp
#
# Entities [('r.da fazendinha 19', 'LOGRA')]
# r.da fazendinha 19 centro 18520-000 cerquilho sp
#
# Entities [('av. tarquino lopes s/n', 'LOGRA')]
# av. tarquino lopes s/n centro 65200-000 pinheiro ma
#
# Entities [('avenida kennedy n 271', 'LOGRA')]
# avenida kennedy n 271 parte jardim do mar 09726-260 sao bernardo do campo sp
#
# Entities [('rua dr. renato paes de barros n 1017', 'LOGRA')]
# rua dr. renato paes de barros n 1017 12 andar itaim bibi 04530-001 sao paulo sp
#
# Entities [('av. yolanda loureiro de carvalho 848', 'LOGRA')]
# av. yolanda loureiro de carvalho 848 centro 87350-000 ubirata pr
#
# Entities [('rua humait', 'LOGRA')]
# rua humait centro 98140-000 quevedos rs
#
# Entities [('av pres.dutra', 'LOGRA')]
# av pres.dutra cidade nova 28300-000 itaperuna rj
#
# Entities [('av.parana 2380', 'LOGRA')]
# av.parana 2380 centro 87750-000 alto parana pr
#
# Entities [('rua barao de itapetininga 298', 'LOGRA')]
# rua barao de itapetininga 298 centro 01042-000 sao paulo sp
#
# Entities [('av rodion podolsky 1835', 'LOGRA')]
# av rodion podolsky 1835 centro 17980-000 panorama sp
#
# Entities [('sbn quadra 2 - bl e lt 15', 'LOGRA')]
# sbn quadra 2 - bl e lt 15 10 andar a norte 70040-020 brasilia df
#
# Entities [('av. presidente vargas 1026', 'LOGRA')]
# av. presidente vargas 1026 centro 95320-000 nova prata rs
#
# Entities [('av. domemanuel 310', 'LOGRA')]
# av. domemanuel 310 setor rodoviario 74430-180 goiania go
#
# Entities [('pca.nove de julho 150', 'LOGRA')]
# pca.nove de julho 150 centro 18290-000 buri sp
#
# Entities [('rua paes leme', 'LOGRA')]
# rua paes leme centro 16901-010 andradina sp
#
# Entities [('r 7 de setembro', 'LOGRA')]
# r 7 de setembro centro 65284-000 governador nunes freire ma
#
# Entities [('av.osorio de paiva 1371', 'LOGRA')]
# av.osorio de paiva 1371 parangaba 60720-000 fortaleza ce
#
# Entities [('rua pres. juscelino kubitschek 604', 'LOGRA')]
# rua pres. juscelino kubitschek 604 centro 73700-000 padre bernardo go
#
# Entities [('avenida jose paulino sta', 'LOGRA')]
# avenida jose paulino sta cecilia 13140-320 paulinia sp
#
# Entities [('rua manoel ribeiro maracaja 10', 'LOGRA')]
# rua manoel ribeiro maracaja 10 centro 18590-000 bofete sp
#
# Entities [('av julio de castilho 1831', 'LOGRA')]
# av julio de castilho 1831 vl alba 79100-005 campo grande ms
#
# Entities [('av.liberato salzano 271', 'LOGRA')]
# av.liberato salzano 271 centro 98970-000 candido godoi rs
#
# Entities [('ruatres de outubro', 'LOGRA')]
# ruatres de outubro bairro languiru centro 95890-000 teutonia rs
#
# Entities [('avenida brasil', 'LOGRA')]
# avenida brasil jardim amanda ii 13188-252 hortolandia sp
#
# Entities [('rua maria freitas 136', 'LOGRA')]
# rua maria freitas 136 madureira 21351-010 rio de janeiro rj
#
# Entities [('av corifeu de azevedo marques 1248', 'LOGRA')]
# av corifeu de azevedo marques 1248 butant 05582-001 sao paulo sp
#
# Entities [('av assuncao 904', 'LOGRA')]
# av assuncao 904 centro 28900-000 cabo frio rj
#
# Entities [('av cruzeiro do sul 1100', 'LOGRA')]
# av cruzeiro do sul 1100 caninde 03033-020 sao paulo sp
#
# Entities [('praca getulio vargas', 'LOGRA')]
# praca getulio vargas loja centro 37002-035 varginha mg
#
# Entities [('av.joao cesar de oliveira 2669', 'LOGRA')]
# av.joao cesar de oliveira 2669 eldorado 32315-140 contagem mg
#
# Entities [('av. pres. juscelino kubitschek 2041/2235 bloco', 'LOGRA')]
# av. pres. juscelino kubitschek 2041/2235 bloco a (parte) vila olmpia 04543-011 sao paulo sp
#
# Entities [('rua felipe schmidt 497', 'LOGRA')]
# rua felipe schmidt 497 centro 88750-000 braco do norte sc
#
# Entities [('av.mal.floriano peixoto 309', 'LOGRA')]
# av.mal.floriano peixoto 309 pompeia 11060-303 santos sp
#
# Entities [('avenida brasil 390', 'LOGRA')]
# avenida brasil 390 iguacu 35162-036 ipatinga mg
#
# Entities [('r.dias ferreira 33', 'LOGRA')]
# r.dias ferreira 33 lj a e b leblon 22431-050 rio de janeiro rj
#
# Entities [('rua dr. mello peixoto 186', 'LOGRA')]
# rua dr. mello peixoto 186 centro 14930-000 boa esperanca do sul sp
#
# Entities [('av. osvaldo aranha', 'LOGRA')]
# av. osvaldo aranha sala 101 centro 95330-000 veranopolis rs
#
# Entities [('av.raimundo veridiano cardoso 42', 'LOGRA')]
# av.raimundo veridiano cardoso 42 bela vista 68456-760 tucurui pa
#
# Entities [('praca antonio augusto genelhu nr 122', 'LOGRA')]
# praca antonio augusto genelhu nr 122 centro 29780-000 sao gabriel da palha es
#
# Entities [('av. avelino chaves s/n', 'LOGRA')]
# av. avelino chaves s/n centro 69940-000 sena madureira ac
#
# Entities [('av.carlos mauro 336', 'LOGRA')]
# av.carlos mauro 336 centro 13525-000 aguas de sao pedro sp
#
# Entities [('av.mons.scalabrini 693', 'LOGRA')]
# av.mons.scalabrini 693 centro 99200-000 guapore rs
#
# Entities [('av.rio branco 81-a', 'LOGRA')]
# av.rio branco 81-a centro 20040-004 rio de janeiro rj
#
# Entities [('r.eng.rui mesquita 387', 'LOGRA')]
# r.eng.rui mesquita 387 centro 65765-000 dom pedro ma
#
# Entities [('avenida duque de caxias', 'LOGRA')]
# avenida duque de caxias santa efigenia 01214-000 sao paulo sp
#
# Entities [('rua guarani 303', 'LOGRA')]
# rua guarani 303 centro 85501-050 pato branco pr
#
# Entities [('av.onze de marco 129', 'LOGRA')]
# av.onze de marco 129 centro 65780-000 governador eugenio barros ma
#
# Entities [('avenida andrade neves', 'LOGRA')]
# avenida andrade neves jardim chapadao 13070-000 campinas sp
#
# Entities [('rua lvares penteado 195', 'LOGRA')]
# rua lvares penteado 195 centro 01012-001 sao paulo sp
#
# Entities [('r.sao paulo 151', 'LOGRA')]
# r.sao paulo 151 centro 35500-006 divinopolis mg
#
# Entities [('sria qe 40', 'LOGRA')]
# sria qe 40 conjunto h loja 09 guar ii 71070-082 brasilia df
#
# Entities [('av madre benvenuta 883', 'LOGRA')]
# av madre benvenuta 883 santa monica 88035-000 florianopolis sc
#
# Entities [('avenida armindo moura 581', 'LOGRA')]
# avenida armindo moura 581 boa viagem 51130-180 recife pe
#
# Entities [('avenida caxanga', 'LOGRA')]
# avenida caxanga cordeiro 50731-000 recife pe
#
# Entities [('r do comercio', 'LOGRA')]
# r do comercio centro 14400-660 franca sp
#
# Entities [('rua quinze de novembro 228/246', 'LOGRA')]
# rua quinze de novembro 228/246 centro 18010-081 sorocaba sp
#
# Entities [('av tiradentes s/n', 'LOGRA')]
# av tiradentes s/n aman independencia 27534-970 resende rj
#
# Entities [('av. casper libero 356', 'LOGRA')]
# av. casper libero 356 sta efigenia 01033-000 sao paulo sp
#
# Entities [('r.cap.zenobio da costa 123', 'LOGRA')]
# r.cap.zenobio da costa 123 lojas 101/102 centro 26950-000 paty do alferes rj
#
# Entities [('rua xv de novembro 430', 'LOGRA')]
# rua xv de novembro 430 centro 19700-000 paraguacu paulista sp
#
# Entities [('rua joao batista 11', 'LOGRA')]
# rua joao batista 11 centro 55750-000 surubim pe
#
# Entities [('jornalista moacir padilha quadra', 'LOGRA')]
# jornalista moacir padilha quadra jardim primavera 25215-250 duque de caxias rj
#
# Entities [('rua conselheiro franco 391', 'LOGRA')]
# rua conselheiro franco 391 centro 48010-010 alagoinhas ba
#
# Entities [('pca.sen.joaquim pires 336', 'LOGRA')]
# pca.sen.joaquim pires 336 centro 64100-000 barras pi
#
# Entities [('avenida silves 187', 'LOGRA')]
# avenida silves 187 crespo 69073-175 manaus am
#
# Entities [('av. paracatu 539', 'LOGRA')]
# av. paracatu 539 centro 38780-000 vazante mg
#
# Entities [('rua rangel pestana 295', 'LOGRA')]
# rua rangel pestana 295 centro 13201-000 jundiai sp
#
# Entities [('r barao de jundiai', 'LOGRA')]
# r barao de jundiai centro 13201-012 jundiai sp
#
# Entities [('av brig faria lima 2537 2541/2525 -andterreo - ljs 01 02. 03 -', 'LOGRA')]
# av brig faria lima 2537 2541/2525 -andterreo - ljs 01 02. 03 - edif.igua jardim paulistano 01452-000 sao paulo sp
#
# Entities [('rua nossa senhora aparecida ii tavares de', 'LOGRA')]
# rua nossa senhora aparecida ii tavares de lira centro 59280-000 macaiba rn
#
# Entities [('r.conego vasconcelos 186', 'LOGRA')]
# r.conego vasconcelos 186 bangu 21810-012 rio de janeiro rj
#
# Entities [('quadra 01 conj. c lote 24', 'LOGRA')]
# quadra 01 conj. c lote 24 ade centro-norte 72237-130 brasilia (ceilandia) df
#
# Entities [('av.dr.cristiano guimaraes 1811', 'LOGRA')]
# av.dr.cristiano guimaraes 1811 planalto 31720-300 belo horizonte mg
#
# Entities [('av n sra do sabara', 'LOGRA')]
# av n sra do sabara vila emir 04447-020 sao paulo sp
#
# Entities [('rua coronel luiz pereira dos santos 243', 'LOGRA')]
# rua coronel luiz pereira dos santos 243 lote 01 quadra 10 centro 24890-000 tangua rj
#
# Entities [('av. getulio vargas 5375', 'LOGRA')]
# av. getulio vargas 5375 centro 35930-000 joao monlevade mg
#
# Entities [('av. 28 de setembro 264', 'LOGRA')]
# av. 28 de setembro 264 vila isabel 20551-000 rio de janeiro rj
#
# Entities [('rua brasil 613', 'LOGRA')]
# rua brasil 613 centro 15650-000 estrela d'oeste sp
#
# Entities [('rua ten. pedro egidio 220', 'LOGRA')]
# rua ten. pedro egidio 220 centro 18640-000 pardinho sp
#
# Entities [('r.odilon negrao 629', 'LOGRA')]
# r.odilon negrao 629 esq.c/av.francisco porto centro 14900-000 itapolis sp
#
# Entities [('avenida brasil 228', 'LOGRA')]
# avenida brasil 228 centro 85485-000 tres barras do parana pr
#
# Entities [('av.29 de dezembro 1678', 'LOGRA')]
# av.29 de dezembro 1678 centro 68650-000 capitao poco pa
#
# Entities [('rua das laranjeiras 495/rua gal glicerio 32', 'LOGRA')]
# rua das laranjeiras 495/rua gal glicerio 32 laranjeiras 22240-002 rio de janeiro rj
#
# Entities [("av. prof. othon da gama d'eca 900", 'LOGRA')]
# av. prof. othon da gama d'eca 900 centro 88015-240 florianopolis sc
#
# Entities [('praca joao pessoa 26', 'LOGRA')]
# praca joao pessoa 26 centro 06850-035 itapecerica da serra sp
#
# Entities [('avenida tancredo neves', 'LOGRA')]
# avenida tancredo neves setor institucional 76872-854 ariquemes ro
#
# Entities [('av. mario melo s/n', 'LOGRA')]
# av. mario melo s/n centro c.igarassu 53610-600 igarassu pe
#
# Entities [('rua presidente dutra 285', 'LOGRA')]
# rua presidente dutra 285 centro 88860-000 sideropolis sc
# Entities [('rua da carioca 77 e 81', 'LOGRA')]
# rua da carioca 77 e 81 centro 20050-008 rio de janeiro rj
#
# Entities [('shc/sw clsw 304 bloco b', 'LOGRA'), (') setor sudoeste 70670-622 brasilia df', 'LOGRA')]
# shc/sw clsw 304 bloco b lojas c/numeros pares de 32 a 50) setor sudoeste 70670-622 brasilia df
#
# Entities [('rua dr. pereira dos santos', 'LOGRA')]
# rua dr. pereira dos santos centro 24800-041 itaborai rj
#
# Entities [('pca.nove de janeiro 20', 'LOGRA')]
# pca.nove de janeiro 20 terreo centro 62380-000 guaraciaba do norte ce
#
# Entities [('rua professor atilio innocenti', 'LOGRA')]
# rua professor atilio innocenti conjunto 1601 - 15 andar 00000-000 sao paulo sp
#
# Entities [('r.anisio de abreu 600', 'LOGRA')]
# r.anisio de abreu 600 vizinho aos correios centro 64930-000 gilbues pi
#
# Entities [('praa da repblica s/n', 'LOGRA')]
# praa da repblica s/n centro 68170-000 juruti pa
#
# Entities [('r.pres.juscelino 234', 'LOGRA')]
# ...
#
# Entities [('r.pres.castelo branco 63', 'LOGRA')]
# r.pres.castelo branco 63 centro 89920-000 guaraciaba sc
#
# Entities [('rchafic maluf 396', 'LOGRA')]
# rchafic maluf 396 sto amaro 04710-160 sao paulo sp
#
# Entities [('praa dr. jos sacramento e silva 64', 'LOGRA')]
# praa dr. jos sacramento e silva 64 centro 18540-000 porto feliz sp
#
# Entities [('pca alencastro 0 quadra 70 - lote 74', 'LOGRA')]
# pca alencastro 0 quadra 70 - lote 74 centro norte 78005-360 cuiaba mt
#
# Entities [('av.sao paulo 1538', 'LOGRA')]
# av.sao paulo 1538 sala 2 centro 87890-000 terra rica pr
#
# Entities [('av.bernardo de vasconcelos 2429', 'LOGRA')]
# av.bernardo de vasconcelos 2429 ipiranga 31160-440 belo horizonte mg
#
# Entities [('av. aniceto zacchi 228', 'LOGRA')]
# av. aniceto zacchi 228 loja 02 ponte do imaruim 88130-300 palhoca sc
#
# Entities [('r.jose augusto chaves 468', 'LOGRA')]
# r.jose augusto chaves 468 centro 38900-000 bambui mg
#
# Entities [('rua jardim botnico 635 - a', 'LOGRA')]
# rua jardim botnico 635 - a jardim botnico 22470-050 rio de janeiro rj
#
# Entities [('rua 93 s/n', 'LOGRA')]
# rua 93 s/n monte dourado 68240-000 almeirim pa
#
# Entities [('r.dr. hernani hugo gomes 16', 'LOGRA')]
# r.dr. hernani hugo gomes 16 sala 200 c macio 59082-270 natal rn
#
# Entities [('av. espanha', 'LOGRA')]
# av. espanha centro 96740-000 arroio dos ratos rs
#
# Entities [('rua caetano furquim 26', 'LOGRA')]
# rua caetano furquim 26 centro 27700-000 vassouras rj
#
# Entities [('rua conde de bonfim 390 a - loja', 'LOGRA')]
# rua conde de bonfim 390 a - loja sobreloja e subsolo tijuca 20520-054 rio de janeiro rj
#
# Entities [('av.brasil 4365', 'LOGRA')]
# av.brasil 4365 banco do brasil manguinhos 21040-900 rio de janeiro rj
#
# Entities [('avenida paulo ayres', 'LOGRA')]
# avenida paulo ayres parque pinheiros 06767-220 taboao da serra sp
#
# Entities [('av das americas', 'LOGRA')]
# av das americas barra da tijuca 22631-004 rio de janeiro rj
#
# Entities [('av.amazonas 553', 'LOGRA')]
# av.amazonas 553 centro 75930-000 maurilandia go
#
# Entities [('rua tijucas 20', 'LOGRA')]
# rua tijucas 20 estreito 88075-540 florianopolis sc
#
# Entities [('avenida nove de julho 1223', 'LOGRA')]
# avenida nove de julho 1223 parte jardim sumare 14025-000 ribeirao preto sp
#
# Entities [('rua agamenon magalhaes 576', 'LOGRA')]
# rua agamenon magalhaes 576 centro 56100-000 salgueiro pe
#
# Entities [('rua barao do triunfo 491', 'LOGRA')]
# rua barao do triunfo 491 brooklin 45560-000 sao paulo sp
#
# Entities [('av francisco porto (portinox)', 'LOGRA')]
# av francisco porto (portinox) qd g lt 112 jardins 49025-230 aracaju se
#
# Entities [('r bahia 639', 'LOGRA')]
# r bahia 639 centro 79002-952 campo grande ms
#
# Entities [('pca.mons.jose maria s.bezerra 231', 'LOGRA')]
# pca.mons.jose maria s.bezerra 231 centro 15410-000 cajobi sp
#
# Entities [('estrada loureno correa gomes', 'LOGRA')]
# estrada loureno correa gomes centro 95515-000 caraa rs
#
# Entities [('rua visconde de piraja 357', 'LOGRA')]
# rua visconde de piraja 357 loja a ipanema 22410-000 rio de janeiro rj
#
# Entities [('av. rio branco 319', 'LOGRA')]
# av. rio branco 319 centro 65725-500 pedreiras ma
#
# Entities [('pca.nove de julho 122', 'LOGRA')]
# pca.nove de julho 122 centro 14870-325 jaboticabal sp
#
# Entities [('av.mal.cordeiro de farias 855', 'LOGRA')]
# av.mal.cordeiro de farias 855 centro 65620-000 coelho neto ma
#
# Entities [('rua prudente de moraes 163', 'LOGRA')]
# rua prudente de moraes 163 centro 89400-000 porto uniao sc
#
# Entities [('pca.castelo branco 488', 'LOGRA')]
# pca.castelo branco 488 centro 45836-000 itamaraju ba
#
# Entities [('rua boqueiro 351', 'LOGRA')]
# rua boqueiro 351 igara 92410-350 canoas rs
#
# Entities [('rua dr. gabriel de rezende 573/575', 'LOGRA')]
# rua dr. gabriel de rezende 573/575 vila invernada 33500-000 sao paulo sp
#
# Entities [('av. assis brasil 3940', 'LOGRA')]
# av. assis brasil 3940 12 andar passo d'areia 91010-003 porto alegre rs
#
# Entities [('av.de cillo 1688', 'LOGRA')]
# av.de cillo 1688 jd.sao paulo 13466-550 americana sp
#
# Entities [('avenida francisco glicrio 892', 'LOGRA')]
# avenida francisco glicrio 892 (parte) centro 13012-000 campinas sp
#
# Entities [('av.sete de setembro 751', 'LOGRA')]
# av.sete de setembro 751 centro 36950-000 ipanema mg
#
# Entities [('r sete de setembro 475 esq. c/ salvador menchior', 'LOGRA')]
# r sete de setembro 475 esq. c/ salvador menchior centro 18950-000 ipaussu sp
#
# Entities [('rua estevao alves correa 562', 'LOGRA')]
# rua estevao alves correa 562 centro 79200-000 aquidauana ms
#
# Entities [('estrada do campo limpo 3949', 'LOGRA')]
# estrada do campo limpo 3949 pirajussara 05787-000 sao paulo sp
#
# Entities [('av. conselheiro joo gaya n. 1300', 'LOGRA')]
# av. conselheiro joo gaya n. 1300 centro 88375-000 navegantes sc
#
# Entities [('rua general sampaio', 'LOGRA')]
# rua general sampaio loja 01 sao pelegrino 95097-970 caxias do sul rs
#
# Entities [('r. belem 26', 'LOGRA')]
# r. belem 26 centro 86026-000 londrina pr
#
# Entities [('av. llete bueno 148', 'LOGRA')]
# av. llete bueno 148 centro 75450-000 itaucu go
#
# Entities [('av.coronel colares moreira 420', 'LOGRA')]
# av.coronel colares moreira 420 qd ac lote ii renascenca ii 65075-440 sao luis ma
#
# Entities [('avenida luis de camoes num 575', 'LOGRA')]
# avenida luis de camoes num 575 coral 88523-000 lages sc
#
# Entities [('praca visconde figueira 11', 'LOGRA')]
# praca visconde figueira 11 360305 centro 28470-000 santo antonio de padua rj
#
# Entities [('r.paulo guerreiro franco 604', 'LOGRA')]
# r.paulo guerreiro franco 604 centro 17560-000 vera cruz sp
#
# Entities [('ncleo cidade de deus s/n', 'LOGRA')]
# ncleo cidade de deus s/n prdio rubi trreo sala 2 vila yara 06029-900 osasco sp
#
# Entities [('alameda paulista 1957', 'LOGRA')]
# alameda paulista 1957 jardim paulistano 14810-270 araraquara sp
#
# Entities [('rua senador pompeu 716', 'LOGRA')]
# rua senador pompeu 716 centro 60025-000 fortaleza ce
#
# Entities [('rua noronha torrezao 17', 'LOGRA')]
# rua noronha torrezao 17 lojas 101 e santa rosa 24240-180 niteroi rj
#
# Entities [('av. nove de julho 31', 'LOGRA')]
# av. nove de julho 31 centro 11920-000 iguape sp
#
# Entities [('av. esperana 220/230', 'LOGRA')]
# av. esperana 220/230 vila zaira 07095-005 guarulhos sp
#
# Entities [('pca. rui barbosa 127', 'LOGRA')]
# pca. rui barbosa 127 centro 15400-000 olimpia sp
#
# Entities [('avenida brasil', 'LOGRA')]
# avenida brasil jardim america 01430-000 sao paulo sp
#
# Entities [('r.dos pinheiros s/', 'LOGRA')]
# r.dos pinheiros s/n centro 89906-000 paraiso sc
#
# Entities [('rua marechal deodoro 941 - trreo', 'LOGRA')]
# rua marechal deodoro 941 - trreo centro 80060-010 curitiba pr
#
# Entities [('praca monsenhor berenguer', 'LOGRA')]
# praca monsenhor berenguer centro 48800-000 monte santo ba
#
# Entities [('avenida do exercito bloco a bloco h', 'LOGRA')]
# avenida do exercito bloco a bloco h trreo setor militar urbano 70630-901 brasilia df
#
# Entities [('av. getulio vargas 1855', 'LOGRA')]
# av. getulio vargas 1855 monte castelo 65020-300 sao luis ma
#
# Entities [('r neo alves martins', 'LOGRA')]
# r neo alves martins zona 01 87013-060 maringa pr
#
# Entities [('rua halfeld 634', 'LOGRA')]
# rua halfeld 634 centro 36010-002 juiz de fora mg
#
# Entities [('avenida dos pioneiros 2355', 'LOGRA')]
# avenida dos pioneiros 2355 centro 84145-000 carambei pr
#
# Entities [('av. getulio vargas 76', 'LOGRA')]
# av. getulio vargas 76 centro 35620-000 abaete mg
#
# Entities [('rua rio grande do norte 645', 'LOGRA')]
# rua rio grande do norte 645 60746948 funcionarios 30130-130 belo horizonte mg
#
# Entities [('praca da independencia 500', 'LOGRA')]
# praca da independencia 500 centro 36500-000 uba mg
# Entities [('av. engenheiro', 'LOGRA')]
# av. engenheiro heitor antnio eiras garcia n 4.185 jardim raposo tavares 05564-100 sao paulo sp
#
# Entities [('av. manoel goulart 2400', 'LOGRA')]
# av. manoel goulart 2400 jardim das rosas 19060-000 presidente prudente sp
#
# Entities [('avenida visconde de souza franco 857', 'LOGRA')]
# avenida visconde de souza franco 857 reduto 66053-000 belem pa
#
# Entities [('rua dr. costa aguiar 700', 'LOGRA')]
# rua dr. costa aguiar 700 centro 13010-061 campinas sp
#
# Entities [('pca.cel.flavio fernandes 39', 'LOGRA')]
# pca.cel.flavio fernandes 39 centro 37405-000 monsenhor paulo mg
#
# Entities [('r bom pastor 153', 'LOGRA')]
# r bom pastor 153 2. e 3. andares ipiranga 04203-050 sao paulo sp
#
# Entities [('rua dr. xavier da silva 834', 'LOGRA')]
# rua dr. xavier da silva 834 centro 86410-000 ribeirao claro pr
#
# Entities [('av. carlos lindemberg', 'LOGRA')]
# av. carlos lindemberg centro 29230-000 anchieta es
#
# Entities [('av.caxanga cordeiro 50630-000', 'LOGRA')]
# av.caxanga cordeiro 50630-000 recife pe
#
# Entities [('av. governador joao durval carneiro 3665', 'LOGRA')]
# av. governador joao durval carneiro 3665 boulevard shopping loja 123 caseb 44052-064 feira de santana ba
#
# Entities [('av. osvaldo aranha', 'LOGRA')]
# av. osvaldo aranha bonfim 90210-000 porto alegre rs
#
# Entities [('av. getulio vargas 362', 'LOGRA')]
# av. getulio vargas 362 centro 36010-110 juiz de fora mg
#
# Entities [('praca getlio vargas 80', 'LOGRA')]
# praca getlio vargas 80 centro 86350-000 santa mariana pr
#
# Entities [('avenida joo ramalho 205', 'LOGRA')]
# avenida joo ramalho 205 vila nomia 09371-520 maua sp
#
# Entities [('rua emilia marengo', 'LOGRA')]
# rua emilia marengo vila regente feijo 03336-000 sao paulo sp
#
# Entities [('rua augusta 2575', 'LOGRA')]
# rua augusta 2575 cerqueira cesar 01413-100 sao paulo sp
#
# Entities [('rua osvaldo cruz 36', 'LOGRA')]
# rua osvaldo cruz 36 centro 16010-040 aracatuba sp
#
# Entities [('av. senador lemos 1095', 'LOGRA')]
# av. senador lemos 1095 telegrafo 66120-000 belem pa
#
# Entities [('av.anhanguera 5996 qd.1-a lote 9', 'LOGRA')]
# av.anhanguera 5996 qd.1-a lote 9 setor aeroporto 74075-010 goiania go
#
# Entities [('av. rui barbosa 758', 'LOGRA')]
# av. rui barbosa 758 parte centro 27910-362 macae rj
#
# Entities [('r parsifal barroso s/n', 'LOGRA')]
# r parsifal barroso s/n centro 62560-000 marco ce
#
# Entities [('rua general urquiza 67', 'LOGRA')]
# rua general urquiza 67 loja e leblon 22431-040 rio de janeiro rj
#
# Entities [('av.do contorno 1600', 'LOGRA')]
# av.do contorno 1600 floresta 30110-008 belo horizonte mg
#
# Entities [('av.dr.guilherme dumont vilares 1199', 'LOGRA')]
# av.dr.guilherme dumont vilares 1199 vl. suzana 05640-000 sao paulo sp
#
# Entities [('saun quadra 5 bloco b', 'LOGRA')]
# saun quadra 5 bloco b ed. bb torre central - 6 andar a norte 70040-912 brasilia df
#
# Entities [('avenida presidente juscelino kubitschek', 'LOGRA')]
# avenida presidente juscelino kubitschek 11 andar edificio wtorre plaza jk torre d vila nova conceio 04543-011 sao paulo sp
#
# Entities [('r.pe.felipe 30', 'LOGRA')]
# r.pe.felipe 30 centro 93265-010 esteio rs
#
# Entities [('r.rodolfo miranda 368', 'LOGRA')]
# r.rodolfo miranda 368 centro 17570-000 oriente sp
#
# Entities [('av. da saudade 1421', 'LOGRA')]
# av. da saudade 1421 campos eliseos 14080-000 ribeirao preto sp
#
# Entities [('r quinze de dezembro 147', 'LOGRA')]
# r quinze de dezembro 147 centro 75024-070 anapolis go
#
# Entities [('av dorival candido luz de oliveira', 'LOGRA')]
# av dorival candido luz de oliveira parque olinda 94060-000 gravatai rs
#
# Entities [('avenida pereira da silva', 'LOGRA')]
# avenida pereira da silva vila santa rosalia 18095-340 sorocaba sp
#
# Entities [('avenida pinheiro machado', 'LOGRA')]
# avenida pinheiro machado so cristovo 76804-046 porto velho ro
#
# Entities [('rodovia br 316 km 1', 'LOGRA')]
# rodovia br 316 km 1 atalaia 67013-000 ananindeua pa
#
# Entities [('av. automovel clube 2384', 'LOGRA')]
# av. automovel clube 2384 loja 1062 vilar dos teles 25515-126 sao joao de meriti rj
#
# Entities [('r.visc.de guarapuava 310', 'LOGRA')]
# r.visc.de guarapuava 310 centro 85200-000 pitanga pr
#
# Entities [('av contagem s/n', 'LOGRA')]
# av contagem s/n qd 40 vila nova vista 34710-000 sabara mg
#
# Entities [('praa jos bonifcio 936', 'LOGRA')]
# praa jos bonifcio 936 centro 13400-340 piracicaba sp
#
# Entities [('r.uruguai 185', 'LOGRA')]
# r.uruguai 185 terreo/sobreloja centro 90010-140 porto alegre rs
#
# Entities [('r.miguel bournier 4', 'LOGRA')]
# r.miguel bournier 4 lojas 1 e 2 barra avenida 40140-190 salvador ba
#
# Entities [('rua cel. jose nava', 'LOGRA')]
# rua cel. jose nava centro 65950-000 barra do corda ma
#
# Entities [('av. brasil', 'LOGRA')]
# av. brasil centro 96503-491 cachoeira do sul rs
#
# Entities [('rua saul brandalise 10', 'LOGRA')]
# rua saul brandalise 10 centro 89560-000 videira sc
#
# Entities [('pca.brasil 100', 'LOGRA')]
# pca.brasil 100 centro 27197-000 pinheiral rj
#
# Entities [('avenida adolfo pinheiro n 478', 'LOGRA')]
# avenida adolfo pinheiro n 478 parte santo amaro 04734-000 sao paulo sp
#
# Entities [('rua santa catarina 211', 'LOGRA')]
# rua santa catarina 211 conjunto 2 centro 09510-120 sao caetano do sul sp
#
# Entities [('av.pio xii esq.c/rua da', 'LOGRA')]
# av.pio xii esq.c/rua da imprensa quadra 1 lotes 5/6 vl.aurora oeste 74425-098 goiania go
#
# Entities [('rua doutor ferreira correia 119', 'LOGRA')]
# rua doutor ferreira correia 119 centro 84460-000 ivai pr
#
# Entities [('rua senador flaquer', 'LOGRA')]
# rua senador flaquer 1 andar centro 09010-160 santo andre sp
#
# Entities [('av.mato grosso 445 qd.47 lote 15', 'LOGRA')]
# av.mato grosso 445 qd.47 lote 15 centro 79770-000 anaurilandia ms
#
# Entities [('estrada do portela 222', 'LOGRA')]
# estrada do portela 222 lojas 108 a 116 madureira 21351-050 rio de janeiro rj
#
# Entities [('av. meriti 2257', 'LOGRA')]
# av. meriti 2257 vila kosmos 21220-202 rio de janeiro rj
#
# Entities [('rua silveira martins 206', 'LOGRA')]
# rua silveira martins 206 cabula 41150-000 salvador ba
#
# Entities [('av 136 sn quadra f44 lt 22', 'LOGRA')]
# av 136 sn quadra f44 lt 22 setor sul 00000-000 goiania go
#
# Entities [('av alphaville qd cs 3', 'LOGRA')]
# av alphaville qd cs 3 alphaville i 41701-015 salvador ba
#
# Entities [('praca xv de novembro 01', 'LOGRA')]
# praca xv de novembro 01 centro 44420-000 maragogipe ba
#
# Entities [('av. allan kardec 1451', 'LOGRA')]
# av. allan kardec 1451 lojas 15/16 e 16a centro 14701-904 bebedouro sp
#
# Entities [('av. nacoes unidas 10999', 'LOGRA')]
# av. nacoes unidas 10999 loja 2 bela vista 04578-000 sao paulo sp
#
# Entities [('r.cel.jose pedro de lima 317', 'LOGRA')]
# r.cel.jose pedro de lima 317 centro 18440-000 itabera sp
#
# Entities [('av.dos autonomistas 5152', 'LOGRA')]
# av.dos autonomistas 5152 quitauna 06194-060 osasco sp
#
# Entities [('rodovia br-262 km 01 - s/n', 'LOGRA')]
# rodovia br-262 km 01 - s/n jardim america 29140-261 cariacica es
#
# Entities [('r.quinze de janeiro 88', 'LOGRA')]
# r.quinze de janeiro 88 centro 92010-300 canoas rs
#
# Entities [('av. jose paulino 970', 'LOGRA')]
# av. jose paulino 970 centro 13140-320 paulinia sp
#
# Entities [('avenida sto. antonio 194', 'LOGRA')]
# avenida sto. antonio 194 centro 55700-000 limoeiro pe
#
# Entities [('rua felipe sabag 200', 'LOGRA')]
# rua felipe sabag 200 salas 5t e 5t1 centro 94000-000 ribeirao pires sp
#
# Entities [('r.coronel francisco rocha 121/131', 'LOGRA')]
# r.coronel francisco rocha 121/131 centro 29380-000 muniz freire es
#
# Entities [('r.lobo da costa 1315', 'LOGRA')]
# r.lobo da costa 1315 3 4 e 5.andar centro 96010-150 pelotas rs
#
# Entities [('av.uirapuru 710', 'LOGRA')]
# av.uirapuru 710 centro 86701-010 arapongas pr
#
# Entities [('ruajoaofernandes neto 1345', 'LOGRA')]
# ruajoaofernandes neto 1345 loja belford roxo 26130-050 belford roxo rj
#
# Entities [('avenida goias', 'LOGRA')]
# avenida goias 1659/1661/1665 santo antonio 09521-310 sao caetano do sul sp
#
# Entities [('rua schilling 590/606', 'LOGRA')]
# rua schilling 590/606 vila leopoldina 05302-001 sao paulo sp
#
# Entities [('av. santo amaro 4584', 'LOGRA')]
# av. santo amaro 4584 60746948 santo amaro 04702-000 sao paulo sp
#
# Entities [('praca da bandeira 85', 'LOGRA')]
# praca da bandeira 85 360305 centro 12281-630 cacapava sp
#
# Entities [('av republica argentina 5044', 'LOGRA')]
# av republica argentina 5044 jardim sao paulo 85856-378 foz do iguacu pr
#
# Entities [('avenida caxanga', 'LOGRA')]
# avenida caxanga zumbi 50720-655 recife pe
#
# Entities [('rua tiburcio targino 258', 'LOGRA')]
# rua tiburcio targino 258 centro 61700-000 aquiraz ce
#
# Entities [('rua cel. teofilo leme 1384', 'LOGRA')]
# rua cel. teofilo leme 1384 centro 12900-005 braganca paulista sp

# %% [markdown]
# Frase qualquer

# %%
phrase = "SHVP Rua 12 435 casa 22 lote 1"

doc = nlp(phrase)
print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
print(phrase)
# Out:
# Entities [('SHVP Rua 12 435', 'LOGRA')]
# SHVP Rua 12 435 casa 22 lote 1
